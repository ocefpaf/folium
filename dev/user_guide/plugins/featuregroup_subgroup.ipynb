# %%
import folium
import folium.plugins

# %% [markdown]
# ## FeatureGroupSubGroup
#
# ### Sub categories
#
# Disable all markers in the category, or just one of the subgroup.

# %%
m = folium.Map(location=[0, 0], zoom_start=6)

fg = folium.FeatureGroup(name="groups")
m.add_child(fg)

g1 = folium.plugins.FeatureGroupSubGroup(fg, "group1")
m.add_child(g1)

g2 = folium.plugins.FeatureGroupSubGroup(fg, "group2")
m.add_child(g2)

folium.Marker([-1, -1]).add_to(g1)
folium.Marker([1, 1]).add_to(g1)

folium.Marker([-1, 1]).add_to(g2)
folium.Marker([1, -1]).add_to(g2)

folium.LayerControl(collapsed=False).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_aad9d028a4aa6a1a1b37797ef93ebf54 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_aad9d028a4aa6a1a1b37797ef93ebf54&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_aad9d028a4aa6a1a1b37797ef93ebf54 = L.map(
#                 &quot;map_aad9d028a4aa6a1a1b37797ef93ebf54&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_43c875560cfdb2246c9bc0dcc9568dc3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_43c875560cfdb2246c9bc0dcc9568dc3.addTo(map_aad9d028a4aa6a1a1b37797ef93ebf54);
#
#
#             var feature_group_5f72f4bfda6c4d70235dc11806fca5f1 = L.featureGroup(
#                 {}
#             );
#
#
#             feature_group_5f72f4bfda6c4d70235dc11806fca5f1.addTo(map_aad9d028a4aa6a1a1b37797ef93ebf54);
#
#
#             var feature_group_sub_group_6dafb2f9e36ab20408ad42ff398d32ff = L.featureGroup.subGroup(
#                 feature_group_5f72f4bfda6c4d70235dc11806fca5f1
#             );
#
#
#             var marker_30dd50173719507aa78533a9f03b86f6 = L.marker(
#                 [-1.0, -1.0],
#                 {}
#             ).addTo(feature_group_sub_group_6dafb2f9e36ab20408ad42ff398d32ff);
#
#
#             var marker_f567d55827f104108808b4f3e98f2c21 = L.marker(
#                 [1.0, 1.0],
#                 {}
#             ).addTo(feature_group_sub_group_6dafb2f9e36ab20408ad42ff398d32ff);
#
#
#             feature_group_sub_group_6dafb2f9e36ab20408ad42ff398d32ff.addTo(map_aad9d028a4aa6a1a1b37797ef93ebf54);
#
#
#             var feature_group_sub_group_584253ccd226cf0e5fa883a9549b9838 = L.featureGroup.subGroup(
#                 feature_group_5f72f4bfda6c4d70235dc11806fca5f1
#             );
#
#
#             var marker_731d4f5181dd91727c33d614f6a61257 = L.marker(
#                 [-1.0, 1.0],
#                 {}
#             ).addTo(feature_group_sub_group_584253ccd226cf0e5fa883a9549b9838);
#
#
#             var marker_01afaaa409ef8a689065212040d342a3 = L.marker(
#                 [1.0, -1.0],
#                 {}
#             ).addTo(feature_group_sub_group_584253ccd226cf0e5fa883a9549b9838);
#
#
#             feature_group_sub_group_584253ccd226cf0e5fa883a9549b9838.addTo(map_aad9d028a4aa6a1a1b37797ef93ebf54);
#
#
#             var layer_control_a1a6ee81bc23d603097862536239fa5a_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_43c875560cfdb2246c9bc0dcc9568dc3,
#                 },
#                 overlays :  {
#                     &quot;groups&quot; : feature_group_5f72f4bfda6c4d70235dc11806fca5f1,
#                     &quot;group1&quot; : feature_group_sub_group_6dafb2f9e36ab20408ad42ff398d32ff,
#                     &quot;group2&quot; : feature_group_sub_group_584253ccd226cf0e5fa883a9549b9838,
#                 },
#             };
#             let layer_control_a1a6ee81bc23d603097862536239fa5a = L.control.layers(
#                 layer_control_a1a6ee81bc23d603097862536239fa5a_layers.base_layers,
#                 layer_control_a1a6ee81bc23d603097862536239fa5a_layers.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: false, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_aad9d028a4aa6a1a1b37797ef93ebf54);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Marker clusters across groups
#
# Create two subgroups, but cluster markers together.

# %%
m = folium.Map(location=[0, 0], zoom_start=6)

mcg = folium.plugins.MarkerCluster(control=False)
m.add_child(mcg)

g1 = folium.plugins.FeatureGroupSubGroup(mcg, "group1")
m.add_child(g1)

g2 = folium.plugins.FeatureGroupSubGroup(mcg, "group2")
m.add_child(g2)

folium.Marker([-1, -1]).add_to(g1)
folium.Marker([1, 1]).add_to(g1)

folium.Marker([-1, 1]).add_to(g2)
folium.Marker([1, -1]).add_to(g2)

folium.LayerControl(collapsed=False).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3be450ee2d82ff8260cd8612a736fb08 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3be450ee2d82ff8260cd8612a736fb08&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3be450ee2d82ff8260cd8612a736fb08 = L.map(
#                 &quot;map_3be450ee2d82ff8260cd8612a736fb08&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_550ffda0d44d79b217ba419b282d76d2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_550ffda0d44d79b217ba419b282d76d2.addTo(map_3be450ee2d82ff8260cd8612a736fb08);
#
#
#             var marker_cluster_d9179003f2c0e4f7218ed684dc2c2f84 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             marker_cluster_d9179003f2c0e4f7218ed684dc2c2f84.addTo(map_3be450ee2d82ff8260cd8612a736fb08);
#
#
#             var feature_group_sub_group_0e5b477081d0e2dea3f32e9feca5897f = L.featureGroup.subGroup(
#                 marker_cluster_d9179003f2c0e4f7218ed684dc2c2f84
#             );
#
#
#             var marker_18505e0d0eae2dfeb57a3051585b4508 = L.marker(
#                 [-1.0, -1.0],
#                 {}
#             ).addTo(feature_group_sub_group_0e5b477081d0e2dea3f32e9feca5897f);
#
#
#             var marker_d89bd51d6790e2ef1244fc4d6bdbd82a = L.marker(
#                 [1.0, 1.0],
#                 {}
#             ).addTo(feature_group_sub_group_0e5b477081d0e2dea3f32e9feca5897f);
#
#
#             feature_group_sub_group_0e5b477081d0e2dea3f32e9feca5897f.addTo(map_3be450ee2d82ff8260cd8612a736fb08);
#
#
#             var feature_group_sub_group_d3506f9f3d39f2e7bedfe6b09aae94b2 = L.featureGroup.subGroup(
#                 marker_cluster_d9179003f2c0e4f7218ed684dc2c2f84
#             );
#
#
#             var marker_29d2dc8d57ebbcf7f9bb2d957f030e18 = L.marker(
#                 [-1.0, 1.0],
#                 {}
#             ).addTo(feature_group_sub_group_d3506f9f3d39f2e7bedfe6b09aae94b2);
#
#
#             var marker_6bc0882e2227ab34a05f655203df0312 = L.marker(
#                 [1.0, -1.0],
#                 {}
#             ).addTo(feature_group_sub_group_d3506f9f3d39f2e7bedfe6b09aae94b2);
#
#
#             feature_group_sub_group_d3506f9f3d39f2e7bedfe6b09aae94b2.addTo(map_3be450ee2d82ff8260cd8612a736fb08);
#
#
#             var layer_control_b51b4d9663747f09be15f0d32f11ee08_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_550ffda0d44d79b217ba419b282d76d2,
#                 },
#                 overlays :  {
#                     &quot;group1&quot; : feature_group_sub_group_0e5b477081d0e2dea3f32e9feca5897f,
#                     &quot;group2&quot; : feature_group_sub_group_d3506f9f3d39f2e7bedfe6b09aae94b2,
#                 },
#             };
#             let layer_control_b51b4d9663747f09be15f0d32f11ee08 = L.control.layers(
#                 layer_control_b51b4d9663747f09be15f0d32f11ee08_layers.base_layers,
#                 layer_control_b51b4d9663747f09be15f0d32f11ee08_layers.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: false, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_3be450ee2d82ff8260cd8612a736fb08);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
