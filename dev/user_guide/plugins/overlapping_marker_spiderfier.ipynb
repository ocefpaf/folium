# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_93c891d37273c7465796ea0685516159 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_93c891d37273c7465796ea0685516159&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_93c891d37273c7465796ea0685516159 = L.map(
#                 &quot;map_93c891d37273c7465796ea0685516159&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8838e2eace731e7a51be9a44151a0217 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8838e2eace731e7a51be9a44151a0217.addTo(map_93c891d37273c7465796ea0685516159);
#
#
#             var marker_edb4953fe2e6eb6b183eaad7179194e7 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_93c891d37273c7465796ea0685516159);
#
#
#         var popup_9b0982d46a4345b84284444344830bf6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_62e97461436ce47cf9950798dbc8bccf = $(`&lt;div id=&quot;html_62e97461436ce47cf9950798dbc8bccf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_9b0982d46a4345b84284444344830bf6.setContent(html_62e97461436ce47cf9950798dbc8bccf);
#
#
#
#         marker_edb4953fe2e6eb6b183eaad7179194e7.bindPopup(popup_9b0982d46a4345b84284444344830bf6)
#         ;
#
#
#
#
#             var marker_32ee8bb85f1c1bd783457dad62a221b7 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_93c891d37273c7465796ea0685516159);
#
#
#         var popup_94b8aabfbba31e145ec0fb6a066c7a85 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bf38c25ef69863d08e9f929588c83d9a = $(`&lt;div id=&quot;html_bf38c25ef69863d08e9f929588c83d9a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_94b8aabfbba31e145ec0fb6a066c7a85.setContent(html_bf38c25ef69863d08e9f929588c83d9a);
#
#
#
#         marker_32ee8bb85f1c1bd783457dad62a221b7.bindPopup(popup_94b8aabfbba31e145ec0fb6a066c7a85)
#         ;
#
#
#
#
#             var marker_bcf9d8b7b990bc87ed2237873ff03b06 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_93c891d37273c7465796ea0685516159);
#
#
#         var popup_9d29b54610df8a14b6af9b534be78468 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b24b7686777b9dc5c986932901b0a764 = $(`&lt;div id=&quot;html_b24b7686777b9dc5c986932901b0a764&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_9d29b54610df8a14b6af9b534be78468.setContent(html_b24b7686777b9dc5c986932901b0a764);
#
#
#
#         marker_bcf9d8b7b990bc87ed2237873ff03b06.bindPopup(popup_9d29b54610df8a14b6af9b534be78468)
#         ;
#
#
#
#
#             var marker_272224ebc7d63399db0b682ce677033d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_93c891d37273c7465796ea0685516159);
#
#
#         var popup_30461ec2eaf725e3fd95ff734ffaa265 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dc5bc055a8250da705a91f41ecf7aa2e = $(`&lt;div id=&quot;html_dc5bc055a8250da705a91f41ecf7aa2e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_30461ec2eaf725e3fd95ff734ffaa265.setContent(html_dc5bc055a8250da705a91f41ecf7aa2e);
#
#
#
#         marker_272224ebc7d63399db0b682ce677033d.bindPopup(popup_30461ec2eaf725e3fd95ff734ffaa265)
#         ;
#
#
#
#
#             var marker_af959930eccbd0c7533735a0d4be8088 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_93c891d37273c7465796ea0685516159);
#
#
#         var popup_ffb9081cdfef77d3f7dfe8cf8b81cb47 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1f5eec076219e6386e3abe7b25c25976 = $(`&lt;div id=&quot;html_1f5eec076219e6386e3abe7b25c25976&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_ffb9081cdfef77d3f7dfe8cf8b81cb47.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b6ddf704a75a7832d26900c5696cb997 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b6ddf704a75a7832d26900c5696cb997&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b6ddf704a75a7832d26900c5696cb997 = L.map(
#                 &quot;map_b6ddf704a75a7832d26900c5696cb997&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_22b5afc9c0df3da3d8f32a83bfe71583 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_22b5afc9c0df3da3d8f32a83bfe71583.addTo(map_b6ddf704a75a7832d26900c5696cb997);
#
#
#             var feature_group_170d70c2a1c41752dd665b4d4c702e64 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_0b94a8b15848142f734d431dd282a27d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_170d70c2a1c41752dd665b4d4c702e64);
#
#
#         var popup_c3378eff251a06d89b3c8f29409226d7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b8bd7ff988b6bea370a4b2c0bf97bc3f = $(`&lt;div id=&quot;html_b8bd7ff988b6bea370a4b2c0bf97bc3f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_c3378eff251a06d89b3c8f29409226d7.setContent(html_b8bd7ff988b6bea370a4b2c0bf97bc3f);
#
#
#
#         marker_0b94a8b15848142f734d431dd282a27d.bindPopup(popup_c3378eff251a06d89b3c8f29409226d7)
#         ;
#
#
#
#
#             var marker_0dc59082c7e5cdc5a27fb095aa81eadf = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_170d70c2a1c41752dd665b4d4c702e64);
#
#
#         var popup_2eb2edc671c61b773c3efd0fd6d7ea53 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5f412ae55bc7590efcc8b0a7473e31b8 = $(`&lt;div id=&quot;html_5f412ae55bc7590efcc8b0a7473e31b8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_2eb2edc671c61b773c3efd0fd6d7ea53.setContent(html_5f412ae55bc7590efcc8b0a7473e31b8);
#
#
#
#         marker_0dc59082c7e5cdc5a27fb095aa81eadf.bindPopup(popup_2eb2edc671c61b773c3efd0fd6d7ea53)
#         ;
#
#
#
#
#             var marker_f3d6ac506f0f041a6455221c55f43f73 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_170d70c2a1c41752dd665b4d4c702e64);
#
#
#         var popup_6760a425da5fbe06a306ab347fafd51e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dc2d57aaa01be661d431f33934c679bc = $(`&lt;div id=&quot;html_dc2d57aaa01be661d431f33934c679bc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_6760a425da5fbe06a306ab347fafd51e.setContent(html_dc2d57aaa01be661d431f33934c679bc);
#
#
#
#         marker_f3d6ac506f0f041a6455221c55f43f73.bindPopup(popup_6760a425da5fbe06a306ab347fafd51e)
#         ;
#
#
#
#
#             var marker_f292e9a86e58b938659fa3385d76f52d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_170d70c2a1c41752dd665b4d4c702e64);
#
#
#         var popup_0beb8d682e75cf8c578ca3163bd78e22 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ba164677b8f479edd8729461da1ed67e = $(`&lt;div id=&quot;html_ba164677b8f479edd8729461da1ed67e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_0beb8d682e75cf8c578ca3163bd78e22.setContent(html_ba164677b8f479edd8729461da1ed67e);
#
#
#
#         marker_f292e9a86e58b938659fa3385d76f52d.bindPopup(popup_0beb8d682e75cf8c578ca3163bd78e22)
#         ;
#
#
#
#
#             var marker_02403eb46e6b303c85327fcec20bdd7b = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_170d70c2a1c41752dd665b4d4c702e64);
#
#
#         var popup_4c314e3247bf89299881394fcab6e04b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f976a8f89471e0c0f3882e96c8bf05d7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f976a8f89471e0c0f3882e96c8bf05d7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f976a8f89471e0c0f3882e96c8bf05d7 = L.map(
#                 &quot;map_f976a8f89471e0c0f3882e96c8bf05d7&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_efb2b3480cc6ea2b0bb56311c8495018 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_efb2b3480cc6ea2b0bb56311c8495018.addTo(map_f976a8f89471e0c0f3882e96c8bf05d7);
#
#
#             var feature_group_c11f855e182e454b5a2f7d5827e35509 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_c11f855e182e454b5a2f7d5827e35509.addTo(map_f976a8f89471e0c0f3882e96c8bf05d7);
#
#
#             var feature_group_sub_group_605676426e47348d028d74a42ff0aeb9 = L.featureGroup.subGroup(
#                 feature_group_c11f855e182e454b5a2f7d5827e35509
#             );
#
#
#             var marker_7141f0a187c727335da14f4f84c2047d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_605676426e47348d028d74a42ff0aeb9);
#
#
#         var popup_f66e61dadbe8a9e642148a93924bb7d6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d264860c05491b68651961d48d6b8957 = $(`&lt;div id=&quot;html_d264860c05491b68651961d48d6b8957&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_f66e61dadbe8a9e642148a93924bb7d6.setContent(html_d264860c05491b68651961d48d6b8957);
#
#
#
#         marker_7141f0a187c727335da14f4f84c2047d.bindPopup(popup_f66e61dadbe8a9e642148a93924bb7d6)
#         ;
#
#
#
#
#             var marker_da14999910247ff5c111b417ddb4826c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_605676426e47348d028d74a42ff0aeb9);
#
#
#         var popup_f0a7bb7ce7b7fc0622d0b4043f4fabf7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_667638c0de030507942ce613df763aad = $(`&lt;div id=&quot;html_667638c0de030507942ce613df763aad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_f0a7bb7ce7b7fc0622d0b4043f4fabf7.setContent(html_667638c0de030507942ce613df763aad);
#
#
#
#         marker_da14999910247ff5c111b417ddb4826c.bindPopup(popup_f0a7bb7ce7b7fc0622d0b4043f4fabf7)
#         ;
#
#
#
#
#             var marker_9321e053c22040ff76b82ef88c71b0ea = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_605676426e47348d028d74a42ff0aeb9);
#
#
#         var popup_d03372b87bd3961334efc1c0a0878ae1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cb81059f849f5fc00d9c9abf062195e2 = $(`&lt;div id=&quot;html_cb81059f849f5fc00d9c9abf062195e2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_d03372b87bd3961334efc1c0a0878ae1.setContent(html_cb81059f849f5fc00d9c9abf062195e2);
#
#
#
#         marker_9321e053c22040ff76b82ef88c71b0ea.bindPopup(popup_d03372b87bd3961334efc1c0a0878ae1)
#         ;
#
#
#
#
#             var marker_37e8191780faa69288cf2cbe941ba609 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_605676426e47348d028d74a42ff0aeb9);
#
#
#         var popup_3b2781bfb1f361c818e0202b44369d87 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7c98eda358b69caa13e12a7ff72b7636 = $(`&lt;div id=&quot;html_7c98eda358b69caa13e12a7ff72b7636&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_3b2781bfb1f361c818e0202b44369d87.setContent(html_7c98eda358b69caa13e12a7ff72b7636);
#
#
#
#         marker_
