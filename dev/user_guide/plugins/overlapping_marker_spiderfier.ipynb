# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9c3ef1ad10cf5e826f7ad00968ba6679 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9c3ef1ad10cf5e826f7ad00968ba6679&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9c3ef1ad10cf5e826f7ad00968ba6679 = L.map(
#                 &quot;map_9c3ef1ad10cf5e826f7ad00968ba6679&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7e14aab401c353b479dd5a1784890202 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7e14aab401c353b479dd5a1784890202.addTo(map_9c3ef1ad10cf5e826f7ad00968ba6679);
#
#
#             var marker_33ea14d41ca2873125af503fe4b123f3 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_9c3ef1ad10cf5e826f7ad00968ba6679);
#
#
#         var popup_aa19f916f1118a43bc2bc34fc9993a32 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0f7fd8c56ed68dd722d2d6f6d80de638 = $(`&lt;div id=&quot;html_0f7fd8c56ed68dd722d2d6f6d80de638&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_aa19f916f1118a43bc2bc34fc9993a32.setContent(html_0f7fd8c56ed68dd722d2d6f6d80de638);
#
#
#
#         marker_33ea14d41ca2873125af503fe4b123f3.bindPopup(popup_aa19f916f1118a43bc2bc34fc9993a32)
#         ;
#
#
#
#
#             var marker_9f7ceb5f956e23bd735e4d61f1f8e9ff = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_9c3ef1ad10cf5e826f7ad00968ba6679);
#
#
#         var popup_b12f5486b6ca364914e79a6afcea18a0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ffb1403b15ed2df447dce02447d1ce69 = $(`&lt;div id=&quot;html_ffb1403b15ed2df447dce02447d1ce69&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_b12f5486b6ca364914e79a6afcea18a0.setContent(html_ffb1403b15ed2df447dce02447d1ce69);
#
#
#
#         marker_9f7ceb5f956e23bd735e4d61f1f8e9ff.bindPopup(popup_b12f5486b6ca364914e79a6afcea18a0)
#         ;
#
#
#
#
#             var marker_6eb8f4c64bd26c13c29be5ca2bb7f31a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_9c3ef1ad10cf5e826f7ad00968ba6679);
#
#
#         var popup_39c81ca59271fe5f44bfae5626b61c75 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_507f5f7996cc732f0fad8e883686305c = $(`&lt;div id=&quot;html_507f5f7996cc732f0fad8e883686305c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_39c81ca59271fe5f44bfae5626b61c75.setContent(html_507f5f7996cc732f0fad8e883686305c);
#
#
#
#         marker_6eb8f4c64bd26c13c29be5ca2bb7f31a.bindPopup(popup_39c81ca59271fe5f44bfae5626b61c75)
#         ;
#
#
#
#
#             var marker_c2127d2834a99182498a50b15669cff8 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_9c3ef1ad10cf5e826f7ad00968ba6679);
#
#
#         var popup_edb4c3a0ab867f55a66d0cd8a68a746b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4058a2eae5b80623ff12ca1a00876c8c = $(`&lt;div id=&quot;html_4058a2eae5b80623ff12ca1a00876c8c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_edb4c3a0ab867f55a66d0cd8a68a746b.setContent(html_4058a2eae5b80623ff12ca1a00876c8c);
#
#
#
#         marker_c2127d2834a99182498a50b15669cff8.bindPopup(popup_edb4c3a0ab867f55a66d0cd8a68a746b)
#         ;
#
#
#
#
#             var marker_6020c284a7e95adcb6a3736fd305c172 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_9c3ef1ad10cf5e826f7ad00968ba6679);
#
#
#         var popup_48b679c2dd3d584f81680debb3148393 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d8cd655a349f4d42e4f8cd08a397e622 = $(`&lt;div id=&quot;html_d8cd655a349f4d42e4f8cd08a397e622&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_48b679c2dd3d584f81680debb3148393.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8ac228a5e28ab0128a106879ee7b26bc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8ac228a5e28ab0128a106879ee7b26bc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8ac228a5e28ab0128a106879ee7b26bc = L.map(
#                 &quot;map_8ac228a5e28ab0128a106879ee7b26bc&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0b79c3146ee56088bc53c307634bf79c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0b79c3146ee56088bc53c307634bf79c.addTo(map_8ac228a5e28ab0128a106879ee7b26bc);
#
#
#             var feature_group_466300c567b47314fffd80a1a90d76be = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_ab9ce38e29bcf2cddd0f6ab2c7017e5e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_466300c567b47314fffd80a1a90d76be);
#
#
#         var popup_b0148d5f143784b6f8d3e3fd20feb063 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_30bfb136541376cf0fb7d4a5cbd2a060 = $(`&lt;div id=&quot;html_30bfb136541376cf0fb7d4a5cbd2a060&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_b0148d5f143784b6f8d3e3fd20feb063.setContent(html_30bfb136541376cf0fb7d4a5cbd2a060);
#
#
#
#         marker_ab9ce38e29bcf2cddd0f6ab2c7017e5e.bindPopup(popup_b0148d5f143784b6f8d3e3fd20feb063)
#         ;
#
#
#
#
#             var marker_bb7abda6ae44a6fa9eac50e8df0ca327 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_466300c567b47314fffd80a1a90d76be);
#
#
#         var popup_2ac350cb37fb7e6e721ce8369e88c652 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3e73da3781ecc9cbb0e867f3284db576 = $(`&lt;div id=&quot;html_3e73da3781ecc9cbb0e867f3284db576&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_2ac350cb37fb7e6e721ce8369e88c652.setContent(html_3e73da3781ecc9cbb0e867f3284db576);
#
#
#
#         marker_bb7abda6ae44a6fa9eac50e8df0ca327.bindPopup(popup_2ac350cb37fb7e6e721ce8369e88c652)
#         ;
#
#
#
#
#             var marker_874fb1b2ca5f6da14f0aedfa179a6552 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_466300c567b47314fffd80a1a90d76be);
#
#
#         var popup_5189986b5bdfe6b968fe4f067743f7c6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_98b03230e7a4a61c45794737c8454564 = $(`&lt;div id=&quot;html_98b03230e7a4a61c45794737c8454564&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_5189986b5bdfe6b968fe4f067743f7c6.setContent(html_98b03230e7a4a61c45794737c8454564);
#
#
#
#         marker_874fb1b2ca5f6da14f0aedfa179a6552.bindPopup(popup_5189986b5bdfe6b968fe4f067743f7c6)
#         ;
#
#
#
#
#             var marker_99cc36b5dfaa8594a527a661b5a91dae = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_466300c567b47314fffd80a1a90d76be);
#
#
#         var popup_83e046e5d8aad6ff486f88be120bfbc7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ee871cee6c06e18bc237aa3749befd30 = $(`&lt;div id=&quot;html_ee871cee6c06e18bc237aa3749befd30&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_83e046e5d8aad6ff486f88be120bfbc7.setContent(html_ee871cee6c06e18bc237aa3749befd30);
#
#
#
#         marker_99cc36b5dfaa8594a527a661b5a91dae.bindPopup(popup_83e046e5d8aad6ff486f88be120bfbc7)
#         ;
#
#
#
#
#             var marker_007f008fd6d8a1d71be7402cf8d0cb28 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_466300c567b47314fffd80a1a90d76be);
#
#
#         var popup_9e754c0d353f02837bcd044bf6e677f7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cb9895b6ac8bac87a6be303953c30ce8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cb9895b6ac8bac87a6be303953c30ce8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cb9895b6ac8bac87a6be303953c30ce8 = L.map(
#                 &quot;map_cb9895b6ac8bac87a6be303953c30ce8&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_aacf4d9be8cf67c7cfad334806b5689a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_aacf4d9be8cf67c7cfad334806b5689a.addTo(map_cb9895b6ac8bac87a6be303953c30ce8);
#
#
#             var feature_group_220af88aeebf20fc95f4f244a7ed3677 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_220af88aeebf20fc95f4f244a7ed3677.addTo(map_cb9895b6ac8bac87a6be303953c30ce8);
#
#
#             var feature_group_sub_group_e73d7e4987cb5d94ce6d6beed4864363 = L.featureGroup.subGroup(
#                 feature_group_220af88aeebf20fc95f4f244a7ed3677
#             );
#
#
#             var marker_0fdf46d457d77e63922152823d9b0af5 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_e73d7e4987cb5d94ce6d6beed4864363);
#
#
#         var popup_45dd421b57f29c783d91c2eb152690f3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_07ee66427db2b571fa6bbbe5c1c92cad = $(`&lt;div id=&quot;html_07ee66427db2b571fa6bbbe5c1c92cad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_45dd421b57f29c783d91c2eb152690f3.setContent(html_07ee66427db2b571fa6bbbe5c1c92cad);
#
#
#
#         marker_0fdf46d457d77e63922152823d9b0af5.bindPopup(popup_45dd421b57f29c783d91c2eb152690f3)
#         ;
#
#
#
#
#             var marker_dec1c19da4176bac5f44213a5b3c7cc6 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_e73d7e4987cb5d94ce6d6beed4864363);
#
#
#         var popup_64043140eb26a1b060720c9a31a69458 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c9477234f5aaa4ed47d4be77abf28b5c = $(`&lt;div id=&quot;html_c9477234f5aaa4ed47d4be77abf28b5c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_64043140eb26a1b060720c9a31a69458.setContent(html_c9477234f5aaa4ed47d4be77abf28b5c);
#
#
#
#         marker_dec1c19da4176bac5f44213a5b3c7cc6.bindPopup(popup_64043140eb26a1b060720c9a31a69458)
#         ;
#
#
#
#
#             var marker_d791aebe29bae9dd0ddf7e7fd7cfa8af = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_e73d7e4987cb5d94ce6d6beed4864363);
#
#
#         var popup_eb0b911954b96e02303e10dfc7aa6635 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ada9170d7b8940fcc1fc9722d91bcf05 = $(`&lt;div id=&quot;html_ada9170d7b8940fcc1fc9722d91bcf05&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_eb0b911954b96e02303e10dfc7aa6635.setContent(html_ada9170d7b8940fcc1fc9722d91bcf05);
#
#
#
#         marker_d791aebe29bae9dd0ddf7e7fd7cfa8af.bindPopup(popup_eb0b911954b96e02303e10dfc7aa6635)
#         ;
#
#
#
#
#             var marker_b2253a70ec1b48d4cfcd0d1b92bc282f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_e73d7e4987cb5d94ce6d6beed4864363);
#
#
#         var popup_554afa1c8cfc0f5d835d57008c8a0128 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_63fde2e845d11b0f8ca101183681ce06 = $(`&lt;div id=&quot;html_63fde2e845d11b0f8ca101183681ce06&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_554afa1c8cfc0f5d835d57008c8a0128.setContent(html_63fde2e845d11b0f8ca101183681ce06);
#
#
#
#         marker_
