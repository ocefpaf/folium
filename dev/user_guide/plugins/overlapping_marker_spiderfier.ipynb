# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_06f50996eb47abced12022ad1045e560 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_06f50996eb47abced12022ad1045e560&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_06f50996eb47abced12022ad1045e560 = L.map(
#                 &quot;map_06f50996eb47abced12022ad1045e560&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_763c2404c78b8320595772baa81dd9a6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_763c2404c78b8320595772baa81dd9a6.addTo(map_06f50996eb47abced12022ad1045e560);
#
#
#             var marker_f31ae8172ed66ba5ce1bd1131b350685 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_06f50996eb47abced12022ad1045e560);
#
#
#         var popup_21257162d2afb157be0d8cb64d78541a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c1f731abe68f2723849ee53ad4302cee = $(`&lt;div id=&quot;html_c1f731abe68f2723849ee53ad4302cee&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_21257162d2afb157be0d8cb64d78541a.setContent(html_c1f731abe68f2723849ee53ad4302cee);
#
#
#
#         marker_f31ae8172ed66ba5ce1bd1131b350685.bindPopup(popup_21257162d2afb157be0d8cb64d78541a)
#         ;
#
#
#
#
#             var marker_e2b2e0fa280a664d39270ab95bd6f8be = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_06f50996eb47abced12022ad1045e560);
#
#
#         var popup_9a524b724f96b57fcba008d222d85329 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_188222fdd9c878d315769e99906319c7 = $(`&lt;div id=&quot;html_188222fdd9c878d315769e99906319c7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_9a524b724f96b57fcba008d222d85329.setContent(html_188222fdd9c878d315769e99906319c7);
#
#
#
#         marker_e2b2e0fa280a664d39270ab95bd6f8be.bindPopup(popup_9a524b724f96b57fcba008d222d85329)
#         ;
#
#
#
#
#             var marker_9c79fba582a31dca888d1f4b10124d51 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_06f50996eb47abced12022ad1045e560);
#
#
#         var popup_b9089aa0253a010b21333dcb8e3d075d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_52e059f438449169ec55574adbe6ca8e = $(`&lt;div id=&quot;html_52e059f438449169ec55574adbe6ca8e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_b9089aa0253a010b21333dcb8e3d075d.setContent(html_52e059f438449169ec55574adbe6ca8e);
#
#
#
#         marker_9c79fba582a31dca888d1f4b10124d51.bindPopup(popup_b9089aa0253a010b21333dcb8e3d075d)
#         ;
#
#
#
#
#             var marker_591464d2520e9d40624e6c3c80dddfb9 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_06f50996eb47abced12022ad1045e560);
#
#
#         var popup_654d8924cf953aba14f7fb6bc6ff55bc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_28715109611125d527c45ea1d579bbf6 = $(`&lt;div id=&quot;html_28715109611125d527c45ea1d579bbf6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_654d8924cf953aba14f7fb6bc6ff55bc.setContent(html_28715109611125d527c45ea1d579bbf6);
#
#
#
#         marker_591464d2520e9d40624e6c3c80dddfb9.bindPopup(popup_654d8924cf953aba14f7fb6bc6ff55bc)
#         ;
#
#
#
#
#             var marker_68791a11292c5aa347561c19324f48e9 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_06f50996eb47abced12022ad1045e560);
#
#
#         var popup_941a9b5057a3cee6d9c65372658a09b9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_beaa61a8b5ce1d2d575ca914cb149e78 = $(`&lt;div id=&quot;html_beaa61a8b5ce1d2d575ca914cb149e78&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_941a9b5057a3cee6d9c65372658a09b9.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_238bc84892bddac8133733a064a5dd36 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_238bc84892bddac8133733a064a5dd36&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_238bc84892bddac8133733a064a5dd36 = L.map(
#                 &quot;map_238bc84892bddac8133733a064a5dd36&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1ad94d80878e8bcfda398c96d0ae8d64 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1ad94d80878e8bcfda398c96d0ae8d64.addTo(map_238bc84892bddac8133733a064a5dd36);
#
#
#             var feature_group_22bb10b778be390e3ba2070ec3c7b7b4 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_b93c3f8d8e29441db38c76f4de547f1c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_22bb10b778be390e3ba2070ec3c7b7b4);
#
#
#         var popup_3ad9bcff601a2f006b7f7a27fb5ccdd2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f5e733214cf1d5bf2c09a65b946ab178 = $(`&lt;div id=&quot;html_f5e733214cf1d5bf2c09a65b946ab178&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_3ad9bcff601a2f006b7f7a27fb5ccdd2.setContent(html_f5e733214cf1d5bf2c09a65b946ab178);
#
#
#
#         marker_b93c3f8d8e29441db38c76f4de547f1c.bindPopup(popup_3ad9bcff601a2f006b7f7a27fb5ccdd2)
#         ;
#
#
#
#
#             var marker_5670d00bc4d0fa04f0807cec4aa22557 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_22bb10b778be390e3ba2070ec3c7b7b4);
#
#
#         var popup_4d5bf458e560d088a678282d7e6dd05d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1040504f34800433e98f58a81ed8173a = $(`&lt;div id=&quot;html_1040504f34800433e98f58a81ed8173a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_4d5bf458e560d088a678282d7e6dd05d.setContent(html_1040504f34800433e98f58a81ed8173a);
#
#
#
#         marker_5670d00bc4d0fa04f0807cec4aa22557.bindPopup(popup_4d5bf458e560d088a678282d7e6dd05d)
#         ;
#
#
#
#
#             var marker_0a4f525de192cc1b3f47eca6fad3e871 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_22bb10b778be390e3ba2070ec3c7b7b4);
#
#
#         var popup_8660f4c839823cdba4eac13d9b0411dc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b50fa6e1e740d18745007dfc49660087 = $(`&lt;div id=&quot;html_b50fa6e1e740d18745007dfc49660087&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_8660f4c839823cdba4eac13d9b0411dc.setContent(html_b50fa6e1e740d18745007dfc49660087);
#
#
#
#         marker_0a4f525de192cc1b3f47eca6fad3e871.bindPopup(popup_8660f4c839823cdba4eac13d9b0411dc)
#         ;
#
#
#
#
#             var marker_134c6ef2755fe3902135ee8c0b4b008f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_22bb10b778be390e3ba2070ec3c7b7b4);
#
#
#         var popup_7a0b8fd9e5497e9e8cc1a4c9e3fa2b52 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f56706b68e6a4500d8a609e4a7d38886 = $(`&lt;div id=&quot;html_f56706b68e6a4500d8a609e4a7d38886&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_7a0b8fd9e5497e9e8cc1a4c9e3fa2b52.setContent(html_f56706b68e6a4500d8a609e4a7d38886);
#
#
#
#         marker_134c6ef2755fe3902135ee8c0b4b008f.bindPopup(popup_7a0b8fd9e5497e9e8cc1a4c9e3fa2b52)
#         ;
#
#
#
#
#             var marker_c0ec4b91130935e0ea44b50684929aad = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_22bb10b778be390e3ba2070ec3c7b7b4);
#
#
#         var popup_084bf31b28273f1c9673e858273df845 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1d9d18902f230a15aeae542594b9b4c6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1d9d18902f230a15aeae542594b9b4c6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1d9d18902f230a15aeae542594b9b4c6 = L.map(
#                 &quot;map_1d9d18902f230a15aeae542594b9b4c6&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9ccfe5c5bbb3d97e93bc3364be87f2e8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9ccfe5c5bbb3d97e93bc3364be87f2e8.addTo(map_1d9d18902f230a15aeae542594b9b4c6);
#
#
#             var feature_group_43f25a4958c915ccf2d93e9f438b58bb = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_43f25a4958c915ccf2d93e9f438b58bb.addTo(map_1d9d18902f230a15aeae542594b9b4c6);
#
#
#             var feature_group_sub_group_e8c18f6cd1754fdc4fa28272c274aa61 = L.featureGroup.subGroup(
#                 feature_group_43f25a4958c915ccf2d93e9f438b58bb
#             );
#
#
#             var marker_6ac8539dd4ea4c8344ccdf1ff0d7e733 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_e8c18f6cd1754fdc4fa28272c274aa61);
#
#
#         var popup_4c482b516622d448f9f47f7fd5bb72cc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_32f99cd6c243ceb89601872ca5eae8bc = $(`&lt;div id=&quot;html_32f99cd6c243ceb89601872ca5eae8bc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_4c482b516622d448f9f47f7fd5bb72cc.setContent(html_32f99cd6c243ceb89601872ca5eae8bc);
#
#
#
#         marker_6ac8539dd4ea4c8344ccdf1ff0d7e733.bindPopup(popup_4c482b516622d448f9f47f7fd5bb72cc)
#         ;
#
#
#
#
#             var marker_41f51358b3b230ac4d298646feff944a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_e8c18f6cd1754fdc4fa28272c274aa61);
#
#
#         var popup_d8ab7738922d7c2f7bca2ef433129454 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8606a01e2f45024314beb7df12cb47e0 = $(`&lt;div id=&quot;html_8606a01e2f45024314beb7df12cb47e0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_d8ab7738922d7c2f7bca2ef433129454.setContent(html_8606a01e2f45024314beb7df12cb47e0);
#
#
#
#         marker_41f51358b3b230ac4d298646feff944a.bindPopup(popup_d8ab7738922d7c2f7bca2ef433129454)
#         ;
#
#
#
#
#             var marker_72d95b428a6aa06d22dece524c89f28d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_e8c18f6cd1754fdc4fa28272c274aa61);
#
#
#         var popup_2c033591da0aee08873bbeaa898dc26e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_211ac591db9b5037d0bdc5ec0a8f1bbd = $(`&lt;div id=&quot;html_211ac591db9b5037d0bdc5ec0a8f1bbd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_2c033591da0aee08873bbeaa898dc26e.setContent(html_211ac591db9b5037d0bdc5ec0a8f1bbd);
#
#
#
#         marker_72d95b428a6aa06d22dece524c89f28d.bindPopup(popup_2c033591da0aee08873bbeaa898dc26e)
#         ;
#
#
#
#
#             var marker_a6467b99a60504d5a502a2f0f8213129 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_e8c18f6cd1754fdc4fa28272c274aa61);
#
#
#         var popup_2414c444bde07b6b52c6277017d3a532 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5c36bfd1ae9a505fc4d698c0d532aebd = $(`&lt;div id=&quot;html_5c36bfd1ae9a505fc4d698c0d532aebd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_2414c444bde07b6b52c6277017d3a532.setContent(html_5c36bfd1ae9a505fc4d698c0d532aebd);
#
#
#
#         marker_
