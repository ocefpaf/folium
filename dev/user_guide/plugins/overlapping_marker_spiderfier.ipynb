# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3ecb5c8e69d6c6b84e35747ff7632397 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3ecb5c8e69d6c6b84e35747ff7632397&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3ecb5c8e69d6c6b84e35747ff7632397 = L.map(
#                 &quot;map_3ecb5c8e69d6c6b84e35747ff7632397&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0c026182e35836d9f82a7de18164a77c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0c026182e35836d9f82a7de18164a77c.addTo(map_3ecb5c8e69d6c6b84e35747ff7632397);
#
#
#             var marker_ee0179cbd84b1152636b7d0503a1b221 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_3ecb5c8e69d6c6b84e35747ff7632397);
#
#
#         var popup_85804f5fee52daf69831e69a192b4de6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e1e761c5f19ff8016f4d2c50b5288fae = $(`&lt;div id=&quot;html_e1e761c5f19ff8016f4d2c50b5288fae&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_85804f5fee52daf69831e69a192b4de6.setContent(html_e1e761c5f19ff8016f4d2c50b5288fae);
#
#
#
#         marker_ee0179cbd84b1152636b7d0503a1b221.bindPopup(popup_85804f5fee52daf69831e69a192b4de6)
#         ;
#
#
#
#
#             var marker_e90928108fd5b380599423b3c59bc2b3 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_3ecb5c8e69d6c6b84e35747ff7632397);
#
#
#         var popup_3b2c41527cf5a64e909f914632b8cc2c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f0c7183959f6153188c2ccd461f1fff1 = $(`&lt;div id=&quot;html_f0c7183959f6153188c2ccd461f1fff1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_3b2c41527cf5a64e909f914632b8cc2c.setContent(html_f0c7183959f6153188c2ccd461f1fff1);
#
#
#
#         marker_e90928108fd5b380599423b3c59bc2b3.bindPopup(popup_3b2c41527cf5a64e909f914632b8cc2c)
#         ;
#
#
#
#
#             var marker_e7e56284e974aaec21b4773f94fe2c13 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_3ecb5c8e69d6c6b84e35747ff7632397);
#
#
#         var popup_322dd164cf84d6acdcd20fa5d6d1b115 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9fc15e864e7d23dc128a1dbc6aeb7905 = $(`&lt;div id=&quot;html_9fc15e864e7d23dc128a1dbc6aeb7905&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_322dd164cf84d6acdcd20fa5d6d1b115.setContent(html_9fc15e864e7d23dc128a1dbc6aeb7905);
#
#
#
#         marker_e7e56284e974aaec21b4773f94fe2c13.bindPopup(popup_322dd164cf84d6acdcd20fa5d6d1b115)
#         ;
#
#
#
#
#             var marker_86ec25afaf18694688dcdbb6930e2924 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_3ecb5c8e69d6c6b84e35747ff7632397);
#
#
#         var popup_f27b8f4be03ba37849e7119259b10812 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4bf491a57bb7780946eeb2e10b0aa8d4 = $(`&lt;div id=&quot;html_4bf491a57bb7780946eeb2e10b0aa8d4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_f27b8f4be03ba37849e7119259b10812.setContent(html_4bf491a57bb7780946eeb2e10b0aa8d4);
#
#
#
#         marker_86ec25afaf18694688dcdbb6930e2924.bindPopup(popup_f27b8f4be03ba37849e7119259b10812)
#         ;
#
#
#
#
#             var marker_cd6e2a3923a81ce68a1e027399e7d494 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_3ecb5c8e69d6c6b84e35747ff7632397);
#
#
#         var popup_fd2ec94d8ef68409b8e3df4589c0a2a4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_aefa9b002d14f5ea054ff1cdb1c8fc4c = $(`&lt;div id=&quot;html_aefa9b002d14f5ea054ff1cdb1c8fc4c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_fd2ec94d8ef68409b8e3df4589c0a2a4.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f86942832d3fa511b3db4c8ebfcd8c90 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f86942832d3fa511b3db4c8ebfcd8c90&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f86942832d3fa511b3db4c8ebfcd8c90 = L.map(
#                 &quot;map_f86942832d3fa511b3db4c8ebfcd8c90&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_422555ee7851d92bb6d06ee529c7ba6c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_422555ee7851d92bb6d06ee529c7ba6c.addTo(map_f86942832d3fa511b3db4c8ebfcd8c90);
#
#
#             var feature_group_63c54cc4dcf0ac8be2380ee422c2ecbb = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_83edf543a5650e22e59050a995c8da37 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_63c54cc4dcf0ac8be2380ee422c2ecbb);
#
#
#         var popup_227ae46e477921cc28e117f664ceeaf6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_123c06239146d0b3fb0b1e500fbd412c = $(`&lt;div id=&quot;html_123c06239146d0b3fb0b1e500fbd412c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_227ae46e477921cc28e117f664ceeaf6.setContent(html_123c06239146d0b3fb0b1e500fbd412c);
#
#
#
#         marker_83edf543a5650e22e59050a995c8da37.bindPopup(popup_227ae46e477921cc28e117f664ceeaf6)
#         ;
#
#
#
#
#             var marker_148da3cb18eea31b45f3bba4d334cbab = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_63c54cc4dcf0ac8be2380ee422c2ecbb);
#
#
#         var popup_5ee4ad3eb3e112e0947f8ce557e2576d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_78f8d89944b149f453f9846b232bf9a9 = $(`&lt;div id=&quot;html_78f8d89944b149f453f9846b232bf9a9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_5ee4ad3eb3e112e0947f8ce557e2576d.setContent(html_78f8d89944b149f453f9846b232bf9a9);
#
#
#
#         marker_148da3cb18eea31b45f3bba4d334cbab.bindPopup(popup_5ee4ad3eb3e112e0947f8ce557e2576d)
#         ;
#
#
#
#
#             var marker_0123956d403219f452e91ed8457cfb30 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_63c54cc4dcf0ac8be2380ee422c2ecbb);
#
#
#         var popup_04c2dfb05382e3d3972945397f550656 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_24b321ae3f5b3e9638b16c22e1a6482a = $(`&lt;div id=&quot;html_24b321ae3f5b3e9638b16c22e1a6482a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_04c2dfb05382e3d3972945397f550656.setContent(html_24b321ae3f5b3e9638b16c22e1a6482a);
#
#
#
#         marker_0123956d403219f452e91ed8457cfb30.bindPopup(popup_04c2dfb05382e3d3972945397f550656)
#         ;
#
#
#
#
#             var marker_2614d02c13f50b1b666de9aee00a3a91 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_63c54cc4dcf0ac8be2380ee422c2ecbb);
#
#
#         var popup_047536cd7f20c951dcc50d39851f414a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b976f9f1ee6ddd876be8dd3c8c3283bb = $(`&lt;div id=&quot;html_b976f9f1ee6ddd876be8dd3c8c3283bb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_047536cd7f20c951dcc50d39851f414a.setContent(html_b976f9f1ee6ddd876be8dd3c8c3283bb);
#
#
#
#         marker_2614d02c13f50b1b666de9aee00a3a91.bindPopup(popup_047536cd7f20c951dcc50d39851f414a)
#         ;
#
#
#
#
#             var marker_ef1ba2f23307835ed1d3de1018d3dcd4 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_63c54cc4dcf0ac8be2380ee422c2ecbb);
#
#
#         var popup_931e4e780e7e155811a246ec744c5282 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f0849f72ebaef1aee5926c11c7b83e06 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f0849f72ebaef1aee5926c11c7b83e06&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f0849f72ebaef1aee5926c11c7b83e06 = L.map(
#                 &quot;map_f0849f72ebaef1aee5926c11c7b83e06&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1164d2bfbc95c00a6910c02b82236023 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1164d2bfbc95c00a6910c02b82236023.addTo(map_f0849f72ebaef1aee5926c11c7b83e06);
#
#
#             var feature_group_8a6f44b04452aed248e3e6ee21973cd0 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_8a6f44b04452aed248e3e6ee21973cd0.addTo(map_f0849f72ebaef1aee5926c11c7b83e06);
#
#
#             var feature_group_sub_group_b0b6c098ac0b260c09326bbdfdb0a1bd = L.featureGroup.subGroup(
#                 feature_group_8a6f44b04452aed248e3e6ee21973cd0
#             );
#
#
#             var marker_18c751b9cd13c16c6f89bc41cb15217b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_b0b6c098ac0b260c09326bbdfdb0a1bd);
#
#
#         var popup_44af98019770342a446b86378a69649e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7d83239fab603169ae4b4e498a09081a = $(`&lt;div id=&quot;html_7d83239fab603169ae4b4e498a09081a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_44af98019770342a446b86378a69649e.setContent(html_7d83239fab603169ae4b4e498a09081a);
#
#
#
#         marker_18c751b9cd13c16c6f89bc41cb15217b.bindPopup(popup_44af98019770342a446b86378a69649e)
#         ;
#
#
#
#
#             var marker_4e4a776e73bfc12559bd06959fff607f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_b0b6c098ac0b260c09326bbdfdb0a1bd);
#
#
#         var popup_c8d5c61662bce3ab87f3758489799c28 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9059b656a57979f0ffa73768ca761f8b = $(`&lt;div id=&quot;html_9059b656a57979f0ffa73768ca761f8b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_c8d5c61662bce3ab87f3758489799c28.setContent(html_9059b656a57979f0ffa73768ca761f8b);
#
#
#
#         marker_4e4a776e73bfc12559bd06959fff607f.bindPopup(popup_c8d5c61662bce3ab87f3758489799c28)
#         ;
#
#
#
#
#             var marker_746283fdf94fa550f96028f166b8a902 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_b0b6c098ac0b260c09326bbdfdb0a1bd);
#
#
#         var popup_9eb8dba7c2c90fa42e972323cbff12d6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bbe9c31859c2c13f6a0ce235916eb055 = $(`&lt;div id=&quot;html_bbe9c31859c2c13f6a0ce235916eb055&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_9eb8dba7c2c90fa42e972323cbff12d6.setContent(html_bbe9c31859c2c13f6a0ce235916eb055);
#
#
#
#         marker_746283fdf94fa550f96028f166b8a902.bindPopup(popup_9eb8dba7c2c90fa42e972323cbff12d6)
#         ;
#
#
#
#
#             var marker_c73fc12f4427efe01685f534cd9788bc = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_b0b6c098ac0b260c09326bbdfdb0a1bd);
#
#
#         var popup_fd3b152ae207b29125b13241d45bc23a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_46afb24086ebceef78ddb3570952a54e = $(`&lt;div id=&quot;html_46afb24086ebceef78ddb3570952a54e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_fd3b152ae207b29125b13241d45bc23a.setContent(html_46afb24086ebceef78ddb3570952a54e);
#
#
#
#         marker_
