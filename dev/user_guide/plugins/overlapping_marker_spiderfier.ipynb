# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0f03b6aef61f6255eaf3711ca588abd2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0f03b6aef61f6255eaf3711ca588abd2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0f03b6aef61f6255eaf3711ca588abd2 = L.map(
#                 &quot;map_0f03b6aef61f6255eaf3711ca588abd2&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_628db8b68a2de1b4da7fd7d6113eee1a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_628db8b68a2de1b4da7fd7d6113eee1a.addTo(map_0f03b6aef61f6255eaf3711ca588abd2);
#
#
#             var marker_31dab421b396ffc6828f91118721bc9b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_0f03b6aef61f6255eaf3711ca588abd2);
#
#
#         var popup_e3fce751776e523818e975ce95087325 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a253cbcd1f3159df5b4034b16934cad1 = $(`&lt;div id=&quot;html_a253cbcd1f3159df5b4034b16934cad1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_e3fce751776e523818e975ce95087325.setContent(html_a253cbcd1f3159df5b4034b16934cad1);
#
#
#
#         marker_31dab421b396ffc6828f91118721bc9b.bindPopup(popup_e3fce751776e523818e975ce95087325)
#         ;
#
#
#
#
#             var marker_e65442b5f2349b4f493624b2b82a3e3b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_0f03b6aef61f6255eaf3711ca588abd2);
#
#
#         var popup_0b7af55c5e70b329493e3e39b8f4152b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e238908cd7f691f3a33e02f357badbf5 = $(`&lt;div id=&quot;html_e238908cd7f691f3a33e02f357badbf5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_0b7af55c5e70b329493e3e39b8f4152b.setContent(html_e238908cd7f691f3a33e02f357badbf5);
#
#
#
#         marker_e65442b5f2349b4f493624b2b82a3e3b.bindPopup(popup_0b7af55c5e70b329493e3e39b8f4152b)
#         ;
#
#
#
#
#             var marker_1693b66193d61e2d0a4f645305e79bb2 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_0f03b6aef61f6255eaf3711ca588abd2);
#
#
#         var popup_088b7633307260f686a7546b28a07451 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0f1b846670ef8103a4df91ad472ad470 = $(`&lt;div id=&quot;html_0f1b846670ef8103a4df91ad472ad470&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_088b7633307260f686a7546b28a07451.setContent(html_0f1b846670ef8103a4df91ad472ad470);
#
#
#
#         marker_1693b66193d61e2d0a4f645305e79bb2.bindPopup(popup_088b7633307260f686a7546b28a07451)
#         ;
#
#
#
#
#             var marker_83d0bb30a30a302f4d006883b1e58cf7 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_0f03b6aef61f6255eaf3711ca588abd2);
#
#
#         var popup_0d204dc64a742f1befaca07ac19efccd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0b598031d776158c8b594183dff34f9b = $(`&lt;div id=&quot;html_0b598031d776158c8b594183dff34f9b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_0d204dc64a742f1befaca07ac19efccd.setContent(html_0b598031d776158c8b594183dff34f9b);
#
#
#
#         marker_83d0bb30a30a302f4d006883b1e58cf7.bindPopup(popup_0d204dc64a742f1befaca07ac19efccd)
#         ;
#
#
#
#
#             var marker_9e5f55f05ecad5920b5e53d96665ff80 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_0f03b6aef61f6255eaf3711ca588abd2);
#
#
#         var popup_40275c05c5a98f3f43439e4499d89e56 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e2bf69818bcb4ca111accfb185f1ad61 = $(`&lt;div id=&quot;html_e2bf69818bcb4ca111accfb185f1ad61&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_40275c05c5a98f3f43439e4499d89e56.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_afc5f807ecdbc0c808c2559deb911763 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_afc5f807ecdbc0c808c2559deb911763&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_afc5f807ecdbc0c808c2559deb911763 = L.map(
#                 &quot;map_afc5f807ecdbc0c808c2559deb911763&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a96f0b1e7d31eb795f2a15ad37dd4f46 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a96f0b1e7d31eb795f2a15ad37dd4f46.addTo(map_afc5f807ecdbc0c808c2559deb911763);
#
#
#             var feature_group_5fc616ea108e9b3b4ed4f27502f39f98 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_9ee5728c7576cf19da3eba0655e1128d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_5fc616ea108e9b3b4ed4f27502f39f98);
#
#
#         var popup_a74e0144ec5dd267c9b200a57008a7bc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fbc8a3a11f1a09e6503209988405fbda = $(`&lt;div id=&quot;html_fbc8a3a11f1a09e6503209988405fbda&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_a74e0144ec5dd267c9b200a57008a7bc.setContent(html_fbc8a3a11f1a09e6503209988405fbda);
#
#
#
#         marker_9ee5728c7576cf19da3eba0655e1128d.bindPopup(popup_a74e0144ec5dd267c9b200a57008a7bc)
#         ;
#
#
#
#
#             var marker_bf9af2e6074677de6a5f41b8d6c484b0 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_5fc616ea108e9b3b4ed4f27502f39f98);
#
#
#         var popup_be0134510fd5fbfb4be2bf0cc7035209 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e3f77f022e1eba4487b5d89136e27bbd = $(`&lt;div id=&quot;html_e3f77f022e1eba4487b5d89136e27bbd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_be0134510fd5fbfb4be2bf0cc7035209.setContent(html_e3f77f022e1eba4487b5d89136e27bbd);
#
#
#
#         marker_bf9af2e6074677de6a5f41b8d6c484b0.bindPopup(popup_be0134510fd5fbfb4be2bf0cc7035209)
#         ;
#
#
#
#
#             var marker_b7ef4dfa0a65382e7dabde9431b3cc8c = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_5fc616ea108e9b3b4ed4f27502f39f98);
#
#
#         var popup_492953b0bd27db9810742956225d6bdd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a53e4bbe0ea91adc5dcce2946f4bb3cf = $(`&lt;div id=&quot;html_a53e4bbe0ea91adc5dcce2946f4bb3cf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_492953b0bd27db9810742956225d6bdd.setContent(html_a53e4bbe0ea91adc5dcce2946f4bb3cf);
#
#
#
#         marker_b7ef4dfa0a65382e7dabde9431b3cc8c.bindPopup(popup_492953b0bd27db9810742956225d6bdd)
#         ;
#
#
#
#
#             var marker_0fcc00b7e83106fa8f1527e5000a5d91 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_5fc616ea108e9b3b4ed4f27502f39f98);
#
#
#         var popup_bdbcc8a7e79174612301e6b082400973 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a5246176ccdb168f31a76fc36daaacf1 = $(`&lt;div id=&quot;html_a5246176ccdb168f31a76fc36daaacf1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_bdbcc8a7e79174612301e6b082400973.setContent(html_a5246176ccdb168f31a76fc36daaacf1);
#
#
#
#         marker_0fcc00b7e83106fa8f1527e5000a5d91.bindPopup(popup_bdbcc8a7e79174612301e6b082400973)
#         ;
#
#
#
#
#             var marker_5881cfab3b18c49d0a33799ba2da1fba = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_5fc616ea108e9b3b4ed4f27502f39f98);
#
#
#         var popup_6274ee6c70b06108a445c2029b786d5f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bbe08abcb39a8e483b8e586e139cf9b4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bbe08abcb39a8e483b8e586e139cf9b4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bbe08abcb39a8e483b8e586e139cf9b4 = L.map(
#                 &quot;map_bbe08abcb39a8e483b8e586e139cf9b4&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_665dba823c738bcba440694ac82a2a23 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_665dba823c738bcba440694ac82a2a23.addTo(map_bbe08abcb39a8e483b8e586e139cf9b4);
#
#
#             var feature_group_938aa228bf68e69aecc3834979caf46b = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_938aa228bf68e69aecc3834979caf46b.addTo(map_bbe08abcb39a8e483b8e586e139cf9b4);
#
#
#             var feature_group_sub_group_418c52fa32c80ac7ebdd95e764af559e = L.featureGroup.subGroup(
#                 feature_group_938aa228bf68e69aecc3834979caf46b
#             );
#
#
#             var marker_639e290781abb9c02ad3ba733a318aab = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_418c52fa32c80ac7ebdd95e764af559e);
#
#
#         var popup_afc3f8ed6c2f7ace85d5bc22d7e4002c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_01642fbfae0cca428e4384d545e64e29 = $(`&lt;div id=&quot;html_01642fbfae0cca428e4384d545e64e29&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_afc3f8ed6c2f7ace85d5bc22d7e4002c.setContent(html_01642fbfae0cca428e4384d545e64e29);
#
#
#
#         marker_639e290781abb9c02ad3ba733a318aab.bindPopup(popup_afc3f8ed6c2f7ace85d5bc22d7e4002c)
#         ;
#
#
#
#
#             var marker_5b102dcf96727da16b153b4bbd58bed5 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_418c52fa32c80ac7ebdd95e764af559e);
#
#
#         var popup_9a1e59d990d3831cabe91229356cc065 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2b9286e0ab3a7b30983500847220cb3d = $(`&lt;div id=&quot;html_2b9286e0ab3a7b30983500847220cb3d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_9a1e59d990d3831cabe91229356cc065.setContent(html_2b9286e0ab3a7b30983500847220cb3d);
#
#
#
#         marker_5b102dcf96727da16b153b4bbd58bed5.bindPopup(popup_9a1e59d990d3831cabe91229356cc065)
#         ;
#
#
#
#
#             var marker_c228047d34f9f1f9acc3cf06bd7bbe8a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_418c52fa32c80ac7ebdd95e764af559e);
#
#
#         var popup_eab7b86e728b9fa848c95de5e8b2b57e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_690b0ef595b21c68fe03dd2605f248b0 = $(`&lt;div id=&quot;html_690b0ef595b21c68fe03dd2605f248b0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_eab7b86e728b9fa848c95de5e8b2b57e.setContent(html_690b0ef595b21c68fe03dd2605f248b0);
#
#
#
#         marker_c228047d34f9f1f9acc3cf06bd7bbe8a.bindPopup(popup_eab7b86e728b9fa848c95de5e8b2b57e)
#         ;
#
#
#
#
#             var marker_b4d070142426746031cb3eaf69997728 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_418c52fa32c80ac7ebdd95e764af559e);
#
#
#         var popup_282291dd3e4df3738aa657dba28d46ef = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f0b5c4adbf1c58c7863bbb9490015534 = $(`&lt;div id=&quot;html_f0b5c4adbf1c58c7863bbb9490015534&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_282291dd3e4df3738aa657dba28d46ef.setContent(html_f0b5c4adbf1c58c7863bbb9490015534);
#
#
#
#         marker_
