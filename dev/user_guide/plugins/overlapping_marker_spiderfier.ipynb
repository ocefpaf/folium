# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_704ed0af1915b580318af0ad048fcdba {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_704ed0af1915b580318af0ad048fcdba&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_704ed0af1915b580318af0ad048fcdba = L.map(
#                 &quot;map_704ed0af1915b580318af0ad048fcdba&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cf37132f9c5de22fec07e4f874aba74f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_cf37132f9c5de22fec07e4f874aba74f.addTo(map_704ed0af1915b580318af0ad048fcdba);
#
#
#             var marker_77c40fd8fe702938e56d52ae6976ea5c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_704ed0af1915b580318af0ad048fcdba);
#
#
#         var popup_46ff3d4f3b6e6e40ce54fa5cd6c49d5d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1e149e1c8d3763291ea23a8274421192 = $(`&lt;div id=&quot;html_1e149e1c8d3763291ea23a8274421192&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_46ff3d4f3b6e6e40ce54fa5cd6c49d5d.setContent(html_1e149e1c8d3763291ea23a8274421192);
#
#
#
#         marker_77c40fd8fe702938e56d52ae6976ea5c.bindPopup(popup_46ff3d4f3b6e6e40ce54fa5cd6c49d5d)
#         ;
#
#
#
#
#             var marker_c9284ffd0f4a90139529796429b579fa = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_704ed0af1915b580318af0ad048fcdba);
#
#
#         var popup_7e8cf6d70f678de42af70e89dbbb79da = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0f131c329d0d18e1af423a54c5e6dc73 = $(`&lt;div id=&quot;html_0f131c329d0d18e1af423a54c5e6dc73&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_7e8cf6d70f678de42af70e89dbbb79da.setContent(html_0f131c329d0d18e1af423a54c5e6dc73);
#
#
#
#         marker_c9284ffd0f4a90139529796429b579fa.bindPopup(popup_7e8cf6d70f678de42af70e89dbbb79da)
#         ;
#
#
#
#
#             var marker_9af0d7a1f7323bf12d61897d89aaea68 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_704ed0af1915b580318af0ad048fcdba);
#
#
#         var popup_1a984cde7e3ffd930f3869ffe2d00944 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_558fa39d632e471a09c044bece361e1c = $(`&lt;div id=&quot;html_558fa39d632e471a09c044bece361e1c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_1a984cde7e3ffd930f3869ffe2d00944.setContent(html_558fa39d632e471a09c044bece361e1c);
#
#
#
#         marker_9af0d7a1f7323bf12d61897d89aaea68.bindPopup(popup_1a984cde7e3ffd930f3869ffe2d00944)
#         ;
#
#
#
#
#             var marker_52b6aff9ec36c651816c614bde8c402e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_704ed0af1915b580318af0ad048fcdba);
#
#
#         var popup_e914dbfafafcd0486a145ad246c3f64e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_adb02caf3fc65c076c89a1c145aaef7c = $(`&lt;div id=&quot;html_adb02caf3fc65c076c89a1c145aaef7c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_e914dbfafafcd0486a145ad246c3f64e.setContent(html_adb02caf3fc65c076c89a1c145aaef7c);
#
#
#
#         marker_52b6aff9ec36c651816c614bde8c402e.bindPopup(popup_e914dbfafafcd0486a145ad246c3f64e)
#         ;
#
#
#
#
#             var marker_99c5a16024059f0961665f51310ee1de = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_704ed0af1915b580318af0ad048fcdba);
#
#
#         var popup_e2ecc462a8109c8e8d1553926a9022d6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6e22bd5df76fead985671e813e5b948c = $(`&lt;div id=&quot;html_6e22bd5df76fead985671e813e5b948c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_e2ecc462a8109c8e8d1553926a9022d6.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c873710fff7131873ad09b2cf208894d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c873710fff7131873ad09b2cf208894d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c873710fff7131873ad09b2cf208894d = L.map(
#                 &quot;map_c873710fff7131873ad09b2cf208894d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7560a5417f3ffe31b778027842c71778 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7560a5417f3ffe31b778027842c71778.addTo(map_c873710fff7131873ad09b2cf208894d);
#
#
#             var feature_group_6d3ab35c900bc41a56553987f8a2153c = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_47e7351138eddf89fc040ae7eda2d075 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_6d3ab35c900bc41a56553987f8a2153c);
#
#
#         var popup_f9fb648337d599f385533e6b92f398ad = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2efdd13004292952f11f64ab330b86f9 = $(`&lt;div id=&quot;html_2efdd13004292952f11f64ab330b86f9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_f9fb648337d599f385533e6b92f398ad.setContent(html_2efdd13004292952f11f64ab330b86f9);
#
#
#
#         marker_47e7351138eddf89fc040ae7eda2d075.bindPopup(popup_f9fb648337d599f385533e6b92f398ad)
#         ;
#
#
#
#
#             var marker_35dd22b18ecebbc56d233b48c1455af3 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_6d3ab35c900bc41a56553987f8a2153c);
#
#
#         var popup_08ecd6d830a9dbabccaa010518653a7f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f674770828700675e5ede3f038db6a92 = $(`&lt;div id=&quot;html_f674770828700675e5ede3f038db6a92&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_08ecd6d830a9dbabccaa010518653a7f.setContent(html_f674770828700675e5ede3f038db6a92);
#
#
#
#         marker_35dd22b18ecebbc56d233b48c1455af3.bindPopup(popup_08ecd6d830a9dbabccaa010518653a7f)
#         ;
#
#
#
#
#             var marker_9449de981942e824e84e85dfbf1ef573 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_6d3ab35c900bc41a56553987f8a2153c);
#
#
#         var popup_23079e2f70720a1ea3dae57f3671a66b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e8965a37bfc3162cc9db97b5503e4a8a = $(`&lt;div id=&quot;html_e8965a37bfc3162cc9db97b5503e4a8a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_23079e2f70720a1ea3dae57f3671a66b.setContent(html_e8965a37bfc3162cc9db97b5503e4a8a);
#
#
#
#         marker_9449de981942e824e84e85dfbf1ef573.bindPopup(popup_23079e2f70720a1ea3dae57f3671a66b)
#         ;
#
#
#
#
#             var marker_f58dfb700c1fda1232af6684b8897deb = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_6d3ab35c900bc41a56553987f8a2153c);
#
#
#         var popup_ec30cd0bf865303de1057722eba9ca79 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f37a9a4aa3f98f0044d0d4c08498cf4e = $(`&lt;div id=&quot;html_f37a9a4aa3f98f0044d0d4c08498cf4e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_ec30cd0bf865303de1057722eba9ca79.setContent(html_f37a9a4aa3f98f0044d0d4c08498cf4e);
#
#
#
#         marker_f58dfb700c1fda1232af6684b8897deb.bindPopup(popup_ec30cd0bf865303de1057722eba9ca79)
#         ;
#
#
#
#
#             var marker_653459cf24f8fbc0dfc49e19afde4b7b = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_6d3ab35c900bc41a56553987f8a2153c);
#
#
#         var popup_f33501f8484f6b95a5965ccbfaedc7ba = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_287cee385853e53b6cb69fc1deab2638 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_287cee385853e53b6cb69fc1deab2638&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_287cee385853e53b6cb69fc1deab2638 = L.map(
#                 &quot;map_287cee385853e53b6cb69fc1deab2638&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fb185446dc096e04399391f27628ffab = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_fb185446dc096e04399391f27628ffab.addTo(map_287cee385853e53b6cb69fc1deab2638);
#
#
#             var feature_group_df0b5dcf8ff7459acc51bb291953eeb7 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_df0b5dcf8ff7459acc51bb291953eeb7.addTo(map_287cee385853e53b6cb69fc1deab2638);
#
#
#             var feature_group_sub_group_7d5dca71f4c8a0f2ad94635a8f3e2f51 = L.featureGroup.subGroup(
#                 feature_group_df0b5dcf8ff7459acc51bb291953eeb7
#             );
#
#
#             var marker_525d01d091d3abdbbc103f1bae493873 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_7d5dca71f4c8a0f2ad94635a8f3e2f51);
#
#
#         var popup_51c7aca3dd65fe07abb91d493192e9cd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c311e29bcf9d59399f0b5cf2ecba67c0 = $(`&lt;div id=&quot;html_c311e29bcf9d59399f0b5cf2ecba67c0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_51c7aca3dd65fe07abb91d493192e9cd.setContent(html_c311e29bcf9d59399f0b5cf2ecba67c0);
#
#
#
#         marker_525d01d091d3abdbbc103f1bae493873.bindPopup(popup_51c7aca3dd65fe07abb91d493192e9cd)
#         ;
#
#
#
#
#             var marker_9aadda69f264fdcebd84f1bf290bd9b0 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_7d5dca71f4c8a0f2ad94635a8f3e2f51);
#
#
#         var popup_78d8fbe2f0bd22ed05e02ebe71864b26 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1b59c0a761d0089505f43fedc12e19ad = $(`&lt;div id=&quot;html_1b59c0a761d0089505f43fedc12e19ad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_78d8fbe2f0bd22ed05e02ebe71864b26.setContent(html_1b59c0a761d0089505f43fedc12e19ad);
#
#
#
#         marker_9aadda69f264fdcebd84f1bf290bd9b0.bindPopup(popup_78d8fbe2f0bd22ed05e02ebe71864b26)
#         ;
#
#
#
#
#             var marker_a340005a41340999caeaa92288f8aa06 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_7d5dca71f4c8a0f2ad94635a8f3e2f51);
#
#
#         var popup_0ca1e9dc0457b544346b651c6798827c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_aec410e0c952485b89334512a87ba718 = $(`&lt;div id=&quot;html_aec410e0c952485b89334512a87ba718&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_0ca1e9dc0457b544346b651c6798827c.setContent(html_aec410e0c952485b89334512a87ba718);
#
#
#
#         marker_a340005a41340999caeaa92288f8aa06.bindPopup(popup_0ca1e9dc0457b544346b651c6798827c)
#         ;
#
#
#
#
#             var marker_ed26c7a8f8778bd6d39e06cb3968cca5 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_7d5dca71f4c8a0f2ad94635a8f3e2f51);
#
#
#         var popup_d3a995708855a7e61989f9b388d594a6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a02c7c870a762222d7b503910bf7b63c = $(`&lt;div id=&quot;html_a02c7c870a762222d7b503910bf7b63c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_d3a995708855a7e61989f9b388d594a6.setContent(html_a02c7c870a762222d7b503910bf7b63c);
#
#
#
#         marker_
