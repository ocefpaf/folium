# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4ace1acd72a9f5639503d20e7a4df975 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4ace1acd72a9f5639503d20e7a4df975&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4ace1acd72a9f5639503d20e7a4df975 = L.map(
#                 &quot;map_4ace1acd72a9f5639503d20e7a4df975&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_404e4b5b68803fd0911f4de3196526d4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_404e4b5b68803fd0911f4de3196526d4.addTo(map_4ace1acd72a9f5639503d20e7a4df975);
#
#
#             var marker_690a743bf55c2f7881e16fd1265084b7 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_4ace1acd72a9f5639503d20e7a4df975);
#
#
#         var popup_8633837c4cf1e667c3d2ef1516aef6a3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ebc37a7a47b84586f3c1677492e5dc13 = $(`&lt;div id=&quot;html_ebc37a7a47b84586f3c1677492e5dc13&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_8633837c4cf1e667c3d2ef1516aef6a3.setContent(html_ebc37a7a47b84586f3c1677492e5dc13);
#
#
#
#         marker_690a743bf55c2f7881e16fd1265084b7.bindPopup(popup_8633837c4cf1e667c3d2ef1516aef6a3)
#         ;
#
#
#
#
#             var marker_10af2bc09855b2422537be5ef2b164af = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_4ace1acd72a9f5639503d20e7a4df975);
#
#
#         var popup_52696e4f785b3be3e0794343de74402c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_165daa4afd9a82ecddf8094d3af033d4 = $(`&lt;div id=&quot;html_165daa4afd9a82ecddf8094d3af033d4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_52696e4f785b3be3e0794343de74402c.setContent(html_165daa4afd9a82ecddf8094d3af033d4);
#
#
#
#         marker_10af2bc09855b2422537be5ef2b164af.bindPopup(popup_52696e4f785b3be3e0794343de74402c)
#         ;
#
#
#
#
#             var marker_6adccb701e473756bec281c74510aba8 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_4ace1acd72a9f5639503d20e7a4df975);
#
#
#         var popup_061822e0c9a988657101befb6badce86 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e92fa46cdc1f2a8e5bfafbeaf30c55cf = $(`&lt;div id=&quot;html_e92fa46cdc1f2a8e5bfafbeaf30c55cf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_061822e0c9a988657101befb6badce86.setContent(html_e92fa46cdc1f2a8e5bfafbeaf30c55cf);
#
#
#
#         marker_6adccb701e473756bec281c74510aba8.bindPopup(popup_061822e0c9a988657101befb6badce86)
#         ;
#
#
#
#
#             var marker_0233a74f31d514f0b4db8a27ef85f426 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_4ace1acd72a9f5639503d20e7a4df975);
#
#
#         var popup_7560cbf0c3b15bd03d2d0e92ae5ae968 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8b52b9fc2829a32f60df72079bbddf22 = $(`&lt;div id=&quot;html_8b52b9fc2829a32f60df72079bbddf22&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_7560cbf0c3b15bd03d2d0e92ae5ae968.setContent(html_8b52b9fc2829a32f60df72079bbddf22);
#
#
#
#         marker_0233a74f31d514f0b4db8a27ef85f426.bindPopup(popup_7560cbf0c3b15bd03d2d0e92ae5ae968)
#         ;
#
#
#
#
#             var marker_b122bf99b2bd1e5e18c4dd570d52fabf = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_4ace1acd72a9f5639503d20e7a4df975);
#
#
#         var popup_8fe8af62fef04082a5fd3804a9a574dc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_282cf33a40526485e042c78c900e1114 = $(`&lt;div id=&quot;html_282cf33a40526485e042c78c900e1114&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_8fe8af62fef04082a5fd3804a9a574dc.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d0e522ea54c8a1d6ccbc91b76987367d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d0e522ea54c8a1d6ccbc91b76987367d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d0e522ea54c8a1d6ccbc91b76987367d = L.map(
#                 &quot;map_d0e522ea54c8a1d6ccbc91b76987367d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_16e91e8c1ab4a7ea75513a68768751c8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_16e91e8c1ab4a7ea75513a68768751c8.addTo(map_d0e522ea54c8a1d6ccbc91b76987367d);
#
#
#             var feature_group_1b82733005ebcf650aac0f3fc1f377a7 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_7e00f4b546ddb0cb5e02cb4239c7ce5c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_1b82733005ebcf650aac0f3fc1f377a7);
#
#
#         var popup_f8910da9c2b5dd7801f3f9b21c50bbd1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3dfd5f17c1f421e68869b0e22362dbfd = $(`&lt;div id=&quot;html_3dfd5f17c1f421e68869b0e22362dbfd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_f8910da9c2b5dd7801f3f9b21c50bbd1.setContent(html_3dfd5f17c1f421e68869b0e22362dbfd);
#
#
#
#         marker_7e00f4b546ddb0cb5e02cb4239c7ce5c.bindPopup(popup_f8910da9c2b5dd7801f3f9b21c50bbd1)
#         ;
#
#
#
#
#             var marker_dfd266463c81c68ef2ec24461fca53a6 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_1b82733005ebcf650aac0f3fc1f377a7);
#
#
#         var popup_6b1d83b975b27ba545720603a9459f9d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_63cce76701771e12655c2ef28d5d6823 = $(`&lt;div id=&quot;html_63cce76701771e12655c2ef28d5d6823&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_6b1d83b975b27ba545720603a9459f9d.setContent(html_63cce76701771e12655c2ef28d5d6823);
#
#
#
#         marker_dfd266463c81c68ef2ec24461fca53a6.bindPopup(popup_6b1d83b975b27ba545720603a9459f9d)
#         ;
#
#
#
#
#             var marker_cc773507b0b4f00f107fc0db2dedcc5a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_1b82733005ebcf650aac0f3fc1f377a7);
#
#
#         var popup_71726826fe4238f73c68640145511dd1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ba727fd0720a241de4a021025475f52e = $(`&lt;div id=&quot;html_ba727fd0720a241de4a021025475f52e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_71726826fe4238f73c68640145511dd1.setContent(html_ba727fd0720a241de4a021025475f52e);
#
#
#
#         marker_cc773507b0b4f00f107fc0db2dedcc5a.bindPopup(popup_71726826fe4238f73c68640145511dd1)
#         ;
#
#
#
#
#             var marker_ddc89e8bac4e8a9236c5934e728556a8 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_1b82733005ebcf650aac0f3fc1f377a7);
#
#
#         var popup_bd403fcda6fd41621f63f4427c172383 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fc52a83f2732e8d9a36e9fea8fe6f42e = $(`&lt;div id=&quot;html_fc52a83f2732e8d9a36e9fea8fe6f42e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_bd403fcda6fd41621f63f4427c172383.setContent(html_fc52a83f2732e8d9a36e9fea8fe6f42e);
#
#
#
#         marker_ddc89e8bac4e8a9236c5934e728556a8.bindPopup(popup_bd403fcda6fd41621f63f4427c172383)
#         ;
#
#
#
#
#             var marker_6ffa63e6c40f2739212b74b7d042300e = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_1b82733005ebcf650aac0f3fc1f377a7);
#
#
#         var popup_1b85d997ce515ff4e53cf63d634eebf9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_16530c8f30f424ddd6ea8972f1fe2b3c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_16530c8f30f424ddd6ea8972f1fe2b3c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_16530c8f30f424ddd6ea8972f1fe2b3c = L.map(
#                 &quot;map_16530c8f30f424ddd6ea8972f1fe2b3c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_90c1126566703ef463626c3cfe68b2ed = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_90c1126566703ef463626c3cfe68b2ed.addTo(map_16530c8f30f424ddd6ea8972f1fe2b3c);
#
#
#             var feature_group_f99d4eb1e4e7b0d4b1381a58b15fc087 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_f99d4eb1e4e7b0d4b1381a58b15fc087.addTo(map_16530c8f30f424ddd6ea8972f1fe2b3c);
#
#
#             var feature_group_sub_group_c8d3cac4fda19640e4d8c6e66b28c01b = L.featureGroup.subGroup(
#                 feature_group_f99d4eb1e4e7b0d4b1381a58b15fc087
#             );
#
#
#             var marker_ee9126ce2b496bc257899d82460cb57a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_c8d3cac4fda19640e4d8c6e66b28c01b);
#
#
#         var popup_224e88b200bb758559be296e4f0d04fd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_805ba6441256a4b93994ec1db872cb73 = $(`&lt;div id=&quot;html_805ba6441256a4b93994ec1db872cb73&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_224e88b200bb758559be296e4f0d04fd.setContent(html_805ba6441256a4b93994ec1db872cb73);
#
#
#
#         marker_ee9126ce2b496bc257899d82460cb57a.bindPopup(popup_224e88b200bb758559be296e4f0d04fd)
#         ;
#
#
#
#
#             var marker_7f843feff3271210708ab8aca97ec130 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_c8d3cac4fda19640e4d8c6e66b28c01b);
#
#
#         var popup_41f3754b628fbc2c89618f32a8c67fb7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9b7bfe12c4fb402ab9a2e49606fba4da = $(`&lt;div id=&quot;html_9b7bfe12c4fb402ab9a2e49606fba4da&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_41f3754b628fbc2c89618f32a8c67fb7.setContent(html_9b7bfe12c4fb402ab9a2e49606fba4da);
#
#
#
#         marker_7f843feff3271210708ab8aca97ec130.bindPopup(popup_41f3754b628fbc2c89618f32a8c67fb7)
#         ;
#
#
#
#
#             var marker_8190598ccc18d0b321b00f2a31791f61 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_c8d3cac4fda19640e4d8c6e66b28c01b);
#
#
#         var popup_3ab790559faa15b6ed60d13abb81c081 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3a38f02de3ef570c7d546c36b18afc66 = $(`&lt;div id=&quot;html_3a38f02de3ef570c7d546c36b18afc66&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_3ab790559faa15b6ed60d13abb81c081.setContent(html_3a38f02de3ef570c7d546c36b18afc66);
#
#
#
#         marker_8190598ccc18d0b321b00f2a31791f61.bindPopup(popup_3ab790559faa15b6ed60d13abb81c081)
#         ;
#
#
#
#
#             var marker_07971fa6e2119ff8169d0f0d2887d521 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_c8d3cac4fda19640e4d8c6e66b28c01b);
#
#
#         var popup_5f97612e4c2c4265e01833d90f15ff14 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5d86068a501e6efbf7f4a504e922dbf1 = $(`&lt;div id=&quot;html_5d86068a501e6efbf7f4a504e922dbf1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_5f97612e4c2c4265e01833d90f15ff14.setContent(html_5d86068a501e6efbf7f4a504e922dbf1);
#
#
#
#         marker_
