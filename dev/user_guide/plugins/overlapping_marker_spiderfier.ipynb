# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f52cb10031da45755a74887f6978abe6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f52cb10031da45755a74887f6978abe6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f52cb10031da45755a74887f6978abe6 = L.map(
#                 &quot;map_f52cb10031da45755a74887f6978abe6&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_800812f505b96c59006f0cffa346aa23 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_800812f505b96c59006f0cffa346aa23.addTo(map_f52cb10031da45755a74887f6978abe6);
#
#
#             var marker_1f4c9c85d813a6006985dbe2bf8446ce = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_f52cb10031da45755a74887f6978abe6);
#
#
#         var popup_d3ace5443d6a6093543a43080b661a23 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_90bb2d3b72ba4033bc3fca301dac87d7 = $(`&lt;div id=&quot;html_90bb2d3b72ba4033bc3fca301dac87d7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_d3ace5443d6a6093543a43080b661a23.setContent(html_90bb2d3b72ba4033bc3fca301dac87d7);
#
#
#
#         marker_1f4c9c85d813a6006985dbe2bf8446ce.bindPopup(popup_d3ace5443d6a6093543a43080b661a23)
#         ;
#
#
#
#
#             var marker_629ff70f424ea53039bcd12048edb121 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_f52cb10031da45755a74887f6978abe6);
#
#
#         var popup_dc18e356d776c1ca9b7824842e610ce2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_be7004b47dfe3d4b64bcb5cbedeee9b4 = $(`&lt;div id=&quot;html_be7004b47dfe3d4b64bcb5cbedeee9b4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_dc18e356d776c1ca9b7824842e610ce2.setContent(html_be7004b47dfe3d4b64bcb5cbedeee9b4);
#
#
#
#         marker_629ff70f424ea53039bcd12048edb121.bindPopup(popup_dc18e356d776c1ca9b7824842e610ce2)
#         ;
#
#
#
#
#             var marker_01a523cd214f37c4a53ff41892ebd73d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_f52cb10031da45755a74887f6978abe6);
#
#
#         var popup_3b9eb81c37dda90986e545ed9d709ee5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c283e86655d5ed399165987c835f727d = $(`&lt;div id=&quot;html_c283e86655d5ed399165987c835f727d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_3b9eb81c37dda90986e545ed9d709ee5.setContent(html_c283e86655d5ed399165987c835f727d);
#
#
#
#         marker_01a523cd214f37c4a53ff41892ebd73d.bindPopup(popup_3b9eb81c37dda90986e545ed9d709ee5)
#         ;
#
#
#
#
#             var marker_1a40ad9ace8195e9fe52b630cefefe55 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_f52cb10031da45755a74887f6978abe6);
#
#
#         var popup_3630e27146db36de49ad8afb56e4f496 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2e7cf585b29b884055634c79f3226179 = $(`&lt;div id=&quot;html_2e7cf585b29b884055634c79f3226179&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_3630e27146db36de49ad8afb56e4f496.setContent(html_2e7cf585b29b884055634c79f3226179);
#
#
#
#         marker_1a40ad9ace8195e9fe52b630cefefe55.bindPopup(popup_3630e27146db36de49ad8afb56e4f496)
#         ;
#
#
#
#
#             var marker_a5a58f0b14fb3a8a54fb36551c9127d0 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_f52cb10031da45755a74887f6978abe6);
#
#
#         var popup_868da3ce44bf7d315cd194ba3965e144 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2b9c57534736900014bd8a397a1c460c = $(`&lt;div id=&quot;html_2b9c57534736900014bd8a397a1c460c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_868da3ce44bf7d315cd194ba3965e144.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4d493f8d1d0667083b99c17018e421d8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4d493f8d1d0667083b99c17018e421d8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4d493f8d1d0667083b99c17018e421d8 = L.map(
#                 &quot;map_4d493f8d1d0667083b99c17018e421d8&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7d679f82412fdd9c7510c06af87c24f7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7d679f82412fdd9c7510c06af87c24f7.addTo(map_4d493f8d1d0667083b99c17018e421d8);
#
#
#             var feature_group_02e59d8a922aedb8b48bea2b800f991f = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_287bafb8a8767c000394c57a7c2456f1 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_02e59d8a922aedb8b48bea2b800f991f);
#
#
#         var popup_5fd60c800df4dbf4dc4af051ab351000 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f0d92f425bb9fce575bb6cac0a3f43aa = $(`&lt;div id=&quot;html_f0d92f425bb9fce575bb6cac0a3f43aa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_5fd60c800df4dbf4dc4af051ab351000.setContent(html_f0d92f425bb9fce575bb6cac0a3f43aa);
#
#
#
#         marker_287bafb8a8767c000394c57a7c2456f1.bindPopup(popup_5fd60c800df4dbf4dc4af051ab351000)
#         ;
#
#
#
#
#             var marker_32907a9fd24093f20ed64192f4b1fb11 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_02e59d8a922aedb8b48bea2b800f991f);
#
#
#         var popup_debb9730120c1a63633a2d45d9ec1237 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_13f85d5ea2879d5fb4e897206b27102a = $(`&lt;div id=&quot;html_13f85d5ea2879d5fb4e897206b27102a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_debb9730120c1a63633a2d45d9ec1237.setContent(html_13f85d5ea2879d5fb4e897206b27102a);
#
#
#
#         marker_32907a9fd24093f20ed64192f4b1fb11.bindPopup(popup_debb9730120c1a63633a2d45d9ec1237)
#         ;
#
#
#
#
#             var marker_5a99588577b3fa3361114a8418357cb4 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_02e59d8a922aedb8b48bea2b800f991f);
#
#
#         var popup_b022dd79dfb220f6bbe6a2309359fa1e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c2b168301555396f533c3badf23694b9 = $(`&lt;div id=&quot;html_c2b168301555396f533c3badf23694b9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_b022dd79dfb220f6bbe6a2309359fa1e.setContent(html_c2b168301555396f533c3badf23694b9);
#
#
#
#         marker_5a99588577b3fa3361114a8418357cb4.bindPopup(popup_b022dd79dfb220f6bbe6a2309359fa1e)
#         ;
#
#
#
#
#             var marker_6b281d971456b59f6217f916c810f4d0 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_02e59d8a922aedb8b48bea2b800f991f);
#
#
#         var popup_6c661bcae887bbca80895ce81a07b0b3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b917e2f3d1f2c5fd811cfc86c69e807e = $(`&lt;div id=&quot;html_b917e2f3d1f2c5fd811cfc86c69e807e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_6c661bcae887bbca80895ce81a07b0b3.setContent(html_b917e2f3d1f2c5fd811cfc86c69e807e);
#
#
#
#         marker_6b281d971456b59f6217f916c810f4d0.bindPopup(popup_6c661bcae887bbca80895ce81a07b0b3)
#         ;
#
#
#
#
#             var marker_67fa6ffe6b0148018ba573a6a77000ce = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_02e59d8a922aedb8b48bea2b800f991f);
#
#
#         var popup_e8d91c9cf5336fda0b766cc7fe1f931d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c2e3b31668c8fe3112fc8bce994d496c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c2e3b31668c8fe3112fc8bce994d496c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c2e3b31668c8fe3112fc8bce994d496c = L.map(
#                 &quot;map_c2e3b31668c8fe3112fc8bce994d496c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fe7f22c08190d21a75c992e1aad5f736 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_fe7f22c08190d21a75c992e1aad5f736.addTo(map_c2e3b31668c8fe3112fc8bce994d496c);
#
#
#             var feature_group_5f6eac176b19932eb7f25df947c70094 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_5f6eac176b19932eb7f25df947c70094.addTo(map_c2e3b31668c8fe3112fc8bce994d496c);
#
#
#             var feature_group_sub_group_dd3c466e2df241562910e8e5f3b111fb = L.featureGroup.subGroup(
#                 feature_group_5f6eac176b19932eb7f25df947c70094
#             );
#
#
#             var marker_038d49b8b8cfe07310d3638c22141097 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_dd3c466e2df241562910e8e5f3b111fb);
#
#
#         var popup_0591c75a0a2cfaed5413e9d61e71e3cd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3528182049dc6f529ad4628a4b2be200 = $(`&lt;div id=&quot;html_3528182049dc6f529ad4628a4b2be200&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_0591c75a0a2cfaed5413e9d61e71e3cd.setContent(html_3528182049dc6f529ad4628a4b2be200);
#
#
#
#         marker_038d49b8b8cfe07310d3638c22141097.bindPopup(popup_0591c75a0a2cfaed5413e9d61e71e3cd)
#         ;
#
#
#
#
#             var marker_440bd2d23ca1e2eaf2b4f75935038253 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_dd3c466e2df241562910e8e5f3b111fb);
#
#
#         var popup_dd35e8ad12c348a63e44daa3e47e2141 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_57211afaf71f50e73cb169ade98471ce = $(`&lt;div id=&quot;html_57211afaf71f50e73cb169ade98471ce&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_dd35e8ad12c348a63e44daa3e47e2141.setContent(html_57211afaf71f50e73cb169ade98471ce);
#
#
#
#         marker_440bd2d23ca1e2eaf2b4f75935038253.bindPopup(popup_dd35e8ad12c348a63e44daa3e47e2141)
#         ;
#
#
#
#
#             var marker_8202d7231385b07c52bb7ad434b58fc2 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_dd3c466e2df241562910e8e5f3b111fb);
#
#
#         var popup_7dbddbb368ee4d79f0e2ee765dc51a72 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1193983e1c9beceb61486ba23a4cc324 = $(`&lt;div id=&quot;html_1193983e1c9beceb61486ba23a4cc324&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_7dbddbb368ee4d79f0e2ee765dc51a72.setContent(html_1193983e1c9beceb61486ba23a4cc324);
#
#
#
#         marker_8202d7231385b07c52bb7ad434b58fc2.bindPopup(popup_7dbddbb368ee4d79f0e2ee765dc51a72)
#         ;
#
#
#
#
#             var marker_6ecc78132191a96c54b3e7652d2b6982 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_dd3c466e2df241562910e8e5f3b111fb);
#
#
#         var popup_f9596276f33e3d12c927162541d2136d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5ab9ecedc6b1f744f7ccf839485bd2cb = $(`&lt;div id=&quot;html_5ab9ecedc6b1f744f7ccf839485bd2cb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_f9596276f33e3d12c927162541d2136d.setContent(html_5ab9ecedc6b1f744f7ccf839485bd2cb);
#
#
#
#         marker_
