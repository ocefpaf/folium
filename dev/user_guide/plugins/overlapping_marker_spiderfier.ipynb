# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3dee95f8fe89eb050c2c8cb05a9dac38 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3dee95f8fe89eb050c2c8cb05a9dac38&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3dee95f8fe89eb050c2c8cb05a9dac38 = L.map(
#                 &quot;map_3dee95f8fe89eb050c2c8cb05a9dac38&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fe37c88c3a9dfb9a90b72027bc0ab045 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_fe37c88c3a9dfb9a90b72027bc0ab045.addTo(map_3dee95f8fe89eb050c2c8cb05a9dac38);
#
#
#             var marker_2544d645e1c576b4772248bf8a120787 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_3dee95f8fe89eb050c2c8cb05a9dac38);
#
#
#         var popup_7704016a713fa72ea815c2f3ca5c91a3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ee0f7803d789767663854cbaae2c3e13 = $(`&lt;div id=&quot;html_ee0f7803d789767663854cbaae2c3e13&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_7704016a713fa72ea815c2f3ca5c91a3.setContent(html_ee0f7803d789767663854cbaae2c3e13);
#
#
#
#         marker_2544d645e1c576b4772248bf8a120787.bindPopup(popup_7704016a713fa72ea815c2f3ca5c91a3)
#         ;
#
#
#
#
#             var marker_90d34500e3a1ca709a20f86ad242e6d7 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_3dee95f8fe89eb050c2c8cb05a9dac38);
#
#
#         var popup_688831e69bcfcf56e19590768f1bb3c9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_30e7549eb5af4c5d16cc94c3988572ff = $(`&lt;div id=&quot;html_30e7549eb5af4c5d16cc94c3988572ff&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_688831e69bcfcf56e19590768f1bb3c9.setContent(html_30e7549eb5af4c5d16cc94c3988572ff);
#
#
#
#         marker_90d34500e3a1ca709a20f86ad242e6d7.bindPopup(popup_688831e69bcfcf56e19590768f1bb3c9)
#         ;
#
#
#
#
#             var marker_598ef26aa85f7705a82413c8c0423cba = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_3dee95f8fe89eb050c2c8cb05a9dac38);
#
#
#         var popup_45666a8f1f89ce08fbe2d94362db4393 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8d86f42809c7f81e90c0df1e63db3bd0 = $(`&lt;div id=&quot;html_8d86f42809c7f81e90c0df1e63db3bd0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_45666a8f1f89ce08fbe2d94362db4393.setContent(html_8d86f42809c7f81e90c0df1e63db3bd0);
#
#
#
#         marker_598ef26aa85f7705a82413c8c0423cba.bindPopup(popup_45666a8f1f89ce08fbe2d94362db4393)
#         ;
#
#
#
#
#             var marker_b6e1b604c6acc1d9fe24afd961f9782a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_3dee95f8fe89eb050c2c8cb05a9dac38);
#
#
#         var popup_a638ad74c08ebdb8648806bac0d27971 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f455c750bfe7deeffe8ce54fbf4a347d = $(`&lt;div id=&quot;html_f455c750bfe7deeffe8ce54fbf4a347d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_a638ad74c08ebdb8648806bac0d27971.setContent(html_f455c750bfe7deeffe8ce54fbf4a347d);
#
#
#
#         marker_b6e1b604c6acc1d9fe24afd961f9782a.bindPopup(popup_a638ad74c08ebdb8648806bac0d27971)
#         ;
#
#
#
#
#             var marker_bf0bab391e0e7348cfe4fe694302c455 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_3dee95f8fe89eb050c2c8cb05a9dac38);
#
#
#         var popup_5b50a818c3cea34d02c45eb82ea1a14f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_646c4e0dc544feda27e99d393b0d6941 = $(`&lt;div id=&quot;html_646c4e0dc544feda27e99d393b0d6941&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_5b50a818c3cea34d02c45eb82ea1a14f.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f217f04b00be84a365d1bfc9218274ae {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f217f04b00be84a365d1bfc9218274ae&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f217f04b00be84a365d1bfc9218274ae = L.map(
#                 &quot;map_f217f04b00be84a365d1bfc9218274ae&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_77f50fc0170f1f6d867678fe7a6d3df9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_77f50fc0170f1f6d867678fe7a6d3df9.addTo(map_f217f04b00be84a365d1bfc9218274ae);
#
#
#             var feature_group_016227dd1d235983bd1383cc4174e777 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_2f6cfbc77fb836a2d7593fde5d0413b7 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_016227dd1d235983bd1383cc4174e777);
#
#
#         var popup_b9d0e6c27dc5d08d9c70e62ed01c243f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b2a4be68916450d7288a04f08924a6a8 = $(`&lt;div id=&quot;html_b2a4be68916450d7288a04f08924a6a8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_b9d0e6c27dc5d08d9c70e62ed01c243f.setContent(html_b2a4be68916450d7288a04f08924a6a8);
#
#
#
#         marker_2f6cfbc77fb836a2d7593fde5d0413b7.bindPopup(popup_b9d0e6c27dc5d08d9c70e62ed01c243f)
#         ;
#
#
#
#
#             var marker_52d96890cf9cf7e6ad138c63625eab54 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_016227dd1d235983bd1383cc4174e777);
#
#
#         var popup_73f9942d7c9935804aa3dc820881502f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2eb585af8053c0498c9cfd315a8ef22b = $(`&lt;div id=&quot;html_2eb585af8053c0498c9cfd315a8ef22b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_73f9942d7c9935804aa3dc820881502f.setContent(html_2eb585af8053c0498c9cfd315a8ef22b);
#
#
#
#         marker_52d96890cf9cf7e6ad138c63625eab54.bindPopup(popup_73f9942d7c9935804aa3dc820881502f)
#         ;
#
#
#
#
#             var marker_30091ee362092270f6bec1fed49ad5bf = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_016227dd1d235983bd1383cc4174e777);
#
#
#         var popup_1cd698a5346737cba50537e4e3159f4c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_76c04ce16b5c46ea2e5d728a3073da0f = $(`&lt;div id=&quot;html_76c04ce16b5c46ea2e5d728a3073da0f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_1cd698a5346737cba50537e4e3159f4c.setContent(html_76c04ce16b5c46ea2e5d728a3073da0f);
#
#
#
#         marker_30091ee362092270f6bec1fed49ad5bf.bindPopup(popup_1cd698a5346737cba50537e4e3159f4c)
#         ;
#
#
#
#
#             var marker_69ead5cae4cd8cbc4e31811e52d65653 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_016227dd1d235983bd1383cc4174e777);
#
#
#         var popup_12e066561b1a2564d0bfa56534e6ad30 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ceb1dc08b0a0c07ab386c70872956f35 = $(`&lt;div id=&quot;html_ceb1dc08b0a0c07ab386c70872956f35&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_12e066561b1a2564d0bfa56534e6ad30.setContent(html_ceb1dc08b0a0c07ab386c70872956f35);
#
#
#
#         marker_69ead5cae4cd8cbc4e31811e52d65653.bindPopup(popup_12e066561b1a2564d0bfa56534e6ad30)
#         ;
#
#
#
#
#             var marker_c796e5f088956b50c64663f60c1cd847 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_016227dd1d235983bd1383cc4174e777);
#
#
#         var popup_f30ed047d2b1a96804718ef9d9e61051 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d1686fd71c95d9de68b2a18302866932 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d1686fd71c95d9de68b2a18302866932&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d1686fd71c95d9de68b2a18302866932 = L.map(
#                 &quot;map_d1686fd71c95d9de68b2a18302866932&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3312db789f8b1610027fe1630bf6f0c1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3312db789f8b1610027fe1630bf6f0c1.addTo(map_d1686fd71c95d9de68b2a18302866932);
#
#
#             var feature_group_7a2d5cd30354c19b14f046069455fb56 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_7a2d5cd30354c19b14f046069455fb56.addTo(map_d1686fd71c95d9de68b2a18302866932);
#
#
#             var feature_group_sub_group_0d6f460f09c0f59fcd3e25b7a6080864 = L.featureGroup.subGroup(
#                 feature_group_7a2d5cd30354c19b14f046069455fb56
#             );
#
#
#             var marker_02d8874ae857b994002f1315587282e6 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_0d6f460f09c0f59fcd3e25b7a6080864);
#
#
#         var popup_7a975852f90e01e4b96056c0039a89f7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2b0ef1097cfa2a3a9fdea61d264eb2fa = $(`&lt;div id=&quot;html_2b0ef1097cfa2a3a9fdea61d264eb2fa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_7a975852f90e01e4b96056c0039a89f7.setContent(html_2b0ef1097cfa2a3a9fdea61d264eb2fa);
#
#
#
#         marker_02d8874ae857b994002f1315587282e6.bindPopup(popup_7a975852f90e01e4b96056c0039a89f7)
#         ;
#
#
#
#
#             var marker_1880e75329086f7a43738c2e0b196304 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_0d6f460f09c0f59fcd3e25b7a6080864);
#
#
#         var popup_e464b50dd58cfc17e05ff7d15c2adec5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e8c6aa222f0030e6aa44b8e92b32e674 = $(`&lt;div id=&quot;html_e8c6aa222f0030e6aa44b8e92b32e674&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_e464b50dd58cfc17e05ff7d15c2adec5.setContent(html_e8c6aa222f0030e6aa44b8e92b32e674);
#
#
#
#         marker_1880e75329086f7a43738c2e0b196304.bindPopup(popup_e464b50dd58cfc17e05ff7d15c2adec5)
#         ;
#
#
#
#
#             var marker_313e7855c5adc46cd704770307d302c7 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_0d6f460f09c0f59fcd3e25b7a6080864);
#
#
#         var popup_20bf2f3b0900953a83705e82a74339e1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f289df0cf6f34b4cc8646b883eb7571e = $(`&lt;div id=&quot;html_f289df0cf6f34b4cc8646b883eb7571e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_20bf2f3b0900953a83705e82a74339e1.setContent(html_f289df0cf6f34b4cc8646b883eb7571e);
#
#
#
#         marker_313e7855c5adc46cd704770307d302c7.bindPopup(popup_20bf2f3b0900953a83705e82a74339e1)
#         ;
#
#
#
#
#             var marker_d1e01597a0213d6e89a974f3d05f3d36 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_0d6f460f09c0f59fcd3e25b7a6080864);
#
#
#         var popup_f0aac07b4b14f1092b36b99845f31c01 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cb84256e2e92fe44dc4872dc5e9875fa = $(`&lt;div id=&quot;html_cb84256e2e92fe44dc4872dc5e9875fa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_f0aac07b4b14f1092b36b99845f31c01.setContent(html_cb84256e2e92fe44dc4872dc5e9875fa);
#
#
#
#         marker_
