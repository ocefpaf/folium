# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_45c2f5faf873d9345cd37b8ee3ab400e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_45c2f5faf873d9345cd37b8ee3ab400e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_45c2f5faf873d9345cd37b8ee3ab400e = L.map(
#                 &quot;map_45c2f5faf873d9345cd37b8ee3ab400e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_535c93cf0a90a826fc542ae15bd0303d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_535c93cf0a90a826fc542ae15bd0303d.addTo(map_45c2f5faf873d9345cd37b8ee3ab400e);
#
#
#             var marker_3a904fa74acfffd76d847c72b4db8ded = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_45c2f5faf873d9345cd37b8ee3ab400e);
#
#
#         var popup_8bd6ce3200f16950fca917c0646b1bad = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6f984f8e76260ad47f2e11c640dac422 = $(`&lt;div id=&quot;html_6f984f8e76260ad47f2e11c640dac422&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_8bd6ce3200f16950fca917c0646b1bad.setContent(html_6f984f8e76260ad47f2e11c640dac422);
#
#
#
#         marker_3a904fa74acfffd76d847c72b4db8ded.bindPopup(popup_8bd6ce3200f16950fca917c0646b1bad)
#         ;
#
#
#
#
#             var marker_0f9e7dc210dd902ad9cffb7fcee60d4e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_45c2f5faf873d9345cd37b8ee3ab400e);
#
#
#         var popup_ce289b1850b3cae644c9c044ef8c85a2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_34fb0b109d64b8f3f78d176243b70184 = $(`&lt;div id=&quot;html_34fb0b109d64b8f3f78d176243b70184&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_ce289b1850b3cae644c9c044ef8c85a2.setContent(html_34fb0b109d64b8f3f78d176243b70184);
#
#
#
#         marker_0f9e7dc210dd902ad9cffb7fcee60d4e.bindPopup(popup_ce289b1850b3cae644c9c044ef8c85a2)
#         ;
#
#
#
#
#             var marker_db87fdd300af2d1237d0587a994fe146 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_45c2f5faf873d9345cd37b8ee3ab400e);
#
#
#         var popup_dfec23618c840ce9003af392ddc49970 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_498b060244587757b7bd1d942d9fdbb2 = $(`&lt;div id=&quot;html_498b060244587757b7bd1d942d9fdbb2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_dfec23618c840ce9003af392ddc49970.setContent(html_498b060244587757b7bd1d942d9fdbb2);
#
#
#
#         marker_db87fdd300af2d1237d0587a994fe146.bindPopup(popup_dfec23618c840ce9003af392ddc49970)
#         ;
#
#
#
#
#             var marker_41e2f34f2c3ef35ab1335221b4913317 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_45c2f5faf873d9345cd37b8ee3ab400e);
#
#
#         var popup_69ecb756d54f8d10aded07ed98ecb6dd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_353247c389df2b7d1c9cc861ed433dee = $(`&lt;div id=&quot;html_353247c389df2b7d1c9cc861ed433dee&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_69ecb756d54f8d10aded07ed98ecb6dd.setContent(html_353247c389df2b7d1c9cc861ed433dee);
#
#
#
#         marker_41e2f34f2c3ef35ab1335221b4913317.bindPopup(popup_69ecb756d54f8d10aded07ed98ecb6dd)
#         ;
#
#
#
#
#             var marker_f6bf5709a63a549df06876ccf165d80a = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_45c2f5faf873d9345cd37b8ee3ab400e);
#
#
#         var popup_889514cc2b24aadf60238a55f83edbc3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5f8af3a1f7bb31330265e32e3bc91d5e = $(`&lt;div id=&quot;html_5f8af3a1f7bb31330265e32e3bc91d5e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_889514cc2b24aadf60238a55f83edbc3.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5a30408db8024efa0c96410c6371b36f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5a30408db8024efa0c96410c6371b36f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5a30408db8024efa0c96410c6371b36f = L.map(
#                 &quot;map_5a30408db8024efa0c96410c6371b36f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e3e03f1068333460c1916feb7a684898 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e3e03f1068333460c1916feb7a684898.addTo(map_5a30408db8024efa0c96410c6371b36f);
#
#
#             var feature_group_eaad7385050fde7a9c65f16a3f7e9a96 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_f83b2103a233f24b668c6c454226eae7 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_eaad7385050fde7a9c65f16a3f7e9a96);
#
#
#         var popup_e14ad7fa0bce61cd2026dd7eba1b18f2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c2ca79dcaa95022bfe4bf5b2e644a4aa = $(`&lt;div id=&quot;html_c2ca79dcaa95022bfe4bf5b2e644a4aa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_e14ad7fa0bce61cd2026dd7eba1b18f2.setContent(html_c2ca79dcaa95022bfe4bf5b2e644a4aa);
#
#
#
#         marker_f83b2103a233f24b668c6c454226eae7.bindPopup(popup_e14ad7fa0bce61cd2026dd7eba1b18f2)
#         ;
#
#
#
#
#             var marker_a74c00f7536619f6ef332803a331da41 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_eaad7385050fde7a9c65f16a3f7e9a96);
#
#
#         var popup_ead1394af1662b3afd191760319a9de8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1a7630fbb7c45482d999b1e129a4c55a = $(`&lt;div id=&quot;html_1a7630fbb7c45482d999b1e129a4c55a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_ead1394af1662b3afd191760319a9de8.setContent(html_1a7630fbb7c45482d999b1e129a4c55a);
#
#
#
#         marker_a74c00f7536619f6ef332803a331da41.bindPopup(popup_ead1394af1662b3afd191760319a9de8)
#         ;
#
#
#
#
#             var marker_1b127f898e80b504cc490c5bf7477ed2 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_eaad7385050fde7a9c65f16a3f7e9a96);
#
#
#         var popup_443a58f47625e052aeede038127473fd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_835ce062a536b9be81cd2457aae9214a = $(`&lt;div id=&quot;html_835ce062a536b9be81cd2457aae9214a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_443a58f47625e052aeede038127473fd.setContent(html_835ce062a536b9be81cd2457aae9214a);
#
#
#
#         marker_1b127f898e80b504cc490c5bf7477ed2.bindPopup(popup_443a58f47625e052aeede038127473fd)
#         ;
#
#
#
#
#             var marker_3ec79cc0596de6f2b354d4c6fa386e40 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_eaad7385050fde7a9c65f16a3f7e9a96);
#
#
#         var popup_44de6cefabf2dabb4839c90bf56576c2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_01a81acd25f072076c0719662dd663b9 = $(`&lt;div id=&quot;html_01a81acd25f072076c0719662dd663b9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_44de6cefabf2dabb4839c90bf56576c2.setContent(html_01a81acd25f072076c0719662dd663b9);
#
#
#
#         marker_3ec79cc0596de6f2b354d4c6fa386e40.bindPopup(popup_44de6cefabf2dabb4839c90bf56576c2)
#         ;
#
#
#
#
#             var marker_92fd4cb5aec9f198669210abd1471196 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_eaad7385050fde7a9c65f16a3f7e9a96);
#
#
#         var popup_619e0ecf4f82eb25dc7eeb41976b1398 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9456b98bedf3d9b85a5acf57dad42ab4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9456b98bedf3d9b85a5acf57dad42ab4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9456b98bedf3d9b85a5acf57dad42ab4 = L.map(
#                 &quot;map_9456b98bedf3d9b85a5acf57dad42ab4&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_885d4b2b23357d3b1e5240eef2a51ee8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_885d4b2b23357d3b1e5240eef2a51ee8.addTo(map_9456b98bedf3d9b85a5acf57dad42ab4);
#
#
#             var feature_group_237609f9e7ca8583c75c7bdbef6237bd = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_237609f9e7ca8583c75c7bdbef6237bd.addTo(map_9456b98bedf3d9b85a5acf57dad42ab4);
#
#
#             var feature_group_sub_group_22b45fd6da1bd17a30809ea1503296c8 = L.featureGroup.subGroup(
#                 feature_group_237609f9e7ca8583c75c7bdbef6237bd
#             );
#
#
#             var marker_229f032812629d99cda75a5eeb231008 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_22b45fd6da1bd17a30809ea1503296c8);
#
#
#         var popup_d8d84d596112cc6f03a4dd91d657d84e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6f57c02891c4d1247e45ce7a9df6a6d0 = $(`&lt;div id=&quot;html_6f57c02891c4d1247e45ce7a9df6a6d0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_d8d84d596112cc6f03a4dd91d657d84e.setContent(html_6f57c02891c4d1247e45ce7a9df6a6d0);
#
#
#
#         marker_229f032812629d99cda75a5eeb231008.bindPopup(popup_d8d84d596112cc6f03a4dd91d657d84e)
#         ;
#
#
#
#
#             var marker_195bcad0278c65943a7b5ab925fe966a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_22b45fd6da1bd17a30809ea1503296c8);
#
#
#         var popup_bdd73332090722287b3e9f0da412ede5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7315c5de5d8366e98955e9868f3e4713 = $(`&lt;div id=&quot;html_7315c5de5d8366e98955e9868f3e4713&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_bdd73332090722287b3e9f0da412ede5.setContent(html_7315c5de5d8366e98955e9868f3e4713);
#
#
#
#         marker_195bcad0278c65943a7b5ab925fe966a.bindPopup(popup_bdd73332090722287b3e9f0da412ede5)
#         ;
#
#
#
#
#             var marker_e6bb3f001066c5ff90d5279667530d8d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_22b45fd6da1bd17a30809ea1503296c8);
#
#
#         var popup_60468bb902d815467da78390c0010f83 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1afbeff61a50debd89599fcae2477567 = $(`&lt;div id=&quot;html_1afbeff61a50debd89599fcae2477567&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_60468bb902d815467da78390c0010f83.setContent(html_1afbeff61a50debd89599fcae2477567);
#
#
#
#         marker_e6bb3f001066c5ff90d5279667530d8d.bindPopup(popup_60468bb902d815467da78390c0010f83)
#         ;
#
#
#
#
#             var marker_73c86558d98dff774f488225e94d0904 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_22b45fd6da1bd17a30809ea1503296c8);
#
#
#         var popup_6d9db1bf3fb0806f00fc6988251354ae = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cc13ddd60c1578ccb8450fe4652515d5 = $(`&lt;div id=&quot;html_cc13ddd60c1578ccb8450fe4652515d5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_6d9db1bf3fb0806f00fc6988251354ae.setContent(html_cc13ddd60c1578ccb8450fe4652515d5);
#
#
#
#         marker_
