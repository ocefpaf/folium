# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_165b27bb77cbd0233db0b3c18e0c6aa6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_165b27bb77cbd0233db0b3c18e0c6aa6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_165b27bb77cbd0233db0b3c18e0c6aa6 = L.map(
#                 &quot;map_165b27bb77cbd0233db0b3c18e0c6aa6&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_581c30eb6fc507cb0142f023c816f112 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_581c30eb6fc507cb0142f023c816f112.addTo(map_165b27bb77cbd0233db0b3c18e0c6aa6);
#
#
#             var marker_32574644c6fbf238d40677bb534e3561 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_165b27bb77cbd0233db0b3c18e0c6aa6);
#
#
#         var popup_0d4438d4c6491e5588343b00dc9d7a30 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0c350877488d948618bd5d78cbb8cf78 = $(`&lt;div id=&quot;html_0c350877488d948618bd5d78cbb8cf78&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_0d4438d4c6491e5588343b00dc9d7a30.setContent(html_0c350877488d948618bd5d78cbb8cf78);
#
#
#
#         marker_32574644c6fbf238d40677bb534e3561.bindPopup(popup_0d4438d4c6491e5588343b00dc9d7a30)
#         ;
#
#
#
#
#             var marker_b0ad18672a80558e80e4b0606e4eb5ae = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_165b27bb77cbd0233db0b3c18e0c6aa6);
#
#
#         var popup_4292ddee3c12b2b9f9a044855693c2ad = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_13ba22adb66db8ed098f283c2a3e676c = $(`&lt;div id=&quot;html_13ba22adb66db8ed098f283c2a3e676c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_4292ddee3c12b2b9f9a044855693c2ad.setContent(html_13ba22adb66db8ed098f283c2a3e676c);
#
#
#
#         marker_b0ad18672a80558e80e4b0606e4eb5ae.bindPopup(popup_4292ddee3c12b2b9f9a044855693c2ad)
#         ;
#
#
#
#
#             var marker_4a662bd670ed85372de43fb5cdfe8ca2 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_165b27bb77cbd0233db0b3c18e0c6aa6);
#
#
#         var popup_80c23fa58199c986f8656fce4304fe97 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_96689f722e9f3e8c3c975ecd55576beb = $(`&lt;div id=&quot;html_96689f722e9f3e8c3c975ecd55576beb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_80c23fa58199c986f8656fce4304fe97.setContent(html_96689f722e9f3e8c3c975ecd55576beb);
#
#
#
#         marker_4a662bd670ed85372de43fb5cdfe8ca2.bindPopup(popup_80c23fa58199c986f8656fce4304fe97)
#         ;
#
#
#
#
#             var marker_1e6b79ad7df42cbe18f84200030ef9d0 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_165b27bb77cbd0233db0b3c18e0c6aa6);
#
#
#         var popup_c05c2e49de81bfe2f95994523e64cdc9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6c8437a912d0b38c681ba4ef902f05de = $(`&lt;div id=&quot;html_6c8437a912d0b38c681ba4ef902f05de&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_c05c2e49de81bfe2f95994523e64cdc9.setContent(html_6c8437a912d0b38c681ba4ef902f05de);
#
#
#
#         marker_1e6b79ad7df42cbe18f84200030ef9d0.bindPopup(popup_c05c2e49de81bfe2f95994523e64cdc9)
#         ;
#
#
#
#
#             var marker_1db63845965a988214b1b20d19618efb = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_165b27bb77cbd0233db0b3c18e0c6aa6);
#
#
#         var popup_6f0bf886ae5315f47ff887d78b81594e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0662cdfcdc98cfb9acd4fd4550e81696 = $(`&lt;div id=&quot;html_0662cdfcdc98cfb9acd4fd4550e81696&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_6f0bf886ae5315f47ff887d78b81594e.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1a178787b1dc450b06284e6402d02edb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1a178787b1dc450b06284e6402d02edb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1a178787b1dc450b06284e6402d02edb = L.map(
#                 &quot;map_1a178787b1dc450b06284e6402d02edb&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_060d67f1bee6ebd6f6c444f0bb059623 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_060d67f1bee6ebd6f6c444f0bb059623.addTo(map_1a178787b1dc450b06284e6402d02edb);
#
#
#             var feature_group_41f0b2d61851fa32dc8b01e2d5595e80 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_50d3454402543130de9d6b9d9a42c361 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_41f0b2d61851fa32dc8b01e2d5595e80);
#
#
#         var popup_51c6589faa05638be2620062cb6cc5e2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c9372b24d2797851170d79442ea1688a = $(`&lt;div id=&quot;html_c9372b24d2797851170d79442ea1688a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_51c6589faa05638be2620062cb6cc5e2.setContent(html_c9372b24d2797851170d79442ea1688a);
#
#
#
#         marker_50d3454402543130de9d6b9d9a42c361.bindPopup(popup_51c6589faa05638be2620062cb6cc5e2)
#         ;
#
#
#
#
#             var marker_529becdb4baa54329dfa96381c8dca03 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_41f0b2d61851fa32dc8b01e2d5595e80);
#
#
#         var popup_c3b66c8b2305050f6490cc5383cbca71 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8af069bc834b9b4e0f5efc6e99acfb92 = $(`&lt;div id=&quot;html_8af069bc834b9b4e0f5efc6e99acfb92&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_c3b66c8b2305050f6490cc5383cbca71.setContent(html_8af069bc834b9b4e0f5efc6e99acfb92);
#
#
#
#         marker_529becdb4baa54329dfa96381c8dca03.bindPopup(popup_c3b66c8b2305050f6490cc5383cbca71)
#         ;
#
#
#
#
#             var marker_2c7d7a471c23284146c62ae507a96708 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_41f0b2d61851fa32dc8b01e2d5595e80);
#
#
#         var popup_52c3ccabb74d3c4bce6007bf454b37dd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7a1d824223ca3255aa0bc0af60dff3b8 = $(`&lt;div id=&quot;html_7a1d824223ca3255aa0bc0af60dff3b8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_52c3ccabb74d3c4bce6007bf454b37dd.setContent(html_7a1d824223ca3255aa0bc0af60dff3b8);
#
#
#
#         marker_2c7d7a471c23284146c62ae507a96708.bindPopup(popup_52c3ccabb74d3c4bce6007bf454b37dd)
#         ;
#
#
#
#
#             var marker_1d280d91e21cd05ef20eb72240484e62 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_41f0b2d61851fa32dc8b01e2d5595e80);
#
#
#         var popup_31aebba19520d742fe117a4e5da15949 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dc8dc4bc23e1d852fda9c028e2fd8bb4 = $(`&lt;div id=&quot;html_dc8dc4bc23e1d852fda9c028e2fd8bb4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_31aebba19520d742fe117a4e5da15949.setContent(html_dc8dc4bc23e1d852fda9c028e2fd8bb4);
#
#
#
#         marker_1d280d91e21cd05ef20eb72240484e62.bindPopup(popup_31aebba19520d742fe117a4e5da15949)
#         ;
#
#
#
#
#             var marker_e36b6eea265c2db9e6d71f1d0d9425e9 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_41f0b2d61851fa32dc8b01e2d5595e80);
#
#
#         var popup_9f47e8861beb43efd59a2a6288860c35 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e9d96447002217c0abf43f3a550d133e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e9d96447002217c0abf43f3a550d133e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e9d96447002217c0abf43f3a550d133e = L.map(
#                 &quot;map_e9d96447002217c0abf43f3a550d133e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c9e4ee55454375a7cf8b05e0bcb84754 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c9e4ee55454375a7cf8b05e0bcb84754.addTo(map_e9d96447002217c0abf43f3a550d133e);
#
#
#             var feature_group_015142320e8c75bfd0ae5eb78785dc3a = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_015142320e8c75bfd0ae5eb78785dc3a.addTo(map_e9d96447002217c0abf43f3a550d133e);
#
#
#             var feature_group_sub_group_50192ff042cfc884e16174643e91f43f = L.featureGroup.subGroup(
#                 feature_group_015142320e8c75bfd0ae5eb78785dc3a
#             );
#
#
#             var marker_217dad6c53522c13593dfc68e2351bed = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_50192ff042cfc884e16174643e91f43f);
#
#
#         var popup_08f6b5adc2a3fcd7bc3fd5e7622a861b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dd4d0c155ad1b0e31426e1cecf923236 = $(`&lt;div id=&quot;html_dd4d0c155ad1b0e31426e1cecf923236&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_08f6b5adc2a3fcd7bc3fd5e7622a861b.setContent(html_dd4d0c155ad1b0e31426e1cecf923236);
#
#
#
#         marker_217dad6c53522c13593dfc68e2351bed.bindPopup(popup_08f6b5adc2a3fcd7bc3fd5e7622a861b)
#         ;
#
#
#
#
#             var marker_338523d7f2d6c612cc41b052f8efc3f8 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_50192ff042cfc884e16174643e91f43f);
#
#
#         var popup_ca5a58729713089b24cfc72cd9f296a2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8edd35d3ef22b79b2996d933a70787d8 = $(`&lt;div id=&quot;html_8edd35d3ef22b79b2996d933a70787d8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_ca5a58729713089b24cfc72cd9f296a2.setContent(html_8edd35d3ef22b79b2996d933a70787d8);
#
#
#
#         marker_338523d7f2d6c612cc41b052f8efc3f8.bindPopup(popup_ca5a58729713089b24cfc72cd9f296a2)
#         ;
#
#
#
#
#             var marker_6e5d0483dd01665c085a8f3bf02945e7 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_50192ff042cfc884e16174643e91f43f);
#
#
#         var popup_d0b05be29771c3ef1fc27e55ea0d679e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ad35ebdefc6505ee632bd28564b17e33 = $(`&lt;div id=&quot;html_ad35ebdefc6505ee632bd28564b17e33&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_d0b05be29771c3ef1fc27e55ea0d679e.setContent(html_ad35ebdefc6505ee632bd28564b17e33);
#
#
#
#         marker_6e5d0483dd01665c085a8f3bf02945e7.bindPopup(popup_d0b05be29771c3ef1fc27e55ea0d679e)
#         ;
#
#
#
#
#             var marker_675c11bd6af49910ed873d9794022df4 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_50192ff042cfc884e16174643e91f43f);
#
#
#         var popup_4dd82b193a5a3c3943e52ab94841f233 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_237e4f4c6d2fd27ca3a8ce197293472e = $(`&lt;div id=&quot;html_237e4f4c6d2fd27ca3a8ce197293472e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_4dd82b193a5a3c3943e52ab94841f233.setContent(html_237e4f4c6d2fd27ca3a8ce197293472e);
#
#
#
#         marker_
