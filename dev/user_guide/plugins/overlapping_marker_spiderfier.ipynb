# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_160088ccadef6d6f8c3eb66577de2814 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_160088ccadef6d6f8c3eb66577de2814&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_160088ccadef6d6f8c3eb66577de2814 = L.map(
#                 &quot;map_160088ccadef6d6f8c3eb66577de2814&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d855555a390ef219201dd34c461fce00 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d855555a390ef219201dd34c461fce00.addTo(map_160088ccadef6d6f8c3eb66577de2814);
#
#
#             var marker_ac03f50b50e0480da26991b2eb801deb = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_160088ccadef6d6f8c3eb66577de2814);
#
#
#         var popup_e5e2eb0e42d4403a909564729f8e61ad = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8ea98f4935adb004af5ba76e8ab18208 = $(`&lt;div id=&quot;html_8ea98f4935adb004af5ba76e8ab18208&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_e5e2eb0e42d4403a909564729f8e61ad.setContent(html_8ea98f4935adb004af5ba76e8ab18208);
#
#
#
#         marker_ac03f50b50e0480da26991b2eb801deb.bindPopup(popup_e5e2eb0e42d4403a909564729f8e61ad)
#         ;
#
#
#
#
#             var marker_1d6417e1d39cdc474c6b5ce2114a1d3d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_160088ccadef6d6f8c3eb66577de2814);
#
#
#         var popup_98b54e18549ef51934697f699c5ce648 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5286384ef428b05aa241f28f6cc99ba2 = $(`&lt;div id=&quot;html_5286384ef428b05aa241f28f6cc99ba2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_98b54e18549ef51934697f699c5ce648.setContent(html_5286384ef428b05aa241f28f6cc99ba2);
#
#
#
#         marker_1d6417e1d39cdc474c6b5ce2114a1d3d.bindPopup(popup_98b54e18549ef51934697f699c5ce648)
#         ;
#
#
#
#
#             var marker_a3b73c4a1df9d202299450c422c73f0f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_160088ccadef6d6f8c3eb66577de2814);
#
#
#         var popup_29a0fd5af49d846daa4c010b6f498979 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_63649f7373bb6e34af06c38821888391 = $(`&lt;div id=&quot;html_63649f7373bb6e34af06c38821888391&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_29a0fd5af49d846daa4c010b6f498979.setContent(html_63649f7373bb6e34af06c38821888391);
#
#
#
#         marker_a3b73c4a1df9d202299450c422c73f0f.bindPopup(popup_29a0fd5af49d846daa4c010b6f498979)
#         ;
#
#
#
#
#             var marker_3781f0880b7b35922fc3f3730ed0dbb0 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_160088ccadef6d6f8c3eb66577de2814);
#
#
#         var popup_8ae0d825cca3f968e19ac35bd9f9f351 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cf94d53e64863089c49469634ec301fe = $(`&lt;div id=&quot;html_cf94d53e64863089c49469634ec301fe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_8ae0d825cca3f968e19ac35bd9f9f351.setContent(html_cf94d53e64863089c49469634ec301fe);
#
#
#
#         marker_3781f0880b7b35922fc3f3730ed0dbb0.bindPopup(popup_8ae0d825cca3f968e19ac35bd9f9f351)
#         ;
#
#
#
#
#             var marker_6faa6a01cba3127bb56fc94a14ca3379 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_160088ccadef6d6f8c3eb66577de2814);
#
#
#         var popup_630cc639f3367d66f1b54ce11aed0e00 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8bef1eb2de4c67dfea6fbd36f31b03cd = $(`&lt;div id=&quot;html_8bef1eb2de4c67dfea6fbd36f31b03cd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_630cc639f3367d66f1b54ce11aed0e00.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_be96bb6dfb3c7bfb45c1c5c0985eedb1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_be96bb6dfb3c7bfb45c1c5c0985eedb1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_be96bb6dfb3c7bfb45c1c5c0985eedb1 = L.map(
#                 &quot;map_be96bb6dfb3c7bfb45c1c5c0985eedb1&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e67c8aed02ec9c1e517983b62765c1b8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e67c8aed02ec9c1e517983b62765c1b8.addTo(map_be96bb6dfb3c7bfb45c1c5c0985eedb1);
#
#
#             var feature_group_ebf43d46264e94f15ca6c272f568aa2b = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_e32354cc11625483f67ae70ca0e303fd = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_ebf43d46264e94f15ca6c272f568aa2b);
#
#
#         var popup_d4937d6dd1443d730edfd8b9fa60dd69 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6213e5818ccf21fcfebd1e53cc689ccb = $(`&lt;div id=&quot;html_6213e5818ccf21fcfebd1e53cc689ccb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_d4937d6dd1443d730edfd8b9fa60dd69.setContent(html_6213e5818ccf21fcfebd1e53cc689ccb);
#
#
#
#         marker_e32354cc11625483f67ae70ca0e303fd.bindPopup(popup_d4937d6dd1443d730edfd8b9fa60dd69)
#         ;
#
#
#
#
#             var marker_609144550345059e2f46f36de4a91931 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_ebf43d46264e94f15ca6c272f568aa2b);
#
#
#         var popup_6db91e4444f388d8a09d9beb4443faf2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_21ddc0e463e9cfe0ee51e7c495f336c0 = $(`&lt;div id=&quot;html_21ddc0e463e9cfe0ee51e7c495f336c0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_6db91e4444f388d8a09d9beb4443faf2.setContent(html_21ddc0e463e9cfe0ee51e7c495f336c0);
#
#
#
#         marker_609144550345059e2f46f36de4a91931.bindPopup(popup_6db91e4444f388d8a09d9beb4443faf2)
#         ;
#
#
#
#
#             var marker_6f880bf0e34228987331329317a41f3b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_ebf43d46264e94f15ca6c272f568aa2b);
#
#
#         var popup_cd5c4d8142f5120659e027ab11086be3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5e7fbd04db707dec3039d82090e42077 = $(`&lt;div id=&quot;html_5e7fbd04db707dec3039d82090e42077&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_cd5c4d8142f5120659e027ab11086be3.setContent(html_5e7fbd04db707dec3039d82090e42077);
#
#
#
#         marker_6f880bf0e34228987331329317a41f3b.bindPopup(popup_cd5c4d8142f5120659e027ab11086be3)
#         ;
#
#
#
#
#             var marker_62e6f8f4d416b2d6e2228502896faac5 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_ebf43d46264e94f15ca6c272f568aa2b);
#
#
#         var popup_a4ca03d61d160abdb378e390e0c5be08 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_467122848716da579dd4c540a7befc1c = $(`&lt;div id=&quot;html_467122848716da579dd4c540a7befc1c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_a4ca03d61d160abdb378e390e0c5be08.setContent(html_467122848716da579dd4c540a7befc1c);
#
#
#
#         marker_62e6f8f4d416b2d6e2228502896faac5.bindPopup(popup_a4ca03d61d160abdb378e390e0c5be08)
#         ;
#
#
#
#
#             var marker_2e0f677d08e3a8feb0196eac6605844e = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_ebf43d46264e94f15ca6c272f568aa2b);
#
#
#         var popup_e8c9aab4a607991396a7e1ce5fc209b6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_455fc1cfb38faabab0e174283aec2718 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_455fc1cfb38faabab0e174283aec2718&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_455fc1cfb38faabab0e174283aec2718 = L.map(
#                 &quot;map_455fc1cfb38faabab0e174283aec2718&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_01a03cd1d5d2fc720cbd46049f5786dc = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_01a03cd1d5d2fc720cbd46049f5786dc.addTo(map_455fc1cfb38faabab0e174283aec2718);
#
#
#             var feature_group_fab4534493d536d308b49cacad82a825 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_fab4534493d536d308b49cacad82a825.addTo(map_455fc1cfb38faabab0e174283aec2718);
#
#
#             var feature_group_sub_group_0e8bc09112d27772b3b0ec378403c0ae = L.featureGroup.subGroup(
#                 feature_group_fab4534493d536d308b49cacad82a825
#             );
#
#
#             var marker_acab7b7479987bbed9370ca23f6b7263 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_0e8bc09112d27772b3b0ec378403c0ae);
#
#
#         var popup_7596764e1ea9d3daf00a478f99d260a4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_db621711cf2a3bdf6702b9f0770515c1 = $(`&lt;div id=&quot;html_db621711cf2a3bdf6702b9f0770515c1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_7596764e1ea9d3daf00a478f99d260a4.setContent(html_db621711cf2a3bdf6702b9f0770515c1);
#
#
#
#         marker_acab7b7479987bbed9370ca23f6b7263.bindPopup(popup_7596764e1ea9d3daf00a478f99d260a4)
#         ;
#
#
#
#
#             var marker_be390a322a9a5a888eb5741bebbf367a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_0e8bc09112d27772b3b0ec378403c0ae);
#
#
#         var popup_895a4308946fbafba05829ada0457c73 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dc663ebee64b1b66483412af189ed405 = $(`&lt;div id=&quot;html_dc663ebee64b1b66483412af189ed405&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_895a4308946fbafba05829ada0457c73.setContent(html_dc663ebee64b1b66483412af189ed405);
#
#
#
#         marker_be390a322a9a5a888eb5741bebbf367a.bindPopup(popup_895a4308946fbafba05829ada0457c73)
#         ;
#
#
#
#
#             var marker_05ece8c66847c299be86573a2f7804d2 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_0e8bc09112d27772b3b0ec378403c0ae);
#
#
#         var popup_ca1443e1c87103640cd371b9c31fb5ef = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6aa33dfaccdb433f6d47baf537a6283d = $(`&lt;div id=&quot;html_6aa33dfaccdb433f6d47baf537a6283d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_ca1443e1c87103640cd371b9c31fb5ef.setContent(html_6aa33dfaccdb433f6d47baf537a6283d);
#
#
#
#         marker_05ece8c66847c299be86573a2f7804d2.bindPopup(popup_ca1443e1c87103640cd371b9c31fb5ef)
#         ;
#
#
#
#
#             var marker_fee3ce22a33f6b9e0200b41f657ff688 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_0e8bc09112d27772b3b0ec378403c0ae);
#
#
#         var popup_45adb1d5df7ac9b54b86d3316df13e58 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_052997ca5858e72a72ffe83d9b4d8800 = $(`&lt;div id=&quot;html_052997ca5858e72a72ffe83d9b4d8800&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_45adb1d5df7ac9b54b86d3316df13e58.setContent(html_052997ca5858e72a72ffe83d9b4d8800);
#
#
#
#         marker_
