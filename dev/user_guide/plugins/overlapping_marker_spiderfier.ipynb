# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7219969c11cdec394dd6e9a8cd7eaf73 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7219969c11cdec394dd6e9a8cd7eaf73&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7219969c11cdec394dd6e9a8cd7eaf73 = L.map(
#                 &quot;map_7219969c11cdec394dd6e9a8cd7eaf73&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7696e12f961e2e3b87fbbf0784e9d6f2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7696e12f961e2e3b87fbbf0784e9d6f2.addTo(map_7219969c11cdec394dd6e9a8cd7eaf73);
#
#
#             var marker_bfc262d70c7dc4744022a043e605b6cd = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_7219969c11cdec394dd6e9a8cd7eaf73);
#
#
#         var popup_1979b05e24781c89e6dfedbd401faa31 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3f54b199b2691c08d7a2b11a9e40eb7f = $(`&lt;div id=&quot;html_3f54b199b2691c08d7a2b11a9e40eb7f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_1979b05e24781c89e6dfedbd401faa31.setContent(html_3f54b199b2691c08d7a2b11a9e40eb7f);
#
#
#
#         marker_bfc262d70c7dc4744022a043e605b6cd.bindPopup(popup_1979b05e24781c89e6dfedbd401faa31)
#         ;
#
#
#
#
#             var marker_8e198abc6fdd83475cff893ed44a32b3 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_7219969c11cdec394dd6e9a8cd7eaf73);
#
#
#         var popup_4ae284dbca37e6cd0c8d326812aef2b5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_42435653d7d6a537c9898c255f4eb5e2 = $(`&lt;div id=&quot;html_42435653d7d6a537c9898c255f4eb5e2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_4ae284dbca37e6cd0c8d326812aef2b5.setContent(html_42435653d7d6a537c9898c255f4eb5e2);
#
#
#
#         marker_8e198abc6fdd83475cff893ed44a32b3.bindPopup(popup_4ae284dbca37e6cd0c8d326812aef2b5)
#         ;
#
#
#
#
#             var marker_38690bb56a76568c5d8b637ae9eeaef1 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_7219969c11cdec394dd6e9a8cd7eaf73);
#
#
#         var popup_e1ef8758aab9ddb5bc409aad25cdbe52 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_30b3814693badfe7bb9da1a110849b1f = $(`&lt;div id=&quot;html_30b3814693badfe7bb9da1a110849b1f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_e1ef8758aab9ddb5bc409aad25cdbe52.setContent(html_30b3814693badfe7bb9da1a110849b1f);
#
#
#
#         marker_38690bb56a76568c5d8b637ae9eeaef1.bindPopup(popup_e1ef8758aab9ddb5bc409aad25cdbe52)
#         ;
#
#
#
#
#             var marker_465ac0402bb172cce6140063a884af08 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_7219969c11cdec394dd6e9a8cd7eaf73);
#
#
#         var popup_5ac335309921e78fa9676b1f50c158bb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_72da9d3363aeea0610379a9ddefa447e = $(`&lt;div id=&quot;html_72da9d3363aeea0610379a9ddefa447e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_5ac335309921e78fa9676b1f50c158bb.setContent(html_72da9d3363aeea0610379a9ddefa447e);
#
#
#
#         marker_465ac0402bb172cce6140063a884af08.bindPopup(popup_5ac335309921e78fa9676b1f50c158bb)
#         ;
#
#
#
#
#             var marker_d2ef3be5001426af1a493caf0d131551 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_7219969c11cdec394dd6e9a8cd7eaf73);
#
#
#         var popup_d6faa055bae390657f4e529529b62625 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_829c86bcc159ca919ef50a1e90d0a9a6 = $(`&lt;div id=&quot;html_829c86bcc159ca919ef50a1e90d0a9a6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_d6faa055bae390657f4e529529b62625.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bd63a450913b5551605c3f719eec0316 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bd63a450913b5551605c3f719eec0316&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bd63a450913b5551605c3f719eec0316 = L.map(
#                 &quot;map_bd63a450913b5551605c3f719eec0316&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3ec53968cee7d7f9d906c78f4cce88b9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3ec53968cee7d7f9d906c78f4cce88b9.addTo(map_bd63a450913b5551605c3f719eec0316);
#
#
#             var feature_group_9b08ddd8e7391d517d8d5f8047830637 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_17f08e63514b01392cd545bc9a5a7788 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_9b08ddd8e7391d517d8d5f8047830637);
#
#
#         var popup_4e686f54758e28c1a0679bced7b5a8bf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9eb1b340ce4811b96364196cc9807278 = $(`&lt;div id=&quot;html_9eb1b340ce4811b96364196cc9807278&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_4e686f54758e28c1a0679bced7b5a8bf.setContent(html_9eb1b340ce4811b96364196cc9807278);
#
#
#
#         marker_17f08e63514b01392cd545bc9a5a7788.bindPopup(popup_4e686f54758e28c1a0679bced7b5a8bf)
#         ;
#
#
#
#
#             var marker_be92af42e5ae692552138c52c09fac07 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_9b08ddd8e7391d517d8d5f8047830637);
#
#
#         var popup_b46f983c4b05c74a49b319d1c8c5f289 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bffa5f85eadd011f6262226e8f6c2176 = $(`&lt;div id=&quot;html_bffa5f85eadd011f6262226e8f6c2176&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_b46f983c4b05c74a49b319d1c8c5f289.setContent(html_bffa5f85eadd011f6262226e8f6c2176);
#
#
#
#         marker_be92af42e5ae692552138c52c09fac07.bindPopup(popup_b46f983c4b05c74a49b319d1c8c5f289)
#         ;
#
#
#
#
#             var marker_1409038fbf1e572a4af1e3f5ce92e5e2 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_9b08ddd8e7391d517d8d5f8047830637);
#
#
#         var popup_ba8035d0de3acdfdf059f36875a884ea = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3f63b2c672b4462ab2370eca835eefc4 = $(`&lt;div id=&quot;html_3f63b2c672b4462ab2370eca835eefc4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_ba8035d0de3acdfdf059f36875a884ea.setContent(html_3f63b2c672b4462ab2370eca835eefc4);
#
#
#
#         marker_1409038fbf1e572a4af1e3f5ce92e5e2.bindPopup(popup_ba8035d0de3acdfdf059f36875a884ea)
#         ;
#
#
#
#
#             var marker_95b0a2d50bf221d0b19397aaafaae348 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_9b08ddd8e7391d517d8d5f8047830637);
#
#
#         var popup_e60f2d7f7c2d7848cdbcd979b5a77c85 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e2ac861e9c2966c85ceba50e2d1ba619 = $(`&lt;div id=&quot;html_e2ac861e9c2966c85ceba50e2d1ba619&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_e60f2d7f7c2d7848cdbcd979b5a77c85.setContent(html_e2ac861e9c2966c85ceba50e2d1ba619);
#
#
#
#         marker_95b0a2d50bf221d0b19397aaafaae348.bindPopup(popup_e60f2d7f7c2d7848cdbcd979b5a77c85)
#         ;
#
#
#
#
#             var marker_319acfa31311cb3c004f267de0cce6ea = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_9b08ddd8e7391d517d8d5f8047830637);
#
#
#         var popup_c319a942587f1a56343a65ed8d6cb309 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cc99c535f0c1383143f4021bae7fbc9f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cc99c535f0c1383143f4021bae7fbc9f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cc99c535f0c1383143f4021bae7fbc9f = L.map(
#                 &quot;map_cc99c535f0c1383143f4021bae7fbc9f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_afb5c2cee572bf6fceb7239455fb6c07 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_afb5c2cee572bf6fceb7239455fb6c07.addTo(map_cc99c535f0c1383143f4021bae7fbc9f);
#
#
#             var feature_group_cbd5017a56a28778064d8148205a72e0 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_cbd5017a56a28778064d8148205a72e0.addTo(map_cc99c535f0c1383143f4021bae7fbc9f);
#
#
#             var feature_group_sub_group_496c2962356a6874576730d26c134e2d = L.featureGroup.subGroup(
#                 feature_group_cbd5017a56a28778064d8148205a72e0
#             );
#
#
#             var marker_437d1799faa75e4c4810cfbb9a40aa9e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_496c2962356a6874576730d26c134e2d);
#
#
#         var popup_62e3b1b1aec67260f04a5bcd8612a88f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d56499808c129f09506710a159ee23be = $(`&lt;div id=&quot;html_d56499808c129f09506710a159ee23be&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_62e3b1b1aec67260f04a5bcd8612a88f.setContent(html_d56499808c129f09506710a159ee23be);
#
#
#
#         marker_437d1799faa75e4c4810cfbb9a40aa9e.bindPopup(popup_62e3b1b1aec67260f04a5bcd8612a88f)
#         ;
#
#
#
#
#             var marker_5596e68add5dce492ef887f8c0035723 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_496c2962356a6874576730d26c134e2d);
#
#
#         var popup_f3cfbe755100b646f8b89300ff02484a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b6d7e31ef87f89f3db2b9cb43803897e = $(`&lt;div id=&quot;html_b6d7e31ef87f89f3db2b9cb43803897e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_f3cfbe755100b646f8b89300ff02484a.setContent(html_b6d7e31ef87f89f3db2b9cb43803897e);
#
#
#
#         marker_5596e68add5dce492ef887f8c0035723.bindPopup(popup_f3cfbe755100b646f8b89300ff02484a)
#         ;
#
#
#
#
#             var marker_f204433f65171343a51f38794d923575 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_496c2962356a6874576730d26c134e2d);
#
#
#         var popup_855c3398161f2ec5544d31b95dbde2cc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f06ca4d284886e8d4f8a4bd035b8e043 = $(`&lt;div id=&quot;html_f06ca4d284886e8d4f8a4bd035b8e043&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_855c3398161f2ec5544d31b95dbde2cc.setContent(html_f06ca4d284886e8d4f8a4bd035b8e043);
#
#
#
#         marker_f204433f65171343a51f38794d923575.bindPopup(popup_855c3398161f2ec5544d31b95dbde2cc)
#         ;
#
#
#
#
#             var marker_56081598dbd618d511d23b042d4344a9 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_496c2962356a6874576730d26c134e2d);
#
#
#         var popup_efa4103324386195de067328adec1f65 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ddb91032b2ab9d625035e7edb176197f = $(`&lt;div id=&quot;html_ddb91032b2ab9d625035e7edb176197f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_efa4103324386195de067328adec1f65.setContent(html_ddb91032b2ab9d625035e7edb176197f);
#
#
#
#         marker_
