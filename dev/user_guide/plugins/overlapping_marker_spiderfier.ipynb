# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6ada17a72d6ef062465170f3011712b9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6ada17a72d6ef062465170f3011712b9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6ada17a72d6ef062465170f3011712b9 = L.map(
#                 &quot;map_6ada17a72d6ef062465170f3011712b9&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_000f93f4e6378cc22d6014c02a5d7394 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_000f93f4e6378cc22d6014c02a5d7394.addTo(map_6ada17a72d6ef062465170f3011712b9);
#
#
#             var marker_d66e3df4c37f5e4c7eb390e05dcca79f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_6ada17a72d6ef062465170f3011712b9);
#
#
#         var popup_f77d5f65f4765031f7191edc1e176bd4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c218de488fdc19d7b3b783b4a2d4dd0d = $(`&lt;div id=&quot;html_c218de488fdc19d7b3b783b4a2d4dd0d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_f77d5f65f4765031f7191edc1e176bd4.setContent(html_c218de488fdc19d7b3b783b4a2d4dd0d);
#
#
#
#         marker_d66e3df4c37f5e4c7eb390e05dcca79f.bindPopup(popup_f77d5f65f4765031f7191edc1e176bd4)
#         ;
#
#
#
#
#             var marker_984bf3569e90d79b4ccabc562356326a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_6ada17a72d6ef062465170f3011712b9);
#
#
#         var popup_d98616640a8fcf1737ffe65fa71ee591 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_65d5b28620ae5427a800ba22a58a2f7f = $(`&lt;div id=&quot;html_65d5b28620ae5427a800ba22a58a2f7f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_d98616640a8fcf1737ffe65fa71ee591.setContent(html_65d5b28620ae5427a800ba22a58a2f7f);
#
#
#
#         marker_984bf3569e90d79b4ccabc562356326a.bindPopup(popup_d98616640a8fcf1737ffe65fa71ee591)
#         ;
#
#
#
#
#             var marker_95124e862e2ee1713450a3576b6153ac = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_6ada17a72d6ef062465170f3011712b9);
#
#
#         var popup_6321d973606492327592cddaad8cc478 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dc1b9ecde318a75def1f26880b0d968d = $(`&lt;div id=&quot;html_dc1b9ecde318a75def1f26880b0d968d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_6321d973606492327592cddaad8cc478.setContent(html_dc1b9ecde318a75def1f26880b0d968d);
#
#
#
#         marker_95124e862e2ee1713450a3576b6153ac.bindPopup(popup_6321d973606492327592cddaad8cc478)
#         ;
#
#
#
#
#             var marker_b2abcbf8b3fab3f94f75e024f00ba167 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_6ada17a72d6ef062465170f3011712b9);
#
#
#         var popup_d0f1b5f48e2b5f09858a9601779b0051 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2b937a20c4dd26697a9514e87685bf68 = $(`&lt;div id=&quot;html_2b937a20c4dd26697a9514e87685bf68&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_d0f1b5f48e2b5f09858a9601779b0051.setContent(html_2b937a20c4dd26697a9514e87685bf68);
#
#
#
#         marker_b2abcbf8b3fab3f94f75e024f00ba167.bindPopup(popup_d0f1b5f48e2b5f09858a9601779b0051)
#         ;
#
#
#
#
#             var marker_08bc66c7cc474e13dcb71f7937ad4392 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_6ada17a72d6ef062465170f3011712b9);
#
#
#         var popup_ce251738ab74144f8907f329904ded44 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ec4dd2769e5b3a1aa94cc40f3b9a8931 = $(`&lt;div id=&quot;html_ec4dd2769e5b3a1aa94cc40f3b9a8931&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_ce251738ab74144f8907f329904ded44.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_edbbebbdad2a85579e062028aa1f46e7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_edbbebbdad2a85579e062028aa1f46e7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_edbbebbdad2a85579e062028aa1f46e7 = L.map(
#                 &quot;map_edbbebbdad2a85579e062028aa1f46e7&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b935ce053b099917f264d55a3ea90868 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b935ce053b099917f264d55a3ea90868.addTo(map_edbbebbdad2a85579e062028aa1f46e7);
#
#
#             var feature_group_972b6d3411da9b2beebf2323c32441b4 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_d73c6007f6aa673a0765249855adb76b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_972b6d3411da9b2beebf2323c32441b4);
#
#
#         var popup_78b8d15feee0d635d66ec5b1d54c9c16 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d6b7db2e41c38e5d8539d5b1efcbf3a0 = $(`&lt;div id=&quot;html_d6b7db2e41c38e5d8539d5b1efcbf3a0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_78b8d15feee0d635d66ec5b1d54c9c16.setContent(html_d6b7db2e41c38e5d8539d5b1efcbf3a0);
#
#
#
#         marker_d73c6007f6aa673a0765249855adb76b.bindPopup(popup_78b8d15feee0d635d66ec5b1d54c9c16)
#         ;
#
#
#
#
#             var marker_b12038af308dcfe259fc4579fda839a6 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_972b6d3411da9b2beebf2323c32441b4);
#
#
#         var popup_15e61da1415ef38ac55a23c0a01c3e98 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bef9c7e18965d04ea0167e2bf1c4cab3 = $(`&lt;div id=&quot;html_bef9c7e18965d04ea0167e2bf1c4cab3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_15e61da1415ef38ac55a23c0a01c3e98.setContent(html_bef9c7e18965d04ea0167e2bf1c4cab3);
#
#
#
#         marker_b12038af308dcfe259fc4579fda839a6.bindPopup(popup_15e61da1415ef38ac55a23c0a01c3e98)
#         ;
#
#
#
#
#             var marker_4a92c1e720f9b8434ae3fac143cffa08 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_972b6d3411da9b2beebf2323c32441b4);
#
#
#         var popup_6e3cc678ff243b26ff0a455e6c61e386 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_30738615eba8ddd648f74fe1ac968636 = $(`&lt;div id=&quot;html_30738615eba8ddd648f74fe1ac968636&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_6e3cc678ff243b26ff0a455e6c61e386.setContent(html_30738615eba8ddd648f74fe1ac968636);
#
#
#
#         marker_4a92c1e720f9b8434ae3fac143cffa08.bindPopup(popup_6e3cc678ff243b26ff0a455e6c61e386)
#         ;
#
#
#
#
#             var marker_a9698ee326451da414145277b006964a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_972b6d3411da9b2beebf2323c32441b4);
#
#
#         var popup_49b0f3843eca3cd0b14366f1e74e5e79 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_975d3ad77d384c2916363d97617e7e1b = $(`&lt;div id=&quot;html_975d3ad77d384c2916363d97617e7e1b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_49b0f3843eca3cd0b14366f1e74e5e79.setContent(html_975d3ad77d384c2916363d97617e7e1b);
#
#
#
#         marker_a9698ee326451da414145277b006964a.bindPopup(popup_49b0f3843eca3cd0b14366f1e74e5e79)
#         ;
#
#
#
#
#             var marker_f900db07cc61b032da505725b9c61ac4 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_972b6d3411da9b2beebf2323c32441b4);
#
#
#         var popup_5310f7f031dad7861cd1638c930678f7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bd3972d490220298b9aad1dd8ff1bcd4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bd3972d490220298b9aad1dd8ff1bcd4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bd3972d490220298b9aad1dd8ff1bcd4 = L.map(
#                 &quot;map_bd3972d490220298b9aad1dd8ff1bcd4&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e1ec8350a3c8699494769a060f4a3518 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e1ec8350a3c8699494769a060f4a3518.addTo(map_bd3972d490220298b9aad1dd8ff1bcd4);
#
#
#             var feature_group_3ab73e6a5964a3479c2cd9d3e989eeab = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_3ab73e6a5964a3479c2cd9d3e989eeab.addTo(map_bd3972d490220298b9aad1dd8ff1bcd4);
#
#
#             var feature_group_sub_group_95d2f723c914f7befc84dacc16f825a4 = L.featureGroup.subGroup(
#                 feature_group_3ab73e6a5964a3479c2cd9d3e989eeab
#             );
#
#
#             var marker_d72acee3c79cc217c0865d98afe59b04 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_95d2f723c914f7befc84dacc16f825a4);
#
#
#         var popup_f5aeb0ed7ee8496941cea3759f7b5c3f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_476a75a1f109e068352035d140ee9297 = $(`&lt;div id=&quot;html_476a75a1f109e068352035d140ee9297&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_f5aeb0ed7ee8496941cea3759f7b5c3f.setContent(html_476a75a1f109e068352035d140ee9297);
#
#
#
#         marker_d72acee3c79cc217c0865d98afe59b04.bindPopup(popup_f5aeb0ed7ee8496941cea3759f7b5c3f)
#         ;
#
#
#
#
#             var marker_e4df3f0233f05f0a23813c18c7c4762c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_95d2f723c914f7befc84dacc16f825a4);
#
#
#         var popup_7f5574c276640a0120ce15b0f53434a7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_683a18068e9a30ea36c87ae2bb1ca7f9 = $(`&lt;div id=&quot;html_683a18068e9a30ea36c87ae2bb1ca7f9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_7f5574c276640a0120ce15b0f53434a7.setContent(html_683a18068e9a30ea36c87ae2bb1ca7f9);
#
#
#
#         marker_e4df3f0233f05f0a23813c18c7c4762c.bindPopup(popup_7f5574c276640a0120ce15b0f53434a7)
#         ;
#
#
#
#
#             var marker_4da7e039688fa145ae286957566e2b91 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_95d2f723c914f7befc84dacc16f825a4);
#
#
#         var popup_a87cac2d9fe85f3bbde3651fdc1664ac = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_761437544f8f0e4189c78bd44a800926 = $(`&lt;div id=&quot;html_761437544f8f0e4189c78bd44a800926&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_a87cac2d9fe85f3bbde3651fdc1664ac.setContent(html_761437544f8f0e4189c78bd44a800926);
#
#
#
#         marker_4da7e039688fa145ae286957566e2b91.bindPopup(popup_a87cac2d9fe85f3bbde3651fdc1664ac)
#         ;
#
#
#
#
#             var marker_d8d4a91d2768b1f26ff68c2cbd13e4b7 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_95d2f723c914f7befc84dacc16f825a4);
#
#
#         var popup_00bee7cdde11d3f8703034f1ae20f088 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4044127d730c3d7ce69f684d5a4c6b28 = $(`&lt;div id=&quot;html_4044127d730c3d7ce69f684d5a4c6b28&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_00bee7cdde11d3f8703034f1ae20f088.setContent(html_4044127d730c3d7ce69f684d5a4c6b28);
#
#
#
#         marker_
