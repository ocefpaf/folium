# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8be15977a626f7a98d8c125405b925fc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8be15977a626f7a98d8c125405b925fc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8be15977a626f7a98d8c125405b925fc = L.map(
#                 &quot;map_8be15977a626f7a98d8c125405b925fc&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9755d93f65ea0a1edc7a9569975ffe97 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9755d93f65ea0a1edc7a9569975ffe97.addTo(map_8be15977a626f7a98d8c125405b925fc);
#
#
#             var marker_a5315d328e47841cb33624bb035899c3 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_8be15977a626f7a98d8c125405b925fc);
#
#
#         var popup_d23591c30bd98b1044fd1827a809c88b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e0e29305f34a522927966cc6ad0ea254 = $(`&lt;div id=&quot;html_e0e29305f34a522927966cc6ad0ea254&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_d23591c30bd98b1044fd1827a809c88b.setContent(html_e0e29305f34a522927966cc6ad0ea254);
#
#
#
#         marker_a5315d328e47841cb33624bb035899c3.bindPopup(popup_d23591c30bd98b1044fd1827a809c88b)
#         ;
#
#
#
#
#             var marker_6d596ac0c9c8153b4027960997bb68c0 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_8be15977a626f7a98d8c125405b925fc);
#
#
#         var popup_12217dfbbb5588c0168834aeb3720b95 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a8d4361613c371fc220ad6656d5f0917 = $(`&lt;div id=&quot;html_a8d4361613c371fc220ad6656d5f0917&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_12217dfbbb5588c0168834aeb3720b95.setContent(html_a8d4361613c371fc220ad6656d5f0917);
#
#
#
#         marker_6d596ac0c9c8153b4027960997bb68c0.bindPopup(popup_12217dfbbb5588c0168834aeb3720b95)
#         ;
#
#
#
#
#             var marker_aabe8d10a31a84155e6ffb047d0d0ee0 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_8be15977a626f7a98d8c125405b925fc);
#
#
#         var popup_43f2cdedb1421051aa136a385c3a0e3d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a6e6c67ffb2c0530e3335dc175c2bc47 = $(`&lt;div id=&quot;html_a6e6c67ffb2c0530e3335dc175c2bc47&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_43f2cdedb1421051aa136a385c3a0e3d.setContent(html_a6e6c67ffb2c0530e3335dc175c2bc47);
#
#
#
#         marker_aabe8d10a31a84155e6ffb047d0d0ee0.bindPopup(popup_43f2cdedb1421051aa136a385c3a0e3d)
#         ;
#
#
#
#
#             var marker_db344b5402401020a406628fed935fc1 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_8be15977a626f7a98d8c125405b925fc);
#
#
#         var popup_949899ec47dc94716a498c45c7b57215 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_65457571a4cbefb8fd56c3faebb480e1 = $(`&lt;div id=&quot;html_65457571a4cbefb8fd56c3faebb480e1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_949899ec47dc94716a498c45c7b57215.setContent(html_65457571a4cbefb8fd56c3faebb480e1);
#
#
#
#         marker_db344b5402401020a406628fed935fc1.bindPopup(popup_949899ec47dc94716a498c45c7b57215)
#         ;
#
#
#
#
#             var marker_44861cb85fae5245eb872bf7cd8deaeb = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_8be15977a626f7a98d8c125405b925fc);
#
#
#         var popup_65a1bb21e3c36c693623aac6ec630387 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_72ae166beaec939b6077b466ca6b6990 = $(`&lt;div id=&quot;html_72ae166beaec939b6077b466ca6b6990&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_65a1bb21e3c36c693623aac6ec630387.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_10bf34b9cc6515bb38673552a969c3f2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_10bf34b9cc6515bb38673552a969c3f2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_10bf34b9cc6515bb38673552a969c3f2 = L.map(
#                 &quot;map_10bf34b9cc6515bb38673552a969c3f2&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_397cd021b759df6f6797d3777541c49b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_397cd021b759df6f6797d3777541c49b.addTo(map_10bf34b9cc6515bb38673552a969c3f2);
#
#
#             var feature_group_a0862ad3960b34d7db27becb607d7989 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_09a114ca622222d8973b35ea6c95924f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_a0862ad3960b34d7db27becb607d7989);
#
#
#         var popup_889239443e28b3f7a24338be01ca60ec = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f26c06ec506a267ca583f9772985741a = $(`&lt;div id=&quot;html_f26c06ec506a267ca583f9772985741a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_889239443e28b3f7a24338be01ca60ec.setContent(html_f26c06ec506a267ca583f9772985741a);
#
#
#
#         marker_09a114ca622222d8973b35ea6c95924f.bindPopup(popup_889239443e28b3f7a24338be01ca60ec)
#         ;
#
#
#
#
#             var marker_ce105c57cf228d83acc72bd1dc6ccd0e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_a0862ad3960b34d7db27becb607d7989);
#
#
#         var popup_d60758523bb8b6e19e3b2de989496946 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fda09482e31b5b114a5407243e0b7591 = $(`&lt;div id=&quot;html_fda09482e31b5b114a5407243e0b7591&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_d60758523bb8b6e19e3b2de989496946.setContent(html_fda09482e31b5b114a5407243e0b7591);
#
#
#
#         marker_ce105c57cf228d83acc72bd1dc6ccd0e.bindPopup(popup_d60758523bb8b6e19e3b2de989496946)
#         ;
#
#
#
#
#             var marker_73fa5fc7c28689bdc66863f9ec255384 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_a0862ad3960b34d7db27becb607d7989);
#
#
#         var popup_25594e8dc773ad27fa34613395871a3d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8b31d7aa1f1fcdf63c9191c14cb57be8 = $(`&lt;div id=&quot;html_8b31d7aa1f1fcdf63c9191c14cb57be8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_25594e8dc773ad27fa34613395871a3d.setContent(html_8b31d7aa1f1fcdf63c9191c14cb57be8);
#
#
#
#         marker_73fa5fc7c28689bdc66863f9ec255384.bindPopup(popup_25594e8dc773ad27fa34613395871a3d)
#         ;
#
#
#
#
#             var marker_0025be8bfa2bd0a304b11a14ed49d483 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_a0862ad3960b34d7db27becb607d7989);
#
#
#         var popup_ee6dc4542971a123b20187386c0ddf51 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_87dca96b4f070550d010db7b214d1c3d = $(`&lt;div id=&quot;html_87dca96b4f070550d010db7b214d1c3d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_ee6dc4542971a123b20187386c0ddf51.setContent(html_87dca96b4f070550d010db7b214d1c3d);
#
#
#
#         marker_0025be8bfa2bd0a304b11a14ed49d483.bindPopup(popup_ee6dc4542971a123b20187386c0ddf51)
#         ;
#
#
#
#
#             var marker_34a1985e4c0921cc8e24f486ae9f171a = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_a0862ad3960b34d7db27becb607d7989);
#
#
#         var popup_44d4491489f01c80127ef98744c34f1e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b71483a29cbe0d26d1fb5e49adf8edec {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b71483a29cbe0d26d1fb5e49adf8edec&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b71483a29cbe0d26d1fb5e49adf8edec = L.map(
#                 &quot;map_b71483a29cbe0d26d1fb5e49adf8edec&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_75bb089027f6503d3023487e60d9f6d5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_75bb089027f6503d3023487e60d9f6d5.addTo(map_b71483a29cbe0d26d1fb5e49adf8edec);
#
#
#             var feature_group_9995d350d734908c5abb5b3eeca947c1 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_9995d350d734908c5abb5b3eeca947c1.addTo(map_b71483a29cbe0d26d1fb5e49adf8edec);
#
#
#             var feature_group_sub_group_9a6e42b47722cb20d53617684d481603 = L.featureGroup.subGroup(
#                 feature_group_9995d350d734908c5abb5b3eeca947c1
#             );
#
#
#             var marker_a578d738bdaed568832e62f928dec8ef = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_9a6e42b47722cb20d53617684d481603);
#
#
#         var popup_fd8e2a7ffdf50df3cf840090424404e8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e075fcb5a072bc8a7560cd6c85bdfd92 = $(`&lt;div id=&quot;html_e075fcb5a072bc8a7560cd6c85bdfd92&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_fd8e2a7ffdf50df3cf840090424404e8.setContent(html_e075fcb5a072bc8a7560cd6c85bdfd92);
#
#
#
#         marker_a578d738bdaed568832e62f928dec8ef.bindPopup(popup_fd8e2a7ffdf50df3cf840090424404e8)
#         ;
#
#
#
#
#             var marker_215e46d7e05dadebdef1477ef2a31de8 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_9a6e42b47722cb20d53617684d481603);
#
#
#         var popup_864d13542f22c9309527654dbd326078 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a3f49b1e0c7310d99fa2b7ac4a09602b = $(`&lt;div id=&quot;html_a3f49b1e0c7310d99fa2b7ac4a09602b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_864d13542f22c9309527654dbd326078.setContent(html_a3f49b1e0c7310d99fa2b7ac4a09602b);
#
#
#
#         marker_215e46d7e05dadebdef1477ef2a31de8.bindPopup(popup_864d13542f22c9309527654dbd326078)
#         ;
#
#
#
#
#             var marker_02adbfdd31048b0f799f3dab2e8f76f9 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_9a6e42b47722cb20d53617684d481603);
#
#
#         var popup_2507d6825853a0396fb7d6a809f7b1de = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_34d31db63690ce5048f27b8d6c328b2b = $(`&lt;div id=&quot;html_34d31db63690ce5048f27b8d6c328b2b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_2507d6825853a0396fb7d6a809f7b1de.setContent(html_34d31db63690ce5048f27b8d6c328b2b);
#
#
#
#         marker_02adbfdd31048b0f799f3dab2e8f76f9.bindPopup(popup_2507d6825853a0396fb7d6a809f7b1de)
#         ;
#
#
#
#
#             var marker_3f3b47339a54e6a26aad956f1411472e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_9a6e42b47722cb20d53617684d481603);
#
#
#         var popup_24f8dcfa64c6eb2e46e63ba93dbe817d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dda57be12f2df375627aa1243434a190 = $(`&lt;div id=&quot;html_dda57be12f2df375627aa1243434a190&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_24f8dcfa64c6eb2e46e63ba93dbe817d.setContent(html_dda57be12f2df375627aa1243434a190);
#
#
#
#         marker_
