# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d098ba1deefb6f15ef11e9c4671a670d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d098ba1deefb6f15ef11e9c4671a670d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d098ba1deefb6f15ef11e9c4671a670d = L.map(
#                 &quot;map_d098ba1deefb6f15ef11e9c4671a670d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e216367c93098bab128e3d2ea4478481 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e216367c93098bab128e3d2ea4478481.addTo(map_d098ba1deefb6f15ef11e9c4671a670d);
#
#
#             var marker_f6cfe7af97b71ecb89dc99016b38658d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_d098ba1deefb6f15ef11e9c4671a670d);
#
#
#         var popup_c27f6d9a90a075e4b53f0e61b4baf8b1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3d6409ddbd14dc3d70c4c0cedf54b2ef = $(`&lt;div id=&quot;html_3d6409ddbd14dc3d70c4c0cedf54b2ef&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_c27f6d9a90a075e4b53f0e61b4baf8b1.setContent(html_3d6409ddbd14dc3d70c4c0cedf54b2ef);
#
#
#
#         marker_f6cfe7af97b71ecb89dc99016b38658d.bindPopup(popup_c27f6d9a90a075e4b53f0e61b4baf8b1)
#         ;
#
#
#
#
#             var marker_17297f8e88c4fcef8ce08c6bf92da642 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_d098ba1deefb6f15ef11e9c4671a670d);
#
#
#         var popup_5d7e7caccdb74b8ca9c46ea3b4ae55c6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_29e31466c3f2606bb2137ea665d07c19 = $(`&lt;div id=&quot;html_29e31466c3f2606bb2137ea665d07c19&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_5d7e7caccdb74b8ca9c46ea3b4ae55c6.setContent(html_29e31466c3f2606bb2137ea665d07c19);
#
#
#
#         marker_17297f8e88c4fcef8ce08c6bf92da642.bindPopup(popup_5d7e7caccdb74b8ca9c46ea3b4ae55c6)
#         ;
#
#
#
#
#             var marker_e1ca1ff64850841fb9175f6bdd0e0d22 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_d098ba1deefb6f15ef11e9c4671a670d);
#
#
#         var popup_5dcd5fb25d7bdbc28b32cd41baa62d8c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1783ad05bb702ab0e9a73a2c29924414 = $(`&lt;div id=&quot;html_1783ad05bb702ab0e9a73a2c29924414&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_5dcd5fb25d7bdbc28b32cd41baa62d8c.setContent(html_1783ad05bb702ab0e9a73a2c29924414);
#
#
#
#         marker_e1ca1ff64850841fb9175f6bdd0e0d22.bindPopup(popup_5dcd5fb25d7bdbc28b32cd41baa62d8c)
#         ;
#
#
#
#
#             var marker_b769cec51027bbeea7de0434021fb030 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_d098ba1deefb6f15ef11e9c4671a670d);
#
#
#         var popup_dd8c04b20732567ecc4eca642492c6ff = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_229df1206089b05815026207238e026f = $(`&lt;div id=&quot;html_229df1206089b05815026207238e026f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_dd8c04b20732567ecc4eca642492c6ff.setContent(html_229df1206089b05815026207238e026f);
#
#
#
#         marker_b769cec51027bbeea7de0434021fb030.bindPopup(popup_dd8c04b20732567ecc4eca642492c6ff)
#         ;
#
#
#
#
#             var marker_33258e41286216fc17c9fe126a03920b = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_d098ba1deefb6f15ef11e9c4671a670d);
#
#
#         var popup_6cd5500be7580100adc6a36c56393b7e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6d43033d01dc578e563e8ad8db15b6c2 = $(`&lt;div id=&quot;html_6d43033d01dc578e563e8ad8db15b6c2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_6cd5500be7580100adc6a36c56393b7e.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7585ed936cf6f94c71e0b4a96f37199b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7585ed936cf6f94c71e0b4a96f37199b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7585ed936cf6f94c71e0b4a96f37199b = L.map(
#                 &quot;map_7585ed936cf6f94c71e0b4a96f37199b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8b6ae7da7ef613ccfc896f89af248ef0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8b6ae7da7ef613ccfc896f89af248ef0.addTo(map_7585ed936cf6f94c71e0b4a96f37199b);
#
#
#             var feature_group_f9da1bd50b8f4d97e487907ecb6c5793 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_7ce21d1a3bc1154ecd7c5522361c4ff2 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_f9da1bd50b8f4d97e487907ecb6c5793);
#
#
#         var popup_57e19927406669f6b40c330712a7191b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_264b43e3f32e0632d97bf0ff10f0ca99 = $(`&lt;div id=&quot;html_264b43e3f32e0632d97bf0ff10f0ca99&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_57e19927406669f6b40c330712a7191b.setContent(html_264b43e3f32e0632d97bf0ff10f0ca99);
#
#
#
#         marker_7ce21d1a3bc1154ecd7c5522361c4ff2.bindPopup(popup_57e19927406669f6b40c330712a7191b)
#         ;
#
#
#
#
#             var marker_0500331e98f28b895131e4090a843d81 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_f9da1bd50b8f4d97e487907ecb6c5793);
#
#
#         var popup_b91854722a3c2de93a3c5904bb84c2e5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_88f507c1dc634b2cdf41f98d7870c638 = $(`&lt;div id=&quot;html_88f507c1dc634b2cdf41f98d7870c638&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_b91854722a3c2de93a3c5904bb84c2e5.setContent(html_88f507c1dc634b2cdf41f98d7870c638);
#
#
#
#         marker_0500331e98f28b895131e4090a843d81.bindPopup(popup_b91854722a3c2de93a3c5904bb84c2e5)
#         ;
#
#
#
#
#             var marker_f15dba55e2c953f1e13605b8608579f4 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_f9da1bd50b8f4d97e487907ecb6c5793);
#
#
#         var popup_5c03dd23828a87f2f8e07c748dbc9ca4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_221e30a59f3e84dab3dcdc3b0446ee50 = $(`&lt;div id=&quot;html_221e30a59f3e84dab3dcdc3b0446ee50&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_5c03dd23828a87f2f8e07c748dbc9ca4.setContent(html_221e30a59f3e84dab3dcdc3b0446ee50);
#
#
#
#         marker_f15dba55e2c953f1e13605b8608579f4.bindPopup(popup_5c03dd23828a87f2f8e07c748dbc9ca4)
#         ;
#
#
#
#
#             var marker_661224574590be911384953ddd6a123f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_f9da1bd50b8f4d97e487907ecb6c5793);
#
#
#         var popup_53bac1e3dd0f74ac5a7ae7aea61bb0c3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_88d243ce5b689b3abad9afca23fbfb5d = $(`&lt;div id=&quot;html_88d243ce5b689b3abad9afca23fbfb5d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_53bac1e3dd0f74ac5a7ae7aea61bb0c3.setContent(html_88d243ce5b689b3abad9afca23fbfb5d);
#
#
#
#         marker_661224574590be911384953ddd6a123f.bindPopup(popup_53bac1e3dd0f74ac5a7ae7aea61bb0c3)
#         ;
#
#
#
#
#             var marker_a1fad8b06bdd8f3d8ad8523e49a65a65 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_f9da1bd50b8f4d97e487907ecb6c5793);
#
#
#         var popup_57536397ab87ee4b5ee8b05861dfafc6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9bbd4746705793e6abdc0121b9f386e8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9bbd4746705793e6abdc0121b9f386e8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9bbd4746705793e6abdc0121b9f386e8 = L.map(
#                 &quot;map_9bbd4746705793e6abdc0121b9f386e8&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_de8df3ccd886ef8c60055ebca0b4ff7c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_de8df3ccd886ef8c60055ebca0b4ff7c.addTo(map_9bbd4746705793e6abdc0121b9f386e8);
#
#
#             var feature_group_927fbaf9f892eeb1f85ebe98e3d9695a = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_927fbaf9f892eeb1f85ebe98e3d9695a.addTo(map_9bbd4746705793e6abdc0121b9f386e8);
#
#
#             var feature_group_sub_group_9f00a76fadfdfddd99583f111b8a3a8a = L.featureGroup.subGroup(
#                 feature_group_927fbaf9f892eeb1f85ebe98e3d9695a
#             );
#
#
#             var marker_6473dfa87401caf87080bc6e08459013 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_9f00a76fadfdfddd99583f111b8a3a8a);
#
#
#         var popup_affd97e57c99110ad7a76eccb6a6b134 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c83f5c8687e7b6af77ec7f6b8ea1c1ac = $(`&lt;div id=&quot;html_c83f5c8687e7b6af77ec7f6b8ea1c1ac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_affd97e57c99110ad7a76eccb6a6b134.setContent(html_c83f5c8687e7b6af77ec7f6b8ea1c1ac);
#
#
#
#         marker_6473dfa87401caf87080bc6e08459013.bindPopup(popup_affd97e57c99110ad7a76eccb6a6b134)
#         ;
#
#
#
#
#             var marker_b0eaf025cfc5ef5a244500fb2b399999 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_9f00a76fadfdfddd99583f111b8a3a8a);
#
#
#         var popup_9d355b4060e871b81a667d8b504e1681 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9b46efc4a2d9de0949456b76119333f8 = $(`&lt;div id=&quot;html_9b46efc4a2d9de0949456b76119333f8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_9d355b4060e871b81a667d8b504e1681.setContent(html_9b46efc4a2d9de0949456b76119333f8);
#
#
#
#         marker_b0eaf025cfc5ef5a244500fb2b399999.bindPopup(popup_9d355b4060e871b81a667d8b504e1681)
#         ;
#
#
#
#
#             var marker_b8f48fc327ef954a8f1377347aecd0f3 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_9f00a76fadfdfddd99583f111b8a3a8a);
#
#
#         var popup_fee3f47418cf035d61dac1b78b722da8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_745d78c4c235add628f07d60cfd237b7 = $(`&lt;div id=&quot;html_745d78c4c235add628f07d60cfd237b7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_fee3f47418cf035d61dac1b78b722da8.setContent(html_745d78c4c235add628f07d60cfd237b7);
#
#
#
#         marker_b8f48fc327ef954a8f1377347aecd0f3.bindPopup(popup_fee3f47418cf035d61dac1b78b722da8)
#         ;
#
#
#
#
#             var marker_d8b1815ddc8ae56e1bacc171392c6324 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_9f00a76fadfdfddd99583f111b8a3a8a);
#
#
#         var popup_7926fcd3991d0cdfd2adc8871c177f87 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8251181496ae9464e601621e9c25e8c4 = $(`&lt;div id=&quot;html_8251181496ae9464e601621e9c25e8c4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_7926fcd3991d0cdfd2adc8871c177f87.setContent(html_8251181496ae9464e601621e9c25e8c4);
#
#
#
#         marker_
