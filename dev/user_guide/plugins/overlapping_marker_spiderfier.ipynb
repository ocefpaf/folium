# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4b5524cf59d52a6846a1d2a83270cbfa {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4b5524cf59d52a6846a1d2a83270cbfa&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4b5524cf59d52a6846a1d2a83270cbfa = L.map(
#                 &quot;map_4b5524cf59d52a6846a1d2a83270cbfa&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9c84ad6c31b162e763e6c124b77d0b61 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9c84ad6c31b162e763e6c124b77d0b61.addTo(map_4b5524cf59d52a6846a1d2a83270cbfa);
#
#
#             var marker_c9e7b42ff76d381a1cce8a87b4680481 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_4b5524cf59d52a6846a1d2a83270cbfa);
#
#
#         var popup_00f006da101737705268286cd9375b7e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3c2da64be2b221d70117a6635fe15e0d = $(`&lt;div id=&quot;html_3c2da64be2b221d70117a6635fe15e0d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_00f006da101737705268286cd9375b7e.setContent(html_3c2da64be2b221d70117a6635fe15e0d);
#
#
#
#         marker_c9e7b42ff76d381a1cce8a87b4680481.bindPopup(popup_00f006da101737705268286cd9375b7e)
#         ;
#
#
#
#
#             var marker_0c0fb6c4fd55caa995eaa0abbcb03f0e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_4b5524cf59d52a6846a1d2a83270cbfa);
#
#
#         var popup_ed1a68b95124151275cee0f97424b9e7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ada9e48657be5fe18503c4c7ee55fd92 = $(`&lt;div id=&quot;html_ada9e48657be5fe18503c4c7ee55fd92&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_ed1a68b95124151275cee0f97424b9e7.setContent(html_ada9e48657be5fe18503c4c7ee55fd92);
#
#
#
#         marker_0c0fb6c4fd55caa995eaa0abbcb03f0e.bindPopup(popup_ed1a68b95124151275cee0f97424b9e7)
#         ;
#
#
#
#
#             var marker_89a1d33525cb8f07a01e5eb294bf60ae = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_4b5524cf59d52a6846a1d2a83270cbfa);
#
#
#         var popup_1ea039e4a8677bdc1795d26d8e7641cd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f314ffcefc95b4e4731bbc2cbbc39f95 = $(`&lt;div id=&quot;html_f314ffcefc95b4e4731bbc2cbbc39f95&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_1ea039e4a8677bdc1795d26d8e7641cd.setContent(html_f314ffcefc95b4e4731bbc2cbbc39f95);
#
#
#
#         marker_89a1d33525cb8f07a01e5eb294bf60ae.bindPopup(popup_1ea039e4a8677bdc1795d26d8e7641cd)
#         ;
#
#
#
#
#             var marker_8ccc95ef61a31300e6847cbc20fd26e2 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_4b5524cf59d52a6846a1d2a83270cbfa);
#
#
#         var popup_2e8e942be9251608036893ba493b7932 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a9113e5e4997647ac85991a69f753d58 = $(`&lt;div id=&quot;html_a9113e5e4997647ac85991a69f753d58&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_2e8e942be9251608036893ba493b7932.setContent(html_a9113e5e4997647ac85991a69f753d58);
#
#
#
#         marker_8ccc95ef61a31300e6847cbc20fd26e2.bindPopup(popup_2e8e942be9251608036893ba493b7932)
#         ;
#
#
#
#
#             var marker_54110ec23e8e8aeba141b50f9eec0d4c = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_4b5524cf59d52a6846a1d2a83270cbfa);
#
#
#         var popup_d1ea8c1bfad151ed9345b10acc085ac9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_88259da34199cd34c3ee6aa46d675f3e = $(`&lt;div id=&quot;html_88259da34199cd34c3ee6aa46d675f3e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_d1ea8c1bfad151ed9345b10acc085ac9.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_61562309b16ec294f414e899abde89dd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_61562309b16ec294f414e899abde89dd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_61562309b16ec294f414e899abde89dd = L.map(
#                 &quot;map_61562309b16ec294f414e899abde89dd&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e683913792a411c05ade38f7aa7636cf = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e683913792a411c05ade38f7aa7636cf.addTo(map_61562309b16ec294f414e899abde89dd);
#
#
#             var feature_group_f2a755cdf1b364a34dda6b4088c8d1ac = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_7e548decd79d8febff6aca906d0d480f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_f2a755cdf1b364a34dda6b4088c8d1ac);
#
#
#         var popup_fc565025677ad5bf12fa4e9717139213 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_36ebf0664bda5dd74beb7a888afb3e8e = $(`&lt;div id=&quot;html_36ebf0664bda5dd74beb7a888afb3e8e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_fc565025677ad5bf12fa4e9717139213.setContent(html_36ebf0664bda5dd74beb7a888afb3e8e);
#
#
#
#         marker_7e548decd79d8febff6aca906d0d480f.bindPopup(popup_fc565025677ad5bf12fa4e9717139213)
#         ;
#
#
#
#
#             var marker_44347a90e6d94090bc72af9969aaa331 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_f2a755cdf1b364a34dda6b4088c8d1ac);
#
#
#         var popup_43e52d46a41d4c4304a39ba444839c21 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a3ccbcf3e17d1d799cd0649ad23135cf = $(`&lt;div id=&quot;html_a3ccbcf3e17d1d799cd0649ad23135cf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_43e52d46a41d4c4304a39ba444839c21.setContent(html_a3ccbcf3e17d1d799cd0649ad23135cf);
#
#
#
#         marker_44347a90e6d94090bc72af9969aaa331.bindPopup(popup_43e52d46a41d4c4304a39ba444839c21)
#         ;
#
#
#
#
#             var marker_1fe68b0e8cfa7979de0b54a92408cfa5 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_f2a755cdf1b364a34dda6b4088c8d1ac);
#
#
#         var popup_e06df95d0f982bae71aeed7109e65661 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ff97a9cbc89632c218664b413adce11f = $(`&lt;div id=&quot;html_ff97a9cbc89632c218664b413adce11f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_e06df95d0f982bae71aeed7109e65661.setContent(html_ff97a9cbc89632c218664b413adce11f);
#
#
#
#         marker_1fe68b0e8cfa7979de0b54a92408cfa5.bindPopup(popup_e06df95d0f982bae71aeed7109e65661)
#         ;
#
#
#
#
#             var marker_2cb37620d6fe05eb5b7628ae61806995 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_f2a755cdf1b364a34dda6b4088c8d1ac);
#
#
#         var popup_ee69cf39302057359346bf2ce7f850a5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_975b15d4875d5045f9bc1cb682880ca1 = $(`&lt;div id=&quot;html_975b15d4875d5045f9bc1cb682880ca1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_ee69cf39302057359346bf2ce7f850a5.setContent(html_975b15d4875d5045f9bc1cb682880ca1);
#
#
#
#         marker_2cb37620d6fe05eb5b7628ae61806995.bindPopup(popup_ee69cf39302057359346bf2ce7f850a5)
#         ;
#
#
#
#
#             var marker_858bb6c045331545103b0d4a90cd8544 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_f2a755cdf1b364a34dda6b4088c8d1ac);
#
#
#         var popup_ad307f81cc5e5f013f044cda26d0d76b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a4fb2b2bdfa9ac02d08b3a558b4cae31 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a4fb2b2bdfa9ac02d08b3a558b4cae31&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a4fb2b2bdfa9ac02d08b3a558b4cae31 = L.map(
#                 &quot;map_a4fb2b2bdfa9ac02d08b3a558b4cae31&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_358783181ca9d73b2b04cf9343b8d4ff = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_358783181ca9d73b2b04cf9343b8d4ff.addTo(map_a4fb2b2bdfa9ac02d08b3a558b4cae31);
#
#
#             var feature_group_2f0f5fd381b59b865c27d36b6ea8269b = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_2f0f5fd381b59b865c27d36b6ea8269b.addTo(map_a4fb2b2bdfa9ac02d08b3a558b4cae31);
#
#
#             var feature_group_sub_group_f0842ee6b856c348f2edb0d4e0670f2b = L.featureGroup.subGroup(
#                 feature_group_2f0f5fd381b59b865c27d36b6ea8269b
#             );
#
#
#             var marker_973314c4baad1ed9d6be672f7893ab96 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_f0842ee6b856c348f2edb0d4e0670f2b);
#
#
#         var popup_202a56a5e84174c3c8c8e4197eaeaef0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dd2704abd941e7d45a83479549bccef1 = $(`&lt;div id=&quot;html_dd2704abd941e7d45a83479549bccef1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_202a56a5e84174c3c8c8e4197eaeaef0.setContent(html_dd2704abd941e7d45a83479549bccef1);
#
#
#
#         marker_973314c4baad1ed9d6be672f7893ab96.bindPopup(popup_202a56a5e84174c3c8c8e4197eaeaef0)
#         ;
#
#
#
#
#             var marker_5a2d482cefb08803b4526e1b8e619f6c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_f0842ee6b856c348f2edb0d4e0670f2b);
#
#
#         var popup_1e65da2eaeb381e1e33fe6e074440dc4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8d2cc5b76d67c8ee8a7ae3fe92e7a99f = $(`&lt;div id=&quot;html_8d2cc5b76d67c8ee8a7ae3fe92e7a99f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_1e65da2eaeb381e1e33fe6e074440dc4.setContent(html_8d2cc5b76d67c8ee8a7ae3fe92e7a99f);
#
#
#
#         marker_5a2d482cefb08803b4526e1b8e619f6c.bindPopup(popup_1e65da2eaeb381e1e33fe6e074440dc4)
#         ;
#
#
#
#
#             var marker_d80af0164cdf3611d5af6909f8c86e6f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_f0842ee6b856c348f2edb0d4e0670f2b);
#
#
#         var popup_66977f5ef6e2deea33881f1a2081c4f9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_513defb6001d591238bd30a8bbb628bc = $(`&lt;div id=&quot;html_513defb6001d591238bd30a8bbb628bc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_66977f5ef6e2deea33881f1a2081c4f9.setContent(html_513defb6001d591238bd30a8bbb628bc);
#
#
#
#         marker_d80af0164cdf3611d5af6909f8c86e6f.bindPopup(popup_66977f5ef6e2deea33881f1a2081c4f9)
#         ;
#
#
#
#
#             var marker_8f5b40e20b68f5929dc2243328b3cda4 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_f0842ee6b856c348f2edb0d4e0670f2b);
#
#
#         var popup_9d426d3f887676875f0fd0234435aebc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_986fdc25c45f6a071396ea1019cc8390 = $(`&lt;div id=&quot;html_986fdc25c45f6a071396ea1019cc8390&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_9d426d3f887676875f0fd0234435aebc.setContent(html_986fdc25c45f6a071396ea1019cc8390);
#
#
#
#         marker_
