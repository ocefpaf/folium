# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ad011d1a8e0a36a16107a11e114c2101 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ad011d1a8e0a36a16107a11e114c2101&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ad011d1a8e0a36a16107a11e114c2101 = L.map(
#                 &quot;map_ad011d1a8e0a36a16107a11e114c2101&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c3dce89e6ba2066d1bfe358055aff259 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c3dce89e6ba2066d1bfe358055aff259.addTo(map_ad011d1a8e0a36a16107a11e114c2101);
#
#
#             var marker_cb98cb441d75b65871a55cce8d6ebe6b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_ad011d1a8e0a36a16107a11e114c2101);
#
#
#         var popup_c61ea031fb818c65f55ec7779cc7d2df = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6f8326f6655423ab9e54e931971a8ffa = $(`&lt;div id=&quot;html_6f8326f6655423ab9e54e931971a8ffa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_c61ea031fb818c65f55ec7779cc7d2df.setContent(html_6f8326f6655423ab9e54e931971a8ffa);
#
#
#
#         marker_cb98cb441d75b65871a55cce8d6ebe6b.bindPopup(popup_c61ea031fb818c65f55ec7779cc7d2df)
#         ;
#
#
#
#
#             var marker_5c26398e5746108f9edc4103eb080585 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_ad011d1a8e0a36a16107a11e114c2101);
#
#
#         var popup_6dc4dc865e27f4525629669c4868aba6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9d704200238a49b0f545fafa1a13a773 = $(`&lt;div id=&quot;html_9d704200238a49b0f545fafa1a13a773&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_6dc4dc865e27f4525629669c4868aba6.setContent(html_9d704200238a49b0f545fafa1a13a773);
#
#
#
#         marker_5c26398e5746108f9edc4103eb080585.bindPopup(popup_6dc4dc865e27f4525629669c4868aba6)
#         ;
#
#
#
#
#             var marker_9d4692e88eb1857e35d2c99ed28f2cac = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_ad011d1a8e0a36a16107a11e114c2101);
#
#
#         var popup_65c12b5b798e204affa046efe3fc27fa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2545056804b1aef033053e3d0b4f7770 = $(`&lt;div id=&quot;html_2545056804b1aef033053e3d0b4f7770&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_65c12b5b798e204affa046efe3fc27fa.setContent(html_2545056804b1aef033053e3d0b4f7770);
#
#
#
#         marker_9d4692e88eb1857e35d2c99ed28f2cac.bindPopup(popup_65c12b5b798e204affa046efe3fc27fa)
#         ;
#
#
#
#
#             var marker_a9852aaeeab5f2cb1499a9b16c5b3e84 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_ad011d1a8e0a36a16107a11e114c2101);
#
#
#         var popup_fd0b71803086dda4f520093bd173584d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7d464b568245d001048b4ed5d6283a38 = $(`&lt;div id=&quot;html_7d464b568245d001048b4ed5d6283a38&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_fd0b71803086dda4f520093bd173584d.setContent(html_7d464b568245d001048b4ed5d6283a38);
#
#
#
#         marker_a9852aaeeab5f2cb1499a9b16c5b3e84.bindPopup(popup_fd0b71803086dda4f520093bd173584d)
#         ;
#
#
#
#
#             var marker_769a6c3c86e10c748f15ac873f937b84 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_ad011d1a8e0a36a16107a11e114c2101);
#
#
#         var popup_34740b93e54360c69a6b2a796ac53c1b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ac8bc42521bc3071533a14f893d46ff0 = $(`&lt;div id=&quot;html_ac8bc42521bc3071533a14f893d46ff0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_34740b93e54360c69a6b2a796ac53c1b.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1e58671e270267f5327d96747e3333f8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1e58671e270267f5327d96747e3333f8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1e58671e270267f5327d96747e3333f8 = L.map(
#                 &quot;map_1e58671e270267f5327d96747e3333f8&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9207c29cdebe60cea8c3d91257f6f4f7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9207c29cdebe60cea8c3d91257f6f4f7.addTo(map_1e58671e270267f5327d96747e3333f8);
#
#
#             var feature_group_a4d0d2065d84fb26c0e421244731c9ee = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_b7bf912e61eb986d8bd1a7f4ad5f6b7a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_a4d0d2065d84fb26c0e421244731c9ee);
#
#
#         var popup_e64d41e7fb74413bb60b4536ba30b4dc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2515c8c21819ee5739604f0bc47da8ce = $(`&lt;div id=&quot;html_2515c8c21819ee5739604f0bc47da8ce&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_e64d41e7fb74413bb60b4536ba30b4dc.setContent(html_2515c8c21819ee5739604f0bc47da8ce);
#
#
#
#         marker_b7bf912e61eb986d8bd1a7f4ad5f6b7a.bindPopup(popup_e64d41e7fb74413bb60b4536ba30b4dc)
#         ;
#
#
#
#
#             var marker_da3028fd8b36e6bf2801ec313440c356 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_a4d0d2065d84fb26c0e421244731c9ee);
#
#
#         var popup_3e315d13e1dba47c7243becae85620ac = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f8155d6d32fe0a2b4c3b97c65acebd9a = $(`&lt;div id=&quot;html_f8155d6d32fe0a2b4c3b97c65acebd9a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_3e315d13e1dba47c7243becae85620ac.setContent(html_f8155d6d32fe0a2b4c3b97c65acebd9a);
#
#
#
#         marker_da3028fd8b36e6bf2801ec313440c356.bindPopup(popup_3e315d13e1dba47c7243becae85620ac)
#         ;
#
#
#
#
#             var marker_96b64511e8db55796a9b520a3ed1122d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_a4d0d2065d84fb26c0e421244731c9ee);
#
#
#         var popup_c7a418e38204d2506ab73e98e2b87484 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3a17b56298b0cbb09647512fadd4bc68 = $(`&lt;div id=&quot;html_3a17b56298b0cbb09647512fadd4bc68&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_c7a418e38204d2506ab73e98e2b87484.setContent(html_3a17b56298b0cbb09647512fadd4bc68);
#
#
#
#         marker_96b64511e8db55796a9b520a3ed1122d.bindPopup(popup_c7a418e38204d2506ab73e98e2b87484)
#         ;
#
#
#
#
#             var marker_ead6ba33db5754b512917bba1db59439 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_a4d0d2065d84fb26c0e421244731c9ee);
#
#
#         var popup_cab9b6a90c4cc740188179c5b822db07 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dedb3472491e161225b65eff32c1d78c = $(`&lt;div id=&quot;html_dedb3472491e161225b65eff32c1d78c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_cab9b6a90c4cc740188179c5b822db07.setContent(html_dedb3472491e161225b65eff32c1d78c);
#
#
#
#         marker_ead6ba33db5754b512917bba1db59439.bindPopup(popup_cab9b6a90c4cc740188179c5b822db07)
#         ;
#
#
#
#
#             var marker_b390c722d0767a187c992db0427c30e5 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_a4d0d2065d84fb26c0e421244731c9ee);
#
#
#         var popup_80ab6178973fd3a79de1e7e10cabb11a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8b4dd3d008b2cfd2651a94c28d4cfc31 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8b4dd3d008b2cfd2651a94c28d4cfc31&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8b4dd3d008b2cfd2651a94c28d4cfc31 = L.map(
#                 &quot;map_8b4dd3d008b2cfd2651a94c28d4cfc31&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_999bad2fede1d9082b946eba2e9d0936 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_999bad2fede1d9082b946eba2e9d0936.addTo(map_8b4dd3d008b2cfd2651a94c28d4cfc31);
#
#
#             var feature_group_4d236a36f3b5e964d50bead90af26b47 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_4d236a36f3b5e964d50bead90af26b47.addTo(map_8b4dd3d008b2cfd2651a94c28d4cfc31);
#
#
#             var feature_group_sub_group_07cd5319cdd05dc7e26e9e3a74302645 = L.featureGroup.subGroup(
#                 feature_group_4d236a36f3b5e964d50bead90af26b47
#             );
#
#
#             var marker_2c96ef15926986f236cbd77ffdddce38 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_07cd5319cdd05dc7e26e9e3a74302645);
#
#
#         var popup_e14298df1c3f54492cce57f900a332eb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1421e9594f0882c6cdfe7fabcf6f063f = $(`&lt;div id=&quot;html_1421e9594f0882c6cdfe7fabcf6f063f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_e14298df1c3f54492cce57f900a332eb.setContent(html_1421e9594f0882c6cdfe7fabcf6f063f);
#
#
#
#         marker_2c96ef15926986f236cbd77ffdddce38.bindPopup(popup_e14298df1c3f54492cce57f900a332eb)
#         ;
#
#
#
#
#             var marker_7f3435be87d00a4a75eeb433825ed636 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_07cd5319cdd05dc7e26e9e3a74302645);
#
#
#         var popup_d6f8b697de87a9ef31f2ff6febc5f60e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_04e5ee0df732918614e2786c6dda833a = $(`&lt;div id=&quot;html_04e5ee0df732918614e2786c6dda833a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_d6f8b697de87a9ef31f2ff6febc5f60e.setContent(html_04e5ee0df732918614e2786c6dda833a);
#
#
#
#         marker_7f3435be87d00a4a75eeb433825ed636.bindPopup(popup_d6f8b697de87a9ef31f2ff6febc5f60e)
#         ;
#
#
#
#
#             var marker_d27dae2413245ff36ebbd64b98e9604c = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_07cd5319cdd05dc7e26e9e3a74302645);
#
#
#         var popup_ef632f5bfb10b244804bed958199e2b1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b7708c98f782c95f6cdf129d4d07d5fa = $(`&lt;div id=&quot;html_b7708c98f782c95f6cdf129d4d07d5fa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_ef632f5bfb10b244804bed958199e2b1.setContent(html_b7708c98f782c95f6cdf129d4d07d5fa);
#
#
#
#         marker_d27dae2413245ff36ebbd64b98e9604c.bindPopup(popup_ef632f5bfb10b244804bed958199e2b1)
#         ;
#
#
#
#
#             var marker_412be361fa2ea0b0b5151ca39f5d9b56 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_07cd5319cdd05dc7e26e9e3a74302645);
#
#
#         var popup_e65f080fd70a59ee70c58509f910c859 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7b2a3496f635591446a493b06dc76ed3 = $(`&lt;div id=&quot;html_7b2a3496f635591446a493b06dc76ed3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_e65f080fd70a59ee70c58509f910c859.setContent(html_7b2a3496f635591446a493b06dc76ed3);
#
#
#
#         marker_
