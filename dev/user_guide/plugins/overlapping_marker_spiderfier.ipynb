# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_82ed3e8d1d00b5fb38a1e656d79012f7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_82ed3e8d1d00b5fb38a1e656d79012f7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_82ed3e8d1d00b5fb38a1e656d79012f7 = L.map(
#                 &quot;map_82ed3e8d1d00b5fb38a1e656d79012f7&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bb849b881d8dde02d2dffd4ff26660f3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_bb849b881d8dde02d2dffd4ff26660f3.addTo(map_82ed3e8d1d00b5fb38a1e656d79012f7);
#
#
#             var marker_5032dd3d57342d55160d74d6c46f7946 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_82ed3e8d1d00b5fb38a1e656d79012f7);
#
#
#         var popup_8c0409f29d3ce4feb87b11360fd87a99 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0b649e345dd2925288faaf8b334562e6 = $(`&lt;div id=&quot;html_0b649e345dd2925288faaf8b334562e6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_8c0409f29d3ce4feb87b11360fd87a99.setContent(html_0b649e345dd2925288faaf8b334562e6);
#
#
#
#         marker_5032dd3d57342d55160d74d6c46f7946.bindPopup(popup_8c0409f29d3ce4feb87b11360fd87a99)
#         ;
#
#
#
#
#             var marker_85d2325f6f193c526e2735dce16caffd = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_82ed3e8d1d00b5fb38a1e656d79012f7);
#
#
#         var popup_de409e4fa44210482b475b0166ef5cf0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_afe0f138d4fd5c52860adf5e527d0212 = $(`&lt;div id=&quot;html_afe0f138d4fd5c52860adf5e527d0212&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_de409e4fa44210482b475b0166ef5cf0.setContent(html_afe0f138d4fd5c52860adf5e527d0212);
#
#
#
#         marker_85d2325f6f193c526e2735dce16caffd.bindPopup(popup_de409e4fa44210482b475b0166ef5cf0)
#         ;
#
#
#
#
#             var marker_40c88d9dfbd78853d3abdfeae4d0b917 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_82ed3e8d1d00b5fb38a1e656d79012f7);
#
#
#         var popup_bf3b73c2bede3deb633b22985c709851 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c5c9bd673ad6fbca6262726d3c1edece = $(`&lt;div id=&quot;html_c5c9bd673ad6fbca6262726d3c1edece&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_bf3b73c2bede3deb633b22985c709851.setContent(html_c5c9bd673ad6fbca6262726d3c1edece);
#
#
#
#         marker_40c88d9dfbd78853d3abdfeae4d0b917.bindPopup(popup_bf3b73c2bede3deb633b22985c709851)
#         ;
#
#
#
#
#             var marker_ff8dab2607e2044847edae0845aef377 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_82ed3e8d1d00b5fb38a1e656d79012f7);
#
#
#         var popup_3f9a842f02543b940f23d363e7f5e293 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0eb91e5efcddf9f604bf99d85f801ac4 = $(`&lt;div id=&quot;html_0eb91e5efcddf9f604bf99d85f801ac4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_3f9a842f02543b940f23d363e7f5e293.setContent(html_0eb91e5efcddf9f604bf99d85f801ac4);
#
#
#
#         marker_ff8dab2607e2044847edae0845aef377.bindPopup(popup_3f9a842f02543b940f23d363e7f5e293)
#         ;
#
#
#
#
#             var marker_4fd908206f8a7ee3300764ee3478fd79 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_82ed3e8d1d00b5fb38a1e656d79012f7);
#
#
#         var popup_ff84fb4d4c45e54e3dba5569120994c8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b4c75b4f0bbe4c5ad9ef9611eb01bda0 = $(`&lt;div id=&quot;html_b4c75b4f0bbe4c5ad9ef9611eb01bda0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_ff84fb4d4c45e54e3dba5569120994c8.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0078bb8312b001dc167884a4cc7f6a7c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0078bb8312b001dc167884a4cc7f6a7c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0078bb8312b001dc167884a4cc7f6a7c = L.map(
#                 &quot;map_0078bb8312b001dc167884a4cc7f6a7c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d0929cf5259df020ab91f6e49ec8ca5b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d0929cf5259df020ab91f6e49ec8ca5b.addTo(map_0078bb8312b001dc167884a4cc7f6a7c);
#
#
#             var feature_group_0b11c6965d085fbbb69444bcb9b26284 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_6263f4f446b9cb011b5c207025fb63fd = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_0b11c6965d085fbbb69444bcb9b26284);
#
#
#         var popup_1e8b8a8ea306a53cb7e6e15f72fdf54f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c33ef03efa3d53cc39fb01ba8c4343ee = $(`&lt;div id=&quot;html_c33ef03efa3d53cc39fb01ba8c4343ee&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_1e8b8a8ea306a53cb7e6e15f72fdf54f.setContent(html_c33ef03efa3d53cc39fb01ba8c4343ee);
#
#
#
#         marker_6263f4f446b9cb011b5c207025fb63fd.bindPopup(popup_1e8b8a8ea306a53cb7e6e15f72fdf54f)
#         ;
#
#
#
#
#             var marker_4ef56c6ade1ae895ce35549f5b258d76 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_0b11c6965d085fbbb69444bcb9b26284);
#
#
#         var popup_481ced88e82045270dbbf1e83910baad = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_349cd29d99ce9e5cd522a368d9636e7e = $(`&lt;div id=&quot;html_349cd29d99ce9e5cd522a368d9636e7e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_481ced88e82045270dbbf1e83910baad.setContent(html_349cd29d99ce9e5cd522a368d9636e7e);
#
#
#
#         marker_4ef56c6ade1ae895ce35549f5b258d76.bindPopup(popup_481ced88e82045270dbbf1e83910baad)
#         ;
#
#
#
#
#             var marker_d291eaa3e838d9f38d4db2851e0447ca = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_0b11c6965d085fbbb69444bcb9b26284);
#
#
#         var popup_d308baedef0e211fd8403e3c2ce095d3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8d79529220891531db9f50a0e8975560 = $(`&lt;div id=&quot;html_8d79529220891531db9f50a0e8975560&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_d308baedef0e211fd8403e3c2ce095d3.setContent(html_8d79529220891531db9f50a0e8975560);
#
#
#
#         marker_d291eaa3e838d9f38d4db2851e0447ca.bindPopup(popup_d308baedef0e211fd8403e3c2ce095d3)
#         ;
#
#
#
#
#             var marker_be7280de1fca1832e7cece72250cc10a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_0b11c6965d085fbbb69444bcb9b26284);
#
#
#         var popup_f26f71df1dab1e70ce3c40a366505c31 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ae99f6a26d54bd4106fb21c5a1bc6950 = $(`&lt;div id=&quot;html_ae99f6a26d54bd4106fb21c5a1bc6950&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_f26f71df1dab1e70ce3c40a366505c31.setContent(html_ae99f6a26d54bd4106fb21c5a1bc6950);
#
#
#
#         marker_be7280de1fca1832e7cece72250cc10a.bindPopup(popup_f26f71df1dab1e70ce3c40a366505c31)
#         ;
#
#
#
#
#             var marker_341de18c92198a3828ed093af19a0bf2 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_0b11c6965d085fbbb69444bcb9b26284);
#
#
#         var popup_e9199a860b09c247d3aed56c5d64b8be = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a373059e738a9ca10614b167078ad7a1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a373059e738a9ca10614b167078ad7a1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a373059e738a9ca10614b167078ad7a1 = L.map(
#                 &quot;map_a373059e738a9ca10614b167078ad7a1&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7b9b0b9b9568dc046e4e68cb4945f20c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7b9b0b9b9568dc046e4e68cb4945f20c.addTo(map_a373059e738a9ca10614b167078ad7a1);
#
#
#             var feature_group_6a331e05afe91178d042f19b7ef11607 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_6a331e05afe91178d042f19b7ef11607.addTo(map_a373059e738a9ca10614b167078ad7a1);
#
#
#             var feature_group_sub_group_01eb045bb623c98190b5c0ab2a29f6e2 = L.featureGroup.subGroup(
#                 feature_group_6a331e05afe91178d042f19b7ef11607
#             );
#
#
#             var marker_2b5540fc3d99c00ce6c9caa286d08736 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_01eb045bb623c98190b5c0ab2a29f6e2);
#
#
#         var popup_21ac3d9b3157e4f469aa8c2e5ad9b035 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_32d899b5859dc886059abd803ccad019 = $(`&lt;div id=&quot;html_32d899b5859dc886059abd803ccad019&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_21ac3d9b3157e4f469aa8c2e5ad9b035.setContent(html_32d899b5859dc886059abd803ccad019);
#
#
#
#         marker_2b5540fc3d99c00ce6c9caa286d08736.bindPopup(popup_21ac3d9b3157e4f469aa8c2e5ad9b035)
#         ;
#
#
#
#
#             var marker_40c5e5b167ea6d0d71819683a0f299b3 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_01eb045bb623c98190b5c0ab2a29f6e2);
#
#
#         var popup_8f8227d4e1f6f9a3f12e16775cb3c7a9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_09f5e5bec2f2f5ddc7afc4fc35f7d05d = $(`&lt;div id=&quot;html_09f5e5bec2f2f5ddc7afc4fc35f7d05d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_8f8227d4e1f6f9a3f12e16775cb3c7a9.setContent(html_09f5e5bec2f2f5ddc7afc4fc35f7d05d);
#
#
#
#         marker_40c5e5b167ea6d0d71819683a0f299b3.bindPopup(popup_8f8227d4e1f6f9a3f12e16775cb3c7a9)
#         ;
#
#
#
#
#             var marker_cf8bb9cc79276bb40fd01b150abc7bd5 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_01eb045bb623c98190b5c0ab2a29f6e2);
#
#
#         var popup_5d36be492fc05bd97cffd3c0ccdef4c1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_237987c1a5cee3480d06a78e752938d9 = $(`&lt;div id=&quot;html_237987c1a5cee3480d06a78e752938d9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_5d36be492fc05bd97cffd3c0ccdef4c1.setContent(html_237987c1a5cee3480d06a78e752938d9);
#
#
#
#         marker_cf8bb9cc79276bb40fd01b150abc7bd5.bindPopup(popup_5d36be492fc05bd97cffd3c0ccdef4c1)
#         ;
#
#
#
#
#             var marker_897f1096dba783cbc6b7280a4953a852 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_01eb045bb623c98190b5c0ab2a29f6e2);
#
#
#         var popup_87125c4aef137c029aed47d972e37c7c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_386890b592071c25a5411229fe10c57b = $(`&lt;div id=&quot;html_386890b592071c25a5411229fe10c57b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_87125c4aef137c029aed47d972e37c7c.setContent(html_386890b592071c25a5411229fe10c57b);
#
#
#
#         marker_
