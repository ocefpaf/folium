# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_01a2a4cb03023758377f2d587d41bccb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_01a2a4cb03023758377f2d587d41bccb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_01a2a4cb03023758377f2d587d41bccb = L.map(
#                 &quot;map_01a2a4cb03023758377f2d587d41bccb&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a7087d04f55439f5e47091cf718f9c96 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a7087d04f55439f5e47091cf718f9c96.addTo(map_01a2a4cb03023758377f2d587d41bccb);
#
#
#             var marker_b3352b8036a6d2e155fea64e667ff8cf = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_01a2a4cb03023758377f2d587d41bccb);
#
#
#         var popup_760d868f4137416ba2451e1e55bcdbd1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f2798c3bc8e9058ee5fe48100233886a = $(`&lt;div id=&quot;html_f2798c3bc8e9058ee5fe48100233886a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_760d868f4137416ba2451e1e55bcdbd1.setContent(html_f2798c3bc8e9058ee5fe48100233886a);
#
#
#
#         marker_b3352b8036a6d2e155fea64e667ff8cf.bindPopup(popup_760d868f4137416ba2451e1e55bcdbd1)
#         ;
#
#
#
#
#             var marker_020dae12e2f8805487a616b14f8bdca0 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_01a2a4cb03023758377f2d587d41bccb);
#
#
#         var popup_874490e9cbf4b26c694d949195d7594a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2b2599f288ddbf0fa6fcc6334ef3a5f5 = $(`&lt;div id=&quot;html_2b2599f288ddbf0fa6fcc6334ef3a5f5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_874490e9cbf4b26c694d949195d7594a.setContent(html_2b2599f288ddbf0fa6fcc6334ef3a5f5);
#
#
#
#         marker_020dae12e2f8805487a616b14f8bdca0.bindPopup(popup_874490e9cbf4b26c694d949195d7594a)
#         ;
#
#
#
#
#             var marker_79fd173e8ed0f9aecfde7d30ee547a09 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_01a2a4cb03023758377f2d587d41bccb);
#
#
#         var popup_ac9bd9c3c27ae6b947bf7757e987d265 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3012390810a9a181b9db66cccf4eb1bf = $(`&lt;div id=&quot;html_3012390810a9a181b9db66cccf4eb1bf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_ac9bd9c3c27ae6b947bf7757e987d265.setContent(html_3012390810a9a181b9db66cccf4eb1bf);
#
#
#
#         marker_79fd173e8ed0f9aecfde7d30ee547a09.bindPopup(popup_ac9bd9c3c27ae6b947bf7757e987d265)
#         ;
#
#
#
#
#             var marker_4b9fddf5cf13b609f1970304c26a8c47 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_01a2a4cb03023758377f2d587d41bccb);
#
#
#         var popup_517dd3bb87fdf11e7ae65dea9312733b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_90f2d1e4c5fac9b7bdd4bf0a06491912 = $(`&lt;div id=&quot;html_90f2d1e4c5fac9b7bdd4bf0a06491912&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_517dd3bb87fdf11e7ae65dea9312733b.setContent(html_90f2d1e4c5fac9b7bdd4bf0a06491912);
#
#
#
#         marker_4b9fddf5cf13b609f1970304c26a8c47.bindPopup(popup_517dd3bb87fdf11e7ae65dea9312733b)
#         ;
#
#
#
#
#             var marker_e24983f04f725e33edeb2ffce2219c1e = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_01a2a4cb03023758377f2d587d41bccb);
#
#
#         var popup_7cbe88342c907c4ed35b73d1ef726ca9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4ede158359371ca7b969f5aebe644c69 = $(`&lt;div id=&quot;html_4ede158359371ca7b969f5aebe644c69&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_7cbe88342c907c4ed35b73d1ef726ca9.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1fbac10da0f7d6a4851b7f09c3246d5d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1fbac10da0f7d6a4851b7f09c3246d5d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1fbac10da0f7d6a4851b7f09c3246d5d = L.map(
#                 &quot;map_1fbac10da0f7d6a4851b7f09c3246d5d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3754c5a8c961c559cf690f500d5ed541 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3754c5a8c961c559cf690f500d5ed541.addTo(map_1fbac10da0f7d6a4851b7f09c3246d5d);
#
#
#             var feature_group_bc691f8f4d905337b3ab83c8fd163259 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_c99bf61e4b4d67b18dbb0562e87030af = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_bc691f8f4d905337b3ab83c8fd163259);
#
#
#         var popup_9b3cf4b7fc05dca4617c46c911118046 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_21b19bbbfcf6992068cff8c6faa3a807 = $(`&lt;div id=&quot;html_21b19bbbfcf6992068cff8c6faa3a807&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_9b3cf4b7fc05dca4617c46c911118046.setContent(html_21b19bbbfcf6992068cff8c6faa3a807);
#
#
#
#         marker_c99bf61e4b4d67b18dbb0562e87030af.bindPopup(popup_9b3cf4b7fc05dca4617c46c911118046)
#         ;
#
#
#
#
#             var marker_10b134afe04b308713712bd6ea6f0f4d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_bc691f8f4d905337b3ab83c8fd163259);
#
#
#         var popup_83d91d247366dc39fd800d7f9cf61ea3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_357b24f8464df20dcbeae878386890f4 = $(`&lt;div id=&quot;html_357b24f8464df20dcbeae878386890f4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_83d91d247366dc39fd800d7f9cf61ea3.setContent(html_357b24f8464df20dcbeae878386890f4);
#
#
#
#         marker_10b134afe04b308713712bd6ea6f0f4d.bindPopup(popup_83d91d247366dc39fd800d7f9cf61ea3)
#         ;
#
#
#
#
#             var marker_9ee7c5ee05db7293f9790b46284d8979 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_bc691f8f4d905337b3ab83c8fd163259);
#
#
#         var popup_e85d656ef1dc120cf2029af1dfbb4fe4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_81f67d5c47ec36700a12aaf80cadaf9c = $(`&lt;div id=&quot;html_81f67d5c47ec36700a12aaf80cadaf9c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_e85d656ef1dc120cf2029af1dfbb4fe4.setContent(html_81f67d5c47ec36700a12aaf80cadaf9c);
#
#
#
#         marker_9ee7c5ee05db7293f9790b46284d8979.bindPopup(popup_e85d656ef1dc120cf2029af1dfbb4fe4)
#         ;
#
#
#
#
#             var marker_f9e9ce674dd9fb531556995f5de387a5 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_bc691f8f4d905337b3ab83c8fd163259);
#
#
#         var popup_4488aa7573deb07c6efb000122aeb904 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_aabe02fb65c893fd67590d65a6cd7598 = $(`&lt;div id=&quot;html_aabe02fb65c893fd67590d65a6cd7598&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_4488aa7573deb07c6efb000122aeb904.setContent(html_aabe02fb65c893fd67590d65a6cd7598);
#
#
#
#         marker_f9e9ce674dd9fb531556995f5de387a5.bindPopup(popup_4488aa7573deb07c6efb000122aeb904)
#         ;
#
#
#
#
#             var marker_eb8b0f1cde1d72e0be2acc22d74a38d7 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_bc691f8f4d905337b3ab83c8fd163259);
#
#
#         var popup_5b87322b22206077fc7bd3e8c570ff07 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4d3fd3c9f91b228ae85aba11754d6fbd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4d3fd3c9f91b228ae85aba11754d6fbd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4d3fd3c9f91b228ae85aba11754d6fbd = L.map(
#                 &quot;map_4d3fd3c9f91b228ae85aba11754d6fbd&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_99afd25a3eaf5fcd1e4f9dcaa381c8b1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_99afd25a3eaf5fcd1e4f9dcaa381c8b1.addTo(map_4d3fd3c9f91b228ae85aba11754d6fbd);
#
#
#             var feature_group_1bfefde981f5173eaa6ad0c23a02ff63 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_1bfefde981f5173eaa6ad0c23a02ff63.addTo(map_4d3fd3c9f91b228ae85aba11754d6fbd);
#
#
#             var feature_group_sub_group_7899a428df0f9b5016543381e0d681bc = L.featureGroup.subGroup(
#                 feature_group_1bfefde981f5173eaa6ad0c23a02ff63
#             );
#
#
#             var marker_bd43ce825cf34a83c79e1f18d585865d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_7899a428df0f9b5016543381e0d681bc);
#
#
#         var popup_3d84f4520605d3738d509876f3a677d6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_99eb6cd6a8e68ecd7677761da806073a = $(`&lt;div id=&quot;html_99eb6cd6a8e68ecd7677761da806073a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_3d84f4520605d3738d509876f3a677d6.setContent(html_99eb6cd6a8e68ecd7677761da806073a);
#
#
#
#         marker_bd43ce825cf34a83c79e1f18d585865d.bindPopup(popup_3d84f4520605d3738d509876f3a677d6)
#         ;
#
#
#
#
#             var marker_b1460020f71c1525045b5c3fe8e41a3c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_7899a428df0f9b5016543381e0d681bc);
#
#
#         var popup_0e0e4668246c2e76b84ed74cf25f395a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cd5c649ccc0746b2a5645c9c2996e3d9 = $(`&lt;div id=&quot;html_cd5c649ccc0746b2a5645c9c2996e3d9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_0e0e4668246c2e76b84ed74cf25f395a.setContent(html_cd5c649ccc0746b2a5645c9c2996e3d9);
#
#
#
#         marker_b1460020f71c1525045b5c3fe8e41a3c.bindPopup(popup_0e0e4668246c2e76b84ed74cf25f395a)
#         ;
#
#
#
#
#             var marker_47b3e95ad68fce7c86212e3514ac4e5b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_7899a428df0f9b5016543381e0d681bc);
#
#
#         var popup_7f362aa1911acd838b46d83bf75a9c71 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b2b8db410405dedb3ebd9eab2b3c6db9 = $(`&lt;div id=&quot;html_b2b8db410405dedb3ebd9eab2b3c6db9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_7f362aa1911acd838b46d83bf75a9c71.setContent(html_b2b8db410405dedb3ebd9eab2b3c6db9);
#
#
#
#         marker_47b3e95ad68fce7c86212e3514ac4e5b.bindPopup(popup_7f362aa1911acd838b46d83bf75a9c71)
#         ;
#
#
#
#
#             var marker_54d09b668391bc234559b02b00efeb7d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_7899a428df0f9b5016543381e0d681bc);
#
#
#         var popup_d16a28f90add04706d533c1714ec47e7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_554f28a43d02957b801561b0e4928670 = $(`&lt;div id=&quot;html_554f28a43d02957b801561b0e4928670&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_d16a28f90add04706d533c1714ec47e7.setContent(html_554f28a43d02957b801561b0e4928670);
#
#
#
#         marker_
