# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3c2eca725ae438d00b87a8adc83eff7a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3c2eca725ae438d00b87a8adc83eff7a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3c2eca725ae438d00b87a8adc83eff7a = L.map(
#                 &quot;map_3c2eca725ae438d00b87a8adc83eff7a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e7f574f263489fd72a1822fe3f6bb729 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e7f574f263489fd72a1822fe3f6bb729.addTo(map_3c2eca725ae438d00b87a8adc83eff7a);
#
#
#             var marker_672710b45db1a4471ce382629b399738 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_3c2eca725ae438d00b87a8adc83eff7a);
#
#
#         var popup_e01b6c5a920a289f0cfea3fb565afa20 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0e8749c5e075037a18460941c1191b2f = $(`&lt;div id=&quot;html_0e8749c5e075037a18460941c1191b2f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_e01b6c5a920a289f0cfea3fb565afa20.setContent(html_0e8749c5e075037a18460941c1191b2f);
#
#
#
#         marker_672710b45db1a4471ce382629b399738.bindPopup(popup_e01b6c5a920a289f0cfea3fb565afa20)
#         ;
#
#
#
#
#             var marker_064fa3ac888cef3afaf480386beb06bc = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_3c2eca725ae438d00b87a8adc83eff7a);
#
#
#         var popup_1db36db27ed818c3052d8456a6323242 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cee56655a4b7e0bdf32f61ad7f69a387 = $(`&lt;div id=&quot;html_cee56655a4b7e0bdf32f61ad7f69a387&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_1db36db27ed818c3052d8456a6323242.setContent(html_cee56655a4b7e0bdf32f61ad7f69a387);
#
#
#
#         marker_064fa3ac888cef3afaf480386beb06bc.bindPopup(popup_1db36db27ed818c3052d8456a6323242)
#         ;
#
#
#
#
#             var marker_3c3113ef0e3e16751b02513dd0bb7ada = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_3c2eca725ae438d00b87a8adc83eff7a);
#
#
#         var popup_601a243d0d455aee5624d9a381b4df08 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4d4bef8c5e53ce830a6ecaefc222cc3b = $(`&lt;div id=&quot;html_4d4bef8c5e53ce830a6ecaefc222cc3b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_601a243d0d455aee5624d9a381b4df08.setContent(html_4d4bef8c5e53ce830a6ecaefc222cc3b);
#
#
#
#         marker_3c3113ef0e3e16751b02513dd0bb7ada.bindPopup(popup_601a243d0d455aee5624d9a381b4df08)
#         ;
#
#
#
#
#             var marker_325fc7bff85ca7867b8ef3dd1ebc2832 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_3c2eca725ae438d00b87a8adc83eff7a);
#
#
#         var popup_a7c7dd63a9504365557e117964a501d0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c2c30751a3f5e8ddcbbea5b9f9ede624 = $(`&lt;div id=&quot;html_c2c30751a3f5e8ddcbbea5b9f9ede624&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_a7c7dd63a9504365557e117964a501d0.setContent(html_c2c30751a3f5e8ddcbbea5b9f9ede624);
#
#
#
#         marker_325fc7bff85ca7867b8ef3dd1ebc2832.bindPopup(popup_a7c7dd63a9504365557e117964a501d0)
#         ;
#
#
#
#
#             var marker_7560774c6edeaf70a24e51fc017d6970 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_3c2eca725ae438d00b87a8adc83eff7a);
#
#
#         var popup_ef2ab5b83c45f28b95380c34754340ac = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e0a5f22ad6784219cb6903eb1d95bfba = $(`&lt;div id=&quot;html_e0a5f22ad6784219cb6903eb1d95bfba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_ef2ab5b83c45f28b95380c34754340ac.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c34c2917d60924efd36c233b04f04b71 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c34c2917d60924efd36c233b04f04b71&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c34c2917d60924efd36c233b04f04b71 = L.map(
#                 &quot;map_c34c2917d60924efd36c233b04f04b71&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7f06be27a7937d257639475bab7cb73c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7f06be27a7937d257639475bab7cb73c.addTo(map_c34c2917d60924efd36c233b04f04b71);
#
#
#             var feature_group_7dc5b477e37992667a171ddc777daa94 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_945892a3edd4086b8626cef71df5af3b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_7dc5b477e37992667a171ddc777daa94);
#
#
#         var popup_6c5b7ff6347aae575794d42bdc1a88c3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a25e5a3b50a0df424588d92efebba148 = $(`&lt;div id=&quot;html_a25e5a3b50a0df424588d92efebba148&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_6c5b7ff6347aae575794d42bdc1a88c3.setContent(html_a25e5a3b50a0df424588d92efebba148);
#
#
#
#         marker_945892a3edd4086b8626cef71df5af3b.bindPopup(popup_6c5b7ff6347aae575794d42bdc1a88c3)
#         ;
#
#
#
#
#             var marker_9e224f786428f74b34780568a195dcf9 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_7dc5b477e37992667a171ddc777daa94);
#
#
#         var popup_7e57a9aa2f26c271b66ba0d50de27795 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2c7c612e3bbef1766483a11fdd3f51ac = $(`&lt;div id=&quot;html_2c7c612e3bbef1766483a11fdd3f51ac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_7e57a9aa2f26c271b66ba0d50de27795.setContent(html_2c7c612e3bbef1766483a11fdd3f51ac);
#
#
#
#         marker_9e224f786428f74b34780568a195dcf9.bindPopup(popup_7e57a9aa2f26c271b66ba0d50de27795)
#         ;
#
#
#
#
#             var marker_7da73d4d9ff9aaf8676af05041cfc5a4 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_7dc5b477e37992667a171ddc777daa94);
#
#
#         var popup_0d6773e0b72f94bd3fc1c53bf2ac21b8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8ac1b81deb03b6f40653a7045ee3bd24 = $(`&lt;div id=&quot;html_8ac1b81deb03b6f40653a7045ee3bd24&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_0d6773e0b72f94bd3fc1c53bf2ac21b8.setContent(html_8ac1b81deb03b6f40653a7045ee3bd24);
#
#
#
#         marker_7da73d4d9ff9aaf8676af05041cfc5a4.bindPopup(popup_0d6773e0b72f94bd3fc1c53bf2ac21b8)
#         ;
#
#
#
#
#             var marker_9e73a5ad2bc516205edc7375400a335e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_7dc5b477e37992667a171ddc777daa94);
#
#
#         var popup_9ed8d75a657b9aa30ac1e8251ed8fe7a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0c8c42005754f1d841aec5f168744018 = $(`&lt;div id=&quot;html_0c8c42005754f1d841aec5f168744018&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_9ed8d75a657b9aa30ac1e8251ed8fe7a.setContent(html_0c8c42005754f1d841aec5f168744018);
#
#
#
#         marker_9e73a5ad2bc516205edc7375400a335e.bindPopup(popup_9ed8d75a657b9aa30ac1e8251ed8fe7a)
#         ;
#
#
#
#
#             var marker_3f0e7d4d63fc54853337d8367177425e = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_7dc5b477e37992667a171ddc777daa94);
#
#
#         var popup_c7e7bcc006cfbfa49f87fbfa59669fc3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b29011f4f68c7a240b5a7ce7433b9eb4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b29011f4f68c7a240b5a7ce7433b9eb4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b29011f4f68c7a240b5a7ce7433b9eb4 = L.map(
#                 &quot;map_b29011f4f68c7a240b5a7ce7433b9eb4&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9ee45e7b30a7ebd9c09da639cd788104 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9ee45e7b30a7ebd9c09da639cd788104.addTo(map_b29011f4f68c7a240b5a7ce7433b9eb4);
#
#
#             var feature_group_8eee8962de68495fb6179545f3fe307f = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_8eee8962de68495fb6179545f3fe307f.addTo(map_b29011f4f68c7a240b5a7ce7433b9eb4);
#
#
#             var feature_group_sub_group_aca11429799eab566b461ea7dec03529 = L.featureGroup.subGroup(
#                 feature_group_8eee8962de68495fb6179545f3fe307f
#             );
#
#
#             var marker_541cf87cde919f910dcceff88db79266 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_aca11429799eab566b461ea7dec03529);
#
#
#         var popup_67f2b314808db84442a8777f68736f79 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_763cf2bdb2c3e5109ca9e8aefbfeaf16 = $(`&lt;div id=&quot;html_763cf2bdb2c3e5109ca9e8aefbfeaf16&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_67f2b314808db84442a8777f68736f79.setContent(html_763cf2bdb2c3e5109ca9e8aefbfeaf16);
#
#
#
#         marker_541cf87cde919f910dcceff88db79266.bindPopup(popup_67f2b314808db84442a8777f68736f79)
#         ;
#
#
#
#
#             var marker_d70a13be7fc7b725006f0f190ae7495c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_aca11429799eab566b461ea7dec03529);
#
#
#         var popup_2227269c7819e56fe4fa2d0163fa062e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_399767a726c8fd73c2d9db72e705bcf1 = $(`&lt;div id=&quot;html_399767a726c8fd73c2d9db72e705bcf1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_2227269c7819e56fe4fa2d0163fa062e.setContent(html_399767a726c8fd73c2d9db72e705bcf1);
#
#
#
#         marker_d70a13be7fc7b725006f0f190ae7495c.bindPopup(popup_2227269c7819e56fe4fa2d0163fa062e)
#         ;
#
#
#
#
#             var marker_cd6d96fcfff9f03e3fee56785813e71d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_aca11429799eab566b461ea7dec03529);
#
#
#         var popup_8d0e6214c50c18ca596a20abcccee9ff = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_93e67ff6ee88a7b2ea1ff60030158338 = $(`&lt;div id=&quot;html_93e67ff6ee88a7b2ea1ff60030158338&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_8d0e6214c50c18ca596a20abcccee9ff.setContent(html_93e67ff6ee88a7b2ea1ff60030158338);
#
#
#
#         marker_cd6d96fcfff9f03e3fee56785813e71d.bindPopup(popup_8d0e6214c50c18ca596a20abcccee9ff)
#         ;
#
#
#
#
#             var marker_0e99749172eca1b2a60d7adf3a8714c1 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_aca11429799eab566b461ea7dec03529);
#
#
#         var popup_27dca4d04c57a8ad054487a964795562 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d0847b9b9465b844122344f0853dd1f1 = $(`&lt;div id=&quot;html_d0847b9b9465b844122344f0853dd1f1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_27dca4d04c57a8ad054487a964795562.setContent(html_d0847b9b9465b844122344f0853dd1f1);
#
#
#
#         marker_
