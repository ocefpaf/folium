# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_99feea844ef334e7d6b6850a098d0f45 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_99feea844ef334e7d6b6850a098d0f45&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_99feea844ef334e7d6b6850a098d0f45 = L.map(
#                 &quot;map_99feea844ef334e7d6b6850a098d0f45&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_689c6f1e5e4a74fbe4a235481be00d68 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_689c6f1e5e4a74fbe4a235481be00d68.addTo(map_99feea844ef334e7d6b6850a098d0f45);
#
#
#             var marker_2e39d969b43f2b01969dd2c3b01d3cf8 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_99feea844ef334e7d6b6850a098d0f45);
#
#
#         var popup_d7a230dae9dca13f505c50c328bc69ac = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_20e0839b53de94c73951e0f54d48ff39 = $(`&lt;div id=&quot;html_20e0839b53de94c73951e0f54d48ff39&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_d7a230dae9dca13f505c50c328bc69ac.setContent(html_20e0839b53de94c73951e0f54d48ff39);
#
#
#
#         marker_2e39d969b43f2b01969dd2c3b01d3cf8.bindPopup(popup_d7a230dae9dca13f505c50c328bc69ac)
#         ;
#
#
#
#
#             var marker_84d70df0c5666e1319325474f3f26903 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_99feea844ef334e7d6b6850a098d0f45);
#
#
#         var popup_1620c9df2bb04820b6334180588cce3d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6acede1eb8edbe67b26d9a19164f6b23 = $(`&lt;div id=&quot;html_6acede1eb8edbe67b26d9a19164f6b23&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_1620c9df2bb04820b6334180588cce3d.setContent(html_6acede1eb8edbe67b26d9a19164f6b23);
#
#
#
#         marker_84d70df0c5666e1319325474f3f26903.bindPopup(popup_1620c9df2bb04820b6334180588cce3d)
#         ;
#
#
#
#
#             var marker_14008c819f9ee920cf8c3f52ba002934 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_99feea844ef334e7d6b6850a098d0f45);
#
#
#         var popup_b7f245e403e65058d7e8f1abf20ce7b9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_df7cbc8a6f8bdcd23e09287a9b67ef9e = $(`&lt;div id=&quot;html_df7cbc8a6f8bdcd23e09287a9b67ef9e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_b7f245e403e65058d7e8f1abf20ce7b9.setContent(html_df7cbc8a6f8bdcd23e09287a9b67ef9e);
#
#
#
#         marker_14008c819f9ee920cf8c3f52ba002934.bindPopup(popup_b7f245e403e65058d7e8f1abf20ce7b9)
#         ;
#
#
#
#
#             var marker_c6d76d8b473b4d293d9ed2fe2f0d9b22 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_99feea844ef334e7d6b6850a098d0f45);
#
#
#         var popup_87a0e936808754fde77753c989483c0b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_973ce9c168ab952e1723aaa154e59fca = $(`&lt;div id=&quot;html_973ce9c168ab952e1723aaa154e59fca&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_87a0e936808754fde77753c989483c0b.setContent(html_973ce9c168ab952e1723aaa154e59fca);
#
#
#
#         marker_c6d76d8b473b4d293d9ed2fe2f0d9b22.bindPopup(popup_87a0e936808754fde77753c989483c0b)
#         ;
#
#
#
#
#             var marker_391e61ecda501ff561ffdb0221925851 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_99feea844ef334e7d6b6850a098d0f45);
#
#
#         var popup_b53f98c2d5e5d97f804b0799b8867396 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9fbd987a52786c53ecff433bc114aba6 = $(`&lt;div id=&quot;html_9fbd987a52786c53ecff433bc114aba6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_b53f98c2d5e5d97f804b0799b8867396.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_509fa756fed3d88376f40ffa2d5a9643 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_509fa756fed3d88376f40ffa2d5a9643&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_509fa756fed3d88376f40ffa2d5a9643 = L.map(
#                 &quot;map_509fa756fed3d88376f40ffa2d5a9643&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0b5d0e30fc73728de9a3176616e3ec93 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0b5d0e30fc73728de9a3176616e3ec93.addTo(map_509fa756fed3d88376f40ffa2d5a9643);
#
#
#             var feature_group_8d20d4198fe07f76c7fbe52391f18ddf = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_6aed0a98defc73fbc44ab7d7dd42a949 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_8d20d4198fe07f76c7fbe52391f18ddf);
#
#
#         var popup_e3469eec2efe408d5b3ebebe6c8ddf77 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ea6638297e8484056c5a2f0c7865eb00 = $(`&lt;div id=&quot;html_ea6638297e8484056c5a2f0c7865eb00&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_e3469eec2efe408d5b3ebebe6c8ddf77.setContent(html_ea6638297e8484056c5a2f0c7865eb00);
#
#
#
#         marker_6aed0a98defc73fbc44ab7d7dd42a949.bindPopup(popup_e3469eec2efe408d5b3ebebe6c8ddf77)
#         ;
#
#
#
#
#             var marker_9e5d268d5cf904424507fa5e8d06ca95 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_8d20d4198fe07f76c7fbe52391f18ddf);
#
#
#         var popup_1ffd333c8fbef57769c40c788ae7ae86 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d7e1cec87d3bb3ed09700db5f3cbe589 = $(`&lt;div id=&quot;html_d7e1cec87d3bb3ed09700db5f3cbe589&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_1ffd333c8fbef57769c40c788ae7ae86.setContent(html_d7e1cec87d3bb3ed09700db5f3cbe589);
#
#
#
#         marker_9e5d268d5cf904424507fa5e8d06ca95.bindPopup(popup_1ffd333c8fbef57769c40c788ae7ae86)
#         ;
#
#
#
#
#             var marker_9e58c4e2fe9c8ebd1f1c66fcdbffbb52 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_8d20d4198fe07f76c7fbe52391f18ddf);
#
#
#         var popup_a271321cb37083e77f3e23d938a7492f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4e1aa5f0ded77bacb40e5e99dc994ed7 = $(`&lt;div id=&quot;html_4e1aa5f0ded77bacb40e5e99dc994ed7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_a271321cb37083e77f3e23d938a7492f.setContent(html_4e1aa5f0ded77bacb40e5e99dc994ed7);
#
#
#
#         marker_9e58c4e2fe9c8ebd1f1c66fcdbffbb52.bindPopup(popup_a271321cb37083e77f3e23d938a7492f)
#         ;
#
#
#
#
#             var marker_f6a0fbd41d30c147206c9e09b8ac74bc = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_8d20d4198fe07f76c7fbe52391f18ddf);
#
#
#         var popup_3b08562ca73936a73d3d1201e7e907ed = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_01d6d35cd2f7c449b0a016db797d17e7 = $(`&lt;div id=&quot;html_01d6d35cd2f7c449b0a016db797d17e7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_3b08562ca73936a73d3d1201e7e907ed.setContent(html_01d6d35cd2f7c449b0a016db797d17e7);
#
#
#
#         marker_f6a0fbd41d30c147206c9e09b8ac74bc.bindPopup(popup_3b08562ca73936a73d3d1201e7e907ed)
#         ;
#
#
#
#
#             var marker_b48c0bba979d4bce33d0be43ecbac2eb = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_8d20d4198fe07f76c7fbe52391f18ddf);
#
#
#         var popup_4f5debcbe8f4355612c8e1f68ff50b4a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ab8a62c4428a8cd62e7ffc13b376c9cf {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ab8a62c4428a8cd62e7ffc13b376c9cf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ab8a62c4428a8cd62e7ffc13b376c9cf = L.map(
#                 &quot;map_ab8a62c4428a8cd62e7ffc13b376c9cf&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7b771c87ec0508e0e42323d462a2cced = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7b771c87ec0508e0e42323d462a2cced.addTo(map_ab8a62c4428a8cd62e7ffc13b376c9cf);
#
#
#             var feature_group_7c933564bc4718b4da81558fc448f1ed = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_7c933564bc4718b4da81558fc448f1ed.addTo(map_ab8a62c4428a8cd62e7ffc13b376c9cf);
#
#
#             var feature_group_sub_group_347d6f875cc9c5886afb1d8b0d7d8c1f = L.featureGroup.subGroup(
#                 feature_group_7c933564bc4718b4da81558fc448f1ed
#             );
#
#
#             var marker_c314a1d106d657837026414d580f80fd = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_347d6f875cc9c5886afb1d8b0d7d8c1f);
#
#
#         var popup_380589aaec02b977c545c005521bf7e8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_635cde4be3d6551a9cdbc273f00ca297 = $(`&lt;div id=&quot;html_635cde4be3d6551a9cdbc273f00ca297&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_380589aaec02b977c545c005521bf7e8.setContent(html_635cde4be3d6551a9cdbc273f00ca297);
#
#
#
#         marker_c314a1d106d657837026414d580f80fd.bindPopup(popup_380589aaec02b977c545c005521bf7e8)
#         ;
#
#
#
#
#             var marker_8fe0cff3b61787fd4eb96a32c5b1ff0a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_347d6f875cc9c5886afb1d8b0d7d8c1f);
#
#
#         var popup_380ff712def6570e5cf007a6bd2261c2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d24681c1ca2fbde50766cf70cac9c69e = $(`&lt;div id=&quot;html_d24681c1ca2fbde50766cf70cac9c69e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_380ff712def6570e5cf007a6bd2261c2.setContent(html_d24681c1ca2fbde50766cf70cac9c69e);
#
#
#
#         marker_8fe0cff3b61787fd4eb96a32c5b1ff0a.bindPopup(popup_380ff712def6570e5cf007a6bd2261c2)
#         ;
#
#
#
#
#             var marker_7216f24344988dd3f8eef480aec75670 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_347d6f875cc9c5886afb1d8b0d7d8c1f);
#
#
#         var popup_dd0ea35114545ba8ea205c3cdda1a3aa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_69bd54d54f304c58bd8624b5970af785 = $(`&lt;div id=&quot;html_69bd54d54f304c58bd8624b5970af785&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_dd0ea35114545ba8ea205c3cdda1a3aa.setContent(html_69bd54d54f304c58bd8624b5970af785);
#
#
#
#         marker_7216f24344988dd3f8eef480aec75670.bindPopup(popup_dd0ea35114545ba8ea205c3cdda1a3aa)
#         ;
#
#
#
#
#             var marker_797d2874c2538b9eaa100d943ec79b19 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_347d6f875cc9c5886afb1d8b0d7d8c1f);
#
#
#         var popup_30b53615f5558f455eea3381bd476c78 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_549c4cbbc740a07ce40eaf7b4d2248e1 = $(`&lt;div id=&quot;html_549c4cbbc740a07ce40eaf7b4d2248e1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_30b53615f5558f455eea3381bd476c78.setContent(html_549c4cbbc740a07ce40eaf7b4d2248e1);
#
#
#
#         marker_
