# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7e1ca254a4dface75c55ce3e07ef1e46 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7e1ca254a4dface75c55ce3e07ef1e46&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7e1ca254a4dface75c55ce3e07ef1e46 = L.map(
#                 &quot;map_7e1ca254a4dface75c55ce3e07ef1e46&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_93b9246352eaaf9820480110ae3d7271 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_93b9246352eaaf9820480110ae3d7271.addTo(map_7e1ca254a4dface75c55ce3e07ef1e46);
#
#
#             var marker_029ebb6def7a28208c4542fb76980fc1 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_7e1ca254a4dface75c55ce3e07ef1e46);
#
#
#         var popup_b8f2d67de6058b8d7fca97f4fd39c778 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_abc44e6f9311e185cd2845a100738eb1 = $(`&lt;div id=&quot;html_abc44e6f9311e185cd2845a100738eb1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_b8f2d67de6058b8d7fca97f4fd39c778.setContent(html_abc44e6f9311e185cd2845a100738eb1);
#
#
#
#         marker_029ebb6def7a28208c4542fb76980fc1.bindPopup(popup_b8f2d67de6058b8d7fca97f4fd39c778)
#         ;
#
#
#
#
#             var marker_73bde80d9bd8d81787d34eeb3de8d6cf = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_7e1ca254a4dface75c55ce3e07ef1e46);
#
#
#         var popup_2fa6988aef4eed3d06f295559b6d1ec0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7d84b614887083f385c48655746fa2a9 = $(`&lt;div id=&quot;html_7d84b614887083f385c48655746fa2a9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_2fa6988aef4eed3d06f295559b6d1ec0.setContent(html_7d84b614887083f385c48655746fa2a9);
#
#
#
#         marker_73bde80d9bd8d81787d34eeb3de8d6cf.bindPopup(popup_2fa6988aef4eed3d06f295559b6d1ec0)
#         ;
#
#
#
#
#             var marker_ea6538af1f54feae9ce86feb89ce48e9 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_7e1ca254a4dface75c55ce3e07ef1e46);
#
#
#         var popup_cea7da2b540950d040501a63b3805835 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2bd79c44b17bbf63c175e3e2abc71add = $(`&lt;div id=&quot;html_2bd79c44b17bbf63c175e3e2abc71add&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_cea7da2b540950d040501a63b3805835.setContent(html_2bd79c44b17bbf63c175e3e2abc71add);
#
#
#
#         marker_ea6538af1f54feae9ce86feb89ce48e9.bindPopup(popup_cea7da2b540950d040501a63b3805835)
#         ;
#
#
#
#
#             var marker_cf0934e9a1a9e082d8c56b4f3ad60159 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_7e1ca254a4dface75c55ce3e07ef1e46);
#
#
#         var popup_883bbb938050b1fec085ba13a954130d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_55d479ec06b45ed0993179fd309bc10e = $(`&lt;div id=&quot;html_55d479ec06b45ed0993179fd309bc10e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_883bbb938050b1fec085ba13a954130d.setContent(html_55d479ec06b45ed0993179fd309bc10e);
#
#
#
#         marker_cf0934e9a1a9e082d8c56b4f3ad60159.bindPopup(popup_883bbb938050b1fec085ba13a954130d)
#         ;
#
#
#
#
#             var marker_b311d32a7a1765bb78cdbc39d464edd0 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_7e1ca254a4dface75c55ce3e07ef1e46);
#
#
#         var popup_c133a5796387d4aabf1f86d357949708 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8d41923c633e829ce526d1edbdb47252 = $(`&lt;div id=&quot;html_8d41923c633e829ce526d1edbdb47252&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_c133a5796387d4aabf1f86d357949708.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5a1b2a11a338a692c585e3f07c7eb135 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5a1b2a11a338a692c585e3f07c7eb135&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5a1b2a11a338a692c585e3f07c7eb135 = L.map(
#                 &quot;map_5a1b2a11a338a692c585e3f07c7eb135&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cb72bbc7cb2a116f2f8293c8770a70fc = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_cb72bbc7cb2a116f2f8293c8770a70fc.addTo(map_5a1b2a11a338a692c585e3f07c7eb135);
#
#
#             var feature_group_43d412b74d8926996cf4f4e689db91ad = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_51df8e4defa23d349c0fdc1bf22d5969 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_43d412b74d8926996cf4f4e689db91ad);
#
#
#         var popup_991f87480dad423818dbc74ed3472895 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a024bb531d29105af3f72ad6a30a58c0 = $(`&lt;div id=&quot;html_a024bb531d29105af3f72ad6a30a58c0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_991f87480dad423818dbc74ed3472895.setContent(html_a024bb531d29105af3f72ad6a30a58c0);
#
#
#
#         marker_51df8e4defa23d349c0fdc1bf22d5969.bindPopup(popup_991f87480dad423818dbc74ed3472895)
#         ;
#
#
#
#
#             var marker_f022ef36045d9497eb401ce832c43127 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_43d412b74d8926996cf4f4e689db91ad);
#
#
#         var popup_4d1e275d5e8af12fe1be2e158c08c3b0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8fbcd7a2a538535ebd36d10827e12643 = $(`&lt;div id=&quot;html_8fbcd7a2a538535ebd36d10827e12643&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_4d1e275d5e8af12fe1be2e158c08c3b0.setContent(html_8fbcd7a2a538535ebd36d10827e12643);
#
#
#
#         marker_f022ef36045d9497eb401ce832c43127.bindPopup(popup_4d1e275d5e8af12fe1be2e158c08c3b0)
#         ;
#
#
#
#
#             var marker_7b759633cf17f504b74169fe7968540b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_43d412b74d8926996cf4f4e689db91ad);
#
#
#         var popup_981bf57cf57bddc519eff7f92d1272bf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_498e57ae768bdb879ca807797e463c88 = $(`&lt;div id=&quot;html_498e57ae768bdb879ca807797e463c88&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_981bf57cf57bddc519eff7f92d1272bf.setContent(html_498e57ae768bdb879ca807797e463c88);
#
#
#
#         marker_7b759633cf17f504b74169fe7968540b.bindPopup(popup_981bf57cf57bddc519eff7f92d1272bf)
#         ;
#
#
#
#
#             var marker_d42ab1d71d0a3780cf2cf74d8efd15ea = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_43d412b74d8926996cf4f4e689db91ad);
#
#
#         var popup_aef23719a3a8e4cb5048c9712636bd8f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c5c898bcef6beb54d4df012b5662fa05 = $(`&lt;div id=&quot;html_c5c898bcef6beb54d4df012b5662fa05&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_aef23719a3a8e4cb5048c9712636bd8f.setContent(html_c5c898bcef6beb54d4df012b5662fa05);
#
#
#
#         marker_d42ab1d71d0a3780cf2cf74d8efd15ea.bindPopup(popup_aef23719a3a8e4cb5048c9712636bd8f)
#         ;
#
#
#
#
#             var marker_961b5fae604aafebb5f9d8ea80cd2d52 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_43d412b74d8926996cf4f4e689db91ad);
#
#
#         var popup_25f1b9dda5cbf1c80c9fa7c85096b0fc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1b5e459e5eb80e27ba9d9b1fac3588ab {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1b5e459e5eb80e27ba9d9b1fac3588ab&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1b5e459e5eb80e27ba9d9b1fac3588ab = L.map(
#                 &quot;map_1b5e459e5eb80e27ba9d9b1fac3588ab&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c73db3239cbc3abb5394557b92c17c1b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c73db3239cbc3abb5394557b92c17c1b.addTo(map_1b5e459e5eb80e27ba9d9b1fac3588ab);
#
#
#             var feature_group_eb8a6149e7e01bbcb5ef2abb4dc16fec = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_eb8a6149e7e01bbcb5ef2abb4dc16fec.addTo(map_1b5e459e5eb80e27ba9d9b1fac3588ab);
#
#
#             var feature_group_sub_group_8b4d57a8dcc4dcf235bbec17c7e4242a = L.featureGroup.subGroup(
#                 feature_group_eb8a6149e7e01bbcb5ef2abb4dc16fec
#             );
#
#
#             var marker_07c9f717c6e74d537fa4787bec91442e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_8b4d57a8dcc4dcf235bbec17c7e4242a);
#
#
#         var popup_e4829134edfea3b08d38f92d1bc1a44a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_86fe2f17ed213efdbeef988fff041cb2 = $(`&lt;div id=&quot;html_86fe2f17ed213efdbeef988fff041cb2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_e4829134edfea3b08d38f92d1bc1a44a.setContent(html_86fe2f17ed213efdbeef988fff041cb2);
#
#
#
#         marker_07c9f717c6e74d537fa4787bec91442e.bindPopup(popup_e4829134edfea3b08d38f92d1bc1a44a)
#         ;
#
#
#
#
#             var marker_24aecdf0578f0f0ed8ac5759dc03af8a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_8b4d57a8dcc4dcf235bbec17c7e4242a);
#
#
#         var popup_f70add18a9c318e95fbaf7c4dd3aea23 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9aac09dd4560958853c8380836db5ff1 = $(`&lt;div id=&quot;html_9aac09dd4560958853c8380836db5ff1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_f70add18a9c318e95fbaf7c4dd3aea23.setContent(html_9aac09dd4560958853c8380836db5ff1);
#
#
#
#         marker_24aecdf0578f0f0ed8ac5759dc03af8a.bindPopup(popup_f70add18a9c318e95fbaf7c4dd3aea23)
#         ;
#
#
#
#
#             var marker_215b9bbb8c5d9367f96cc4014a984d89 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_8b4d57a8dcc4dcf235bbec17c7e4242a);
#
#
#         var popup_ef1cea1b8252a30d8ea4738b6da7b4cd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_275bd70a70e8b47c2f1ba7e468b6ca7a = $(`&lt;div id=&quot;html_275bd70a70e8b47c2f1ba7e468b6ca7a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_ef1cea1b8252a30d8ea4738b6da7b4cd.setContent(html_275bd70a70e8b47c2f1ba7e468b6ca7a);
#
#
#
#         marker_215b9bbb8c5d9367f96cc4014a984d89.bindPopup(popup_ef1cea1b8252a30d8ea4738b6da7b4cd)
#         ;
#
#
#
#
#             var marker_27e0e55b1286f60e430b123de7eae200 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_8b4d57a8dcc4dcf235bbec17c7e4242a);
#
#
#         var popup_89e8fe9447367c70309beee444ae2262 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e34175b0e372768fd55e0fa5678a08ed = $(`&lt;div id=&quot;html_e34175b0e372768fd55e0fa5678a08ed&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_89e8fe9447367c70309beee444ae2262.setContent(html_e34175b0e372768fd55e0fa5678a08ed);
#
#
#
#         marker_
