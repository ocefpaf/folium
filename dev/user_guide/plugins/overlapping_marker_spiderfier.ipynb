# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bf7c2d8661db66fa491e2f3a95e7542c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bf7c2d8661db66fa491e2f3a95e7542c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bf7c2d8661db66fa491e2f3a95e7542c = L.map(
#                 &quot;map_bf7c2d8661db66fa491e2f3a95e7542c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1df23087da13d42026f5ec9a68111515 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1df23087da13d42026f5ec9a68111515.addTo(map_bf7c2d8661db66fa491e2f3a95e7542c);
#
#
#             var marker_5c7eac511f6a279c882d29c627f0856b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_bf7c2d8661db66fa491e2f3a95e7542c);
#
#
#         var popup_37ea3a7440c87c18884a1304f529f278 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_08c7f224e7c85369b9af0c3f2b5af010 = $(`&lt;div id=&quot;html_08c7f224e7c85369b9af0c3f2b5af010&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_37ea3a7440c87c18884a1304f529f278.setContent(html_08c7f224e7c85369b9af0c3f2b5af010);
#
#
#
#         marker_5c7eac511f6a279c882d29c627f0856b.bindPopup(popup_37ea3a7440c87c18884a1304f529f278)
#         ;
#
#
#
#
#             var marker_9c80bdf2b652b78fe1cf84a2175796a6 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_bf7c2d8661db66fa491e2f3a95e7542c);
#
#
#         var popup_acdfd47eeb3cd4980c9e882990af409a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fc1253fadbd3172e6fda61f3af2449ed = $(`&lt;div id=&quot;html_fc1253fadbd3172e6fda61f3af2449ed&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_acdfd47eeb3cd4980c9e882990af409a.setContent(html_fc1253fadbd3172e6fda61f3af2449ed);
#
#
#
#         marker_9c80bdf2b652b78fe1cf84a2175796a6.bindPopup(popup_acdfd47eeb3cd4980c9e882990af409a)
#         ;
#
#
#
#
#             var marker_3056e8822eafbf464fbf483b72117e27 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_bf7c2d8661db66fa491e2f3a95e7542c);
#
#
#         var popup_4d704b71b4c19a8047f4a78df2bd2939 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5aa51713f98dfd960b05320bef3c1d9d = $(`&lt;div id=&quot;html_5aa51713f98dfd960b05320bef3c1d9d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_4d704b71b4c19a8047f4a78df2bd2939.setContent(html_5aa51713f98dfd960b05320bef3c1d9d);
#
#
#
#         marker_3056e8822eafbf464fbf483b72117e27.bindPopup(popup_4d704b71b4c19a8047f4a78df2bd2939)
#         ;
#
#
#
#
#             var marker_9593d780be0d67880e2ff5a26b233de8 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_bf7c2d8661db66fa491e2f3a95e7542c);
#
#
#         var popup_882e561f2e1e9d52eaea7f3a9b735e2a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7af1812bdc53624e8ffb9b4327f65b19 = $(`&lt;div id=&quot;html_7af1812bdc53624e8ffb9b4327f65b19&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_882e561f2e1e9d52eaea7f3a9b735e2a.setContent(html_7af1812bdc53624e8ffb9b4327f65b19);
#
#
#
#         marker_9593d780be0d67880e2ff5a26b233de8.bindPopup(popup_882e561f2e1e9d52eaea7f3a9b735e2a)
#         ;
#
#
#
#
#             var marker_285920307bc0b2f054d6ba65a688a8ad = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_bf7c2d8661db66fa491e2f3a95e7542c);
#
#
#         var popup_49601e15d9b9d5d8192c64e2882e9120 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b807c9dd907adc0d753772f226dbb536 = $(`&lt;div id=&quot;html_b807c9dd907adc0d753772f226dbb536&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_49601e15d9b9d5d8192c64e2882e9120.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bce24762a76bfd042e9f72a179aa5d1a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bce24762a76bfd042e9f72a179aa5d1a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bce24762a76bfd042e9f72a179aa5d1a = L.map(
#                 &quot;map_bce24762a76bfd042e9f72a179aa5d1a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a8b3b317b1363e27ebce392568f0997f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a8b3b317b1363e27ebce392568f0997f.addTo(map_bce24762a76bfd042e9f72a179aa5d1a);
#
#
#             var feature_group_5a36805c3e257ad15e417d2e53470388 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_403248322d0b29967bf834aa70eb3393 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_5a36805c3e257ad15e417d2e53470388);
#
#
#         var popup_047abad653ba3b90a87d86c2ced788a7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0c868945a9ac105f63806b925ec5c17e = $(`&lt;div id=&quot;html_0c868945a9ac105f63806b925ec5c17e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_047abad653ba3b90a87d86c2ced788a7.setContent(html_0c868945a9ac105f63806b925ec5c17e);
#
#
#
#         marker_403248322d0b29967bf834aa70eb3393.bindPopup(popup_047abad653ba3b90a87d86c2ced788a7)
#         ;
#
#
#
#
#             var marker_9a47f2e369183609e5a0e3bd920b0107 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_5a36805c3e257ad15e417d2e53470388);
#
#
#         var popup_0d1c3e72c633ec3cdd085397ef4fd678 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1fc30caec2d14b8b14f7066f1f42d528 = $(`&lt;div id=&quot;html_1fc30caec2d14b8b14f7066f1f42d528&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_0d1c3e72c633ec3cdd085397ef4fd678.setContent(html_1fc30caec2d14b8b14f7066f1f42d528);
#
#
#
#         marker_9a47f2e369183609e5a0e3bd920b0107.bindPopup(popup_0d1c3e72c633ec3cdd085397ef4fd678)
#         ;
#
#
#
#
#             var marker_7f1f767c96622c63861f6ee83f73bb7f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_5a36805c3e257ad15e417d2e53470388);
#
#
#         var popup_2f1b4ae95220008e20d742cc14523f43 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a30eea8355877e9355b65e3dd86fbb48 = $(`&lt;div id=&quot;html_a30eea8355877e9355b65e3dd86fbb48&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_2f1b4ae95220008e20d742cc14523f43.setContent(html_a30eea8355877e9355b65e3dd86fbb48);
#
#
#
#         marker_7f1f767c96622c63861f6ee83f73bb7f.bindPopup(popup_2f1b4ae95220008e20d742cc14523f43)
#         ;
#
#
#
#
#             var marker_90920975cd0e8a061af71f1063c984d7 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_5a36805c3e257ad15e417d2e53470388);
#
#
#         var popup_33aa7661cbfdf0cd47a0aab7b7128750 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b3c758cf7e448034d7931bec63ceb4ed = $(`&lt;div id=&quot;html_b3c758cf7e448034d7931bec63ceb4ed&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_33aa7661cbfdf0cd47a0aab7b7128750.setContent(html_b3c758cf7e448034d7931bec63ceb4ed);
#
#
#
#         marker_90920975cd0e8a061af71f1063c984d7.bindPopup(popup_33aa7661cbfdf0cd47a0aab7b7128750)
#         ;
#
#
#
#
#             var marker_97746bb732853343ad26f6c55d5da470 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_5a36805c3e257ad15e417d2e53470388);
#
#
#         var popup_e0800dd3ca93d983823e98798984f0b2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b456345989504585297fb392dd82a636 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b456345989504585297fb392dd82a636&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b456345989504585297fb392dd82a636 = L.map(
#                 &quot;map_b456345989504585297fb392dd82a636&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_eb3d7028b5abd9699e462d051b9ba004 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_eb3d7028b5abd9699e462d051b9ba004.addTo(map_b456345989504585297fb392dd82a636);
#
#
#             var feature_group_c9fa4775c06d8c0895924d397008267d = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_c9fa4775c06d8c0895924d397008267d.addTo(map_b456345989504585297fb392dd82a636);
#
#
#             var feature_group_sub_group_a4349263240cd536fee580f2066af117 = L.featureGroup.subGroup(
#                 feature_group_c9fa4775c06d8c0895924d397008267d
#             );
#
#
#             var marker_492d9097c2e460f8650916a612b8b3b3 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_a4349263240cd536fee580f2066af117);
#
#
#         var popup_3a7aef99b091ca6136eeeb28591f21c3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f961cdfd1cefb8bc46913084c984f44d = $(`&lt;div id=&quot;html_f961cdfd1cefb8bc46913084c984f44d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_3a7aef99b091ca6136eeeb28591f21c3.setContent(html_f961cdfd1cefb8bc46913084c984f44d);
#
#
#
#         marker_492d9097c2e460f8650916a612b8b3b3.bindPopup(popup_3a7aef99b091ca6136eeeb28591f21c3)
#         ;
#
#
#
#
#             var marker_40144864876109bab9dac11faf235e41 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_a4349263240cd536fee580f2066af117);
#
#
#         var popup_c4ea1cadf39a8d8422caaa30f6cfcf12 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_319ce6c758118c0a4acd3f70dd2239cf = $(`&lt;div id=&quot;html_319ce6c758118c0a4acd3f70dd2239cf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_c4ea1cadf39a8d8422caaa30f6cfcf12.setContent(html_319ce6c758118c0a4acd3f70dd2239cf);
#
#
#
#         marker_40144864876109bab9dac11faf235e41.bindPopup(popup_c4ea1cadf39a8d8422caaa30f6cfcf12)
#         ;
#
#
#
#
#             var marker_9c748adee9c4a8db9260da818cd1635f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_a4349263240cd536fee580f2066af117);
#
#
#         var popup_baadf3a82c4a5331ef3274740685ee88 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0b0da036cf9c51c64021d756d05c2f15 = $(`&lt;div id=&quot;html_0b0da036cf9c51c64021d756d05c2f15&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_baadf3a82c4a5331ef3274740685ee88.setContent(html_0b0da036cf9c51c64021d756d05c2f15);
#
#
#
#         marker_9c748adee9c4a8db9260da818cd1635f.bindPopup(popup_baadf3a82c4a5331ef3274740685ee88)
#         ;
#
#
#
#
#             var marker_e6b294825e3f28f0995211f4cceae125 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_a4349263240cd536fee580f2066af117);
#
#
#         var popup_7dfec7313c003a1e81b9b760d173a12f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3df9d1569d0c4bff70a60a549e1528d2 = $(`&lt;div id=&quot;html_3df9d1569d0c4bff70a60a549e1528d2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_7dfec7313c003a1e81b9b760d173a12f.setContent(html_3df9d1569d0c4bff70a60a549e1528d2);
#
#
#
#         marker_
