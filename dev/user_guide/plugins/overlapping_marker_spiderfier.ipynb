# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5cc0af274be3a9f56b2f010bda8f0452 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5cc0af274be3a9f56b2f010bda8f0452&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5cc0af274be3a9f56b2f010bda8f0452 = L.map(
#                 &quot;map_5cc0af274be3a9f56b2f010bda8f0452&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8f8651d50ba23698394ff5fb8c8e0628 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8f8651d50ba23698394ff5fb8c8e0628.addTo(map_5cc0af274be3a9f56b2f010bda8f0452);
#
#
#             var marker_1d8d219d00e48b646eb11f10a93fbd8a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_5cc0af274be3a9f56b2f010bda8f0452);
#
#
#         var popup_b979d18dc4c5708e111c88b3cfad4317 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bf33d0f8ccb73e873a6444a5e6ab4eaf = $(`&lt;div id=&quot;html_bf33d0f8ccb73e873a6444a5e6ab4eaf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_b979d18dc4c5708e111c88b3cfad4317.setContent(html_bf33d0f8ccb73e873a6444a5e6ab4eaf);
#
#
#
#         marker_1d8d219d00e48b646eb11f10a93fbd8a.bindPopup(popup_b979d18dc4c5708e111c88b3cfad4317)
#         ;
#
#
#
#
#             var marker_b3e061ef5255a443e61226a92d58d020 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_5cc0af274be3a9f56b2f010bda8f0452);
#
#
#         var popup_595814f6afa23d4720babce8fbb14c53 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0cf9598c2e49735ec5582698ad7f00fb = $(`&lt;div id=&quot;html_0cf9598c2e49735ec5582698ad7f00fb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_595814f6afa23d4720babce8fbb14c53.setContent(html_0cf9598c2e49735ec5582698ad7f00fb);
#
#
#
#         marker_b3e061ef5255a443e61226a92d58d020.bindPopup(popup_595814f6afa23d4720babce8fbb14c53)
#         ;
#
#
#
#
#             var marker_aca484b37a050619e7122a44360ad0d9 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_5cc0af274be3a9f56b2f010bda8f0452);
#
#
#         var popup_af3afda85fd59163cefcf2ca71acae7d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1b9c8ecaa21d8e83673e768207e3ebd8 = $(`&lt;div id=&quot;html_1b9c8ecaa21d8e83673e768207e3ebd8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_af3afda85fd59163cefcf2ca71acae7d.setContent(html_1b9c8ecaa21d8e83673e768207e3ebd8);
#
#
#
#         marker_aca484b37a050619e7122a44360ad0d9.bindPopup(popup_af3afda85fd59163cefcf2ca71acae7d)
#         ;
#
#
#
#
#             var marker_0f376973687ad1bb28c73e68d6a4e948 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_5cc0af274be3a9f56b2f010bda8f0452);
#
#
#         var popup_e4b2c885d38d29e54118f56223845aae = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2aa4606738a2f3ff44069c7fa1857a73 = $(`&lt;div id=&quot;html_2aa4606738a2f3ff44069c7fa1857a73&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_e4b2c885d38d29e54118f56223845aae.setContent(html_2aa4606738a2f3ff44069c7fa1857a73);
#
#
#
#         marker_0f376973687ad1bb28c73e68d6a4e948.bindPopup(popup_e4b2c885d38d29e54118f56223845aae)
#         ;
#
#
#
#
#             var marker_0730bcb5d5110db491d109c3af5bedce = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_5cc0af274be3a9f56b2f010bda8f0452);
#
#
#         var popup_eeb09064f51c9342eb1c4be8dcb0f3d2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9736f8e40e4f96eae0f1996e84b423f0 = $(`&lt;div id=&quot;html_9736f8e40e4f96eae0f1996e84b423f0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_eeb09064f51c9342eb1c4be8dcb0f3d2.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4d2c6c5397ee70a3283a039b41fece4c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4d2c6c5397ee70a3283a039b41fece4c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4d2c6c5397ee70a3283a039b41fece4c = L.map(
#                 &quot;map_4d2c6c5397ee70a3283a039b41fece4c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2cc3d3b3224c8b4f106069984e8436ca = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2cc3d3b3224c8b4f106069984e8436ca.addTo(map_4d2c6c5397ee70a3283a039b41fece4c);
#
#
#             var feature_group_a73926c63ef98e29004c951f5864f2ae = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_7f97a8ac825120761d452c859dbc153e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_a73926c63ef98e29004c951f5864f2ae);
#
#
#         var popup_b4ef58dbef9a167f03c1020d8a11de14 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b5036d885ca6449c8351633e8dc593aa = $(`&lt;div id=&quot;html_b5036d885ca6449c8351633e8dc593aa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_b4ef58dbef9a167f03c1020d8a11de14.setContent(html_b5036d885ca6449c8351633e8dc593aa);
#
#
#
#         marker_7f97a8ac825120761d452c859dbc153e.bindPopup(popup_b4ef58dbef9a167f03c1020d8a11de14)
#         ;
#
#
#
#
#             var marker_2315c86751e19630112ec5262d8c0fdd = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_a73926c63ef98e29004c951f5864f2ae);
#
#
#         var popup_00854e6bf77ce6f5c010ef23627ff32b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_976b26285f6445ee2efdcd6a1beace32 = $(`&lt;div id=&quot;html_976b26285f6445ee2efdcd6a1beace32&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_00854e6bf77ce6f5c010ef23627ff32b.setContent(html_976b26285f6445ee2efdcd6a1beace32);
#
#
#
#         marker_2315c86751e19630112ec5262d8c0fdd.bindPopup(popup_00854e6bf77ce6f5c010ef23627ff32b)
#         ;
#
#
#
#
#             var marker_4f1383d30dcde49594cc0bcfb0cba338 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_a73926c63ef98e29004c951f5864f2ae);
#
#
#         var popup_ab180431339a344e13ad7fcd5047cb07 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d69a266ddabd29505c1c72ab44d48fd8 = $(`&lt;div id=&quot;html_d69a266ddabd29505c1c72ab44d48fd8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_ab180431339a344e13ad7fcd5047cb07.setContent(html_d69a266ddabd29505c1c72ab44d48fd8);
#
#
#
#         marker_4f1383d30dcde49594cc0bcfb0cba338.bindPopup(popup_ab180431339a344e13ad7fcd5047cb07)
#         ;
#
#
#
#
#             var marker_11d87cc20d596383a773bdd464f01b73 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_a73926c63ef98e29004c951f5864f2ae);
#
#
#         var popup_a977109b482728be7e5de83a4d28777e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_41cb12ffe34edb1fe4391e74254576d9 = $(`&lt;div id=&quot;html_41cb12ffe34edb1fe4391e74254576d9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_a977109b482728be7e5de83a4d28777e.setContent(html_41cb12ffe34edb1fe4391e74254576d9);
#
#
#
#         marker_11d87cc20d596383a773bdd464f01b73.bindPopup(popup_a977109b482728be7e5de83a4d28777e)
#         ;
#
#
#
#
#             var marker_bae8f172421608a28af37721accc8c91 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_a73926c63ef98e29004c951f5864f2ae);
#
#
#         var popup_f5dab620d5fb8d800faf105fc1e76870 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_56e4ce51d209c21888fb14b095086fd5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_56e4ce51d209c21888fb14b095086fd5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_56e4ce51d209c21888fb14b095086fd5 = L.map(
#                 &quot;map_56e4ce51d209c21888fb14b095086fd5&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_070fcc5d0e3b5f6be42ba14c9f9ffca5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_070fcc5d0e3b5f6be42ba14c9f9ffca5.addTo(map_56e4ce51d209c21888fb14b095086fd5);
#
#
#             var feature_group_496adc3d69ea301876be31d46c949e6d = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_496adc3d69ea301876be31d46c949e6d.addTo(map_56e4ce51d209c21888fb14b095086fd5);
#
#
#             var feature_group_sub_group_bd09d34b1cd8b4d065cafe1402ef8ea1 = L.featureGroup.subGroup(
#                 feature_group_496adc3d69ea301876be31d46c949e6d
#             );
#
#
#             var marker_9f1322aca9f5c9724b130ac25e4939b3 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_bd09d34b1cd8b4d065cafe1402ef8ea1);
#
#
#         var popup_516b0938572dd740982515dcfbf110c2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8ac9163f3d4bf986de930999f13fe0b0 = $(`&lt;div id=&quot;html_8ac9163f3d4bf986de930999f13fe0b0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_516b0938572dd740982515dcfbf110c2.setContent(html_8ac9163f3d4bf986de930999f13fe0b0);
#
#
#
#         marker_9f1322aca9f5c9724b130ac25e4939b3.bindPopup(popup_516b0938572dd740982515dcfbf110c2)
#         ;
#
#
#
#
#             var marker_269025bf664d9c1c848f1d11914ee7b9 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_bd09d34b1cd8b4d065cafe1402ef8ea1);
#
#
#         var popup_4247878ef73824c155e87183bb75f303 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8c97738ea9417a70f687d02781354d73 = $(`&lt;div id=&quot;html_8c97738ea9417a70f687d02781354d73&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_4247878ef73824c155e87183bb75f303.setContent(html_8c97738ea9417a70f687d02781354d73);
#
#
#
#         marker_269025bf664d9c1c848f1d11914ee7b9.bindPopup(popup_4247878ef73824c155e87183bb75f303)
#         ;
#
#
#
#
#             var marker_7c38c37608fd8c063d2b1d6aa42802f6 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_bd09d34b1cd8b4d065cafe1402ef8ea1);
#
#
#         var popup_4982aedbe12abbf34446e6e427ff36d2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b5af51f12b9b5dcb3f1d0434b64200b5 = $(`&lt;div id=&quot;html_b5af51f12b9b5dcb3f1d0434b64200b5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_4982aedbe12abbf34446e6e427ff36d2.setContent(html_b5af51f12b9b5dcb3f1d0434b64200b5);
#
#
#
#         marker_7c38c37608fd8c063d2b1d6aa42802f6.bindPopup(popup_4982aedbe12abbf34446e6e427ff36d2)
#         ;
#
#
#
#
#             var marker_2bd6fe28f103fd1b8ce62b3f4f87c2d8 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_bd09d34b1cd8b4d065cafe1402ef8ea1);
#
#
#         var popup_a0edc3a71e2505869190ded536b0f47f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ad6e78b5e5720a83d7ae5c723a9f6ec3 = $(`&lt;div id=&quot;html_ad6e78b5e5720a83d7ae5c723a9f6ec3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_a0edc3a71e2505869190ded536b0f47f.setContent(html_ad6e78b5e5720a83d7ae5c723a9f6ec3);
#
#
#
#         marker_
