# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7526b870eb88a4fef2617b904c5d823b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7526b870eb88a4fef2617b904c5d823b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7526b870eb88a4fef2617b904c5d823b = L.map(
#                 &quot;map_7526b870eb88a4fef2617b904c5d823b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7495afecd6eaa6bb163a97c15c835dd3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7495afecd6eaa6bb163a97c15c835dd3.addTo(map_7526b870eb88a4fef2617b904c5d823b);
#
#
#             var marker_37013bc09c0cd2dfb513e3de49202658 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_7526b870eb88a4fef2617b904c5d823b);
#
#
#         var popup_a72051af13144c3725d9a9d74c8cd8e0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ffbf3918624263edde6c67168eab0ab6 = $(`&lt;div id=&quot;html_ffbf3918624263edde6c67168eab0ab6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_a72051af13144c3725d9a9d74c8cd8e0.setContent(html_ffbf3918624263edde6c67168eab0ab6);
#
#
#
#         marker_37013bc09c0cd2dfb513e3de49202658.bindPopup(popup_a72051af13144c3725d9a9d74c8cd8e0)
#         ;
#
#
#
#
#             var marker_a25edce8ae25d6e3627aea7b0d8c8cab = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_7526b870eb88a4fef2617b904c5d823b);
#
#
#         var popup_5b2b5266efbc80e2b2aa88d20c3cd923 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_166d9b92c6c3804fd19031a699aa2078 = $(`&lt;div id=&quot;html_166d9b92c6c3804fd19031a699aa2078&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_5b2b5266efbc80e2b2aa88d20c3cd923.setContent(html_166d9b92c6c3804fd19031a699aa2078);
#
#
#
#         marker_a25edce8ae25d6e3627aea7b0d8c8cab.bindPopup(popup_5b2b5266efbc80e2b2aa88d20c3cd923)
#         ;
#
#
#
#
#             var marker_12860efad9603ffa1c8d632718486cde = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_7526b870eb88a4fef2617b904c5d823b);
#
#
#         var popup_cdd858ec75ab11fe21bb7d14a2ae861a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_16f4ddc04dee55fff01d4cbb8156aba0 = $(`&lt;div id=&quot;html_16f4ddc04dee55fff01d4cbb8156aba0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_cdd858ec75ab11fe21bb7d14a2ae861a.setContent(html_16f4ddc04dee55fff01d4cbb8156aba0);
#
#
#
#         marker_12860efad9603ffa1c8d632718486cde.bindPopup(popup_cdd858ec75ab11fe21bb7d14a2ae861a)
#         ;
#
#
#
#
#             var marker_c4d79e82bbc04a69c926c54736e5c166 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_7526b870eb88a4fef2617b904c5d823b);
#
#
#         var popup_9a1ecc7be15c6462175e3a6feffb59b7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e43b9627d4395667f824120d0fbd6257 = $(`&lt;div id=&quot;html_e43b9627d4395667f824120d0fbd6257&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_9a1ecc7be15c6462175e3a6feffb59b7.setContent(html_e43b9627d4395667f824120d0fbd6257);
#
#
#
#         marker_c4d79e82bbc04a69c926c54736e5c166.bindPopup(popup_9a1ecc7be15c6462175e3a6feffb59b7)
#         ;
#
#
#
#
#             var marker_71c0d33fbcc004484df6a8cb4dd10df3 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_7526b870eb88a4fef2617b904c5d823b);
#
#
#         var popup_67c39a4d9c00064559d9c6edba627be1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5784d75604430e1c43c85c2d77e2a36d = $(`&lt;div id=&quot;html_5784d75604430e1c43c85c2d77e2a36d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_67c39a4d9c00064559d9c6edba627be1.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_44a92578bdb6ce555ab97dc45a7316e8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_44a92578bdb6ce555ab97dc45a7316e8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_44a92578bdb6ce555ab97dc45a7316e8 = L.map(
#                 &quot;map_44a92578bdb6ce555ab97dc45a7316e8&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_06f340f45b23d091363fe97862baa12e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_06f340f45b23d091363fe97862baa12e.addTo(map_44a92578bdb6ce555ab97dc45a7316e8);
#
#
#             var feature_group_2e09a6920a66f763b755a63987b45b10 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_1f6d9735e829dd1bc6daf502d7d4265a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_2e09a6920a66f763b755a63987b45b10);
#
#
#         var popup_1f03d9a9b7d492366837f6ea2a52616f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bb2e9b193ec141c58e65792613298a46 = $(`&lt;div id=&quot;html_bb2e9b193ec141c58e65792613298a46&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_1f03d9a9b7d492366837f6ea2a52616f.setContent(html_bb2e9b193ec141c58e65792613298a46);
#
#
#
#         marker_1f6d9735e829dd1bc6daf502d7d4265a.bindPopup(popup_1f03d9a9b7d492366837f6ea2a52616f)
#         ;
#
#
#
#
#             var marker_dbccfeb3d23c2cd72a67087f375c71c1 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_2e09a6920a66f763b755a63987b45b10);
#
#
#         var popup_8f864e17d6464acb7999f2a367dffc0e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a4642d0504451696b0371819f99ffab8 = $(`&lt;div id=&quot;html_a4642d0504451696b0371819f99ffab8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_8f864e17d6464acb7999f2a367dffc0e.setContent(html_a4642d0504451696b0371819f99ffab8);
#
#
#
#         marker_dbccfeb3d23c2cd72a67087f375c71c1.bindPopup(popup_8f864e17d6464acb7999f2a367dffc0e)
#         ;
#
#
#
#
#             var marker_5ce65d69520b34f318ae6d104635a2a8 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_2e09a6920a66f763b755a63987b45b10);
#
#
#         var popup_7277ba22a4954dfb3643d08c614afed8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ee18babc3ded31f4c458004223a99c13 = $(`&lt;div id=&quot;html_ee18babc3ded31f4c458004223a99c13&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_7277ba22a4954dfb3643d08c614afed8.setContent(html_ee18babc3ded31f4c458004223a99c13);
#
#
#
#         marker_5ce65d69520b34f318ae6d104635a2a8.bindPopup(popup_7277ba22a4954dfb3643d08c614afed8)
#         ;
#
#
#
#
#             var marker_984b494bb442ebda3bcf9818afc4b031 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_2e09a6920a66f763b755a63987b45b10);
#
#
#         var popup_7b59904d387b14a56451773519311956 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_baf5670784ba886fa2a194e32e5bd7f9 = $(`&lt;div id=&quot;html_baf5670784ba886fa2a194e32e5bd7f9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_7b59904d387b14a56451773519311956.setContent(html_baf5670784ba886fa2a194e32e5bd7f9);
#
#
#
#         marker_984b494bb442ebda3bcf9818afc4b031.bindPopup(popup_7b59904d387b14a56451773519311956)
#         ;
#
#
#
#
#             var marker_c876031c67467449c298d53158096d1a = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_2e09a6920a66f763b755a63987b45b10);
#
#
#         var popup_04ed307f8cb2ea18b6286070bba5fd65 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4692442173484e263d12f171e9cff945 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4692442173484e263d12f171e9cff945&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4692442173484e263d12f171e9cff945 = L.map(
#                 &quot;map_4692442173484e263d12f171e9cff945&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_78797aacdfd5b946315264d9ddb3d8aa = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_78797aacdfd5b946315264d9ddb3d8aa.addTo(map_4692442173484e263d12f171e9cff945);
#
#
#             var feature_group_420956dda01fcf0a4c06e012e08ab555 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_420956dda01fcf0a4c06e012e08ab555.addTo(map_4692442173484e263d12f171e9cff945);
#
#
#             var feature_group_sub_group_fc7c69d3c5fdf92ea1c0ee8d35fc1edb = L.featureGroup.subGroup(
#                 feature_group_420956dda01fcf0a4c06e012e08ab555
#             );
#
#
#             var marker_79bcea2b811db8b85aa9bd397f19bfaf = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_fc7c69d3c5fdf92ea1c0ee8d35fc1edb);
#
#
#         var popup_678bd955df2119c97e9601a8719472c2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e82b199125318d9771e7767ac502f5a9 = $(`&lt;div id=&quot;html_e82b199125318d9771e7767ac502f5a9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_678bd955df2119c97e9601a8719472c2.setContent(html_e82b199125318d9771e7767ac502f5a9);
#
#
#
#         marker_79bcea2b811db8b85aa9bd397f19bfaf.bindPopup(popup_678bd955df2119c97e9601a8719472c2)
#         ;
#
#
#
#
#             var marker_dab8f7ce801a24619a08b5583fcc9b75 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_fc7c69d3c5fdf92ea1c0ee8d35fc1edb);
#
#
#         var popup_ce6803c2ee7e9d408316df182131239c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e74ee1eb0ef8bd5a08f8de7c4821c55e = $(`&lt;div id=&quot;html_e74ee1eb0ef8bd5a08f8de7c4821c55e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_ce6803c2ee7e9d408316df182131239c.setContent(html_e74ee1eb0ef8bd5a08f8de7c4821c55e);
#
#
#
#         marker_dab8f7ce801a24619a08b5583fcc9b75.bindPopup(popup_ce6803c2ee7e9d408316df182131239c)
#         ;
#
#
#
#
#             var marker_29165e72ea1c1fcc0daad466a872214a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_fc7c69d3c5fdf92ea1c0ee8d35fc1edb);
#
#
#         var popup_9cb02b5f45d565aba32a60675ffc0660 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4f96440c679ee9c879f4a4a0511d0e29 = $(`&lt;div id=&quot;html_4f96440c679ee9c879f4a4a0511d0e29&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_9cb02b5f45d565aba32a60675ffc0660.setContent(html_4f96440c679ee9c879f4a4a0511d0e29);
#
#
#
#         marker_29165e72ea1c1fcc0daad466a872214a.bindPopup(popup_9cb02b5f45d565aba32a60675ffc0660)
#         ;
#
#
#
#
#             var marker_a8999514866c08d7bef8f043586476bb = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_fc7c69d3c5fdf92ea1c0ee8d35fc1edb);
#
#
#         var popup_28f42df1b0c81648889cb7d9af0cad34 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e9ff2d25f62b2a53fb2abfabd46ba429 = $(`&lt;div id=&quot;html_e9ff2d25f62b2a53fb2abfabd46ba429&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_28f42df1b0c81648889cb7d9af0cad34.setContent(html_e9ff2d25f62b2a53fb2abfabd46ba429);
#
#
#
#         marker_
