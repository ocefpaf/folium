# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_72359ba80db9bf440fadb94d7a22b1ef {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_72359ba80db9bf440fadb94d7a22b1ef&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_72359ba80db9bf440fadb94d7a22b1ef = L.map(
#                 &quot;map_72359ba80db9bf440fadb94d7a22b1ef&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_641429f4efe8f87a3e5a01c0b4686ecf = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_641429f4efe8f87a3e5a01c0b4686ecf.addTo(map_72359ba80db9bf440fadb94d7a22b1ef);
#
#
#             var marker_6302c0df4d7e77c4dd8e3321a715060e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_72359ba80db9bf440fadb94d7a22b1ef);
#
#
#         var popup_02ae2fb11e95136949bb7b051adb819e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ae14ac23bebf11b4a841425190022948 = $(`&lt;div id=&quot;html_ae14ac23bebf11b4a841425190022948&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_02ae2fb11e95136949bb7b051adb819e.setContent(html_ae14ac23bebf11b4a841425190022948);
#
#
#
#         marker_6302c0df4d7e77c4dd8e3321a715060e.bindPopup(popup_02ae2fb11e95136949bb7b051adb819e)
#         ;
#
#
#
#
#             var marker_b32f6682ede00423ad29060be0fa34e1 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_72359ba80db9bf440fadb94d7a22b1ef);
#
#
#         var popup_8cda7233b70e9183946d9d9087617e98 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ecce24da2204681f70392ae460f72a10 = $(`&lt;div id=&quot;html_ecce24da2204681f70392ae460f72a10&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_8cda7233b70e9183946d9d9087617e98.setContent(html_ecce24da2204681f70392ae460f72a10);
#
#
#
#         marker_b32f6682ede00423ad29060be0fa34e1.bindPopup(popup_8cda7233b70e9183946d9d9087617e98)
#         ;
#
#
#
#
#             var marker_0b99cf71fac80a72680debca7532ee54 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_72359ba80db9bf440fadb94d7a22b1ef);
#
#
#         var popup_35df21b2a1d47486e3f183cf8548f5a8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_eef52b583b274cf80785d76b5b780166 = $(`&lt;div id=&quot;html_eef52b583b274cf80785d76b5b780166&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_35df21b2a1d47486e3f183cf8548f5a8.setContent(html_eef52b583b274cf80785d76b5b780166);
#
#
#
#         marker_0b99cf71fac80a72680debca7532ee54.bindPopup(popup_35df21b2a1d47486e3f183cf8548f5a8)
#         ;
#
#
#
#
#             var marker_dcc707b7978ed7e03696253ab2cf90fd = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_72359ba80db9bf440fadb94d7a22b1ef);
#
#
#         var popup_9fda62fe6661a732aa70acc735587c52 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3b0db2e90a7d8cda4c1ad0bd5eafc32c = $(`&lt;div id=&quot;html_3b0db2e90a7d8cda4c1ad0bd5eafc32c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_9fda62fe6661a732aa70acc735587c52.setContent(html_3b0db2e90a7d8cda4c1ad0bd5eafc32c);
#
#
#
#         marker_dcc707b7978ed7e03696253ab2cf90fd.bindPopup(popup_9fda62fe6661a732aa70acc735587c52)
#         ;
#
#
#
#
#             var marker_8d920159bafe00f09b936b73415705a7 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_72359ba80db9bf440fadb94d7a22b1ef);
#
#
#         var popup_26dc4d215084adc71835d658c0ca69bc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7b204bfb52248b52d6fb53b059400fdd = $(`&lt;div id=&quot;html_7b204bfb52248b52d6fb53b059400fdd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_26dc4d215084adc71835d658c0ca69bc.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b3956c4de74c0f897753a7e56a2b9980 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b3956c4de74c0f897753a7e56a2b9980&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b3956c4de74c0f897753a7e56a2b9980 = L.map(
#                 &quot;map_b3956c4de74c0f897753a7e56a2b9980&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_00beec8d06bd0f59ca526e3db28244fd = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_00beec8d06bd0f59ca526e3db28244fd.addTo(map_b3956c4de74c0f897753a7e56a2b9980);
#
#
#             var feature_group_9191147c5e0cc6977d3ccf181616e8a3 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_14c9173af73e879a6c22f12d838d3284 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_9191147c5e0cc6977d3ccf181616e8a3);
#
#
#         var popup_c27cff38eed57a8fdd1d4bde6cf74ddf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e9bd908fbfce8dcb82b8a8efdb2a7e6d = $(`&lt;div id=&quot;html_e9bd908fbfce8dcb82b8a8efdb2a7e6d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_c27cff38eed57a8fdd1d4bde6cf74ddf.setContent(html_e9bd908fbfce8dcb82b8a8efdb2a7e6d);
#
#
#
#         marker_14c9173af73e879a6c22f12d838d3284.bindPopup(popup_c27cff38eed57a8fdd1d4bde6cf74ddf)
#         ;
#
#
#
#
#             var marker_001334a7c3d06e0793dcef0892725db6 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_9191147c5e0cc6977d3ccf181616e8a3);
#
#
#         var popup_1cbc858d2373410bd3ea8387870ad8b3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_960841e02d82a134b2d98e7ba849bb6a = $(`&lt;div id=&quot;html_960841e02d82a134b2d98e7ba849bb6a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_1cbc858d2373410bd3ea8387870ad8b3.setContent(html_960841e02d82a134b2d98e7ba849bb6a);
#
#
#
#         marker_001334a7c3d06e0793dcef0892725db6.bindPopup(popup_1cbc858d2373410bd3ea8387870ad8b3)
#         ;
#
#
#
#
#             var marker_f9e00c34baccdf26478157ac2640b37c = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_9191147c5e0cc6977d3ccf181616e8a3);
#
#
#         var popup_4f014a1dd1a43779b3a6c4ee3d88f11d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b17656a1231748515de92c8d238e1d79 = $(`&lt;div id=&quot;html_b17656a1231748515de92c8d238e1d79&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_4f014a1dd1a43779b3a6c4ee3d88f11d.setContent(html_b17656a1231748515de92c8d238e1d79);
#
#
#
#         marker_f9e00c34baccdf26478157ac2640b37c.bindPopup(popup_4f014a1dd1a43779b3a6c4ee3d88f11d)
#         ;
#
#
#
#
#             var marker_fdc696f0ea1b8921ee8c7343c75dc02a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_9191147c5e0cc6977d3ccf181616e8a3);
#
#
#         var popup_4c6768baa4d5bc55b534b914a3ef08fb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f463ea43ff934f0cb2f2249e47ec936e = $(`&lt;div id=&quot;html_f463ea43ff934f0cb2f2249e47ec936e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_4c6768baa4d5bc55b534b914a3ef08fb.setContent(html_f463ea43ff934f0cb2f2249e47ec936e);
#
#
#
#         marker_fdc696f0ea1b8921ee8c7343c75dc02a.bindPopup(popup_4c6768baa4d5bc55b534b914a3ef08fb)
#         ;
#
#
#
#
#             var marker_9dd65f8de4571ab9de0242e684695171 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_9191147c5e0cc6977d3ccf181616e8a3);
#
#
#         var popup_6c9c37eab2db3f64c885d04801a1fe8b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ce1e9629b65fe50929ebfef0ad16d917 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ce1e9629b65fe50929ebfef0ad16d917&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ce1e9629b65fe50929ebfef0ad16d917 = L.map(
#                 &quot;map_ce1e9629b65fe50929ebfef0ad16d917&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8111d34bce41f0837ff4f8243a77d01b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8111d34bce41f0837ff4f8243a77d01b.addTo(map_ce1e9629b65fe50929ebfef0ad16d917);
#
#
#             var feature_group_1f55d227eb62d09e37a884865903778b = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_1f55d227eb62d09e37a884865903778b.addTo(map_ce1e9629b65fe50929ebfef0ad16d917);
#
#
#             var feature_group_sub_group_eca6ae7ca70c0479b4255624aca2deb0 = L.featureGroup.subGroup(
#                 feature_group_1f55d227eb62d09e37a884865903778b
#             );
#
#
#             var marker_33a61a131d2c6358d4d832c310c20a5d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_eca6ae7ca70c0479b4255624aca2deb0);
#
#
#         var popup_b24d10b41e1471439f569676b640cd66 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f5e7fa3d12fd82bd05e9b439998e899d = $(`&lt;div id=&quot;html_f5e7fa3d12fd82bd05e9b439998e899d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_b24d10b41e1471439f569676b640cd66.setContent(html_f5e7fa3d12fd82bd05e9b439998e899d);
#
#
#
#         marker_33a61a131d2c6358d4d832c310c20a5d.bindPopup(popup_b24d10b41e1471439f569676b640cd66)
#         ;
#
#
#
#
#             var marker_dbf6e8e03833cf77b58e85edb6bda618 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_eca6ae7ca70c0479b4255624aca2deb0);
#
#
#         var popup_59a575f21ab7976ea3625476e05962ee = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fad46fa28cbf89a7bad310874e32d3f3 = $(`&lt;div id=&quot;html_fad46fa28cbf89a7bad310874e32d3f3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_59a575f21ab7976ea3625476e05962ee.setContent(html_fad46fa28cbf89a7bad310874e32d3f3);
#
#
#
#         marker_dbf6e8e03833cf77b58e85edb6bda618.bindPopup(popup_59a575f21ab7976ea3625476e05962ee)
#         ;
#
#
#
#
#             var marker_8f66f43c3fcf8b25411d6ebba1bb28a4 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_eca6ae7ca70c0479b4255624aca2deb0);
#
#
#         var popup_f6a224d2426756f387a45c3f4f176a66 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_30c8f748cb0305aca77a1eaf342e9a62 = $(`&lt;div id=&quot;html_30c8f748cb0305aca77a1eaf342e9a62&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_f6a224d2426756f387a45c3f4f176a66.setContent(html_30c8f748cb0305aca77a1eaf342e9a62);
#
#
#
#         marker_8f66f43c3fcf8b25411d6ebba1bb28a4.bindPopup(popup_f6a224d2426756f387a45c3f4f176a66)
#         ;
#
#
#
#
#             var marker_3817022d5e8484f4a43ca249c4577067 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_eca6ae7ca70c0479b4255624aca2deb0);
#
#
#         var popup_e5bb174a01f96b8957917acf6c988347 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9c6932a8c174124e72e7b4b9420ae8ae = $(`&lt;div id=&quot;html_9c6932a8c174124e72e7b4b9420ae8ae&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_e5bb174a01f96b8957917acf6c988347.setContent(html_9c6932a8c174124e72e7b4b9420ae8ae);
#
#
#
#         marker_
