# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_14bd84f3c0734efc0e255c45aa304a0c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_14bd84f3c0734efc0e255c45aa304a0c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_14bd84f3c0734efc0e255c45aa304a0c = L.map(
#                 &quot;map_14bd84f3c0734efc0e255c45aa304a0c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_be8893fcd63bd43ba807eb3415f40ca3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_be8893fcd63bd43ba807eb3415f40ca3.addTo(map_14bd84f3c0734efc0e255c45aa304a0c);
#
#
#             var marker_70771f4626ecaaea77e5fc6ed8464f6c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_14bd84f3c0734efc0e255c45aa304a0c);
#
#
#         var popup_f626074030dd0178b0abf50eef575a53 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bb7494de4e7e4984d242036638d2a37d = $(`&lt;div id=&quot;html_bb7494de4e7e4984d242036638d2a37d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_f626074030dd0178b0abf50eef575a53.setContent(html_bb7494de4e7e4984d242036638d2a37d);
#
#
#
#         marker_70771f4626ecaaea77e5fc6ed8464f6c.bindPopup(popup_f626074030dd0178b0abf50eef575a53)
#         ;
#
#
#
#
#             var marker_2648e77052315dd6eaffe40ec1e2b851 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_14bd84f3c0734efc0e255c45aa304a0c);
#
#
#         var popup_5902cfc068232e275a9cf88af24ff002 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8391c45ec1f890f398dd629bc2fd5f8a = $(`&lt;div id=&quot;html_8391c45ec1f890f398dd629bc2fd5f8a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_5902cfc068232e275a9cf88af24ff002.setContent(html_8391c45ec1f890f398dd629bc2fd5f8a);
#
#
#
#         marker_2648e77052315dd6eaffe40ec1e2b851.bindPopup(popup_5902cfc068232e275a9cf88af24ff002)
#         ;
#
#
#
#
#             var marker_e33fd619810fe9b3c86e3926d375772e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_14bd84f3c0734efc0e255c45aa304a0c);
#
#
#         var popup_fddc1848426cab272ca9678c8bf77ab7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_832bfe2580325c3282b371123e7b4b7f = $(`&lt;div id=&quot;html_832bfe2580325c3282b371123e7b4b7f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_fddc1848426cab272ca9678c8bf77ab7.setContent(html_832bfe2580325c3282b371123e7b4b7f);
#
#
#
#         marker_e33fd619810fe9b3c86e3926d375772e.bindPopup(popup_fddc1848426cab272ca9678c8bf77ab7)
#         ;
#
#
#
#
#             var marker_d1262181b87f48c71c0f74527d2d413f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_14bd84f3c0734efc0e255c45aa304a0c);
#
#
#         var popup_9a53464947600515143c20dd55be0b49 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_314de09c2a4a551c39c249a0473a0374 = $(`&lt;div id=&quot;html_314de09c2a4a551c39c249a0473a0374&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_9a53464947600515143c20dd55be0b49.setContent(html_314de09c2a4a551c39c249a0473a0374);
#
#
#
#         marker_d1262181b87f48c71c0f74527d2d413f.bindPopup(popup_9a53464947600515143c20dd55be0b49)
#         ;
#
#
#
#
#             var marker_fb9b59d4da2eba0c34b07c0d84154405 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_14bd84f3c0734efc0e255c45aa304a0c);
#
#
#         var popup_883bdc1b7a3a9513e25d0a412954e2d0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8d187a9efa5527a57862ef5df60cd792 = $(`&lt;div id=&quot;html_8d187a9efa5527a57862ef5df60cd792&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_883bdc1b7a3a9513e25d0a412954e2d0.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bcaebad548ffa5cf022aa5fc43e907d0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bcaebad548ffa5cf022aa5fc43e907d0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bcaebad548ffa5cf022aa5fc43e907d0 = L.map(
#                 &quot;map_bcaebad548ffa5cf022aa5fc43e907d0&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_862d8f4957b4604b5934b69a5bc8e6e3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_862d8f4957b4604b5934b69a5bc8e6e3.addTo(map_bcaebad548ffa5cf022aa5fc43e907d0);
#
#
#             var feature_group_a6b93e3f094ec485329b03a4d21b39c5 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_612b6b1409cc2ad69cecf34f60786b88 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_a6b93e3f094ec485329b03a4d21b39c5);
#
#
#         var popup_cee8db4e7b5b1559603a5e76c0426f3a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b21b7003c08b27d834693917cde08e0e = $(`&lt;div id=&quot;html_b21b7003c08b27d834693917cde08e0e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_cee8db4e7b5b1559603a5e76c0426f3a.setContent(html_b21b7003c08b27d834693917cde08e0e);
#
#
#
#         marker_612b6b1409cc2ad69cecf34f60786b88.bindPopup(popup_cee8db4e7b5b1559603a5e76c0426f3a)
#         ;
#
#
#
#
#             var marker_b1651aa58d537e8d82dc2a82afd597be = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_a6b93e3f094ec485329b03a4d21b39c5);
#
#
#         var popup_31b1a890d8c943b78118f4f7afd4dc42 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b184f1a7c22e5773080b94b3abc12d8f = $(`&lt;div id=&quot;html_b184f1a7c22e5773080b94b3abc12d8f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_31b1a890d8c943b78118f4f7afd4dc42.setContent(html_b184f1a7c22e5773080b94b3abc12d8f);
#
#
#
#         marker_b1651aa58d537e8d82dc2a82afd597be.bindPopup(popup_31b1a890d8c943b78118f4f7afd4dc42)
#         ;
#
#
#
#
#             var marker_7a9df858aaa8ebb48593c896ddb9b648 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_a6b93e3f094ec485329b03a4d21b39c5);
#
#
#         var popup_596cae548765188f7ac1ac51f3ea11e5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9d3bda2e30978a1b5af8442b0423c849 = $(`&lt;div id=&quot;html_9d3bda2e30978a1b5af8442b0423c849&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_596cae548765188f7ac1ac51f3ea11e5.setContent(html_9d3bda2e30978a1b5af8442b0423c849);
#
#
#
#         marker_7a9df858aaa8ebb48593c896ddb9b648.bindPopup(popup_596cae548765188f7ac1ac51f3ea11e5)
#         ;
#
#
#
#
#             var marker_29cdcf02466f8e266c89e05e4dab54ca = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_a6b93e3f094ec485329b03a4d21b39c5);
#
#
#         var popup_bc2859fbeddc5aed51d2a59560d47188 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ccd57db718de10c7b4f5e8ebd334c35c = $(`&lt;div id=&quot;html_ccd57db718de10c7b4f5e8ebd334c35c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_bc2859fbeddc5aed51d2a59560d47188.setContent(html_ccd57db718de10c7b4f5e8ebd334c35c);
#
#
#
#         marker_29cdcf02466f8e266c89e05e4dab54ca.bindPopup(popup_bc2859fbeddc5aed51d2a59560d47188)
#         ;
#
#
#
#
#             var marker_f33fa50aceff2fb13d4fd7208811b51a = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_a6b93e3f094ec485329b03a4d21b39c5);
#
#
#         var popup_8fb6ec2d719c5e2e37c6e1ca652e0c0e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f4b81a063e358aa46f59714d7a815a4a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f4b81a063e358aa46f59714d7a815a4a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f4b81a063e358aa46f59714d7a815a4a = L.map(
#                 &quot;map_f4b81a063e358aa46f59714d7a815a4a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_360b61aa08ad6585f9a0c34e58200018 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_360b61aa08ad6585f9a0c34e58200018.addTo(map_f4b81a063e358aa46f59714d7a815a4a);
#
#
#             var feature_group_bc9f76eb998a1b135376022fa62aa232 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_bc9f76eb998a1b135376022fa62aa232.addTo(map_f4b81a063e358aa46f59714d7a815a4a);
#
#
#             var feature_group_sub_group_c4aba53aa83acdff10426057606b56c4 = L.featureGroup.subGroup(
#                 feature_group_bc9f76eb998a1b135376022fa62aa232
#             );
#
#
#             var marker_9243c16a41c995a753315ef80399b024 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_c4aba53aa83acdff10426057606b56c4);
#
#
#         var popup_3a991ae35faf25527ace3ddf03b8d2e0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e3b2ae75f1962d427ec1b563d25032eb = $(`&lt;div id=&quot;html_e3b2ae75f1962d427ec1b563d25032eb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_3a991ae35faf25527ace3ddf03b8d2e0.setContent(html_e3b2ae75f1962d427ec1b563d25032eb);
#
#
#
#         marker_9243c16a41c995a753315ef80399b024.bindPopup(popup_3a991ae35faf25527ace3ddf03b8d2e0)
#         ;
#
#
#
#
#             var marker_4a17b8ad30f3e49fe16b2df04870f00c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_c4aba53aa83acdff10426057606b56c4);
#
#
#         var popup_3b46141458c3cabf7cf864b709e1be67 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_690adfb343ba99063728dc93ae11b776 = $(`&lt;div id=&quot;html_690adfb343ba99063728dc93ae11b776&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_3b46141458c3cabf7cf864b709e1be67.setContent(html_690adfb343ba99063728dc93ae11b776);
#
#
#
#         marker_4a17b8ad30f3e49fe16b2df04870f00c.bindPopup(popup_3b46141458c3cabf7cf864b709e1be67)
#         ;
#
#
#
#
#             var marker_851b361153af7adbed02bfca4203c258 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_c4aba53aa83acdff10426057606b56c4);
#
#
#         var popup_f089ebc90b9bdf6a30fe0b546e3b88f8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_60798d01ecc7054eae442d04e6389cf0 = $(`&lt;div id=&quot;html_60798d01ecc7054eae442d04e6389cf0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_f089ebc90b9bdf6a30fe0b546e3b88f8.setContent(html_60798d01ecc7054eae442d04e6389cf0);
#
#
#
#         marker_851b361153af7adbed02bfca4203c258.bindPopup(popup_f089ebc90b9bdf6a30fe0b546e3b88f8)
#         ;
#
#
#
#
#             var marker_ba1247615d7b339f1327767e7c510722 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_c4aba53aa83acdff10426057606b56c4);
#
#
#         var popup_1511c49a3cd88e1b9d3ac9861aff8d6a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6b15502617d03a670d78466a7711a115 = $(`&lt;div id=&quot;html_6b15502617d03a670d78466a7711a115&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_1511c49a3cd88e1b9d3ac9861aff8d6a.setContent(html_6b15502617d03a670d78466a7711a115);
#
#
#
#         marker_
