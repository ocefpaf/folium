# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_73c0f6594d71877917f2e1fa5459063f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_73c0f6594d71877917f2e1fa5459063f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_73c0f6594d71877917f2e1fa5459063f = L.map(
#                 &quot;map_73c0f6594d71877917f2e1fa5459063f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_692603e00e4565eeda5d1acd872a88b5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_692603e00e4565eeda5d1acd872a88b5.addTo(map_73c0f6594d71877917f2e1fa5459063f);
#
#
#             var marker_cc14eefe584419ef4ff48b72dc8e1423 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_73c0f6594d71877917f2e1fa5459063f);
#
#
#         var popup_1a13dac1c0fecdc5e2d753b0c68d7043 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4fe2916159e2d61d85c36f7e59f5bab3 = $(`&lt;div id=&quot;html_4fe2916159e2d61d85c36f7e59f5bab3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_1a13dac1c0fecdc5e2d753b0c68d7043.setContent(html_4fe2916159e2d61d85c36f7e59f5bab3);
#
#
#
#         marker_cc14eefe584419ef4ff48b72dc8e1423.bindPopup(popup_1a13dac1c0fecdc5e2d753b0c68d7043)
#         ;
#
#
#
#
#             var marker_5a50de54ee35cdfb56a45b64a2633bd2 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_73c0f6594d71877917f2e1fa5459063f);
#
#
#         var popup_07952ff637ead1f831318d201a5f6cbb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_be83732238a5f07b291f81f9855b7fcb = $(`&lt;div id=&quot;html_be83732238a5f07b291f81f9855b7fcb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_07952ff637ead1f831318d201a5f6cbb.setContent(html_be83732238a5f07b291f81f9855b7fcb);
#
#
#
#         marker_5a50de54ee35cdfb56a45b64a2633bd2.bindPopup(popup_07952ff637ead1f831318d201a5f6cbb)
#         ;
#
#
#
#
#             var marker_897509a24a6bd642f4f7500664979dbc = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_73c0f6594d71877917f2e1fa5459063f);
#
#
#         var popup_084d5967a3a1defcac5126cb56ee94a5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b039ac1d13463030129af7318ca70327 = $(`&lt;div id=&quot;html_b039ac1d13463030129af7318ca70327&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_084d5967a3a1defcac5126cb56ee94a5.setContent(html_b039ac1d13463030129af7318ca70327);
#
#
#
#         marker_897509a24a6bd642f4f7500664979dbc.bindPopup(popup_084d5967a3a1defcac5126cb56ee94a5)
#         ;
#
#
#
#
#             var marker_6fc69179501327a2913da87133a85d81 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_73c0f6594d71877917f2e1fa5459063f);
#
#
#         var popup_b903e4ee228e67d1152547fc635e07d6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_78bfc88a40625b312cf79ee320926aa7 = $(`&lt;div id=&quot;html_78bfc88a40625b312cf79ee320926aa7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_b903e4ee228e67d1152547fc635e07d6.setContent(html_78bfc88a40625b312cf79ee320926aa7);
#
#
#
#         marker_6fc69179501327a2913da87133a85d81.bindPopup(popup_b903e4ee228e67d1152547fc635e07d6)
#         ;
#
#
#
#
#             var marker_b238c4bd44a103bf7a30b3fa4c777685 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_73c0f6594d71877917f2e1fa5459063f);
#
#
#         var popup_e471a7a9cdf000e6a100e2aeea904bd4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_815fced14bb2d4bd7835440c7c29d6e8 = $(`&lt;div id=&quot;html_815fced14bb2d4bd7835440c7c29d6e8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_e471a7a9cdf000e6a100e2aeea904bd4.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f9a3f8cc1104810e27937879357126ca {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f9a3f8cc1104810e27937879357126ca&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f9a3f8cc1104810e27937879357126ca = L.map(
#                 &quot;map_f9a3f8cc1104810e27937879357126ca&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2c710f68cbb8a7456ef40deece60add6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2c710f68cbb8a7456ef40deece60add6.addTo(map_f9a3f8cc1104810e27937879357126ca);
#
#
#             var feature_group_09b2fce4f33712b9795fa45c1af28a3e = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_634c955a57be1f29150e74bf94426217 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_09b2fce4f33712b9795fa45c1af28a3e);
#
#
#         var popup_87e7d76a182c9f9db1671f2f43333a9c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8917e1a50eb39bdf51586c8da67ece32 = $(`&lt;div id=&quot;html_8917e1a50eb39bdf51586c8da67ece32&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_87e7d76a182c9f9db1671f2f43333a9c.setContent(html_8917e1a50eb39bdf51586c8da67ece32);
#
#
#
#         marker_634c955a57be1f29150e74bf94426217.bindPopup(popup_87e7d76a182c9f9db1671f2f43333a9c)
#         ;
#
#
#
#
#             var marker_189355e034000753208b064a90a79c01 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_09b2fce4f33712b9795fa45c1af28a3e);
#
#
#         var popup_fedf53562f6b87b618ae37c5f4fba8b1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4bb83a24bd0da06118bd1fffd1b2d190 = $(`&lt;div id=&quot;html_4bb83a24bd0da06118bd1fffd1b2d190&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_fedf53562f6b87b618ae37c5f4fba8b1.setContent(html_4bb83a24bd0da06118bd1fffd1b2d190);
#
#
#
#         marker_189355e034000753208b064a90a79c01.bindPopup(popup_fedf53562f6b87b618ae37c5f4fba8b1)
#         ;
#
#
#
#
#             var marker_7d49dcd911f6a8bb9a79cea250701ddb = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_09b2fce4f33712b9795fa45c1af28a3e);
#
#
#         var popup_075c79a51e550652d11b82f3126e4ce2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b81c7d15ea24e97ea2a4666463acda60 = $(`&lt;div id=&quot;html_b81c7d15ea24e97ea2a4666463acda60&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_075c79a51e550652d11b82f3126e4ce2.setContent(html_b81c7d15ea24e97ea2a4666463acda60);
#
#
#
#         marker_7d49dcd911f6a8bb9a79cea250701ddb.bindPopup(popup_075c79a51e550652d11b82f3126e4ce2)
#         ;
#
#
#
#
#             var marker_9617240034392ceae61ebb5f1512e008 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_09b2fce4f33712b9795fa45c1af28a3e);
#
#
#         var popup_8785a1f0b566f5d42ade3eeb10079cd9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_77963afd71f60d0c15c007d86ce0e69f = $(`&lt;div id=&quot;html_77963afd71f60d0c15c007d86ce0e69f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_8785a1f0b566f5d42ade3eeb10079cd9.setContent(html_77963afd71f60d0c15c007d86ce0e69f);
#
#
#
#         marker_9617240034392ceae61ebb5f1512e008.bindPopup(popup_8785a1f0b566f5d42ade3eeb10079cd9)
#         ;
#
#
#
#
#             var marker_b4c834ad038f53a327546c2a537741b8 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_09b2fce4f33712b9795fa45c1af28a3e);
#
#
#         var popup_5e1990d7fe7184fda69ced183f9a0a35 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_579f9ca17f1f6474e8841433edebd15c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_579f9ca17f1f6474e8841433edebd15c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_579f9ca17f1f6474e8841433edebd15c = L.map(
#                 &quot;map_579f9ca17f1f6474e8841433edebd15c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7b6487f1ca0ba90cbe257040d3f877e4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7b6487f1ca0ba90cbe257040d3f877e4.addTo(map_579f9ca17f1f6474e8841433edebd15c);
#
#
#             var feature_group_255b754009afd36c9dd3eeda49556464 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_255b754009afd36c9dd3eeda49556464.addTo(map_579f9ca17f1f6474e8841433edebd15c);
#
#
#             var feature_group_sub_group_3efbe16e38e950af284c253b0a172ff3 = L.featureGroup.subGroup(
#                 feature_group_255b754009afd36c9dd3eeda49556464
#             );
#
#
#             var marker_dcee3184d8d0cee95656561ffb9c480b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_3efbe16e38e950af284c253b0a172ff3);
#
#
#         var popup_417a43a8c348e74c559d8f07f54e81f9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b37396409846c01d3c637e162a8e21cc = $(`&lt;div id=&quot;html_b37396409846c01d3c637e162a8e21cc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_417a43a8c348e74c559d8f07f54e81f9.setContent(html_b37396409846c01d3c637e162a8e21cc);
#
#
#
#         marker_dcee3184d8d0cee95656561ffb9c480b.bindPopup(popup_417a43a8c348e74c559d8f07f54e81f9)
#         ;
#
#
#
#
#             var marker_47f253c3939e9ca9d8fa94af6f7e314c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_3efbe16e38e950af284c253b0a172ff3);
#
#
#         var popup_75c3defc52d4de45706064616f3d13ac = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_90782f21e0fe3b8eeb2be4e02df6af4b = $(`&lt;div id=&quot;html_90782f21e0fe3b8eeb2be4e02df6af4b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_75c3defc52d4de45706064616f3d13ac.setContent(html_90782f21e0fe3b8eeb2be4e02df6af4b);
#
#
#
#         marker_47f253c3939e9ca9d8fa94af6f7e314c.bindPopup(popup_75c3defc52d4de45706064616f3d13ac)
#         ;
#
#
#
#
#             var marker_1590f469b6c50f924a76a7c82b254aae = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_3efbe16e38e950af284c253b0a172ff3);
#
#
#         var popup_09c4aa402f343cdc88a46f2b1a39c99c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3a6b2c1bcbb20d971b8ecb6cc5c88e5e = $(`&lt;div id=&quot;html_3a6b2c1bcbb20d971b8ecb6cc5c88e5e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_09c4aa402f343cdc88a46f2b1a39c99c.setContent(html_3a6b2c1bcbb20d971b8ecb6cc5c88e5e);
#
#
#
#         marker_1590f469b6c50f924a76a7c82b254aae.bindPopup(popup_09c4aa402f343cdc88a46f2b1a39c99c)
#         ;
#
#
#
#
#             var marker_0415466b8f6193251e35e16c228c760a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_3efbe16e38e950af284c253b0a172ff3);
#
#
#         var popup_3c17172ae4adaf41ec6a23a064f0a649 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c6afe1bc2604d5228ccf26d6753f71ba = $(`&lt;div id=&quot;html_c6afe1bc2604d5228ccf26d6753f71ba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_3c17172ae4adaf41ec6a23a064f0a649.setContent(html_c6afe1bc2604d5228ccf26d6753f71ba);
#
#
#
#         marker_
