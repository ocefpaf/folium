# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0703afc15e75c00fca790e8e7d4a8db8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0703afc15e75c00fca790e8e7d4a8db8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0703afc15e75c00fca790e8e7d4a8db8 = L.map(
#                 &quot;map_0703afc15e75c00fca790e8e7d4a8db8&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e1c7a57d3cef97d0c1ebb9fe84ec807f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e1c7a57d3cef97d0c1ebb9fe84ec807f.addTo(map_0703afc15e75c00fca790e8e7d4a8db8);
#
#
#             var marker_ce4b284596bcdbf4e27820ccd219dec2 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_0703afc15e75c00fca790e8e7d4a8db8);
#
#
#         var popup_42f9478ace3bd85c54f617a094f7bcbc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9faee7dc3a3638243d51a5fccf0599e5 = $(`&lt;div id=&quot;html_9faee7dc3a3638243d51a5fccf0599e5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_42f9478ace3bd85c54f617a094f7bcbc.setContent(html_9faee7dc3a3638243d51a5fccf0599e5);
#
#
#
#         marker_ce4b284596bcdbf4e27820ccd219dec2.bindPopup(popup_42f9478ace3bd85c54f617a094f7bcbc)
#         ;
#
#
#
#
#             var marker_55b6aab3d93347aa248c0e4cada03d03 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_0703afc15e75c00fca790e8e7d4a8db8);
#
#
#         var popup_ae79f76e5122e279d2c09466c0206b77 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f5ac2e4f74b7856601c1078bc9471320 = $(`&lt;div id=&quot;html_f5ac2e4f74b7856601c1078bc9471320&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_ae79f76e5122e279d2c09466c0206b77.setContent(html_f5ac2e4f74b7856601c1078bc9471320);
#
#
#
#         marker_55b6aab3d93347aa248c0e4cada03d03.bindPopup(popup_ae79f76e5122e279d2c09466c0206b77)
#         ;
#
#
#
#
#             var marker_9b49ab78c58ed6cd97729534aae47b38 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_0703afc15e75c00fca790e8e7d4a8db8);
#
#
#         var popup_7f7998e726f979666cad3839611be289 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f763df6a6a12626613a41318a0a2b364 = $(`&lt;div id=&quot;html_f763df6a6a12626613a41318a0a2b364&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_7f7998e726f979666cad3839611be289.setContent(html_f763df6a6a12626613a41318a0a2b364);
#
#
#
#         marker_9b49ab78c58ed6cd97729534aae47b38.bindPopup(popup_7f7998e726f979666cad3839611be289)
#         ;
#
#
#
#
#             var marker_123423478d48a4fe9713a8ff13296a63 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_0703afc15e75c00fca790e8e7d4a8db8);
#
#
#         var popup_78c8a9bcfbcd0958031b8432d09d918c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d7cd4c0c1b83c72f464ba6c00a3927ec = $(`&lt;div id=&quot;html_d7cd4c0c1b83c72f464ba6c00a3927ec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_78c8a9bcfbcd0958031b8432d09d918c.setContent(html_d7cd4c0c1b83c72f464ba6c00a3927ec);
#
#
#
#         marker_123423478d48a4fe9713a8ff13296a63.bindPopup(popup_78c8a9bcfbcd0958031b8432d09d918c)
#         ;
#
#
#
#
#             var marker_dfa37ca3f4e31458b40b1958850e93d9 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_0703afc15e75c00fca790e8e7d4a8db8);
#
#
#         var popup_de562a1261e21847a121d0e100362ec9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f85e102dd44a7e9005f2acd4cb1d98f2 = $(`&lt;div id=&quot;html_f85e102dd44a7e9005f2acd4cb1d98f2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_de562a1261e21847a121d0e100362ec9.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_348b4d7631e25c3fd167b78d873d1e72 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_348b4d7631e25c3fd167b78d873d1e72&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_348b4d7631e25c3fd167b78d873d1e72 = L.map(
#                 &quot;map_348b4d7631e25c3fd167b78d873d1e72&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7379e5d990d9a9e85fbaa12acb7b5246 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7379e5d990d9a9e85fbaa12acb7b5246.addTo(map_348b4d7631e25c3fd167b78d873d1e72);
#
#
#             var feature_group_a18d8ac96ca13d418f72a4e7a5abd9ad = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_a9eb97aca350ac4141ed035aeec740d2 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_a18d8ac96ca13d418f72a4e7a5abd9ad);
#
#
#         var popup_99f30d538c144682002f98e5227ca9e8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_95784512d683eee1811d2cb09481065a = $(`&lt;div id=&quot;html_95784512d683eee1811d2cb09481065a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_99f30d538c144682002f98e5227ca9e8.setContent(html_95784512d683eee1811d2cb09481065a);
#
#
#
#         marker_a9eb97aca350ac4141ed035aeec740d2.bindPopup(popup_99f30d538c144682002f98e5227ca9e8)
#         ;
#
#
#
#
#             var marker_4d7bd5873991d01c5515be2909ea5806 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_a18d8ac96ca13d418f72a4e7a5abd9ad);
#
#
#         var popup_cfbcfb759f19323d7c34a6401dc3d81d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_51294aaa504fb41c1ae96994c4784386 = $(`&lt;div id=&quot;html_51294aaa504fb41c1ae96994c4784386&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_cfbcfb759f19323d7c34a6401dc3d81d.setContent(html_51294aaa504fb41c1ae96994c4784386);
#
#
#
#         marker_4d7bd5873991d01c5515be2909ea5806.bindPopup(popup_cfbcfb759f19323d7c34a6401dc3d81d)
#         ;
#
#
#
#
#             var marker_d33e87a56480cb5a2f76e7c29a9aa0d0 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_a18d8ac96ca13d418f72a4e7a5abd9ad);
#
#
#         var popup_26bdb0c2e17df09980d657ecb58f1662 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3c0cd440ab595b06c460f96dcad2eff8 = $(`&lt;div id=&quot;html_3c0cd440ab595b06c460f96dcad2eff8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_26bdb0c2e17df09980d657ecb58f1662.setContent(html_3c0cd440ab595b06c460f96dcad2eff8);
#
#
#
#         marker_d33e87a56480cb5a2f76e7c29a9aa0d0.bindPopup(popup_26bdb0c2e17df09980d657ecb58f1662)
#         ;
#
#
#
#
#             var marker_ec8efe7d4b8f16627bc3009788d121e4 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_a18d8ac96ca13d418f72a4e7a5abd9ad);
#
#
#         var popup_3cc3faadc37eb940e233983818f7accd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1832ce40f43e01e7abaf7d019e0a8edf = $(`&lt;div id=&quot;html_1832ce40f43e01e7abaf7d019e0a8edf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_3cc3faadc37eb940e233983818f7accd.setContent(html_1832ce40f43e01e7abaf7d019e0a8edf);
#
#
#
#         marker_ec8efe7d4b8f16627bc3009788d121e4.bindPopup(popup_3cc3faadc37eb940e233983818f7accd)
#         ;
#
#
#
#
#             var marker_2f72fbca0e20fb2b0a39365e18b73bd9 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_a18d8ac96ca13d418f72a4e7a5abd9ad);
#
#
#         var popup_5a60c362f9d2bb736c68e4adcf51c23b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_55a0abbea13d428cc904c82cf8b6f4af {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_55a0abbea13d428cc904c82cf8b6f4af&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_55a0abbea13d428cc904c82cf8b6f4af = L.map(
#                 &quot;map_55a0abbea13d428cc904c82cf8b6f4af&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c1af58b3e5d588cb5503bd9afc709338 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c1af58b3e5d588cb5503bd9afc709338.addTo(map_55a0abbea13d428cc904c82cf8b6f4af);
#
#
#             var feature_group_8dc2ecbed93609d013c7eddccdd1d649 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_8dc2ecbed93609d013c7eddccdd1d649.addTo(map_55a0abbea13d428cc904c82cf8b6f4af);
#
#
#             var feature_group_sub_group_13be252e103ba90dc4385ff874d10cf3 = L.featureGroup.subGroup(
#                 feature_group_8dc2ecbed93609d013c7eddccdd1d649
#             );
#
#
#             var marker_2270500747a98649c82b5bc7448ff49e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_13be252e103ba90dc4385ff874d10cf3);
#
#
#         var popup_2947a27fbc0114fa8cb19127e261157b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c259de7dae6cc0398e7d1a5205e03ddf = $(`&lt;div id=&quot;html_c259de7dae6cc0398e7d1a5205e03ddf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_2947a27fbc0114fa8cb19127e261157b.setContent(html_c259de7dae6cc0398e7d1a5205e03ddf);
#
#
#
#         marker_2270500747a98649c82b5bc7448ff49e.bindPopup(popup_2947a27fbc0114fa8cb19127e261157b)
#         ;
#
#
#
#
#             var marker_ddc60408a6265b86f825283772ff9c90 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_13be252e103ba90dc4385ff874d10cf3);
#
#
#         var popup_347d747da109b11e1043539d74dde441 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ae447b09bf5d8ced96682867f8aa5426 = $(`&lt;div id=&quot;html_ae447b09bf5d8ced96682867f8aa5426&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_347d747da109b11e1043539d74dde441.setContent(html_ae447b09bf5d8ced96682867f8aa5426);
#
#
#
#         marker_ddc60408a6265b86f825283772ff9c90.bindPopup(popup_347d747da109b11e1043539d74dde441)
#         ;
#
#
#
#
#             var marker_0f119273de540f3dde7cbbb3974e5048 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_13be252e103ba90dc4385ff874d10cf3);
#
#
#         var popup_141d7b5b170384360b378e92ba3b7932 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_37b47f402b4d46959b2084530321a2d4 = $(`&lt;div id=&quot;html_37b47f402b4d46959b2084530321a2d4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_141d7b5b170384360b378e92ba3b7932.setContent(html_37b47f402b4d46959b2084530321a2d4);
#
#
#
#         marker_0f119273de540f3dde7cbbb3974e5048.bindPopup(popup_141d7b5b170384360b378e92ba3b7932)
#         ;
#
#
#
#
#             var marker_13ee3a44dd117075fb08b3f12d8413dc = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_13be252e103ba90dc4385ff874d10cf3);
#
#
#         var popup_69a67f84ba17f60314e3875343c824e1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2ea2128c74ea2868587ea11a62864379 = $(`&lt;div id=&quot;html_2ea2128c74ea2868587ea11a62864379&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_69a67f84ba17f60314e3875343c824e1.setContent(html_2ea2128c74ea2868587ea11a62864379);
#
#
#
#         marker_
