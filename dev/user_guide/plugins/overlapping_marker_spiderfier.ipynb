# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b8396776a6666fc1effea0ac4a853ca2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b8396776a6666fc1effea0ac4a853ca2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b8396776a6666fc1effea0ac4a853ca2 = L.map(
#                 &quot;map_b8396776a6666fc1effea0ac4a853ca2&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_72410979a2f8138726d0d9cfe239be19 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_72410979a2f8138726d0d9cfe239be19.addTo(map_b8396776a6666fc1effea0ac4a853ca2);
#
#
#             var marker_a5880480c56c1f38530ade0c758b921b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_b8396776a6666fc1effea0ac4a853ca2);
#
#
#         var popup_5ad240eb952a1f0d7efbc84722b97df5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ec91342245347903a6c5aab1d7096a18 = $(`&lt;div id=&quot;html_ec91342245347903a6c5aab1d7096a18&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_5ad240eb952a1f0d7efbc84722b97df5.setContent(html_ec91342245347903a6c5aab1d7096a18);
#
#
#
#         marker_a5880480c56c1f38530ade0c758b921b.bindPopup(popup_5ad240eb952a1f0d7efbc84722b97df5)
#         ;
#
#
#
#
#             var marker_9d6492ac126d93a14cee99fee69c8ef5 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_b8396776a6666fc1effea0ac4a853ca2);
#
#
#         var popup_51bf5e28e596e549af80e84b8d0fb093 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9b70435774f1ab43f4ba59cb9be2730e = $(`&lt;div id=&quot;html_9b70435774f1ab43f4ba59cb9be2730e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_51bf5e28e596e549af80e84b8d0fb093.setContent(html_9b70435774f1ab43f4ba59cb9be2730e);
#
#
#
#         marker_9d6492ac126d93a14cee99fee69c8ef5.bindPopup(popup_51bf5e28e596e549af80e84b8d0fb093)
#         ;
#
#
#
#
#             var marker_7c64b51e962608f5a643fdc9fb2f7861 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_b8396776a6666fc1effea0ac4a853ca2);
#
#
#         var popup_f5b81d8ab2e7ca65a5f8f90af51508c9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b4b6b53700f5fa4661d983246179474b = $(`&lt;div id=&quot;html_b4b6b53700f5fa4661d983246179474b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_f5b81d8ab2e7ca65a5f8f90af51508c9.setContent(html_b4b6b53700f5fa4661d983246179474b);
#
#
#
#         marker_7c64b51e962608f5a643fdc9fb2f7861.bindPopup(popup_f5b81d8ab2e7ca65a5f8f90af51508c9)
#         ;
#
#
#
#
#             var marker_dc241acd67bdc78f4e3a68909c1717c6 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_b8396776a6666fc1effea0ac4a853ca2);
#
#
#         var popup_c2b8047efbd1c52ce4831e4813422c2d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f77fb34bcb659b4128f757e5aa8b5111 = $(`&lt;div id=&quot;html_f77fb34bcb659b4128f757e5aa8b5111&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_c2b8047efbd1c52ce4831e4813422c2d.setContent(html_f77fb34bcb659b4128f757e5aa8b5111);
#
#
#
#         marker_dc241acd67bdc78f4e3a68909c1717c6.bindPopup(popup_c2b8047efbd1c52ce4831e4813422c2d)
#         ;
#
#
#
#
#             var marker_e10f00c01e2d59a36691e5792fa24867 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_b8396776a6666fc1effea0ac4a853ca2);
#
#
#         var popup_10b5a7c6551c9b7848b0ba9813e83c43 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_28720f0f6c8a0c790803a575c2f5fd8d = $(`&lt;div id=&quot;html_28720f0f6c8a0c790803a575c2f5fd8d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_10b5a7c6551c9b7848b0ba9813e83c43.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5602084858f529515aeeee7ad451d016 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5602084858f529515aeeee7ad451d016&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5602084858f529515aeeee7ad451d016 = L.map(
#                 &quot;map_5602084858f529515aeeee7ad451d016&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6bb4e2a68c36433a768f6d86a16d85f5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6bb4e2a68c36433a768f6d86a16d85f5.addTo(map_5602084858f529515aeeee7ad451d016);
#
#
#             var feature_group_b32ee23045406917b67cb8b0a733af05 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_b5774a947d6bccc7bdc7a5b3b572e5a4 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_b32ee23045406917b67cb8b0a733af05);
#
#
#         var popup_798589a29b639a927219e834e3e3edfe = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cbf32da4be344446a918a439d90d70b9 = $(`&lt;div id=&quot;html_cbf32da4be344446a918a439d90d70b9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_798589a29b639a927219e834e3e3edfe.setContent(html_cbf32da4be344446a918a439d90d70b9);
#
#
#
#         marker_b5774a947d6bccc7bdc7a5b3b572e5a4.bindPopup(popup_798589a29b639a927219e834e3e3edfe)
#         ;
#
#
#
#
#             var marker_12134715f78ae167bca266611b6274a7 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_b32ee23045406917b67cb8b0a733af05);
#
#
#         var popup_32654b3fa67572af59d04a9ab0f4f9bf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4d2af26d7d6a2c4c3aa102c89948f153 = $(`&lt;div id=&quot;html_4d2af26d7d6a2c4c3aa102c89948f153&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_32654b3fa67572af59d04a9ab0f4f9bf.setContent(html_4d2af26d7d6a2c4c3aa102c89948f153);
#
#
#
#         marker_12134715f78ae167bca266611b6274a7.bindPopup(popup_32654b3fa67572af59d04a9ab0f4f9bf)
#         ;
#
#
#
#
#             var marker_a36e847b0dedaff7e7e8ae40e58199c8 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_b32ee23045406917b67cb8b0a733af05);
#
#
#         var popup_47de0685ade5d6665d0c05d87d3206dd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f2a3a0a5379268d543562f4a42b3e377 = $(`&lt;div id=&quot;html_f2a3a0a5379268d543562f4a42b3e377&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_47de0685ade5d6665d0c05d87d3206dd.setContent(html_f2a3a0a5379268d543562f4a42b3e377);
#
#
#
#         marker_a36e847b0dedaff7e7e8ae40e58199c8.bindPopup(popup_47de0685ade5d6665d0c05d87d3206dd)
#         ;
#
#
#
#
#             var marker_0f19cec241a19666631b04bec904f59c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_b32ee23045406917b67cb8b0a733af05);
#
#
#         var popup_02f1e1dc6d70e755ed67b52569ca4b05 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_aca7cbbafa7ec8d610e0b5d99e994af0 = $(`&lt;div id=&quot;html_aca7cbbafa7ec8d610e0b5d99e994af0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_02f1e1dc6d70e755ed67b52569ca4b05.setContent(html_aca7cbbafa7ec8d610e0b5d99e994af0);
#
#
#
#         marker_0f19cec241a19666631b04bec904f59c.bindPopup(popup_02f1e1dc6d70e755ed67b52569ca4b05)
#         ;
#
#
#
#
#             var marker_6c65043132d70cd975449750dd72e0ac = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_b32ee23045406917b67cb8b0a733af05);
#
#
#         var popup_396a8daa361dbbef98ae1868a6965250 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b10f3baf4a6aa41f632842a3b4aab162 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b10f3baf4a6aa41f632842a3b4aab162&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b10f3baf4a6aa41f632842a3b4aab162 = L.map(
#                 &quot;map_b10f3baf4a6aa41f632842a3b4aab162&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6421cb3195e6d5572882aaf16c5b920c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6421cb3195e6d5572882aaf16c5b920c.addTo(map_b10f3baf4a6aa41f632842a3b4aab162);
#
#
#             var feature_group_a600264a44e5b657e04872755217580c = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_a600264a44e5b657e04872755217580c.addTo(map_b10f3baf4a6aa41f632842a3b4aab162);
#
#
#             var feature_group_sub_group_ae3013c6f68ee5714ed03036e41d38bd = L.featureGroup.subGroup(
#                 feature_group_a600264a44e5b657e04872755217580c
#             );
#
#
#             var marker_3da2e5005e6f0fecef77f89733a1600d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_ae3013c6f68ee5714ed03036e41d38bd);
#
#
#         var popup_e2d7d366aaa9d0d52d4feddf305bab2c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0d11807e158fb418bcbdacbd8ec942e8 = $(`&lt;div id=&quot;html_0d11807e158fb418bcbdacbd8ec942e8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_e2d7d366aaa9d0d52d4feddf305bab2c.setContent(html_0d11807e158fb418bcbdacbd8ec942e8);
#
#
#
#         marker_3da2e5005e6f0fecef77f89733a1600d.bindPopup(popup_e2d7d366aaa9d0d52d4feddf305bab2c)
#         ;
#
#
#
#
#             var marker_19f70ad26f012e8184b6a68854012a4b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_ae3013c6f68ee5714ed03036e41d38bd);
#
#
#         var popup_6ab58b93fe6e039436c53ba69c728694 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_191ababd8b699d663cd75e5dbe860875 = $(`&lt;div id=&quot;html_191ababd8b699d663cd75e5dbe860875&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_6ab58b93fe6e039436c53ba69c728694.setContent(html_191ababd8b699d663cd75e5dbe860875);
#
#
#
#         marker_19f70ad26f012e8184b6a68854012a4b.bindPopup(popup_6ab58b93fe6e039436c53ba69c728694)
#         ;
#
#
#
#
#             var marker_1c0e4bba4829b93fc8c6c1639bd419ce = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_ae3013c6f68ee5714ed03036e41d38bd);
#
#
#         var popup_54b5e427eae563e993939a14e616ca58 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dff9dd6bef6ed243f6b7edf47b600bcb = $(`&lt;div id=&quot;html_dff9dd6bef6ed243f6b7edf47b600bcb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_54b5e427eae563e993939a14e616ca58.setContent(html_dff9dd6bef6ed243f6b7edf47b600bcb);
#
#
#
#         marker_1c0e4bba4829b93fc8c6c1639bd419ce.bindPopup(popup_54b5e427eae563e993939a14e616ca58)
#         ;
#
#
#
#
#             var marker_a236170ed263fdd4a22ba2cc1ce3c860 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_ae3013c6f68ee5714ed03036e41d38bd);
#
#
#         var popup_6ac08c455be106c1e492c272eeeca6e3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_df96392a13a056bc0e91b51ac991d416 = $(`&lt;div id=&quot;html_df96392a13a056bc0e91b51ac991d416&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_6ac08c455be106c1e492c272eeeca6e3.setContent(html_df96392a13a056bc0e91b51ac991d416);
#
#
#
#         marker_
