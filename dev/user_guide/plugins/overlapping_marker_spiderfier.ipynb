# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b3053c51eda50515479f72e03d2c9c41 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b3053c51eda50515479f72e03d2c9c41&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b3053c51eda50515479f72e03d2c9c41 = L.map(
#                 &quot;map_b3053c51eda50515479f72e03d2c9c41&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_924411548c2e93aa8e4028eb7c051cd3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_924411548c2e93aa8e4028eb7c051cd3.addTo(map_b3053c51eda50515479f72e03d2c9c41);
#
#
#             var marker_e0cf4e89ee13c55fd9bb1854221ab617 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_b3053c51eda50515479f72e03d2c9c41);
#
#
#         var popup_eb5c9bcb3a93bcc2d74f06d00695cafb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9fe99e952d2f9be8b9ecfd9031c069b0 = $(`&lt;div id=&quot;html_9fe99e952d2f9be8b9ecfd9031c069b0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_eb5c9bcb3a93bcc2d74f06d00695cafb.setContent(html_9fe99e952d2f9be8b9ecfd9031c069b0);
#
#
#
#         marker_e0cf4e89ee13c55fd9bb1854221ab617.bindPopup(popup_eb5c9bcb3a93bcc2d74f06d00695cafb)
#         ;
#
#
#
#
#             var marker_1b7fe5b5ac66b6c0524d9e5426a6dbd3 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_b3053c51eda50515479f72e03d2c9c41);
#
#
#         var popup_e94b3f218a2c2f88d1ceaac6d7c3cd5e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e29ec1fdaca3c7de4f3f58ef6eeb7af9 = $(`&lt;div id=&quot;html_e29ec1fdaca3c7de4f3f58ef6eeb7af9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_e94b3f218a2c2f88d1ceaac6d7c3cd5e.setContent(html_e29ec1fdaca3c7de4f3f58ef6eeb7af9);
#
#
#
#         marker_1b7fe5b5ac66b6c0524d9e5426a6dbd3.bindPopup(popup_e94b3f218a2c2f88d1ceaac6d7c3cd5e)
#         ;
#
#
#
#
#             var marker_d147b878efc261e321a92910d3ce9b95 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_b3053c51eda50515479f72e03d2c9c41);
#
#
#         var popup_866b963700798e59f6c4e6ec9f053b1c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_15a024191df21378a081c0c57e236b6c = $(`&lt;div id=&quot;html_15a024191df21378a081c0c57e236b6c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_866b963700798e59f6c4e6ec9f053b1c.setContent(html_15a024191df21378a081c0c57e236b6c);
#
#
#
#         marker_d147b878efc261e321a92910d3ce9b95.bindPopup(popup_866b963700798e59f6c4e6ec9f053b1c)
#         ;
#
#
#
#
#             var marker_8be857b173b5f6ceb6b105b95564272c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_b3053c51eda50515479f72e03d2c9c41);
#
#
#         var popup_00040a59b8eb9ee0eb587b789850354a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ba34f3a61068ef18f07d2e39a0647750 = $(`&lt;div id=&quot;html_ba34f3a61068ef18f07d2e39a0647750&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_00040a59b8eb9ee0eb587b789850354a.setContent(html_ba34f3a61068ef18f07d2e39a0647750);
#
#
#
#         marker_8be857b173b5f6ceb6b105b95564272c.bindPopup(popup_00040a59b8eb9ee0eb587b789850354a)
#         ;
#
#
#
#
#             var marker_8a7d629694b2b975fa8b57b13fb99144 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_b3053c51eda50515479f72e03d2c9c41);
#
#
#         var popup_591fd9151922273bb04263729ba30b97 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_22e44ce5dcd3e1aa8e4b99b7a8073a68 = $(`&lt;div id=&quot;html_22e44ce5dcd3e1aa8e4b99b7a8073a68&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_591fd9151922273bb04263729ba30b97.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4243fed98bc9e08e054fe9c018256f1f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4243fed98bc9e08e054fe9c018256f1f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4243fed98bc9e08e054fe9c018256f1f = L.map(
#                 &quot;map_4243fed98bc9e08e054fe9c018256f1f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_969c4999fbce8964ed11fbc708917a73 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_969c4999fbce8964ed11fbc708917a73.addTo(map_4243fed98bc9e08e054fe9c018256f1f);
#
#
#             var feature_group_51d7102d6d572cf742276e5614bcb86f = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_5cda86291e0c30b9c2fda104581aa836 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_51d7102d6d572cf742276e5614bcb86f);
#
#
#         var popup_c22a204c9aee877b800d8d68f8f33e83 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ee2255134455faefc97c09719b790dc8 = $(`&lt;div id=&quot;html_ee2255134455faefc97c09719b790dc8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_c22a204c9aee877b800d8d68f8f33e83.setContent(html_ee2255134455faefc97c09719b790dc8);
#
#
#
#         marker_5cda86291e0c30b9c2fda104581aa836.bindPopup(popup_c22a204c9aee877b800d8d68f8f33e83)
#         ;
#
#
#
#
#             var marker_4c0ec95679c8476f8e735f77c8d1b025 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_51d7102d6d572cf742276e5614bcb86f);
#
#
#         var popup_73616d71b0b9fcfd7dfba5f245bb252d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c880b6e4b242eb5051c18b591ef090fe = $(`&lt;div id=&quot;html_c880b6e4b242eb5051c18b591ef090fe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_73616d71b0b9fcfd7dfba5f245bb252d.setContent(html_c880b6e4b242eb5051c18b591ef090fe);
#
#
#
#         marker_4c0ec95679c8476f8e735f77c8d1b025.bindPopup(popup_73616d71b0b9fcfd7dfba5f245bb252d)
#         ;
#
#
#
#
#             var marker_9bdfa97b385936a107a0d28a6e5bf684 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_51d7102d6d572cf742276e5614bcb86f);
#
#
#         var popup_1a6a54bab734f44d0eb54404d9c1a7f7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_40d6e245b580ac3986997a4ade09b087 = $(`&lt;div id=&quot;html_40d6e245b580ac3986997a4ade09b087&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_1a6a54bab734f44d0eb54404d9c1a7f7.setContent(html_40d6e245b580ac3986997a4ade09b087);
#
#
#
#         marker_9bdfa97b385936a107a0d28a6e5bf684.bindPopup(popup_1a6a54bab734f44d0eb54404d9c1a7f7)
#         ;
#
#
#
#
#             var marker_2358542b305aef155fb6881d7271f6e2 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_51d7102d6d572cf742276e5614bcb86f);
#
#
#         var popup_5c87e0c6e914d389ec3cfd61419d7760 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f10a00c621fd5fa8264853ba40ec9d36 = $(`&lt;div id=&quot;html_f10a00c621fd5fa8264853ba40ec9d36&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_5c87e0c6e914d389ec3cfd61419d7760.setContent(html_f10a00c621fd5fa8264853ba40ec9d36);
#
#
#
#         marker_2358542b305aef155fb6881d7271f6e2.bindPopup(popup_5c87e0c6e914d389ec3cfd61419d7760)
#         ;
#
#
#
#
#             var marker_c1b854f893e3a5a107e70489e22152cf = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_51d7102d6d572cf742276e5614bcb86f);
#
#
#         var popup_b48a53744fe84d34de3648f01af35f40 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e7adfe465a462de852018f00eeab2c13 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e7adfe465a462de852018f00eeab2c13&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e7adfe465a462de852018f00eeab2c13 = L.map(
#                 &quot;map_e7adfe465a462de852018f00eeab2c13&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ebad9b0f5405264adbc96e8aa1bb7fb6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ebad9b0f5405264adbc96e8aa1bb7fb6.addTo(map_e7adfe465a462de852018f00eeab2c13);
#
#
#             var feature_group_5d976d0887b67234b736e5d517b741f4 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_5d976d0887b67234b736e5d517b741f4.addTo(map_e7adfe465a462de852018f00eeab2c13);
#
#
#             var feature_group_sub_group_3e3f119cff1a517df10f71bd735da8b4 = L.featureGroup.subGroup(
#                 feature_group_5d976d0887b67234b736e5d517b741f4
#             );
#
#
#             var marker_b353057ea026b1e0627815686bdedff7 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_3e3f119cff1a517df10f71bd735da8b4);
#
#
#         var popup_05ac3d8968bec24009ab1f44cfcc9cfb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_eee9e5fad2e67e006ad636a92bf8c7a8 = $(`&lt;div id=&quot;html_eee9e5fad2e67e006ad636a92bf8c7a8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_05ac3d8968bec24009ab1f44cfcc9cfb.setContent(html_eee9e5fad2e67e006ad636a92bf8c7a8);
#
#
#
#         marker_b353057ea026b1e0627815686bdedff7.bindPopup(popup_05ac3d8968bec24009ab1f44cfcc9cfb)
#         ;
#
#
#
#
#             var marker_37cbf7ce97bf538c8c342aac05be7dfd = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_3e3f119cff1a517df10f71bd735da8b4);
#
#
#         var popup_2cbef5273a2687f98eecb5eadae318b0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_296a3408a15fc13b0d5c64976b16cf9c = $(`&lt;div id=&quot;html_296a3408a15fc13b0d5c64976b16cf9c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_2cbef5273a2687f98eecb5eadae318b0.setContent(html_296a3408a15fc13b0d5c64976b16cf9c);
#
#
#
#         marker_37cbf7ce97bf538c8c342aac05be7dfd.bindPopup(popup_2cbef5273a2687f98eecb5eadae318b0)
#         ;
#
#
#
#
#             var marker_bd6869b541a2708c95e923ddfd4c337c = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_3e3f119cff1a517df10f71bd735da8b4);
#
#
#         var popup_ca412c484404bf401e6bad3b1c07c505 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_76404f3a4697ceaf09500c461f96c00f = $(`&lt;div id=&quot;html_76404f3a4697ceaf09500c461f96c00f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_ca412c484404bf401e6bad3b1c07c505.setContent(html_76404f3a4697ceaf09500c461f96c00f);
#
#
#
#         marker_bd6869b541a2708c95e923ddfd4c337c.bindPopup(popup_ca412c484404bf401e6bad3b1c07c505)
#         ;
#
#
#
#
#             var marker_04a88af2fe7a4add2c80a74a51c63714 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_3e3f119cff1a517df10f71bd735da8b4);
#
#
#         var popup_94d6027494d92a4db68b93e02d4356f0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ebbb5ff89f9bbe7146e92eddedd00115 = $(`&lt;div id=&quot;html_ebbb5ff89f9bbe7146e92eddedd00115&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_94d6027494d92a4db68b93e02d4356f0.setContent(html_ebbb5ff89f9bbe7146e92eddedd00115);
#
#
#
#         marker_
