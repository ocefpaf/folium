# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_746d11c83779767e766d09388179353b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_746d11c83779767e766d09388179353b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_746d11c83779767e766d09388179353b = L.map(
#                 &quot;map_746d11c83779767e766d09388179353b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a2190b242022a4c31949eff228e2ec7a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a2190b242022a4c31949eff228e2ec7a.addTo(map_746d11c83779767e766d09388179353b);
#
#
#             var marker_dce33958773df017b8c41af2df3d31c5 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_746d11c83779767e766d09388179353b);
#
#
#         var popup_335382ba7cf94aa5ca64e4765e9a0452 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5a2d6bf4e8f502ba612acf6dd4fc5a85 = $(`&lt;div id=&quot;html_5a2d6bf4e8f502ba612acf6dd4fc5a85&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_335382ba7cf94aa5ca64e4765e9a0452.setContent(html_5a2d6bf4e8f502ba612acf6dd4fc5a85);
#
#
#
#         marker_dce33958773df017b8c41af2df3d31c5.bindPopup(popup_335382ba7cf94aa5ca64e4765e9a0452)
#         ;
#
#
#
#
#             var marker_9f118826c9f44df4c5d200157f5e921f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_746d11c83779767e766d09388179353b);
#
#
#         var popup_8b3d96b79f409ea98a2d9c5d462e2806 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4065468cc5bb1ca10b63bf0c00d11a2f = $(`&lt;div id=&quot;html_4065468cc5bb1ca10b63bf0c00d11a2f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_8b3d96b79f409ea98a2d9c5d462e2806.setContent(html_4065468cc5bb1ca10b63bf0c00d11a2f);
#
#
#
#         marker_9f118826c9f44df4c5d200157f5e921f.bindPopup(popup_8b3d96b79f409ea98a2d9c5d462e2806)
#         ;
#
#
#
#
#             var marker_6f7ad1c26c42a9fad80575248a5da119 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_746d11c83779767e766d09388179353b);
#
#
#         var popup_ed9d6a49d157be185732651ff5e7ef9a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2cdac13225b52f353377ab90f1aefb9a = $(`&lt;div id=&quot;html_2cdac13225b52f353377ab90f1aefb9a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_ed9d6a49d157be185732651ff5e7ef9a.setContent(html_2cdac13225b52f353377ab90f1aefb9a);
#
#
#
#         marker_6f7ad1c26c42a9fad80575248a5da119.bindPopup(popup_ed9d6a49d157be185732651ff5e7ef9a)
#         ;
#
#
#
#
#             var marker_855293656c880825d2469e73530e6abf = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_746d11c83779767e766d09388179353b);
#
#
#         var popup_c1780a2db3bca99529c99226e9d5da4b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_758239fabf38754dc7ef76942dec7c62 = $(`&lt;div id=&quot;html_758239fabf38754dc7ef76942dec7c62&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_c1780a2db3bca99529c99226e9d5da4b.setContent(html_758239fabf38754dc7ef76942dec7c62);
#
#
#
#         marker_855293656c880825d2469e73530e6abf.bindPopup(popup_c1780a2db3bca99529c99226e9d5da4b)
#         ;
#
#
#
#
#             var marker_23f18652aa960f02f20b9ff9a3a098d0 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_746d11c83779767e766d09388179353b);
#
#
#         var popup_842b86d7337b07c04b0a9e5da8f20fb2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_eda5abf76ebff6bd35244dfa9eaacdb6 = $(`&lt;div id=&quot;html_eda5abf76ebff6bd35244dfa9eaacdb6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_842b86d7337b07c04b0a9e5da8f20fb2.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_16ef96a920ffc5cc42670adff6f1eb0e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_16ef96a920ffc5cc42670adff6f1eb0e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_16ef96a920ffc5cc42670adff6f1eb0e = L.map(
#                 &quot;map_16ef96a920ffc5cc42670adff6f1eb0e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b648cf2452ac3958868fff8d6c0849c4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b648cf2452ac3958868fff8d6c0849c4.addTo(map_16ef96a920ffc5cc42670adff6f1eb0e);
#
#
#             var feature_group_9835afb6652b8a0a46f2a8a34d656e00 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_8a7258e4dc859efd0652ff52116c4e6d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_9835afb6652b8a0a46f2a8a34d656e00);
#
#
#         var popup_4dc976a7e7039e4fe5e2716eac0a8e87 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dcdb91f824d32bdb6cae4dd7c15b8f02 = $(`&lt;div id=&quot;html_dcdb91f824d32bdb6cae4dd7c15b8f02&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_4dc976a7e7039e4fe5e2716eac0a8e87.setContent(html_dcdb91f824d32bdb6cae4dd7c15b8f02);
#
#
#
#         marker_8a7258e4dc859efd0652ff52116c4e6d.bindPopup(popup_4dc976a7e7039e4fe5e2716eac0a8e87)
#         ;
#
#
#
#
#             var marker_9290b88a9990cf8736853896d64bbc4e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_9835afb6652b8a0a46f2a8a34d656e00);
#
#
#         var popup_cced93950c2da828a5158abf16f5e621 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_10425b5b484cf1ae7f2a85d3359e75a8 = $(`&lt;div id=&quot;html_10425b5b484cf1ae7f2a85d3359e75a8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_cced93950c2da828a5158abf16f5e621.setContent(html_10425b5b484cf1ae7f2a85d3359e75a8);
#
#
#
#         marker_9290b88a9990cf8736853896d64bbc4e.bindPopup(popup_cced93950c2da828a5158abf16f5e621)
#         ;
#
#
#
#
#             var marker_778980555c1b7de1af63ef8d1e71a439 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_9835afb6652b8a0a46f2a8a34d656e00);
#
#
#         var popup_085de43521eed24e9745b555f82adbdc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4195b728a954e63db4cdd3883fa9c15e = $(`&lt;div id=&quot;html_4195b728a954e63db4cdd3883fa9c15e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_085de43521eed24e9745b555f82adbdc.setContent(html_4195b728a954e63db4cdd3883fa9c15e);
#
#
#
#         marker_778980555c1b7de1af63ef8d1e71a439.bindPopup(popup_085de43521eed24e9745b555f82adbdc)
#         ;
#
#
#
#
#             var marker_71887810868249dc07786857236ed362 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_9835afb6652b8a0a46f2a8a34d656e00);
#
#
#         var popup_6a23eb04879760b7095569e41c4d72d9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8f8c1144211c66c452a1a06f99f4b7a5 = $(`&lt;div id=&quot;html_8f8c1144211c66c452a1a06f99f4b7a5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_6a23eb04879760b7095569e41c4d72d9.setContent(html_8f8c1144211c66c452a1a06f99f4b7a5);
#
#
#
#         marker_71887810868249dc07786857236ed362.bindPopup(popup_6a23eb04879760b7095569e41c4d72d9)
#         ;
#
#
#
#
#             var marker_7d6322d31e80c5e5f525bae0a24fb716 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_9835afb6652b8a0a46f2a8a34d656e00);
#
#
#         var popup_f40ad97e9ff63520b7131bd115e5c5a8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3d933241d30904f1ba7929b9a4f84f19 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3d933241d30904f1ba7929b9a4f84f19&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3d933241d30904f1ba7929b9a4f84f19 = L.map(
#                 &quot;map_3d933241d30904f1ba7929b9a4f84f19&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3fdd8da95a27c0f03c202b024bcc1617 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3fdd8da95a27c0f03c202b024bcc1617.addTo(map_3d933241d30904f1ba7929b9a4f84f19);
#
#
#             var feature_group_89ebe8b2e71d9f31d8fabf7fa116340c = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_89ebe8b2e71d9f31d8fabf7fa116340c.addTo(map_3d933241d30904f1ba7929b9a4f84f19);
#
#
#             var feature_group_sub_group_96aac5e79cdd8be0c09be2d433fb176d = L.featureGroup.subGroup(
#                 feature_group_89ebe8b2e71d9f31d8fabf7fa116340c
#             );
#
#
#             var marker_94289a0d6148ca5eced783c43fc380c3 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_96aac5e79cdd8be0c09be2d433fb176d);
#
#
#         var popup_c8e89a095ff4cc553b58339b7ce4c5e1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_290cba00e8bc859910326212e350af53 = $(`&lt;div id=&quot;html_290cba00e8bc859910326212e350af53&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_c8e89a095ff4cc553b58339b7ce4c5e1.setContent(html_290cba00e8bc859910326212e350af53);
#
#
#
#         marker_94289a0d6148ca5eced783c43fc380c3.bindPopup(popup_c8e89a095ff4cc553b58339b7ce4c5e1)
#         ;
#
#
#
#
#             var marker_e0069cd3e8be04bc1f736e539b86de16 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_96aac5e79cdd8be0c09be2d433fb176d);
#
#
#         var popup_4ec4b469a3139e112c8802c1f8e8bf49 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1ceaa83333d385916a0901c11ebc536f = $(`&lt;div id=&quot;html_1ceaa83333d385916a0901c11ebc536f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_4ec4b469a3139e112c8802c1f8e8bf49.setContent(html_1ceaa83333d385916a0901c11ebc536f);
#
#
#
#         marker_e0069cd3e8be04bc1f736e539b86de16.bindPopup(popup_4ec4b469a3139e112c8802c1f8e8bf49)
#         ;
#
#
#
#
#             var marker_eb767fdc1a04af59d19aaec8f8a728af = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_96aac5e79cdd8be0c09be2d433fb176d);
#
#
#         var popup_457bff6264c533c6258be3840616293a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cfe85e8aa8ee983812b88f23eb31adf9 = $(`&lt;div id=&quot;html_cfe85e8aa8ee983812b88f23eb31adf9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_457bff6264c533c6258be3840616293a.setContent(html_cfe85e8aa8ee983812b88f23eb31adf9);
#
#
#
#         marker_eb767fdc1a04af59d19aaec8f8a728af.bindPopup(popup_457bff6264c533c6258be3840616293a)
#         ;
#
#
#
#
#             var marker_06d355f0b81d216ea1bd373ea8c65eb5 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_96aac5e79cdd8be0c09be2d433fb176d);
#
#
#         var popup_f650beace3d836d2035cae8e4278f9bf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_99978f1f1bf57d6156037fc6477ff3eb = $(`&lt;div id=&quot;html_99978f1f1bf57d6156037fc6477ff3eb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_f650beace3d836d2035cae8e4278f9bf.setContent(html_99978f1f1bf57d6156037fc6477ff3eb);
#
#
#
#         marker_
