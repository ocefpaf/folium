# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ef2147137ce20615b211948166b59661 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ef2147137ce20615b211948166b59661&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ef2147137ce20615b211948166b59661 = L.map(
#                 &quot;map_ef2147137ce20615b211948166b59661&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fba974a4be3afe1e16833413b905a005 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_fba974a4be3afe1e16833413b905a005.addTo(map_ef2147137ce20615b211948166b59661);
#
#
#             var marker_8471d9db004ed94623b092929eb47d0f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_ef2147137ce20615b211948166b59661);
#
#
#         var popup_802ede19374aafdc3ae41eb67f175d63 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_302d35740816316da5abc852de18d697 = $(`&lt;div id=&quot;html_302d35740816316da5abc852de18d697&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_802ede19374aafdc3ae41eb67f175d63.setContent(html_302d35740816316da5abc852de18d697);
#
#
#
#         marker_8471d9db004ed94623b092929eb47d0f.bindPopup(popup_802ede19374aafdc3ae41eb67f175d63)
#         ;
#
#
#
#
#             var marker_c4e25125e599485d4b969423177df301 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_ef2147137ce20615b211948166b59661);
#
#
#         var popup_9b2703e8bd02baf9fe1390e2ed32e8be = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ebf1f88e4c932eb79c7b07768461b008 = $(`&lt;div id=&quot;html_ebf1f88e4c932eb79c7b07768461b008&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_9b2703e8bd02baf9fe1390e2ed32e8be.setContent(html_ebf1f88e4c932eb79c7b07768461b008);
#
#
#
#         marker_c4e25125e599485d4b969423177df301.bindPopup(popup_9b2703e8bd02baf9fe1390e2ed32e8be)
#         ;
#
#
#
#
#             var marker_09a8c8255b69aa8d2a90f11b9eea04c1 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_ef2147137ce20615b211948166b59661);
#
#
#         var popup_49e6249a0020ccf0ac2bb1b1e812fbeb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0cec49730b1c1c6f427d342381880fd1 = $(`&lt;div id=&quot;html_0cec49730b1c1c6f427d342381880fd1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_49e6249a0020ccf0ac2bb1b1e812fbeb.setContent(html_0cec49730b1c1c6f427d342381880fd1);
#
#
#
#         marker_09a8c8255b69aa8d2a90f11b9eea04c1.bindPopup(popup_49e6249a0020ccf0ac2bb1b1e812fbeb)
#         ;
#
#
#
#
#             var marker_6f6ddcf558b024f578128d94c70e0970 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_ef2147137ce20615b211948166b59661);
#
#
#         var popup_84cd635859bdcc103835aa6463ea4eae = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b0caa03e17a715d9c52020a5380a2ea4 = $(`&lt;div id=&quot;html_b0caa03e17a715d9c52020a5380a2ea4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_84cd635859bdcc103835aa6463ea4eae.setContent(html_b0caa03e17a715d9c52020a5380a2ea4);
#
#
#
#         marker_6f6ddcf558b024f578128d94c70e0970.bindPopup(popup_84cd635859bdcc103835aa6463ea4eae)
#         ;
#
#
#
#
#             var marker_81fb2ece301931395a13d9fd7633db47 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_ef2147137ce20615b211948166b59661);
#
#
#         var popup_8be374fb882ec564887596317feb321d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9d17586525a7d9ec7ca57182370b4df5 = $(`&lt;div id=&quot;html_9d17586525a7d9ec7ca57182370b4df5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_8be374fb882ec564887596317feb321d.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_35693b4a48e134e509bc66e660e7fd7b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_35693b4a48e134e509bc66e660e7fd7b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_35693b4a48e134e509bc66e660e7fd7b = L.map(
#                 &quot;map_35693b4a48e134e509bc66e660e7fd7b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0750e0b793e4af474c7f33658251a991 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0750e0b793e4af474c7f33658251a991.addTo(map_35693b4a48e134e509bc66e660e7fd7b);
#
#
#             var feature_group_9bf5c9386b554c597b35b1ff028e3b0f = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_0a76320bd3962ba748e179f2d42382e2 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_9bf5c9386b554c597b35b1ff028e3b0f);
#
#
#         var popup_0028f478749f29dfba8b1f6fce2e7d65 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_af81ec6366278d1f9ba3cf8dce892a49 = $(`&lt;div id=&quot;html_af81ec6366278d1f9ba3cf8dce892a49&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_0028f478749f29dfba8b1f6fce2e7d65.setContent(html_af81ec6366278d1f9ba3cf8dce892a49);
#
#
#
#         marker_0a76320bd3962ba748e179f2d42382e2.bindPopup(popup_0028f478749f29dfba8b1f6fce2e7d65)
#         ;
#
#
#
#
#             var marker_d89d273aef044ef3203a2df1a3f1aeb0 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_9bf5c9386b554c597b35b1ff028e3b0f);
#
#
#         var popup_394d277259e1b1e00bfc7dd0540c0933 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_56f7b190c2846c77a9fbeddda7ce58a2 = $(`&lt;div id=&quot;html_56f7b190c2846c77a9fbeddda7ce58a2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_394d277259e1b1e00bfc7dd0540c0933.setContent(html_56f7b190c2846c77a9fbeddda7ce58a2);
#
#
#
#         marker_d89d273aef044ef3203a2df1a3f1aeb0.bindPopup(popup_394d277259e1b1e00bfc7dd0540c0933)
#         ;
#
#
#
#
#             var marker_06ff0234dd2af4f1d6148efb5c033bf8 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_9bf5c9386b554c597b35b1ff028e3b0f);
#
#
#         var popup_fd573157294ed4b6144aea4a36e595ed = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5ebab249cda7bd36d37f5e93e72fe8e7 = $(`&lt;div id=&quot;html_5ebab249cda7bd36d37f5e93e72fe8e7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_fd573157294ed4b6144aea4a36e595ed.setContent(html_5ebab249cda7bd36d37f5e93e72fe8e7);
#
#
#
#         marker_06ff0234dd2af4f1d6148efb5c033bf8.bindPopup(popup_fd573157294ed4b6144aea4a36e595ed)
#         ;
#
#
#
#
#             var marker_8c8f955d107c5297c3c9d6efdc2467b3 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_9bf5c9386b554c597b35b1ff028e3b0f);
#
#
#         var popup_2da88fc04137d34fc624e7e3f64c1999 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7ac589770ade4e63889bce3f228291c9 = $(`&lt;div id=&quot;html_7ac589770ade4e63889bce3f228291c9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_2da88fc04137d34fc624e7e3f64c1999.setContent(html_7ac589770ade4e63889bce3f228291c9);
#
#
#
#         marker_8c8f955d107c5297c3c9d6efdc2467b3.bindPopup(popup_2da88fc04137d34fc624e7e3f64c1999)
#         ;
#
#
#
#
#             var marker_14c962708278be95b6746365ab591e51 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_9bf5c9386b554c597b35b1ff028e3b0f);
#
#
#         var popup_c7bd353be4724299edf309f1bb869775 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7830e598bac8d49e0be828031e9e7da1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7830e598bac8d49e0be828031e9e7da1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7830e598bac8d49e0be828031e9e7da1 = L.map(
#                 &quot;map_7830e598bac8d49e0be828031e9e7da1&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3cfe3fb0a22c52c225dc761a8dc4df20 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3cfe3fb0a22c52c225dc761a8dc4df20.addTo(map_7830e598bac8d49e0be828031e9e7da1);
#
#
#             var feature_group_61b15047ca754fa4d96a84daf064d0e3 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_61b15047ca754fa4d96a84daf064d0e3.addTo(map_7830e598bac8d49e0be828031e9e7da1);
#
#
#             var feature_group_sub_group_cb493b12abc6921c9b75dc00f8d07c2b = L.featureGroup.subGroup(
#                 feature_group_61b15047ca754fa4d96a84daf064d0e3
#             );
#
#
#             var marker_a9a054cfe42a53f514a50add56037949 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_cb493b12abc6921c9b75dc00f8d07c2b);
#
#
#         var popup_f28b6b9d05d365ef4f0c71f0a22510fc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a901bb5b0f48d2d728415892e37ce1ec = $(`&lt;div id=&quot;html_a901bb5b0f48d2d728415892e37ce1ec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_f28b6b9d05d365ef4f0c71f0a22510fc.setContent(html_a901bb5b0f48d2d728415892e37ce1ec);
#
#
#
#         marker_a9a054cfe42a53f514a50add56037949.bindPopup(popup_f28b6b9d05d365ef4f0c71f0a22510fc)
#         ;
#
#
#
#
#             var marker_4318a855f84b0fae009452e0535b91af = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_cb493b12abc6921c9b75dc00f8d07c2b);
#
#
#         var popup_fc3c34bee3525661d79d688ca635effc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b8ec91b1f6fb4ebca8bd0860fde60756 = $(`&lt;div id=&quot;html_b8ec91b1f6fb4ebca8bd0860fde60756&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_fc3c34bee3525661d79d688ca635effc.setContent(html_b8ec91b1f6fb4ebca8bd0860fde60756);
#
#
#
#         marker_4318a855f84b0fae009452e0535b91af.bindPopup(popup_fc3c34bee3525661d79d688ca635effc)
#         ;
#
#
#
#
#             var marker_4790b05e53b22b9fc55454df7409ebc6 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_cb493b12abc6921c9b75dc00f8d07c2b);
#
#
#         var popup_4944282e60b2f74a254f3b0778dcc52e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_54ee2fa6302f734c76478a625c25c342 = $(`&lt;div id=&quot;html_54ee2fa6302f734c76478a625c25c342&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_4944282e60b2f74a254f3b0778dcc52e.setContent(html_54ee2fa6302f734c76478a625c25c342);
#
#
#
#         marker_4790b05e53b22b9fc55454df7409ebc6.bindPopup(popup_4944282e60b2f74a254f3b0778dcc52e)
#         ;
#
#
#
#
#             var marker_299f38c5253bbf1258670b47719d33b0 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_cb493b12abc6921c9b75dc00f8d07c2b);
#
#
#         var popup_f34adc86a9b6e1b51ae97da0daee136d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7c946d82a2cbecd7e44a6a802f9891fb = $(`&lt;div id=&quot;html_7c946d82a2cbecd7e44a6a802f9891fb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_f34adc86a9b6e1b51ae97da0daee136d.setContent(html_7c946d82a2cbecd7e44a6a802f9891fb);
#
#
#
#         marker_
