# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8ef713b3c625e41e3d55ab6adf9e1d20 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8ef713b3c625e41e3d55ab6adf9e1d20&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8ef713b3c625e41e3d55ab6adf9e1d20 = L.map(
#                 &quot;map_8ef713b3c625e41e3d55ab6adf9e1d20&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_878a6bdc5c3c7c8c415f877648e029fb = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_878a6bdc5c3c7c8c415f877648e029fb.addTo(map_8ef713b3c625e41e3d55ab6adf9e1d20);
#
#
#             var marker_8df38b25237a9bc1d63358aa10a30fb3 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_8ef713b3c625e41e3d55ab6adf9e1d20);
#
#
#         var popup_aeaf479e24eefe2b9fc1e647ec53d62a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1916c5ee563fe2c9478953a42140a436 = $(`&lt;div id=&quot;html_1916c5ee563fe2c9478953a42140a436&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_aeaf479e24eefe2b9fc1e647ec53d62a.setContent(html_1916c5ee563fe2c9478953a42140a436);
#
#
#
#         marker_8df38b25237a9bc1d63358aa10a30fb3.bindPopup(popup_aeaf479e24eefe2b9fc1e647ec53d62a)
#         ;
#
#
#
#
#             var marker_10f595c03b61021abd2d2ce1e37d0ac9 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_8ef713b3c625e41e3d55ab6adf9e1d20);
#
#
#         var popup_20118191d6de8d0f396633723ce7ad52 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9098bd643635cfca2a1a67b9ccfb2d0f = $(`&lt;div id=&quot;html_9098bd643635cfca2a1a67b9ccfb2d0f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_20118191d6de8d0f396633723ce7ad52.setContent(html_9098bd643635cfca2a1a67b9ccfb2d0f);
#
#
#
#         marker_10f595c03b61021abd2d2ce1e37d0ac9.bindPopup(popup_20118191d6de8d0f396633723ce7ad52)
#         ;
#
#
#
#
#             var marker_eb2ddff34ab5c3706f443a59de9d266e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_8ef713b3c625e41e3d55ab6adf9e1d20);
#
#
#         var popup_e9ca57f6d771d5b2e48681d384d70e66 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_537e25c7999f428bfc9076cebe4d5fa0 = $(`&lt;div id=&quot;html_537e25c7999f428bfc9076cebe4d5fa0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_e9ca57f6d771d5b2e48681d384d70e66.setContent(html_537e25c7999f428bfc9076cebe4d5fa0);
#
#
#
#         marker_eb2ddff34ab5c3706f443a59de9d266e.bindPopup(popup_e9ca57f6d771d5b2e48681d384d70e66)
#         ;
#
#
#
#
#             var marker_d9ff0feaffeaefdbab26e03ce9bd4609 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_8ef713b3c625e41e3d55ab6adf9e1d20);
#
#
#         var popup_21a404627ed6457fb8663afa36bc7c2b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3736e8a57acd0122ffd1f83c03f3110c = $(`&lt;div id=&quot;html_3736e8a57acd0122ffd1f83c03f3110c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_21a404627ed6457fb8663afa36bc7c2b.setContent(html_3736e8a57acd0122ffd1f83c03f3110c);
#
#
#
#         marker_d9ff0feaffeaefdbab26e03ce9bd4609.bindPopup(popup_21a404627ed6457fb8663afa36bc7c2b)
#         ;
#
#
#
#
#             var marker_e3817d693ea7aca074805c03f24154ff = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_8ef713b3c625e41e3d55ab6adf9e1d20);
#
#
#         var popup_f88eaee19d30eda169590ddd6901f489 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_22eb5637cf772b88d154d24df77378d4 = $(`&lt;div id=&quot;html_22eb5637cf772b88d154d24df77378d4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_f88eaee19d30eda169590ddd6901f489.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_df6babe6287faf34601047f0abc7b449 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_df6babe6287faf34601047f0abc7b449&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_df6babe6287faf34601047f0abc7b449 = L.map(
#                 &quot;map_df6babe6287faf34601047f0abc7b449&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b2e5bcdbeeb22d74fbe6bb8d5d5ce654 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b2e5bcdbeeb22d74fbe6bb8d5d5ce654.addTo(map_df6babe6287faf34601047f0abc7b449);
#
#
#             var feature_group_671acf69bf398f3fac3941d165452d76 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_7bb735bd4da0a39bfe8cce16bda2ef4f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_671acf69bf398f3fac3941d165452d76);
#
#
#         var popup_c2bf06584d90706e6176d0e382ede08f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ab1e4c280b0fd842594b3157498c0cce = $(`&lt;div id=&quot;html_ab1e4c280b0fd842594b3157498c0cce&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_c2bf06584d90706e6176d0e382ede08f.setContent(html_ab1e4c280b0fd842594b3157498c0cce);
#
#
#
#         marker_7bb735bd4da0a39bfe8cce16bda2ef4f.bindPopup(popup_c2bf06584d90706e6176d0e382ede08f)
#         ;
#
#
#
#
#             var marker_ca7165063146cf9552210b8b11633a7e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_671acf69bf398f3fac3941d165452d76);
#
#
#         var popup_b9304166edfe2b4762bb6f9bbea8a95f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cb80bba2524ab5e33ca07edf5da35e5b = $(`&lt;div id=&quot;html_cb80bba2524ab5e33ca07edf5da35e5b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_b9304166edfe2b4762bb6f9bbea8a95f.setContent(html_cb80bba2524ab5e33ca07edf5da35e5b);
#
#
#
#         marker_ca7165063146cf9552210b8b11633a7e.bindPopup(popup_b9304166edfe2b4762bb6f9bbea8a95f)
#         ;
#
#
#
#
#             var marker_f6ec9043d9e8d44e8a6e85e8856f8655 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_671acf69bf398f3fac3941d165452d76);
#
#
#         var popup_495ec674cc053d1288e0c0f3e088bb2f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_edf2eb9d4ef9c448949a07747ab50d4d = $(`&lt;div id=&quot;html_edf2eb9d4ef9c448949a07747ab50d4d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_495ec674cc053d1288e0c0f3e088bb2f.setContent(html_edf2eb9d4ef9c448949a07747ab50d4d);
#
#
#
#         marker_f6ec9043d9e8d44e8a6e85e8856f8655.bindPopup(popup_495ec674cc053d1288e0c0f3e088bb2f)
#         ;
#
#
#
#
#             var marker_9e096ada0944a9a735787cf85fe69eaf = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_671acf69bf398f3fac3941d165452d76);
#
#
#         var popup_02e192f8f4e9ab30a8d88b2b99252e6b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5dbd9f337b9e589f652aa6d1ed4260e8 = $(`&lt;div id=&quot;html_5dbd9f337b9e589f652aa6d1ed4260e8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_02e192f8f4e9ab30a8d88b2b99252e6b.setContent(html_5dbd9f337b9e589f652aa6d1ed4260e8);
#
#
#
#         marker_9e096ada0944a9a735787cf85fe69eaf.bindPopup(popup_02e192f8f4e9ab30a8d88b2b99252e6b)
#         ;
#
#
#
#
#             var marker_130a249cddc05c7959fadfdfebc7dec7 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_671acf69bf398f3fac3941d165452d76);
#
#
#         var popup_23aacfe000c09b735639488b471e4042 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c9d99dcd6e6da6bb93af526a6c7437c5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c9d99dcd6e6da6bb93af526a6c7437c5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c9d99dcd6e6da6bb93af526a6c7437c5 = L.map(
#                 &quot;map_c9d99dcd6e6da6bb93af526a6c7437c5&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9fbf4a21c0d8b4a55e8958a60aaffe19 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9fbf4a21c0d8b4a55e8958a60aaffe19.addTo(map_c9d99dcd6e6da6bb93af526a6c7437c5);
#
#
#             var feature_group_58718ae19b9f7894ba9662f4a34c7bfa = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_58718ae19b9f7894ba9662f4a34c7bfa.addTo(map_c9d99dcd6e6da6bb93af526a6c7437c5);
#
#
#             var feature_group_sub_group_5066adb3ec1f471840945a4a3f6d48b8 = L.featureGroup.subGroup(
#                 feature_group_58718ae19b9f7894ba9662f4a34c7bfa
#             );
#
#
#             var marker_5ea268f4f56c75bef8a77135696ff2a6 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_5066adb3ec1f471840945a4a3f6d48b8);
#
#
#         var popup_2b67107804d0a3dc2b458522e8fb1e25 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f2ee71705eee67e4a695a14e715d45a1 = $(`&lt;div id=&quot;html_f2ee71705eee67e4a695a14e715d45a1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_2b67107804d0a3dc2b458522e8fb1e25.setContent(html_f2ee71705eee67e4a695a14e715d45a1);
#
#
#
#         marker_5ea268f4f56c75bef8a77135696ff2a6.bindPopup(popup_2b67107804d0a3dc2b458522e8fb1e25)
#         ;
#
#
#
#
#             var marker_ffd6f001d53a9cd5f1d5015f860dc642 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_5066adb3ec1f471840945a4a3f6d48b8);
#
#
#         var popup_3f9f141cde8f47bd8bdcbffce1dc3951 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_76ada81d31e1f8308494b77108a12810 = $(`&lt;div id=&quot;html_76ada81d31e1f8308494b77108a12810&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_3f9f141cde8f47bd8bdcbffce1dc3951.setContent(html_76ada81d31e1f8308494b77108a12810);
#
#
#
#         marker_ffd6f001d53a9cd5f1d5015f860dc642.bindPopup(popup_3f9f141cde8f47bd8bdcbffce1dc3951)
#         ;
#
#
#
#
#             var marker_58e36bcacff75e606691dabab88ecb44 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_5066adb3ec1f471840945a4a3f6d48b8);
#
#
#         var popup_070d228cfc17f48ff3b7bae40c184408 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5a0db9c315cdbb4962f01858790564c4 = $(`&lt;div id=&quot;html_5a0db9c315cdbb4962f01858790564c4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_070d228cfc17f48ff3b7bae40c184408.setContent(html_5a0db9c315cdbb4962f01858790564c4);
#
#
#
#         marker_58e36bcacff75e606691dabab88ecb44.bindPopup(popup_070d228cfc17f48ff3b7bae40c184408)
#         ;
#
#
#
#
#             var marker_38e1a6dae370821529119f0f489bf94e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_5066adb3ec1f471840945a4a3f6d48b8);
#
#
#         var popup_9b2fc2bc93f432fc39509420127a924d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_91e44efdec7b143807f30e5398b1e074 = $(`&lt;div id=&quot;html_91e44efdec7b143807f30e5398b1e074&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_9b2fc2bc93f432fc39509420127a924d.setContent(html_91e44efdec7b143807f30e5398b1e074);
#
#
#
#         marker_
