# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e6a8eb37a1c0e0b2d17ab20864535b69 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e6a8eb37a1c0e0b2d17ab20864535b69&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e6a8eb37a1c0e0b2d17ab20864535b69 = L.map(
#                 &quot;map_e6a8eb37a1c0e0b2d17ab20864535b69&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c5c7e429a3fa0496b7fd90571c0ff200 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c5c7e429a3fa0496b7fd90571c0ff200.addTo(map_e6a8eb37a1c0e0b2d17ab20864535b69);
#
#
#             var marker_7ae1a7488c49324d734d435bd97d07be = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_e6a8eb37a1c0e0b2d17ab20864535b69);
#
#
#         var popup_8dc048140e37c00badd4e95542e500da = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e39e8625308fe5ee3be1d93475f41736 = $(`&lt;div id=&quot;html_e39e8625308fe5ee3be1d93475f41736&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_8dc048140e37c00badd4e95542e500da.setContent(html_e39e8625308fe5ee3be1d93475f41736);
#
#
#
#         marker_7ae1a7488c49324d734d435bd97d07be.bindPopup(popup_8dc048140e37c00badd4e95542e500da)
#         ;
#
#
#
#
#             var marker_17f755b3ac417831c8e1520db9eb9c08 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_e6a8eb37a1c0e0b2d17ab20864535b69);
#
#
#         var popup_68bc5dff3eff3316a2a7fb812c9ecf6c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_aa7643347d168ca7da79ac65fee0148f = $(`&lt;div id=&quot;html_aa7643347d168ca7da79ac65fee0148f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_68bc5dff3eff3316a2a7fb812c9ecf6c.setContent(html_aa7643347d168ca7da79ac65fee0148f);
#
#
#
#         marker_17f755b3ac417831c8e1520db9eb9c08.bindPopup(popup_68bc5dff3eff3316a2a7fb812c9ecf6c)
#         ;
#
#
#
#
#             var marker_ecda8a06b54e4ebd8895941070ce7f64 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_e6a8eb37a1c0e0b2d17ab20864535b69);
#
#
#         var popup_5ec915d912a2748b68ba091298f52323 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6bd4b1cceb2e80751f057c0dbf5a0f43 = $(`&lt;div id=&quot;html_6bd4b1cceb2e80751f057c0dbf5a0f43&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_5ec915d912a2748b68ba091298f52323.setContent(html_6bd4b1cceb2e80751f057c0dbf5a0f43);
#
#
#
#         marker_ecda8a06b54e4ebd8895941070ce7f64.bindPopup(popup_5ec915d912a2748b68ba091298f52323)
#         ;
#
#
#
#
#             var marker_0b536c4b393898d66586756ab961e5fe = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_e6a8eb37a1c0e0b2d17ab20864535b69);
#
#
#         var popup_66c06532ffc667dbe3994d1bf49e7fb3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_92f10c16dec038ff5ac4722206d20811 = $(`&lt;div id=&quot;html_92f10c16dec038ff5ac4722206d20811&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_66c06532ffc667dbe3994d1bf49e7fb3.setContent(html_92f10c16dec038ff5ac4722206d20811);
#
#
#
#         marker_0b536c4b393898d66586756ab961e5fe.bindPopup(popup_66c06532ffc667dbe3994d1bf49e7fb3)
#         ;
#
#
#
#
#             var marker_3b947aae1b52cbc9e34e611fa098cdeb = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_e6a8eb37a1c0e0b2d17ab20864535b69);
#
#
#         var popup_810b4690163be341102583b8e9394bfa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_28c1b5481df042710947e1b0b5ca393b = $(`&lt;div id=&quot;html_28c1b5481df042710947e1b0b5ca393b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_810b4690163be341102583b8e9394bfa.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7343b5a6913a5ace33ebf09328518334 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7343b5a6913a5ace33ebf09328518334&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7343b5a6913a5ace33ebf09328518334 = L.map(
#                 &quot;map_7343b5a6913a5ace33ebf09328518334&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d62fc4948511359277600c9e24461789 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d62fc4948511359277600c9e24461789.addTo(map_7343b5a6913a5ace33ebf09328518334);
#
#
#             var feature_group_0c8c9fc8e76512b6368cd8b8d4d69fce = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_0b254d4d7b574d4f2cafffc5f116f5f5 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_0c8c9fc8e76512b6368cd8b8d4d69fce);
#
#
#         var popup_0af8d57e34f35d6d5e4f4c02ed9cbe7a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ceb8b1294cec711b4795949268f8c61f = $(`&lt;div id=&quot;html_ceb8b1294cec711b4795949268f8c61f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_0af8d57e34f35d6d5e4f4c02ed9cbe7a.setContent(html_ceb8b1294cec711b4795949268f8c61f);
#
#
#
#         marker_0b254d4d7b574d4f2cafffc5f116f5f5.bindPopup(popup_0af8d57e34f35d6d5e4f4c02ed9cbe7a)
#         ;
#
#
#
#
#             var marker_1f4f7f4a623e212211d97c9721caa23e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_0c8c9fc8e76512b6368cd8b8d4d69fce);
#
#
#         var popup_bb55e314f5169c3c7c191a01174ab576 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_706b50566a315af5c3a01b460d853223 = $(`&lt;div id=&quot;html_706b50566a315af5c3a01b460d853223&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_bb55e314f5169c3c7c191a01174ab576.setContent(html_706b50566a315af5c3a01b460d853223);
#
#
#
#         marker_1f4f7f4a623e212211d97c9721caa23e.bindPopup(popup_bb55e314f5169c3c7c191a01174ab576)
#         ;
#
#
#
#
#             var marker_b9ad6f2757a69e5230f121cd22c1eaf0 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_0c8c9fc8e76512b6368cd8b8d4d69fce);
#
#
#         var popup_d4e9cc486aac2fcf00a7a4d641bb4f54 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3cf43289d2e9acc45768fdfcc7d78a68 = $(`&lt;div id=&quot;html_3cf43289d2e9acc45768fdfcc7d78a68&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_d4e9cc486aac2fcf00a7a4d641bb4f54.setContent(html_3cf43289d2e9acc45768fdfcc7d78a68);
#
#
#
#         marker_b9ad6f2757a69e5230f121cd22c1eaf0.bindPopup(popup_d4e9cc486aac2fcf00a7a4d641bb4f54)
#         ;
#
#
#
#
#             var marker_4f25e3ff667eea17f2f96c0d834287fc = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_0c8c9fc8e76512b6368cd8b8d4d69fce);
#
#
#         var popup_ee15cc81abe5cac30c789a5f1e594b12 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fcf92bdd6e819509a1f814d1c4242294 = $(`&lt;div id=&quot;html_fcf92bdd6e819509a1f814d1c4242294&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_ee15cc81abe5cac30c789a5f1e594b12.setContent(html_fcf92bdd6e819509a1f814d1c4242294);
#
#
#
#         marker_4f25e3ff667eea17f2f96c0d834287fc.bindPopup(popup_ee15cc81abe5cac30c789a5f1e594b12)
#         ;
#
#
#
#
#             var marker_626782f8dbf3e5a30ca23419ef66dcbd = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_0c8c9fc8e76512b6368cd8b8d4d69fce);
#
#
#         var popup_b1085d8aabe9ef535db02b5bf4698c21 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1d57982357d3a0e4eece975e1028c4d4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1d57982357d3a0e4eece975e1028c4d4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1d57982357d3a0e4eece975e1028c4d4 = L.map(
#                 &quot;map_1d57982357d3a0e4eece975e1028c4d4&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c3fbeedf0ab2620686ce7d4bc8a587c5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c3fbeedf0ab2620686ce7d4bc8a587c5.addTo(map_1d57982357d3a0e4eece975e1028c4d4);
#
#
#             var feature_group_f14786956264fe794beaa8079babfd77 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_f14786956264fe794beaa8079babfd77.addTo(map_1d57982357d3a0e4eece975e1028c4d4);
#
#
#             var feature_group_sub_group_14b077affbdad603639a0fef1e8dda03 = L.featureGroup.subGroup(
#                 feature_group_f14786956264fe794beaa8079babfd77
#             );
#
#
#             var marker_dfad4648ab3240e1476eb35212c4da16 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_14b077affbdad603639a0fef1e8dda03);
#
#
#         var popup_b25a4a60382879985ead593b3252a728 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5f012da00a123f0a6be08f18219fa890 = $(`&lt;div id=&quot;html_5f012da00a123f0a6be08f18219fa890&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_b25a4a60382879985ead593b3252a728.setContent(html_5f012da00a123f0a6be08f18219fa890);
#
#
#
#         marker_dfad4648ab3240e1476eb35212c4da16.bindPopup(popup_b25a4a60382879985ead593b3252a728)
#         ;
#
#
#
#
#             var marker_a99b13784da86f37d63c9a0df34c7899 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_14b077affbdad603639a0fef1e8dda03);
#
#
#         var popup_27719ec86d0c98e1c2b4fcd76e8935ad = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c3816f11420a38dd2bd8f40de14d86d7 = $(`&lt;div id=&quot;html_c3816f11420a38dd2bd8f40de14d86d7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_27719ec86d0c98e1c2b4fcd76e8935ad.setContent(html_c3816f11420a38dd2bd8f40de14d86d7);
#
#
#
#         marker_a99b13784da86f37d63c9a0df34c7899.bindPopup(popup_27719ec86d0c98e1c2b4fcd76e8935ad)
#         ;
#
#
#
#
#             var marker_76f64a995352d07da4fe692dd2e2c58f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_14b077affbdad603639a0fef1e8dda03);
#
#
#         var popup_2041b17ff274f67bee293e534de603f9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_12bd3d2e40f4dc7a0a7b3cdf3aa47fec = $(`&lt;div id=&quot;html_12bd3d2e40f4dc7a0a7b3cdf3aa47fec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_2041b17ff274f67bee293e534de603f9.setContent(html_12bd3d2e40f4dc7a0a7b3cdf3aa47fec);
#
#
#
#         marker_76f64a995352d07da4fe692dd2e2c58f.bindPopup(popup_2041b17ff274f67bee293e534de603f9)
#         ;
#
#
#
#
#             var marker_7be11e00c9090e09ddda2f2488976b56 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_14b077affbdad603639a0fef1e8dda03);
#
#
#         var popup_d75d539134e5b94a09815749d71b90f2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5b4bb35a197930e065b0432ed0df1d77 = $(`&lt;div id=&quot;html_5b4bb35a197930e065b0432ed0df1d77&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_d75d539134e5b94a09815749d71b90f2.setContent(html_5b4bb35a197930e065b0432ed0df1d77);
#
#
#
#         marker_
