# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b962d50847447ba10bdf233a473e65c8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b962d50847447ba10bdf233a473e65c8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b962d50847447ba10bdf233a473e65c8 = L.map(
#                 &quot;map_b962d50847447ba10bdf233a473e65c8&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d7f1025e0324ff2dc568bf6196c7aae4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d7f1025e0324ff2dc568bf6196c7aae4.addTo(map_b962d50847447ba10bdf233a473e65c8);
#
#
#             var marker_38c967ced3d1cd2e75b2fbdc0ea2ad86 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_b962d50847447ba10bdf233a473e65c8);
#
#
#         var popup_93395fcc56bbe7fd38e3c9e674db3b18 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_70c2481ed68e8313d61c2738fc536e36 = $(`&lt;div id=&quot;html_70c2481ed68e8313d61c2738fc536e36&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_93395fcc56bbe7fd38e3c9e674db3b18.setContent(html_70c2481ed68e8313d61c2738fc536e36);
#
#
#
#         marker_38c967ced3d1cd2e75b2fbdc0ea2ad86.bindPopup(popup_93395fcc56bbe7fd38e3c9e674db3b18)
#         ;
#
#
#
#
#             var marker_14ec9afe8fd2b4a1c589bfe62606bcf2 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_b962d50847447ba10bdf233a473e65c8);
#
#
#         var popup_7c1743c7781573b3d661c1e7f59fe90b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3b5e2ba3990c9a5b1059c1519aae2f88 = $(`&lt;div id=&quot;html_3b5e2ba3990c9a5b1059c1519aae2f88&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_7c1743c7781573b3d661c1e7f59fe90b.setContent(html_3b5e2ba3990c9a5b1059c1519aae2f88);
#
#
#
#         marker_14ec9afe8fd2b4a1c589bfe62606bcf2.bindPopup(popup_7c1743c7781573b3d661c1e7f59fe90b)
#         ;
#
#
#
#
#             var marker_c62dcbd19329be56bb5b6dbbc0b70eb8 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_b962d50847447ba10bdf233a473e65c8);
#
#
#         var popup_479f6c8546c10cedd139b2f8910a7c9f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c5a96e4a6d32d9921db2902d7a140ab4 = $(`&lt;div id=&quot;html_c5a96e4a6d32d9921db2902d7a140ab4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_479f6c8546c10cedd139b2f8910a7c9f.setContent(html_c5a96e4a6d32d9921db2902d7a140ab4);
#
#
#
#         marker_c62dcbd19329be56bb5b6dbbc0b70eb8.bindPopup(popup_479f6c8546c10cedd139b2f8910a7c9f)
#         ;
#
#
#
#
#             var marker_0d839db06e2b7bf269ac2221c0f25e2c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_b962d50847447ba10bdf233a473e65c8);
#
#
#         var popup_081735741e40847d37144dc441862612 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1a9bf240e8bb895186e9cb420709aa28 = $(`&lt;div id=&quot;html_1a9bf240e8bb895186e9cb420709aa28&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_081735741e40847d37144dc441862612.setContent(html_1a9bf240e8bb895186e9cb420709aa28);
#
#
#
#         marker_0d839db06e2b7bf269ac2221c0f25e2c.bindPopup(popup_081735741e40847d37144dc441862612)
#         ;
#
#
#
#
#             var marker_e6f2912f3ea294d56caf5aa98ac4d12c = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_b962d50847447ba10bdf233a473e65c8);
#
#
#         var popup_0edea7f7a62b822332aa0a4fe4c02ce5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2b49414e7ec135cea87e60ca45aa0d5b = $(`&lt;div id=&quot;html_2b49414e7ec135cea87e60ca45aa0d5b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_0edea7f7a62b822332aa0a4fe4c02ce5.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_126706928e4ee29f6352a3f5df1073e1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_126706928e4ee29f6352a3f5df1073e1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_126706928e4ee29f6352a3f5df1073e1 = L.map(
#                 &quot;map_126706928e4ee29f6352a3f5df1073e1&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4689be0166644ff9afab6def168b5da1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4689be0166644ff9afab6def168b5da1.addTo(map_126706928e4ee29f6352a3f5df1073e1);
#
#
#             var feature_group_0b3d6b40d9727e603327b51d7094b309 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_1a4f77beb14d4111f440d2cbc9058603 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_0b3d6b40d9727e603327b51d7094b309);
#
#
#         var popup_e26634a2c78e76a9debe74702fa89edc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6d011bd6eee6264e43f65f01d3207d5c = $(`&lt;div id=&quot;html_6d011bd6eee6264e43f65f01d3207d5c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_e26634a2c78e76a9debe74702fa89edc.setContent(html_6d011bd6eee6264e43f65f01d3207d5c);
#
#
#
#         marker_1a4f77beb14d4111f440d2cbc9058603.bindPopup(popup_e26634a2c78e76a9debe74702fa89edc)
#         ;
#
#
#
#
#             var marker_de219c953aedae50be8a6dba0d7b0e1e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_0b3d6b40d9727e603327b51d7094b309);
#
#
#         var popup_2e87fd2d7e1350e4a7b763984fbdce08 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ea7fffb65a068a937298ffc6781da9ed = $(`&lt;div id=&quot;html_ea7fffb65a068a937298ffc6781da9ed&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_2e87fd2d7e1350e4a7b763984fbdce08.setContent(html_ea7fffb65a068a937298ffc6781da9ed);
#
#
#
#         marker_de219c953aedae50be8a6dba0d7b0e1e.bindPopup(popup_2e87fd2d7e1350e4a7b763984fbdce08)
#         ;
#
#
#
#
#             var marker_e63c7db63fb6d7e3c6259139b47dc3ae = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_0b3d6b40d9727e603327b51d7094b309);
#
#
#         var popup_40fdafd5f6d35bc3432dbef8e2f16cbd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ef823ee59fa8b91627f4ade82930a647 = $(`&lt;div id=&quot;html_ef823ee59fa8b91627f4ade82930a647&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_40fdafd5f6d35bc3432dbef8e2f16cbd.setContent(html_ef823ee59fa8b91627f4ade82930a647);
#
#
#
#         marker_e63c7db63fb6d7e3c6259139b47dc3ae.bindPopup(popup_40fdafd5f6d35bc3432dbef8e2f16cbd)
#         ;
#
#
#
#
#             var marker_2d2a9f1e896fa0c47c9de8cee327cd84 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_0b3d6b40d9727e603327b51d7094b309);
#
#
#         var popup_b427c9ea013fedc7b940a42ddf79bd0a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4cec4948fe3e239be4c8e7025d88e432 = $(`&lt;div id=&quot;html_4cec4948fe3e239be4c8e7025d88e432&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_b427c9ea013fedc7b940a42ddf79bd0a.setContent(html_4cec4948fe3e239be4c8e7025d88e432);
#
#
#
#         marker_2d2a9f1e896fa0c47c9de8cee327cd84.bindPopup(popup_b427c9ea013fedc7b940a42ddf79bd0a)
#         ;
#
#
#
#
#             var marker_817898b789d0de2efb7cdc326e375d59 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_0b3d6b40d9727e603327b51d7094b309);
#
#
#         var popup_f509c653fb520fe60ec9e32b3a5c3422 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_79c8b13b39d77edad5e35424541462cc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_79c8b13b39d77edad5e35424541462cc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_79c8b13b39d77edad5e35424541462cc = L.map(
#                 &quot;map_79c8b13b39d77edad5e35424541462cc&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3975ada67a79b7287f2854b9f4988c89 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3975ada67a79b7287f2854b9f4988c89.addTo(map_79c8b13b39d77edad5e35424541462cc);
#
#
#             var feature_group_dbc19730aa495c0c6ed0c9606e76b727 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_dbc19730aa495c0c6ed0c9606e76b727.addTo(map_79c8b13b39d77edad5e35424541462cc);
#
#
#             var feature_group_sub_group_c4ce01a0fabc020ac3fb2f5112ae12c7 = L.featureGroup.subGroup(
#                 feature_group_dbc19730aa495c0c6ed0c9606e76b727
#             );
#
#
#             var marker_f30e48ad1ca5c5594705d9409dd15690 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_c4ce01a0fabc020ac3fb2f5112ae12c7);
#
#
#         var popup_352650303ba98410dfe7fe696fd571c4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e4bb32348da38bb055fe535ff9a324cd = $(`&lt;div id=&quot;html_e4bb32348da38bb055fe535ff9a324cd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_352650303ba98410dfe7fe696fd571c4.setContent(html_e4bb32348da38bb055fe535ff9a324cd);
#
#
#
#         marker_f30e48ad1ca5c5594705d9409dd15690.bindPopup(popup_352650303ba98410dfe7fe696fd571c4)
#         ;
#
#
#
#
#             var marker_0529e48b89bb9bc0f93674095edd1ae3 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_c4ce01a0fabc020ac3fb2f5112ae12c7);
#
#
#         var popup_566b6082f8f5d3f3aae0e1a641abbea1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9c5d3923da329a6f6fec2f5c5678c53a = $(`&lt;div id=&quot;html_9c5d3923da329a6f6fec2f5c5678c53a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_566b6082f8f5d3f3aae0e1a641abbea1.setContent(html_9c5d3923da329a6f6fec2f5c5678c53a);
#
#
#
#         marker_0529e48b89bb9bc0f93674095edd1ae3.bindPopup(popup_566b6082f8f5d3f3aae0e1a641abbea1)
#         ;
#
#
#
#
#             var marker_b09ecfb10a606ee08ce6db84d6aa430b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_c4ce01a0fabc020ac3fb2f5112ae12c7);
#
#
#         var popup_350add4ddb2849861b0f85e1426547c9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7a1d5549125957d327d38ce6836c4bb2 = $(`&lt;div id=&quot;html_7a1d5549125957d327d38ce6836c4bb2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_350add4ddb2849861b0f85e1426547c9.setContent(html_7a1d5549125957d327d38ce6836c4bb2);
#
#
#
#         marker_b09ecfb10a606ee08ce6db84d6aa430b.bindPopup(popup_350add4ddb2849861b0f85e1426547c9)
#         ;
#
#
#
#
#             var marker_fa19b50094c09ba7965a56f9dc5e45b8 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_c4ce01a0fabc020ac3fb2f5112ae12c7);
#
#
#         var popup_4c8ac9b9d9889f476780d97af1d1acf2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_021d83b5c0e4b936085c609e15c9ea2e = $(`&lt;div id=&quot;html_021d83b5c0e4b936085c609e15c9ea2e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_4c8ac9b9d9889f476780d97af1d1acf2.setContent(html_021d83b5c0e4b936085c609e15c9ea2e);
#
#
#
#         marker_
