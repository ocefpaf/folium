# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8f3f43a81823d6a38f12dbefb468f9fa {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8f3f43a81823d6a38f12dbefb468f9fa&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8f3f43a81823d6a38f12dbefb468f9fa = L.map(
#                 &quot;map_8f3f43a81823d6a38f12dbefb468f9fa&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2e5cd42497c94956a0eb034545587a53 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2e5cd42497c94956a0eb034545587a53.addTo(map_8f3f43a81823d6a38f12dbefb468f9fa);
#
#
#             var marker_aac2ffa029447a48bf83f15bab611a57 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_8f3f43a81823d6a38f12dbefb468f9fa);
#
#
#         var popup_acbe3067007eaa40b4b0580f4ff3f57d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b84f26e8732472baa3321724f7b9f825 = $(`&lt;div id=&quot;html_b84f26e8732472baa3321724f7b9f825&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_acbe3067007eaa40b4b0580f4ff3f57d.setContent(html_b84f26e8732472baa3321724f7b9f825);
#
#
#
#         marker_aac2ffa029447a48bf83f15bab611a57.bindPopup(popup_acbe3067007eaa40b4b0580f4ff3f57d)
#         ;
#
#
#
#
#             var marker_0eb508d774d8f158b2e18ee465ba3186 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_8f3f43a81823d6a38f12dbefb468f9fa);
#
#
#         var popup_083b3b88d412d689c77a3c88d1c4cdb4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6aeb368d55d3b3ec87e1328f59dc10d8 = $(`&lt;div id=&quot;html_6aeb368d55d3b3ec87e1328f59dc10d8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_083b3b88d412d689c77a3c88d1c4cdb4.setContent(html_6aeb368d55d3b3ec87e1328f59dc10d8);
#
#
#
#         marker_0eb508d774d8f158b2e18ee465ba3186.bindPopup(popup_083b3b88d412d689c77a3c88d1c4cdb4)
#         ;
#
#
#
#
#             var marker_b118132ba64856b9d19864ae32a8bf0e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_8f3f43a81823d6a38f12dbefb468f9fa);
#
#
#         var popup_4f60fe36d78ef81a13a9b8e03987ca44 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dc1973cbd9bbe925705248d54843c4ea = $(`&lt;div id=&quot;html_dc1973cbd9bbe925705248d54843c4ea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_4f60fe36d78ef81a13a9b8e03987ca44.setContent(html_dc1973cbd9bbe925705248d54843c4ea);
#
#
#
#         marker_b118132ba64856b9d19864ae32a8bf0e.bindPopup(popup_4f60fe36d78ef81a13a9b8e03987ca44)
#         ;
#
#
#
#
#             var marker_2f89d4d46b9480adad0d29987c36e5a2 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_8f3f43a81823d6a38f12dbefb468f9fa);
#
#
#         var popup_bfae4ca9278d5309d8b865b286d073c6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ae8be66ef6ed2c89fc9431c90620afd3 = $(`&lt;div id=&quot;html_ae8be66ef6ed2c89fc9431c90620afd3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_bfae4ca9278d5309d8b865b286d073c6.setContent(html_ae8be66ef6ed2c89fc9431c90620afd3);
#
#
#
#         marker_2f89d4d46b9480adad0d29987c36e5a2.bindPopup(popup_bfae4ca9278d5309d8b865b286d073c6)
#         ;
#
#
#
#
#             var marker_bd83c0ffaa847eac8f971117ed08b49b = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_8f3f43a81823d6a38f12dbefb468f9fa);
#
#
#         var popup_fdbacb0e434347d96599f4b82c75f624 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e5401558372e4591b0ee1ac4e9175951 = $(`&lt;div id=&quot;html_e5401558372e4591b0ee1ac4e9175951&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_fdbacb0e434347d96599f4b82c75f624.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3a92425337830e160e60c5f9c6c0e4a7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3a92425337830e160e60c5f9c6c0e4a7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3a92425337830e160e60c5f9c6c0e4a7 = L.map(
#                 &quot;map_3a92425337830e160e60c5f9c6c0e4a7&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e7dd6e47c4f94fd192c53df6a18be3fa = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e7dd6e47c4f94fd192c53df6a18be3fa.addTo(map_3a92425337830e160e60c5f9c6c0e4a7);
#
#
#             var feature_group_a9ad69c57481948fe9cba45a3a54ccd3 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_bd2f9bf71bf698a67dfa65ab502fc7b2 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_a9ad69c57481948fe9cba45a3a54ccd3);
#
#
#         var popup_e74317b3412b04f5bc2d610197a6b6c5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_18eb929a89202819d72c29d27d3f4220 = $(`&lt;div id=&quot;html_18eb929a89202819d72c29d27d3f4220&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_e74317b3412b04f5bc2d610197a6b6c5.setContent(html_18eb929a89202819d72c29d27d3f4220);
#
#
#
#         marker_bd2f9bf71bf698a67dfa65ab502fc7b2.bindPopup(popup_e74317b3412b04f5bc2d610197a6b6c5)
#         ;
#
#
#
#
#             var marker_06c39d620869fcbc4e6ebd75b6e30b46 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_a9ad69c57481948fe9cba45a3a54ccd3);
#
#
#         var popup_75e042b292646fed294ade2b07ac5e87 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4996791376cf7165852ed11246517fea = $(`&lt;div id=&quot;html_4996791376cf7165852ed11246517fea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_75e042b292646fed294ade2b07ac5e87.setContent(html_4996791376cf7165852ed11246517fea);
#
#
#
#         marker_06c39d620869fcbc4e6ebd75b6e30b46.bindPopup(popup_75e042b292646fed294ade2b07ac5e87)
#         ;
#
#
#
#
#             var marker_dba5b2e2b6490d41fe30cdd93e6e6911 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_a9ad69c57481948fe9cba45a3a54ccd3);
#
#
#         var popup_e6fd2d817c532202b362f7b2b1780983 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_63a0ece8b92412c3ef2be501c786ef1e = $(`&lt;div id=&quot;html_63a0ece8b92412c3ef2be501c786ef1e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_e6fd2d817c532202b362f7b2b1780983.setContent(html_63a0ece8b92412c3ef2be501c786ef1e);
#
#
#
#         marker_dba5b2e2b6490d41fe30cdd93e6e6911.bindPopup(popup_e6fd2d817c532202b362f7b2b1780983)
#         ;
#
#
#
#
#             var marker_ee4c1093b1f5d9e51f03d45a385ac328 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_a9ad69c57481948fe9cba45a3a54ccd3);
#
#
#         var popup_f18f85f7cbf1f5e106327458a177e7c8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fbf66582af36643ea1d50ae7c3c19a3e = $(`&lt;div id=&quot;html_fbf66582af36643ea1d50ae7c3c19a3e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_f18f85f7cbf1f5e106327458a177e7c8.setContent(html_fbf66582af36643ea1d50ae7c3c19a3e);
#
#
#
#         marker_ee4c1093b1f5d9e51f03d45a385ac328.bindPopup(popup_f18f85f7cbf1f5e106327458a177e7c8)
#         ;
#
#
#
#
#             var marker_1ec1d2206b15ab9bb7972ca2471761db = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_a9ad69c57481948fe9cba45a3a54ccd3);
#
#
#         var popup_f7cae1bfd0a1039eae37e2f2803dc6a3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b6f7c6811701f9bb34a7653ca332640e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b6f7c6811701f9bb34a7653ca332640e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b6f7c6811701f9bb34a7653ca332640e = L.map(
#                 &quot;map_b6f7c6811701f9bb34a7653ca332640e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dcad14848966dcfedfff1f108d2979a8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_dcad14848966dcfedfff1f108d2979a8.addTo(map_b6f7c6811701f9bb34a7653ca332640e);
#
#
#             var feature_group_e29d8307257da9b808bf1f9e655d5500 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_e29d8307257da9b808bf1f9e655d5500.addTo(map_b6f7c6811701f9bb34a7653ca332640e);
#
#
#             var feature_group_sub_group_fa798bd49b570162c3bc5f77a5ccd58f = L.featureGroup.subGroup(
#                 feature_group_e29d8307257da9b808bf1f9e655d5500
#             );
#
#
#             var marker_5388928282275ba494f0e6870de8b269 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_fa798bd49b570162c3bc5f77a5ccd58f);
#
#
#         var popup_6c303e92c2081245a07d4de65e51945b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ad83f9feda5b99a0cbbba5b7eeccc04c = $(`&lt;div id=&quot;html_ad83f9feda5b99a0cbbba5b7eeccc04c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_6c303e92c2081245a07d4de65e51945b.setContent(html_ad83f9feda5b99a0cbbba5b7eeccc04c);
#
#
#
#         marker_5388928282275ba494f0e6870de8b269.bindPopup(popup_6c303e92c2081245a07d4de65e51945b)
#         ;
#
#
#
#
#             var marker_301cd9cb7de7e09ebdd5866cb3383297 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_fa798bd49b570162c3bc5f77a5ccd58f);
#
#
#         var popup_12b6b4e9f18bcb6e5f5f1329dd97fe51 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2eb96857aee010fbce8cbf3495530a36 = $(`&lt;div id=&quot;html_2eb96857aee010fbce8cbf3495530a36&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_12b6b4e9f18bcb6e5f5f1329dd97fe51.setContent(html_2eb96857aee010fbce8cbf3495530a36);
#
#
#
#         marker_301cd9cb7de7e09ebdd5866cb3383297.bindPopup(popup_12b6b4e9f18bcb6e5f5f1329dd97fe51)
#         ;
#
#
#
#
#             var marker_2c5695659a525b2559bcbf13147cec8b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_fa798bd49b570162c3bc5f77a5ccd58f);
#
#
#         var popup_87719d3880bd2a3de02b400440f0ab9a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_245e60ef92dbd14f34f1fd526c601e29 = $(`&lt;div id=&quot;html_245e60ef92dbd14f34f1fd526c601e29&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_87719d3880bd2a3de02b400440f0ab9a.setContent(html_245e60ef92dbd14f34f1fd526c601e29);
#
#
#
#         marker_2c5695659a525b2559bcbf13147cec8b.bindPopup(popup_87719d3880bd2a3de02b400440f0ab9a)
#         ;
#
#
#
#
#             var marker_33846d6a88b5eb45a64ee90b940d5448 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_fa798bd49b570162c3bc5f77a5ccd58f);
#
#
#         var popup_f7a95fe08aa17048eded7581cb39dc1a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a8ae548ff0352a6e8b60bb37b4eb4031 = $(`&lt;div id=&quot;html_a8ae548ff0352a6e8b60bb37b4eb4031&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_f7a95fe08aa17048eded7581cb39dc1a.setContent(html_a8ae548ff0352a6e8b60bb37b4eb4031);
#
#
#
#         marker_
