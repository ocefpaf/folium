# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cc1b097ceaa313bc6d6192ebdb2cf614 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cc1b097ceaa313bc6d6192ebdb2cf614&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cc1b097ceaa313bc6d6192ebdb2cf614 = L.map(
#                 &quot;map_cc1b097ceaa313bc6d6192ebdb2cf614&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7062768fb517a4c369378834e16350a5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7062768fb517a4c369378834e16350a5.addTo(map_cc1b097ceaa313bc6d6192ebdb2cf614);
#
#
#             var marker_fc274973a8f692a1b981038924c9e6dd = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_cc1b097ceaa313bc6d6192ebdb2cf614);
#
#
#         var popup_a32844d447eb022c9c820ec19e9a79c8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d8f27a54c319f242a2991428f888d3f3 = $(`&lt;div id=&quot;html_d8f27a54c319f242a2991428f888d3f3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_a32844d447eb022c9c820ec19e9a79c8.setContent(html_d8f27a54c319f242a2991428f888d3f3);
#
#
#
#         marker_fc274973a8f692a1b981038924c9e6dd.bindPopup(popup_a32844d447eb022c9c820ec19e9a79c8)
#         ;
#
#
#
#
#             var marker_d64d5b8b304d084332e1c5a1c4896b4a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_cc1b097ceaa313bc6d6192ebdb2cf614);
#
#
#         var popup_3486ed5fe5914802645ff4f2cada09ec = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_14e306dced9cfaaffffff27c1d2efe15 = $(`&lt;div id=&quot;html_14e306dced9cfaaffffff27c1d2efe15&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_3486ed5fe5914802645ff4f2cada09ec.setContent(html_14e306dced9cfaaffffff27c1d2efe15);
#
#
#
#         marker_d64d5b8b304d084332e1c5a1c4896b4a.bindPopup(popup_3486ed5fe5914802645ff4f2cada09ec)
#         ;
#
#
#
#
#             var marker_4a867fca56d113e09705e031a615a1fa = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_cc1b097ceaa313bc6d6192ebdb2cf614);
#
#
#         var popup_7910cad2942986291c4f9b374effca90 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bbe734eda3a79a400609460738739b5f = $(`&lt;div id=&quot;html_bbe734eda3a79a400609460738739b5f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_7910cad2942986291c4f9b374effca90.setContent(html_bbe734eda3a79a400609460738739b5f);
#
#
#
#         marker_4a867fca56d113e09705e031a615a1fa.bindPopup(popup_7910cad2942986291c4f9b374effca90)
#         ;
#
#
#
#
#             var marker_6a0f2c8ccbe8eef7b4aedd6b9b84d984 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_cc1b097ceaa313bc6d6192ebdb2cf614);
#
#
#         var popup_7337ad550cae295ee830e035825709f8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6df04af6784ea510b021f3528c5b9cbb = $(`&lt;div id=&quot;html_6df04af6784ea510b021f3528c5b9cbb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_7337ad550cae295ee830e035825709f8.setContent(html_6df04af6784ea510b021f3528c5b9cbb);
#
#
#
#         marker_6a0f2c8ccbe8eef7b4aedd6b9b84d984.bindPopup(popup_7337ad550cae295ee830e035825709f8)
#         ;
#
#
#
#
#             var marker_b17757a90657ecaf144d3f6ac48ccc74 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_cc1b097ceaa313bc6d6192ebdb2cf614);
#
#
#         var popup_844a22c413f386b4686b466e9df43d70 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8510f0674458b01c2792ee43c9858c25 = $(`&lt;div id=&quot;html_8510f0674458b01c2792ee43c9858c25&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_844a22c413f386b4686b466e9df43d70.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b1b7c50f70a6e7924d4bcb96646d66dd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b1b7c50f70a6e7924d4bcb96646d66dd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b1b7c50f70a6e7924d4bcb96646d66dd = L.map(
#                 &quot;map_b1b7c50f70a6e7924d4bcb96646d66dd&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_00f17b2767d21a66ed039a5915117140 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_00f17b2767d21a66ed039a5915117140.addTo(map_b1b7c50f70a6e7924d4bcb96646d66dd);
#
#
#             var feature_group_b279bb28e288c7d7ce1802f9b1cb909d = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_4fddecf831e7c7c616836f28af00ea90 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_b279bb28e288c7d7ce1802f9b1cb909d);
#
#
#         var popup_dc344a722a5403ac321c996974c34f79 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_df0e48af2de297808a14d5e67b5dda24 = $(`&lt;div id=&quot;html_df0e48af2de297808a14d5e67b5dda24&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_dc344a722a5403ac321c996974c34f79.setContent(html_df0e48af2de297808a14d5e67b5dda24);
#
#
#
#         marker_4fddecf831e7c7c616836f28af00ea90.bindPopup(popup_dc344a722a5403ac321c996974c34f79)
#         ;
#
#
#
#
#             var marker_15c7d39066205e138fd85121e5beebe0 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_b279bb28e288c7d7ce1802f9b1cb909d);
#
#
#         var popup_1c3cd75ccc6ebcf6175d782c625e66f0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dc01642b19a2cb6dce1bb8ccb605fd49 = $(`&lt;div id=&quot;html_dc01642b19a2cb6dce1bb8ccb605fd49&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_1c3cd75ccc6ebcf6175d782c625e66f0.setContent(html_dc01642b19a2cb6dce1bb8ccb605fd49);
#
#
#
#         marker_15c7d39066205e138fd85121e5beebe0.bindPopup(popup_1c3cd75ccc6ebcf6175d782c625e66f0)
#         ;
#
#
#
#
#             var marker_39247d67f3f7282d513dd6d1692596fc = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_b279bb28e288c7d7ce1802f9b1cb909d);
#
#
#         var popup_9ab260fb9eba5e1af30781fc03a33366 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4ac7b7657cb7416643f162144acc7abb = $(`&lt;div id=&quot;html_4ac7b7657cb7416643f162144acc7abb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_9ab260fb9eba5e1af30781fc03a33366.setContent(html_4ac7b7657cb7416643f162144acc7abb);
#
#
#
#         marker_39247d67f3f7282d513dd6d1692596fc.bindPopup(popup_9ab260fb9eba5e1af30781fc03a33366)
#         ;
#
#
#
#
#             var marker_bcf787e86a681f78615fe978fe6cf2d9 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_b279bb28e288c7d7ce1802f9b1cb909d);
#
#
#         var popup_c048da9bea5646354bc8e6a888116fe6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7bcd326311ffcfc8444093b6d88d96b1 = $(`&lt;div id=&quot;html_7bcd326311ffcfc8444093b6d88d96b1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_c048da9bea5646354bc8e6a888116fe6.setContent(html_7bcd326311ffcfc8444093b6d88d96b1);
#
#
#
#         marker_bcf787e86a681f78615fe978fe6cf2d9.bindPopup(popup_c048da9bea5646354bc8e6a888116fe6)
#         ;
#
#
#
#
#             var marker_21d22f82470b994a553b6db9a7a4ebf3 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_b279bb28e288c7d7ce1802f9b1cb909d);
#
#
#         var popup_8806b1a427d4c77347990e7c96d7491f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8da15ef06a9952f6fde62d819da986e4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8da15ef06a9952f6fde62d819da986e4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8da15ef06a9952f6fde62d819da986e4 = L.map(
#                 &quot;map_8da15ef06a9952f6fde62d819da986e4&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0d1725df1ae93ef006be02f949a3a254 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0d1725df1ae93ef006be02f949a3a254.addTo(map_8da15ef06a9952f6fde62d819da986e4);
#
#
#             var feature_group_2841a298d486a482c794d17fa3239abe = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_2841a298d486a482c794d17fa3239abe.addTo(map_8da15ef06a9952f6fde62d819da986e4);
#
#
#             var feature_group_sub_group_826d00fbf27e16c957fd8989d63aec55 = L.featureGroup.subGroup(
#                 feature_group_2841a298d486a482c794d17fa3239abe
#             );
#
#
#             var marker_5cb5eb9c423b36575da3f76b4ed38c08 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_826d00fbf27e16c957fd8989d63aec55);
#
#
#         var popup_a7f79bb63a5985aa845fa00b49893602 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_04b481f33eb0e462c38d3faa6dc03819 = $(`&lt;div id=&quot;html_04b481f33eb0e462c38d3faa6dc03819&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_a7f79bb63a5985aa845fa00b49893602.setContent(html_04b481f33eb0e462c38d3faa6dc03819);
#
#
#
#         marker_5cb5eb9c423b36575da3f76b4ed38c08.bindPopup(popup_a7f79bb63a5985aa845fa00b49893602)
#         ;
#
#
#
#
#             var marker_432174d9047e6ea481552b3adaa83c93 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_826d00fbf27e16c957fd8989d63aec55);
#
#
#         var popup_b4339e3013626f735262b8ebf9a12446 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_93db6fadf77acc04dce7e06a5523a2b6 = $(`&lt;div id=&quot;html_93db6fadf77acc04dce7e06a5523a2b6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_b4339e3013626f735262b8ebf9a12446.setContent(html_93db6fadf77acc04dce7e06a5523a2b6);
#
#
#
#         marker_432174d9047e6ea481552b3adaa83c93.bindPopup(popup_b4339e3013626f735262b8ebf9a12446)
#         ;
#
#
#
#
#             var marker_b1a329705f4a173edc81cdfd09e20a9d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_826d00fbf27e16c957fd8989d63aec55);
#
#
#         var popup_526e70e6f9f7b9f325e3c7fb77751c76 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7775c2631375c722c66cefa2a3fef91a = $(`&lt;div id=&quot;html_7775c2631375c722c66cefa2a3fef91a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_526e70e6f9f7b9f325e3c7fb77751c76.setContent(html_7775c2631375c722c66cefa2a3fef91a);
#
#
#
#         marker_b1a329705f4a173edc81cdfd09e20a9d.bindPopup(popup_526e70e6f9f7b9f325e3c7fb77751c76)
#         ;
#
#
#
#
#             var marker_1d333d1a5e2132c55d848c4aac86b1cb = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_826d00fbf27e16c957fd8989d63aec55);
#
#
#         var popup_f8d9b764186f4abab6d0549bf5475915 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_04fbb53e13122fabcc356e96bdf7f4e0 = $(`&lt;div id=&quot;html_04fbb53e13122fabcc356e96bdf7f4e0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_f8d9b764186f4abab6d0549bf5475915.setContent(html_04fbb53e13122fabcc356e96bdf7f4e0);
#
#
#
#         marker_
