# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7d9e70929e5cd5874f506b1b749d5849 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7d9e70929e5cd5874f506b1b749d5849&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7d9e70929e5cd5874f506b1b749d5849 = L.map(
#                 &quot;map_7d9e70929e5cd5874f506b1b749d5849&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4db231ca6b9e72c1995946f1cf688189 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4db231ca6b9e72c1995946f1cf688189.addTo(map_7d9e70929e5cd5874f506b1b749d5849);
#
#
#             var marker_cea4aea53fdf75f53838a50edb75f336 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_7d9e70929e5cd5874f506b1b749d5849);
#
#
#         var popup_4fb7b35d96bfd737981010bd6b95b526 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9a4fe0f59f1cddf98511e88392133c6d = $(`&lt;div id=&quot;html_9a4fe0f59f1cddf98511e88392133c6d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_4fb7b35d96bfd737981010bd6b95b526.setContent(html_9a4fe0f59f1cddf98511e88392133c6d);
#
#
#
#         marker_cea4aea53fdf75f53838a50edb75f336.bindPopup(popup_4fb7b35d96bfd737981010bd6b95b526)
#         ;
#
#
#
#
#             var marker_743d69dd1bf8f9b5242984a148bc43eb = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_7d9e70929e5cd5874f506b1b749d5849);
#
#
#         var popup_38c2bb6c21529a9da765e920fdaabcd5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3d495e015c61aa61663c1f0356a014eb = $(`&lt;div id=&quot;html_3d495e015c61aa61663c1f0356a014eb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_38c2bb6c21529a9da765e920fdaabcd5.setContent(html_3d495e015c61aa61663c1f0356a014eb);
#
#
#
#         marker_743d69dd1bf8f9b5242984a148bc43eb.bindPopup(popup_38c2bb6c21529a9da765e920fdaabcd5)
#         ;
#
#
#
#
#             var marker_94d400eb9b35f7b3e510a86026b46a0c = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_7d9e70929e5cd5874f506b1b749d5849);
#
#
#         var popup_1d76a67f732cfd9266fffc68c10ecc1b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2045d71a372e0d1c6a5d0951ff73a12c = $(`&lt;div id=&quot;html_2045d71a372e0d1c6a5d0951ff73a12c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_1d76a67f732cfd9266fffc68c10ecc1b.setContent(html_2045d71a372e0d1c6a5d0951ff73a12c);
#
#
#
#         marker_94d400eb9b35f7b3e510a86026b46a0c.bindPopup(popup_1d76a67f732cfd9266fffc68c10ecc1b)
#         ;
#
#
#
#
#             var marker_764460624eda6951caf01d5b455960fc = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_7d9e70929e5cd5874f506b1b749d5849);
#
#
#         var popup_bf9c417a53899c9cd1f9c396a66a5cbc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_98d376d4dc10e531e8a34131a0bac385 = $(`&lt;div id=&quot;html_98d376d4dc10e531e8a34131a0bac385&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_bf9c417a53899c9cd1f9c396a66a5cbc.setContent(html_98d376d4dc10e531e8a34131a0bac385);
#
#
#
#         marker_764460624eda6951caf01d5b455960fc.bindPopup(popup_bf9c417a53899c9cd1f9c396a66a5cbc)
#         ;
#
#
#
#
#             var marker_837c79a64d2e2ad331b05eb8f83f29be = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_7d9e70929e5cd5874f506b1b749d5849);
#
#
#         var popup_ac95bf47cf04d3640b83b2fa18b95ace = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cc86d5fedcde1608bd704f9023d4ba6f = $(`&lt;div id=&quot;html_cc86d5fedcde1608bd704f9023d4ba6f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_ac95bf47cf04d3640b83b2fa18b95ace.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_961b3ce0f73ab5d6a853a15f32ce1d40 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_961b3ce0f73ab5d6a853a15f32ce1d40&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_961b3ce0f73ab5d6a853a15f32ce1d40 = L.map(
#                 &quot;map_961b3ce0f73ab5d6a853a15f32ce1d40&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7f9bfc3de314e5321628b74761904712 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7f9bfc3de314e5321628b74761904712.addTo(map_961b3ce0f73ab5d6a853a15f32ce1d40);
#
#
#             var feature_group_ce61122f908ec0f455622a67a768d72c = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_8b95a53a343a1133c2bf481abaa588eb = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_ce61122f908ec0f455622a67a768d72c);
#
#
#         var popup_6f582fbbbaa2d2f1c0a1bb72003a3f89 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_99003b3cc3bc383dc3dbe39341fc01a7 = $(`&lt;div id=&quot;html_99003b3cc3bc383dc3dbe39341fc01a7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_6f582fbbbaa2d2f1c0a1bb72003a3f89.setContent(html_99003b3cc3bc383dc3dbe39341fc01a7);
#
#
#
#         marker_8b95a53a343a1133c2bf481abaa588eb.bindPopup(popup_6f582fbbbaa2d2f1c0a1bb72003a3f89)
#         ;
#
#
#
#
#             var marker_ed565d9152bc067df447527dfa9ae80a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_ce61122f908ec0f455622a67a768d72c);
#
#
#         var popup_c92b246980f1c3486ea010d18fe184d4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4f4675142d70909a6e5a2869c7d36122 = $(`&lt;div id=&quot;html_4f4675142d70909a6e5a2869c7d36122&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_c92b246980f1c3486ea010d18fe184d4.setContent(html_4f4675142d70909a6e5a2869c7d36122);
#
#
#
#         marker_ed565d9152bc067df447527dfa9ae80a.bindPopup(popup_c92b246980f1c3486ea010d18fe184d4)
#         ;
#
#
#
#
#             var marker_cc8a3e9f80fb1837821f175aa385c3c9 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_ce61122f908ec0f455622a67a768d72c);
#
#
#         var popup_1fc12a7783d943a5b17fff92edbf2988 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fd985d2c4f0431fc745f8a05086b12c2 = $(`&lt;div id=&quot;html_fd985d2c4f0431fc745f8a05086b12c2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_1fc12a7783d943a5b17fff92edbf2988.setContent(html_fd985d2c4f0431fc745f8a05086b12c2);
#
#
#
#         marker_cc8a3e9f80fb1837821f175aa385c3c9.bindPopup(popup_1fc12a7783d943a5b17fff92edbf2988)
#         ;
#
#
#
#
#             var marker_2fa9b651e0bd5c53d35e16842db8a61d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_ce61122f908ec0f455622a67a768d72c);
#
#
#         var popup_325d4174439aec319637c859809dc712 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0a41a7c0602db15ac983a697acad1d45 = $(`&lt;div id=&quot;html_0a41a7c0602db15ac983a697acad1d45&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_325d4174439aec319637c859809dc712.setContent(html_0a41a7c0602db15ac983a697acad1d45);
#
#
#
#         marker_2fa9b651e0bd5c53d35e16842db8a61d.bindPopup(popup_325d4174439aec319637c859809dc712)
#         ;
#
#
#
#
#             var marker_4834aa109df51f8982af36c9339551d1 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_ce61122f908ec0f455622a67a768d72c);
#
#
#         var popup_f52f308227338bc74a6d2e8d58cf2e58 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_666f7df457ce0137f3a5e673cc576319 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_666f7df457ce0137f3a5e673cc576319&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_666f7df457ce0137f3a5e673cc576319 = L.map(
#                 &quot;map_666f7df457ce0137f3a5e673cc576319&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ebfe6172d7c75db3b995351663b85758 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ebfe6172d7c75db3b995351663b85758.addTo(map_666f7df457ce0137f3a5e673cc576319);
#
#
#             var feature_group_fdfb45a3802142c89717ec11d91926d5 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_fdfb45a3802142c89717ec11d91926d5.addTo(map_666f7df457ce0137f3a5e673cc576319);
#
#
#             var feature_group_sub_group_69b209cbdd5d665f97030daa5e97c967 = L.featureGroup.subGroup(
#                 feature_group_fdfb45a3802142c89717ec11d91926d5
#             );
#
#
#             var marker_a5d4934d5b8b7ec436f53a0c8e688714 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_69b209cbdd5d665f97030daa5e97c967);
#
#
#         var popup_4a8d0acbd9d9ba58450fa689a8a73b63 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_be869f9bdb2c01ceaadbb0a4f1d45d52 = $(`&lt;div id=&quot;html_be869f9bdb2c01ceaadbb0a4f1d45d52&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_4a8d0acbd9d9ba58450fa689a8a73b63.setContent(html_be869f9bdb2c01ceaadbb0a4f1d45d52);
#
#
#
#         marker_a5d4934d5b8b7ec436f53a0c8e688714.bindPopup(popup_4a8d0acbd9d9ba58450fa689a8a73b63)
#         ;
#
#
#
#
#             var marker_660f6c5347c0501074f1de44726fab98 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_69b209cbdd5d665f97030daa5e97c967);
#
#
#         var popup_5a4a35009198e7f189490cfd4a6f110d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_95170b858432e6373e10adb9fe23187e = $(`&lt;div id=&quot;html_95170b858432e6373e10adb9fe23187e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_5a4a35009198e7f189490cfd4a6f110d.setContent(html_95170b858432e6373e10adb9fe23187e);
#
#
#
#         marker_660f6c5347c0501074f1de44726fab98.bindPopup(popup_5a4a35009198e7f189490cfd4a6f110d)
#         ;
#
#
#
#
#             var marker_ad40bb5e9e08f41df1f5205ef8638d17 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_69b209cbdd5d665f97030daa5e97c967);
#
#
#         var popup_f8589069bffefad59cd64b64cfbf154e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7c56dc752406e8ba4e43d25238c56fef = $(`&lt;div id=&quot;html_7c56dc752406e8ba4e43d25238c56fef&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_f8589069bffefad59cd64b64cfbf154e.setContent(html_7c56dc752406e8ba4e43d25238c56fef);
#
#
#
#         marker_ad40bb5e9e08f41df1f5205ef8638d17.bindPopup(popup_f8589069bffefad59cd64b64cfbf154e)
#         ;
#
#
#
#
#             var marker_0fe759b79afcf4b54b3d134b6882036b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_69b209cbdd5d665f97030daa5e97c967);
#
#
#         var popup_26dc026e0f85a98fb2b13e5520247268 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_887f334c9711020ea251be9b6456154a = $(`&lt;div id=&quot;html_887f334c9711020ea251be9b6456154a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_26dc026e0f85a98fb2b13e5520247268.setContent(html_887f334c9711020ea251be9b6456154a);
#
#
#
#         marker_
