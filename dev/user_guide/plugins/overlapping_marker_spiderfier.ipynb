# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1397e71b6f59921a63b332bab03141b8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1397e71b6f59921a63b332bab03141b8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1397e71b6f59921a63b332bab03141b8 = L.map(
#                 &quot;map_1397e71b6f59921a63b332bab03141b8&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0ae33ecad280c7717e0772ef52fbf3d7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0ae33ecad280c7717e0772ef52fbf3d7.addTo(map_1397e71b6f59921a63b332bab03141b8);
#
#
#             var marker_59fbcc1232b212f0cb75f4cc35547e95 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_1397e71b6f59921a63b332bab03141b8);
#
#
#         var popup_366f89b58f01c093f831bfe782188cf6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_85d416201b7e327df9b7176ad1824622 = $(`&lt;div id=&quot;html_85d416201b7e327df9b7176ad1824622&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_366f89b58f01c093f831bfe782188cf6.setContent(html_85d416201b7e327df9b7176ad1824622);
#
#
#
#         marker_59fbcc1232b212f0cb75f4cc35547e95.bindPopup(popup_366f89b58f01c093f831bfe782188cf6)
#         ;
#
#
#
#
#             var marker_e4bf382aa2bd969de957c268cda3aa0a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_1397e71b6f59921a63b332bab03141b8);
#
#
#         var popup_8892292daadcd353e3b1d338ac8f6931 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_04364518dd28993984b1a182345020e8 = $(`&lt;div id=&quot;html_04364518dd28993984b1a182345020e8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_8892292daadcd353e3b1d338ac8f6931.setContent(html_04364518dd28993984b1a182345020e8);
#
#
#
#         marker_e4bf382aa2bd969de957c268cda3aa0a.bindPopup(popup_8892292daadcd353e3b1d338ac8f6931)
#         ;
#
#
#
#
#             var marker_ed7b48eb9d43369b445a0cdeddb00ce1 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_1397e71b6f59921a63b332bab03141b8);
#
#
#         var popup_5d29250553f59d4401c1f3ee6abee5cb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_322fd982160b20d2488e26b95fc07c3a = $(`&lt;div id=&quot;html_322fd982160b20d2488e26b95fc07c3a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_5d29250553f59d4401c1f3ee6abee5cb.setContent(html_322fd982160b20d2488e26b95fc07c3a);
#
#
#
#         marker_ed7b48eb9d43369b445a0cdeddb00ce1.bindPopup(popup_5d29250553f59d4401c1f3ee6abee5cb)
#         ;
#
#
#
#
#             var marker_8dd14c91d10fbbfbc85d497caf3dffcb = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_1397e71b6f59921a63b332bab03141b8);
#
#
#         var popup_fc8be2a4f34c8e96e21521b9a5a65b28 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5614d1a94c79cef38cdf269a550a6175 = $(`&lt;div id=&quot;html_5614d1a94c79cef38cdf269a550a6175&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_fc8be2a4f34c8e96e21521b9a5a65b28.setContent(html_5614d1a94c79cef38cdf269a550a6175);
#
#
#
#         marker_8dd14c91d10fbbfbc85d497caf3dffcb.bindPopup(popup_fc8be2a4f34c8e96e21521b9a5a65b28)
#         ;
#
#
#
#
#             var marker_5d833eea969ace18e9b29981cb11d0bb = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_1397e71b6f59921a63b332bab03141b8);
#
#
#         var popup_8433292eb54d9486e58fc8a8292ac6ab = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ccf11763061038944cdde8d9f94935ee = $(`&lt;div id=&quot;html_ccf11763061038944cdde8d9f94935ee&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_8433292eb54d9486e58fc8a8292ac6ab.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_08956291e042a525a263a904202385dc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_08956291e042a525a263a904202385dc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_08956291e042a525a263a904202385dc = L.map(
#                 &quot;map_08956291e042a525a263a904202385dc&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bdaf8d1f7fb32584cdec0445195c8332 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_bdaf8d1f7fb32584cdec0445195c8332.addTo(map_08956291e042a525a263a904202385dc);
#
#
#             var feature_group_4b6353e854f5d55a830b6ac8b631ade9 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_2f0e5d4e8d1073790ee493c499a51272 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_4b6353e854f5d55a830b6ac8b631ade9);
#
#
#         var popup_46341305fcb6bce544048f5dbdd55b0b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cc633e14ef0b3c9de3be5a9e46a5fd45 = $(`&lt;div id=&quot;html_cc633e14ef0b3c9de3be5a9e46a5fd45&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_46341305fcb6bce544048f5dbdd55b0b.setContent(html_cc633e14ef0b3c9de3be5a9e46a5fd45);
#
#
#
#         marker_2f0e5d4e8d1073790ee493c499a51272.bindPopup(popup_46341305fcb6bce544048f5dbdd55b0b)
#         ;
#
#
#
#
#             var marker_7d872fe138b62bc55f37a902827e1de9 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_4b6353e854f5d55a830b6ac8b631ade9);
#
#
#         var popup_0be6446107fa7850be2027316758f932 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fe0fee9d1cbfec91b27e06fa97af0fc6 = $(`&lt;div id=&quot;html_fe0fee9d1cbfec91b27e06fa97af0fc6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_0be6446107fa7850be2027316758f932.setContent(html_fe0fee9d1cbfec91b27e06fa97af0fc6);
#
#
#
#         marker_7d872fe138b62bc55f37a902827e1de9.bindPopup(popup_0be6446107fa7850be2027316758f932)
#         ;
#
#
#
#
#             var marker_44413b64f5e331fec1834489949f3d87 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_4b6353e854f5d55a830b6ac8b631ade9);
#
#
#         var popup_cbed59b97a24a29c97cb4a9d98e6bb5f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6f776b077d059b616e2fd401111c9ad8 = $(`&lt;div id=&quot;html_6f776b077d059b616e2fd401111c9ad8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_cbed59b97a24a29c97cb4a9d98e6bb5f.setContent(html_6f776b077d059b616e2fd401111c9ad8);
#
#
#
#         marker_44413b64f5e331fec1834489949f3d87.bindPopup(popup_cbed59b97a24a29c97cb4a9d98e6bb5f)
#         ;
#
#
#
#
#             var marker_ea2a06ae73872eee8f2c63204fcec5b7 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_4b6353e854f5d55a830b6ac8b631ade9);
#
#
#         var popup_57c05d94b361ebdc03b228bffbc9e2fb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4a3f6029095dcbaeb7875989258573f4 = $(`&lt;div id=&quot;html_4a3f6029095dcbaeb7875989258573f4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_57c05d94b361ebdc03b228bffbc9e2fb.setContent(html_4a3f6029095dcbaeb7875989258573f4);
#
#
#
#         marker_ea2a06ae73872eee8f2c63204fcec5b7.bindPopup(popup_57c05d94b361ebdc03b228bffbc9e2fb)
#         ;
#
#
#
#
#             var marker_7c91c6e2615d67953154b37eec4f5246 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_4b6353e854f5d55a830b6ac8b631ade9);
#
#
#         var popup_e4af886749a7accc5c6ef620f0ad5678 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9e51223d45ff82e77ee28aa375395a58 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9e51223d45ff82e77ee28aa375395a58&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9e51223d45ff82e77ee28aa375395a58 = L.map(
#                 &quot;map_9e51223d45ff82e77ee28aa375395a58&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e5d53f9a916794fb1a03ffb80b4e6378 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e5d53f9a916794fb1a03ffb80b4e6378.addTo(map_9e51223d45ff82e77ee28aa375395a58);
#
#
#             var feature_group_34bac9ae6ce528059a14e083d2b3971d = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_34bac9ae6ce528059a14e083d2b3971d.addTo(map_9e51223d45ff82e77ee28aa375395a58);
#
#
#             var feature_group_sub_group_2a648165f0e086c7ae3b59de439ee7a4 = L.featureGroup.subGroup(
#                 feature_group_34bac9ae6ce528059a14e083d2b3971d
#             );
#
#
#             var marker_246789722052977344dcd836aec75a8d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_2a648165f0e086c7ae3b59de439ee7a4);
#
#
#         var popup_fc3f909ddacc7c2663f415de7a72c8d5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cff45425f1175b116ff1a6e116136750 = $(`&lt;div id=&quot;html_cff45425f1175b116ff1a6e116136750&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_fc3f909ddacc7c2663f415de7a72c8d5.setContent(html_cff45425f1175b116ff1a6e116136750);
#
#
#
#         marker_246789722052977344dcd836aec75a8d.bindPopup(popup_fc3f909ddacc7c2663f415de7a72c8d5)
#         ;
#
#
#
#
#             var marker_aae0ce4f28c352d6523f4ce330c9276f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_2a648165f0e086c7ae3b59de439ee7a4);
#
#
#         var popup_fc2e2e7b843950f1abd5da98f8ddb050 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_184276454b5354b25817689be10ff550 = $(`&lt;div id=&quot;html_184276454b5354b25817689be10ff550&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_fc2e2e7b843950f1abd5da98f8ddb050.setContent(html_184276454b5354b25817689be10ff550);
#
#
#
#         marker_aae0ce4f28c352d6523f4ce330c9276f.bindPopup(popup_fc2e2e7b843950f1abd5da98f8ddb050)
#         ;
#
#
#
#
#             var marker_05b7c5327a38c5c296c7311203c83c69 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_2a648165f0e086c7ae3b59de439ee7a4);
#
#
#         var popup_22d1eb7575ca16e4afabf9732c34622c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6b6dd92087e9c28880a67dc60e8378ff = $(`&lt;div id=&quot;html_6b6dd92087e9c28880a67dc60e8378ff&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_22d1eb7575ca16e4afabf9732c34622c.setContent(html_6b6dd92087e9c28880a67dc60e8378ff);
#
#
#
#         marker_05b7c5327a38c5c296c7311203c83c69.bindPopup(popup_22d1eb7575ca16e4afabf9732c34622c)
#         ;
#
#
#
#
#             var marker_1913f022a5bf623ea61779f1acdcc60f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_2a648165f0e086c7ae3b59de439ee7a4);
#
#
#         var popup_bf2a0be19eae9e1a4f1c751b2ff94c90 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1304f74bd40a7514fb81b22474fdce45 = $(`&lt;div id=&quot;html_1304f74bd40a7514fb81b22474fdce45&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_bf2a0be19eae9e1a4f1c751b2ff94c90.setContent(html_1304f74bd40a7514fb81b22474fdce45);
#
#
#
#         marker_
