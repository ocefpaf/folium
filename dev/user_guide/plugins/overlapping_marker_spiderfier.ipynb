# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_aafd3d7ac7419be779fd71fade8de0ec {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_aafd3d7ac7419be779fd71fade8de0ec&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_aafd3d7ac7419be779fd71fade8de0ec = L.map(
#                 &quot;map_aafd3d7ac7419be779fd71fade8de0ec&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_daa78482b45cb93118f1a2792ba9367c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_daa78482b45cb93118f1a2792ba9367c.addTo(map_aafd3d7ac7419be779fd71fade8de0ec);
#
#
#             var marker_e82839bc8ae28ce6be7744ead0d08d1c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_aafd3d7ac7419be779fd71fade8de0ec);
#
#
#         var popup_0ffdba8e9e531eea3cc9d3505b060b62 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fbea6ea6c281a5651cb01456fcc68d54 = $(`&lt;div id=&quot;html_fbea6ea6c281a5651cb01456fcc68d54&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_0ffdba8e9e531eea3cc9d3505b060b62.setContent(html_fbea6ea6c281a5651cb01456fcc68d54);
#
#
#
#         marker_e82839bc8ae28ce6be7744ead0d08d1c.bindPopup(popup_0ffdba8e9e531eea3cc9d3505b060b62)
#         ;
#
#
#
#
#             var marker_9b715fd7f13c6e46df75f503d0eba04f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_aafd3d7ac7419be779fd71fade8de0ec);
#
#
#         var popup_9b699088dc3bc3fade882622a8d09666 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ef6356b0f9261127ddf3b8efb8add835 = $(`&lt;div id=&quot;html_ef6356b0f9261127ddf3b8efb8add835&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_9b699088dc3bc3fade882622a8d09666.setContent(html_ef6356b0f9261127ddf3b8efb8add835);
#
#
#
#         marker_9b715fd7f13c6e46df75f503d0eba04f.bindPopup(popup_9b699088dc3bc3fade882622a8d09666)
#         ;
#
#
#
#
#             var marker_df7afc9665ffd0af0d27cf72563fe1fa = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_aafd3d7ac7419be779fd71fade8de0ec);
#
#
#         var popup_ee4434d14ebd74ba476bfc653be5ed53 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fedec2c0341712fa16024b16e60368ea = $(`&lt;div id=&quot;html_fedec2c0341712fa16024b16e60368ea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_ee4434d14ebd74ba476bfc653be5ed53.setContent(html_fedec2c0341712fa16024b16e60368ea);
#
#
#
#         marker_df7afc9665ffd0af0d27cf72563fe1fa.bindPopup(popup_ee4434d14ebd74ba476bfc653be5ed53)
#         ;
#
#
#
#
#             var marker_ce6a7a3c60b1e6758a6815033140ea9f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_aafd3d7ac7419be779fd71fade8de0ec);
#
#
#         var popup_b8322cf0f33935cd3bab6c6fd89b784c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_20bd4718f5155f5a83fda58c959673c5 = $(`&lt;div id=&quot;html_20bd4718f5155f5a83fda58c959673c5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_b8322cf0f33935cd3bab6c6fd89b784c.setContent(html_20bd4718f5155f5a83fda58c959673c5);
#
#
#
#         marker_ce6a7a3c60b1e6758a6815033140ea9f.bindPopup(popup_b8322cf0f33935cd3bab6c6fd89b784c)
#         ;
#
#
#
#
#             var marker_15f1ffe257fa1b99a2d7a2dbc8e07c0c = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_aafd3d7ac7419be779fd71fade8de0ec);
#
#
#         var popup_9e603c82f11c0498ab638e289dd853f4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_adeab7b1f99b01c659a0cc1d6dd9537c = $(`&lt;div id=&quot;html_adeab7b1f99b01c659a0cc1d6dd9537c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_9e603c82f11c0498ab638e289dd853f4.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7a87ac7aac961c4928580316368abcb8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7a87ac7aac961c4928580316368abcb8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7a87ac7aac961c4928580316368abcb8 = L.map(
#                 &quot;map_7a87ac7aac961c4928580316368abcb8&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6a6af94edd1a45fdeeea1ca8fde2af8d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6a6af94edd1a45fdeeea1ca8fde2af8d.addTo(map_7a87ac7aac961c4928580316368abcb8);
#
#
#             var feature_group_832ab54acf20c759589df2512c6a38d6 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_7b0ccf2d3945649c41424c9ff89b76a2 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_832ab54acf20c759589df2512c6a38d6);
#
#
#         var popup_86c10e6cf3ec795f0a48488e19840573 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0854e1b33c59eb56af89996ed59e77b0 = $(`&lt;div id=&quot;html_0854e1b33c59eb56af89996ed59e77b0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_86c10e6cf3ec795f0a48488e19840573.setContent(html_0854e1b33c59eb56af89996ed59e77b0);
#
#
#
#         marker_7b0ccf2d3945649c41424c9ff89b76a2.bindPopup(popup_86c10e6cf3ec795f0a48488e19840573)
#         ;
#
#
#
#
#             var marker_5b985d39d8d31606dbc9c343366f2582 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_832ab54acf20c759589df2512c6a38d6);
#
#
#         var popup_d10279db0d7b4e989e5217d42e530b4b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3489d6463399e67178d4c747365f61e7 = $(`&lt;div id=&quot;html_3489d6463399e67178d4c747365f61e7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_d10279db0d7b4e989e5217d42e530b4b.setContent(html_3489d6463399e67178d4c747365f61e7);
#
#
#
#         marker_5b985d39d8d31606dbc9c343366f2582.bindPopup(popup_d10279db0d7b4e989e5217d42e530b4b)
#         ;
#
#
#
#
#             var marker_7099cacb4c7e009f5b5129266a3414e8 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_832ab54acf20c759589df2512c6a38d6);
#
#
#         var popup_4da782b83a9b849b1efab672143cc67d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9c0872060d745afa0eeba627f22a10c5 = $(`&lt;div id=&quot;html_9c0872060d745afa0eeba627f22a10c5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_4da782b83a9b849b1efab672143cc67d.setContent(html_9c0872060d745afa0eeba627f22a10c5);
#
#
#
#         marker_7099cacb4c7e009f5b5129266a3414e8.bindPopup(popup_4da782b83a9b849b1efab672143cc67d)
#         ;
#
#
#
#
#             var marker_0c21f34338caf46b7ff06d954a8415e6 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_832ab54acf20c759589df2512c6a38d6);
#
#
#         var popup_18f9b6ce8120c97ea2653e92ee26da6d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_33c884a2a7442455b29988bdcc5bd77d = $(`&lt;div id=&quot;html_33c884a2a7442455b29988bdcc5bd77d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_18f9b6ce8120c97ea2653e92ee26da6d.setContent(html_33c884a2a7442455b29988bdcc5bd77d);
#
#
#
#         marker_0c21f34338caf46b7ff06d954a8415e6.bindPopup(popup_18f9b6ce8120c97ea2653e92ee26da6d)
#         ;
#
#
#
#
#             var marker_23e5b6de873a3e18cdf9ec6d6768584a = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_832ab54acf20c759589df2512c6a38d6);
#
#
#         var popup_d1fa36c8061f5168294d9f4b7bb875fd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5252b2deadaa64c5703e9567b8784726 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5252b2deadaa64c5703e9567b8784726&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5252b2deadaa64c5703e9567b8784726 = L.map(
#                 &quot;map_5252b2deadaa64c5703e9567b8784726&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3551db57cf40321feea7a9d029f58253 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3551db57cf40321feea7a9d029f58253.addTo(map_5252b2deadaa64c5703e9567b8784726);
#
#
#             var feature_group_10388ff3fe881a21ff949c68af7592a1 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_10388ff3fe881a21ff949c68af7592a1.addTo(map_5252b2deadaa64c5703e9567b8784726);
#
#
#             var feature_group_sub_group_7472125d56dbe2d70619f65ad9b9b154 = L.featureGroup.subGroup(
#                 feature_group_10388ff3fe881a21ff949c68af7592a1
#             );
#
#
#             var marker_6cc9b44936fb6aa4721d7c4c3cb248ed = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_7472125d56dbe2d70619f65ad9b9b154);
#
#
#         var popup_1c4c496d135f6757ed130e5168029f96 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bdcb8015609e87b8c3b61ab4066e94da = $(`&lt;div id=&quot;html_bdcb8015609e87b8c3b61ab4066e94da&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_1c4c496d135f6757ed130e5168029f96.setContent(html_bdcb8015609e87b8c3b61ab4066e94da);
#
#
#
#         marker_6cc9b44936fb6aa4721d7c4c3cb248ed.bindPopup(popup_1c4c496d135f6757ed130e5168029f96)
#         ;
#
#
#
#
#             var marker_688ec848ce4a10a6b09544c16b84323b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_7472125d56dbe2d70619f65ad9b9b154);
#
#
#         var popup_b00ff5bc2b128792e38d912aa832eca9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a1c085307df791c0c9aa1640ca161cbb = $(`&lt;div id=&quot;html_a1c085307df791c0c9aa1640ca161cbb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_b00ff5bc2b128792e38d912aa832eca9.setContent(html_a1c085307df791c0c9aa1640ca161cbb);
#
#
#
#         marker_688ec848ce4a10a6b09544c16b84323b.bindPopup(popup_b00ff5bc2b128792e38d912aa832eca9)
#         ;
#
#
#
#
#             var marker_4d88cd641b0fbcc1eab00f42f40d02d3 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_7472125d56dbe2d70619f65ad9b9b154);
#
#
#         var popup_b23f3e906296492db0e93e9492583e8f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1da1ec58c7a817be48e902f12e8ec06d = $(`&lt;div id=&quot;html_1da1ec58c7a817be48e902f12e8ec06d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_b23f3e906296492db0e93e9492583e8f.setContent(html_1da1ec58c7a817be48e902f12e8ec06d);
#
#
#
#         marker_4d88cd641b0fbcc1eab00f42f40d02d3.bindPopup(popup_b23f3e906296492db0e93e9492583e8f)
#         ;
#
#
#
#
#             var marker_ce432e0041c6ed389d11be82d31cfeba = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_7472125d56dbe2d70619f65ad9b9b154);
#
#
#         var popup_8c2f6fc9ab8123a5ad7d8b9a75e857c1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ced1e4fb75fd4090b2700caeefaff3c9 = $(`&lt;div id=&quot;html_ced1e4fb75fd4090b2700caeefaff3c9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_8c2f6fc9ab8123a5ad7d8b9a75e857c1.setContent(html_ced1e4fb75fd4090b2700caeefaff3c9);
#
#
#
#         marker_
