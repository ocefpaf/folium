# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bb6472d98ca2ff42e5396e3e648d2771 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bb6472d98ca2ff42e5396e3e648d2771&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bb6472d98ca2ff42e5396e3e648d2771 = L.map(
#                 &quot;map_bb6472d98ca2ff42e5396e3e648d2771&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3b44eaa12ca5cd970c54ff7e70c628b7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3b44eaa12ca5cd970c54ff7e70c628b7.addTo(map_bb6472d98ca2ff42e5396e3e648d2771);
#
#
#             var marker_3ea3804a31e9eb7b120687ec850dface = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_bb6472d98ca2ff42e5396e3e648d2771);
#
#
#         var popup_8144965360d6ae65d6bb11468c87c063 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b742b99c53286d1e5251d4cf62fe0d3d = $(`&lt;div id=&quot;html_b742b99c53286d1e5251d4cf62fe0d3d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_8144965360d6ae65d6bb11468c87c063.setContent(html_b742b99c53286d1e5251d4cf62fe0d3d);
#
#
#
#         marker_3ea3804a31e9eb7b120687ec850dface.bindPopup(popup_8144965360d6ae65d6bb11468c87c063)
#         ;
#
#
#
#
#             var marker_6e54e6a9d40b41a1a23a22b2b0f4a0a7 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_bb6472d98ca2ff42e5396e3e648d2771);
#
#
#         var popup_41ca00ef4179b65a89feb979c29647f0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cbd914dce00892771bb7449c0247a7f9 = $(`&lt;div id=&quot;html_cbd914dce00892771bb7449c0247a7f9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_41ca00ef4179b65a89feb979c29647f0.setContent(html_cbd914dce00892771bb7449c0247a7f9);
#
#
#
#         marker_6e54e6a9d40b41a1a23a22b2b0f4a0a7.bindPopup(popup_41ca00ef4179b65a89feb979c29647f0)
#         ;
#
#
#
#
#             var marker_a2cdeec055eb4735c2d3060365d37977 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_bb6472d98ca2ff42e5396e3e648d2771);
#
#
#         var popup_66bf8c6fc839a333e9f2aa50027538ae = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4eb72e3d4fe5524a51cf0f3d624abe1e = $(`&lt;div id=&quot;html_4eb72e3d4fe5524a51cf0f3d624abe1e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_66bf8c6fc839a333e9f2aa50027538ae.setContent(html_4eb72e3d4fe5524a51cf0f3d624abe1e);
#
#
#
#         marker_a2cdeec055eb4735c2d3060365d37977.bindPopup(popup_66bf8c6fc839a333e9f2aa50027538ae)
#         ;
#
#
#
#
#             var marker_fda76c7f71acd82b85fd4ca38921ebbe = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_bb6472d98ca2ff42e5396e3e648d2771);
#
#
#         var popup_ec7f2a5695ec7c81afec2ceb290e538a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7af362f9560aa1961b5af323a6aa317c = $(`&lt;div id=&quot;html_7af362f9560aa1961b5af323a6aa317c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_ec7f2a5695ec7c81afec2ceb290e538a.setContent(html_7af362f9560aa1961b5af323a6aa317c);
#
#
#
#         marker_fda76c7f71acd82b85fd4ca38921ebbe.bindPopup(popup_ec7f2a5695ec7c81afec2ceb290e538a)
#         ;
#
#
#
#
#             var marker_68b2386e7aae5cf2913bed7f086867c4 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_bb6472d98ca2ff42e5396e3e648d2771);
#
#
#         var popup_6efd67507cfed547f1cb17423a736570 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a8c496b21389377215628370d918d49a = $(`&lt;div id=&quot;html_a8c496b21389377215628370d918d49a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_6efd67507cfed547f1cb17423a736570.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_30b4bdbefe93c3e281eb67d2c4ebaf39 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_30b4bdbefe93c3e281eb67d2c4ebaf39&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_30b4bdbefe93c3e281eb67d2c4ebaf39 = L.map(
#                 &quot;map_30b4bdbefe93c3e281eb67d2c4ebaf39&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_62c6193aad234a63d26fab4d4d0e1248 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_62c6193aad234a63d26fab4d4d0e1248.addTo(map_30b4bdbefe93c3e281eb67d2c4ebaf39);
#
#
#             var feature_group_dfab7eeba07ced14bfbc7700f52896e1 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_a1440b2bae1b8994d2aee70614a330d3 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_dfab7eeba07ced14bfbc7700f52896e1);
#
#
#         var popup_df87b851d8ab900f9bdc6f7be3b0df29 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d415c7e292475e9822281ea38fc85a48 = $(`&lt;div id=&quot;html_d415c7e292475e9822281ea38fc85a48&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_df87b851d8ab900f9bdc6f7be3b0df29.setContent(html_d415c7e292475e9822281ea38fc85a48);
#
#
#
#         marker_a1440b2bae1b8994d2aee70614a330d3.bindPopup(popup_df87b851d8ab900f9bdc6f7be3b0df29)
#         ;
#
#
#
#
#             var marker_79e6f6c5ff9516afc3e09853bcb8f34b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_dfab7eeba07ced14bfbc7700f52896e1);
#
#
#         var popup_9dedf0b7fb84fd4896b4d1420d45672a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f4d52b36010b1c2cc1eb2b13118c0151 = $(`&lt;div id=&quot;html_f4d52b36010b1c2cc1eb2b13118c0151&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_9dedf0b7fb84fd4896b4d1420d45672a.setContent(html_f4d52b36010b1c2cc1eb2b13118c0151);
#
#
#
#         marker_79e6f6c5ff9516afc3e09853bcb8f34b.bindPopup(popup_9dedf0b7fb84fd4896b4d1420d45672a)
#         ;
#
#
#
#
#             var marker_59aabc41ac52c31f93d9fdd70785d7d8 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_dfab7eeba07ced14bfbc7700f52896e1);
#
#
#         var popup_747c2eab41246034e464d61ee8b92d82 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f5ddeae9395a10bbd55fe63cdbb0a916 = $(`&lt;div id=&quot;html_f5ddeae9395a10bbd55fe63cdbb0a916&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_747c2eab41246034e464d61ee8b92d82.setContent(html_f5ddeae9395a10bbd55fe63cdbb0a916);
#
#
#
#         marker_59aabc41ac52c31f93d9fdd70785d7d8.bindPopup(popup_747c2eab41246034e464d61ee8b92d82)
#         ;
#
#
#
#
#             var marker_7dfb21bf67824aac014f11df3c218727 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_dfab7eeba07ced14bfbc7700f52896e1);
#
#
#         var popup_817d6dd13fb0d5098458a975b345ecc5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3b431ac3b4499e30071dbd5e90f5964b = $(`&lt;div id=&quot;html_3b431ac3b4499e30071dbd5e90f5964b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_817d6dd13fb0d5098458a975b345ecc5.setContent(html_3b431ac3b4499e30071dbd5e90f5964b);
#
#
#
#         marker_7dfb21bf67824aac014f11df3c218727.bindPopup(popup_817d6dd13fb0d5098458a975b345ecc5)
#         ;
#
#
#
#
#             var marker_72e4b34a546cfedffc04a9446c4cb128 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_dfab7eeba07ced14bfbc7700f52896e1);
#
#
#         var popup_40740106612263d726a89d74f3651727 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_faa637f3e0e20f7873d25fd590158af9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_faa637f3e0e20f7873d25fd590158af9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_faa637f3e0e20f7873d25fd590158af9 = L.map(
#                 &quot;map_faa637f3e0e20f7873d25fd590158af9&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_88bb4816892346d88f64c73a5e511d43 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_88bb4816892346d88f64c73a5e511d43.addTo(map_faa637f3e0e20f7873d25fd590158af9);
#
#
#             var feature_group_e9ed3bb9bf15f480e78b10b8f8829c3b = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_e9ed3bb9bf15f480e78b10b8f8829c3b.addTo(map_faa637f3e0e20f7873d25fd590158af9);
#
#
#             var feature_group_sub_group_47069cf7e9604f5f4e67e261e57326f2 = L.featureGroup.subGroup(
#                 feature_group_e9ed3bb9bf15f480e78b10b8f8829c3b
#             );
#
#
#             var marker_0f213672980edb1562968cb20686915d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_47069cf7e9604f5f4e67e261e57326f2);
#
#
#         var popup_e22d65b61ea82ad34bef99f35442c74b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c0db781c39f30dc3390475ae8dd420bf = $(`&lt;div id=&quot;html_c0db781c39f30dc3390475ae8dd420bf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_e22d65b61ea82ad34bef99f35442c74b.setContent(html_c0db781c39f30dc3390475ae8dd420bf);
#
#
#
#         marker_0f213672980edb1562968cb20686915d.bindPopup(popup_e22d65b61ea82ad34bef99f35442c74b)
#         ;
#
#
#
#
#             var marker_17987b58556fbf55800c1ea435ae482b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_47069cf7e9604f5f4e67e261e57326f2);
#
#
#         var popup_0825e11606bfba162b9f6fcaf553f25b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c59073d66eea6ad06b6e8b30e7b49484 = $(`&lt;div id=&quot;html_c59073d66eea6ad06b6e8b30e7b49484&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_0825e11606bfba162b9f6fcaf553f25b.setContent(html_c59073d66eea6ad06b6e8b30e7b49484);
#
#
#
#         marker_17987b58556fbf55800c1ea435ae482b.bindPopup(popup_0825e11606bfba162b9f6fcaf553f25b)
#         ;
#
#
#
#
#             var marker_fb0f1104d5926c1ea080e9236862a8d9 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_47069cf7e9604f5f4e67e261e57326f2);
#
#
#         var popup_f7e614d912735c87f570cf7e38871773 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6f1147ca54662a5469df46bcbf4ab176 = $(`&lt;div id=&quot;html_6f1147ca54662a5469df46bcbf4ab176&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_f7e614d912735c87f570cf7e38871773.setContent(html_6f1147ca54662a5469df46bcbf4ab176);
#
#
#
#         marker_fb0f1104d5926c1ea080e9236862a8d9.bindPopup(popup_f7e614d912735c87f570cf7e38871773)
#         ;
#
#
#
#
#             var marker_0d7c65bca36c385207f38ab9fcc2b4df = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_47069cf7e9604f5f4e67e261e57326f2);
#
#
#         var popup_6cbdf2a6d614d42b4b9c99663577bdde = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c94dac850b029362e4161f6ef93a3631 = $(`&lt;div id=&quot;html_c94dac850b029362e4161f6ef93a3631&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_6cbdf2a6d614d42b4b9c99663577bdde.setContent(html_c94dac850b029362e4161f6ef93a3631);
#
#
#
#         marker_
