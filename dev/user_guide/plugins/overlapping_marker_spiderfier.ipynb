# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fd50c84ed24dc9eeef77f891c76f69f9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fd50c84ed24dc9eeef77f891c76f69f9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fd50c84ed24dc9eeef77f891c76f69f9 = L.map(
#                 &quot;map_fd50c84ed24dc9eeef77f891c76f69f9&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7935a165d9417ccc8b936d73a0486913 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7935a165d9417ccc8b936d73a0486913.addTo(map_fd50c84ed24dc9eeef77f891c76f69f9);
#
#
#             var marker_45d2628e9369abd30ccdc3ee90ddc0fd = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_fd50c84ed24dc9eeef77f891c76f69f9);
#
#
#         var popup_9ead350f280c37f5aa0e1eae8c3766ce = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_12c2693592e4f4ae5d60dd8e6bc377c4 = $(`&lt;div id=&quot;html_12c2693592e4f4ae5d60dd8e6bc377c4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_9ead350f280c37f5aa0e1eae8c3766ce.setContent(html_12c2693592e4f4ae5d60dd8e6bc377c4);
#
#
#
#         marker_45d2628e9369abd30ccdc3ee90ddc0fd.bindPopup(popup_9ead350f280c37f5aa0e1eae8c3766ce)
#         ;
#
#
#
#
#             var marker_1326de28aba18155e80c44070ff43379 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_fd50c84ed24dc9eeef77f891c76f69f9);
#
#
#         var popup_f1f85027a45da6a572d9798e62b034cb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7ad89b20f2f68fb997b55e8a85d0c209 = $(`&lt;div id=&quot;html_7ad89b20f2f68fb997b55e8a85d0c209&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_f1f85027a45da6a572d9798e62b034cb.setContent(html_7ad89b20f2f68fb997b55e8a85d0c209);
#
#
#
#         marker_1326de28aba18155e80c44070ff43379.bindPopup(popup_f1f85027a45da6a572d9798e62b034cb)
#         ;
#
#
#
#
#             var marker_2d3d1ccd841a2041db1b11aa9aede347 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_fd50c84ed24dc9eeef77f891c76f69f9);
#
#
#         var popup_50d24018023bf9082851f90e24dc523b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1a4da679b32e50bff7b6782f3fa096cf = $(`&lt;div id=&quot;html_1a4da679b32e50bff7b6782f3fa096cf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_50d24018023bf9082851f90e24dc523b.setContent(html_1a4da679b32e50bff7b6782f3fa096cf);
#
#
#
#         marker_2d3d1ccd841a2041db1b11aa9aede347.bindPopup(popup_50d24018023bf9082851f90e24dc523b)
#         ;
#
#
#
#
#             var marker_44832ab4af2024a576fadeb39da00d47 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_fd50c84ed24dc9eeef77f891c76f69f9);
#
#
#         var popup_802b8acc1ba1ca7fd59f867c23da81fd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c0d2093d08dc9cf7188dc1dc33a6b01a = $(`&lt;div id=&quot;html_c0d2093d08dc9cf7188dc1dc33a6b01a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_802b8acc1ba1ca7fd59f867c23da81fd.setContent(html_c0d2093d08dc9cf7188dc1dc33a6b01a);
#
#
#
#         marker_44832ab4af2024a576fadeb39da00d47.bindPopup(popup_802b8acc1ba1ca7fd59f867c23da81fd)
#         ;
#
#
#
#
#             var marker_ed75a2c257347e375ae390b4108d6617 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_fd50c84ed24dc9eeef77f891c76f69f9);
#
#
#         var popup_e182d32b0febde3ecf6dedc1b3909028 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_646a435acd83d237354a283974f772e2 = $(`&lt;div id=&quot;html_646a435acd83d237354a283974f772e2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_e182d32b0febde3ecf6dedc1b3909028.setContent(html_646a435acd83d237354a283974f772e2);
#
#
#
#         marker_ed75a2c257347e375ae390b4108d6617.bindPopup(popup_e182d32b0febde3ecf6dedc1b3909028)
#         ;
#
#
#
#
#             var marker_e683890fa2

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ae8a436396178581f4412e2564bc3b39 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ae8a436396178581f4412e2564bc3b39&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ae8a436396178581f4412e2564bc3b39 = L.map(
#                 &quot;map_ae8a436396178581f4412e2564bc3b39&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cc50e9d657e0c42fc9a30ffdf12ca8c7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_cc50e9d657e0c42fc9a30ffdf12ca8c7.addTo(map_ae8a436396178581f4412e2564bc3b39);
#
#
#             var feature_group_20bcbf0469199633506e733439f65ea2 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_19c451f0e33e1b3d521169b07ef1b452 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_20bcbf0469199633506e733439f65ea2);
#
#
#         var popup_bc506f93167b22ce94d3033f9c556948 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ebeb872d7f60be94e93bf91b0898d90f = $(`&lt;div id=&quot;html_ebeb872d7f60be94e93bf91b0898d90f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_bc506f93167b22ce94d3033f9c556948.setContent(html_ebeb872d7f60be94e93bf91b0898d90f);
#
#
#
#         marker_19c451f0e33e1b3d521169b07ef1b452.bindPopup(popup_bc506f93167b22ce94d3033f9c556948)
#         ;
#
#
#
#
#             var marker_a182af27c85e5cbfb0c5fc2c848f420f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_20bcbf0469199633506e733439f65ea2);
#
#
#         var popup_6fdf93b655d889fe6127c7bcf3dae164 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_50ea5299e7fe932d35a4ff97eaf86ecf = $(`&lt;div id=&quot;html_50ea5299e7fe932d35a4ff97eaf86ecf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_6fdf93b655d889fe6127c7bcf3dae164.setContent(html_50ea5299e7fe932d35a4ff97eaf86ecf);
#
#
#
#         marker_a182af27c85e5cbfb0c5fc2c848f420f.bindPopup(popup_6fdf93b655d889fe6127c7bcf3dae164)
#         ;
#
#
#
#
#             var marker_9379b555be7e73f8cff16a08b8534d31 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_20bcbf0469199633506e733439f65ea2);
#
#
#         var popup_08d5cb05b03c72280e110fd2999a5746 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_162a7d4a6a624fd2f3bbe685fd67d973 = $(`&lt;div id=&quot;html_162a7d4a6a624fd2f3bbe685fd67d973&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_08d5cb05b03c72280e110fd2999a5746.setContent(html_162a7d4a6a624fd2f3bbe685fd67d973);
#
#
#
#         marker_9379b555be7e73f8cff16a08b8534d31.bindPopup(popup_08d5cb05b03c72280e110fd2999a5746)
#         ;
#
#
#
#
#             var marker_6f98b6df2895fea3d747466668169f42 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_20bcbf0469199633506e733439f65ea2);
#
#
#         var popup_feb0452f5bc20938d947d311addc2c31 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b0465e476e815a70816941c380dc36bc = $(`&lt;div id=&quot;html_b0465e476e815a70816941c380dc36bc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_feb0452f5bc20938d947d311addc2c31.setContent(html_b0465e476e815a70816941c380dc36bc);
#
#
#
#         marker_6f98b6df2895fea3d747466668169f42.bindPopup(popup_feb0452f5bc20938d947d311addc2c31)
#         ;
#
#
#
#
#             var marker_fef87a73c1f95b748e7f348c52cf57e4 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_20bcbf0469199633506e733439f65ea2);
#
#
#         var popup_b8ca791d0d44abf181464c259c91aed5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_294f1c3bf4fd0b42a67684522b9fc2ca = $(`&lt;div id=&quot;html_294f1c3bf4fd0b42a67684522b9fc2ca&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 4&lt;/div&gt;`)[0];
#                 popup_b8ca791d0d44abf181

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_761ab963c32a3b4ccf0aa96d7318893e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_761ab963c32a3b4ccf0aa96d7318893e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_761ab963c32a3b4ccf0aa96d7318893e = L.map(
#                 &quot;map_761ab963c32a3b4ccf0aa96d7318893e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_10ffc43d1a036312364603b10666a355 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_10ffc43d1a036312364603b10666a355.addTo(map_761ab963c32a3b4ccf0aa96d7318893e);
#
#
#             var feature_group_10adccf63d989418603f2ffd94e5a9e9 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_10adccf63d989418603f2ffd94e5a9e9.addTo(map_761ab963c32a3b4ccf0aa96d7318893e);
#
#
#             var feature_group_sub_group_2176224e4ca116ba64ffe46d90795e93 = L.featureGroup.subGroup(
#                 feature_group_10adccf63d989418603f2ffd94e5a9e9
#             );
#
#
#             var marker_048bd1604dbcf78ef1cbe6f7eb0b5290 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_2176224e4ca116ba64ffe46d90795e93);
#
#
#         var popup_55eab88877a0b9a8940560fec5fc82be = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c14b7dd956f2d521dc9c16c94c208672 = $(`&lt;div id=&quot;html_c14b7dd956f2d521dc9c16c94c208672&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_55eab88877a0b9a8940560fec5fc82be.setContent(html_c14b7dd956f2d521dc9c16c94c208672);
#
#
#
#         marker_048bd1604dbcf78ef1cbe6f7eb0b5290.bindPopup(popup_55eab88877a0b9a8940560fec5fc82be)
#         ;
#
#
#
#
#             var marker_879ae99428de798e9379c74cdbcce4f3 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_2176224e4ca116ba64ffe46d90795e93);
#
#
#         var popup_985506fcdfd5ff890fad37c7ea40b4a7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d01cd9618c1b2988a4d30938c22f7d35 = $(`&lt;div id=&quot;html_d01cd9618c1b2988a4d30938c22f7d35&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_985506fcdfd5ff890fad37c7ea40b4a7.setContent(html_d01cd9618c1b2988a4d30938c22f7d35);
#
#
#
#         marker_879ae99428de798e9379c74cdbcce4f3.bindPopup(popup_985506fcdfd5ff890fad37c7ea40b4a7)
#         ;
#
#
#
#
#             var marker_7a33b331d7e19392a191a141c062e5a6 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_2176224e4ca116ba64ffe46d90795e93);
#
#
#         var popup_68486fba22ae4288b7fe4c7c9d5f69e3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9f13cbb4bb27d9144e6255f5791d771f = $(`&lt;div id=&quot;html_9f13cbb4bb27d9144e6255f5791d771f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_68486fba22ae4288b7fe4c7c9d5f69e3.setContent(html_9f13cbb4bb27d9144e6255f5791d771f);
#
#
#
#         marker_7a33b331d7e19392a191a141c062e5a6.bindPopup(popup_68486fba22ae4288b7fe4c7c9d5f69e3)
#         ;
#
#
#
#
#             var marker_93b21591a5c245f7a5a09ea5a71d834c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_2176224e4ca116ba64ffe46d90795e93);
#
#
#         var popup_ef4f6eeeeafe89a6315b3ac6045cd3a2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8bfd42d5c567466b3ee288f2753b1e0a = $(`&lt;div id=&quot;html_8bfd42d5c567466b3ee288f2753b1e0a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_ef4f6eeeeafe89a6315b3ac6045cd3a2.setContent(html_8bfd42d5c567466b3ee288f2753b1e0a);
#
#
#
#         marker_93b21591a5c245f7a5a09ea5a71d834c.bindPopup(popup_ef4f6eeeeafe89a6315b3ac6045cd3a2)
#         ;
#
#
#
#
#             var marker_5789252f51924e376e62816e83500d1f = L.marker(
#                 [45.050399999999996, 3.0504],
