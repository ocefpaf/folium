# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_48b36b525abb5bfcccd41e5e0115044e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_48b36b525abb5bfcccd41e5e0115044e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_48b36b525abb5bfcccd41e5e0115044e = L.map(
#                 &quot;map_48b36b525abb5bfcccd41e5e0115044e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7f86a613f2b8355be0977c2895bc981d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7f86a613f2b8355be0977c2895bc981d.addTo(map_48b36b525abb5bfcccd41e5e0115044e);
#
#
#             var marker_a6ebfae656045faad9be58c3d6e7d185 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_48b36b525abb5bfcccd41e5e0115044e);
#
#
#         var popup_d4563f27b715351b753d9862452a1306 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_da54ed97a2f6835eb2da3a59e5159d24 = $(`&lt;div id=&quot;html_da54ed97a2f6835eb2da3a59e5159d24&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_d4563f27b715351b753d9862452a1306.setContent(html_da54ed97a2f6835eb2da3a59e5159d24);
#
#
#
#         marker_a6ebfae656045faad9be58c3d6e7d185.bindPopup(popup_d4563f27b715351b753d9862452a1306)
#         ;
#
#
#
#
#             var marker_47d9fff813f0b8a1027bf8f816a086a7 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_48b36b525abb5bfcccd41e5e0115044e);
#
#
#         var popup_6415497c87d5e9be8c868209f7b82124 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8b2df55f07cf4206086085b4baa61bf6 = $(`&lt;div id=&quot;html_8b2df55f07cf4206086085b4baa61bf6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_6415497c87d5e9be8c868209f7b82124.setContent(html_8b2df55f07cf4206086085b4baa61bf6);
#
#
#
#         marker_47d9fff813f0b8a1027bf8f816a086a7.bindPopup(popup_6415497c87d5e9be8c868209f7b82124)
#         ;
#
#
#
#
#             var marker_220b0780a6fcbf5e3e6dd485da72de2d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_48b36b525abb5bfcccd41e5e0115044e);
#
#
#         var popup_6c189d92d8b7cb204d6f79d27f04b018 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1ac7e401729c7d8787db0e8102f865d6 = $(`&lt;div id=&quot;html_1ac7e401729c7d8787db0e8102f865d6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_6c189d92d8b7cb204d6f79d27f04b018.setContent(html_1ac7e401729c7d8787db0e8102f865d6);
#
#
#
#         marker_220b0780a6fcbf5e3e6dd485da72de2d.bindPopup(popup_6c189d92d8b7cb204d6f79d27f04b018)
#         ;
#
#
#
#
#             var marker_ba15938faeaaa20f0c9398ffee16d794 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_48b36b525abb5bfcccd41e5e0115044e);
#
#
#         var popup_b5ff9731dba4851e191af91df5de0d6b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c85d76b1934e3bb087022392280ce1f3 = $(`&lt;div id=&quot;html_c85d76b1934e3bb087022392280ce1f3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_b5ff9731dba4851e191af91df5de0d6b.setContent(html_c85d76b1934e3bb087022392280ce1f3);
#
#
#
#         marker_ba15938faeaaa20f0c9398ffee16d794.bindPopup(popup_b5ff9731dba4851e191af91df5de0d6b)
#         ;
#
#
#
#
#             var marker_364654bf97bc53eea5fb02066fe1a8ce = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_48b36b525abb5bfcccd41e5e0115044e);
#
#
#         var popup_5d3b7aabf896fe98e12204a6e77f4663 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ea50a3de919857e0ed6c19bb4a41f427 = $(`&lt;div id=&quot;html_ea50a3de919857e0ed6c19bb4a41f427&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_5d3b7aabf896fe98e12204a6e77f4663.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_60f80862a18e4bd50fc45f7f69ba8ae4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_60f80862a18e4bd50fc45f7f69ba8ae4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_60f80862a18e4bd50fc45f7f69ba8ae4 = L.map(
#                 &quot;map_60f80862a18e4bd50fc45f7f69ba8ae4&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2fec20202c4b773d1f4e3501214aa647 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2fec20202c4b773d1f4e3501214aa647.addTo(map_60f80862a18e4bd50fc45f7f69ba8ae4);
#
#
#             var feature_group_47766cd23fef841433aae68b1fa96862 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_b0d03739dca7828b087a2620811d0703 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_47766cd23fef841433aae68b1fa96862);
#
#
#         var popup_48e5fc5e5025c828bee948c622308866 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e76d2254d4749009eeed287ea28afc3d = $(`&lt;div id=&quot;html_e76d2254d4749009eeed287ea28afc3d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_48e5fc5e5025c828bee948c622308866.setContent(html_e76d2254d4749009eeed287ea28afc3d);
#
#
#
#         marker_b0d03739dca7828b087a2620811d0703.bindPopup(popup_48e5fc5e5025c828bee948c622308866)
#         ;
#
#
#
#
#             var marker_52e6f2840b74c6ecb97d10560deca6d4 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_47766cd23fef841433aae68b1fa96862);
#
#
#         var popup_e2d384fc17d63060278a8c7611e794d9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3fb62f53af68f0eddb9c079cfd9b95a3 = $(`&lt;div id=&quot;html_3fb62f53af68f0eddb9c079cfd9b95a3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_e2d384fc17d63060278a8c7611e794d9.setContent(html_3fb62f53af68f0eddb9c079cfd9b95a3);
#
#
#
#         marker_52e6f2840b74c6ecb97d10560deca6d4.bindPopup(popup_e2d384fc17d63060278a8c7611e794d9)
#         ;
#
#
#
#
#             var marker_d1382449fbe3b28b633c71682831732c = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_47766cd23fef841433aae68b1fa96862);
#
#
#         var popup_350ab62d0cf4d5feb961d5525ac73e9d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_48bb762382f4303375766e0a9f10a592 = $(`&lt;div id=&quot;html_48bb762382f4303375766e0a9f10a592&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_350ab62d0cf4d5feb961d5525ac73e9d.setContent(html_48bb762382f4303375766e0a9f10a592);
#
#
#
#         marker_d1382449fbe3b28b633c71682831732c.bindPopup(popup_350ab62d0cf4d5feb961d5525ac73e9d)
#         ;
#
#
#
#
#             var marker_bc8019d1a4533617381cfb3ff890f016 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_47766cd23fef841433aae68b1fa96862);
#
#
#         var popup_6bb20fdab3e4eeed4bdaccca2711e11c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_87fc1a42b937475fafc2a4a198c03a86 = $(`&lt;div id=&quot;html_87fc1a42b937475fafc2a4a198c03a86&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_6bb20fdab3e4eeed4bdaccca2711e11c.setContent(html_87fc1a42b937475fafc2a4a198c03a86);
#
#
#
#         marker_bc8019d1a4533617381cfb3ff890f016.bindPopup(popup_6bb20fdab3e4eeed4bdaccca2711e11c)
#         ;
#
#
#
#
#             var marker_402ea69ec9ae055c58c3bd25f0d9682c = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_47766cd23fef841433aae68b1fa96862);
#
#
#         var popup_f4ee19544ca4eed3e3c1454394ec07f0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7046b3b41dfcd6bfd2b07da9707f4ab4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7046b3b41dfcd6bfd2b07da9707f4ab4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7046b3b41dfcd6bfd2b07da9707f4ab4 = L.map(
#                 &quot;map_7046b3b41dfcd6bfd2b07da9707f4ab4&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_982234781e5f124fe9adab366015fc94 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_982234781e5f124fe9adab366015fc94.addTo(map_7046b3b41dfcd6bfd2b07da9707f4ab4);
#
#
#             var feature_group_49648dd4d5a598d0c545350db4795e4c = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_49648dd4d5a598d0c545350db4795e4c.addTo(map_7046b3b41dfcd6bfd2b07da9707f4ab4);
#
#
#             var feature_group_sub_group_a2164462c951e57700296e3b2d7a58a2 = L.featureGroup.subGroup(
#                 feature_group_49648dd4d5a598d0c545350db4795e4c
#             );
#
#
#             var marker_4d147c6ea9f39ad69ad769891ebb8f0d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_a2164462c951e57700296e3b2d7a58a2);
#
#
#         var popup_284bc0e0bb18f088cc69f7b0ee76fd8e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cc8b0900396c90e23ce387c0750b2eba = $(`&lt;div id=&quot;html_cc8b0900396c90e23ce387c0750b2eba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_284bc0e0bb18f088cc69f7b0ee76fd8e.setContent(html_cc8b0900396c90e23ce387c0750b2eba);
#
#
#
#         marker_4d147c6ea9f39ad69ad769891ebb8f0d.bindPopup(popup_284bc0e0bb18f088cc69f7b0ee76fd8e)
#         ;
#
#
#
#
#             var marker_c56b0bf68207301756257c0fc43c4906 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_a2164462c951e57700296e3b2d7a58a2);
#
#
#         var popup_65ed4c12b7ae637dd9a584a3e5ffbd05 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0e89ae0cbf79055f259a621dc4e8b47c = $(`&lt;div id=&quot;html_0e89ae0cbf79055f259a621dc4e8b47c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_65ed4c12b7ae637dd9a584a3e5ffbd05.setContent(html_0e89ae0cbf79055f259a621dc4e8b47c);
#
#
#
#         marker_c56b0bf68207301756257c0fc43c4906.bindPopup(popup_65ed4c12b7ae637dd9a584a3e5ffbd05)
#         ;
#
#
#
#
#             var marker_6c3e4902b7160d091c5c005a6896c707 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_a2164462c951e57700296e3b2d7a58a2);
#
#
#         var popup_42b17e42d7736b734f6d631e43804054 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_52104b85d982ff21a5821f2a55a6f1ae = $(`&lt;div id=&quot;html_52104b85d982ff21a5821f2a55a6f1ae&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_42b17e42d7736b734f6d631e43804054.setContent(html_52104b85d982ff21a5821f2a55a6f1ae);
#
#
#
#         marker_6c3e4902b7160d091c5c005a6896c707.bindPopup(popup_42b17e42d7736b734f6d631e43804054)
#         ;
#
#
#
#
#             var marker_a462830d21a2af6beb8d5b408eba6861 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_a2164462c951e57700296e3b2d7a58a2);
#
#
#         var popup_aa5b3caa4652f6cc4519d877800f4851 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b9b1c6a50bc5b27e6ce7ded020fdc22d = $(`&lt;div id=&quot;html_b9b1c6a50bc5b27e6ce7ded020fdc22d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_aa5b3caa4652f6cc4519d877800f4851.setContent(html_b9b1c6a50bc5b27e6ce7ded020fdc22d);
#
#
#
#         marker_
