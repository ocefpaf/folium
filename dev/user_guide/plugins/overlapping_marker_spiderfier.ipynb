# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_512fb6292f80bfda80a14fcaff6fa836 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_512fb6292f80bfda80a14fcaff6fa836&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_512fb6292f80bfda80a14fcaff6fa836 = L.map(
#                 &quot;map_512fb6292f80bfda80a14fcaff6fa836&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_52746a4b845ad7f1ea81e61d1b223e74 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_52746a4b845ad7f1ea81e61d1b223e74.addTo(map_512fb6292f80bfda80a14fcaff6fa836);
#
#
#             var marker_f2c79dfabe4e8b8b4bacf171d4b19183 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_512fb6292f80bfda80a14fcaff6fa836);
#
#
#         var popup_72a14a722380ace957f58f5c6f13edcb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ede0bb2a6ff74197705538e52b1670de = $(`&lt;div id=&quot;html_ede0bb2a6ff74197705538e52b1670de&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_72a14a722380ace957f58f5c6f13edcb.setContent(html_ede0bb2a6ff74197705538e52b1670de);
#
#
#
#         marker_f2c79dfabe4e8b8b4bacf171d4b19183.bindPopup(popup_72a14a722380ace957f58f5c6f13edcb)
#         ;
#
#
#
#
#             var marker_fc861bbf4cac492873755fa37badbe2f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_512fb6292f80bfda80a14fcaff6fa836);
#
#
#         var popup_87c4daecaf46ad8cded9e3c985633bb5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_30980e23115516eee6ca8efd8b526754 = $(`&lt;div id=&quot;html_30980e23115516eee6ca8efd8b526754&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_87c4daecaf46ad8cded9e3c985633bb5.setContent(html_30980e23115516eee6ca8efd8b526754);
#
#
#
#         marker_fc861bbf4cac492873755fa37badbe2f.bindPopup(popup_87c4daecaf46ad8cded9e3c985633bb5)
#         ;
#
#
#
#
#             var marker_77c3147f331ca8da0dc7c10b4f1ea770 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_512fb6292f80bfda80a14fcaff6fa836);
#
#
#         var popup_b57ab3ba28564627099426ead5486b07 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_61311f1669f52dc1a1089b3b8b8a739b = $(`&lt;div id=&quot;html_61311f1669f52dc1a1089b3b8b8a739b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_b57ab3ba28564627099426ead5486b07.setContent(html_61311f1669f52dc1a1089b3b8b8a739b);
#
#
#
#         marker_77c3147f331ca8da0dc7c10b4f1ea770.bindPopup(popup_b57ab3ba28564627099426ead5486b07)
#         ;
#
#
#
#
#             var marker_19b92957e408c91a499d5370230a13d6 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_512fb6292f80bfda80a14fcaff6fa836);
#
#
#         var popup_008d364f09dbc73850c691e9eb38add9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1f1b0e698da0598c05596a387ba47e75 = $(`&lt;div id=&quot;html_1f1b0e698da0598c05596a387ba47e75&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_008d364f09dbc73850c691e9eb38add9.setContent(html_1f1b0e698da0598c05596a387ba47e75);
#
#
#
#         marker_19b92957e408c91a499d5370230a13d6.bindPopup(popup_008d364f09dbc73850c691e9eb38add9)
#         ;
#
#
#
#
#             var marker_381e5c154d12befd037d1d73234a2423 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_512fb6292f80bfda80a14fcaff6fa836);
#
#
#         var popup_25c59060fb528071185f04eef713712f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e8971f23b71b66c4a327ed7675e469f3 = $(`&lt;div id=&quot;html_e8971f23b71b66c4a327ed7675e469f3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_25c59060fb528071185f04eef713712f.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a3d1d760557593449da2198168b33019 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a3d1d760557593449da2198168b33019&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a3d1d760557593449da2198168b33019 = L.map(
#                 &quot;map_a3d1d760557593449da2198168b33019&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f9ada9889c7e3d41bda9153224b76751 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f9ada9889c7e3d41bda9153224b76751.addTo(map_a3d1d760557593449da2198168b33019);
#
#
#             var feature_group_1e743bd5d5e8ab42aeeb432372ffaea5 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_fb9aab602510d5e46e92aa098d830028 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_1e743bd5d5e8ab42aeeb432372ffaea5);
#
#
#         var popup_b38dc492aec0d68cbc6ac23f38a7a170 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_191cc2baed2d0287dc162e39d567f68b = $(`&lt;div id=&quot;html_191cc2baed2d0287dc162e39d567f68b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_b38dc492aec0d68cbc6ac23f38a7a170.setContent(html_191cc2baed2d0287dc162e39d567f68b);
#
#
#
#         marker_fb9aab602510d5e46e92aa098d830028.bindPopup(popup_b38dc492aec0d68cbc6ac23f38a7a170)
#         ;
#
#
#
#
#             var marker_c468760546257260d3b48db1b65866dd = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_1e743bd5d5e8ab42aeeb432372ffaea5);
#
#
#         var popup_0892e47554cdb73db90e4423d79cafe1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c0defb730d235e738fc23e94f85156a9 = $(`&lt;div id=&quot;html_c0defb730d235e738fc23e94f85156a9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_0892e47554cdb73db90e4423d79cafe1.setContent(html_c0defb730d235e738fc23e94f85156a9);
#
#
#
#         marker_c468760546257260d3b48db1b65866dd.bindPopup(popup_0892e47554cdb73db90e4423d79cafe1)
#         ;
#
#
#
#
#             var marker_cfd2860463584d7435c30fcfaf424cf7 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_1e743bd5d5e8ab42aeeb432372ffaea5);
#
#
#         var popup_ffe4e0d57c296415f7cbc4c9b0b68f7a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_55c0384b29f16dd37f9e892560d1a463 = $(`&lt;div id=&quot;html_55c0384b29f16dd37f9e892560d1a463&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_ffe4e0d57c296415f7cbc4c9b0b68f7a.setContent(html_55c0384b29f16dd37f9e892560d1a463);
#
#
#
#         marker_cfd2860463584d7435c30fcfaf424cf7.bindPopup(popup_ffe4e0d57c296415f7cbc4c9b0b68f7a)
#         ;
#
#
#
#
#             var marker_84583d232828c9a488028cfc316107b0 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_1e743bd5d5e8ab42aeeb432372ffaea5);
#
#
#         var popup_323ad128a21719298db57743066eb2c9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e10c5cb871a0db72a38bc819774b7fc4 = $(`&lt;div id=&quot;html_e10c5cb871a0db72a38bc819774b7fc4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_323ad128a21719298db57743066eb2c9.setContent(html_e10c5cb871a0db72a38bc819774b7fc4);
#
#
#
#         marker_84583d232828c9a488028cfc316107b0.bindPopup(popup_323ad128a21719298db57743066eb2c9)
#         ;
#
#
#
#
#             var marker_1767f799cc8e8e3de164e5c021f976bc = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_1e743bd5d5e8ab42aeeb432372ffaea5);
#
#
#         var popup_4291fc4f7656dbaa2110c4b933c36e80 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_46ecc4501243a0e4ea96590b2b2fdc4e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_46ecc4501243a0e4ea96590b2b2fdc4e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_46ecc4501243a0e4ea96590b2b2fdc4e = L.map(
#                 &quot;map_46ecc4501243a0e4ea96590b2b2fdc4e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9f1b06d1064a778a5b21277857bd014a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9f1b06d1064a778a5b21277857bd014a.addTo(map_46ecc4501243a0e4ea96590b2b2fdc4e);
#
#
#             var feature_group_3d1bf4b3d2b706834014235d56e41129 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_3d1bf4b3d2b706834014235d56e41129.addTo(map_46ecc4501243a0e4ea96590b2b2fdc4e);
#
#
#             var feature_group_sub_group_87da35a92c09781d34b14d01162420fc = L.featureGroup.subGroup(
#                 feature_group_3d1bf4b3d2b706834014235d56e41129
#             );
#
#
#             var marker_d0cba325c8863889666843ecb32fb594 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_87da35a92c09781d34b14d01162420fc);
#
#
#         var popup_3efdbf1194292096b85d546bc435960e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8de0222b91a85003e891ce9e0dc4cf04 = $(`&lt;div id=&quot;html_8de0222b91a85003e891ce9e0dc4cf04&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_3efdbf1194292096b85d546bc435960e.setContent(html_8de0222b91a85003e891ce9e0dc4cf04);
#
#
#
#         marker_d0cba325c8863889666843ecb32fb594.bindPopup(popup_3efdbf1194292096b85d546bc435960e)
#         ;
#
#
#
#
#             var marker_0b80ba00c5689398650cb7b1eb6058bc = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_87da35a92c09781d34b14d01162420fc);
#
#
#         var popup_9328ad5fb334a8d6bc8293d0c0a224bd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4828d12d7d19f44e543c2af08005a2bf = $(`&lt;div id=&quot;html_4828d12d7d19f44e543c2af08005a2bf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_9328ad5fb334a8d6bc8293d0c0a224bd.setContent(html_4828d12d7d19f44e543c2af08005a2bf);
#
#
#
#         marker_0b80ba00c5689398650cb7b1eb6058bc.bindPopup(popup_9328ad5fb334a8d6bc8293d0c0a224bd)
#         ;
#
#
#
#
#             var marker_37e4a35415397d938dc131c9c976d1dd = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_87da35a92c09781d34b14d01162420fc);
#
#
#         var popup_5644e2da4b5bfc2363c0bacd5e225fc5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_db7ebb07535f47f0c09fa05728ec48c1 = $(`&lt;div id=&quot;html_db7ebb07535f47f0c09fa05728ec48c1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_5644e2da4b5bfc2363c0bacd5e225fc5.setContent(html_db7ebb07535f47f0c09fa05728ec48c1);
#
#
#
#         marker_37e4a35415397d938dc131c9c976d1dd.bindPopup(popup_5644e2da4b5bfc2363c0bacd5e225fc5)
#         ;
#
#
#
#
#             var marker_202bbf4b2811ee511e0d1c0dccdb8815 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_87da35a92c09781d34b14d01162420fc);
#
#
#         var popup_c745c4750da949937abf0204db451219 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fd39f04d143c871cb55002842f1aca04 = $(`&lt;div id=&quot;html_fd39f04d143c871cb55002842f1aca04&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_c745c4750da949937abf0204db451219.setContent(html_fd39f04d143c871cb55002842f1aca04);
#
#
#
#         marker_
