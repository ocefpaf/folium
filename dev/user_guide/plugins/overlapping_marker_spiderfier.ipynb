# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_81c1a014f91a7f36cf39ff1ed24b1a29 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_81c1a014f91a7f36cf39ff1ed24b1a29&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_81c1a014f91a7f36cf39ff1ed24b1a29 = L.map(
#                 &quot;map_81c1a014f91a7f36cf39ff1ed24b1a29&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7dd5e559ad7568bc452406b075df5bd0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7dd5e559ad7568bc452406b075df5bd0.addTo(map_81c1a014f91a7f36cf39ff1ed24b1a29);
#
#
#             var marker_79c58d13345bb03bae31841905b6e729 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_81c1a014f91a7f36cf39ff1ed24b1a29);
#
#
#         var popup_92c59520ecb23fbfb38fe74e1abbab47 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_94f25853a3541fb7613e248197d9ced9 = $(`&lt;div id=&quot;html_94f25853a3541fb7613e248197d9ced9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_92c59520ecb23fbfb38fe74e1abbab47.setContent(html_94f25853a3541fb7613e248197d9ced9);
#
#
#
#         marker_79c58d13345bb03bae31841905b6e729.bindPopup(popup_92c59520ecb23fbfb38fe74e1abbab47)
#         ;
#
#
#
#
#             var marker_fda562bdcc290b0272fa2c20acfa8c9d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_81c1a014f91a7f36cf39ff1ed24b1a29);
#
#
#         var popup_1e420cd388831d94aa84688e71880393 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a23405d65b5c8457db5bf9be20937ee6 = $(`&lt;div id=&quot;html_a23405d65b5c8457db5bf9be20937ee6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_1e420cd388831d94aa84688e71880393.setContent(html_a23405d65b5c8457db5bf9be20937ee6);
#
#
#
#         marker_fda562bdcc290b0272fa2c20acfa8c9d.bindPopup(popup_1e420cd388831d94aa84688e71880393)
#         ;
#
#
#
#
#             var marker_98ce80b3f6a609256320d0f8ed856d2a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_81c1a014f91a7f36cf39ff1ed24b1a29);
#
#
#         var popup_585d057199ec8e4317271d320354c89b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_011d857da39ac3ce80e00d83c67615bc = $(`&lt;div id=&quot;html_011d857da39ac3ce80e00d83c67615bc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_585d057199ec8e4317271d320354c89b.setContent(html_011d857da39ac3ce80e00d83c67615bc);
#
#
#
#         marker_98ce80b3f6a609256320d0f8ed856d2a.bindPopup(popup_585d057199ec8e4317271d320354c89b)
#         ;
#
#
#
#
#             var marker_0a2b51aa04bda13b9beb51f72862a4aa = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_81c1a014f91a7f36cf39ff1ed24b1a29);
#
#
#         var popup_c989ea27e1c83c9cf564b4a268519dad = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5562e197f222b04aaab04884c19cedc0 = $(`&lt;div id=&quot;html_5562e197f222b04aaab04884c19cedc0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_c989ea27e1c83c9cf564b4a268519dad.setContent(html_5562e197f222b04aaab04884c19cedc0);
#
#
#
#         marker_0a2b51aa04bda13b9beb51f72862a4aa.bindPopup(popup_c989ea27e1c83c9cf564b4a268519dad)
#         ;
#
#
#
#
#             var marker_549f4a514a43cf0e7189588f298ab46c = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_81c1a014f91a7f36cf39ff1ed24b1a29);
#
#
#         var popup_b76aa43b55a997db0952a3beeae3216c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c116087bde560424773b93842b35fc36 = $(`&lt;div id=&quot;html_c116087bde560424773b93842b35fc36&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_b76aa43b55a997db0952a3beeae3216c.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c0401eb46e8a30302e5582d13e90146b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c0401eb46e8a30302e5582d13e90146b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c0401eb46e8a30302e5582d13e90146b = L.map(
#                 &quot;map_c0401eb46e8a30302e5582d13e90146b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b84b92d2a9280ba3af4a42a4e330550a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b84b92d2a9280ba3af4a42a4e330550a.addTo(map_c0401eb46e8a30302e5582d13e90146b);
#
#
#             var feature_group_00cca46c79e1d1ae24b84d7c808c2b0b = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_9ce7f08bd39973b60dadf5acefd48fa1 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_00cca46c79e1d1ae24b84d7c808c2b0b);
#
#
#         var popup_19031249cb860355f88f503908519536 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_675fcdb5746bcd83dda3e7da6f726dbf = $(`&lt;div id=&quot;html_675fcdb5746bcd83dda3e7da6f726dbf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_19031249cb860355f88f503908519536.setContent(html_675fcdb5746bcd83dda3e7da6f726dbf);
#
#
#
#         marker_9ce7f08bd39973b60dadf5acefd48fa1.bindPopup(popup_19031249cb860355f88f503908519536)
#         ;
#
#
#
#
#             var marker_fb2bd240dad3f3765ab7bfd27b219016 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_00cca46c79e1d1ae24b84d7c808c2b0b);
#
#
#         var popup_b86d3e1751d1b16aa6455cbc95953f2a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d4e158581ddf4fe23928af9f1d2b73b8 = $(`&lt;div id=&quot;html_d4e158581ddf4fe23928af9f1d2b73b8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_b86d3e1751d1b16aa6455cbc95953f2a.setContent(html_d4e158581ddf4fe23928af9f1d2b73b8);
#
#
#
#         marker_fb2bd240dad3f3765ab7bfd27b219016.bindPopup(popup_b86d3e1751d1b16aa6455cbc95953f2a)
#         ;
#
#
#
#
#             var marker_566b289342c65b0b6afc150a35ce3e7c = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_00cca46c79e1d1ae24b84d7c808c2b0b);
#
#
#         var popup_49efc8a249fcd9e02d8523a51bebfab9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_16948488009a80b5edceab9633c6b4dd = $(`&lt;div id=&quot;html_16948488009a80b5edceab9633c6b4dd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_49efc8a249fcd9e02d8523a51bebfab9.setContent(html_16948488009a80b5edceab9633c6b4dd);
#
#
#
#         marker_566b289342c65b0b6afc150a35ce3e7c.bindPopup(popup_49efc8a249fcd9e02d8523a51bebfab9)
#         ;
#
#
#
#
#             var marker_cb308325d13d75f9e5e4e2d88e5fa306 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_00cca46c79e1d1ae24b84d7c808c2b0b);
#
#
#         var popup_6490b2870a9e34316188d5d0266d96a6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6eced296eb8fb91c24841dc906f1cffe = $(`&lt;div id=&quot;html_6eced296eb8fb91c24841dc906f1cffe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_6490b2870a9e34316188d5d0266d96a6.setContent(html_6eced296eb8fb91c24841dc906f1cffe);
#
#
#
#         marker_cb308325d13d75f9e5e4e2d88e5fa306.bindPopup(popup_6490b2870a9e34316188d5d0266d96a6)
#         ;
#
#
#
#
#             var marker_a286abf5559e27552a7f120fb8a44851 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_00cca46c79e1d1ae24b84d7c808c2b0b);
#
#
#         var popup_f9169c7b7be6a4288f7d915f32538f71 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f81d5a9804e67b693140b987798d74b0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f81d5a9804e67b693140b987798d74b0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f81d5a9804e67b693140b987798d74b0 = L.map(
#                 &quot;map_f81d5a9804e67b693140b987798d74b0&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8d24c06ddeae817f321277a77bd8e437 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8d24c06ddeae817f321277a77bd8e437.addTo(map_f81d5a9804e67b693140b987798d74b0);
#
#
#             var feature_group_6818ec626897b8bcb5bd2fb704210a6e = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_6818ec626897b8bcb5bd2fb704210a6e.addTo(map_f81d5a9804e67b693140b987798d74b0);
#
#
#             var feature_group_sub_group_689a04f8c9470bcc51d91befe57c3806 = L.featureGroup.subGroup(
#                 feature_group_6818ec626897b8bcb5bd2fb704210a6e
#             );
#
#
#             var marker_bb810fc3c9f172b6ed7358c3779350dc = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_689a04f8c9470bcc51d91befe57c3806);
#
#
#         var popup_38bc1eba879f76a3c0e7f278143507aa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_854701fefc6de4d032adc61c17898529 = $(`&lt;div id=&quot;html_854701fefc6de4d032adc61c17898529&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_38bc1eba879f76a3c0e7f278143507aa.setContent(html_854701fefc6de4d032adc61c17898529);
#
#
#
#         marker_bb810fc3c9f172b6ed7358c3779350dc.bindPopup(popup_38bc1eba879f76a3c0e7f278143507aa)
#         ;
#
#
#
#
#             var marker_e9cd76c075f29b7621fdbc574d423b3e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_689a04f8c9470bcc51d91befe57c3806);
#
#
#         var popup_ac613ae16bcad1053011a28b6691b638 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c689e0818f30deeac7bd1038c5784d61 = $(`&lt;div id=&quot;html_c689e0818f30deeac7bd1038c5784d61&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_ac613ae16bcad1053011a28b6691b638.setContent(html_c689e0818f30deeac7bd1038c5784d61);
#
#
#
#         marker_e9cd76c075f29b7621fdbc574d423b3e.bindPopup(popup_ac613ae16bcad1053011a28b6691b638)
#         ;
#
#
#
#
#             var marker_b6a2313420654a99bf454b8c0319c93a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_689a04f8c9470bcc51d91befe57c3806);
#
#
#         var popup_7c43066f0ed9182e71554b8b7924c3c5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_85fa0ce60281ae3d498153a0e3bac896 = $(`&lt;div id=&quot;html_85fa0ce60281ae3d498153a0e3bac896&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_7c43066f0ed9182e71554b8b7924c3c5.setContent(html_85fa0ce60281ae3d498153a0e3bac896);
#
#
#
#         marker_b6a2313420654a99bf454b8c0319c93a.bindPopup(popup_7c43066f0ed9182e71554b8b7924c3c5)
#         ;
#
#
#
#
#             var marker_f2b1b855e83afd72b95349d42c419e5c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_689a04f8c9470bcc51d91befe57c3806);
#
#
#         var popup_662817df69dd15c049ec621db87c6e37 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_65e5d34e33a7961893fe29f67ea69ed8 = $(`&lt;div id=&quot;html_65e5d34e33a7961893fe29f67ea69ed8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_662817df69dd15c049ec621db87c6e37.setContent(html_65e5d34e33a7961893fe29f67ea69ed8);
#
#
#
#         marker_
