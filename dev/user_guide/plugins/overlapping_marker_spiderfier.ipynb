# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_67afa63b40dbcb58c7f9b1b55417bd0a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_67afa63b40dbcb58c7f9b1b55417bd0a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_67afa63b40dbcb58c7f9b1b55417bd0a = L.map(
#                 &quot;map_67afa63b40dbcb58c7f9b1b55417bd0a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8cb8feb9c49727bfe27dd954918d8839 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8cb8feb9c49727bfe27dd954918d8839.addTo(map_67afa63b40dbcb58c7f9b1b55417bd0a);
#
#
#             var marker_4da2ab8c78accbea36d360b93f60c848 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_67afa63b40dbcb58c7f9b1b55417bd0a);
#
#
#         var popup_7c352e37d13daadceead24610cb71b4a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_35c39aba997c3ea39a3d7ccf9706635e = $(`&lt;div id=&quot;html_35c39aba997c3ea39a3d7ccf9706635e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_7c352e37d13daadceead24610cb71b4a.setContent(html_35c39aba997c3ea39a3d7ccf9706635e);
#
#
#
#         marker_4da2ab8c78accbea36d360b93f60c848.bindPopup(popup_7c352e37d13daadceead24610cb71b4a)
#         ;
#
#
#
#
#             var marker_e5b50e2b3bd44662d946e9edfc6c2277 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_67afa63b40dbcb58c7f9b1b55417bd0a);
#
#
#         var popup_9d4729c52551e893c106fe30b68899f8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fba1c496a784bb1baf13700b4ac7d05d = $(`&lt;div id=&quot;html_fba1c496a784bb1baf13700b4ac7d05d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_9d4729c52551e893c106fe30b68899f8.setContent(html_fba1c496a784bb1baf13700b4ac7d05d);
#
#
#
#         marker_e5b50e2b3bd44662d946e9edfc6c2277.bindPopup(popup_9d4729c52551e893c106fe30b68899f8)
#         ;
#
#
#
#
#             var marker_b2e3cbfdfd499f5676fd2f3c70376c36 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_67afa63b40dbcb58c7f9b1b55417bd0a);
#
#
#         var popup_f9298c979a966cabea66dc815c2fe839 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e40e242cd35c38c1a3f4687f30e43f99 = $(`&lt;div id=&quot;html_e40e242cd35c38c1a3f4687f30e43f99&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_f9298c979a966cabea66dc815c2fe839.setContent(html_e40e242cd35c38c1a3f4687f30e43f99);
#
#
#
#         marker_b2e3cbfdfd499f5676fd2f3c70376c36.bindPopup(popup_f9298c979a966cabea66dc815c2fe839)
#         ;
#
#
#
#
#             var marker_4fd8763d3ca1cc66d6f9ae28ff9f70df = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_67afa63b40dbcb58c7f9b1b55417bd0a);
#
#
#         var popup_1ecfe9632c3300693dd1a05ffe6c3d6b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_898f0bbccb3cb2fe0bd1206e85b3df8c = $(`&lt;div id=&quot;html_898f0bbccb3cb2fe0bd1206e85b3df8c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_1ecfe9632c3300693dd1a05ffe6c3d6b.setContent(html_898f0bbccb3cb2fe0bd1206e85b3df8c);
#
#
#
#         marker_4fd8763d3ca1cc66d6f9ae28ff9f70df.bindPopup(popup_1ecfe9632c3300693dd1a05ffe6c3d6b)
#         ;
#
#
#
#
#             var marker_cb51fb56f15ac44daa470dec15036eab = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_67afa63b40dbcb58c7f9b1b55417bd0a);
#
#
#         var popup_1e1c4c0bc0cc6d3937aecc96c50c5451 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_93141026bc8f005327eced09e62ec619 = $(`&lt;div id=&quot;html_93141026bc8f005327eced09e62ec619&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_1e1c4c0bc0cc6d3937aecc96c50c5451.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9109efb1c63f8c1aaf0c4d24df458d59 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9109efb1c63f8c1aaf0c4d24df458d59&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9109efb1c63f8c1aaf0c4d24df458d59 = L.map(
#                 &quot;map_9109efb1c63f8c1aaf0c4d24df458d59&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c45e6ded37dfa7517f9ef06b1c25aaa6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c45e6ded37dfa7517f9ef06b1c25aaa6.addTo(map_9109efb1c63f8c1aaf0c4d24df458d59);
#
#
#             var feature_group_9cac779277af6d6898ebccf8ba145163 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_b0d5247b3e8a18af191927ee1c7af285 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_9cac779277af6d6898ebccf8ba145163);
#
#
#         var popup_fd614c28b24969a98f1d40b7c40c136c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_878825bfb7246d391775dfa0a5d681df = $(`&lt;div id=&quot;html_878825bfb7246d391775dfa0a5d681df&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_fd614c28b24969a98f1d40b7c40c136c.setContent(html_878825bfb7246d391775dfa0a5d681df);
#
#
#
#         marker_b0d5247b3e8a18af191927ee1c7af285.bindPopup(popup_fd614c28b24969a98f1d40b7c40c136c)
#         ;
#
#
#
#
#             var marker_87508a6c8a5ed7287b8627909b10b505 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_9cac779277af6d6898ebccf8ba145163);
#
#
#         var popup_ffc8d21be8f277f5123c12f49a21a0d1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_977adb84d9f93d864f072465aa31e9dd = $(`&lt;div id=&quot;html_977adb84d9f93d864f072465aa31e9dd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_ffc8d21be8f277f5123c12f49a21a0d1.setContent(html_977adb84d9f93d864f072465aa31e9dd);
#
#
#
#         marker_87508a6c8a5ed7287b8627909b10b505.bindPopup(popup_ffc8d21be8f277f5123c12f49a21a0d1)
#         ;
#
#
#
#
#             var marker_ed5989bc6111e3c636b191b5bc279314 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_9cac779277af6d6898ebccf8ba145163);
#
#
#         var popup_960c7bf8c7f74e43093619283303780d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9f756bd143c6896f891c0d5e848e76c0 = $(`&lt;div id=&quot;html_9f756bd143c6896f891c0d5e848e76c0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_960c7bf8c7f74e43093619283303780d.setContent(html_9f756bd143c6896f891c0d5e848e76c0);
#
#
#
#         marker_ed5989bc6111e3c636b191b5bc279314.bindPopup(popup_960c7bf8c7f74e43093619283303780d)
#         ;
#
#
#
#
#             var marker_a942450c3511e466118e726a196f27ba = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_9cac779277af6d6898ebccf8ba145163);
#
#
#         var popup_1012726a41bb6bf6b06a68d353f97018 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_542f6297bcffd775ef72079b0a69c9ff = $(`&lt;div id=&quot;html_542f6297bcffd775ef72079b0a69c9ff&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_1012726a41bb6bf6b06a68d353f97018.setContent(html_542f6297bcffd775ef72079b0a69c9ff);
#
#
#
#         marker_a942450c3511e466118e726a196f27ba.bindPopup(popup_1012726a41bb6bf6b06a68d353f97018)
#         ;
#
#
#
#
#             var marker_63698e32bb065644ae1dff7bac4b3fc4 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_9cac779277af6d6898ebccf8ba145163);
#
#
#         var popup_1ae9ecc705fdb4ec9e02a9932a2ff764 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0c7bdb5a4a211bbf48191852a78b11ef {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0c7bdb5a4a211bbf48191852a78b11ef&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0c7bdb5a4a211bbf48191852a78b11ef = L.map(
#                 &quot;map_0c7bdb5a4a211bbf48191852a78b11ef&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d7a96d58b5910851660b3d28d23773cf = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d7a96d58b5910851660b3d28d23773cf.addTo(map_0c7bdb5a4a211bbf48191852a78b11ef);
#
#
#             var feature_group_2b9ecc5bdf832e87a63e48c612693286 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_2b9ecc5bdf832e87a63e48c612693286.addTo(map_0c7bdb5a4a211bbf48191852a78b11ef);
#
#
#             var feature_group_sub_group_7d07b4d07373b5ec9b6d2e7cb4291665 = L.featureGroup.subGroup(
#                 feature_group_2b9ecc5bdf832e87a63e48c612693286
#             );
#
#
#             var marker_bd26419de7090ca20c2b4bfa2e5fa8cd = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_7d07b4d07373b5ec9b6d2e7cb4291665);
#
#
#         var popup_cd8e4648a8b53bc40dca959c09daca94 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_406ba62f1e72365c417083b406a46769 = $(`&lt;div id=&quot;html_406ba62f1e72365c417083b406a46769&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_cd8e4648a8b53bc40dca959c09daca94.setContent(html_406ba62f1e72365c417083b406a46769);
#
#
#
#         marker_bd26419de7090ca20c2b4bfa2e5fa8cd.bindPopup(popup_cd8e4648a8b53bc40dca959c09daca94)
#         ;
#
#
#
#
#             var marker_e9aed40a60323727d719e380fe916894 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_7d07b4d07373b5ec9b6d2e7cb4291665);
#
#
#         var popup_3a5cec20e9e09dc6cb91cb179e3a7e3e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_843df4a8f28afc1a9599b143dac75b3f = $(`&lt;div id=&quot;html_843df4a8f28afc1a9599b143dac75b3f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_3a5cec20e9e09dc6cb91cb179e3a7e3e.setContent(html_843df4a8f28afc1a9599b143dac75b3f);
#
#
#
#         marker_e9aed40a60323727d719e380fe916894.bindPopup(popup_3a5cec20e9e09dc6cb91cb179e3a7e3e)
#         ;
#
#
#
#
#             var marker_019065e245f7d21a2dbfd407ca02dc1b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_7d07b4d07373b5ec9b6d2e7cb4291665);
#
#
#         var popup_528661aa37ba17a57e37159d21778b59 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7dec1a0575176e1db947161ed3e87e1b = $(`&lt;div id=&quot;html_7dec1a0575176e1db947161ed3e87e1b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_528661aa37ba17a57e37159d21778b59.setContent(html_7dec1a0575176e1db947161ed3e87e1b);
#
#
#
#         marker_019065e245f7d21a2dbfd407ca02dc1b.bindPopup(popup_528661aa37ba17a57e37159d21778b59)
#         ;
#
#
#
#
#             var marker_11c88b7bf0d911c7fce1ea3109bd9657 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_7d07b4d07373b5ec9b6d2e7cb4291665);
#
#
#         var popup_e8d59e4b1dfa01d1edf40098427e3ce6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_22eb418044bed7066e169df74a0d201c = $(`&lt;div id=&quot;html_22eb418044bed7066e169df74a0d201c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_e8d59e4b1dfa01d1edf40098427e3ce6.setContent(html_22eb418044bed7066e169df74a0d201c);
#
#
#
#         marker_
