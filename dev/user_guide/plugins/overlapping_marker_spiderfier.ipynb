# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6fddc6b6bca74a778eae266e6da02d7c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6fddc6b6bca74a778eae266e6da02d7c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6fddc6b6bca74a778eae266e6da02d7c = L.map(
#                 &quot;map_6fddc6b6bca74a778eae266e6da02d7c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c097b841adfcc6f919659f512cc9bd40 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c097b841adfcc6f919659f512cc9bd40.addTo(map_6fddc6b6bca74a778eae266e6da02d7c);
#
#
#             var marker_dc6c47337badf541d6c498a8b4153d2c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_6fddc6b6bca74a778eae266e6da02d7c);
#
#
#         var popup_264ea8a62ba0ff4f2d8426ccfe449d3d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a719d0d7114557fa9b89134ea680f502 = $(`&lt;div id=&quot;html_a719d0d7114557fa9b89134ea680f502&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_264ea8a62ba0ff4f2d8426ccfe449d3d.setContent(html_a719d0d7114557fa9b89134ea680f502);
#
#
#
#         marker_dc6c47337badf541d6c498a8b4153d2c.bindPopup(popup_264ea8a62ba0ff4f2d8426ccfe449d3d)
#         ;
#
#
#
#
#             var marker_cc74913d091d20b8f278508eb76ac1f9 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_6fddc6b6bca74a778eae266e6da02d7c);
#
#
#         var popup_3cf953269740a0d3ab4568ba7ec52885 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_894d16dfd90b3e96c8ce9e7045ebfb8b = $(`&lt;div id=&quot;html_894d16dfd90b3e96c8ce9e7045ebfb8b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_3cf953269740a0d3ab4568ba7ec52885.setContent(html_894d16dfd90b3e96c8ce9e7045ebfb8b);
#
#
#
#         marker_cc74913d091d20b8f278508eb76ac1f9.bindPopup(popup_3cf953269740a0d3ab4568ba7ec52885)
#         ;
#
#
#
#
#             var marker_e72372586a0dde7c3ab9abffef67fa94 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_6fddc6b6bca74a778eae266e6da02d7c);
#
#
#         var popup_70a786c7e3683eef9e3b93b6bdf88f53 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3eb29377e3fe7be21320f2dcb4d24b11 = $(`&lt;div id=&quot;html_3eb29377e3fe7be21320f2dcb4d24b11&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_70a786c7e3683eef9e3b93b6bdf88f53.setContent(html_3eb29377e3fe7be21320f2dcb4d24b11);
#
#
#
#         marker_e72372586a0dde7c3ab9abffef67fa94.bindPopup(popup_70a786c7e3683eef9e3b93b6bdf88f53)
#         ;
#
#
#
#
#             var marker_985d2b30df358f50f15cfb9a1f2f0d68 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_6fddc6b6bca74a778eae266e6da02d7c);
#
#
#         var popup_ab9fd206ef0131bd3ebc2166c6496e5d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a151229c5e91253b26894473bbf0befd = $(`&lt;div id=&quot;html_a151229c5e91253b26894473bbf0befd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_ab9fd206ef0131bd3ebc2166c6496e5d.setContent(html_a151229c5e91253b26894473bbf0befd);
#
#
#
#         marker_985d2b30df358f50f15cfb9a1f2f0d68.bindPopup(popup_ab9fd206ef0131bd3ebc2166c6496e5d)
#         ;
#
#
#
#
#             var marker_e8495ee0b064aa2353e486de44c243c6 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_6fddc6b6bca74a778eae266e6da02d7c);
#
#
#         var popup_abdd3c5b1e186e7e2040c5b7100ce2ce = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9ca6428f882afa1086040381af811358 = $(`&lt;div id=&quot;html_9ca6428f882afa1086040381af811358&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_abdd3c5b1e186e7e2040c5b7100ce2ce.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a238fcf3c605e55645ecf3f0ae634575 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a238fcf3c605e55645ecf3f0ae634575&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a238fcf3c605e55645ecf3f0ae634575 = L.map(
#                 &quot;map_a238fcf3c605e55645ecf3f0ae634575&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ce04d5d8d88267cd54b0efd00b5d7d6b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ce04d5d8d88267cd54b0efd00b5d7d6b.addTo(map_a238fcf3c605e55645ecf3f0ae634575);
#
#
#             var feature_group_3179d1dd257c839fd38bcd7ca7500aa9 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_c84483bad5d9218069331a5638c804af = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_3179d1dd257c839fd38bcd7ca7500aa9);
#
#
#         var popup_1a3a130b311e9fac6c8fd968422d8bfd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6077afb056022be7180768321c9bf318 = $(`&lt;div id=&quot;html_6077afb056022be7180768321c9bf318&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_1a3a130b311e9fac6c8fd968422d8bfd.setContent(html_6077afb056022be7180768321c9bf318);
#
#
#
#         marker_c84483bad5d9218069331a5638c804af.bindPopup(popup_1a3a130b311e9fac6c8fd968422d8bfd)
#         ;
#
#
#
#
#             var marker_06f9492c4c59a9a9fef4031eac1b2d45 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_3179d1dd257c839fd38bcd7ca7500aa9);
#
#
#         var popup_a91721d10c5b568d356c80ecf93c7314 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6437189558626959814b2d717a5f1a4b = $(`&lt;div id=&quot;html_6437189558626959814b2d717a5f1a4b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_a91721d10c5b568d356c80ecf93c7314.setContent(html_6437189558626959814b2d717a5f1a4b);
#
#
#
#         marker_06f9492c4c59a9a9fef4031eac1b2d45.bindPopup(popup_a91721d10c5b568d356c80ecf93c7314)
#         ;
#
#
#
#
#             var marker_0a9a7ef6b740f14408f03ba8195eddba = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_3179d1dd257c839fd38bcd7ca7500aa9);
#
#
#         var popup_c5200686980c6b00614ea0fce55fce55 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_68763fe0204b3ca26c1860b6dabdc8ab = $(`&lt;div id=&quot;html_68763fe0204b3ca26c1860b6dabdc8ab&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_c5200686980c6b00614ea0fce55fce55.setContent(html_68763fe0204b3ca26c1860b6dabdc8ab);
#
#
#
#         marker_0a9a7ef6b740f14408f03ba8195eddba.bindPopup(popup_c5200686980c6b00614ea0fce55fce55)
#         ;
#
#
#
#
#             var marker_3dc2d3cd889e49b560ea9d587a67b45d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_3179d1dd257c839fd38bcd7ca7500aa9);
#
#
#         var popup_63aa643ab50570123c2948d8194db29c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2296d55cba54d0506a12c42eff80ba68 = $(`&lt;div id=&quot;html_2296d55cba54d0506a12c42eff80ba68&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_63aa643ab50570123c2948d8194db29c.setContent(html_2296d55cba54d0506a12c42eff80ba68);
#
#
#
#         marker_3dc2d3cd889e49b560ea9d587a67b45d.bindPopup(popup_63aa643ab50570123c2948d8194db29c)
#         ;
#
#
#
#
#             var marker_571237eb5f761d32548459414e7902c6 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_3179d1dd257c839fd38bcd7ca7500aa9);
#
#
#         var popup_cb4e972f7a817bb552ccded20bc9bbed = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_62b71b8a7452582b5260a2dd0b516486 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_62b71b8a7452582b5260a2dd0b516486&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_62b71b8a7452582b5260a2dd0b516486 = L.map(
#                 &quot;map_62b71b8a7452582b5260a2dd0b516486&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c5260f938a1a89a4bc57c901d66c8f13 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c5260f938a1a89a4bc57c901d66c8f13.addTo(map_62b71b8a7452582b5260a2dd0b516486);
#
#
#             var feature_group_af3d58967e788f24a95483ac0833b276 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_af3d58967e788f24a95483ac0833b276.addTo(map_62b71b8a7452582b5260a2dd0b516486);
#
#
#             var feature_group_sub_group_79ddae6544a07784d52ae2a62e7dd5c9 = L.featureGroup.subGroup(
#                 feature_group_af3d58967e788f24a95483ac0833b276
#             );
#
#
#             var marker_2532b62990106259ad6f6be8af60ed26 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_79ddae6544a07784d52ae2a62e7dd5c9);
#
#
#         var popup_d107e2e7190a02257f67e7fd1b59f4b2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_358eac4dcd0eeee48b52a6718cd6c244 = $(`&lt;div id=&quot;html_358eac4dcd0eeee48b52a6718cd6c244&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_d107e2e7190a02257f67e7fd1b59f4b2.setContent(html_358eac4dcd0eeee48b52a6718cd6c244);
#
#
#
#         marker_2532b62990106259ad6f6be8af60ed26.bindPopup(popup_d107e2e7190a02257f67e7fd1b59f4b2)
#         ;
#
#
#
#
#             var marker_64ee2d1d4fcb49425b729c02baebec17 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_79ddae6544a07784d52ae2a62e7dd5c9);
#
#
#         var popup_46af99f5f9a8b68fef6c3b3e1a95cdc1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_726624d0d817b16a5eafbcf226140969 = $(`&lt;div id=&quot;html_726624d0d817b16a5eafbcf226140969&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_46af99f5f9a8b68fef6c3b3e1a95cdc1.setContent(html_726624d0d817b16a5eafbcf226140969);
#
#
#
#         marker_64ee2d1d4fcb49425b729c02baebec17.bindPopup(popup_46af99f5f9a8b68fef6c3b3e1a95cdc1)
#         ;
#
#
#
#
#             var marker_1def205e0beb97b9884dbdf08d2627d8 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_79ddae6544a07784d52ae2a62e7dd5c9);
#
#
#         var popup_52c10fbc68c082ffae6d747f81f9f673 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f80ef26eeedbdb205cbf281ee713d17e = $(`&lt;div id=&quot;html_f80ef26eeedbdb205cbf281ee713d17e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_52c10fbc68c082ffae6d747f81f9f673.setContent(html_f80ef26eeedbdb205cbf281ee713d17e);
#
#
#
#         marker_1def205e0beb97b9884dbdf08d2627d8.bindPopup(popup_52c10fbc68c082ffae6d747f81f9f673)
#         ;
#
#
#
#
#             var marker_6d7d4dc656329083545c45ca5819e5ff = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_79ddae6544a07784d52ae2a62e7dd5c9);
#
#
#         var popup_bbc6df8f600cccc93d79a0624f017711 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5d2da43772cdbf3426ae4853633fa33b = $(`&lt;div id=&quot;html_5d2da43772cdbf3426ae4853633fa33b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_bbc6df8f600cccc93d79a0624f017711.setContent(html_5d2da43772cdbf3426ae4853633fa33b);
#
#
#
#         marker_
