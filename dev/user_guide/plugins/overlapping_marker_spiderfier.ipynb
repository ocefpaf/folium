# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_83ed27f54d11c06144989aa40b93ce41 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_83ed27f54d11c06144989aa40b93ce41&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_83ed27f54d11c06144989aa40b93ce41 = L.map(
#                 &quot;map_83ed27f54d11c06144989aa40b93ce41&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ed721112ef349858dcf250ecc319907c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ed721112ef349858dcf250ecc319907c.addTo(map_83ed27f54d11c06144989aa40b93ce41);
#
#
#             var marker_7d54c5e9dd565298b046237f4af54fe2 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_83ed27f54d11c06144989aa40b93ce41);
#
#
#         var popup_a5447925610c896fe53166a4b801568e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8796b14bf8060c2606d663edb3e20ab6 = $(`&lt;div id=&quot;html_8796b14bf8060c2606d663edb3e20ab6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_a5447925610c896fe53166a4b801568e.setContent(html_8796b14bf8060c2606d663edb3e20ab6);
#
#
#
#         marker_7d54c5e9dd565298b046237f4af54fe2.bindPopup(popup_a5447925610c896fe53166a4b801568e)
#         ;
#
#
#
#
#             var marker_e8bbbf439f5765f7c966692bea02e77f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_83ed27f54d11c06144989aa40b93ce41);
#
#
#         var popup_827434c8c6441513ed149d4f7d948375 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8544f32e21db026ac17a2663b2570734 = $(`&lt;div id=&quot;html_8544f32e21db026ac17a2663b2570734&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_827434c8c6441513ed149d4f7d948375.setContent(html_8544f32e21db026ac17a2663b2570734);
#
#
#
#         marker_e8bbbf439f5765f7c966692bea02e77f.bindPopup(popup_827434c8c6441513ed149d4f7d948375)
#         ;
#
#
#
#
#             var marker_1200973749e838779899c8dbff49cd96 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_83ed27f54d11c06144989aa40b93ce41);
#
#
#         var popup_37645f30fa088bdeaef81d4702c58d4d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5c4c1b330c596411cdba1f31f3bccbcd = $(`&lt;div id=&quot;html_5c4c1b330c596411cdba1f31f3bccbcd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_37645f30fa088bdeaef81d4702c58d4d.setContent(html_5c4c1b330c596411cdba1f31f3bccbcd);
#
#
#
#         marker_1200973749e838779899c8dbff49cd96.bindPopup(popup_37645f30fa088bdeaef81d4702c58d4d)
#         ;
#
#
#
#
#             var marker_d45c0f46424fd6f327f53d8fd77a8cd9 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_83ed27f54d11c06144989aa40b93ce41);
#
#
#         var popup_5bf380467b7b2efdf913e6b7a360c973 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8c5c21511bc0c5bfcacb0cf53532fa96 = $(`&lt;div id=&quot;html_8c5c21511bc0c5bfcacb0cf53532fa96&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_5bf380467b7b2efdf913e6b7a360c973.setContent(html_8c5c21511bc0c5bfcacb0cf53532fa96);
#
#
#
#         marker_d45c0f46424fd6f327f53d8fd77a8cd9.bindPopup(popup_5bf380467b7b2efdf913e6b7a360c973)
#         ;
#
#
#
#
#             var marker_54ed753d2662c53eeee660869dbf9521 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_83ed27f54d11c06144989aa40b93ce41);
#
#
#         var popup_d6c0b22f5db81b1799b1ffc7b0eb229e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e50963c18a59c182437a884b48179c46 = $(`&lt;div id=&quot;html_e50963c18a59c182437a884b48179c46&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_d6c0b22f5db81b1799b1ffc7b0eb229e.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_94c473584a7e274c5dfa39d49b50be7e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_94c473584a7e274c5dfa39d49b50be7e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_94c473584a7e274c5dfa39d49b50be7e = L.map(
#                 &quot;map_94c473584a7e274c5dfa39d49b50be7e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ce3c8a00d46ddd1791110fef915ef177 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ce3c8a00d46ddd1791110fef915ef177.addTo(map_94c473584a7e274c5dfa39d49b50be7e);
#
#
#             var feature_group_fb7aa8bf8f9b957434d30b536ff800eb = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_f850e26dd68570cbeabc2a85962da805 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_fb7aa8bf8f9b957434d30b536ff800eb);
#
#
#         var popup_821b1cc3eec1b18b3bc348a199ede8b8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ef7a1a1e512207009d2df2ebf471211c = $(`&lt;div id=&quot;html_ef7a1a1e512207009d2df2ebf471211c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_821b1cc3eec1b18b3bc348a199ede8b8.setContent(html_ef7a1a1e512207009d2df2ebf471211c);
#
#
#
#         marker_f850e26dd68570cbeabc2a85962da805.bindPopup(popup_821b1cc3eec1b18b3bc348a199ede8b8)
#         ;
#
#
#
#
#             var marker_1f16b1452ac96702bd7975499f0c79b9 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_fb7aa8bf8f9b957434d30b536ff800eb);
#
#
#         var popup_725736a5a64c7b6f83dcdd0d10d14f22 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8f1440208effeb50c4837d344054b286 = $(`&lt;div id=&quot;html_8f1440208effeb50c4837d344054b286&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_725736a5a64c7b6f83dcdd0d10d14f22.setContent(html_8f1440208effeb50c4837d344054b286);
#
#
#
#         marker_1f16b1452ac96702bd7975499f0c79b9.bindPopup(popup_725736a5a64c7b6f83dcdd0d10d14f22)
#         ;
#
#
#
#
#             var marker_f8a992482b1530bde3f60126b321a837 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_fb7aa8bf8f9b957434d30b536ff800eb);
#
#
#         var popup_8cad93644dfc0cc674586b1049fbc272 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5fb13bc50ba93c95ceb5a2807f9acbac = $(`&lt;div id=&quot;html_5fb13bc50ba93c95ceb5a2807f9acbac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_8cad93644dfc0cc674586b1049fbc272.setContent(html_5fb13bc50ba93c95ceb5a2807f9acbac);
#
#
#
#         marker_f8a992482b1530bde3f60126b321a837.bindPopup(popup_8cad93644dfc0cc674586b1049fbc272)
#         ;
#
#
#
#
#             var marker_b0b4355b0a754ad608e64d59b6db907f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_fb7aa8bf8f9b957434d30b536ff800eb);
#
#
#         var popup_52f4466211baef092c55f0e52355574d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_808e4ad420ef1c00a3b290f4b6898b6f = $(`&lt;div id=&quot;html_808e4ad420ef1c00a3b290f4b6898b6f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_52f4466211baef092c55f0e52355574d.setContent(html_808e4ad420ef1c00a3b290f4b6898b6f);
#
#
#
#         marker_b0b4355b0a754ad608e64d59b6db907f.bindPopup(popup_52f4466211baef092c55f0e52355574d)
#         ;
#
#
#
#
#             var marker_ff27a119329592643a4ca3b0aef29650 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_fb7aa8bf8f9b957434d30b536ff800eb);
#
#
#         var popup_079adabb9ac9cc0ad3952b32089cc005 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a0bf827e74ddfc0fef5e2b07e192f558 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a0bf827e74ddfc0fef5e2b07e192f558&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a0bf827e74ddfc0fef5e2b07e192f558 = L.map(
#                 &quot;map_a0bf827e74ddfc0fef5e2b07e192f558&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0d4282cad81031f1a2ff7ee4f4b927a6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0d4282cad81031f1a2ff7ee4f4b927a6.addTo(map_a0bf827e74ddfc0fef5e2b07e192f558);
#
#
#             var feature_group_06129f5e4a54a5428da2fdf86460dc25 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_06129f5e4a54a5428da2fdf86460dc25.addTo(map_a0bf827e74ddfc0fef5e2b07e192f558);
#
#
#             var feature_group_sub_group_0142c20ff9e85df7965de07652a794ef = L.featureGroup.subGroup(
#                 feature_group_06129f5e4a54a5428da2fdf86460dc25
#             );
#
#
#             var marker_1a20776d957897964c2614faafccf8e5 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_0142c20ff9e85df7965de07652a794ef);
#
#
#         var popup_9a7b95623f145f8b199e69d320143592 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0e088e4ad3967975c02678e7fa9cd390 = $(`&lt;div id=&quot;html_0e088e4ad3967975c02678e7fa9cd390&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_9a7b95623f145f8b199e69d320143592.setContent(html_0e088e4ad3967975c02678e7fa9cd390);
#
#
#
#         marker_1a20776d957897964c2614faafccf8e5.bindPopup(popup_9a7b95623f145f8b199e69d320143592)
#         ;
#
#
#
#
#             var marker_2ab1840babeb3869ec43554665fde0dc = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_0142c20ff9e85df7965de07652a794ef);
#
#
#         var popup_377f77c2e43b48d5a57e1b8b2daecbac = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7413b62ea4134bb190e2e4ddfd649e81 = $(`&lt;div id=&quot;html_7413b62ea4134bb190e2e4ddfd649e81&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_377f77c2e43b48d5a57e1b8b2daecbac.setContent(html_7413b62ea4134bb190e2e4ddfd649e81);
#
#
#
#         marker_2ab1840babeb3869ec43554665fde0dc.bindPopup(popup_377f77c2e43b48d5a57e1b8b2daecbac)
#         ;
#
#
#
#
#             var marker_27898fd412d9e1b8fb92735ffcc60340 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_0142c20ff9e85df7965de07652a794ef);
#
#
#         var popup_b8506171120595da3990fbf286c2364e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8ee06f2bdbf7662a69603187cdd9e6cb = $(`&lt;div id=&quot;html_8ee06f2bdbf7662a69603187cdd9e6cb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_b8506171120595da3990fbf286c2364e.setContent(html_8ee06f2bdbf7662a69603187cdd9e6cb);
#
#
#
#         marker_27898fd412d9e1b8fb92735ffcc60340.bindPopup(popup_b8506171120595da3990fbf286c2364e)
#         ;
#
#
#
#
#             var marker_e391ffb6230e69bfe0b7e52ad8cd3d1f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_0142c20ff9e85df7965de07652a794ef);
#
#
#         var popup_d1cb7738afe23fa7e60b34293b2c6861 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e6541ea7e40f54944eaf11a17102683c = $(`&lt;div id=&quot;html_e6541ea7e40f54944eaf11a17102683c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_d1cb7738afe23fa7e60b34293b2c6861.setContent(html_e6541ea7e40f54944eaf11a17102683c);
#
#
#
#         marker_
