# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e91edd74ba42cbaa5aaeb038d1e9b62f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e91edd74ba42cbaa5aaeb038d1e9b62f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e91edd74ba42cbaa5aaeb038d1e9b62f = L.map(
#                 &quot;map_e91edd74ba42cbaa5aaeb038d1e9b62f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_17d89afff06936686c27ef06d61b3af7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_17d89afff06936686c27ef06d61b3af7.addTo(map_e91edd74ba42cbaa5aaeb038d1e9b62f);
#
#
#             var marker_f03adc0cc0c81a8e13a62e80138158f1 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_e91edd74ba42cbaa5aaeb038d1e9b62f);
#
#
#         var popup_9480d9bd6915f925a20bd425a3cfa374 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e0fe56cb325d9bfec06b6fd48805e181 = $(`&lt;div id=&quot;html_e0fe56cb325d9bfec06b6fd48805e181&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_9480d9bd6915f925a20bd425a3cfa374.setContent(html_e0fe56cb325d9bfec06b6fd48805e181);
#
#
#
#         marker_f03adc0cc0c81a8e13a62e80138158f1.bindPopup(popup_9480d9bd6915f925a20bd425a3cfa374)
#         ;
#
#
#
#
#             var marker_3e4a9d6d437cf30f3a05ae6526df25de = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_e91edd74ba42cbaa5aaeb038d1e9b62f);
#
#
#         var popup_acfa7b61d04e774e357165e0ae5466dc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6603b48a2c444618f1b6d836fc96cc1a = $(`&lt;div id=&quot;html_6603b48a2c444618f1b6d836fc96cc1a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_acfa7b61d04e774e357165e0ae5466dc.setContent(html_6603b48a2c444618f1b6d836fc96cc1a);
#
#
#
#         marker_3e4a9d6d437cf30f3a05ae6526df25de.bindPopup(popup_acfa7b61d04e774e357165e0ae5466dc)
#         ;
#
#
#
#
#             var marker_1e26cba5e97f543b15d1bea2c4ceb314 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_e91edd74ba42cbaa5aaeb038d1e9b62f);
#
#
#         var popup_a1423ae9b3c4da00288140aaab9b131d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_17d2d5ebf8bb96a21cbd86e881edfe33 = $(`&lt;div id=&quot;html_17d2d5ebf8bb96a21cbd86e881edfe33&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_a1423ae9b3c4da00288140aaab9b131d.setContent(html_17d2d5ebf8bb96a21cbd86e881edfe33);
#
#
#
#         marker_1e26cba5e97f543b15d1bea2c4ceb314.bindPopup(popup_a1423ae9b3c4da00288140aaab9b131d)
#         ;
#
#
#
#
#             var marker_013c313af3d8486fc89f6ec0b0b42fc5 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_e91edd74ba42cbaa5aaeb038d1e9b62f);
#
#
#         var popup_a91e43f5d562568eb1be338c70d7bc26 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7daafd694f8d18e58caeb8769262257e = $(`&lt;div id=&quot;html_7daafd694f8d18e58caeb8769262257e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_a91e43f5d562568eb1be338c70d7bc26.setContent(html_7daafd694f8d18e58caeb8769262257e);
#
#
#
#         marker_013c313af3d8486fc89f6ec0b0b42fc5.bindPopup(popup_a91e43f5d562568eb1be338c70d7bc26)
#         ;
#
#
#
#
#             var marker_cbd71a76525017b83af4815a8a16d528 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_e91edd74ba42cbaa5aaeb038d1e9b62f);
#
#
#         var popup_2acbea713aa98feabedff79d70406eba = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d649ea137d6559fb02ce88b91310fb79 = $(`&lt;div id=&quot;html_d649ea137d6559fb02ce88b91310fb79&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_2acbea713aa98feabedff79d70406eba.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_23e34c0ced4321b85729ae0085af609e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_23e34c0ced4321b85729ae0085af609e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_23e34c0ced4321b85729ae0085af609e = L.map(
#                 &quot;map_23e34c0ced4321b85729ae0085af609e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_43744ef192dcb85bde58e3129fce6cad = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_43744ef192dcb85bde58e3129fce6cad.addTo(map_23e34c0ced4321b85729ae0085af609e);
#
#
#             var feature_group_d95cf35754905a445ec78bfc2179bcaa = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_49c87b25a45818a2dd55e2cd6f290153 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_d95cf35754905a445ec78bfc2179bcaa);
#
#
#         var popup_2f96ba46ec1b7bf904d05a39ff501c42 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f48f67df62d3cc3341cb9d733b69a08e = $(`&lt;div id=&quot;html_f48f67df62d3cc3341cb9d733b69a08e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_2f96ba46ec1b7bf904d05a39ff501c42.setContent(html_f48f67df62d3cc3341cb9d733b69a08e);
#
#
#
#         marker_49c87b25a45818a2dd55e2cd6f290153.bindPopup(popup_2f96ba46ec1b7bf904d05a39ff501c42)
#         ;
#
#
#
#
#             var marker_e6517782dba3257d09fae68384856ab4 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_d95cf35754905a445ec78bfc2179bcaa);
#
#
#         var popup_c0541713930d425cc23252d8c2e99ff9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_df740dddfe96e91b144aeebb978e7d6d = $(`&lt;div id=&quot;html_df740dddfe96e91b144aeebb978e7d6d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_c0541713930d425cc23252d8c2e99ff9.setContent(html_df740dddfe96e91b144aeebb978e7d6d);
#
#
#
#         marker_e6517782dba3257d09fae68384856ab4.bindPopup(popup_c0541713930d425cc23252d8c2e99ff9)
#         ;
#
#
#
#
#             var marker_294dd6ece7bd437ad5d5cc5730c4b320 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_d95cf35754905a445ec78bfc2179bcaa);
#
#
#         var popup_c52cdbd6e49e700e09e02ecaf32f4743 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_03bec314c8143aaeb35cc6776e5909e8 = $(`&lt;div id=&quot;html_03bec314c8143aaeb35cc6776e5909e8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_c52cdbd6e49e700e09e02ecaf32f4743.setContent(html_03bec314c8143aaeb35cc6776e5909e8);
#
#
#
#         marker_294dd6ece7bd437ad5d5cc5730c4b320.bindPopup(popup_c52cdbd6e49e700e09e02ecaf32f4743)
#         ;
#
#
#
#
#             var marker_5aad77a9303d2521cd7ef7b84d365346 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_d95cf35754905a445ec78bfc2179bcaa);
#
#
#         var popup_fd0530f451c42dd9cbfd8dae9b491e07 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4a5cfdda16d3c539d04bf96239a62b55 = $(`&lt;div id=&quot;html_4a5cfdda16d3c539d04bf96239a62b55&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_fd0530f451c42dd9cbfd8dae9b491e07.setContent(html_4a5cfdda16d3c539d04bf96239a62b55);
#
#
#
#         marker_5aad77a9303d2521cd7ef7b84d365346.bindPopup(popup_fd0530f451c42dd9cbfd8dae9b491e07)
#         ;
#
#
#
#
#             var marker_4d96b055d8af6a8e1946ae4c14c7d2de = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_d95cf35754905a445ec78bfc2179bcaa);
#
#
#         var popup_e9e4d79ef933c59ef5815f017bf342da = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_60d691f8585acae938c90f28249ad844 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_60d691f8585acae938c90f28249ad844&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_60d691f8585acae938c90f28249ad844 = L.map(
#                 &quot;map_60d691f8585acae938c90f28249ad844&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7a35cb6f0755750237e4fc87a79077da = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7a35cb6f0755750237e4fc87a79077da.addTo(map_60d691f8585acae938c90f28249ad844);
#
#
#             var feature_group_184e453382becad99592c6e00ce162c7 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_184e453382becad99592c6e00ce162c7.addTo(map_60d691f8585acae938c90f28249ad844);
#
#
#             var feature_group_sub_group_c222417e7eab4c2fa1919772ab1ed49f = L.featureGroup.subGroup(
#                 feature_group_184e453382becad99592c6e00ce162c7
#             );
#
#
#             var marker_7f1922953c48730ce55b2bda94e109ea = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_c222417e7eab4c2fa1919772ab1ed49f);
#
#
#         var popup_a62fab48e3e6c94b308c2d3e18264948 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_602cb8b9fbce85e50f792ae86e64cf85 = $(`&lt;div id=&quot;html_602cb8b9fbce85e50f792ae86e64cf85&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_a62fab48e3e6c94b308c2d3e18264948.setContent(html_602cb8b9fbce85e50f792ae86e64cf85);
#
#
#
#         marker_7f1922953c48730ce55b2bda94e109ea.bindPopup(popup_a62fab48e3e6c94b308c2d3e18264948)
#         ;
#
#
#
#
#             var marker_b6b793cfa623bf458a4d919f0f0226f9 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_c222417e7eab4c2fa1919772ab1ed49f);
#
#
#         var popup_e33ddc75c7e2ecd62389a9a7aab1ad6d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_325e7bfe984f7310cd32548693c902cd = $(`&lt;div id=&quot;html_325e7bfe984f7310cd32548693c902cd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_e33ddc75c7e2ecd62389a9a7aab1ad6d.setContent(html_325e7bfe984f7310cd32548693c902cd);
#
#
#
#         marker_b6b793cfa623bf458a4d919f0f0226f9.bindPopup(popup_e33ddc75c7e2ecd62389a9a7aab1ad6d)
#         ;
#
#
#
#
#             var marker_255e6a9330517baf4b1c341c433eedfb = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_c222417e7eab4c2fa1919772ab1ed49f);
#
#
#         var popup_288c37ced04e5b5e7a4a3725d293b6b7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ad08495840181f730ef68eb055cbaf85 = $(`&lt;div id=&quot;html_ad08495840181f730ef68eb055cbaf85&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_288c37ced04e5b5e7a4a3725d293b6b7.setContent(html_ad08495840181f730ef68eb055cbaf85);
#
#
#
#         marker_255e6a9330517baf4b1c341c433eedfb.bindPopup(popup_288c37ced04e5b5e7a4a3725d293b6b7)
#         ;
#
#
#
#
#             var marker_58f4fc1a5644ecf6aaf0c2eb27ac777a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_c222417e7eab4c2fa1919772ab1ed49f);
#
#
#         var popup_7b9e018123fe378d3f8d8087eb5ea736 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2a1f7ef87b32291ff477fd7ec9f4fd89 = $(`&lt;div id=&quot;html_2a1f7ef87b32291ff477fd7ec9f4fd89&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_7b9e018123fe378d3f8d8087eb5ea736.setContent(html_2a1f7ef87b32291ff477fd7ec9f4fd89);
#
#
#
#         marker_
