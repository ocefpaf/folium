# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_22994a8caf367790452b98b266f05fa9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_22994a8caf367790452b98b266f05fa9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_22994a8caf367790452b98b266f05fa9 = L.map(
#                 &quot;map_22994a8caf367790452b98b266f05fa9&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_69c9691f38d914aa74809251d04256cc = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_69c9691f38d914aa74809251d04256cc.addTo(map_22994a8caf367790452b98b266f05fa9);
#
#
#             var marker_fd3de307b617c0006a4942c831359a74 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_22994a8caf367790452b98b266f05fa9);
#
#
#         var popup_825e38d54d8e59f03ce0edfc4653e0f7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e2b32f75bba69e9ac53e7c68ac5f849f = $(`&lt;div id=&quot;html_e2b32f75bba69e9ac53e7c68ac5f849f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_825e38d54d8e59f03ce0edfc4653e0f7.setContent(html_e2b32f75bba69e9ac53e7c68ac5f849f);
#
#
#
#         marker_fd3de307b617c0006a4942c831359a74.bindPopup(popup_825e38d54d8e59f03ce0edfc4653e0f7)
#         ;
#
#
#
#
#             var marker_866afc8a1a9de857f5b5f4d9178716c5 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_22994a8caf367790452b98b266f05fa9);
#
#
#         var popup_ab4f9aea9438d0ea38a25f1ea10e24ee = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4bd26f7204d27b77eff77b913c86e0bf = $(`&lt;div id=&quot;html_4bd26f7204d27b77eff77b913c86e0bf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_ab4f9aea9438d0ea38a25f1ea10e24ee.setContent(html_4bd26f7204d27b77eff77b913c86e0bf);
#
#
#
#         marker_866afc8a1a9de857f5b5f4d9178716c5.bindPopup(popup_ab4f9aea9438d0ea38a25f1ea10e24ee)
#         ;
#
#
#
#
#             var marker_71f36263f4fb9d10e5d3df53e7c942b8 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_22994a8caf367790452b98b266f05fa9);
#
#
#         var popup_26478de1ff496512518381ba50d6b117 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1570a4bd006f51a04e2f6325acad9ca4 = $(`&lt;div id=&quot;html_1570a4bd006f51a04e2f6325acad9ca4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_26478de1ff496512518381ba50d6b117.setContent(html_1570a4bd006f51a04e2f6325acad9ca4);
#
#
#
#         marker_71f36263f4fb9d10e5d3df53e7c942b8.bindPopup(popup_26478de1ff496512518381ba50d6b117)
#         ;
#
#
#
#
#             var marker_5a3d1cdb8932aef21eb9f5d87940e955 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_22994a8caf367790452b98b266f05fa9);
#
#
#         var popup_541f05de9b23fa5aab31a1bc42f24f5a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_389544461bdbb015cf7cc2589d4f2964 = $(`&lt;div id=&quot;html_389544461bdbb015cf7cc2589d4f2964&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_541f05de9b23fa5aab31a1bc42f24f5a.setContent(html_389544461bdbb015cf7cc2589d4f2964);
#
#
#
#         marker_5a3d1cdb8932aef21eb9f5d87940e955.bindPopup(popup_541f05de9b23fa5aab31a1bc42f24f5a)
#         ;
#
#
#
#
#             var marker_c749f2cd11ce3bde899934f4c45746ce = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_22994a8caf367790452b98b266f05fa9);
#
#
#         var popup_d87549063a45527025c887920cbc1d9a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b2dd1567a4582aedaf1a4c43902fd85d = $(`&lt;div id=&quot;html_b2dd1567a4582aedaf1a4c43902fd85d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_d87549063a45527025c887920cbc1d9a.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6c99f4d750e63b50c3d16bc1613bf569 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6c99f4d750e63b50c3d16bc1613bf569&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6c99f4d750e63b50c3d16bc1613bf569 = L.map(
#                 &quot;map_6c99f4d750e63b50c3d16bc1613bf569&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d9cc3ee0db1df04e616e91bc94893ef4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d9cc3ee0db1df04e616e91bc94893ef4.addTo(map_6c99f4d750e63b50c3d16bc1613bf569);
#
#
#             var feature_group_407a90f7d675e4b4199ba60e98c25d5e = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_80cf3118827561d85890e80cf096d484 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_407a90f7d675e4b4199ba60e98c25d5e);
#
#
#         var popup_46ac33c4d060343f12a8159de4e355b5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8b92fca78b55497ccb07ad16f4ab3cee = $(`&lt;div id=&quot;html_8b92fca78b55497ccb07ad16f4ab3cee&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_46ac33c4d060343f12a8159de4e355b5.setContent(html_8b92fca78b55497ccb07ad16f4ab3cee);
#
#
#
#         marker_80cf3118827561d85890e80cf096d484.bindPopup(popup_46ac33c4d060343f12a8159de4e355b5)
#         ;
#
#
#
#
#             var marker_18dfa318b177a53e5b5bd9bf4b9d0ca7 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_407a90f7d675e4b4199ba60e98c25d5e);
#
#
#         var popup_abcd1610b0a5bd7654c60b40fb1edbf4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f5c6ce7f7a098c295a0cd3bdf5dbc232 = $(`&lt;div id=&quot;html_f5c6ce7f7a098c295a0cd3bdf5dbc232&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_abcd1610b0a5bd7654c60b40fb1edbf4.setContent(html_f5c6ce7f7a098c295a0cd3bdf5dbc232);
#
#
#
#         marker_18dfa318b177a53e5b5bd9bf4b9d0ca7.bindPopup(popup_abcd1610b0a5bd7654c60b40fb1edbf4)
#         ;
#
#
#
#
#             var marker_fd91402d0253f6f4067db30dbce4e00b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_407a90f7d675e4b4199ba60e98c25d5e);
#
#
#         var popup_d7b9125085ba3d7b2258e4f642d7b32b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_076804d1c3c24b23e74805c57de5d3b6 = $(`&lt;div id=&quot;html_076804d1c3c24b23e74805c57de5d3b6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_d7b9125085ba3d7b2258e4f642d7b32b.setContent(html_076804d1c3c24b23e74805c57de5d3b6);
#
#
#
#         marker_fd91402d0253f6f4067db30dbce4e00b.bindPopup(popup_d7b9125085ba3d7b2258e4f642d7b32b)
#         ;
#
#
#
#
#             var marker_fbc9c63959d59a1d771822b3c8ce06ca = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_407a90f7d675e4b4199ba60e98c25d5e);
#
#
#         var popup_502ea50d0c1fc4afbdfde4fc3eedf829 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9e0153f6e63d3086c744e85a42c41df5 = $(`&lt;div id=&quot;html_9e0153f6e63d3086c744e85a42c41df5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_502ea50d0c1fc4afbdfde4fc3eedf829.setContent(html_9e0153f6e63d3086c744e85a42c41df5);
#
#
#
#         marker_fbc9c63959d59a1d771822b3c8ce06ca.bindPopup(popup_502ea50d0c1fc4afbdfde4fc3eedf829)
#         ;
#
#
#
#
#             var marker_37f76c6061a9c639f3afb01879c0b5b0 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_407a90f7d675e4b4199ba60e98c25d5e);
#
#
#         var popup_e4445bc145b8fdf3254c104fbfaab784 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_78d81a1eac8aeab08fe04245f958e756 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_78d81a1eac8aeab08fe04245f958e756&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_78d81a1eac8aeab08fe04245f958e756 = L.map(
#                 &quot;map_78d81a1eac8aeab08fe04245f958e756&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_aa4ef3e67b689080001a4023aa5a8f85 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_aa4ef3e67b689080001a4023aa5a8f85.addTo(map_78d81a1eac8aeab08fe04245f958e756);
#
#
#             var feature_group_1a1126842a4661855ee5e57db6fd3097 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_1a1126842a4661855ee5e57db6fd3097.addTo(map_78d81a1eac8aeab08fe04245f958e756);
#
#
#             var feature_group_sub_group_3686feae9d5d021c8d97e096a8690c6c = L.featureGroup.subGroup(
#                 feature_group_1a1126842a4661855ee5e57db6fd3097
#             );
#
#
#             var marker_3182652fbf9614965d6183c6fa8128b4 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_3686feae9d5d021c8d97e096a8690c6c);
#
#
#         var popup_4407279c278adc4a072921672bb2f59f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b6f56c3694fbe1d1f249b6ad004926b6 = $(`&lt;div id=&quot;html_b6f56c3694fbe1d1f249b6ad004926b6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_4407279c278adc4a072921672bb2f59f.setContent(html_b6f56c3694fbe1d1f249b6ad004926b6);
#
#
#
#         marker_3182652fbf9614965d6183c6fa8128b4.bindPopup(popup_4407279c278adc4a072921672bb2f59f)
#         ;
#
#
#
#
#             var marker_8b0444ec804396f9567b2a571eca5c37 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_3686feae9d5d021c8d97e096a8690c6c);
#
#
#         var popup_41981801019d05206cbd5ab66b1a1b44 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d3148fa900342032042e157f442e34e0 = $(`&lt;div id=&quot;html_d3148fa900342032042e157f442e34e0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_41981801019d05206cbd5ab66b1a1b44.setContent(html_d3148fa900342032042e157f442e34e0);
#
#
#
#         marker_8b0444ec804396f9567b2a571eca5c37.bindPopup(popup_41981801019d05206cbd5ab66b1a1b44)
#         ;
#
#
#
#
#             var marker_4df6eec003e7b6db220f1a2809d6b406 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_3686feae9d5d021c8d97e096a8690c6c);
#
#
#         var popup_14423c8cb5dd41094e6ffeb4c054d91d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_72d99a3b3af9eedbfa72616034a3df73 = $(`&lt;div id=&quot;html_72d99a3b3af9eedbfa72616034a3df73&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_14423c8cb5dd41094e6ffeb4c054d91d.setContent(html_72d99a3b3af9eedbfa72616034a3df73);
#
#
#
#         marker_4df6eec003e7b6db220f1a2809d6b406.bindPopup(popup_14423c8cb5dd41094e6ffeb4c054d91d)
#         ;
#
#
#
#
#             var marker_b5870da6b2e9f8d6738b7364a1e3ee27 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_3686feae9d5d021c8d97e096a8690c6c);
#
#
#         var popup_895192e36e93883ff22c384a51cc254b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_00d0f81ac10fd0eb088a5e55d8f69eae = $(`&lt;div id=&quot;html_00d0f81ac10fd0eb088a5e55d8f69eae&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_895192e36e93883ff22c384a51cc254b.setContent(html_00d0f81ac10fd0eb088a5e55d8f69eae);
#
#
#
#         marker_
