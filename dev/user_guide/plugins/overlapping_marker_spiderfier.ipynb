# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b45ea49ba146a69842d0c2927975d2be {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b45ea49ba146a69842d0c2927975d2be&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b45ea49ba146a69842d0c2927975d2be = L.map(
#                 &quot;map_b45ea49ba146a69842d0c2927975d2be&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f96a2e7e1774268e4860cba35d19edd7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f96a2e7e1774268e4860cba35d19edd7.addTo(map_b45ea49ba146a69842d0c2927975d2be);
#
#
#             var marker_29dbb32d144cd0d947187a0ea5d588f8 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_b45ea49ba146a69842d0c2927975d2be);
#
#
#         var popup_99181f6c09c7d6386bc4d92d394c8f5a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_394f2be3ac62031f7f9cf92aa4108256 = $(`&lt;div id=&quot;html_394f2be3ac62031f7f9cf92aa4108256&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_99181f6c09c7d6386bc4d92d394c8f5a.setContent(html_394f2be3ac62031f7f9cf92aa4108256);
#
#
#
#         marker_29dbb32d144cd0d947187a0ea5d588f8.bindPopup(popup_99181f6c09c7d6386bc4d92d394c8f5a)
#         ;
#
#
#
#
#             var marker_9640e9ef263aa919e73cd4a7fc70fe3a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_b45ea49ba146a69842d0c2927975d2be);
#
#
#         var popup_40085a1a3203b1d9513823cb4d54b917 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f8b1c9e208acb2cbdb0848425ab8c77a = $(`&lt;div id=&quot;html_f8b1c9e208acb2cbdb0848425ab8c77a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_40085a1a3203b1d9513823cb4d54b917.setContent(html_f8b1c9e208acb2cbdb0848425ab8c77a);
#
#
#
#         marker_9640e9ef263aa919e73cd4a7fc70fe3a.bindPopup(popup_40085a1a3203b1d9513823cb4d54b917)
#         ;
#
#
#
#
#             var marker_a9fc3f86fe9ac5e16c4556ad7d124ecd = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_b45ea49ba146a69842d0c2927975d2be);
#
#
#         var popup_ee9bd2422afb3afd9673c35f742b69f9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7a8b72da2a124b98f63478103729b12d = $(`&lt;div id=&quot;html_7a8b72da2a124b98f63478103729b12d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_ee9bd2422afb3afd9673c35f742b69f9.setContent(html_7a8b72da2a124b98f63478103729b12d);
#
#
#
#         marker_a9fc3f86fe9ac5e16c4556ad7d124ecd.bindPopup(popup_ee9bd2422afb3afd9673c35f742b69f9)
#         ;
#
#
#
#
#             var marker_d4cecdec7c171274faf9503b5b85c374 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_b45ea49ba146a69842d0c2927975d2be);
#
#
#         var popup_7d24d652eb2f1983e6be6bcf055384ee = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b61453110541a34fac35db7801d30004 = $(`&lt;div id=&quot;html_b61453110541a34fac35db7801d30004&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_7d24d652eb2f1983e6be6bcf055384ee.setContent(html_b61453110541a34fac35db7801d30004);
#
#
#
#         marker_d4cecdec7c171274faf9503b5b85c374.bindPopup(popup_7d24d652eb2f1983e6be6bcf055384ee)
#         ;
#
#
#
#
#             var marker_93fa3d59c5992ab768dda363d35a8a3d = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_b45ea49ba146a69842d0c2927975d2be);
#
#
#         var popup_77cc06df93ba0d5179e8ad7cee06df7b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9844479566987cd084f123ec5e3170bf = $(`&lt;div id=&quot;html_9844479566987cd084f123ec5e3170bf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_77cc06df93ba0d5179e8ad7cee06df7b.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_03ddaa0439fd6836dbcf0b7e597e00b7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_03ddaa0439fd6836dbcf0b7e597e00b7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_03ddaa0439fd6836dbcf0b7e597e00b7 = L.map(
#                 &quot;map_03ddaa0439fd6836dbcf0b7e597e00b7&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d13bdab8b1366e0218e47dad2c369e1a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d13bdab8b1366e0218e47dad2c369e1a.addTo(map_03ddaa0439fd6836dbcf0b7e597e00b7);
#
#
#             var feature_group_e660465031583481b910e1b27a5b66d6 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_981279b49790060dfb1307736ddfcace = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_e660465031583481b910e1b27a5b66d6);
#
#
#         var popup_9ec0a0d46584ffa3f0d9ae445c62d87c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_19ea1f86f6884fe0370e32c36e580408 = $(`&lt;div id=&quot;html_19ea1f86f6884fe0370e32c36e580408&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_9ec0a0d46584ffa3f0d9ae445c62d87c.setContent(html_19ea1f86f6884fe0370e32c36e580408);
#
#
#
#         marker_981279b49790060dfb1307736ddfcace.bindPopup(popup_9ec0a0d46584ffa3f0d9ae445c62d87c)
#         ;
#
#
#
#
#             var marker_4ca7091ad6fa445a02cb15ec486d11a5 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_e660465031583481b910e1b27a5b66d6);
#
#
#         var popup_e7f6df997948878ea640ac56e4c10cf4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_89b277b43660691cc1a2e4ca9333c682 = $(`&lt;div id=&quot;html_89b277b43660691cc1a2e4ca9333c682&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_e7f6df997948878ea640ac56e4c10cf4.setContent(html_89b277b43660691cc1a2e4ca9333c682);
#
#
#
#         marker_4ca7091ad6fa445a02cb15ec486d11a5.bindPopup(popup_e7f6df997948878ea640ac56e4c10cf4)
#         ;
#
#
#
#
#             var marker_28699027b1602b0124a15a4a90cef5cb = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_e660465031583481b910e1b27a5b66d6);
#
#
#         var popup_b01e926b6df3030e7801ec0581b9a1b6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ee08f76ed7b96f25f1ad8bc1d09565a5 = $(`&lt;div id=&quot;html_ee08f76ed7b96f25f1ad8bc1d09565a5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_b01e926b6df3030e7801ec0581b9a1b6.setContent(html_ee08f76ed7b96f25f1ad8bc1d09565a5);
#
#
#
#         marker_28699027b1602b0124a15a4a90cef5cb.bindPopup(popup_b01e926b6df3030e7801ec0581b9a1b6)
#         ;
#
#
#
#
#             var marker_7731729d6e9a50c215a4bf8d47f26e81 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_e660465031583481b910e1b27a5b66d6);
#
#
#         var popup_0b9fb17ad836b7a22297fb6aaa4757e9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_68d30b2fed165abf9ae9cad47e6c28f6 = $(`&lt;div id=&quot;html_68d30b2fed165abf9ae9cad47e6c28f6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_0b9fb17ad836b7a22297fb6aaa4757e9.setContent(html_68d30b2fed165abf9ae9cad47e6c28f6);
#
#
#
#         marker_7731729d6e9a50c215a4bf8d47f26e81.bindPopup(popup_0b9fb17ad836b7a22297fb6aaa4757e9)
#         ;
#
#
#
#
#             var marker_c65ab6710cb84ee1cfda3ee4f68bb83e = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_e660465031583481b910e1b27a5b66d6);
#
#
#         var popup_b62ba5dba9621e770c78a15bb2d377b7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1b8bacf97bc960a87e2b75c81dc759bc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1b8bacf97bc960a87e2b75c81dc759bc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1b8bacf97bc960a87e2b75c81dc759bc = L.map(
#                 &quot;map_1b8bacf97bc960a87e2b75c81dc759bc&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_43c76067c32ea7308e4d2690493c9e74 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_43c76067c32ea7308e4d2690493c9e74.addTo(map_1b8bacf97bc960a87e2b75c81dc759bc);
#
#
#             var feature_group_0b577b64c72f7ab40372f6b6307b4af6 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_0b577b64c72f7ab40372f6b6307b4af6.addTo(map_1b8bacf97bc960a87e2b75c81dc759bc);
#
#
#             var feature_group_sub_group_8d3f9300a172172ddbb1c5d58aef664d = L.featureGroup.subGroup(
#                 feature_group_0b577b64c72f7ab40372f6b6307b4af6
#             );
#
#
#             var marker_eb807712c7be1fa7c2dd0da4aa1d90da = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_8d3f9300a172172ddbb1c5d58aef664d);
#
#
#         var popup_46f1f98c6dcf147b7a3b6a8964a18681 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a034d1e0b2d533a35065a3c463315a59 = $(`&lt;div id=&quot;html_a034d1e0b2d533a35065a3c463315a59&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_46f1f98c6dcf147b7a3b6a8964a18681.setContent(html_a034d1e0b2d533a35065a3c463315a59);
#
#
#
#         marker_eb807712c7be1fa7c2dd0da4aa1d90da.bindPopup(popup_46f1f98c6dcf147b7a3b6a8964a18681)
#         ;
#
#
#
#
#             var marker_966f369a2caaaa44dc515588d3a9ebfb = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_8d3f9300a172172ddbb1c5d58aef664d);
#
#
#         var popup_4521f7bc9dda3dbca761494a6065e6a0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_af988e965eed4bdf78b898973c0c2b4a = $(`&lt;div id=&quot;html_af988e965eed4bdf78b898973c0c2b4a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_4521f7bc9dda3dbca761494a6065e6a0.setContent(html_af988e965eed4bdf78b898973c0c2b4a);
#
#
#
#         marker_966f369a2caaaa44dc515588d3a9ebfb.bindPopup(popup_4521f7bc9dda3dbca761494a6065e6a0)
#         ;
#
#
#
#
#             var marker_16a20f5448ac83f766b00a4ee8e04299 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_8d3f9300a172172ddbb1c5d58aef664d);
#
#
#         var popup_7d02296a38c2590d87a03d4cf48f0692 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2a6362910e08848e586234517dc58466 = $(`&lt;div id=&quot;html_2a6362910e08848e586234517dc58466&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_7d02296a38c2590d87a03d4cf48f0692.setContent(html_2a6362910e08848e586234517dc58466);
#
#
#
#         marker_16a20f5448ac83f766b00a4ee8e04299.bindPopup(popup_7d02296a38c2590d87a03d4cf48f0692)
#         ;
#
#
#
#
#             var marker_6ee1373fbfc47ffc37d8545a8772e030 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_8d3f9300a172172ddbb1c5d58aef664d);
#
#
#         var popup_0e4ead73adb200308b58dd4a44380d91 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4a776501b25b706ae295c7a880786aa9 = $(`&lt;div id=&quot;html_4a776501b25b706ae295c7a880786aa9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_0e4ead73adb200308b58dd4a44380d91.setContent(html_4a776501b25b706ae295c7a880786aa9);
#
#
#
#         marker_
