# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a3f14ffca40629ded1473bd60ff077b8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a3f14ffca40629ded1473bd60ff077b8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a3f14ffca40629ded1473bd60ff077b8 = L.map(
#                 &quot;map_a3f14ffca40629ded1473bd60ff077b8&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2c8d3ff483ea632f9747047fcbb8b30c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2c8d3ff483ea632f9747047fcbb8b30c.addTo(map_a3f14ffca40629ded1473bd60ff077b8);
#
#
#             var marker_9f645afd5af0e5add52a1cb4385905d4 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_a3f14ffca40629ded1473bd60ff077b8);
#
#
#         var popup_a1fa50fa3f443238fefb5d8a843096d0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5603625638f6dcba5fd6a2e48a7e50c0 = $(`&lt;div id=&quot;html_5603625638f6dcba5fd6a2e48a7e50c0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_a1fa50fa3f443238fefb5d8a843096d0.setContent(html_5603625638f6dcba5fd6a2e48a7e50c0);
#
#
#
#         marker_9f645afd5af0e5add52a1cb4385905d4.bindPopup(popup_a1fa50fa3f443238fefb5d8a843096d0)
#         ;
#
#
#
#
#             var marker_b75843613c21445c8675410fdb8b0604 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_a3f14ffca40629ded1473bd60ff077b8);
#
#
#         var popup_13e6f74b20a00083e562e1762a70a75b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f049c0f146794a9865930ba1ec898a77 = $(`&lt;div id=&quot;html_f049c0f146794a9865930ba1ec898a77&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_13e6f74b20a00083e562e1762a70a75b.setContent(html_f049c0f146794a9865930ba1ec898a77);
#
#
#
#         marker_b75843613c21445c8675410fdb8b0604.bindPopup(popup_13e6f74b20a00083e562e1762a70a75b)
#         ;
#
#
#
#
#             var marker_d7eac21ce8c1c0ba2c22caeed7f33122 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_a3f14ffca40629ded1473bd60ff077b8);
#
#
#         var popup_7649eff0dbefd226dbacb3c4cdc72c21 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fe869dad747595da6c8c5285eff859f7 = $(`&lt;div id=&quot;html_fe869dad747595da6c8c5285eff859f7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_7649eff0dbefd226dbacb3c4cdc72c21.setContent(html_fe869dad747595da6c8c5285eff859f7);
#
#
#
#         marker_d7eac21ce8c1c0ba2c22caeed7f33122.bindPopup(popup_7649eff0dbefd226dbacb3c4cdc72c21)
#         ;
#
#
#
#
#             var marker_b294010f9c6e5c60fbb150945ebc26c3 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_a3f14ffca40629ded1473bd60ff077b8);
#
#
#         var popup_3ab92df0eef6184cd9cfe969fb417e11 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_eafb2a3985aef284181e5c4f9a895f4c = $(`&lt;div id=&quot;html_eafb2a3985aef284181e5c4f9a895f4c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_3ab92df0eef6184cd9cfe969fb417e11.setContent(html_eafb2a3985aef284181e5c4f9a895f4c);
#
#
#
#         marker_b294010f9c6e5c60fbb150945ebc26c3.bindPopup(popup_3ab92df0eef6184cd9cfe969fb417e11)
#         ;
#
#
#
#
#             var marker_b619aa80770f1e93b1689e9c66d75b3d = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_a3f14ffca40629ded1473bd60ff077b8);
#
#
#         var popup_bc1e435049b352c4d9f775d80314b120 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_08d1f727d7dfcd22858e8d5314b5e2ee = $(`&lt;div id=&quot;html_08d1f727d7dfcd22858e8d5314b5e2ee&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_bc1e435049b352c4d9f775d80314b120.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d3e8966a466cb45534ac1bd5e2a75c9b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d3e8966a466cb45534ac1bd5e2a75c9b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d3e8966a466cb45534ac1bd5e2a75c9b = L.map(
#                 &quot;map_d3e8966a466cb45534ac1bd5e2a75c9b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1ba4eb4b078bd1cc3dbe478973f5e34c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1ba4eb4b078bd1cc3dbe478973f5e34c.addTo(map_d3e8966a466cb45534ac1bd5e2a75c9b);
#
#
#             var feature_group_bcb0692d28ae1ffc390b922ea2fecf54 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_15a3d68a463e6568e05ef18c9eabe91c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_bcb0692d28ae1ffc390b922ea2fecf54);
#
#
#         var popup_6311dfba0b6c210c91ffcd79cf077572 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fcba5b1402acf85cc3e5624a7e839153 = $(`&lt;div id=&quot;html_fcba5b1402acf85cc3e5624a7e839153&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_6311dfba0b6c210c91ffcd79cf077572.setContent(html_fcba5b1402acf85cc3e5624a7e839153);
#
#
#
#         marker_15a3d68a463e6568e05ef18c9eabe91c.bindPopup(popup_6311dfba0b6c210c91ffcd79cf077572)
#         ;
#
#
#
#
#             var marker_dd863dadf4bc832893781ec6513094dd = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_bcb0692d28ae1ffc390b922ea2fecf54);
#
#
#         var popup_93b57aa5073dd48cc12030c497cccf5d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8986a28c1ab3557d3a94bd4629392f02 = $(`&lt;div id=&quot;html_8986a28c1ab3557d3a94bd4629392f02&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_93b57aa5073dd48cc12030c497cccf5d.setContent(html_8986a28c1ab3557d3a94bd4629392f02);
#
#
#
#         marker_dd863dadf4bc832893781ec6513094dd.bindPopup(popup_93b57aa5073dd48cc12030c497cccf5d)
#         ;
#
#
#
#
#             var marker_6c9a0e4f763589e8b1b8bcab7e187c99 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_bcb0692d28ae1ffc390b922ea2fecf54);
#
#
#         var popup_5607b4129cff096c3ef9dee180681873 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cc5f3a0367962c816911ad921fc22f60 = $(`&lt;div id=&quot;html_cc5f3a0367962c816911ad921fc22f60&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_5607b4129cff096c3ef9dee180681873.setContent(html_cc5f3a0367962c816911ad921fc22f60);
#
#
#
#         marker_6c9a0e4f763589e8b1b8bcab7e187c99.bindPopup(popup_5607b4129cff096c3ef9dee180681873)
#         ;
#
#
#
#
#             var marker_fd87c53fd219c3261bcb35b1dc061ba4 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_bcb0692d28ae1ffc390b922ea2fecf54);
#
#
#         var popup_68d6d31984281a2e57eddb58cb497f9a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c16edc709d5672b2f506cd2d65d1f822 = $(`&lt;div id=&quot;html_c16edc709d5672b2f506cd2d65d1f822&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_68d6d31984281a2e57eddb58cb497f9a.setContent(html_c16edc709d5672b2f506cd2d65d1f822);
#
#
#
#         marker_fd87c53fd219c3261bcb35b1dc061ba4.bindPopup(popup_68d6d31984281a2e57eddb58cb497f9a)
#         ;
#
#
#
#
#             var marker_f21403663a668df8b8de04d2a357b61f = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_bcb0692d28ae1ffc390b922ea2fecf54);
#
#
#         var popup_03e76c6b8ff79f6b5619f7e4cd728247 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3492b2ed884cadf2c2006b94193e81d7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3492b2ed884cadf2c2006b94193e81d7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3492b2ed884cadf2c2006b94193e81d7 = L.map(
#                 &quot;map_3492b2ed884cadf2c2006b94193e81d7&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d4bba23bfc1508b4db7cdaea11dea2c4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d4bba23bfc1508b4db7cdaea11dea2c4.addTo(map_3492b2ed884cadf2c2006b94193e81d7);
#
#
#             var feature_group_f100984c38e486a1320e2d2fd6191806 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_f100984c38e486a1320e2d2fd6191806.addTo(map_3492b2ed884cadf2c2006b94193e81d7);
#
#
#             var feature_group_sub_group_07167024f69bb7df2ebff94bfe3117c4 = L.featureGroup.subGroup(
#                 feature_group_f100984c38e486a1320e2d2fd6191806
#             );
#
#
#             var marker_cccec1806dabd1ec7bdcdd9f26cdc2dc = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_07167024f69bb7df2ebff94bfe3117c4);
#
#
#         var popup_eacf8d8ba1b59c7ec67d4541431a6068 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_aa87e0fab57acb82a802b26dfbbe92ec = $(`&lt;div id=&quot;html_aa87e0fab57acb82a802b26dfbbe92ec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_eacf8d8ba1b59c7ec67d4541431a6068.setContent(html_aa87e0fab57acb82a802b26dfbbe92ec);
#
#
#
#         marker_cccec1806dabd1ec7bdcdd9f26cdc2dc.bindPopup(popup_eacf8d8ba1b59c7ec67d4541431a6068)
#         ;
#
#
#
#
#             var marker_5cce7b5f83e9c941bf6aec30814ef1a5 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_07167024f69bb7df2ebff94bfe3117c4);
#
#
#         var popup_a7abd871daf79513b85289c46e09d12a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_44cb6c1d44eeadee3ee4ac794a3ba0aa = $(`&lt;div id=&quot;html_44cb6c1d44eeadee3ee4ac794a3ba0aa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_a7abd871daf79513b85289c46e09d12a.setContent(html_44cb6c1d44eeadee3ee4ac794a3ba0aa);
#
#
#
#         marker_5cce7b5f83e9c941bf6aec30814ef1a5.bindPopup(popup_a7abd871daf79513b85289c46e09d12a)
#         ;
#
#
#
#
#             var marker_fefb64f587f289cdd2737acc6d346008 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_07167024f69bb7df2ebff94bfe3117c4);
#
#
#         var popup_25128f0f731fc9cc2ade56f266bdfcd7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2cff760993de7b0b2223481e6b017e63 = $(`&lt;div id=&quot;html_2cff760993de7b0b2223481e6b017e63&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_25128f0f731fc9cc2ade56f266bdfcd7.setContent(html_2cff760993de7b0b2223481e6b017e63);
#
#
#
#         marker_fefb64f587f289cdd2737acc6d346008.bindPopup(popup_25128f0f731fc9cc2ade56f266bdfcd7)
#         ;
#
#
#
#
#             var marker_909bfa95c6de39494265a24de08d2284 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_07167024f69bb7df2ebff94bfe3117c4);
#
#
#         var popup_a9d632043a2c3152141238843cf4e173 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bb3fc039628e47afb8fed5248e17d8d2 = $(`&lt;div id=&quot;html_bb3fc039628e47afb8fed5248e17d8d2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_a9d632043a2c3152141238843cf4e173.setContent(html_bb3fc039628e47afb8fed5248e17d8d2);
#
#
#
#         marker_
