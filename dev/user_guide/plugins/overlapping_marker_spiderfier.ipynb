# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f78f7ac87d515c32c9acae61cea5bb97 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f78f7ac87d515c32c9acae61cea5bb97&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f78f7ac87d515c32c9acae61cea5bb97 = L.map(
#                 &quot;map_f78f7ac87d515c32c9acae61cea5bb97&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4b4d312ee7275b48ffa900e0e540c9d3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4b4d312ee7275b48ffa900e0e540c9d3.addTo(map_f78f7ac87d515c32c9acae61cea5bb97);
#
#
#             var marker_5129ad07553ab7126919faf22ed776e4 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_f78f7ac87d515c32c9acae61cea5bb97);
#
#
#         var popup_000152020f479a322d402df3adeedda7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5814bfdde65ec7727846647ca436dd56 = $(`&lt;div id=&quot;html_5814bfdde65ec7727846647ca436dd56&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_000152020f479a322d402df3adeedda7.setContent(html_5814bfdde65ec7727846647ca436dd56);
#
#
#
#         marker_5129ad07553ab7126919faf22ed776e4.bindPopup(popup_000152020f479a322d402df3adeedda7)
#         ;
#
#
#
#
#             var marker_237899b4f07d53e9687f4b80a8666bc8 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_f78f7ac87d515c32c9acae61cea5bb97);
#
#
#         var popup_a8cedf80a834512ef9fc754bf28c403e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a444802a470f74ea46ed6148ba210ff1 = $(`&lt;div id=&quot;html_a444802a470f74ea46ed6148ba210ff1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_a8cedf80a834512ef9fc754bf28c403e.setContent(html_a444802a470f74ea46ed6148ba210ff1);
#
#
#
#         marker_237899b4f07d53e9687f4b80a8666bc8.bindPopup(popup_a8cedf80a834512ef9fc754bf28c403e)
#         ;
#
#
#
#
#             var marker_fa8656cd7d250f00e5a37484cd898712 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_f78f7ac87d515c32c9acae61cea5bb97);
#
#
#         var popup_915948744d18cb63e955d0162bfe6d06 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_585113d517f6bf6714536cc36af6dfa9 = $(`&lt;div id=&quot;html_585113d517f6bf6714536cc36af6dfa9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_915948744d18cb63e955d0162bfe6d06.setContent(html_585113d517f6bf6714536cc36af6dfa9);
#
#
#
#         marker_fa8656cd7d250f00e5a37484cd898712.bindPopup(popup_915948744d18cb63e955d0162bfe6d06)
#         ;
#
#
#
#
#             var marker_a69a59bbb28ea0ac865ec18620086f78 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_f78f7ac87d515c32c9acae61cea5bb97);
#
#
#         var popup_661e6420245ae5c055ac34429cb108b2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6e751afa330c1ff30e6b72bed8d93a4b = $(`&lt;div id=&quot;html_6e751afa330c1ff30e6b72bed8d93a4b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_661e6420245ae5c055ac34429cb108b2.setContent(html_6e751afa330c1ff30e6b72bed8d93a4b);
#
#
#
#         marker_a69a59bbb28ea0ac865ec18620086f78.bindPopup(popup_661e6420245ae5c055ac34429cb108b2)
#         ;
#
#
#
#
#             var marker_00742d8cf8413fa15b1fd7a888d9883e = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_f78f7ac87d515c32c9acae61cea5bb97);
#
#
#         var popup_5bb41639febabc6d1bead542b46df9e5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b725695fd1fd8b8f48a977be03adcc1a = $(`&lt;div id=&quot;html_b725695fd1fd8b8f48a977be03adcc1a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_5bb41639febabc6d1bead542b46df9e5.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_526c3af8ae12d93777f43d43e41f2bd4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_526c3af8ae12d93777f43d43e41f2bd4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_526c3af8ae12d93777f43d43e41f2bd4 = L.map(
#                 &quot;map_526c3af8ae12d93777f43d43e41f2bd4&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d858622481dedeccaf57994d758fb75e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d858622481dedeccaf57994d758fb75e.addTo(map_526c3af8ae12d93777f43d43e41f2bd4);
#
#
#             var feature_group_2eb7da19399332182ac81ca9072fc978 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_16c1e0d51dd83ef83c034951c6413710 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_2eb7da19399332182ac81ca9072fc978);
#
#
#         var popup_42ddde6419d17bf0779374719aa4c454 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7712a0c0273a393213f502011c64a320 = $(`&lt;div id=&quot;html_7712a0c0273a393213f502011c64a320&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_42ddde6419d17bf0779374719aa4c454.setContent(html_7712a0c0273a393213f502011c64a320);
#
#
#
#         marker_16c1e0d51dd83ef83c034951c6413710.bindPopup(popup_42ddde6419d17bf0779374719aa4c454)
#         ;
#
#
#
#
#             var marker_b79f2619390126eee30393c027fc30ab = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_2eb7da19399332182ac81ca9072fc978);
#
#
#         var popup_c9f911b9cd1aa905b1fda6e1ab52ebe1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0ff809d4882a33b41bc7924067656ef2 = $(`&lt;div id=&quot;html_0ff809d4882a33b41bc7924067656ef2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_c9f911b9cd1aa905b1fda6e1ab52ebe1.setContent(html_0ff809d4882a33b41bc7924067656ef2);
#
#
#
#         marker_b79f2619390126eee30393c027fc30ab.bindPopup(popup_c9f911b9cd1aa905b1fda6e1ab52ebe1)
#         ;
#
#
#
#
#             var marker_ce88d81c3270e044947ad1399e6a42f6 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_2eb7da19399332182ac81ca9072fc978);
#
#
#         var popup_a7b8ee73d41e0b6da7b8ec4c02ab1520 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_63b3bc888a2f94da1624a1456a9e43bf = $(`&lt;div id=&quot;html_63b3bc888a2f94da1624a1456a9e43bf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_a7b8ee73d41e0b6da7b8ec4c02ab1520.setContent(html_63b3bc888a2f94da1624a1456a9e43bf);
#
#
#
#         marker_ce88d81c3270e044947ad1399e6a42f6.bindPopup(popup_a7b8ee73d41e0b6da7b8ec4c02ab1520)
#         ;
#
#
#
#
#             var marker_5a2b39ee4beda3763b0a52371aa05fae = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_2eb7da19399332182ac81ca9072fc978);
#
#
#         var popup_ab05cac1bd46d4d26c51e4dc1bb1ac48 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_706e935179c4f7f5f70e6a8313dfc6d8 = $(`&lt;div id=&quot;html_706e935179c4f7f5f70e6a8313dfc6d8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_ab05cac1bd46d4d26c51e4dc1bb1ac48.setContent(html_706e935179c4f7f5f70e6a8313dfc6d8);
#
#
#
#         marker_5a2b39ee4beda3763b0a52371aa05fae.bindPopup(popup_ab05cac1bd46d4d26c51e4dc1bb1ac48)
#         ;
#
#
#
#
#             var marker_77e2dea1dc31ef0996c5766e410293dc = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_2eb7da19399332182ac81ca9072fc978);
#
#
#         var popup_2f2a2f71821d3da5de2b60e6d655d34c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0334ac42d655dd9026608fa711199a6b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0334ac42d655dd9026608fa711199a6b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0334ac42d655dd9026608fa711199a6b = L.map(
#                 &quot;map_0334ac42d655dd9026608fa711199a6b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4fb11a94b9d4927d90233cf67b325577 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4fb11a94b9d4927d90233cf67b325577.addTo(map_0334ac42d655dd9026608fa711199a6b);
#
#
#             var feature_group_f8a9b67206aa9c583b084444c72c73df = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_f8a9b67206aa9c583b084444c72c73df.addTo(map_0334ac42d655dd9026608fa711199a6b);
#
#
#             var feature_group_sub_group_c6f047a2da7ee11bf41a36ccf2e5015f = L.featureGroup.subGroup(
#                 feature_group_f8a9b67206aa9c583b084444c72c73df
#             );
#
#
#             var marker_225bad4e29597031f3020e8e7be060d7 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_c6f047a2da7ee11bf41a36ccf2e5015f);
#
#
#         var popup_0f37789e3e8634ef4c8f12f3f0d34e63 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_de99c10a886e00ed02642c4e2063bcd0 = $(`&lt;div id=&quot;html_de99c10a886e00ed02642c4e2063bcd0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_0f37789e3e8634ef4c8f12f3f0d34e63.setContent(html_de99c10a886e00ed02642c4e2063bcd0);
#
#
#
#         marker_225bad4e29597031f3020e8e7be060d7.bindPopup(popup_0f37789e3e8634ef4c8f12f3f0d34e63)
#         ;
#
#
#
#
#             var marker_f12574609e07b387d50f23d209dd0da6 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_c6f047a2da7ee11bf41a36ccf2e5015f);
#
#
#         var popup_aacce242d9e8697a1baf23cd6c59c3e0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_13172b0708989d82496a6d2e8443ec63 = $(`&lt;div id=&quot;html_13172b0708989d82496a6d2e8443ec63&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_aacce242d9e8697a1baf23cd6c59c3e0.setContent(html_13172b0708989d82496a6d2e8443ec63);
#
#
#
#         marker_f12574609e07b387d50f23d209dd0da6.bindPopup(popup_aacce242d9e8697a1baf23cd6c59c3e0)
#         ;
#
#
#
#
#             var marker_68bc82ed4479364295084d2066df5437 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_c6f047a2da7ee11bf41a36ccf2e5015f);
#
#
#         var popup_1ea56d7e53d7488bca9c3f32736328ac = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_77b5f30f48c401369f201a0f83d350cd = $(`&lt;div id=&quot;html_77b5f30f48c401369f201a0f83d350cd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_1ea56d7e53d7488bca9c3f32736328ac.setContent(html_77b5f30f48c401369f201a0f83d350cd);
#
#
#
#         marker_68bc82ed4479364295084d2066df5437.bindPopup(popup_1ea56d7e53d7488bca9c3f32736328ac)
#         ;
#
#
#
#
#             var marker_bcd447328233bcb4aa0a5de4664a1044 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_c6f047a2da7ee11bf41a36ccf2e5015f);
#
#
#         var popup_1aa5988eab4266060d08cdac6f2ad17e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_309a27a61a2f8462ef4d9de280aa27d5 = $(`&lt;div id=&quot;html_309a27a61a2f8462ef4d9de280aa27d5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_1aa5988eab4266060d08cdac6f2ad17e.setContent(html_309a27a61a2f8462ef4d9de280aa27d5);
#
#
#
#         marker_
