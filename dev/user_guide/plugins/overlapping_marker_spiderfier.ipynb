# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a6e49ccbedb0cd9db48e1e96630dccc0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a6e49ccbedb0cd9db48e1e96630dccc0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a6e49ccbedb0cd9db48e1e96630dccc0 = L.map(
#                 &quot;map_a6e49ccbedb0cd9db48e1e96630dccc0&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2d75e8a99fb238268409960bdad92b82 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2d75e8a99fb238268409960bdad92b82.addTo(map_a6e49ccbedb0cd9db48e1e96630dccc0);
#
#
#             var marker_ae281d7fa5e9d4dcdcb03ae1ccf9dc33 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_a6e49ccbedb0cd9db48e1e96630dccc0);
#
#
#         var popup_2e59a3592dc434e521d8945de916922b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4ebf50b9f899c9675dbc382a78217737 = $(`&lt;div id=&quot;html_4ebf50b9f899c9675dbc382a78217737&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_2e59a3592dc434e521d8945de916922b.setContent(html_4ebf50b9f899c9675dbc382a78217737);
#
#
#
#         marker_ae281d7fa5e9d4dcdcb03ae1ccf9dc33.bindPopup(popup_2e59a3592dc434e521d8945de916922b)
#         ;
#
#
#
#
#             var marker_72c2d40ee4bf315a80c5c0b6562b7a1e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_a6e49ccbedb0cd9db48e1e96630dccc0);
#
#
#         var popup_69afb9122f42ffb4a00848b22bc89415 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1ab638b52c1faa3f4fd1a45fdbf65343 = $(`&lt;div id=&quot;html_1ab638b52c1faa3f4fd1a45fdbf65343&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_69afb9122f42ffb4a00848b22bc89415.setContent(html_1ab638b52c1faa3f4fd1a45fdbf65343);
#
#
#
#         marker_72c2d40ee4bf315a80c5c0b6562b7a1e.bindPopup(popup_69afb9122f42ffb4a00848b22bc89415)
#         ;
#
#
#
#
#             var marker_2819043f008f9383c1c98b2db9373158 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_a6e49ccbedb0cd9db48e1e96630dccc0);
#
#
#         var popup_256f486e72f2272690c90dfc98220b01 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_87968c91ffd2ca721630a905765d1536 = $(`&lt;div id=&quot;html_87968c91ffd2ca721630a905765d1536&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_256f486e72f2272690c90dfc98220b01.setContent(html_87968c91ffd2ca721630a905765d1536);
#
#
#
#         marker_2819043f008f9383c1c98b2db9373158.bindPopup(popup_256f486e72f2272690c90dfc98220b01)
#         ;
#
#
#
#
#             var marker_867b0c8dd79a07c661a948ceb7770271 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_a6e49ccbedb0cd9db48e1e96630dccc0);
#
#
#         var popup_0d6be5b6b58b44da451df77f1717517e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1a55d69dd3ab59433d4d4f9c24ba93fa = $(`&lt;div id=&quot;html_1a55d69dd3ab59433d4d4f9c24ba93fa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_0d6be5b6b58b44da451df77f1717517e.setContent(html_1a55d69dd3ab59433d4d4f9c24ba93fa);
#
#
#
#         marker_867b0c8dd79a07c661a948ceb7770271.bindPopup(popup_0d6be5b6b58b44da451df77f1717517e)
#         ;
#
#
#
#
#             var marker_2e26ca052d6ed518074cb01752c6d4b3 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_a6e49ccbedb0cd9db48e1e96630dccc0);
#
#
#         var popup_5604083d69d2a2728972bc929894b640 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a83f35f3bc5379b86612bdc90c319115 = $(`&lt;div id=&quot;html_a83f35f3bc5379b86612bdc90c319115&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_5604083d69d2a2728972bc929894b640.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a9e2ae804da025c4e87e97d751101d53 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a9e2ae804da025c4e87e97d751101d53&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a9e2ae804da025c4e87e97d751101d53 = L.map(
#                 &quot;map_a9e2ae804da025c4e87e97d751101d53&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_503a53dbc482f38678b2c2b9cef65882 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_503a53dbc482f38678b2c2b9cef65882.addTo(map_a9e2ae804da025c4e87e97d751101d53);
#
#
#             var feature_group_4fc263beeaa34ced2e95c0b8f0e69f62 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_882f7760c5a596a0df6d1964924fc93c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_4fc263beeaa34ced2e95c0b8f0e69f62);
#
#
#         var popup_30d5dc71a6f1a5a10b59fd41db2fae6d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5b37b699c227e2944afb0b1e133c2e97 = $(`&lt;div id=&quot;html_5b37b699c227e2944afb0b1e133c2e97&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_30d5dc71a6f1a5a10b59fd41db2fae6d.setContent(html_5b37b699c227e2944afb0b1e133c2e97);
#
#
#
#         marker_882f7760c5a596a0df6d1964924fc93c.bindPopup(popup_30d5dc71a6f1a5a10b59fd41db2fae6d)
#         ;
#
#
#
#
#             var marker_e36038cce30de2a12c759b0dfd939939 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_4fc263beeaa34ced2e95c0b8f0e69f62);
#
#
#         var popup_6d198831190e6b054877157227ae6f8b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bcfb9c4c169df711de01f1eae9862734 = $(`&lt;div id=&quot;html_bcfb9c4c169df711de01f1eae9862734&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_6d198831190e6b054877157227ae6f8b.setContent(html_bcfb9c4c169df711de01f1eae9862734);
#
#
#
#         marker_e36038cce30de2a12c759b0dfd939939.bindPopup(popup_6d198831190e6b054877157227ae6f8b)
#         ;
#
#
#
#
#             var marker_3bea1b65a37692155e73bafe021a56f8 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_4fc263beeaa34ced2e95c0b8f0e69f62);
#
#
#         var popup_a53b25d9287a73f73c664c83f9b30201 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6e29d7dca7771b6b8fe43962f782fc29 = $(`&lt;div id=&quot;html_6e29d7dca7771b6b8fe43962f782fc29&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_a53b25d9287a73f73c664c83f9b30201.setContent(html_6e29d7dca7771b6b8fe43962f782fc29);
#
#
#
#         marker_3bea1b65a37692155e73bafe021a56f8.bindPopup(popup_a53b25d9287a73f73c664c83f9b30201)
#         ;
#
#
#
#
#             var marker_fc896a68db096edbb129821a6b2e8856 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_4fc263beeaa34ced2e95c0b8f0e69f62);
#
#
#         var popup_c560cfd21589fa2fef61259d8c1de625 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0c236ffced94b9c286f396fe3b151bb9 = $(`&lt;div id=&quot;html_0c236ffced94b9c286f396fe3b151bb9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_c560cfd21589fa2fef61259d8c1de625.setContent(html_0c236ffced94b9c286f396fe3b151bb9);
#
#
#
#         marker_fc896a68db096edbb129821a6b2e8856.bindPopup(popup_c560cfd21589fa2fef61259d8c1de625)
#         ;
#
#
#
#
#             var marker_623d1ceb166ef9466d7c9dc71d9c532e = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_4fc263beeaa34ced2e95c0b8f0e69f62);
#
#
#         var popup_461cc75b54c5bd05bb2a0f1bc1125306 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_795486a382ac9e28d224f601b195cbfe {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_795486a382ac9e28d224f601b195cbfe&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_795486a382ac9e28d224f601b195cbfe = L.map(
#                 &quot;map_795486a382ac9e28d224f601b195cbfe&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cae9166fe3a481143975d63073ee6f06 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_cae9166fe3a481143975d63073ee6f06.addTo(map_795486a382ac9e28d224f601b195cbfe);
#
#
#             var feature_group_b8971140082a8ce8ea5bd1c67807680f = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_b8971140082a8ce8ea5bd1c67807680f.addTo(map_795486a382ac9e28d224f601b195cbfe);
#
#
#             var feature_group_sub_group_814c11bf7c2d4bd70776f1756cff6d87 = L.featureGroup.subGroup(
#                 feature_group_b8971140082a8ce8ea5bd1c67807680f
#             );
#
#
#             var marker_97c7df37101cf42ce162f5045b810ade = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_814c11bf7c2d4bd70776f1756cff6d87);
#
#
#         var popup_76e2faafcad5b256890d6c173b9b7ac1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_24de236cff95c3ed6f19e7106c786837 = $(`&lt;div id=&quot;html_24de236cff95c3ed6f19e7106c786837&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_76e2faafcad5b256890d6c173b9b7ac1.setContent(html_24de236cff95c3ed6f19e7106c786837);
#
#
#
#         marker_97c7df37101cf42ce162f5045b810ade.bindPopup(popup_76e2faafcad5b256890d6c173b9b7ac1)
#         ;
#
#
#
#
#             var marker_c32e992f52b14dc598ea7aeee17bbbef = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_814c11bf7c2d4bd70776f1756cff6d87);
#
#
#         var popup_6505746adc6e85d493e487e55e0ed7a5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d09f517a8661a1b1cd6a8ea0dfb16549 = $(`&lt;div id=&quot;html_d09f517a8661a1b1cd6a8ea0dfb16549&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_6505746adc6e85d493e487e55e0ed7a5.setContent(html_d09f517a8661a1b1cd6a8ea0dfb16549);
#
#
#
#         marker_c32e992f52b14dc598ea7aeee17bbbef.bindPopup(popup_6505746adc6e85d493e487e55e0ed7a5)
#         ;
#
#
#
#
#             var marker_16a08b3dc29e38a40997e4943695459b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_814c11bf7c2d4bd70776f1756cff6d87);
#
#
#         var popup_a481858e4ac9c6aeacb1ea97ad06c452 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_23fd6b0a28d83f6e137d2911985fad2c = $(`&lt;div id=&quot;html_23fd6b0a28d83f6e137d2911985fad2c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_a481858e4ac9c6aeacb1ea97ad06c452.setContent(html_23fd6b0a28d83f6e137d2911985fad2c);
#
#
#
#         marker_16a08b3dc29e38a40997e4943695459b.bindPopup(popup_a481858e4ac9c6aeacb1ea97ad06c452)
#         ;
#
#
#
#
#             var marker_c94883f0c739ad2e477058fb7bee47d6 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_814c11bf7c2d4bd70776f1756cff6d87);
#
#
#         var popup_b61f9e4c5de8b6e6fa9d0dfe61012bc3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f2a71c357eac0ed333fd3fb1c51d33bc = $(`&lt;div id=&quot;html_f2a71c357eac0ed333fd3fb1c51d33bc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_b61f9e4c5de8b6e6fa9d0dfe61012bc3.setContent(html_f2a71c357eac0ed333fd3fb1c51d33bc);
#
#
#
#         marker_
