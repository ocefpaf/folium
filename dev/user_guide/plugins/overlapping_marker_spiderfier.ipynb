# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5328f642a889dbc6bd251b8391cd96a4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5328f642a889dbc6bd251b8391cd96a4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5328f642a889dbc6bd251b8391cd96a4 = L.map(
#                 &quot;map_5328f642a889dbc6bd251b8391cd96a4&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8fcf3e80942b7634344e89024fcabd10 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8fcf3e80942b7634344e89024fcabd10.addTo(map_5328f642a889dbc6bd251b8391cd96a4);
#
#
#             var marker_ec574354ed0861a5f53a87cad0074db2 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_5328f642a889dbc6bd251b8391cd96a4);
#
#
#         var popup_9c4b3872c6779e8211af85c6b11b47ee = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1e62fd46fcd216b1f1440cef5fc3a4ac = $(`&lt;div id=&quot;html_1e62fd46fcd216b1f1440cef5fc3a4ac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_9c4b3872c6779e8211af85c6b11b47ee.setContent(html_1e62fd46fcd216b1f1440cef5fc3a4ac);
#
#
#
#         marker_ec574354ed0861a5f53a87cad0074db2.bindPopup(popup_9c4b3872c6779e8211af85c6b11b47ee)
#         ;
#
#
#
#
#             var marker_4a442442543feb780a93875faba86768 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_5328f642a889dbc6bd251b8391cd96a4);
#
#
#         var popup_f4b4f14e3271ed621d54837605cec02d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_117af9345f023d9cec6abd3f24cfda31 = $(`&lt;div id=&quot;html_117af9345f023d9cec6abd3f24cfda31&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_f4b4f14e3271ed621d54837605cec02d.setContent(html_117af9345f023d9cec6abd3f24cfda31);
#
#
#
#         marker_4a442442543feb780a93875faba86768.bindPopup(popup_f4b4f14e3271ed621d54837605cec02d)
#         ;
#
#
#
#
#             var marker_d1a8ef72b37ac9446770949ef953a964 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_5328f642a889dbc6bd251b8391cd96a4);
#
#
#         var popup_d8b28ad094d0a200d35e2afc302f8669 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_04989fb2f2308e93548a17876b409089 = $(`&lt;div id=&quot;html_04989fb2f2308e93548a17876b409089&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_d8b28ad094d0a200d35e2afc302f8669.setContent(html_04989fb2f2308e93548a17876b409089);
#
#
#
#         marker_d1a8ef72b37ac9446770949ef953a964.bindPopup(popup_d8b28ad094d0a200d35e2afc302f8669)
#         ;
#
#
#
#
#             var marker_891c9375f704a7d7acda16b304dcaa5e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_5328f642a889dbc6bd251b8391cd96a4);
#
#
#         var popup_fe94ba60966fa0b896d5c8d9f7410948 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e8ff531d60fce6ebcc84cb517aa45f00 = $(`&lt;div id=&quot;html_e8ff531d60fce6ebcc84cb517aa45f00&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_fe94ba60966fa0b896d5c8d9f7410948.setContent(html_e8ff531d60fce6ebcc84cb517aa45f00);
#
#
#
#         marker_891c9375f704a7d7acda16b304dcaa5e.bindPopup(popup_fe94ba60966fa0b896d5c8d9f7410948)
#         ;
#
#
#
#
#             var marker_1cbb205d4d0f4f7b3590de7b5851ec0d = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_5328f642a889dbc6bd251b8391cd96a4);
#
#
#         var popup_867a2ea03c922c894db8e5bd4b9ef49b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7cc4e4c2e585633b33fe22fe9980d228 = $(`&lt;div id=&quot;html_7cc4e4c2e585633b33fe22fe9980d228&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_867a2ea03c922c894db8e5bd4b9ef49b.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_85b75324e7b61947486f50efd0b68184 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_85b75324e7b61947486f50efd0b68184&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_85b75324e7b61947486f50efd0b68184 = L.map(
#                 &quot;map_85b75324e7b61947486f50efd0b68184&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fce77879b06d4aca05370442ad711c8a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_fce77879b06d4aca05370442ad711c8a.addTo(map_85b75324e7b61947486f50efd0b68184);
#
#
#             var feature_group_0b44295550d32ca1d772967e8c54fbe7 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_d5d1ebd6eb7eae6b10145ae0c5457fc7 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_0b44295550d32ca1d772967e8c54fbe7);
#
#
#         var popup_0c76cbe8f2393ad39022f4033d97d059 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8ad1e9bd0fc0dc44183ca99616fef838 = $(`&lt;div id=&quot;html_8ad1e9bd0fc0dc44183ca99616fef838&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_0c76cbe8f2393ad39022f4033d97d059.setContent(html_8ad1e9bd0fc0dc44183ca99616fef838);
#
#
#
#         marker_d5d1ebd6eb7eae6b10145ae0c5457fc7.bindPopup(popup_0c76cbe8f2393ad39022f4033d97d059)
#         ;
#
#
#
#
#             var marker_14ff941a20dde8e42c8765c3e3d7e0af = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_0b44295550d32ca1d772967e8c54fbe7);
#
#
#         var popup_ea2d46382956905692d9195bf30b5153 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3428265c0ccbcfa23b1eba99d62b124a = $(`&lt;div id=&quot;html_3428265c0ccbcfa23b1eba99d62b124a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_ea2d46382956905692d9195bf30b5153.setContent(html_3428265c0ccbcfa23b1eba99d62b124a);
#
#
#
#         marker_14ff941a20dde8e42c8765c3e3d7e0af.bindPopup(popup_ea2d46382956905692d9195bf30b5153)
#         ;
#
#
#
#
#             var marker_56cfcacb4b739fbe31cbbb8fd849a08c = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_0b44295550d32ca1d772967e8c54fbe7);
#
#
#         var popup_eee781cc775eb1fd54b36073dd59b80d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_faaac3bfcad3a01bc71e8368df90c3e6 = $(`&lt;div id=&quot;html_faaac3bfcad3a01bc71e8368df90c3e6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_eee781cc775eb1fd54b36073dd59b80d.setContent(html_faaac3bfcad3a01bc71e8368df90c3e6);
#
#
#
#         marker_56cfcacb4b739fbe31cbbb8fd849a08c.bindPopup(popup_eee781cc775eb1fd54b36073dd59b80d)
#         ;
#
#
#
#
#             var marker_16e2bbe8d49c05bd9f4a8f728ad00156 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_0b44295550d32ca1d772967e8c54fbe7);
#
#
#         var popup_daf7ea1f0a4fd3d2ade7e00b70a0677b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_71edd7a65fbd2a87d0e8695f7142607b = $(`&lt;div id=&quot;html_71edd7a65fbd2a87d0e8695f7142607b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_daf7ea1f0a4fd3d2ade7e00b70a0677b.setContent(html_71edd7a65fbd2a87d0e8695f7142607b);
#
#
#
#         marker_16e2bbe8d49c05bd9f4a8f728ad00156.bindPopup(popup_daf7ea1f0a4fd3d2ade7e00b70a0677b)
#         ;
#
#
#
#
#             var marker_b3a8f4935dc92209466a27dd4a931cfb = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_0b44295550d32ca1d772967e8c54fbe7);
#
#
#         var popup_169fec5e6278c001f3c10008f8e149f9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1871b3147afb8ecc7f8e4fe4bfe10b40 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1871b3147afb8ecc7f8e4fe4bfe10b40&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1871b3147afb8ecc7f8e4fe4bfe10b40 = L.map(
#                 &quot;map_1871b3147afb8ecc7f8e4fe4bfe10b40&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2fba4b6b788397f865ce3100fae1bf73 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2fba4b6b788397f865ce3100fae1bf73.addTo(map_1871b3147afb8ecc7f8e4fe4bfe10b40);
#
#
#             var feature_group_23d9ba3a24e9cd2f532b210d727a7fa7 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_23d9ba3a24e9cd2f532b210d727a7fa7.addTo(map_1871b3147afb8ecc7f8e4fe4bfe10b40);
#
#
#             var feature_group_sub_group_bbc77da92dfc748a6700e31fb1bc5548 = L.featureGroup.subGroup(
#                 feature_group_23d9ba3a24e9cd2f532b210d727a7fa7
#             );
#
#
#             var marker_f70dc4ff0cb6b7214496b47165ef9f19 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_bbc77da92dfc748a6700e31fb1bc5548);
#
#
#         var popup_ee5cae9be214e7f100e816f4ae86bb1a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8db1900e670b6c6776de6cad32d52a34 = $(`&lt;div id=&quot;html_8db1900e670b6c6776de6cad32d52a34&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_ee5cae9be214e7f100e816f4ae86bb1a.setContent(html_8db1900e670b6c6776de6cad32d52a34);
#
#
#
#         marker_f70dc4ff0cb6b7214496b47165ef9f19.bindPopup(popup_ee5cae9be214e7f100e816f4ae86bb1a)
#         ;
#
#
#
#
#             var marker_9c33d994cb18de583cf21c3e296626f1 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_bbc77da92dfc748a6700e31fb1bc5548);
#
#
#         var popup_2bae5db789f74c446cbfdc1358f81fcf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d83769b0eab23c608eabe394060e1d24 = $(`&lt;div id=&quot;html_d83769b0eab23c608eabe394060e1d24&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_2bae5db789f74c446cbfdc1358f81fcf.setContent(html_d83769b0eab23c608eabe394060e1d24);
#
#
#
#         marker_9c33d994cb18de583cf21c3e296626f1.bindPopup(popup_2bae5db789f74c446cbfdc1358f81fcf)
#         ;
#
#
#
#
#             var marker_cfe02dfdd5ea2dfd365ff27168ca6fc0 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_bbc77da92dfc748a6700e31fb1bc5548);
#
#
#         var popup_2b784f6d9efe87cff456ded7336f2445 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_73c794e976ae66693c35ab4e310abbde = $(`&lt;div id=&quot;html_73c794e976ae66693c35ab4e310abbde&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_2b784f6d9efe87cff456ded7336f2445.setContent(html_73c794e976ae66693c35ab4e310abbde);
#
#
#
#         marker_cfe02dfdd5ea2dfd365ff27168ca6fc0.bindPopup(popup_2b784f6d9efe87cff456ded7336f2445)
#         ;
#
#
#
#
#             var marker_afd0a0c63cc1fba3d9e337b048060dd0 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_bbc77da92dfc748a6700e31fb1bc5548);
#
#
#         var popup_e92f4e30b27cdf614e1ca2df3a2b7f3d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0e36abec670acf5f173f3e3f0afa1126 = $(`&lt;div id=&quot;html_0e36abec670acf5f173f3e3f0afa1126&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_e92f4e30b27cdf614e1ca2df3a2b7f3d.setContent(html_0e36abec670acf5f173f3e3f0afa1126);
#
#
#
#         marker_
