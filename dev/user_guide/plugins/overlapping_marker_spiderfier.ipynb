# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_879978dad31332b7f2e727dd0d4b1363 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_879978dad31332b7f2e727dd0d4b1363&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_879978dad31332b7f2e727dd0d4b1363 = L.map(
#                 &quot;map_879978dad31332b7f2e727dd0d4b1363&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d3a786d643a664f5473cbe5be6f6d069 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d3a786d643a664f5473cbe5be6f6d069.addTo(map_879978dad31332b7f2e727dd0d4b1363);
#
#
#             var marker_9ab5fb366d12ad20c1ed5540cce1cd7b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_879978dad31332b7f2e727dd0d4b1363);
#
#
#         var popup_39e316e1f606d631059a02735130e19d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1bc729f745bc001585d92c20207263d6 = $(`&lt;div id=&quot;html_1bc729f745bc001585d92c20207263d6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_39e316e1f606d631059a02735130e19d.setContent(html_1bc729f745bc001585d92c20207263d6);
#
#
#
#         marker_9ab5fb366d12ad20c1ed5540cce1cd7b.bindPopup(popup_39e316e1f606d631059a02735130e19d)
#         ;
#
#
#
#
#             var marker_f8725e618b9dcd08476c43312b492175 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_879978dad31332b7f2e727dd0d4b1363);
#
#
#         var popup_8a50ae86b73f1143f3a1011de9b6cad4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f5d4da1d0e823e7931afac5c9e48284a = $(`&lt;div id=&quot;html_f5d4da1d0e823e7931afac5c9e48284a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_8a50ae86b73f1143f3a1011de9b6cad4.setContent(html_f5d4da1d0e823e7931afac5c9e48284a);
#
#
#
#         marker_f8725e618b9dcd08476c43312b492175.bindPopup(popup_8a50ae86b73f1143f3a1011de9b6cad4)
#         ;
#
#
#
#
#             var marker_5237da4c2bbb2080a68e03d35c14ba22 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_879978dad31332b7f2e727dd0d4b1363);
#
#
#         var popup_16c0cb35b447c8f1203221a29f8d2a4f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a39aaaccc439d39d93775fadc150c87f = $(`&lt;div id=&quot;html_a39aaaccc439d39d93775fadc150c87f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_16c0cb35b447c8f1203221a29f8d2a4f.setContent(html_a39aaaccc439d39d93775fadc150c87f);
#
#
#
#         marker_5237da4c2bbb2080a68e03d35c14ba22.bindPopup(popup_16c0cb35b447c8f1203221a29f8d2a4f)
#         ;
#
#
#
#
#             var marker_1b1394a2f22870ee5f9d6ced43cc71cf = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_879978dad31332b7f2e727dd0d4b1363);
#
#
#         var popup_cb224e902c7ea9a4f604d20e40ca1a92 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_96c76452632ae2500bd2f9b94f2e310c = $(`&lt;div id=&quot;html_96c76452632ae2500bd2f9b94f2e310c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_cb224e902c7ea9a4f604d20e40ca1a92.setContent(html_96c76452632ae2500bd2f9b94f2e310c);
#
#
#
#         marker_1b1394a2f22870ee5f9d6ced43cc71cf.bindPopup(popup_cb224e902c7ea9a4f604d20e40ca1a92)
#         ;
#
#
#
#
#             var marker_b00eb682ddb493b51cc0f16154f1611d = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_879978dad31332b7f2e727dd0d4b1363);
#
#
#         var popup_4619afbdb52b148e4177914b5b16efb0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_277c0be1b57c47d0803f124ca01a3155 = $(`&lt;div id=&quot;html_277c0be1b57c47d0803f124ca01a3155&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_4619afbdb52b148e4177914b5b16efb0.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_36ec057ab0d6ff48929b6aa662284fd6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_36ec057ab0d6ff48929b6aa662284fd6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_36ec057ab0d6ff48929b6aa662284fd6 = L.map(
#                 &quot;map_36ec057ab0d6ff48929b6aa662284fd6&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b1b8eb0933fdee9b614c4cb327d887b0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b1b8eb0933fdee9b614c4cb327d887b0.addTo(map_36ec057ab0d6ff48929b6aa662284fd6);
#
#
#             var feature_group_91cbc5285b814dc2572d55fc9f7589e1 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_40c76256ec54c8a6798b1c6adec18afe = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_91cbc5285b814dc2572d55fc9f7589e1);
#
#
#         var popup_449d89c81f4ecf45f22ca477f2a183f9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_12e6045c6b3d87509e6c4a92d09bf256 = $(`&lt;div id=&quot;html_12e6045c6b3d87509e6c4a92d09bf256&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_449d89c81f4ecf45f22ca477f2a183f9.setContent(html_12e6045c6b3d87509e6c4a92d09bf256);
#
#
#
#         marker_40c76256ec54c8a6798b1c6adec18afe.bindPopup(popup_449d89c81f4ecf45f22ca477f2a183f9)
#         ;
#
#
#
#
#             var marker_5ab56c5f93fa7ea90d7fa9534c148c88 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_91cbc5285b814dc2572d55fc9f7589e1);
#
#
#         var popup_1671031ae4bb3a4da369625a6d7abeb7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_60110546b5e7bf7a568534f131a9a9d9 = $(`&lt;div id=&quot;html_60110546b5e7bf7a568534f131a9a9d9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_1671031ae4bb3a4da369625a6d7abeb7.setContent(html_60110546b5e7bf7a568534f131a9a9d9);
#
#
#
#         marker_5ab56c5f93fa7ea90d7fa9534c148c88.bindPopup(popup_1671031ae4bb3a4da369625a6d7abeb7)
#         ;
#
#
#
#
#             var marker_8058b0937c8e26208b7798f47cb2aa2d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_91cbc5285b814dc2572d55fc9f7589e1);
#
#
#         var popup_a0d298e1d8a73722984ec039e7f99373 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_37fb90d5a33f47e846843bea124213c2 = $(`&lt;div id=&quot;html_37fb90d5a33f47e846843bea124213c2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_a0d298e1d8a73722984ec039e7f99373.setContent(html_37fb90d5a33f47e846843bea124213c2);
#
#
#
#         marker_8058b0937c8e26208b7798f47cb2aa2d.bindPopup(popup_a0d298e1d8a73722984ec039e7f99373)
#         ;
#
#
#
#
#             var marker_1031b7edc52e1f810a4facefe18e5c0a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_91cbc5285b814dc2572d55fc9f7589e1);
#
#
#         var popup_c81cddfaf463f58e5e83c0241e46fb9c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0b9371df87c64a213708b7945c32e714 = $(`&lt;div id=&quot;html_0b9371df87c64a213708b7945c32e714&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_c81cddfaf463f58e5e83c0241e46fb9c.setContent(html_0b9371df87c64a213708b7945c32e714);
#
#
#
#         marker_1031b7edc52e1f810a4facefe18e5c0a.bindPopup(popup_c81cddfaf463f58e5e83c0241e46fb9c)
#         ;
#
#
#
#
#             var marker_376ec8efd726d774158e4eaa48a77d14 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_91cbc5285b814dc2572d55fc9f7589e1);
#
#
#         var popup_02f13868d0bc7f17c4273a154d07f8ff = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_81fb25ccd2fce136935d154d0a95604f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_81fb25ccd2fce136935d154d0a95604f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_81fb25ccd2fce136935d154d0a95604f = L.map(
#                 &quot;map_81fb25ccd2fce136935d154d0a95604f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_66ede83dbaafad4e55b0650d896d535a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_66ede83dbaafad4e55b0650d896d535a.addTo(map_81fb25ccd2fce136935d154d0a95604f);
#
#
#             var feature_group_572d7e192f1b14ed7aef9f239c0e36f1 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_572d7e192f1b14ed7aef9f239c0e36f1.addTo(map_81fb25ccd2fce136935d154d0a95604f);
#
#
#             var feature_group_sub_group_60d1a493dfcd189c500d5f9a69882596 = L.featureGroup.subGroup(
#                 feature_group_572d7e192f1b14ed7aef9f239c0e36f1
#             );
#
#
#             var marker_280104f0a005e6a187f130cf356dcd37 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_60d1a493dfcd189c500d5f9a69882596);
#
#
#         var popup_03cbf24eaaf62bdaf72c947cdd7f9398 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6651724e9735250648bda7a4f138e9ed = $(`&lt;div id=&quot;html_6651724e9735250648bda7a4f138e9ed&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_03cbf24eaaf62bdaf72c947cdd7f9398.setContent(html_6651724e9735250648bda7a4f138e9ed);
#
#
#
#         marker_280104f0a005e6a187f130cf356dcd37.bindPopup(popup_03cbf24eaaf62bdaf72c947cdd7f9398)
#         ;
#
#
#
#
#             var marker_b1b7573a034d998d1ddb353d165999c1 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_60d1a493dfcd189c500d5f9a69882596);
#
#
#         var popup_7870150e7aefcae232da1eb51242f176 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6e308fc5c46bf8725948da39de9eb586 = $(`&lt;div id=&quot;html_6e308fc5c46bf8725948da39de9eb586&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_7870150e7aefcae232da1eb51242f176.setContent(html_6e308fc5c46bf8725948da39de9eb586);
#
#
#
#         marker_b1b7573a034d998d1ddb353d165999c1.bindPopup(popup_7870150e7aefcae232da1eb51242f176)
#         ;
#
#
#
#
#             var marker_1dce6410711d67962818c6ced1d95969 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_60d1a493dfcd189c500d5f9a69882596);
#
#
#         var popup_008b87f8aa78ec1448d0d8bc6a917e66 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_70169d5497c07b08f27be4c65d3145fe = $(`&lt;div id=&quot;html_70169d5497c07b08f27be4c65d3145fe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_008b87f8aa78ec1448d0d8bc6a917e66.setContent(html_70169d5497c07b08f27be4c65d3145fe);
#
#
#
#         marker_1dce6410711d67962818c6ced1d95969.bindPopup(popup_008b87f8aa78ec1448d0d8bc6a917e66)
#         ;
#
#
#
#
#             var marker_1de60c148af518ae6d155f6b30c3efc7 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_60d1a493dfcd189c500d5f9a69882596);
#
#
#         var popup_373170fe22594190a0c967a72d6253be = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ca23ffb31f884a453641f30801385d11 = $(`&lt;div id=&quot;html_ca23ffb31f884a453641f30801385d11&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_373170fe22594190a0c967a72d6253be.setContent(html_ca23ffb31f884a453641f30801385d11);
#
#
#
#         marker_
