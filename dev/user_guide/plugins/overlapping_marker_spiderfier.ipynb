# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8a4adcbf2a7aff59f6ac9e4efc118d43 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8a4adcbf2a7aff59f6ac9e4efc118d43&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8a4adcbf2a7aff59f6ac9e4efc118d43 = L.map(
#                 &quot;map_8a4adcbf2a7aff59f6ac9e4efc118d43&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7af273eee6d42e835e80a63eb4569f8e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7af273eee6d42e835e80a63eb4569f8e.addTo(map_8a4adcbf2a7aff59f6ac9e4efc118d43);
#
#
#             var marker_ac8c574c0017d878e284e916bdacd8f1 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_8a4adcbf2a7aff59f6ac9e4efc118d43);
#
#
#         var popup_de4ba0c828220a8ce279adc931334a28 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d813da1336dbf5824fc50fe96838f7ff = $(`&lt;div id=&quot;html_d813da1336dbf5824fc50fe96838f7ff&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_de4ba0c828220a8ce279adc931334a28.setContent(html_d813da1336dbf5824fc50fe96838f7ff);
#
#
#
#         marker_ac8c574c0017d878e284e916bdacd8f1.bindPopup(popup_de4ba0c828220a8ce279adc931334a28)
#         ;
#
#
#
#
#             var marker_3b1197092c3f7d0818731030ecd457bf = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_8a4adcbf2a7aff59f6ac9e4efc118d43);
#
#
#         var popup_8279b340a3fc63e001f7e8ea42c78cc4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_073ce56e8b104a7804c4dd31a1075f51 = $(`&lt;div id=&quot;html_073ce56e8b104a7804c4dd31a1075f51&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_8279b340a3fc63e001f7e8ea42c78cc4.setContent(html_073ce56e8b104a7804c4dd31a1075f51);
#
#
#
#         marker_3b1197092c3f7d0818731030ecd457bf.bindPopup(popup_8279b340a3fc63e001f7e8ea42c78cc4)
#         ;
#
#
#
#
#             var marker_5b570a87f2ea2782a9b22e4f67338bf2 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_8a4adcbf2a7aff59f6ac9e4efc118d43);
#
#
#         var popup_b1853dd601330d10cb64ceb2f88fa5ec = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b1f62b0d6dbfaebfb38e73768e18a083 = $(`&lt;div id=&quot;html_b1f62b0d6dbfaebfb38e73768e18a083&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_b1853dd601330d10cb64ceb2f88fa5ec.setContent(html_b1f62b0d6dbfaebfb38e73768e18a083);
#
#
#
#         marker_5b570a87f2ea2782a9b22e4f67338bf2.bindPopup(popup_b1853dd601330d10cb64ceb2f88fa5ec)
#         ;
#
#
#
#
#             var marker_12e6c9929c28f7058fba69d16cb22686 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_8a4adcbf2a7aff59f6ac9e4efc118d43);
#
#
#         var popup_f0cc9c2844ace63b76451e987a678384 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1747e4571c651684793079199215f87f = $(`&lt;div id=&quot;html_1747e4571c651684793079199215f87f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_f0cc9c2844ace63b76451e987a678384.setContent(html_1747e4571c651684793079199215f87f);
#
#
#
#         marker_12e6c9929c28f7058fba69d16cb22686.bindPopup(popup_f0cc9c2844ace63b76451e987a678384)
#         ;
#
#
#
#
#             var marker_3a34c3c367d9ffd83bf8c96339449662 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_8a4adcbf2a7aff59f6ac9e4efc118d43);
#
#
#         var popup_6e2fbc76d5d47fe736ca0a52269ad5b3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_48e18ab85403baab344382078577bf87 = $(`&lt;div id=&quot;html_48e18ab85403baab344382078577bf87&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_6e2fbc76d5d47fe736ca0a52269ad5b3.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_93116388179cbb41124b3b60261b1ab3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_93116388179cbb41124b3b60261b1ab3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_93116388179cbb41124b3b60261b1ab3 = L.map(
#                 &quot;map_93116388179cbb41124b3b60261b1ab3&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_48d0d86ab545649bf788553cd3840f5e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_48d0d86ab545649bf788553cd3840f5e.addTo(map_93116388179cbb41124b3b60261b1ab3);
#
#
#             var feature_group_17966ed4e700011e2e4aa719b54a5fc8 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_34f47b4a6c48373c493abea310e2cdad = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_17966ed4e700011e2e4aa719b54a5fc8);
#
#
#         var popup_9896688ab3cdb113d870de4f76d8ce1b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1e54d30ea3b5121174e8cc169c2e526e = $(`&lt;div id=&quot;html_1e54d30ea3b5121174e8cc169c2e526e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_9896688ab3cdb113d870de4f76d8ce1b.setContent(html_1e54d30ea3b5121174e8cc169c2e526e);
#
#
#
#         marker_34f47b4a6c48373c493abea310e2cdad.bindPopup(popup_9896688ab3cdb113d870de4f76d8ce1b)
#         ;
#
#
#
#
#             var marker_2d15e4831a0032508a26e2c7b08d5913 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_17966ed4e700011e2e4aa719b54a5fc8);
#
#
#         var popup_307d112e13ad5ee78b38ce4cd103cc92 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2179b025f34c27224d196220ca3313fd = $(`&lt;div id=&quot;html_2179b025f34c27224d196220ca3313fd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_307d112e13ad5ee78b38ce4cd103cc92.setContent(html_2179b025f34c27224d196220ca3313fd);
#
#
#
#         marker_2d15e4831a0032508a26e2c7b08d5913.bindPopup(popup_307d112e13ad5ee78b38ce4cd103cc92)
#         ;
#
#
#
#
#             var marker_e66afabeb0614180e670391776534da7 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_17966ed4e700011e2e4aa719b54a5fc8);
#
#
#         var popup_cf2255da6ba9b61038b198b097b64707 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5c2729921eed0e3c8d35e19393cce928 = $(`&lt;div id=&quot;html_5c2729921eed0e3c8d35e19393cce928&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_cf2255da6ba9b61038b198b097b64707.setContent(html_5c2729921eed0e3c8d35e19393cce928);
#
#
#
#         marker_e66afabeb0614180e670391776534da7.bindPopup(popup_cf2255da6ba9b61038b198b097b64707)
#         ;
#
#
#
#
#             var marker_5067f19beeb554a519783223fde53355 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_17966ed4e700011e2e4aa719b54a5fc8);
#
#
#         var popup_2456173c92900599eb3a7531ad0048a5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c465aada34bbe9452c635c0a4ca34969 = $(`&lt;div id=&quot;html_c465aada34bbe9452c635c0a4ca34969&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_2456173c92900599eb3a7531ad0048a5.setContent(html_c465aada34bbe9452c635c0a4ca34969);
#
#
#
#         marker_5067f19beeb554a519783223fde53355.bindPopup(popup_2456173c92900599eb3a7531ad0048a5)
#         ;
#
#
#
#
#             var marker_9506204dcdb9579f9bf676c1af054873 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_17966ed4e700011e2e4aa719b54a5fc8);
#
#
#         var popup_450b748c7f6a5c6f560f7ef7b96f981c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9357541f50c67260dea22003da0bc603 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9357541f50c67260dea22003da0bc603&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9357541f50c67260dea22003da0bc603 = L.map(
#                 &quot;map_9357541f50c67260dea22003da0bc603&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_87cfdb0a50c9f4135cde8cee0150ac91 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_87cfdb0a50c9f4135cde8cee0150ac91.addTo(map_9357541f50c67260dea22003da0bc603);
#
#
#             var feature_group_953f9fe091736b2a9689c7954e89d9ab = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_953f9fe091736b2a9689c7954e89d9ab.addTo(map_9357541f50c67260dea22003da0bc603);
#
#
#             var feature_group_sub_group_3102388dddfe3314a4d2d65c01822fb1 = L.featureGroup.subGroup(
#                 feature_group_953f9fe091736b2a9689c7954e89d9ab
#             );
#
#
#             var marker_2b7014fdc58305367a5e2340868a3a13 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_3102388dddfe3314a4d2d65c01822fb1);
#
#
#         var popup_e8197448afb3cf7731a9f3b7342aa13c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1fd93fafa3c0a26edf4c5f0ee25d98d1 = $(`&lt;div id=&quot;html_1fd93fafa3c0a26edf4c5f0ee25d98d1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_e8197448afb3cf7731a9f3b7342aa13c.setContent(html_1fd93fafa3c0a26edf4c5f0ee25d98d1);
#
#
#
#         marker_2b7014fdc58305367a5e2340868a3a13.bindPopup(popup_e8197448afb3cf7731a9f3b7342aa13c)
#         ;
#
#
#
#
#             var marker_f040bad3e6492975e2453483755102f6 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_3102388dddfe3314a4d2d65c01822fb1);
#
#
#         var popup_1e09b67da434c9332c2a6d987295f349 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_651dd66122db14d3bb3570bd3dfd1815 = $(`&lt;div id=&quot;html_651dd66122db14d3bb3570bd3dfd1815&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_1e09b67da434c9332c2a6d987295f349.setContent(html_651dd66122db14d3bb3570bd3dfd1815);
#
#
#
#         marker_f040bad3e6492975e2453483755102f6.bindPopup(popup_1e09b67da434c9332c2a6d987295f349)
#         ;
#
#
#
#
#             var marker_4d5570efea18f9ce4ce14f63aed46615 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_3102388dddfe3314a4d2d65c01822fb1);
#
#
#         var popup_7dd6fe8f3d9a1fcc1be79093edff927c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9e7a644a406b2653ab2bd15004451938 = $(`&lt;div id=&quot;html_9e7a644a406b2653ab2bd15004451938&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_7dd6fe8f3d9a1fcc1be79093edff927c.setContent(html_9e7a644a406b2653ab2bd15004451938);
#
#
#
#         marker_4d5570efea18f9ce4ce14f63aed46615.bindPopup(popup_7dd6fe8f3d9a1fcc1be79093edff927c)
#         ;
#
#
#
#
#             var marker_402700de2e2d9d43cb6af91f268dcbff = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_3102388dddfe3314a4d2d65c01822fb1);
#
#
#         var popup_bbcc2643c35dbb1815db3bc0325e4cbf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9a1741e6fbcc898b4411f00021e06c44 = $(`&lt;div id=&quot;html_9a1741e6fbcc898b4411f00021e06c44&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_bbcc2643c35dbb1815db3bc0325e4cbf.setContent(html_9a1741e6fbcc898b4411f00021e06c44);
#
#
#
#         marker_
