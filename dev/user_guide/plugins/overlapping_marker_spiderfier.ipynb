# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9f9e1c79330d8a07e1cf8698b940a277 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9f9e1c79330d8a07e1cf8698b940a277&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9f9e1c79330d8a07e1cf8698b940a277 = L.map(
#                 &quot;map_9f9e1c79330d8a07e1cf8698b940a277&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_36da0355af56220951673379de91ae9f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_36da0355af56220951673379de91ae9f.addTo(map_9f9e1c79330d8a07e1cf8698b940a277);
#
#
#             var marker_aa87ce8bc2d93f7e55e8f68ac09ac502 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_9f9e1c79330d8a07e1cf8698b940a277);
#
#
#         var popup_b5dbb1d732dc812a55bc50367e1c965d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_48b470234fdc88192d668a0c3be6d662 = $(`&lt;div id=&quot;html_48b470234fdc88192d668a0c3be6d662&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_b5dbb1d732dc812a55bc50367e1c965d.setContent(html_48b470234fdc88192d668a0c3be6d662);
#
#
#
#         marker_aa87ce8bc2d93f7e55e8f68ac09ac502.bindPopup(popup_b5dbb1d732dc812a55bc50367e1c965d)
#         ;
#
#
#
#
#             var marker_8e799acd0aa92e711db7675192d12b0f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_9f9e1c79330d8a07e1cf8698b940a277);
#
#
#         var popup_e73a09f217f0665822724f397f991f7b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8ee4f8efcb9d8f34c205e9df06f9b8c7 = $(`&lt;div id=&quot;html_8ee4f8efcb9d8f34c205e9df06f9b8c7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_e73a09f217f0665822724f397f991f7b.setContent(html_8ee4f8efcb9d8f34c205e9df06f9b8c7);
#
#
#
#         marker_8e799acd0aa92e711db7675192d12b0f.bindPopup(popup_e73a09f217f0665822724f397f991f7b)
#         ;
#
#
#
#
#             var marker_2e8c6021c32c5fb8eb70efac52eb3840 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_9f9e1c79330d8a07e1cf8698b940a277);
#
#
#         var popup_bcf5036b3c8158cc5402824fcf39fac4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6f4e0005c4093c1a9b88e8a4dc7b3438 = $(`&lt;div id=&quot;html_6f4e0005c4093c1a9b88e8a4dc7b3438&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_bcf5036b3c8158cc5402824fcf39fac4.setContent(html_6f4e0005c4093c1a9b88e8a4dc7b3438);
#
#
#
#         marker_2e8c6021c32c5fb8eb70efac52eb3840.bindPopup(popup_bcf5036b3c8158cc5402824fcf39fac4)
#         ;
#
#
#
#
#             var marker_54132d46cc79d8b1290d86671d06bdbc = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_9f9e1c79330d8a07e1cf8698b940a277);
#
#
#         var popup_49ad36774a05b92089d86ef577048a12 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_73de8fa72f2306585e118450204a298d = $(`&lt;div id=&quot;html_73de8fa72f2306585e118450204a298d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_49ad36774a05b92089d86ef577048a12.setContent(html_73de8fa72f2306585e118450204a298d);
#
#
#
#         marker_54132d46cc79d8b1290d86671d06bdbc.bindPopup(popup_49ad36774a05b92089d86ef577048a12)
#         ;
#
#
#
#
#             var marker_efdd5d65a1cf124a91d24e42513c4da1 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_9f9e1c79330d8a07e1cf8698b940a277);
#
#
#         var popup_0c815f14ded9e8e25fa5064c47ca1163 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_12a96d746377231563a14e352d0a0849 = $(`&lt;div id=&quot;html_12a96d746377231563a14e352d0a0849&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_0c815f14ded9e8e25fa5064c47ca1163.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3dfafe1f1e50665818947bdcbf1147c0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3dfafe1f1e50665818947bdcbf1147c0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3dfafe1f1e50665818947bdcbf1147c0 = L.map(
#                 &quot;map_3dfafe1f1e50665818947bdcbf1147c0&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_09d3d78c59df651b692bdfe874511e0b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_09d3d78c59df651b692bdfe874511e0b.addTo(map_3dfafe1f1e50665818947bdcbf1147c0);
#
#
#             var feature_group_152f08ba2f5e9a4932220a324330e32a = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_03ec63e38a49e67535a91689518dcb1e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_152f08ba2f5e9a4932220a324330e32a);
#
#
#         var popup_130c7470f836bade0a103fee7ee639c6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9bd1126852b70d1b09b19820923be660 = $(`&lt;div id=&quot;html_9bd1126852b70d1b09b19820923be660&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_130c7470f836bade0a103fee7ee639c6.setContent(html_9bd1126852b70d1b09b19820923be660);
#
#
#
#         marker_03ec63e38a49e67535a91689518dcb1e.bindPopup(popup_130c7470f836bade0a103fee7ee639c6)
#         ;
#
#
#
#
#             var marker_0f9913d6abd65ced98c0af20bf3cc661 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_152f08ba2f5e9a4932220a324330e32a);
#
#
#         var popup_37d0c996a1eebc82adf4e1c5ff8a9f65 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_273412a3cb035be1aa3c9ab1107f74a7 = $(`&lt;div id=&quot;html_273412a3cb035be1aa3c9ab1107f74a7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_37d0c996a1eebc82adf4e1c5ff8a9f65.setContent(html_273412a3cb035be1aa3c9ab1107f74a7);
#
#
#
#         marker_0f9913d6abd65ced98c0af20bf3cc661.bindPopup(popup_37d0c996a1eebc82adf4e1c5ff8a9f65)
#         ;
#
#
#
#
#             var marker_f5f9b2700a246cedb7af6c66dc903880 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_152f08ba2f5e9a4932220a324330e32a);
#
#
#         var popup_81b467c591ac85db907cc643e89471eb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4892207c53e588edb24dca127189c2a5 = $(`&lt;div id=&quot;html_4892207c53e588edb24dca127189c2a5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_81b467c591ac85db907cc643e89471eb.setContent(html_4892207c53e588edb24dca127189c2a5);
#
#
#
#         marker_f5f9b2700a246cedb7af6c66dc903880.bindPopup(popup_81b467c591ac85db907cc643e89471eb)
#         ;
#
#
#
#
#             var marker_3fe6925b409368c679bad8905dca8279 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_152f08ba2f5e9a4932220a324330e32a);
#
#
#         var popup_2ee2801af637769efe2e1e04c57e4842 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fc7fa3a670c2af2689a03e5f7819552e = $(`&lt;div id=&quot;html_fc7fa3a670c2af2689a03e5f7819552e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_2ee2801af637769efe2e1e04c57e4842.setContent(html_fc7fa3a670c2af2689a03e5f7819552e);
#
#
#
#         marker_3fe6925b409368c679bad8905dca8279.bindPopup(popup_2ee2801af637769efe2e1e04c57e4842)
#         ;
#
#
#
#
#             var marker_cf6285cf499b1b832dd1dc5b64ead479 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_152f08ba2f5e9a4932220a324330e32a);
#
#
#         var popup_78a1a87ba5d8e9ba8d9d27ff0b410898 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3af044ecce2c5e11cf9fabaaf518a4a1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3af044ecce2c5e11cf9fabaaf518a4a1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3af044ecce2c5e11cf9fabaaf518a4a1 = L.map(
#                 &quot;map_3af044ecce2c5e11cf9fabaaf518a4a1&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_364c790072123a09ad916c435359588b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_364c790072123a09ad916c435359588b.addTo(map_3af044ecce2c5e11cf9fabaaf518a4a1);
#
#
#             var feature_group_b1b58b4f78c87d54a9182b6cf0787ae7 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_b1b58b4f78c87d54a9182b6cf0787ae7.addTo(map_3af044ecce2c5e11cf9fabaaf518a4a1);
#
#
#             var feature_group_sub_group_a94edcf8527f73ceaf8b8665f4828b3c = L.featureGroup.subGroup(
#                 feature_group_b1b58b4f78c87d54a9182b6cf0787ae7
#             );
#
#
#             var marker_69d08a59d8e7c0b85a217dfc6940b3fb = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_a94edcf8527f73ceaf8b8665f4828b3c);
#
#
#         var popup_6ae654998485c4f47d3ed1f143be71c7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7e45df9b179c9e836b3b4e44109b2cfb = $(`&lt;div id=&quot;html_7e45df9b179c9e836b3b4e44109b2cfb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_6ae654998485c4f47d3ed1f143be71c7.setContent(html_7e45df9b179c9e836b3b4e44109b2cfb);
#
#
#
#         marker_69d08a59d8e7c0b85a217dfc6940b3fb.bindPopup(popup_6ae654998485c4f47d3ed1f143be71c7)
#         ;
#
#
#
#
#             var marker_c632c35432c198ea0e813fc8e8612fe2 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_a94edcf8527f73ceaf8b8665f4828b3c);
#
#
#         var popup_98252d2aeb8b479851a2af2cb58d4c83 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_208748a430eb7ada2ff14f4527b5138b = $(`&lt;div id=&quot;html_208748a430eb7ada2ff14f4527b5138b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_98252d2aeb8b479851a2af2cb58d4c83.setContent(html_208748a430eb7ada2ff14f4527b5138b);
#
#
#
#         marker_c632c35432c198ea0e813fc8e8612fe2.bindPopup(popup_98252d2aeb8b479851a2af2cb58d4c83)
#         ;
#
#
#
#
#             var marker_bfe18feafd6896c6e335c79f41985ae1 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_a94edcf8527f73ceaf8b8665f4828b3c);
#
#
#         var popup_81c114862d14d6c4fc51fa5f14627ff7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4ad16e0d80ef2ab807b12a37f4aa4184 = $(`&lt;div id=&quot;html_4ad16e0d80ef2ab807b12a37f4aa4184&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_81c114862d14d6c4fc51fa5f14627ff7.setContent(html_4ad16e0d80ef2ab807b12a37f4aa4184);
#
#
#
#         marker_bfe18feafd6896c6e335c79f41985ae1.bindPopup(popup_81c114862d14d6c4fc51fa5f14627ff7)
#         ;
#
#
#
#
#             var marker_45694458affb2309db3dece6ed823178 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_a94edcf8527f73ceaf8b8665f4828b3c);
#
#
#         var popup_8033853a9a4af3ed9f6fa8e0ee022b20 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_02f0f82bd9ae94fcfbbe991f9ed36b0d = $(`&lt;div id=&quot;html_02f0f82bd9ae94fcfbbe991f9ed36b0d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_8033853a9a4af3ed9f6fa8e0ee022b20.setContent(html_02f0f82bd9ae94fcfbbe991f9ed36b0d);
#
#
#
#         marker_
