# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8ed98f02705dd7e16c6e722274e3ff9a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8ed98f02705dd7e16c6e722274e3ff9a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8ed98f02705dd7e16c6e722274e3ff9a = L.map(
#                 &quot;map_8ed98f02705dd7e16c6e722274e3ff9a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3c8ddf5630ba8cf2b0fbf68d4a816b17 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3c8ddf5630ba8cf2b0fbf68d4a816b17.addTo(map_8ed98f02705dd7e16c6e722274e3ff9a);
#
#
#             var marker_7fca05d89f4f8221f1eaceb93f7b9b63 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_8ed98f02705dd7e16c6e722274e3ff9a);
#
#
#         var popup_2529153689654cafc2babc64f528c65b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2456a6d03e3b5254a5bc3f1fd79b6aba = $(`&lt;div id=&quot;html_2456a6d03e3b5254a5bc3f1fd79b6aba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_2529153689654cafc2babc64f528c65b.setContent(html_2456a6d03e3b5254a5bc3f1fd79b6aba);
#
#
#
#         marker_7fca05d89f4f8221f1eaceb93f7b9b63.bindPopup(popup_2529153689654cafc2babc64f528c65b)
#         ;
#
#
#
#
#             var marker_87c32c1b7cf5f74a840eb329937c3150 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_8ed98f02705dd7e16c6e722274e3ff9a);
#
#
#         var popup_6169f15c18d9eed14f6995760b669e5c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e4d2e5d716a304e8b3552ce926bedb9c = $(`&lt;div id=&quot;html_e4d2e5d716a304e8b3552ce926bedb9c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_6169f15c18d9eed14f6995760b669e5c.setContent(html_e4d2e5d716a304e8b3552ce926bedb9c);
#
#
#
#         marker_87c32c1b7cf5f74a840eb329937c3150.bindPopup(popup_6169f15c18d9eed14f6995760b669e5c)
#         ;
#
#
#
#
#             var marker_54edb186fb5bcb8cb69f7027ce4058af = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_8ed98f02705dd7e16c6e722274e3ff9a);
#
#
#         var popup_37412c6c60ceb938f1e34c264920deeb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4e738b40bea94c234fd111d8b72110db = $(`&lt;div id=&quot;html_4e738b40bea94c234fd111d8b72110db&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_37412c6c60ceb938f1e34c264920deeb.setContent(html_4e738b40bea94c234fd111d8b72110db);
#
#
#
#         marker_54edb186fb5bcb8cb69f7027ce4058af.bindPopup(popup_37412c6c60ceb938f1e34c264920deeb)
#         ;
#
#
#
#
#             var marker_7aaa4adb8b1bf6e223ddd8d119dcaa52 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_8ed98f02705dd7e16c6e722274e3ff9a);
#
#
#         var popup_4aac0e42676216680d88d8934e8d7934 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b8df267c3bdaf258930021e44cf25aa5 = $(`&lt;div id=&quot;html_b8df267c3bdaf258930021e44cf25aa5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_4aac0e42676216680d88d8934e8d7934.setContent(html_b8df267c3bdaf258930021e44cf25aa5);
#
#
#
#         marker_7aaa4adb8b1bf6e223ddd8d119dcaa52.bindPopup(popup_4aac0e42676216680d88d8934e8d7934)
#         ;
#
#
#
#
#             var marker_74e1758d1c8d9b141824902205d9472a = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_8ed98f02705dd7e16c6e722274e3ff9a);
#
#
#         var popup_1b70eb00272b9bae4e572a09629d1c2e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3cf7d7943e76810369812c323431376d = $(`&lt;div id=&quot;html_3cf7d7943e76810369812c323431376d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_1b70eb00272b9bae4e572a09629d1c2e.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c3cd24cf6c9265c5d98bbd5ade265555 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c3cd24cf6c9265c5d98bbd5ade265555&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c3cd24cf6c9265c5d98bbd5ade265555 = L.map(
#                 &quot;map_c3cd24cf6c9265c5d98bbd5ade265555&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_150f6e56564fdf06686cbf739cac8697 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_150f6e56564fdf06686cbf739cac8697.addTo(map_c3cd24cf6c9265c5d98bbd5ade265555);
#
#
#             var feature_group_a731b28205c30120ea366856512e1d11 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_af7bd72365d29a3750de886cbdae1d9a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_a731b28205c30120ea366856512e1d11);
#
#
#         var popup_73d403e02316ff00ad1d4379c333def0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_913ebbbc9c468374c4cde6fa6866ea02 = $(`&lt;div id=&quot;html_913ebbbc9c468374c4cde6fa6866ea02&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_73d403e02316ff00ad1d4379c333def0.setContent(html_913ebbbc9c468374c4cde6fa6866ea02);
#
#
#
#         marker_af7bd72365d29a3750de886cbdae1d9a.bindPopup(popup_73d403e02316ff00ad1d4379c333def0)
#         ;
#
#
#
#
#             var marker_41a3d64c60e71878d26a8d2fd867c3b7 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_a731b28205c30120ea366856512e1d11);
#
#
#         var popup_309136a263a016095509189df97565c9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6a261aa1d9a7e6efe5626e8e6dff0fdb = $(`&lt;div id=&quot;html_6a261aa1d9a7e6efe5626e8e6dff0fdb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_309136a263a016095509189df97565c9.setContent(html_6a261aa1d9a7e6efe5626e8e6dff0fdb);
#
#
#
#         marker_41a3d64c60e71878d26a8d2fd867c3b7.bindPopup(popup_309136a263a016095509189df97565c9)
#         ;
#
#
#
#
#             var marker_12087de6629de489bbc86ca31e5117f6 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_a731b28205c30120ea366856512e1d11);
#
#
#         var popup_81dd6ce61237b45ae9c132f0987bd75a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3a95f1e2aba8647f16b3f6013e368a0e = $(`&lt;div id=&quot;html_3a95f1e2aba8647f16b3f6013e368a0e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_81dd6ce61237b45ae9c132f0987bd75a.setContent(html_3a95f1e2aba8647f16b3f6013e368a0e);
#
#
#
#         marker_12087de6629de489bbc86ca31e5117f6.bindPopup(popup_81dd6ce61237b45ae9c132f0987bd75a)
#         ;
#
#
#
#
#             var marker_59507ab554d86176efb1baf46fa0c707 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_a731b28205c30120ea366856512e1d11);
#
#
#         var popup_67a9edbb6dbb4107231946d4dd36bd43 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_737d0f0e77ba9baf3592836d4bc416b0 = $(`&lt;div id=&quot;html_737d0f0e77ba9baf3592836d4bc416b0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_67a9edbb6dbb4107231946d4dd36bd43.setContent(html_737d0f0e77ba9baf3592836d4bc416b0);
#
#
#
#         marker_59507ab554d86176efb1baf46fa0c707.bindPopup(popup_67a9edbb6dbb4107231946d4dd36bd43)
#         ;
#
#
#
#
#             var marker_8b04922aae0a18d7d866858240ad3af4 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_a731b28205c30120ea366856512e1d11);
#
#
#         var popup_6f911445208ec57634f0dacec81883b6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_90d027084382d97de3e14adecdb0db7b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_90d027084382d97de3e14adecdb0db7b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_90d027084382d97de3e14adecdb0db7b = L.map(
#                 &quot;map_90d027084382d97de3e14adecdb0db7b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e5de859d22bc5c160a2d46889cdae777 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e5de859d22bc5c160a2d46889cdae777.addTo(map_90d027084382d97de3e14adecdb0db7b);
#
#
#             var feature_group_aced1c42fe96f12dab55ceec071c403a = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_aced1c42fe96f12dab55ceec071c403a.addTo(map_90d027084382d97de3e14adecdb0db7b);
#
#
#             var feature_group_sub_group_64930cee8fc2d2324cc971eedc26d2da = L.featureGroup.subGroup(
#                 feature_group_aced1c42fe96f12dab55ceec071c403a
#             );
#
#
#             var marker_811d46400336caf4aeb053346670dc2e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_64930cee8fc2d2324cc971eedc26d2da);
#
#
#         var popup_90d5ebfaebce60fdbdf2d3d8f8a68367 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3bc9ba7597c1aac12794a589cabdd44f = $(`&lt;div id=&quot;html_3bc9ba7597c1aac12794a589cabdd44f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_90d5ebfaebce60fdbdf2d3d8f8a68367.setContent(html_3bc9ba7597c1aac12794a589cabdd44f);
#
#
#
#         marker_811d46400336caf4aeb053346670dc2e.bindPopup(popup_90d5ebfaebce60fdbdf2d3d8f8a68367)
#         ;
#
#
#
#
#             var marker_21469fe0eb6b0d38815a6111f35ab7e0 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_64930cee8fc2d2324cc971eedc26d2da);
#
#
#         var popup_31aa2efa6c330b847c71f1cdf1c16377 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_06a67b7b0d43b408d1845d518bad9553 = $(`&lt;div id=&quot;html_06a67b7b0d43b408d1845d518bad9553&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_31aa2efa6c330b847c71f1cdf1c16377.setContent(html_06a67b7b0d43b408d1845d518bad9553);
#
#
#
#         marker_21469fe0eb6b0d38815a6111f35ab7e0.bindPopup(popup_31aa2efa6c330b847c71f1cdf1c16377)
#         ;
#
#
#
#
#             var marker_8e5a6eb56003e1c02411524899af3a42 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_64930cee8fc2d2324cc971eedc26d2da);
#
#
#         var popup_2347c18a370c82798e314e332538d412 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5c67c3f261ffc1822fb62a9b90142351 = $(`&lt;div id=&quot;html_5c67c3f261ffc1822fb62a9b90142351&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_2347c18a370c82798e314e332538d412.setContent(html_5c67c3f261ffc1822fb62a9b90142351);
#
#
#
#         marker_8e5a6eb56003e1c02411524899af3a42.bindPopup(popup_2347c18a370c82798e314e332538d412)
#         ;
#
#
#
#
#             var marker_a0678e6d7c0e47185d478a8998017677 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_64930cee8fc2d2324cc971eedc26d2da);
#
#
#         var popup_ab88ddab1e097ff0dfaa9916708d795a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_27f2fd9efddb12ab9c3a6f2424ab1f25 = $(`&lt;div id=&quot;html_27f2fd9efddb12ab9c3a6f2424ab1f25&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_ab88ddab1e097ff0dfaa9916708d795a.setContent(html_27f2fd9efddb12ab9c3a6f2424ab1f25);
#
#
#
#         marker_
