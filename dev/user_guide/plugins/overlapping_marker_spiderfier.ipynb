# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a54454c9edd8f73c9c84327664c6109b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a54454c9edd8f73c9c84327664c6109b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a54454c9edd8f73c9c84327664c6109b = L.map(
#                 &quot;map_a54454c9edd8f73c9c84327664c6109b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4ac6c7ea9ec439af821bbc43a0159d5c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4ac6c7ea9ec439af821bbc43a0159d5c.addTo(map_a54454c9edd8f73c9c84327664c6109b);
#
#
#             var marker_708d269bd8b9c58e6181eca51add04e2 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_a54454c9edd8f73c9c84327664c6109b);
#
#
#         var popup_902ef89c1b8c444c251ef57c7c778045 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6ad4d7003cb2d40540ac369a784fe925 = $(`&lt;div id=&quot;html_6ad4d7003cb2d40540ac369a784fe925&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_902ef89c1b8c444c251ef57c7c778045.setContent(html_6ad4d7003cb2d40540ac369a784fe925);
#
#
#
#         marker_708d269bd8b9c58e6181eca51add04e2.bindPopup(popup_902ef89c1b8c444c251ef57c7c778045)
#         ;
#
#
#
#
#             var marker_e8352b49ccc80640b98fef78a3373ede = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_a54454c9edd8f73c9c84327664c6109b);
#
#
#         var popup_fa6a5f80dd183b05aade5755d41303f3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_60246e5b29579d953d77c19d017fde15 = $(`&lt;div id=&quot;html_60246e5b29579d953d77c19d017fde15&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_fa6a5f80dd183b05aade5755d41303f3.setContent(html_60246e5b29579d953d77c19d017fde15);
#
#
#
#         marker_e8352b49ccc80640b98fef78a3373ede.bindPopup(popup_fa6a5f80dd183b05aade5755d41303f3)
#         ;
#
#
#
#
#             var marker_70c3c663ffe08e4970088de31392ae67 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_a54454c9edd8f73c9c84327664c6109b);
#
#
#         var popup_3cdafc4a386d6298aa1e10938e4e6513 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b6e08221d12236e098332849b6d4b859 = $(`&lt;div id=&quot;html_b6e08221d12236e098332849b6d4b859&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_3cdafc4a386d6298aa1e10938e4e6513.setContent(html_b6e08221d12236e098332849b6d4b859);
#
#
#
#         marker_70c3c663ffe08e4970088de31392ae67.bindPopup(popup_3cdafc4a386d6298aa1e10938e4e6513)
#         ;
#
#
#
#
#             var marker_58367f62f81ac64d7b95ea0a45523276 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_a54454c9edd8f73c9c84327664c6109b);
#
#
#         var popup_80f35d0363fb3bad86b7712bc1f057ea = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fa02d854a9c3995ac182c202ccfe76b8 = $(`&lt;div id=&quot;html_fa02d854a9c3995ac182c202ccfe76b8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_80f35d0363fb3bad86b7712bc1f057ea.setContent(html_fa02d854a9c3995ac182c202ccfe76b8);
#
#
#
#         marker_58367f62f81ac64d7b95ea0a45523276.bindPopup(popup_80f35d0363fb3bad86b7712bc1f057ea)
#         ;
#
#
#
#
#             var marker_5d1a85fda7a8734f244a12d276865936 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_a54454c9edd8f73c9c84327664c6109b);
#
#
#         var popup_5c82bb0507de0a90397666b47cd457f3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c32a2a72939f0dc2401c1348a0c0bb19 = $(`&lt;div id=&quot;html_c32a2a72939f0dc2401c1348a0c0bb19&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_5c82bb0507de0a90397666b47cd457f3.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6f9748b90f6675066aa206b0eea10711 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6f9748b90f6675066aa206b0eea10711&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6f9748b90f6675066aa206b0eea10711 = L.map(
#                 &quot;map_6f9748b90f6675066aa206b0eea10711&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c88afa7f9fd0c230f83ee69510839690 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c88afa7f9fd0c230f83ee69510839690.addTo(map_6f9748b90f6675066aa206b0eea10711);
#
#
#             var feature_group_01dc168ddb9d34534c3340eb0e8eb1a0 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_1efeeab09fb4317216740043021fa75b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_01dc168ddb9d34534c3340eb0e8eb1a0);
#
#
#         var popup_3937785cc0e3372fef9a72a7b2842add = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7ddae3e17a222007605e544c8fa9a198 = $(`&lt;div id=&quot;html_7ddae3e17a222007605e544c8fa9a198&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_3937785cc0e3372fef9a72a7b2842add.setContent(html_7ddae3e17a222007605e544c8fa9a198);
#
#
#
#         marker_1efeeab09fb4317216740043021fa75b.bindPopup(popup_3937785cc0e3372fef9a72a7b2842add)
#         ;
#
#
#
#
#             var marker_8da92cc8828cc346b55727c07490ae68 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_01dc168ddb9d34534c3340eb0e8eb1a0);
#
#
#         var popup_4e23dbe2a640c03c9e1cac350f2a6640 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fe66c1cfa75e8df57fd4bc71fb66703e = $(`&lt;div id=&quot;html_fe66c1cfa75e8df57fd4bc71fb66703e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_4e23dbe2a640c03c9e1cac350f2a6640.setContent(html_fe66c1cfa75e8df57fd4bc71fb66703e);
#
#
#
#         marker_8da92cc8828cc346b55727c07490ae68.bindPopup(popup_4e23dbe2a640c03c9e1cac350f2a6640)
#         ;
#
#
#
#
#             var marker_734088c5c2a41ef4a2250ba943ce2ac3 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_01dc168ddb9d34534c3340eb0e8eb1a0);
#
#
#         var popup_a63a05e1000ebcb569e76b08ca9cc094 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_62e3ca1044c183cd602ee9a1b32c4414 = $(`&lt;div id=&quot;html_62e3ca1044c183cd602ee9a1b32c4414&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_a63a05e1000ebcb569e76b08ca9cc094.setContent(html_62e3ca1044c183cd602ee9a1b32c4414);
#
#
#
#         marker_734088c5c2a41ef4a2250ba943ce2ac3.bindPopup(popup_a63a05e1000ebcb569e76b08ca9cc094)
#         ;
#
#
#
#
#             var marker_3622d10e5049d0792abf9131f18ac5b4 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_01dc168ddb9d34534c3340eb0e8eb1a0);
#
#
#         var popup_63be92f314dbeab2250c03a098bce5bb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_27741ada1219db1fee7720ffd2a6d500 = $(`&lt;div id=&quot;html_27741ada1219db1fee7720ffd2a6d500&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_63be92f314dbeab2250c03a098bce5bb.setContent(html_27741ada1219db1fee7720ffd2a6d500);
#
#
#
#         marker_3622d10e5049d0792abf9131f18ac5b4.bindPopup(popup_63be92f314dbeab2250c03a098bce5bb)
#         ;
#
#
#
#
#             var marker_ffbcadafb1b020aff8b8046a9dc41188 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_01dc168ddb9d34534c3340eb0e8eb1a0);
#
#
#         var popup_9e8e8423c065f749d2a826a130be3302 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5550b094d2f391723f7394743769b4ca {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5550b094d2f391723f7394743769b4ca&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5550b094d2f391723f7394743769b4ca = L.map(
#                 &quot;map_5550b094d2f391723f7394743769b4ca&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2ff639e837e1d2045b7dfc3ab49e2998 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2ff639e837e1d2045b7dfc3ab49e2998.addTo(map_5550b094d2f391723f7394743769b4ca);
#
#
#             var feature_group_309f5df4cfd6ecebe1faaf5e1eab89a2 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_309f5df4cfd6ecebe1faaf5e1eab89a2.addTo(map_5550b094d2f391723f7394743769b4ca);
#
#
#             var feature_group_sub_group_fae7abcbe06546a2d7890a4c22f6e34a = L.featureGroup.subGroup(
#                 feature_group_309f5df4cfd6ecebe1faaf5e1eab89a2
#             );
#
#
#             var marker_2cbb40b78cdcc5ef0c279056a2ccb0f8 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_fae7abcbe06546a2d7890a4c22f6e34a);
#
#
#         var popup_0e306e67a1c7eba9aa1165cf5e5ea67f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_34a8971ccf4a8f3064d8f8d5ff5129a8 = $(`&lt;div id=&quot;html_34a8971ccf4a8f3064d8f8d5ff5129a8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_0e306e67a1c7eba9aa1165cf5e5ea67f.setContent(html_34a8971ccf4a8f3064d8f8d5ff5129a8);
#
#
#
#         marker_2cbb40b78cdcc5ef0c279056a2ccb0f8.bindPopup(popup_0e306e67a1c7eba9aa1165cf5e5ea67f)
#         ;
#
#
#
#
#             var marker_35bd1a1d1f566b433cf9b35370e6645a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_fae7abcbe06546a2d7890a4c22f6e34a);
#
#
#         var popup_36348b9046d34ea8393fb01bd13d817b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f91cef97bbd56d8f5556a64e7a5d5424 = $(`&lt;div id=&quot;html_f91cef97bbd56d8f5556a64e7a5d5424&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_36348b9046d34ea8393fb01bd13d817b.setContent(html_f91cef97bbd56d8f5556a64e7a5d5424);
#
#
#
#         marker_35bd1a1d1f566b433cf9b35370e6645a.bindPopup(popup_36348b9046d34ea8393fb01bd13d817b)
#         ;
#
#
#
#
#             var marker_d9ff811e3101ffdcfa286a97c3e9a27f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_fae7abcbe06546a2d7890a4c22f6e34a);
#
#
#         var popup_a81d3de7f1b085ec203dad06e6a6eb81 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e52ba0904c14dea1a08e3955104c4d0f = $(`&lt;div id=&quot;html_e52ba0904c14dea1a08e3955104c4d0f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_a81d3de7f1b085ec203dad06e6a6eb81.setContent(html_e52ba0904c14dea1a08e3955104c4d0f);
#
#
#
#         marker_d9ff811e3101ffdcfa286a97c3e9a27f.bindPopup(popup_a81d3de7f1b085ec203dad06e6a6eb81)
#         ;
#
#
#
#
#             var marker_da738f2053c71a9e39c0df47621f3ffe = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_fae7abcbe06546a2d7890a4c22f6e34a);
#
#
#         var popup_66bbfc031d147422462118c71647247b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_20ae388b8240c00123cf1aac7f380fce = $(`&lt;div id=&quot;html_20ae388b8240c00123cf1aac7f380fce&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_66bbfc031d147422462118c71647247b.setContent(html_20ae388b8240c00123cf1aac7f380fce);
#
#
#
#         marker_
