# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_492ec782d2be444f648a09640abb831d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_492ec782d2be444f648a09640abb831d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_492ec782d2be444f648a09640abb831d = L.map(
#                 &quot;map_492ec782d2be444f648a09640abb831d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_153e841c119e4c63013fbbdeb8eb4f2c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_153e841c119e4c63013fbbdeb8eb4f2c.addTo(map_492ec782d2be444f648a09640abb831d);
#
#
#             var marker_a38485f807a0e0b50ceaf8fae0c7c6cf = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_492ec782d2be444f648a09640abb831d);
#
#
#         var popup_8f2ae95215c855305915ac32103b281c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_27ed8334f7d23d8a319ff57f2d56b86f = $(`&lt;div id=&quot;html_27ed8334f7d23d8a319ff57f2d56b86f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_8f2ae95215c855305915ac32103b281c.setContent(html_27ed8334f7d23d8a319ff57f2d56b86f);
#
#
#
#         marker_a38485f807a0e0b50ceaf8fae0c7c6cf.bindPopup(popup_8f2ae95215c855305915ac32103b281c)
#         ;
#
#
#
#
#             var marker_8fece6dbd4c549c8da05092bea462d1c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_492ec782d2be444f648a09640abb831d);
#
#
#         var popup_2b7facd0b449890fae485881df498045 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0633a8d154c8509a9d85340beff63ed0 = $(`&lt;div id=&quot;html_0633a8d154c8509a9d85340beff63ed0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_2b7facd0b449890fae485881df498045.setContent(html_0633a8d154c8509a9d85340beff63ed0);
#
#
#
#         marker_8fece6dbd4c549c8da05092bea462d1c.bindPopup(popup_2b7facd0b449890fae485881df498045)
#         ;
#
#
#
#
#             var marker_961ccc8f531832e7a7ccd083ae3a4510 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_492ec782d2be444f648a09640abb831d);
#
#
#         var popup_a8eb4396fb35770b8b4687d1a4799ed1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4f0edb3bb3d04cc9bd8ca081a3929ad0 = $(`&lt;div id=&quot;html_4f0edb3bb3d04cc9bd8ca081a3929ad0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_a8eb4396fb35770b8b4687d1a4799ed1.setContent(html_4f0edb3bb3d04cc9bd8ca081a3929ad0);
#
#
#
#         marker_961ccc8f531832e7a7ccd083ae3a4510.bindPopup(popup_a8eb4396fb35770b8b4687d1a4799ed1)
#         ;
#
#
#
#
#             var marker_f70ff6b42b210eb610867bdd272e94f0 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_492ec782d2be444f648a09640abb831d);
#
#
#         var popup_10c06e084f1f46cab4f5a0e43b7fcf68 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6361b983a0ee5efda4b88066dd9f6c59 = $(`&lt;div id=&quot;html_6361b983a0ee5efda4b88066dd9f6c59&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_10c06e084f1f46cab4f5a0e43b7fcf68.setContent(html_6361b983a0ee5efda4b88066dd9f6c59);
#
#
#
#         marker_f70ff6b42b210eb610867bdd272e94f0.bindPopup(popup_10c06e084f1f46cab4f5a0e43b7fcf68)
#         ;
#
#
#
#
#             var marker_00d0a5cd22b53f35744b17df1d9b038b = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_492ec782d2be444f648a09640abb831d);
#
#
#         var popup_94652de3abb54e234429597f6b8e6e47 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_580a04a33a9c2a8fb293acbc1b5cd8fe = $(`&lt;div id=&quot;html_580a04a33a9c2a8fb293acbc1b5cd8fe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_94652de3abb54e234429597f6b8e6e47.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4f33b6be56d79e3a28f465e4e472cc35 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4f33b6be56d79e3a28f465e4e472cc35&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4f33b6be56d79e3a28f465e4e472cc35 = L.map(
#                 &quot;map_4f33b6be56d79e3a28f465e4e472cc35&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_75cf059d1c358efae451fd4f959fee10 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_75cf059d1c358efae451fd4f959fee10.addTo(map_4f33b6be56d79e3a28f465e4e472cc35);
#
#
#             var feature_group_056bf00f16aa62ab2b2a0cd2bdc0a28c = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_4af3de5b674e1f4e97047e3555840a89 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_056bf00f16aa62ab2b2a0cd2bdc0a28c);
#
#
#         var popup_d565db51a9d37d92debe6f44768385a6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_38bba154ee6ac123418b146f410caa15 = $(`&lt;div id=&quot;html_38bba154ee6ac123418b146f410caa15&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_d565db51a9d37d92debe6f44768385a6.setContent(html_38bba154ee6ac123418b146f410caa15);
#
#
#
#         marker_4af3de5b674e1f4e97047e3555840a89.bindPopup(popup_d565db51a9d37d92debe6f44768385a6)
#         ;
#
#
#
#
#             var marker_863d71daf37e33409e33cf8ee638378c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_056bf00f16aa62ab2b2a0cd2bdc0a28c);
#
#
#         var popup_f9535856398b2c74423f02d4d25a359f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dcb20d76a14ac2d9aeaccb23d4d9ff86 = $(`&lt;div id=&quot;html_dcb20d76a14ac2d9aeaccb23d4d9ff86&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_f9535856398b2c74423f02d4d25a359f.setContent(html_dcb20d76a14ac2d9aeaccb23d4d9ff86);
#
#
#
#         marker_863d71daf37e33409e33cf8ee638378c.bindPopup(popup_f9535856398b2c74423f02d4d25a359f)
#         ;
#
#
#
#
#             var marker_e6353ccd5e0e29b23423dcfdcc89d6fc = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_056bf00f16aa62ab2b2a0cd2bdc0a28c);
#
#
#         var popup_3ff2e9d20f05bdd68398ee26c9a0f805 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d6117850ac38e02b985b309ff869b605 = $(`&lt;div id=&quot;html_d6117850ac38e02b985b309ff869b605&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_3ff2e9d20f05bdd68398ee26c9a0f805.setContent(html_d6117850ac38e02b985b309ff869b605);
#
#
#
#         marker_e6353ccd5e0e29b23423dcfdcc89d6fc.bindPopup(popup_3ff2e9d20f05bdd68398ee26c9a0f805)
#         ;
#
#
#
#
#             var marker_1e5122319bf50834c3ceb7b2f8649ea4 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_056bf00f16aa62ab2b2a0cd2bdc0a28c);
#
#
#         var popup_a4e777363dafd334fa3c8b4df86ba041 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e5e7b05ffce24b8f07d175d433c8d619 = $(`&lt;div id=&quot;html_e5e7b05ffce24b8f07d175d433c8d619&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_a4e777363dafd334fa3c8b4df86ba041.setContent(html_e5e7b05ffce24b8f07d175d433c8d619);
#
#
#
#         marker_1e5122319bf50834c3ceb7b2f8649ea4.bindPopup(popup_a4e777363dafd334fa3c8b4df86ba041)
#         ;
#
#
#
#
#             var marker_c47e68f02f99285948f24982c0344106 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_056bf00f16aa62ab2b2a0cd2bdc0a28c);
#
#
#         var popup_a4667bf8ecb9eff47300f2686d70fad5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c48d943e1d557326ead37465e92648c8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c48d943e1d557326ead37465e92648c8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c48d943e1d557326ead37465e92648c8 = L.map(
#                 &quot;map_c48d943e1d557326ead37465e92648c8&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_48dd62975ecd1ea8d438d74807767477 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_48dd62975ecd1ea8d438d74807767477.addTo(map_c48d943e1d557326ead37465e92648c8);
#
#
#             var feature_group_1daf0720721bd2c2a31ef718756e972f = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_1daf0720721bd2c2a31ef718756e972f.addTo(map_c48d943e1d557326ead37465e92648c8);
#
#
#             var feature_group_sub_group_d628536913d51d357d84eaffd7752fb5 = L.featureGroup.subGroup(
#                 feature_group_1daf0720721bd2c2a31ef718756e972f
#             );
#
#
#             var marker_097eea45a4c5aee0433c51b2a9c30912 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_d628536913d51d357d84eaffd7752fb5);
#
#
#         var popup_341f1ecf1aac79a8702556463c11fd2b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d8057bf35c448bbca469c7069b0ccd31 = $(`&lt;div id=&quot;html_d8057bf35c448bbca469c7069b0ccd31&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_341f1ecf1aac79a8702556463c11fd2b.setContent(html_d8057bf35c448bbca469c7069b0ccd31);
#
#
#
#         marker_097eea45a4c5aee0433c51b2a9c30912.bindPopup(popup_341f1ecf1aac79a8702556463c11fd2b)
#         ;
#
#
#
#
#             var marker_f8c602c7b17e0f138d8a6e388e78fa97 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_d628536913d51d357d84eaffd7752fb5);
#
#
#         var popup_70fa143e324e4ca9f9b711f1eb9faaea = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b43b4099b9fef64627ec32720caae46e = $(`&lt;div id=&quot;html_b43b4099b9fef64627ec32720caae46e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_70fa143e324e4ca9f9b711f1eb9faaea.setContent(html_b43b4099b9fef64627ec32720caae46e);
#
#
#
#         marker_f8c602c7b17e0f138d8a6e388e78fa97.bindPopup(popup_70fa143e324e4ca9f9b711f1eb9faaea)
#         ;
#
#
#
#
#             var marker_f458c52ed40ad9f9651e273701114938 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_d628536913d51d357d84eaffd7752fb5);
#
#
#         var popup_3d41db2f6c3e9827d5cc843aaf057e50 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_49c971d7a16d36d34b842760ce2acdf2 = $(`&lt;div id=&quot;html_49c971d7a16d36d34b842760ce2acdf2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_3d41db2f6c3e9827d5cc843aaf057e50.setContent(html_49c971d7a16d36d34b842760ce2acdf2);
#
#
#
#         marker_f458c52ed40ad9f9651e273701114938.bindPopup(popup_3d41db2f6c3e9827d5cc843aaf057e50)
#         ;
#
#
#
#
#             var marker_40b616987e4457c987c5803ce57e9ce3 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_d628536913d51d357d84eaffd7752fb5);
#
#
#         var popup_c665899b91f14992b526d8071b0a9a7d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a5dd73ffbb0fa4313c48558d020dd28b = $(`&lt;div id=&quot;html_a5dd73ffbb0fa4313c48558d020dd28b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_c665899b91f14992b526d8071b0a9a7d.setContent(html_a5dd73ffbb0fa4313c48558d020dd28b);
#
#
#
#         marker_
