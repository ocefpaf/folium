# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_062593ae526389bc1326bb7774beeb8a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_062593ae526389bc1326bb7774beeb8a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_062593ae526389bc1326bb7774beeb8a = L.map(
#                 &quot;map_062593ae526389bc1326bb7774beeb8a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d6e01010f40b3e958fbcff83aeec3350 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d6e01010f40b3e958fbcff83aeec3350.addTo(map_062593ae526389bc1326bb7774beeb8a);
#
#
#             var marker_8045e3809d175ac0067203f38733110e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_062593ae526389bc1326bb7774beeb8a);
#
#
#         var popup_dc51a23d0d273814dae83fb3ba290d78 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_efb86ca0283b4404df23772d946ed2b7 = $(`&lt;div id=&quot;html_efb86ca0283b4404df23772d946ed2b7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_dc51a23d0d273814dae83fb3ba290d78.setContent(html_efb86ca0283b4404df23772d946ed2b7);
#
#
#
#         marker_8045e3809d175ac0067203f38733110e.bindPopup(popup_dc51a23d0d273814dae83fb3ba290d78)
#         ;
#
#
#
#
#             var marker_991829702df30bc0bbf845cc32ea404c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_062593ae526389bc1326bb7774beeb8a);
#
#
#         var popup_4e7c725aafe95fe79ef17db9553ad118 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7faa54f15cfe77066a66f55a17651b1d = $(`&lt;div id=&quot;html_7faa54f15cfe77066a66f55a17651b1d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_4e7c725aafe95fe79ef17db9553ad118.setContent(html_7faa54f15cfe77066a66f55a17651b1d);
#
#
#
#         marker_991829702df30bc0bbf845cc32ea404c.bindPopup(popup_4e7c725aafe95fe79ef17db9553ad118)
#         ;
#
#
#
#
#             var marker_9f3605cede39b76110dbacdfdd5a37f4 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_062593ae526389bc1326bb7774beeb8a);
#
#
#         var popup_8c4076cb48ab6b7648a617d721022591 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b4a3ef87427a6ee74855851bc77e72e2 = $(`&lt;div id=&quot;html_b4a3ef87427a6ee74855851bc77e72e2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_8c4076cb48ab6b7648a617d721022591.setContent(html_b4a3ef87427a6ee74855851bc77e72e2);
#
#
#
#         marker_9f3605cede39b76110dbacdfdd5a37f4.bindPopup(popup_8c4076cb48ab6b7648a617d721022591)
#         ;
#
#
#
#
#             var marker_d952debb68913e7229f322fbf2fec72a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_062593ae526389bc1326bb7774beeb8a);
#
#
#         var popup_aaa71b098ae2317802d6a6475de4eedf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_626c1b8543de35a025c8ff3cc0922996 = $(`&lt;div id=&quot;html_626c1b8543de35a025c8ff3cc0922996&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_aaa71b098ae2317802d6a6475de4eedf.setContent(html_626c1b8543de35a025c8ff3cc0922996);
#
#
#
#         marker_d952debb68913e7229f322fbf2fec72a.bindPopup(popup_aaa71b098ae2317802d6a6475de4eedf)
#         ;
#
#
#
#
#             var marker_0eedfb74db837f5e21ff6258ce20aa5a = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_062593ae526389bc1326bb7774beeb8a);
#
#
#         var popup_4ce00cad10237f74375cba0b2e0505c1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dcfdf10d8ea605766baeefec89478002 = $(`&lt;div id=&quot;html_dcfdf10d8ea605766baeefec89478002&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_4ce00cad10237f74375cba0b2e0505c1.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_58956f2d8aabf043a4267115fac732ce {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_58956f2d8aabf043a4267115fac732ce&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_58956f2d8aabf043a4267115fac732ce = L.map(
#                 &quot;map_58956f2d8aabf043a4267115fac732ce&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2bdde0a1bbe53b534f5106d5d385b03c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2bdde0a1bbe53b534f5106d5d385b03c.addTo(map_58956f2d8aabf043a4267115fac732ce);
#
#
#             var feature_group_6dec7ad3a8cbcc04ae9463ee45e25caf = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_33b97f5fe0b34c7f1a1f4e50fc84425b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_6dec7ad3a8cbcc04ae9463ee45e25caf);
#
#
#         var popup_df0028f04ff4a4f8315d8f5e3026a35c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cf6a0c71da07c7409da73551254755c2 = $(`&lt;div id=&quot;html_cf6a0c71da07c7409da73551254755c2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_df0028f04ff4a4f8315d8f5e3026a35c.setContent(html_cf6a0c71da07c7409da73551254755c2);
#
#
#
#         marker_33b97f5fe0b34c7f1a1f4e50fc84425b.bindPopup(popup_df0028f04ff4a4f8315d8f5e3026a35c)
#         ;
#
#
#
#
#             var marker_3bac50b1269029e1a06d663257fc9047 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_6dec7ad3a8cbcc04ae9463ee45e25caf);
#
#
#         var popup_3d21dad5a5b340f6fe9c65a5a1b7392c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5b07b9f93a76e5d97925756cd95a5632 = $(`&lt;div id=&quot;html_5b07b9f93a76e5d97925756cd95a5632&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_3d21dad5a5b340f6fe9c65a5a1b7392c.setContent(html_5b07b9f93a76e5d97925756cd95a5632);
#
#
#
#         marker_3bac50b1269029e1a06d663257fc9047.bindPopup(popup_3d21dad5a5b340f6fe9c65a5a1b7392c)
#         ;
#
#
#
#
#             var marker_972ab6f526c4a5a80de734c70173859c = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_6dec7ad3a8cbcc04ae9463ee45e25caf);
#
#
#         var popup_42e5801061ad221235375cdb047e5684 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d8cc8da0d5b3788af3a4919c803b0f1e = $(`&lt;div id=&quot;html_d8cc8da0d5b3788af3a4919c803b0f1e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_42e5801061ad221235375cdb047e5684.setContent(html_d8cc8da0d5b3788af3a4919c803b0f1e);
#
#
#
#         marker_972ab6f526c4a5a80de734c70173859c.bindPopup(popup_42e5801061ad221235375cdb047e5684)
#         ;
#
#
#
#
#             var marker_30d79306242f44986f58b2b0818bea4e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_6dec7ad3a8cbcc04ae9463ee45e25caf);
#
#
#         var popup_cc9f97ea04325a1d8afc4d7e23f1f63a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f02fe60c7d61e60588e39eae3517a11d = $(`&lt;div id=&quot;html_f02fe60c7d61e60588e39eae3517a11d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_cc9f97ea04325a1d8afc4d7e23f1f63a.setContent(html_f02fe60c7d61e60588e39eae3517a11d);
#
#
#
#         marker_30d79306242f44986f58b2b0818bea4e.bindPopup(popup_cc9f97ea04325a1d8afc4d7e23f1f63a)
#         ;
#
#
#
#
#             var marker_5f2c33902b4db5f3bcfa5ac63b2345d7 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_6dec7ad3a8cbcc04ae9463ee45e25caf);
#
#
#         var popup_e55163eb918899a2eb325188935c6e7b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_56599bf570794acab6d97379dd769049 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_56599bf570794acab6d97379dd769049&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_56599bf570794acab6d97379dd769049 = L.map(
#                 &quot;map_56599bf570794acab6d97379dd769049&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a527741e2420c590ffae1bc1fce7d78b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a527741e2420c590ffae1bc1fce7d78b.addTo(map_56599bf570794acab6d97379dd769049);
#
#
#             var feature_group_499eea9b72fbca8b8be4d39a5b08a3d9 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_499eea9b72fbca8b8be4d39a5b08a3d9.addTo(map_56599bf570794acab6d97379dd769049);
#
#
#             var feature_group_sub_group_f98e8db8d4ba60f69be3e2d08b775727 = L.featureGroup.subGroup(
#                 feature_group_499eea9b72fbca8b8be4d39a5b08a3d9
#             );
#
#
#             var marker_b29490db7b4886e2008d0d67c247c824 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_f98e8db8d4ba60f69be3e2d08b775727);
#
#
#         var popup_eae0a2fd00de774fe6f557f2bc07aa09 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fd66dbe7d301506596c0e08f993ea073 = $(`&lt;div id=&quot;html_fd66dbe7d301506596c0e08f993ea073&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_eae0a2fd00de774fe6f557f2bc07aa09.setContent(html_fd66dbe7d301506596c0e08f993ea073);
#
#
#
#         marker_b29490db7b4886e2008d0d67c247c824.bindPopup(popup_eae0a2fd00de774fe6f557f2bc07aa09)
#         ;
#
#
#
#
#             var marker_d9172d96dc76348909a34b3ec657d46d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_f98e8db8d4ba60f69be3e2d08b775727);
#
#
#         var popup_168c9434505e6217139e1aecba3b11f8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1903d05d5fc3623ed2c7e17c3c6eef61 = $(`&lt;div id=&quot;html_1903d05d5fc3623ed2c7e17c3c6eef61&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_168c9434505e6217139e1aecba3b11f8.setContent(html_1903d05d5fc3623ed2c7e17c3c6eef61);
#
#
#
#         marker_d9172d96dc76348909a34b3ec657d46d.bindPopup(popup_168c9434505e6217139e1aecba3b11f8)
#         ;
#
#
#
#
#             var marker_aec08cf4cbde18dcf50cc3f84ea1425b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_f98e8db8d4ba60f69be3e2d08b775727);
#
#
#         var popup_0592df96abd2624eb9981b4cc18661a9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c18e6ca6c0dbd00dc05c90779682978e = $(`&lt;div id=&quot;html_c18e6ca6c0dbd00dc05c90779682978e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_0592df96abd2624eb9981b4cc18661a9.setContent(html_c18e6ca6c0dbd00dc05c90779682978e);
#
#
#
#         marker_aec08cf4cbde18dcf50cc3f84ea1425b.bindPopup(popup_0592df96abd2624eb9981b4cc18661a9)
#         ;
#
#
#
#
#             var marker_622526b0fc6b2d8261ae9f21745f506a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_f98e8db8d4ba60f69be3e2d08b775727);
#
#
#         var popup_134dde56168d8677bfe3879472dced89 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_46d5c0a5706e098fcc51151b19894804 = $(`&lt;div id=&quot;html_46d5c0a5706e098fcc51151b19894804&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_134dde56168d8677bfe3879472dced89.setContent(html_46d5c0a5706e098fcc51151b19894804);
#
#
#
#         marker_
