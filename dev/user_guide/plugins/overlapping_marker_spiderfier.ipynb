# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4667a4be43b78ee6cbb8df852cbaee63 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4667a4be43b78ee6cbb8df852cbaee63&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4667a4be43b78ee6cbb8df852cbaee63 = L.map(
#                 &quot;map_4667a4be43b78ee6cbb8df852cbaee63&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9bb23e81b34576290350f96bf0acdac2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9bb23e81b34576290350f96bf0acdac2.addTo(map_4667a4be43b78ee6cbb8df852cbaee63);
#
#
#             var marker_075e6bdec71d311ccf92d366aebc852b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_4667a4be43b78ee6cbb8df852cbaee63);
#
#
#         var popup_2f2bf0f6eab4df332578139e769d980f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cf6788ce24f2b8da6b850075e9384c55 = $(`&lt;div id=&quot;html_cf6788ce24f2b8da6b850075e9384c55&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_2f2bf0f6eab4df332578139e769d980f.setContent(html_cf6788ce24f2b8da6b850075e9384c55);
#
#
#
#         marker_075e6bdec71d311ccf92d366aebc852b.bindPopup(popup_2f2bf0f6eab4df332578139e769d980f)
#         ;
#
#
#
#
#             var marker_511355eb5fee207ba286af5faa3ec6b3 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_4667a4be43b78ee6cbb8df852cbaee63);
#
#
#         var popup_2afe38cdddc72950ee2973f274e8ba86 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_01f22e7513d8a9a90318e4bf1f94401e = $(`&lt;div id=&quot;html_01f22e7513d8a9a90318e4bf1f94401e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_2afe38cdddc72950ee2973f274e8ba86.setContent(html_01f22e7513d8a9a90318e4bf1f94401e);
#
#
#
#         marker_511355eb5fee207ba286af5faa3ec6b3.bindPopup(popup_2afe38cdddc72950ee2973f274e8ba86)
#         ;
#
#
#
#
#             var marker_005f926689c31b9e5b9237845c936918 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_4667a4be43b78ee6cbb8df852cbaee63);
#
#
#         var popup_dca2532fd166b771a4d0fae21f087e67 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_50050f53aeaf1ae3cc337243419453a5 = $(`&lt;div id=&quot;html_50050f53aeaf1ae3cc337243419453a5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_dca2532fd166b771a4d0fae21f087e67.setContent(html_50050f53aeaf1ae3cc337243419453a5);
#
#
#
#         marker_005f926689c31b9e5b9237845c936918.bindPopup(popup_dca2532fd166b771a4d0fae21f087e67)
#         ;
#
#
#
#
#             var marker_1bbecbd3e9b4023cc12bfb5c97867140 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_4667a4be43b78ee6cbb8df852cbaee63);
#
#
#         var popup_f0b1b137c63499b77087cba5f0b7b283 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_01fcd403c12b713563034d4ae4019ed8 = $(`&lt;div id=&quot;html_01fcd403c12b713563034d4ae4019ed8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_f0b1b137c63499b77087cba5f0b7b283.setContent(html_01fcd403c12b713563034d4ae4019ed8);
#
#
#
#         marker_1bbecbd3e9b4023cc12bfb5c97867140.bindPopup(popup_f0b1b137c63499b77087cba5f0b7b283)
#         ;
#
#
#
#
#             var marker_fa9e23e18266202f1a904e9d39828914 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_4667a4be43b78ee6cbb8df852cbaee63);
#
#
#         var popup_d27bcc35f1b9864806c13ed8048c1969 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ebd8ecfc97a50c511332863815ff611a = $(`&lt;div id=&quot;html_ebd8ecfc97a50c511332863815ff611a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_d27bcc35f1b9864806c13ed8048c1969.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fc805f31806f028d9044b02f98bb43c8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fc805f31806f028d9044b02f98bb43c8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fc805f31806f028d9044b02f98bb43c8 = L.map(
#                 &quot;map_fc805f31806f028d9044b02f98bb43c8&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f2c70d2ef980706f198f19c2ca0c099d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f2c70d2ef980706f198f19c2ca0c099d.addTo(map_fc805f31806f028d9044b02f98bb43c8);
#
#
#             var feature_group_039ef886c959683102787b3a5b2f76d9 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_1b1a611bfe7228060d8f65d371ef233c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_039ef886c959683102787b3a5b2f76d9);
#
#
#         var popup_7295cd3dbe268517b9bf08cd4d95cb85 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_364ea5980b0a6273aba4f7715bf7cec1 = $(`&lt;div id=&quot;html_364ea5980b0a6273aba4f7715bf7cec1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_7295cd3dbe268517b9bf08cd4d95cb85.setContent(html_364ea5980b0a6273aba4f7715bf7cec1);
#
#
#
#         marker_1b1a611bfe7228060d8f65d371ef233c.bindPopup(popup_7295cd3dbe268517b9bf08cd4d95cb85)
#         ;
#
#
#
#
#             var marker_b3873947146ac23c7d77f39829384306 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_039ef886c959683102787b3a5b2f76d9);
#
#
#         var popup_52e0797721fc1005cb660e2074c8f637 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a70aa7dd97a68dc8ff38859b009b4b26 = $(`&lt;div id=&quot;html_a70aa7dd97a68dc8ff38859b009b4b26&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_52e0797721fc1005cb660e2074c8f637.setContent(html_a70aa7dd97a68dc8ff38859b009b4b26);
#
#
#
#         marker_b3873947146ac23c7d77f39829384306.bindPopup(popup_52e0797721fc1005cb660e2074c8f637)
#         ;
#
#
#
#
#             var marker_6bea74f39bf529f63eb58d4057fdeb0c = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_039ef886c959683102787b3a5b2f76d9);
#
#
#         var popup_2e4ffa51dd22ff8cfee025f1ccd869ba = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a00c8bf748b21ff125636545984e7994 = $(`&lt;div id=&quot;html_a00c8bf748b21ff125636545984e7994&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_2e4ffa51dd22ff8cfee025f1ccd869ba.setContent(html_a00c8bf748b21ff125636545984e7994);
#
#
#
#         marker_6bea74f39bf529f63eb58d4057fdeb0c.bindPopup(popup_2e4ffa51dd22ff8cfee025f1ccd869ba)
#         ;
#
#
#
#
#             var marker_2a005e09f06ad34b743a53d10d38e157 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_039ef886c959683102787b3a5b2f76d9);
#
#
#         var popup_e6d1273517b28986a2de9e7d9099f545 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9be62c7fb35e1c89f531e5f590484ba9 = $(`&lt;div id=&quot;html_9be62c7fb35e1c89f531e5f590484ba9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_e6d1273517b28986a2de9e7d9099f545.setContent(html_9be62c7fb35e1c89f531e5f590484ba9);
#
#
#
#         marker_2a005e09f06ad34b743a53d10d38e157.bindPopup(popup_e6d1273517b28986a2de9e7d9099f545)
#         ;
#
#
#
#
#             var marker_eb6d2ec428e23510b8703c636a54ffac = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_039ef886c959683102787b3a5b2f76d9);
#
#
#         var popup_e951a5cd62f92ff03ed5d2482a0385c7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_278a484cbfc4cb960afad02e936d1139 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_278a484cbfc4cb960afad02e936d1139&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_278a484cbfc4cb960afad02e936d1139 = L.map(
#                 &quot;map_278a484cbfc4cb960afad02e936d1139&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1c04c0b7982692fc8974fa9bdc802276 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1c04c0b7982692fc8974fa9bdc802276.addTo(map_278a484cbfc4cb960afad02e936d1139);
#
#
#             var feature_group_7cb8a1ccd160cce9f3b5fb5602eff476 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_7cb8a1ccd160cce9f3b5fb5602eff476.addTo(map_278a484cbfc4cb960afad02e936d1139);
#
#
#             var feature_group_sub_group_d6580aaa90cd68e482b8399ef7e89cb3 = L.featureGroup.subGroup(
#                 feature_group_7cb8a1ccd160cce9f3b5fb5602eff476
#             );
#
#
#             var marker_6503aaab917c00cf324ecb913229e074 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_d6580aaa90cd68e482b8399ef7e89cb3);
#
#
#         var popup_73f6b2f202ff2a0098e177d8a3d21844 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4539e6c2dc27bfd3c345669394cfef0e = $(`&lt;div id=&quot;html_4539e6c2dc27bfd3c345669394cfef0e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_73f6b2f202ff2a0098e177d8a3d21844.setContent(html_4539e6c2dc27bfd3c345669394cfef0e);
#
#
#
#         marker_6503aaab917c00cf324ecb913229e074.bindPopup(popup_73f6b2f202ff2a0098e177d8a3d21844)
#         ;
#
#
#
#
#             var marker_2aefa35e637b53ee53008fff4274af7c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_d6580aaa90cd68e482b8399ef7e89cb3);
#
#
#         var popup_8b68044f227e97cd1634a8b5625460bc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f58537c2b0157d2a92d39611f995a9bb = $(`&lt;div id=&quot;html_f58537c2b0157d2a92d39611f995a9bb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_8b68044f227e97cd1634a8b5625460bc.setContent(html_f58537c2b0157d2a92d39611f995a9bb);
#
#
#
#         marker_2aefa35e637b53ee53008fff4274af7c.bindPopup(popup_8b68044f227e97cd1634a8b5625460bc)
#         ;
#
#
#
#
#             var marker_f35df32998ee853f4a939a38342cf5ec = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_d6580aaa90cd68e482b8399ef7e89cb3);
#
#
#         var popup_b24b8c6885e8d90f464ff6f1ea2156e9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_926685a5bceb9f2fcec5aa44c7caca67 = $(`&lt;div id=&quot;html_926685a5bceb9f2fcec5aa44c7caca67&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_b24b8c6885e8d90f464ff6f1ea2156e9.setContent(html_926685a5bceb9f2fcec5aa44c7caca67);
#
#
#
#         marker_f35df32998ee853f4a939a38342cf5ec.bindPopup(popup_b24b8c6885e8d90f464ff6f1ea2156e9)
#         ;
#
#
#
#
#             var marker_410f8c9bcb53cf1ab0d5ac076c5636fc = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_d6580aaa90cd68e482b8399ef7e89cb3);
#
#
#         var popup_8e8a991203d4d2af4614620c32c2e2bb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_330bb2ec22057b16116a81c42c8e71fd = $(`&lt;div id=&quot;html_330bb2ec22057b16116a81c42c8e71fd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_8e8a991203d4d2af4614620c32c2e2bb.setContent(html_330bb2ec22057b16116a81c42c8e71fd);
#
#
#
#         marker_
