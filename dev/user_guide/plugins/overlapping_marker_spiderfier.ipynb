# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_25742f6593454d1c3f0129f3cbf05b2f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_25742f6593454d1c3f0129f3cbf05b2f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_25742f6593454d1c3f0129f3cbf05b2f = L.map(
#                 &quot;map_25742f6593454d1c3f0129f3cbf05b2f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5a1dfcb1e175de3b1158221e2cfc8e95 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5a1dfcb1e175de3b1158221e2cfc8e95.addTo(map_25742f6593454d1c3f0129f3cbf05b2f);
#
#
#             var marker_5588ee4be7b3d4f49548918c6b808630 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_25742f6593454d1c3f0129f3cbf05b2f);
#
#
#         var popup_f6c7e3ceae42f21449dbcf4a60da4646 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_055faf900807e90aeb91140e7bd8e379 = $(`&lt;div id=&quot;html_055faf900807e90aeb91140e7bd8e379&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_f6c7e3ceae42f21449dbcf4a60da4646.setContent(html_055faf900807e90aeb91140e7bd8e379);
#
#
#
#         marker_5588ee4be7b3d4f49548918c6b808630.bindPopup(popup_f6c7e3ceae42f21449dbcf4a60da4646)
#         ;
#
#
#
#
#             var marker_84b4c32f006b141f2d456e8c716cf6ac = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_25742f6593454d1c3f0129f3cbf05b2f);
#
#
#         var popup_c66e100e2b33d0c3d4528b2a404ef28f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8687df5f8503d381026d3ec8d471ed5f = $(`&lt;div id=&quot;html_8687df5f8503d381026d3ec8d471ed5f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_c66e100e2b33d0c3d4528b2a404ef28f.setContent(html_8687df5f8503d381026d3ec8d471ed5f);
#
#
#
#         marker_84b4c32f006b141f2d456e8c716cf6ac.bindPopup(popup_c66e100e2b33d0c3d4528b2a404ef28f)
#         ;
#
#
#
#
#             var marker_c53baa7b1035b0e532a76a15fe56234a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_25742f6593454d1c3f0129f3cbf05b2f);
#
#
#         var popup_998e7d7f01d097fdfa1606c076e55770 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_04a657d13053b862479d0f4b7ef18f9c = $(`&lt;div id=&quot;html_04a657d13053b862479d0f4b7ef18f9c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_998e7d7f01d097fdfa1606c076e55770.setContent(html_04a657d13053b862479d0f4b7ef18f9c);
#
#
#
#         marker_c53baa7b1035b0e532a76a15fe56234a.bindPopup(popup_998e7d7f01d097fdfa1606c076e55770)
#         ;
#
#
#
#
#             var marker_a2c1cd51a8024e697bb53221f23dd142 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_25742f6593454d1c3f0129f3cbf05b2f);
#
#
#         var popup_03c75494da0de51049cfdd7b87e50694 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_57fc06d9da66168c26a1b56777c96942 = $(`&lt;div id=&quot;html_57fc06d9da66168c26a1b56777c96942&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_03c75494da0de51049cfdd7b87e50694.setContent(html_57fc06d9da66168c26a1b56777c96942);
#
#
#
#         marker_a2c1cd51a8024e697bb53221f23dd142.bindPopup(popup_03c75494da0de51049cfdd7b87e50694)
#         ;
#
#
#
#
#             var marker_cc79d25c163480f8f5221dcb71e072e3 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_25742f6593454d1c3f0129f3cbf05b2f);
#
#
#         var popup_0542bbea8b491895210383da7ddd2831 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_43324fbc893a05e41f541a67ece812ce = $(`&lt;div id=&quot;html_43324fbc893a05e41f541a67ece812ce&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_0542bbea8b491895210383da7ddd2831.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8c587d22209faa3fcc0a2d5ee12efab0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8c587d22209faa3fcc0a2d5ee12efab0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8c587d22209faa3fcc0a2d5ee12efab0 = L.map(
#                 &quot;map_8c587d22209faa3fcc0a2d5ee12efab0&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fff7370cf73de43399ae358cfe47ae65 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_fff7370cf73de43399ae358cfe47ae65.addTo(map_8c587d22209faa3fcc0a2d5ee12efab0);
#
#
#             var feature_group_8b06f9ae8edd9e264ce5ef37c575eb5a = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_c2568b72f2f0e15093c00e4db545ba0e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_8b06f9ae8edd9e264ce5ef37c575eb5a);
#
#
#         var popup_921386c9bd54dfdfef65a678ffe4ef4b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_052c3af4d7348977e8a72e689f7b7839 = $(`&lt;div id=&quot;html_052c3af4d7348977e8a72e689f7b7839&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_921386c9bd54dfdfef65a678ffe4ef4b.setContent(html_052c3af4d7348977e8a72e689f7b7839);
#
#
#
#         marker_c2568b72f2f0e15093c00e4db545ba0e.bindPopup(popup_921386c9bd54dfdfef65a678ffe4ef4b)
#         ;
#
#
#
#
#             var marker_15bfb2f3679f268cbf837ac1b15fc829 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_8b06f9ae8edd9e264ce5ef37c575eb5a);
#
#
#         var popup_4110e02c959efc982ced4931556920fc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8db476cdfff51fb13f765d609a5f5901 = $(`&lt;div id=&quot;html_8db476cdfff51fb13f765d609a5f5901&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_4110e02c959efc982ced4931556920fc.setContent(html_8db476cdfff51fb13f765d609a5f5901);
#
#
#
#         marker_15bfb2f3679f268cbf837ac1b15fc829.bindPopup(popup_4110e02c959efc982ced4931556920fc)
#         ;
#
#
#
#
#             var marker_54ce1563eb4b68c5158613a630acd8ad = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_8b06f9ae8edd9e264ce5ef37c575eb5a);
#
#
#         var popup_83f658b9a22da8a26c82a603eab6c7f9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1fd24f638aa12ff33cc7687517653b04 = $(`&lt;div id=&quot;html_1fd24f638aa12ff33cc7687517653b04&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_83f658b9a22da8a26c82a603eab6c7f9.setContent(html_1fd24f638aa12ff33cc7687517653b04);
#
#
#
#         marker_54ce1563eb4b68c5158613a630acd8ad.bindPopup(popup_83f658b9a22da8a26c82a603eab6c7f9)
#         ;
#
#
#
#
#             var marker_65e08d5bf4f134674ca5fc7a8eda6f05 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_8b06f9ae8edd9e264ce5ef37c575eb5a);
#
#
#         var popup_94be4f239af3de7884de3a0913cdeab8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_912707c287ed8f16755a565f0c5dcdc4 = $(`&lt;div id=&quot;html_912707c287ed8f16755a565f0c5dcdc4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_94be4f239af3de7884de3a0913cdeab8.setContent(html_912707c287ed8f16755a565f0c5dcdc4);
#
#
#
#         marker_65e08d5bf4f134674ca5fc7a8eda6f05.bindPopup(popup_94be4f239af3de7884de3a0913cdeab8)
#         ;
#
#
#
#
#             var marker_10cdf139b0ae8cf912aa27896764ae01 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_8b06f9ae8edd9e264ce5ef37c575eb5a);
#
#
#         var popup_ad4dd32a20c4b3fbeb64585e9eeb43e6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a48ba6f6796ce7c8b19360a795349b64 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a48ba6f6796ce7c8b19360a795349b64&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a48ba6f6796ce7c8b19360a795349b64 = L.map(
#                 &quot;map_a48ba6f6796ce7c8b19360a795349b64&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6a86272be7f9ae2e48d4d52f8e5f65bd = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6a86272be7f9ae2e48d4d52f8e5f65bd.addTo(map_a48ba6f6796ce7c8b19360a795349b64);
#
#
#             var feature_group_bd238c79f6a2cce5e101edb3b85f35e9 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_bd238c79f6a2cce5e101edb3b85f35e9.addTo(map_a48ba6f6796ce7c8b19360a795349b64);
#
#
#             var feature_group_sub_group_d787959db57b3671929f471e575f6060 = L.featureGroup.subGroup(
#                 feature_group_bd238c79f6a2cce5e101edb3b85f35e9
#             );
#
#
#             var marker_4155f47429c84ad3376cda02ffe269a2 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_d787959db57b3671929f471e575f6060);
#
#
#         var popup_a995dc2f95e95b176fb7b096a85740c5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ea1ee97131183cbce23edb4ca2be423c = $(`&lt;div id=&quot;html_ea1ee97131183cbce23edb4ca2be423c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_a995dc2f95e95b176fb7b096a85740c5.setContent(html_ea1ee97131183cbce23edb4ca2be423c);
#
#
#
#         marker_4155f47429c84ad3376cda02ffe269a2.bindPopup(popup_a995dc2f95e95b176fb7b096a85740c5)
#         ;
#
#
#
#
#             var marker_741647db9825ccf8b9ddaa628b073185 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_d787959db57b3671929f471e575f6060);
#
#
#         var popup_d8af26f9f9c4b3fbf575c6ab2d58a24d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d57947991b2aea5b8c6fb51801246738 = $(`&lt;div id=&quot;html_d57947991b2aea5b8c6fb51801246738&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_d8af26f9f9c4b3fbf575c6ab2d58a24d.setContent(html_d57947991b2aea5b8c6fb51801246738);
#
#
#
#         marker_741647db9825ccf8b9ddaa628b073185.bindPopup(popup_d8af26f9f9c4b3fbf575c6ab2d58a24d)
#         ;
#
#
#
#
#             var marker_acac47a533b061080cc24da7e62705f8 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_d787959db57b3671929f471e575f6060);
#
#
#         var popup_39b935fc55b4d56458bb8dd5f37d2dec = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_af5edc1d5530de27effacb14753b1239 = $(`&lt;div id=&quot;html_af5edc1d5530de27effacb14753b1239&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_39b935fc55b4d56458bb8dd5f37d2dec.setContent(html_af5edc1d5530de27effacb14753b1239);
#
#
#
#         marker_acac47a533b061080cc24da7e62705f8.bindPopup(popup_39b935fc55b4d56458bb8dd5f37d2dec)
#         ;
#
#
#
#
#             var marker_6ffaf66a9bc56c72415a7612e8076b7c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_d787959db57b3671929f471e575f6060);
#
#
#         var popup_c3826c06c84dc547b3c71678cf4c22df = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_603f8fdf3f5c1493ab4fdc057ba65b5e = $(`&lt;div id=&quot;html_603f8fdf3f5c1493ab4fdc057ba65b5e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_c3826c06c84dc547b3c71678cf4c22df.setContent(html_603f8fdf3f5c1493ab4fdc057ba65b5e);
#
#
#
#         marker_
