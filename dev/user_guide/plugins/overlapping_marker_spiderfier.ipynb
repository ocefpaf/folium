# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4335e915d929881bad41d46028fd7d76 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4335e915d929881bad41d46028fd7d76&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4335e915d929881bad41d46028fd7d76 = L.map(
#                 &quot;map_4335e915d929881bad41d46028fd7d76&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_36a5e29725fc9eae4df557da8e65f0b2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_36a5e29725fc9eae4df557da8e65f0b2.addTo(map_4335e915d929881bad41d46028fd7d76);
#
#
#             var marker_39179fcd07f75e6953367d1237bbf723 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_4335e915d929881bad41d46028fd7d76);
#
#
#         var popup_9dcbef67cc8adc495191ae2bc45ffa24 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0e71cc587df9a4878d0d7fd7efff30f8 = $(`&lt;div id=&quot;html_0e71cc587df9a4878d0d7fd7efff30f8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_9dcbef67cc8adc495191ae2bc45ffa24.setContent(html_0e71cc587df9a4878d0d7fd7efff30f8);
#
#
#
#         marker_39179fcd07f75e6953367d1237bbf723.bindPopup(popup_9dcbef67cc8adc495191ae2bc45ffa24)
#         ;
#
#
#
#
#             var marker_55a352876d0895584d6ee84ddaa8208d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_4335e915d929881bad41d46028fd7d76);
#
#
#         var popup_00264531fbb93bd7753f0e488799d040 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b03ca43197b45d8d144837b0a44b0b1c = $(`&lt;div id=&quot;html_b03ca43197b45d8d144837b0a44b0b1c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_00264531fbb93bd7753f0e488799d040.setContent(html_b03ca43197b45d8d144837b0a44b0b1c);
#
#
#
#         marker_55a352876d0895584d6ee84ddaa8208d.bindPopup(popup_00264531fbb93bd7753f0e488799d040)
#         ;
#
#
#
#
#             var marker_c4a078c1d7c9e0e70485f26cff618373 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_4335e915d929881bad41d46028fd7d76);
#
#
#         var popup_7f5dc650ee3be9c608874a1dfba47c25 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_355f58d136a6d2418452e7faf59a82ac = $(`&lt;div id=&quot;html_355f58d136a6d2418452e7faf59a82ac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_7f5dc650ee3be9c608874a1dfba47c25.setContent(html_355f58d136a6d2418452e7faf59a82ac);
#
#
#
#         marker_c4a078c1d7c9e0e70485f26cff618373.bindPopup(popup_7f5dc650ee3be9c608874a1dfba47c25)
#         ;
#
#
#
#
#             var marker_7a29b9e5288441b04105abdcff42b696 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_4335e915d929881bad41d46028fd7d76);
#
#
#         var popup_f4d5f0e81dfa48cae2cb1bd18e52dc5d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1b75194a3f560c8a719d3db29d3a56e8 = $(`&lt;div id=&quot;html_1b75194a3f560c8a719d3db29d3a56e8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_f4d5f0e81dfa48cae2cb1bd18e52dc5d.setContent(html_1b75194a3f560c8a719d3db29d3a56e8);
#
#
#
#         marker_7a29b9e5288441b04105abdcff42b696.bindPopup(popup_f4d5f0e81dfa48cae2cb1bd18e52dc5d)
#         ;
#
#
#
#
#             var marker_8f264fa0ecff49a5a807f92fecf9cef5 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_4335e915d929881bad41d46028fd7d76);
#
#
#         var popup_0441fbcbf41a77c7c175fd0f2e32c68d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_907dadc0a50cb8a6aaa58d745ed20172 = $(`&lt;div id=&quot;html_907dadc0a50cb8a6aaa58d745ed20172&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_0441fbcbf41a77c7c175fd0f2e32c68d.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6424e5407edf01ef2b229c4aeae698ea {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6424e5407edf01ef2b229c4aeae698ea&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6424e5407edf01ef2b229c4aeae698ea = L.map(
#                 &quot;map_6424e5407edf01ef2b229c4aeae698ea&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_10d7b1e31a40cb137c4d15231cfab8a2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_10d7b1e31a40cb137c4d15231cfab8a2.addTo(map_6424e5407edf01ef2b229c4aeae698ea);
#
#
#             var feature_group_53ba20c9e1856546255676edef269646 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_127c055d5b619ba588a5fdb05b7b50cb = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_53ba20c9e1856546255676edef269646);
#
#
#         var popup_175b854fbfa38db2d60077a7ca53d0ac = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4e8159273f47b0ee82eac759d13e0888 = $(`&lt;div id=&quot;html_4e8159273f47b0ee82eac759d13e0888&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_175b854fbfa38db2d60077a7ca53d0ac.setContent(html_4e8159273f47b0ee82eac759d13e0888);
#
#
#
#         marker_127c055d5b619ba588a5fdb05b7b50cb.bindPopup(popup_175b854fbfa38db2d60077a7ca53d0ac)
#         ;
#
#
#
#
#             var marker_aad9bdb8045459edc8046f58afc7170a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_53ba20c9e1856546255676edef269646);
#
#
#         var popup_7f8318d7b4d072e81bca072d400fc0ff = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cb7f8ae044b815512e8161d9dedc9280 = $(`&lt;div id=&quot;html_cb7f8ae044b815512e8161d9dedc9280&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_7f8318d7b4d072e81bca072d400fc0ff.setContent(html_cb7f8ae044b815512e8161d9dedc9280);
#
#
#
#         marker_aad9bdb8045459edc8046f58afc7170a.bindPopup(popup_7f8318d7b4d072e81bca072d400fc0ff)
#         ;
#
#
#
#
#             var marker_ba801fad3390ec35ac8f8a86afb052f5 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_53ba20c9e1856546255676edef269646);
#
#
#         var popup_8da660b992300f28831097ae460b3fa4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ec9deed775f455439e9bf8c410f6a28e = $(`&lt;div id=&quot;html_ec9deed775f455439e9bf8c410f6a28e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_8da660b992300f28831097ae460b3fa4.setContent(html_ec9deed775f455439e9bf8c410f6a28e);
#
#
#
#         marker_ba801fad3390ec35ac8f8a86afb052f5.bindPopup(popup_8da660b992300f28831097ae460b3fa4)
#         ;
#
#
#
#
#             var marker_4108f935c915f70b550ced27f801d418 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_53ba20c9e1856546255676edef269646);
#
#
#         var popup_0a0000dfcef2df1cea6016878bbd5e9d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_51baa3711490da7214890173b95ad9e1 = $(`&lt;div id=&quot;html_51baa3711490da7214890173b95ad9e1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_0a0000dfcef2df1cea6016878bbd5e9d.setContent(html_51baa3711490da7214890173b95ad9e1);
#
#
#
#         marker_4108f935c915f70b550ced27f801d418.bindPopup(popup_0a0000dfcef2df1cea6016878bbd5e9d)
#         ;
#
#
#
#
#             var marker_bec384663d4780b54fc6a35e1bd98ec7 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_53ba20c9e1856546255676edef269646);
#
#
#         var popup_3a30960254fc604101c8a9c406be2ee5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2397bb4e7425787eecb734f821a4816e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2397bb4e7425787eecb734f821a4816e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2397bb4e7425787eecb734f821a4816e = L.map(
#                 &quot;map_2397bb4e7425787eecb734f821a4816e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_583c4bfe29305e358a7bf38ff0bef77d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_583c4bfe29305e358a7bf38ff0bef77d.addTo(map_2397bb4e7425787eecb734f821a4816e);
#
#
#             var feature_group_d1e991148e2011f6ed3bee69eecfd62a = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_d1e991148e2011f6ed3bee69eecfd62a.addTo(map_2397bb4e7425787eecb734f821a4816e);
#
#
#             var feature_group_sub_group_646f64706f3a3fd937e7df39ed8e7e03 = L.featureGroup.subGroup(
#                 feature_group_d1e991148e2011f6ed3bee69eecfd62a
#             );
#
#
#             var marker_bbbcb344e6894280440f12dcf7e3ddd1 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_646f64706f3a3fd937e7df39ed8e7e03);
#
#
#         var popup_89802fd1eaa04e429dccdff9cdd63184 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b359cd4f318b3f8b1d7b4ecbfc6a36c5 = $(`&lt;div id=&quot;html_b359cd4f318b3f8b1d7b4ecbfc6a36c5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_89802fd1eaa04e429dccdff9cdd63184.setContent(html_b359cd4f318b3f8b1d7b4ecbfc6a36c5);
#
#
#
#         marker_bbbcb344e6894280440f12dcf7e3ddd1.bindPopup(popup_89802fd1eaa04e429dccdff9cdd63184)
#         ;
#
#
#
#
#             var marker_bf9401196bd495b18c5a5dbcb20873b6 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_646f64706f3a3fd937e7df39ed8e7e03);
#
#
#         var popup_1de6bf9bc291eff5710b759b8e985561 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_678eace4e75582ac49aa4132ad2015de = $(`&lt;div id=&quot;html_678eace4e75582ac49aa4132ad2015de&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_1de6bf9bc291eff5710b759b8e985561.setContent(html_678eace4e75582ac49aa4132ad2015de);
#
#
#
#         marker_bf9401196bd495b18c5a5dbcb20873b6.bindPopup(popup_1de6bf9bc291eff5710b759b8e985561)
#         ;
#
#
#
#
#             var marker_7a6efc4f802c90087ed1d6d2b1c71b3a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_646f64706f3a3fd937e7df39ed8e7e03);
#
#
#         var popup_5e97fbf0d9f08ea700e12ba6075989ee = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f1ef67eae0fccf3f4cb07c92c5af58c4 = $(`&lt;div id=&quot;html_f1ef67eae0fccf3f4cb07c92c5af58c4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_5e97fbf0d9f08ea700e12ba6075989ee.setContent(html_f1ef67eae0fccf3f4cb07c92c5af58c4);
#
#
#
#         marker_7a6efc4f802c90087ed1d6d2b1c71b3a.bindPopup(popup_5e97fbf0d9f08ea700e12ba6075989ee)
#         ;
#
#
#
#
#             var marker_0f3d3649dbf4e7e29c7fbf72733d613a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_646f64706f3a3fd937e7df39ed8e7e03);
#
#
#         var popup_c4a2dc3eb55050fa5fe131de7c4db1bf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d97b75bb9fd463411f900471b5dd11ab = $(`&lt;div id=&quot;html_d97b75bb9fd463411f900471b5dd11ab&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_c4a2dc3eb55050fa5fe131de7c4db1bf.setContent(html_d97b75bb9fd463411f900471b5dd11ab);
#
#
#
#         marker_
