# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a4caa08ab5bd43240b7f6595f59483b5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a4caa08ab5bd43240b7f6595f59483b5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a4caa08ab5bd43240b7f6595f59483b5 = L.map(
#                 &quot;map_a4caa08ab5bd43240b7f6595f59483b5&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8c79d57b30efb36141ef5496f136e6e3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8c79d57b30efb36141ef5496f136e6e3.addTo(map_a4caa08ab5bd43240b7f6595f59483b5);
#
#
#             var marker_73353d6c91f89abf751bc73fe2e8f530 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_a4caa08ab5bd43240b7f6595f59483b5);
#
#
#         var popup_201597ea42d5538598fb34aef91f9e63 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7593d24fc5a085e7f99646c0f6ae2ca9 = $(`&lt;div id=&quot;html_7593d24fc5a085e7f99646c0f6ae2ca9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_201597ea42d5538598fb34aef91f9e63.setContent(html_7593d24fc5a085e7f99646c0f6ae2ca9);
#
#
#
#         marker_73353d6c91f89abf751bc73fe2e8f530.bindPopup(popup_201597ea42d5538598fb34aef91f9e63)
#         ;
#
#
#
#
#             var marker_8581431a61c03dde5f39f770c135c0dc = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_a4caa08ab5bd43240b7f6595f59483b5);
#
#
#         var popup_475b2c5d76dc2aa0525fb31ef07e3ef0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b08b297a092193e84618337f52546f48 = $(`&lt;div id=&quot;html_b08b297a092193e84618337f52546f48&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_475b2c5d76dc2aa0525fb31ef07e3ef0.setContent(html_b08b297a092193e84618337f52546f48);
#
#
#
#         marker_8581431a61c03dde5f39f770c135c0dc.bindPopup(popup_475b2c5d76dc2aa0525fb31ef07e3ef0)
#         ;
#
#
#
#
#             var marker_c0a85e1d72e8035ce34ba19a3f44d2cd = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_a4caa08ab5bd43240b7f6595f59483b5);
#
#
#         var popup_813dc6deb2676cecc773531d97754947 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_61eeadc9ad89dcecb8749b7aebca410e = $(`&lt;div id=&quot;html_61eeadc9ad89dcecb8749b7aebca410e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_813dc6deb2676cecc773531d97754947.setContent(html_61eeadc9ad89dcecb8749b7aebca410e);
#
#
#
#         marker_c0a85e1d72e8035ce34ba19a3f44d2cd.bindPopup(popup_813dc6deb2676cecc773531d97754947)
#         ;
#
#
#
#
#             var marker_a0cce5ab1597f8f905e54db0d65f2bde = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_a4caa08ab5bd43240b7f6595f59483b5);
#
#
#         var popup_85505eec80d052b8b6bb0f8f10b4ea3f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f461e730da7cc41feb38d1c652d98749 = $(`&lt;div id=&quot;html_f461e730da7cc41feb38d1c652d98749&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_85505eec80d052b8b6bb0f8f10b4ea3f.setContent(html_f461e730da7cc41feb38d1c652d98749);
#
#
#
#         marker_a0cce5ab1597f8f905e54db0d65f2bde.bindPopup(popup_85505eec80d052b8b6bb0f8f10b4ea3f)
#         ;
#
#
#
#
#             var marker_d87475b9738c581e51da9abc62b9681e = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_a4caa08ab5bd43240b7f6595f59483b5);
#
#
#         var popup_ff0a93f794a181b49ef2218f681866c9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2208f7f1a5770e2f8980eeab28a8323d = $(`&lt;div id=&quot;html_2208f7f1a5770e2f8980eeab28a8323d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_ff0a93f794a181b49ef2218f681866c9.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cf83bb599a937cad071275453ff210aa {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cf83bb599a937cad071275453ff210aa&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cf83bb599a937cad071275453ff210aa = L.map(
#                 &quot;map_cf83bb599a937cad071275453ff210aa&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_66469c638274b8a7f1bfd6c3d41568ed = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_66469c638274b8a7f1bfd6c3d41568ed.addTo(map_cf83bb599a937cad071275453ff210aa);
#
#
#             var feature_group_9f566fb9a6b2a6153f9d3fe55f1d88da = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_7cac3e833fcd0907ec7b50c78ec2548b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_9f566fb9a6b2a6153f9d3fe55f1d88da);
#
#
#         var popup_8d69f852e8575f92ae3b7dd59d2cf0f1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ca848b739f9d15cfa528260596519dc4 = $(`&lt;div id=&quot;html_ca848b739f9d15cfa528260596519dc4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_8d69f852e8575f92ae3b7dd59d2cf0f1.setContent(html_ca848b739f9d15cfa528260596519dc4);
#
#
#
#         marker_7cac3e833fcd0907ec7b50c78ec2548b.bindPopup(popup_8d69f852e8575f92ae3b7dd59d2cf0f1)
#         ;
#
#
#
#
#             var marker_7f098eda73fa1700a24520c17481c04e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_9f566fb9a6b2a6153f9d3fe55f1d88da);
#
#
#         var popup_0533b88134d636abdf0fed3591a006e7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1849912a92cf5dcd9d58e6d4ddae9dee = $(`&lt;div id=&quot;html_1849912a92cf5dcd9d58e6d4ddae9dee&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_0533b88134d636abdf0fed3591a006e7.setContent(html_1849912a92cf5dcd9d58e6d4ddae9dee);
#
#
#
#         marker_7f098eda73fa1700a24520c17481c04e.bindPopup(popup_0533b88134d636abdf0fed3591a006e7)
#         ;
#
#
#
#
#             var marker_46a8a09cd7dfbe4cfabdb68712e16d8a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_9f566fb9a6b2a6153f9d3fe55f1d88da);
#
#
#         var popup_aa0b63922e1d439e6048531d1fb9de4a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fcb2a39f5c1c196f69e3ebc8940db837 = $(`&lt;div id=&quot;html_fcb2a39f5c1c196f69e3ebc8940db837&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_aa0b63922e1d439e6048531d1fb9de4a.setContent(html_fcb2a39f5c1c196f69e3ebc8940db837);
#
#
#
#         marker_46a8a09cd7dfbe4cfabdb68712e16d8a.bindPopup(popup_aa0b63922e1d439e6048531d1fb9de4a)
#         ;
#
#
#
#
#             var marker_fe4651911946d8fca3b1cd0c0913612d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_9f566fb9a6b2a6153f9d3fe55f1d88da);
#
#
#         var popup_21632bc3f08122162a0890d75b071220 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fa2e152c9d0ba85ce9c8a80ca2868fed = $(`&lt;div id=&quot;html_fa2e152c9d0ba85ce9c8a80ca2868fed&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_21632bc3f08122162a0890d75b071220.setContent(html_fa2e152c9d0ba85ce9c8a80ca2868fed);
#
#
#
#         marker_fe4651911946d8fca3b1cd0c0913612d.bindPopup(popup_21632bc3f08122162a0890d75b071220)
#         ;
#
#
#
#
#             var marker_a17d59ad5df826a735b1210cdd4bc6ec = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_9f566fb9a6b2a6153f9d3fe55f1d88da);
#
#
#         var popup_e21c4b9feacc2a7102d1bcc529a89190 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c89ca8d13e722a9a3d42ca3825311525 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c89ca8d13e722a9a3d42ca3825311525&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c89ca8d13e722a9a3d42ca3825311525 = L.map(
#                 &quot;map_c89ca8d13e722a9a3d42ca3825311525&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f91ab28c029b65d14b09cd9d64fcac60 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f91ab28c029b65d14b09cd9d64fcac60.addTo(map_c89ca8d13e722a9a3d42ca3825311525);
#
#
#             var feature_group_847e1aa631e131c519a2a297f7fcbc8a = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_847e1aa631e131c519a2a297f7fcbc8a.addTo(map_c89ca8d13e722a9a3d42ca3825311525);
#
#
#             var feature_group_sub_group_a36b3b48618dd25465f5052ba272fc96 = L.featureGroup.subGroup(
#                 feature_group_847e1aa631e131c519a2a297f7fcbc8a
#             );
#
#
#             var marker_afde708c4dee0e916ff4e60a52ddbfbd = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_a36b3b48618dd25465f5052ba272fc96);
#
#
#         var popup_4a5da76f2c4e6e521e302a219990e32d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_39601cfefb8d11317fca2f5f2069ac29 = $(`&lt;div id=&quot;html_39601cfefb8d11317fca2f5f2069ac29&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_4a5da76f2c4e6e521e302a219990e32d.setContent(html_39601cfefb8d11317fca2f5f2069ac29);
#
#
#
#         marker_afde708c4dee0e916ff4e60a52ddbfbd.bindPopup(popup_4a5da76f2c4e6e521e302a219990e32d)
#         ;
#
#
#
#
#             var marker_6ca94625dce43ebe655035be2b9ec06b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_a36b3b48618dd25465f5052ba272fc96);
#
#
#         var popup_e46038a2a348f4c32f7d08bcf063d401 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a959e49abd6617667efe184371c49761 = $(`&lt;div id=&quot;html_a959e49abd6617667efe184371c49761&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_e46038a2a348f4c32f7d08bcf063d401.setContent(html_a959e49abd6617667efe184371c49761);
#
#
#
#         marker_6ca94625dce43ebe655035be2b9ec06b.bindPopup(popup_e46038a2a348f4c32f7d08bcf063d401)
#         ;
#
#
#
#
#             var marker_36f791ceda15a47e4416299f93fc2cbd = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_a36b3b48618dd25465f5052ba272fc96);
#
#
#         var popup_80d71c58d62cca70bad28c147f46c7d1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1067d330e14ac0632da829201d4466f6 = $(`&lt;div id=&quot;html_1067d330e14ac0632da829201d4466f6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_80d71c58d62cca70bad28c147f46c7d1.setContent(html_1067d330e14ac0632da829201d4466f6);
#
#
#
#         marker_36f791ceda15a47e4416299f93fc2cbd.bindPopup(popup_80d71c58d62cca70bad28c147f46c7d1)
#         ;
#
#
#
#
#             var marker_9e4290295ecf201a6dfdbdda524ac317 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_a36b3b48618dd25465f5052ba272fc96);
#
#
#         var popup_ed94beebbfc17732919047e57badf9e2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a187e735a4f2782b577ea457656603fa = $(`&lt;div id=&quot;html_a187e735a4f2782b577ea457656603fa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_ed94beebbfc17732919047e57badf9e2.setContent(html_a187e735a4f2782b577ea457656603fa);
#
#
#
#         marker_
