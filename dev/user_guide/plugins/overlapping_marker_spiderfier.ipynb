# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_77a107f22167fbacd5491f61ea5f5a79 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_77a107f22167fbacd5491f61ea5f5a79&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_77a107f22167fbacd5491f61ea5f5a79 = L.map(
#                 &quot;map_77a107f22167fbacd5491f61ea5f5a79&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_40676302f31eba8572680473292ed759 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_40676302f31eba8572680473292ed759.addTo(map_77a107f22167fbacd5491f61ea5f5a79);
#
#
#             var marker_83c7f5bde7d65f23c67e6489c3897337 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_77a107f22167fbacd5491f61ea5f5a79);
#
#
#         var popup_39260e28cc5e9f412dfb05e5f9285f6b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b0f53f23bc43ac8a59368395d51abc99 = $(`&lt;div id=&quot;html_b0f53f23bc43ac8a59368395d51abc99&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_39260e28cc5e9f412dfb05e5f9285f6b.setContent(html_b0f53f23bc43ac8a59368395d51abc99);
#
#
#
#         marker_83c7f5bde7d65f23c67e6489c3897337.bindPopup(popup_39260e28cc5e9f412dfb05e5f9285f6b)
#         ;
#
#
#
#
#             var marker_747cc34c5a608da4a880b1dc4bb6cd96 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_77a107f22167fbacd5491f61ea5f5a79);
#
#
#         var popup_088e7897e69ae9b233d3b914ff4499c8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f00d3a8fab08240e8b7df5554b24ac0a = $(`&lt;div id=&quot;html_f00d3a8fab08240e8b7df5554b24ac0a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_088e7897e69ae9b233d3b914ff4499c8.setContent(html_f00d3a8fab08240e8b7df5554b24ac0a);
#
#
#
#         marker_747cc34c5a608da4a880b1dc4bb6cd96.bindPopup(popup_088e7897e69ae9b233d3b914ff4499c8)
#         ;
#
#
#
#
#             var marker_0ba5dd14c6c07920f8b9e73ad97c6ff3 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_77a107f22167fbacd5491f61ea5f5a79);
#
#
#         var popup_4a854da8a24336a08f68d70a45ce2580 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f6b2cd07b8e4a43289ff518d4fcc2bbc = $(`&lt;div id=&quot;html_f6b2cd07b8e4a43289ff518d4fcc2bbc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_4a854da8a24336a08f68d70a45ce2580.setContent(html_f6b2cd07b8e4a43289ff518d4fcc2bbc);
#
#
#
#         marker_0ba5dd14c6c07920f8b9e73ad97c6ff3.bindPopup(popup_4a854da8a24336a08f68d70a45ce2580)
#         ;
#
#
#
#
#             var marker_67c98358586bc360150dd29555a3584a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_77a107f22167fbacd5491f61ea5f5a79);
#
#
#         var popup_ba1883f39cceef3d20217e5888a7cba3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_42fb9f286608b70503f87a8ad36cf09d = $(`&lt;div id=&quot;html_42fb9f286608b70503f87a8ad36cf09d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_ba1883f39cceef3d20217e5888a7cba3.setContent(html_42fb9f286608b70503f87a8ad36cf09d);
#
#
#
#         marker_67c98358586bc360150dd29555a3584a.bindPopup(popup_ba1883f39cceef3d20217e5888a7cba3)
#         ;
#
#
#
#
#             var marker_f415bef33771f1b6f6c408c301a062d4 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_77a107f22167fbacd5491f61ea5f5a79);
#
#
#         var popup_1eba1e07f8bdb6ee0c70ab34f4900fea = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_352f82cb0b603dfd897372fce11426e4 = $(`&lt;div id=&quot;html_352f82cb0b603dfd897372fce11426e4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_1eba1e07f8bdb6ee0c70ab34f4900fea.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e53785d36b3fb9955dbd3a6e98e84f77 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e53785d36b3fb9955dbd3a6e98e84f77&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e53785d36b3fb9955dbd3a6e98e84f77 = L.map(
#                 &quot;map_e53785d36b3fb9955dbd3a6e98e84f77&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3bd6bc1dc74a3d91c1fee8c2f6980d3b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3bd6bc1dc74a3d91c1fee8c2f6980d3b.addTo(map_e53785d36b3fb9955dbd3a6e98e84f77);
#
#
#             var feature_group_d077d745fe0b4104b7e12e2cbb114a9d = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_17a84dd006f352add1a5049665b51bc4 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_d077d745fe0b4104b7e12e2cbb114a9d);
#
#
#         var popup_9a839258fab3d09d3c9c662925230126 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2d9fa47b112c3569f25252ed091d7484 = $(`&lt;div id=&quot;html_2d9fa47b112c3569f25252ed091d7484&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_9a839258fab3d09d3c9c662925230126.setContent(html_2d9fa47b112c3569f25252ed091d7484);
#
#
#
#         marker_17a84dd006f352add1a5049665b51bc4.bindPopup(popup_9a839258fab3d09d3c9c662925230126)
#         ;
#
#
#
#
#             var marker_efa12f3871b07890a9478eb036da80d1 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_d077d745fe0b4104b7e12e2cbb114a9d);
#
#
#         var popup_ad781883faf0f3c226395328181372d2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a9909306e751d7964e1b29b7699278b0 = $(`&lt;div id=&quot;html_a9909306e751d7964e1b29b7699278b0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_ad781883faf0f3c226395328181372d2.setContent(html_a9909306e751d7964e1b29b7699278b0);
#
#
#
#         marker_efa12f3871b07890a9478eb036da80d1.bindPopup(popup_ad781883faf0f3c226395328181372d2)
#         ;
#
#
#
#
#             var marker_0c6a912d06b9dc1b9c5a1044aca3378b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_d077d745fe0b4104b7e12e2cbb114a9d);
#
#
#         var popup_eb0b379b53b18abd8b74da541bcdbdde = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5f164f53c86148eb1f44d299118b39bd = $(`&lt;div id=&quot;html_5f164f53c86148eb1f44d299118b39bd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_eb0b379b53b18abd8b74da541bcdbdde.setContent(html_5f164f53c86148eb1f44d299118b39bd);
#
#
#
#         marker_0c6a912d06b9dc1b9c5a1044aca3378b.bindPopup(popup_eb0b379b53b18abd8b74da541bcdbdde)
#         ;
#
#
#
#
#             var marker_f63091757ecda6484228ef942394594e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_d077d745fe0b4104b7e12e2cbb114a9d);
#
#
#         var popup_972811b8c86d5e8817438817f3048402 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_360faec7705dd3160a902aa54bb538f5 = $(`&lt;div id=&quot;html_360faec7705dd3160a902aa54bb538f5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_972811b8c86d5e8817438817f3048402.setContent(html_360faec7705dd3160a902aa54bb538f5);
#
#
#
#         marker_f63091757ecda6484228ef942394594e.bindPopup(popup_972811b8c86d5e8817438817f3048402)
#         ;
#
#
#
#
#             var marker_8166db7da1a660a5c5433e910c62bdf3 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_d077d745fe0b4104b7e12e2cbb114a9d);
#
#
#         var popup_e23afe4d9a91ea547647eee2479c87e0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_994fc75a33f5ae069fa37ea5d8ba8d6a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_994fc75a33f5ae069fa37ea5d8ba8d6a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_994fc75a33f5ae069fa37ea5d8ba8d6a = L.map(
#                 &quot;map_994fc75a33f5ae069fa37ea5d8ba8d6a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_15862bced2e8016486f40830129d9dcf = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_15862bced2e8016486f40830129d9dcf.addTo(map_994fc75a33f5ae069fa37ea5d8ba8d6a);
#
#
#             var feature_group_a847d1b42aa6d1caea6fb1be09c673d7 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_a847d1b42aa6d1caea6fb1be09c673d7.addTo(map_994fc75a33f5ae069fa37ea5d8ba8d6a);
#
#
#             var feature_group_sub_group_dede59202c58ef2f3d651ee802bdec69 = L.featureGroup.subGroup(
#                 feature_group_a847d1b42aa6d1caea6fb1be09c673d7
#             );
#
#
#             var marker_b768ee8f7b8c158f383410a116815774 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_dede59202c58ef2f3d651ee802bdec69);
#
#
#         var popup_1ff772d3f5b4330a4fa4f510eea2935e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_607e51bcd6580e897844a69cddebb102 = $(`&lt;div id=&quot;html_607e51bcd6580e897844a69cddebb102&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_1ff772d3f5b4330a4fa4f510eea2935e.setContent(html_607e51bcd6580e897844a69cddebb102);
#
#
#
#         marker_b768ee8f7b8c158f383410a116815774.bindPopup(popup_1ff772d3f5b4330a4fa4f510eea2935e)
#         ;
#
#
#
#
#             var marker_a392f4b4db4a7ea8fa9c7e11e97f3d5d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_dede59202c58ef2f3d651ee802bdec69);
#
#
#         var popup_35c70b35a6dc5836dc14b4346583c980 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_18d1acb293838d563bdf35966d1d3b89 = $(`&lt;div id=&quot;html_18d1acb293838d563bdf35966d1d3b89&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_35c70b35a6dc5836dc14b4346583c980.setContent(html_18d1acb293838d563bdf35966d1d3b89);
#
#
#
#         marker_a392f4b4db4a7ea8fa9c7e11e97f3d5d.bindPopup(popup_35c70b35a6dc5836dc14b4346583c980)
#         ;
#
#
#
#
#             var marker_20ae83646f09720b9ad43210dd51af27 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_dede59202c58ef2f3d651ee802bdec69);
#
#
#         var popup_14c24af7905a91f2851e54b4cf291f40 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e6108e74e38926a3c9dd0fd284df241e = $(`&lt;div id=&quot;html_e6108e74e38926a3c9dd0fd284df241e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_14c24af7905a91f2851e54b4cf291f40.setContent(html_e6108e74e38926a3c9dd0fd284df241e);
#
#
#
#         marker_20ae83646f09720b9ad43210dd51af27.bindPopup(popup_14c24af7905a91f2851e54b4cf291f40)
#         ;
#
#
#
#
#             var marker_89f86a0f86e3041343af939531dbe5ce = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_dede59202c58ef2f3d651ee802bdec69);
#
#
#         var popup_bdfd87fb2a2b4bf2a9432312383bfef3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ccc4b7844f9dca383caa758ed356638a = $(`&lt;div id=&quot;html_ccc4b7844f9dca383caa758ed356638a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_bdfd87fb2a2b4bf2a9432312383bfef3.setContent(html_ccc4b7844f9dca383caa758ed356638a);
#
#
#
#         marker_
