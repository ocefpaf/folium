# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_63a8c9b36b6764ea71fe1e2b17024f11 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_63a8c9b36b6764ea71fe1e2b17024f11&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_63a8c9b36b6764ea71fe1e2b17024f11 = L.map(
#                 &quot;map_63a8c9b36b6764ea71fe1e2b17024f11&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_defe0078ac1b27fd24cd3caaf6145173 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_defe0078ac1b27fd24cd3caaf6145173.addTo(map_63a8c9b36b6764ea71fe1e2b17024f11);
#
#
#             var marker_dc21feba43137114e0dfdfe97e79dd60 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_63a8c9b36b6764ea71fe1e2b17024f11);
#
#
#         var popup_0deca08e1f342b0e64627daa203b5836 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fa94dbf09ab3abdd886f61df83c76244 = $(`&lt;div id=&quot;html_fa94dbf09ab3abdd886f61df83c76244&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_0deca08e1f342b0e64627daa203b5836.setContent(html_fa94dbf09ab3abdd886f61df83c76244);
#
#
#
#         marker_dc21feba43137114e0dfdfe97e79dd60.bindPopup(popup_0deca08e1f342b0e64627daa203b5836)
#         ;
#
#
#
#
#             var marker_a845d722f658ad0b0570519aef813948 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_63a8c9b36b6764ea71fe1e2b17024f11);
#
#
#         var popup_c066f16f0c5c9267f2466c98b4adc027 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_809cb7658aa19a48fafaa19a93e0baef = $(`&lt;div id=&quot;html_809cb7658aa19a48fafaa19a93e0baef&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_c066f16f0c5c9267f2466c98b4adc027.setContent(html_809cb7658aa19a48fafaa19a93e0baef);
#
#
#
#         marker_a845d722f658ad0b0570519aef813948.bindPopup(popup_c066f16f0c5c9267f2466c98b4adc027)
#         ;
#
#
#
#
#             var marker_05756774c1437c7c37835b4477e3d9e8 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_63a8c9b36b6764ea71fe1e2b17024f11);
#
#
#         var popup_21165c0fccd793725d3f226b536a294a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b57bde5fb0c5e92f4aa1d5eccba5c047 = $(`&lt;div id=&quot;html_b57bde5fb0c5e92f4aa1d5eccba5c047&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_21165c0fccd793725d3f226b536a294a.setContent(html_b57bde5fb0c5e92f4aa1d5eccba5c047);
#
#
#
#         marker_05756774c1437c7c37835b4477e3d9e8.bindPopup(popup_21165c0fccd793725d3f226b536a294a)
#         ;
#
#
#
#
#             var marker_8957cec5f743b763eddd770b8de6ab7e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_63a8c9b36b6764ea71fe1e2b17024f11);
#
#
#         var popup_492a299895b0a253d015cc236e469aea = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_60aa865f5e999a4b127ef5f562f23cca = $(`&lt;div id=&quot;html_60aa865f5e999a4b127ef5f562f23cca&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_492a299895b0a253d015cc236e469aea.setContent(html_60aa865f5e999a4b127ef5f562f23cca);
#
#
#
#         marker_8957cec5f743b763eddd770b8de6ab7e.bindPopup(popup_492a299895b0a253d015cc236e469aea)
#         ;
#
#
#
#
#             var marker_dae8fbf062ce0f085cc88a601964bf4a = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_63a8c9b36b6764ea71fe1e2b17024f11);
#
#
#         var popup_aa423f8ff5f290f9066b237ebd1eeb4d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ab4789e86da2a83f9a2308b9f4c6d762 = $(`&lt;div id=&quot;html_ab4789e86da2a83f9a2308b9f4c6d762&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_aa423f8ff5f290f9066b237ebd1eeb4d.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1ee67122f21ef1983cd482b84051053e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1ee67122f21ef1983cd482b84051053e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1ee67122f21ef1983cd482b84051053e = L.map(
#                 &quot;map_1ee67122f21ef1983cd482b84051053e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d6b5efdb3bbf921b1d357f74b9a6e59d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d6b5efdb3bbf921b1d357f74b9a6e59d.addTo(map_1ee67122f21ef1983cd482b84051053e);
#
#
#             var feature_group_9bfa7577184a14be259e0c3ac063c883 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_0a9b6ef3feb16e056ef827a615ccb11c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_9bfa7577184a14be259e0c3ac063c883);
#
#
#         var popup_4e916833ff5ea16dd481f57aa7b3be66 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f5a6f08d2300defbf321adbe2622f563 = $(`&lt;div id=&quot;html_f5a6f08d2300defbf321adbe2622f563&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_4e916833ff5ea16dd481f57aa7b3be66.setContent(html_f5a6f08d2300defbf321adbe2622f563);
#
#
#
#         marker_0a9b6ef3feb16e056ef827a615ccb11c.bindPopup(popup_4e916833ff5ea16dd481f57aa7b3be66)
#         ;
#
#
#
#
#             var marker_143f552367e03eec072757d84468bd44 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_9bfa7577184a14be259e0c3ac063c883);
#
#
#         var popup_15b9b6653da5b2c1fb27c7a3a7700e8b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fb0f73639c9f9530ecc1f11fc31cc31f = $(`&lt;div id=&quot;html_fb0f73639c9f9530ecc1f11fc31cc31f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_15b9b6653da5b2c1fb27c7a3a7700e8b.setContent(html_fb0f73639c9f9530ecc1f11fc31cc31f);
#
#
#
#         marker_143f552367e03eec072757d84468bd44.bindPopup(popup_15b9b6653da5b2c1fb27c7a3a7700e8b)
#         ;
#
#
#
#
#             var marker_06a52b7c4678dc003663551c3ee52286 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_9bfa7577184a14be259e0c3ac063c883);
#
#
#         var popup_57f9b2e577e2efdae5265ae6a5ad2b5d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8615434b2454a417d0eff5d19794bb33 = $(`&lt;div id=&quot;html_8615434b2454a417d0eff5d19794bb33&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_57f9b2e577e2efdae5265ae6a5ad2b5d.setContent(html_8615434b2454a417d0eff5d19794bb33);
#
#
#
#         marker_06a52b7c4678dc003663551c3ee52286.bindPopup(popup_57f9b2e577e2efdae5265ae6a5ad2b5d)
#         ;
#
#
#
#
#             var marker_4797f706c6c755937ec2896221538f08 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_9bfa7577184a14be259e0c3ac063c883);
#
#
#         var popup_5abb5c1028d4aa21a00a39434370ae4f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8b6db4b3748f378ba6e4eb4ada01081e = $(`&lt;div id=&quot;html_8b6db4b3748f378ba6e4eb4ada01081e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_5abb5c1028d4aa21a00a39434370ae4f.setContent(html_8b6db4b3748f378ba6e4eb4ada01081e);
#
#
#
#         marker_4797f706c6c755937ec2896221538f08.bindPopup(popup_5abb5c1028d4aa21a00a39434370ae4f)
#         ;
#
#
#
#
#             var marker_f772ec022b28412939f49101add6b127 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_9bfa7577184a14be259e0c3ac063c883);
#
#
#         var popup_717ef512f8dfb87fb0bc01fc2e4b2820 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_984df2f2f3bb800dd4f32466c538e5f7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_984df2f2f3bb800dd4f32466c538e5f7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_984df2f2f3bb800dd4f32466c538e5f7 = L.map(
#                 &quot;map_984df2f2f3bb800dd4f32466c538e5f7&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_489998b194a58a74b898d43c06bdfb6e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_489998b194a58a74b898d43c06bdfb6e.addTo(map_984df2f2f3bb800dd4f32466c538e5f7);
#
#
#             var feature_group_476c7be712caacf7b4e89173c3cfe808 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_476c7be712caacf7b4e89173c3cfe808.addTo(map_984df2f2f3bb800dd4f32466c538e5f7);
#
#
#             var feature_group_sub_group_fb1a025cc190119e183aa94476e39a48 = L.featureGroup.subGroup(
#                 feature_group_476c7be712caacf7b4e89173c3cfe808
#             );
#
#
#             var marker_15fe696ec234d546095d5e5f19118566 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_fb1a025cc190119e183aa94476e39a48);
#
#
#         var popup_bd3aea7be564d31bf55b2b2c11232efa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c17e1e05e2d980ef43584ce985dacf8b = $(`&lt;div id=&quot;html_c17e1e05e2d980ef43584ce985dacf8b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_bd3aea7be564d31bf55b2b2c11232efa.setContent(html_c17e1e05e2d980ef43584ce985dacf8b);
#
#
#
#         marker_15fe696ec234d546095d5e5f19118566.bindPopup(popup_bd3aea7be564d31bf55b2b2c11232efa)
#         ;
#
#
#
#
#             var marker_9e2b3f801081acab3cc6291f451e5d11 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_fb1a025cc190119e183aa94476e39a48);
#
#
#         var popup_4a99068888e4d3795d63e012a526b1ea = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_11eeb324519291d7a867849aef7cff6f = $(`&lt;div id=&quot;html_11eeb324519291d7a867849aef7cff6f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_4a99068888e4d3795d63e012a526b1ea.setContent(html_11eeb324519291d7a867849aef7cff6f);
#
#
#
#         marker_9e2b3f801081acab3cc6291f451e5d11.bindPopup(popup_4a99068888e4d3795d63e012a526b1ea)
#         ;
#
#
#
#
#             var marker_3a43730c2f215549bbbfd685a68ff245 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_fb1a025cc190119e183aa94476e39a48);
#
#
#         var popup_f408b53ea1a7454b97a4bddade27ac5f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0ba1d4b8939c05e582887f90ac53050c = $(`&lt;div id=&quot;html_0ba1d4b8939c05e582887f90ac53050c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_f408b53ea1a7454b97a4bddade27ac5f.setContent(html_0ba1d4b8939c05e582887f90ac53050c);
#
#
#
#         marker_3a43730c2f215549bbbfd685a68ff245.bindPopup(popup_f408b53ea1a7454b97a4bddade27ac5f)
#         ;
#
#
#
#
#             var marker_f0dd145da2c174442f70085c3afcf819 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_fb1a025cc190119e183aa94476e39a48);
#
#
#         var popup_44f35fcec5f49c26ba1c1d83ece32caf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_60964653539be588ea8e24f42a8a830c = $(`&lt;div id=&quot;html_60964653539be588ea8e24f42a8a830c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_44f35fcec5f49c26ba1c1d83ece32caf.setContent(html_60964653539be588ea8e24f42a8a830c);
#
#
#
#         marker_
