# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e6eabe75e65a4e1f729645db894ed7e6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e6eabe75e65a4e1f729645db894ed7e6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e6eabe75e65a4e1f729645db894ed7e6 = L.map(
#                 &quot;map_e6eabe75e65a4e1f729645db894ed7e6&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_afe9cf8956ccbb993a4104986f46bb92 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_afe9cf8956ccbb993a4104986f46bb92.addTo(map_e6eabe75e65a4e1f729645db894ed7e6);
#
#
#             var marker_2f98e145506b386d49b32aa704f0c93e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_e6eabe75e65a4e1f729645db894ed7e6);
#
#
#         var popup_278a8cd783368c8076830fee2911980e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bac3ef01f7177a942ddfca84c79735ab = $(`&lt;div id=&quot;html_bac3ef01f7177a942ddfca84c79735ab&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_278a8cd783368c8076830fee2911980e.setContent(html_bac3ef01f7177a942ddfca84c79735ab);
#
#
#
#         marker_2f98e145506b386d49b32aa704f0c93e.bindPopup(popup_278a8cd783368c8076830fee2911980e)
#         ;
#
#
#
#
#             var marker_1d05934b10c044412617b58224ab0b24 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_e6eabe75e65a4e1f729645db894ed7e6);
#
#
#         var popup_66604c05686cb9e948e6f8e0c8aefcd1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8d1d70d428d045adcd19a0e705b78580 = $(`&lt;div id=&quot;html_8d1d70d428d045adcd19a0e705b78580&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_66604c05686cb9e948e6f8e0c8aefcd1.setContent(html_8d1d70d428d045adcd19a0e705b78580);
#
#
#
#         marker_1d05934b10c044412617b58224ab0b24.bindPopup(popup_66604c05686cb9e948e6f8e0c8aefcd1)
#         ;
#
#
#
#
#             var marker_62bbc0065155f9622fa160e3b05c4d08 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_e6eabe75e65a4e1f729645db894ed7e6);
#
#
#         var popup_817f92eae2eee98f931223668734fd48 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1ed12f5e09a374b64bbd8012cf50393b = $(`&lt;div id=&quot;html_1ed12f5e09a374b64bbd8012cf50393b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_817f92eae2eee98f931223668734fd48.setContent(html_1ed12f5e09a374b64bbd8012cf50393b);
#
#
#
#         marker_62bbc0065155f9622fa160e3b05c4d08.bindPopup(popup_817f92eae2eee98f931223668734fd48)
#         ;
#
#
#
#
#             var marker_fa82af13b4c6db70501e633315c993a5 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_e6eabe75e65a4e1f729645db894ed7e6);
#
#
#         var popup_dbb6c35f1295cb770eaf25de4fc01751 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6d4fbf9c45986f7a95e625979d101eb3 = $(`&lt;div id=&quot;html_6d4fbf9c45986f7a95e625979d101eb3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_dbb6c35f1295cb770eaf25de4fc01751.setContent(html_6d4fbf9c45986f7a95e625979d101eb3);
#
#
#
#         marker_fa82af13b4c6db70501e633315c993a5.bindPopup(popup_dbb6c35f1295cb770eaf25de4fc01751)
#         ;
#
#
#
#
#             var marker_7716ac77b84cd581be0a5bda28aaa2ad = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_e6eabe75e65a4e1f729645db894ed7e6);
#
#
#         var popup_2b173588fb26dc6918cea195893c52f8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7d60bd5f09652e66f65f03d8ee25fcdb = $(`&lt;div id=&quot;html_7d60bd5f09652e66f65f03d8ee25fcdb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_2b173588fb26dc6918cea195893c52f8.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ea35e8b2d3dde503e1921b0c6aad234b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ea35e8b2d3dde503e1921b0c6aad234b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ea35e8b2d3dde503e1921b0c6aad234b = L.map(
#                 &quot;map_ea35e8b2d3dde503e1921b0c6aad234b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_784bdeaee3a0f02cec292d9735a96f04 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_784bdeaee3a0f02cec292d9735a96f04.addTo(map_ea35e8b2d3dde503e1921b0c6aad234b);
#
#
#             var feature_group_9146ea63e50bada106526126f3463b9c = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_75c79bbc2078465e932303cdf630a67c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_9146ea63e50bada106526126f3463b9c);
#
#
#         var popup_2aa4a0c525213595d350281c4ced6417 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ba684e97d7a0ce16af83ea217b7db369 = $(`&lt;div id=&quot;html_ba684e97d7a0ce16af83ea217b7db369&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_2aa4a0c525213595d350281c4ced6417.setContent(html_ba684e97d7a0ce16af83ea217b7db369);
#
#
#
#         marker_75c79bbc2078465e932303cdf630a67c.bindPopup(popup_2aa4a0c525213595d350281c4ced6417)
#         ;
#
#
#
#
#             var marker_3e58a10d11a4fd22b5fce71bf3146cc2 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_9146ea63e50bada106526126f3463b9c);
#
#
#         var popup_f19dc62fbe9cd71a84335a8acfa6e764 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_834dde6262edb73711993824fb46705d = $(`&lt;div id=&quot;html_834dde6262edb73711993824fb46705d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_f19dc62fbe9cd71a84335a8acfa6e764.setContent(html_834dde6262edb73711993824fb46705d);
#
#
#
#         marker_3e58a10d11a4fd22b5fce71bf3146cc2.bindPopup(popup_f19dc62fbe9cd71a84335a8acfa6e764)
#         ;
#
#
#
#
#             var marker_e69e325edd9e2b5942d7ee037f279c46 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_9146ea63e50bada106526126f3463b9c);
#
#
#         var popup_fd480ea3d2d07b54cf6b8a6928334cd7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6e76c4d4814a0aa543a936b90d7f3544 = $(`&lt;div id=&quot;html_6e76c4d4814a0aa543a936b90d7f3544&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_fd480ea3d2d07b54cf6b8a6928334cd7.setContent(html_6e76c4d4814a0aa543a936b90d7f3544);
#
#
#
#         marker_e69e325edd9e2b5942d7ee037f279c46.bindPopup(popup_fd480ea3d2d07b54cf6b8a6928334cd7)
#         ;
#
#
#
#
#             var marker_16ba1ff79cef10b8ae3d394ad73a7afd = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_9146ea63e50bada106526126f3463b9c);
#
#
#         var popup_db92be2fbc4703463f1c74a2f4f2c0db = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_de7d7de006e0710285032ee3b7bd5f7c = $(`&lt;div id=&quot;html_de7d7de006e0710285032ee3b7bd5f7c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_db92be2fbc4703463f1c74a2f4f2c0db.setContent(html_de7d7de006e0710285032ee3b7bd5f7c);
#
#
#
#         marker_16ba1ff79cef10b8ae3d394ad73a7afd.bindPopup(popup_db92be2fbc4703463f1c74a2f4f2c0db)
#         ;
#
#
#
#
#             var marker_418d836f67c271bd5e06bd0e2d94f09c = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_9146ea63e50bada106526126f3463b9c);
#
#
#         var popup_e8ee1e4dfbbadb275cef73d8f22075ed = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6996c5dc468445016f9dca600b747328 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6996c5dc468445016f9dca600b747328&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6996c5dc468445016f9dca600b747328 = L.map(
#                 &quot;map_6996c5dc468445016f9dca600b747328&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e81cfe065d367c4e8e2809c5f01aa2a4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e81cfe065d367c4e8e2809c5f01aa2a4.addTo(map_6996c5dc468445016f9dca600b747328);
#
#
#             var feature_group_d2d755a6c23c7c5d8e7565bddfdb5ff9 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_d2d755a6c23c7c5d8e7565bddfdb5ff9.addTo(map_6996c5dc468445016f9dca600b747328);
#
#
#             var feature_group_sub_group_4cd38ae936f4e80d46929af8f706b998 = L.featureGroup.subGroup(
#                 feature_group_d2d755a6c23c7c5d8e7565bddfdb5ff9
#             );
#
#
#             var marker_1b9697cda0ffd8de3f4daff0677229c6 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_4cd38ae936f4e80d46929af8f706b998);
#
#
#         var popup_8643d35ddaa4803eb831f85ee949d0d8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_77c0ec45fc44bea5444f29f6e0731699 = $(`&lt;div id=&quot;html_77c0ec45fc44bea5444f29f6e0731699&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_8643d35ddaa4803eb831f85ee949d0d8.setContent(html_77c0ec45fc44bea5444f29f6e0731699);
#
#
#
#         marker_1b9697cda0ffd8de3f4daff0677229c6.bindPopup(popup_8643d35ddaa4803eb831f85ee949d0d8)
#         ;
#
#
#
#
#             var marker_3ad79cf325841c0a622688944402e942 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_4cd38ae936f4e80d46929af8f706b998);
#
#
#         var popup_458b850c18a9e851bd12b23c224cee29 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f51f5b9900adb54d2f81b071252eca4a = $(`&lt;div id=&quot;html_f51f5b9900adb54d2f81b071252eca4a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_458b850c18a9e851bd12b23c224cee29.setContent(html_f51f5b9900adb54d2f81b071252eca4a);
#
#
#
#         marker_3ad79cf325841c0a622688944402e942.bindPopup(popup_458b850c18a9e851bd12b23c224cee29)
#         ;
#
#
#
#
#             var marker_fdaf139c1231e8fef1e8b007ff6a29ed = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_4cd38ae936f4e80d46929af8f706b998);
#
#
#         var popup_78ae3d9e86b4d4cb241da647ec40be24 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d4c6ea3c9e62edc7919b136d52e31f7f = $(`&lt;div id=&quot;html_d4c6ea3c9e62edc7919b136d52e31f7f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_78ae3d9e86b4d4cb241da647ec40be24.setContent(html_d4c6ea3c9e62edc7919b136d52e31f7f);
#
#
#
#         marker_fdaf139c1231e8fef1e8b007ff6a29ed.bindPopup(popup_78ae3d9e86b4d4cb241da647ec40be24)
#         ;
#
#
#
#
#             var marker_fa8f86bc3ace311ec52cd0259f9f4634 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_4cd38ae936f4e80d46929af8f706b998);
#
#
#         var popup_7cad5a0027a69849418f98ecefd751ec = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a7459657cb9f16fc57c5bbef25a2db15 = $(`&lt;div id=&quot;html_a7459657cb9f16fc57c5bbef25a2db15&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_7cad5a0027a69849418f98ecefd751ec.setContent(html_a7459657cb9f16fc57c5bbef25a2db15);
#
#
#
#         marker_
