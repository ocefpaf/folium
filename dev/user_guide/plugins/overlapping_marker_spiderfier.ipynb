# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6cb6a85c376c9896d4772d58247ad8de {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6cb6a85c376c9896d4772d58247ad8de&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6cb6a85c376c9896d4772d58247ad8de = L.map(
#                 &quot;map_6cb6a85c376c9896d4772d58247ad8de&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3f7e85b3c54771341b7ef003b0d0df17 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3f7e85b3c54771341b7ef003b0d0df17.addTo(map_6cb6a85c376c9896d4772d58247ad8de);
#
#
#             var marker_5fb9d6b3bfa088b890b324caa8abe0c7 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_6cb6a85c376c9896d4772d58247ad8de);
#
#
#         var popup_820414c1449b1cb8dd06d91fc063607f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a8d8db0fecdcd56e2776419fe626e6bf = $(`&lt;div id=&quot;html_a8d8db0fecdcd56e2776419fe626e6bf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_820414c1449b1cb8dd06d91fc063607f.setContent(html_a8d8db0fecdcd56e2776419fe626e6bf);
#
#
#
#         marker_5fb9d6b3bfa088b890b324caa8abe0c7.bindPopup(popup_820414c1449b1cb8dd06d91fc063607f)
#         ;
#
#
#
#
#             var marker_28d5b9f73037b5b033e177e3ac896e80 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_6cb6a85c376c9896d4772d58247ad8de);
#
#
#         var popup_d0c9bb2bf6b57d353c5adb6b089d01de = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d74942b13f6c4199ad589e0be6d05d54 = $(`&lt;div id=&quot;html_d74942b13f6c4199ad589e0be6d05d54&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_d0c9bb2bf6b57d353c5adb6b089d01de.setContent(html_d74942b13f6c4199ad589e0be6d05d54);
#
#
#
#         marker_28d5b9f73037b5b033e177e3ac896e80.bindPopup(popup_d0c9bb2bf6b57d353c5adb6b089d01de)
#         ;
#
#
#
#
#             var marker_6df5fbdfa4a51faabab64162558981c1 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_6cb6a85c376c9896d4772d58247ad8de);
#
#
#         var popup_fdd67115e255a14893c0c3961f186460 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7e7e2a6a89c65eec619a4e0c608719f3 = $(`&lt;div id=&quot;html_7e7e2a6a89c65eec619a4e0c608719f3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_fdd67115e255a14893c0c3961f186460.setContent(html_7e7e2a6a89c65eec619a4e0c608719f3);
#
#
#
#         marker_6df5fbdfa4a51faabab64162558981c1.bindPopup(popup_fdd67115e255a14893c0c3961f186460)
#         ;
#
#
#
#
#             var marker_3cbbf783a3185938e35df39644e54f87 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_6cb6a85c376c9896d4772d58247ad8de);
#
#
#         var popup_a07eaa2e4f9fed828078791db2a35715 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_872d3cd1ccb7ecf3ca8241950836233c = $(`&lt;div id=&quot;html_872d3cd1ccb7ecf3ca8241950836233c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_a07eaa2e4f9fed828078791db2a35715.setContent(html_872d3cd1ccb7ecf3ca8241950836233c);
#
#
#
#         marker_3cbbf783a3185938e35df39644e54f87.bindPopup(popup_a07eaa2e4f9fed828078791db2a35715)
#         ;
#
#
#
#
#             var marker_103c6de35d171df412d7ba8a15e9278b = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_6cb6a85c376c9896d4772d58247ad8de);
#
#
#         var popup_87fd3217166db9f5a420e35b382ad946 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2fe7744ba4914fe6985123a8d7561ca7 = $(`&lt;div id=&quot;html_2fe7744ba4914fe6985123a8d7561ca7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_87fd3217166db9f5a420e35b382ad946.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5d6dfc80c79963478ac7997f4887e48f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5d6dfc80c79963478ac7997f4887e48f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5d6dfc80c79963478ac7997f4887e48f = L.map(
#                 &quot;map_5d6dfc80c79963478ac7997f4887e48f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_adb25510d7668f3d70068b49839f9b8f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_adb25510d7668f3d70068b49839f9b8f.addTo(map_5d6dfc80c79963478ac7997f4887e48f);
#
#
#             var feature_group_7d6350f4a7b2f5dbd0d58658323ef09d = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_9ccbae2a2a883f65843874be05468522 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_7d6350f4a7b2f5dbd0d58658323ef09d);
#
#
#         var popup_60d3736c03c409c87008d793ee12508b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_71398a562222cae9a1ee79fdabd69fbc = $(`&lt;div id=&quot;html_71398a562222cae9a1ee79fdabd69fbc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_60d3736c03c409c87008d793ee12508b.setContent(html_71398a562222cae9a1ee79fdabd69fbc);
#
#
#
#         marker_9ccbae2a2a883f65843874be05468522.bindPopup(popup_60d3736c03c409c87008d793ee12508b)
#         ;
#
#
#
#
#             var marker_679fa6da405e63fa74652d4571b2aa13 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_7d6350f4a7b2f5dbd0d58658323ef09d);
#
#
#         var popup_f53c0f188effe1d051c04f62f0b731f0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3e705fc4094b2d632bf09784b5e4ae01 = $(`&lt;div id=&quot;html_3e705fc4094b2d632bf09784b5e4ae01&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_f53c0f188effe1d051c04f62f0b731f0.setContent(html_3e705fc4094b2d632bf09784b5e4ae01);
#
#
#
#         marker_679fa6da405e63fa74652d4571b2aa13.bindPopup(popup_f53c0f188effe1d051c04f62f0b731f0)
#         ;
#
#
#
#
#             var marker_7cfd5b89c33c39f82a80a588eab4c701 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_7d6350f4a7b2f5dbd0d58658323ef09d);
#
#
#         var popup_c871f44bf1c84e4b60a444df0a02a124 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ea1c1ebf0d63ed07241f0f3324d4c6a1 = $(`&lt;div id=&quot;html_ea1c1ebf0d63ed07241f0f3324d4c6a1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_c871f44bf1c84e4b60a444df0a02a124.setContent(html_ea1c1ebf0d63ed07241f0f3324d4c6a1);
#
#
#
#         marker_7cfd5b89c33c39f82a80a588eab4c701.bindPopup(popup_c871f44bf1c84e4b60a444df0a02a124)
#         ;
#
#
#
#
#             var marker_95b33a71661510ac41bdb14c4e26b881 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_7d6350f4a7b2f5dbd0d58658323ef09d);
#
#
#         var popup_6da99e17aa2ebe0b139d043f7b800ab2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a2884ff5e7d4ccb04b09a041413991aa = $(`&lt;div id=&quot;html_a2884ff5e7d4ccb04b09a041413991aa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_6da99e17aa2ebe0b139d043f7b800ab2.setContent(html_a2884ff5e7d4ccb04b09a041413991aa);
#
#
#
#         marker_95b33a71661510ac41bdb14c4e26b881.bindPopup(popup_6da99e17aa2ebe0b139d043f7b800ab2)
#         ;
#
#
#
#
#             var marker_48b8169d9e42301910f21446354d4463 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_7d6350f4a7b2f5dbd0d58658323ef09d);
#
#
#         var popup_832feecb4f5034216b65dcd0e8c5731e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_07ef638e84160f389e583ffafaccddf3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_07ef638e84160f389e583ffafaccddf3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_07ef638e84160f389e583ffafaccddf3 = L.map(
#                 &quot;map_07ef638e84160f389e583ffafaccddf3&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0bdbd3ca53b6abcd578a4421a8060822 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0bdbd3ca53b6abcd578a4421a8060822.addTo(map_07ef638e84160f389e583ffafaccddf3);
#
#
#             var feature_group_8af6b44947a0148fdf1facfc514273f2 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_8af6b44947a0148fdf1facfc514273f2.addTo(map_07ef638e84160f389e583ffafaccddf3);
#
#
#             var feature_group_sub_group_5c0c6647141116f330a185d390ae514f = L.featureGroup.subGroup(
#                 feature_group_8af6b44947a0148fdf1facfc514273f2
#             );
#
#
#             var marker_e41b0917502dffa3df8ad429a2851a1f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_5c0c6647141116f330a185d390ae514f);
#
#
#         var popup_a961a7eb5b743ccb435eda97ebd7e673 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_579e2adffaa59d96483510025838dfd2 = $(`&lt;div id=&quot;html_579e2adffaa59d96483510025838dfd2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_a961a7eb5b743ccb435eda97ebd7e673.setContent(html_579e2adffaa59d96483510025838dfd2);
#
#
#
#         marker_e41b0917502dffa3df8ad429a2851a1f.bindPopup(popup_a961a7eb5b743ccb435eda97ebd7e673)
#         ;
#
#
#
#
#             var marker_fa2eddda57d5e165ffa5b3f792a8291d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_5c0c6647141116f330a185d390ae514f);
#
#
#         var popup_5aff76a46008e4eb5bebf20bbeee2a5f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cf0c31831e8295b728a26ead99a861f1 = $(`&lt;div id=&quot;html_cf0c31831e8295b728a26ead99a861f1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_5aff76a46008e4eb5bebf20bbeee2a5f.setContent(html_cf0c31831e8295b728a26ead99a861f1);
#
#
#
#         marker_fa2eddda57d5e165ffa5b3f792a8291d.bindPopup(popup_5aff76a46008e4eb5bebf20bbeee2a5f)
#         ;
#
#
#
#
#             var marker_8d73a175620642d2c9ae7173fbf7233c = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_5c0c6647141116f330a185d390ae514f);
#
#
#         var popup_6b8b56110bd84304c352564b24323de3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d2b8f8081ebd467962da6e1e96544c03 = $(`&lt;div id=&quot;html_d2b8f8081ebd467962da6e1e96544c03&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_6b8b56110bd84304c352564b24323de3.setContent(html_d2b8f8081ebd467962da6e1e96544c03);
#
#
#
#         marker_8d73a175620642d2c9ae7173fbf7233c.bindPopup(popup_6b8b56110bd84304c352564b24323de3)
#         ;
#
#
#
#
#             var marker_d7d31b68a71e5995831ef38b8dd76b86 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_5c0c6647141116f330a185d390ae514f);
#
#
#         var popup_0bce1fa96f4b4bab6bb9cd602ca159f9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a05ff03587c824ebb0c60f4096ee4567 = $(`&lt;div id=&quot;html_a05ff03587c824ebb0c60f4096ee4567&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_0bce1fa96f4b4bab6bb9cd602ca159f9.setContent(html_a05ff03587c824ebb0c60f4096ee4567);
#
#
#
#         marker_
