# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_83d6030f07374d62644b11406771a470 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_83d6030f07374d62644b11406771a470&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_83d6030f07374d62644b11406771a470 = L.map(
#                 &quot;map_83d6030f07374d62644b11406771a470&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e37b40b183888cb465784cfd1efa9ce1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e37b40b183888cb465784cfd1efa9ce1.addTo(map_83d6030f07374d62644b11406771a470);
#
#
#             var marker_0cd4a783b4e9b37de9cccd01c22baaf9 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_83d6030f07374d62644b11406771a470);
#
#
#         var popup_9b8bad6925249c03a9813fcddc883934 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e89a00150eee222136e05995be1d2411 = $(`&lt;div id=&quot;html_e89a00150eee222136e05995be1d2411&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_9b8bad6925249c03a9813fcddc883934.setContent(html_e89a00150eee222136e05995be1d2411);
#
#
#
#         marker_0cd4a783b4e9b37de9cccd01c22baaf9.bindPopup(popup_9b8bad6925249c03a9813fcddc883934)
#         ;
#
#
#
#
#             var marker_40f1874516746c3565ba0a8484f804b6 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_83d6030f07374d62644b11406771a470);
#
#
#         var popup_3074cd116f5893d9c4fb5d01f55a2296 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d186b71991c7d7d77cd61390a29bb6b7 = $(`&lt;div id=&quot;html_d186b71991c7d7d77cd61390a29bb6b7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_3074cd116f5893d9c4fb5d01f55a2296.setContent(html_d186b71991c7d7d77cd61390a29bb6b7);
#
#
#
#         marker_40f1874516746c3565ba0a8484f804b6.bindPopup(popup_3074cd116f5893d9c4fb5d01f55a2296)
#         ;
#
#
#
#
#             var marker_013e47274aefe1de47558e8d783e4024 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_83d6030f07374d62644b11406771a470);
#
#
#         var popup_615fdd20036ec296e990b92b61a96c49 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d40fe1872bc935027d245db0b9e32d75 = $(`&lt;div id=&quot;html_d40fe1872bc935027d245db0b9e32d75&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_615fdd20036ec296e990b92b61a96c49.setContent(html_d40fe1872bc935027d245db0b9e32d75);
#
#
#
#         marker_013e47274aefe1de47558e8d783e4024.bindPopup(popup_615fdd20036ec296e990b92b61a96c49)
#         ;
#
#
#
#
#             var marker_71c7a2f11deb783b26884a339e94825f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_83d6030f07374d62644b11406771a470);
#
#
#         var popup_9c353eadaf3a6f0c268c375ec68cc490 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d6af7cd172ecc23d6a2be9b8b0513af4 = $(`&lt;div id=&quot;html_d6af7cd172ecc23d6a2be9b8b0513af4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_9c353eadaf3a6f0c268c375ec68cc490.setContent(html_d6af7cd172ecc23d6a2be9b8b0513af4);
#
#
#
#         marker_71c7a2f11deb783b26884a339e94825f.bindPopup(popup_9c353eadaf3a6f0c268c375ec68cc490)
#         ;
#
#
#
#
#             var marker_2c439ba25f4c1f600e7844e7aec56879 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_83d6030f07374d62644b11406771a470);
#
#
#         var popup_44a888f62356e4746b8fdd4fd41aa1be = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_701c2812a8fb2a1a1d88fb75262a7202 = $(`&lt;div id=&quot;html_701c2812a8fb2a1a1d88fb75262a7202&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_44a888f62356e4746b8fdd4fd41aa1be.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8206aa3e4d3cf06a6845e4784468c361 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8206aa3e4d3cf06a6845e4784468c361&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8206aa3e4d3cf06a6845e4784468c361 = L.map(
#                 &quot;map_8206aa3e4d3cf06a6845e4784468c361&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c5b065edc4d5c8de1dd568c007611607 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c5b065edc4d5c8de1dd568c007611607.addTo(map_8206aa3e4d3cf06a6845e4784468c361);
#
#
#             var feature_group_a9f9c9b30e7eaa22abd1dbfb0573db24 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_05f9aef1b2479d93e021371ae89f3fdd = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_a9f9c9b30e7eaa22abd1dbfb0573db24);
#
#
#         var popup_e35acdb659bf0bb0656e9eace380c606 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b73ae989d2d9ed6ad54fcbd011b69507 = $(`&lt;div id=&quot;html_b73ae989d2d9ed6ad54fcbd011b69507&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_e35acdb659bf0bb0656e9eace380c606.setContent(html_b73ae989d2d9ed6ad54fcbd011b69507);
#
#
#
#         marker_05f9aef1b2479d93e021371ae89f3fdd.bindPopup(popup_e35acdb659bf0bb0656e9eace380c606)
#         ;
#
#
#
#
#             var marker_1fabca91edc77e611f47f8b8364672af = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_a9f9c9b30e7eaa22abd1dbfb0573db24);
#
#
#         var popup_55243aa9d218f5ed6a3c73bc72ab78d9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_63c45f1a35632b7c61b8682ca0ed0066 = $(`&lt;div id=&quot;html_63c45f1a35632b7c61b8682ca0ed0066&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_55243aa9d218f5ed6a3c73bc72ab78d9.setContent(html_63c45f1a35632b7c61b8682ca0ed0066);
#
#
#
#         marker_1fabca91edc77e611f47f8b8364672af.bindPopup(popup_55243aa9d218f5ed6a3c73bc72ab78d9)
#         ;
#
#
#
#
#             var marker_1fc81f4a17a44efe103d86aa936063cc = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_a9f9c9b30e7eaa22abd1dbfb0573db24);
#
#
#         var popup_f769bfc81063236e6375afdb537b3b8b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d0459cfb3d92f0d9f2e08491322d4992 = $(`&lt;div id=&quot;html_d0459cfb3d92f0d9f2e08491322d4992&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_f769bfc81063236e6375afdb537b3b8b.setContent(html_d0459cfb3d92f0d9f2e08491322d4992);
#
#
#
#         marker_1fc81f4a17a44efe103d86aa936063cc.bindPopup(popup_f769bfc81063236e6375afdb537b3b8b)
#         ;
#
#
#
#
#             var marker_ba32eff4c312cc909bc874ed1cf3a80e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_a9f9c9b30e7eaa22abd1dbfb0573db24);
#
#
#         var popup_b0ed0e1666f6886fcf75ffadf262bb92 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4b6cb7b4d985dac2c404e63c21ab75a7 = $(`&lt;div id=&quot;html_4b6cb7b4d985dac2c404e63c21ab75a7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_b0ed0e1666f6886fcf75ffadf262bb92.setContent(html_4b6cb7b4d985dac2c404e63c21ab75a7);
#
#
#
#         marker_ba32eff4c312cc909bc874ed1cf3a80e.bindPopup(popup_b0ed0e1666f6886fcf75ffadf262bb92)
#         ;
#
#
#
#
#             var marker_f3629461b7a9f7a1f1a364e5d983b8f3 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_a9f9c9b30e7eaa22abd1dbfb0573db24);
#
#
#         var popup_d36114bd212f9f4481c01c967d042f81 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d7d749bf8f143eda78527f9d4802949d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d7d749bf8f143eda78527f9d4802949d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d7d749bf8f143eda78527f9d4802949d = L.map(
#                 &quot;map_d7d749bf8f143eda78527f9d4802949d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_eed2eb71e635d1fdc1a5a400dc477ad0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_eed2eb71e635d1fdc1a5a400dc477ad0.addTo(map_d7d749bf8f143eda78527f9d4802949d);
#
#
#             var feature_group_fdb9ff902109ea708b3272bc49c8cb0b = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_fdb9ff902109ea708b3272bc49c8cb0b.addTo(map_d7d749bf8f143eda78527f9d4802949d);
#
#
#             var feature_group_sub_group_8d59932488fb8b1094658300a7c6968f = L.featureGroup.subGroup(
#                 feature_group_fdb9ff902109ea708b3272bc49c8cb0b
#             );
#
#
#             var marker_ec42497f75569cf244a815294460c35d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_8d59932488fb8b1094658300a7c6968f);
#
#
#         var popup_8b34978e19ccfe58ecc659a9a0189f88 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0fb40dc65950392fb693337eabb96967 = $(`&lt;div id=&quot;html_0fb40dc65950392fb693337eabb96967&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_8b34978e19ccfe58ecc659a9a0189f88.setContent(html_0fb40dc65950392fb693337eabb96967);
#
#
#
#         marker_ec42497f75569cf244a815294460c35d.bindPopup(popup_8b34978e19ccfe58ecc659a9a0189f88)
#         ;
#
#
#
#
#             var marker_39e63b31e4bb907806f543dca3a6a23c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_8d59932488fb8b1094658300a7c6968f);
#
#
#         var popup_0fced7bf9d0a9c0ee12772326e608af6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4ce12274823189475af2ab1b746e2ef9 = $(`&lt;div id=&quot;html_4ce12274823189475af2ab1b746e2ef9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_0fced7bf9d0a9c0ee12772326e608af6.setContent(html_4ce12274823189475af2ab1b746e2ef9);
#
#
#
#         marker_39e63b31e4bb907806f543dca3a6a23c.bindPopup(popup_0fced7bf9d0a9c0ee12772326e608af6)
#         ;
#
#
#
#
#             var marker_208c54ba7d99dfa2f0c95eee16a07bca = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_8d59932488fb8b1094658300a7c6968f);
#
#
#         var popup_a2eb94a7dfa65a73849bd73a6a96e3d2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_abe732650310249e9e9e138eb5dbc46e = $(`&lt;div id=&quot;html_abe732650310249e9e9e138eb5dbc46e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_a2eb94a7dfa65a73849bd73a6a96e3d2.setContent(html_abe732650310249e9e9e138eb5dbc46e);
#
#
#
#         marker_208c54ba7d99dfa2f0c95eee16a07bca.bindPopup(popup_a2eb94a7dfa65a73849bd73a6a96e3d2)
#         ;
#
#
#
#
#             var marker_b7e825f6e793d7c9962b2ebcfd0438ba = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_8d59932488fb8b1094658300a7c6968f);
#
#
#         var popup_23a5790d9015e581cc4aca4db42c1357 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3c39544f49e4b23c45e57f31e0bf590f = $(`&lt;div id=&quot;html_3c39544f49e4b23c45e57f31e0bf590f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_23a5790d9015e581cc4aca4db42c1357.setContent(html_3c39544f49e4b23c45e57f31e0bf590f);
#
#
#
#         marker_
