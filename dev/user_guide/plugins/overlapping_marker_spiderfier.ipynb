# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_38143f8af7428e7cf561ca7f40128b45 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_38143f8af7428e7cf561ca7f40128b45&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_38143f8af7428e7cf561ca7f40128b45 = L.map(
#                 &quot;map_38143f8af7428e7cf561ca7f40128b45&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1796257aa9a61505728eb247507bf128 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1796257aa9a61505728eb247507bf128.addTo(map_38143f8af7428e7cf561ca7f40128b45);
#
#
#             var marker_63a8cc51cd3123ecc61210e877fe3bc7 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_38143f8af7428e7cf561ca7f40128b45);
#
#
#         var popup_f4b8b21b867728729878303a58c59bc2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_de44e8698d5b0198dfb585006acc92b5 = $(`&lt;div id=&quot;html_de44e8698d5b0198dfb585006acc92b5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_f4b8b21b867728729878303a58c59bc2.setContent(html_de44e8698d5b0198dfb585006acc92b5);
#
#
#
#         marker_63a8cc51cd3123ecc61210e877fe3bc7.bindPopup(popup_f4b8b21b867728729878303a58c59bc2)
#         ;
#
#
#
#
#             var marker_c7f7640c286088c582968a6786f1f760 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_38143f8af7428e7cf561ca7f40128b45);
#
#
#         var popup_306b80f9c2c209b7da77ff0af735d4fb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_28d7c6ceb68487518bdd21bf230ed7ec = $(`&lt;div id=&quot;html_28d7c6ceb68487518bdd21bf230ed7ec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_306b80f9c2c209b7da77ff0af735d4fb.setContent(html_28d7c6ceb68487518bdd21bf230ed7ec);
#
#
#
#         marker_c7f7640c286088c582968a6786f1f760.bindPopup(popup_306b80f9c2c209b7da77ff0af735d4fb)
#         ;
#
#
#
#
#             var marker_ff32dbf3ddfa4040b7e533846a5077e8 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_38143f8af7428e7cf561ca7f40128b45);
#
#
#         var popup_dea990254a584074e907f022b4e8eb52 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_710e897fbf3afeffb6f0739eeae64ffb = $(`&lt;div id=&quot;html_710e897fbf3afeffb6f0739eeae64ffb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_dea990254a584074e907f022b4e8eb52.setContent(html_710e897fbf3afeffb6f0739eeae64ffb);
#
#
#
#         marker_ff32dbf3ddfa4040b7e533846a5077e8.bindPopup(popup_dea990254a584074e907f022b4e8eb52)
#         ;
#
#
#
#
#             var marker_88d7c50a122b59fa02584ce4e402b2d6 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_38143f8af7428e7cf561ca7f40128b45);
#
#
#         var popup_cbc67fd20dacb6477cf47d33e9987b14 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3824c7ad389eec25fea1a39030cc3daf = $(`&lt;div id=&quot;html_3824c7ad389eec25fea1a39030cc3daf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_cbc67fd20dacb6477cf47d33e9987b14.setContent(html_3824c7ad389eec25fea1a39030cc3daf);
#
#
#
#         marker_88d7c50a122b59fa02584ce4e402b2d6.bindPopup(popup_cbc67fd20dacb6477cf47d33e9987b14)
#         ;
#
#
#
#
#             var marker_ec36d03917d16eaa73a2e80c2cf9ccd5 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_38143f8af7428e7cf561ca7f40128b45);
#
#
#         var popup_41dd8aa003c496609a237310e2ffac0d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bd6760adab5b4a90476b3e0150c6932b = $(`&lt;div id=&quot;html_bd6760adab5b4a90476b3e0150c6932b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_41dd8aa003c496609a237310e2ffac0d.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fbf98fa900633127c12966bdad7dee78 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fbf98fa900633127c12966bdad7dee78&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fbf98fa900633127c12966bdad7dee78 = L.map(
#                 &quot;map_fbf98fa900633127c12966bdad7dee78&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8f49154de9fbce73157b924b38be025d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8f49154de9fbce73157b924b38be025d.addTo(map_fbf98fa900633127c12966bdad7dee78);
#
#
#             var feature_group_0a557128ae65e3a66f92e770da94021c = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_861e23796de04cf2ca702429482c8a06 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_0a557128ae65e3a66f92e770da94021c);
#
#
#         var popup_a1b95f6002656bd9acde5ca575d4d722 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7b017551bf4c492724d41308f86bbc82 = $(`&lt;div id=&quot;html_7b017551bf4c492724d41308f86bbc82&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_a1b95f6002656bd9acde5ca575d4d722.setContent(html_7b017551bf4c492724d41308f86bbc82);
#
#
#
#         marker_861e23796de04cf2ca702429482c8a06.bindPopup(popup_a1b95f6002656bd9acde5ca575d4d722)
#         ;
#
#
#
#
#             var marker_549a5072424e538ac00d5842795efb0f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_0a557128ae65e3a66f92e770da94021c);
#
#
#         var popup_3e77e8bf8a48e09b942a80163981cdaf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b1068317063ad52fd814c4b8de2ba58d = $(`&lt;div id=&quot;html_b1068317063ad52fd814c4b8de2ba58d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_3e77e8bf8a48e09b942a80163981cdaf.setContent(html_b1068317063ad52fd814c4b8de2ba58d);
#
#
#
#         marker_549a5072424e538ac00d5842795efb0f.bindPopup(popup_3e77e8bf8a48e09b942a80163981cdaf)
#         ;
#
#
#
#
#             var marker_78fe3cb628a2f098a02d83c00459e10a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_0a557128ae65e3a66f92e770da94021c);
#
#
#         var popup_e4ac03396e6fcc3ed6352bc50fad8eae = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2f32b7eb892426008a6c0ea44cdb75c8 = $(`&lt;div id=&quot;html_2f32b7eb892426008a6c0ea44cdb75c8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_e4ac03396e6fcc3ed6352bc50fad8eae.setContent(html_2f32b7eb892426008a6c0ea44cdb75c8);
#
#
#
#         marker_78fe3cb628a2f098a02d83c00459e10a.bindPopup(popup_e4ac03396e6fcc3ed6352bc50fad8eae)
#         ;
#
#
#
#
#             var marker_517010391cee92fb72b5a0d5bc5e08e7 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_0a557128ae65e3a66f92e770da94021c);
#
#
#         var popup_d256f1773c3a7bc13c057d0d4223da34 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f032ed4e1581bec78da82b3ef64292d0 = $(`&lt;div id=&quot;html_f032ed4e1581bec78da82b3ef64292d0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_d256f1773c3a7bc13c057d0d4223da34.setContent(html_f032ed4e1581bec78da82b3ef64292d0);
#
#
#
#         marker_517010391cee92fb72b5a0d5bc5e08e7.bindPopup(popup_d256f1773c3a7bc13c057d0d4223da34)
#         ;
#
#
#
#
#             var marker_a749548ae1ba6b9ff82da72f4d5c9942 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_0a557128ae65e3a66f92e770da94021c);
#
#
#         var popup_27276cbf3da9a135139201ceb909e4f3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c791f3b7a4fdfef7645cc89b0c3be5dc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c791f3b7a4fdfef7645cc89b0c3be5dc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c791f3b7a4fdfef7645cc89b0c3be5dc = L.map(
#                 &quot;map_c791f3b7a4fdfef7645cc89b0c3be5dc&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_16c0af962ef728d082911df471d3a0ff = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_16c0af962ef728d082911df471d3a0ff.addTo(map_c791f3b7a4fdfef7645cc89b0c3be5dc);
#
#
#             var feature_group_695c7cd6a4892e3ee3c6a5ef41fdff30 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_695c7cd6a4892e3ee3c6a5ef41fdff30.addTo(map_c791f3b7a4fdfef7645cc89b0c3be5dc);
#
#
#             var feature_group_sub_group_f3778cb09596e98d76454ee3f7ddc3da = L.featureGroup.subGroup(
#                 feature_group_695c7cd6a4892e3ee3c6a5ef41fdff30
#             );
#
#
#             var marker_2fd22a8159805a9001066cb2d97c1cf7 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_f3778cb09596e98d76454ee3f7ddc3da);
#
#
#         var popup_b0b7ccad41157f70a8e8fc9034590049 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4938f50b1bf25f2a6ee31dd8ceaf8635 = $(`&lt;div id=&quot;html_4938f50b1bf25f2a6ee31dd8ceaf8635&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_b0b7ccad41157f70a8e8fc9034590049.setContent(html_4938f50b1bf25f2a6ee31dd8ceaf8635);
#
#
#
#         marker_2fd22a8159805a9001066cb2d97c1cf7.bindPopup(popup_b0b7ccad41157f70a8e8fc9034590049)
#         ;
#
#
#
#
#             var marker_42352c5280e4bd593295510164dc2668 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_f3778cb09596e98d76454ee3f7ddc3da);
#
#
#         var popup_880724490e5feaa564b94c54019429b8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d3f809d8b530fa0c5755cb1405884e0d = $(`&lt;div id=&quot;html_d3f809d8b530fa0c5755cb1405884e0d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_880724490e5feaa564b94c54019429b8.setContent(html_d3f809d8b530fa0c5755cb1405884e0d);
#
#
#
#         marker_42352c5280e4bd593295510164dc2668.bindPopup(popup_880724490e5feaa564b94c54019429b8)
#         ;
#
#
#
#
#             var marker_dd9a3720c1f1fb02608ffebde828fa4e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_f3778cb09596e98d76454ee3f7ddc3da);
#
#
#         var popup_4f7d3f9a02fcf5370312567370eae139 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f85c2d8f5a181b645b86bef2c51a4487 = $(`&lt;div id=&quot;html_f85c2d8f5a181b645b86bef2c51a4487&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_4f7d3f9a02fcf5370312567370eae139.setContent(html_f85c2d8f5a181b645b86bef2c51a4487);
#
#
#
#         marker_dd9a3720c1f1fb02608ffebde828fa4e.bindPopup(popup_4f7d3f9a02fcf5370312567370eae139)
#         ;
#
#
#
#
#             var marker_454c91c7cfd59ca670b40f644e22e7a2 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_f3778cb09596e98d76454ee3f7ddc3da);
#
#
#         var popup_a3dce69241cd2d7a9b3738db50de2861 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a01a8338bc5bb73d17ed63235cfc201b = $(`&lt;div id=&quot;html_a01a8338bc5bb73d17ed63235cfc201b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_a3dce69241cd2d7a9b3738db50de2861.setContent(html_a01a8338bc5bb73d17ed63235cfc201b);
#
#
#
#         marker_
