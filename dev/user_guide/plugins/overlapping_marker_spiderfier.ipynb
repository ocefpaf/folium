# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_da28bf5d5c58438099d7576451963db7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_da28bf5d5c58438099d7576451963db7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_da28bf5d5c58438099d7576451963db7 = L.map(
#                 &quot;map_da28bf5d5c58438099d7576451963db7&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6b7de4a8b6c21faa8aa3df6cd95f2ed3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6b7de4a8b6c21faa8aa3df6cd95f2ed3.addTo(map_da28bf5d5c58438099d7576451963db7);
#
#
#             var marker_476816fdaa7274f0a47014f3ea7cbffa = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_da28bf5d5c58438099d7576451963db7);
#
#
#         var popup_d65981c756b9133406f4ae741eda5f9c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_918e07df014f512a8125141729ecd581 = $(`&lt;div id=&quot;html_918e07df014f512a8125141729ecd581&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_d65981c756b9133406f4ae741eda5f9c.setContent(html_918e07df014f512a8125141729ecd581);
#
#
#
#         marker_476816fdaa7274f0a47014f3ea7cbffa.bindPopup(popup_d65981c756b9133406f4ae741eda5f9c)
#         ;
#
#
#
#
#             var marker_39fdecab1c6ffaaacde3808acc05e8d2 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_da28bf5d5c58438099d7576451963db7);
#
#
#         var popup_a380736041e124d76ef17ccbc3b43c0b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6a1cfc8d2550697056bdf0458856cefc = $(`&lt;div id=&quot;html_6a1cfc8d2550697056bdf0458856cefc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_a380736041e124d76ef17ccbc3b43c0b.setContent(html_6a1cfc8d2550697056bdf0458856cefc);
#
#
#
#         marker_39fdecab1c6ffaaacde3808acc05e8d2.bindPopup(popup_a380736041e124d76ef17ccbc3b43c0b)
#         ;
#
#
#
#
#             var marker_077dbd8f404818af00cdaad7536f37d2 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_da28bf5d5c58438099d7576451963db7);
#
#
#         var popup_a3fb4ed26930313a7e2bef9533ba0d8a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3daf048f82585052eba89dc0485296c3 = $(`&lt;div id=&quot;html_3daf048f82585052eba89dc0485296c3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_a3fb4ed26930313a7e2bef9533ba0d8a.setContent(html_3daf048f82585052eba89dc0485296c3);
#
#
#
#         marker_077dbd8f404818af00cdaad7536f37d2.bindPopup(popup_a3fb4ed26930313a7e2bef9533ba0d8a)
#         ;
#
#
#
#
#             var marker_9e9177ae4aaa430cf72cb94d8e7724f4 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_da28bf5d5c58438099d7576451963db7);
#
#
#         var popup_a6f8ba5083ec7fb7046183390a40bfbd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1f3bb67a41943451dc1473cc01fb579a = $(`&lt;div id=&quot;html_1f3bb67a41943451dc1473cc01fb579a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_a6f8ba5083ec7fb7046183390a40bfbd.setContent(html_1f3bb67a41943451dc1473cc01fb579a);
#
#
#
#         marker_9e9177ae4aaa430cf72cb94d8e7724f4.bindPopup(popup_a6f8ba5083ec7fb7046183390a40bfbd)
#         ;
#
#
#
#
#             var marker_7bc8e8a7af539ceeb39969bb16dfae2f = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_da28bf5d5c58438099d7576451963db7);
#
#
#         var popup_0fa375baa5e967b6091fc8aadf59e522 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_25249af014904b127365a84335c83779 = $(`&lt;div id=&quot;html_25249af014904b127365a84335c83779&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_0fa375baa5e967b6091fc8aadf59e522.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9fc732b2c62da9d4bf2a97be6f634253 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9fc732b2c62da9d4bf2a97be6f634253&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9fc732b2c62da9d4bf2a97be6f634253 = L.map(
#                 &quot;map_9fc732b2c62da9d4bf2a97be6f634253&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_58ec6b50cec1733f08d42f9cde2c431c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_58ec6b50cec1733f08d42f9cde2c431c.addTo(map_9fc732b2c62da9d4bf2a97be6f634253);
#
#
#             var feature_group_56555e24563d6336202c1161c8dab1ea = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_ff2b76dedc21787f96076e679fd0b36a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_56555e24563d6336202c1161c8dab1ea);
#
#
#         var popup_b16836ff0283ccc520384d26168b1f51 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_87f5ace4f688698024efb3c3cef12f34 = $(`&lt;div id=&quot;html_87f5ace4f688698024efb3c3cef12f34&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_b16836ff0283ccc520384d26168b1f51.setContent(html_87f5ace4f688698024efb3c3cef12f34);
#
#
#
#         marker_ff2b76dedc21787f96076e679fd0b36a.bindPopup(popup_b16836ff0283ccc520384d26168b1f51)
#         ;
#
#
#
#
#             var marker_9430affdbf6f892fb8f5ada444f25eaa = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_56555e24563d6336202c1161c8dab1ea);
#
#
#         var popup_702e0ea6a4cbbe5aada9458940055db4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_41ed85aea021d286a9a7b6e1eff98dab = $(`&lt;div id=&quot;html_41ed85aea021d286a9a7b6e1eff98dab&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_702e0ea6a4cbbe5aada9458940055db4.setContent(html_41ed85aea021d286a9a7b6e1eff98dab);
#
#
#
#         marker_9430affdbf6f892fb8f5ada444f25eaa.bindPopup(popup_702e0ea6a4cbbe5aada9458940055db4)
#         ;
#
#
#
#
#             var marker_5dd5c8b0f14543d04d08311e0465aaf5 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_56555e24563d6336202c1161c8dab1ea);
#
#
#         var popup_8c5baeab8cf82cdaa3b1e5e8df7a301f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4db17f8dbf72b64885dd36e1756fd054 = $(`&lt;div id=&quot;html_4db17f8dbf72b64885dd36e1756fd054&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_8c5baeab8cf82cdaa3b1e5e8df7a301f.setContent(html_4db17f8dbf72b64885dd36e1756fd054);
#
#
#
#         marker_5dd5c8b0f14543d04d08311e0465aaf5.bindPopup(popup_8c5baeab8cf82cdaa3b1e5e8df7a301f)
#         ;
#
#
#
#
#             var marker_eca371c5db568dd31ea1f2133ce2f445 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_56555e24563d6336202c1161c8dab1ea);
#
#
#         var popup_2d0e7446dbbe6a387ef87202784050b4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2ebc1b851d00ea506b5d60bf8a3a6e06 = $(`&lt;div id=&quot;html_2ebc1b851d00ea506b5d60bf8a3a6e06&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_2d0e7446dbbe6a387ef87202784050b4.setContent(html_2ebc1b851d00ea506b5d60bf8a3a6e06);
#
#
#
#         marker_eca371c5db568dd31ea1f2133ce2f445.bindPopup(popup_2d0e7446dbbe6a387ef87202784050b4)
#         ;
#
#
#
#
#             var marker_27c57884e2c0f0a7cf5cd3ad77e880c0 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_56555e24563d6336202c1161c8dab1ea);
#
#
#         var popup_e1e500a21aa71e16192f187a9fbbcda2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c49bf69ee9ba51cfce3ef38d0bcd060a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c49bf69ee9ba51cfce3ef38d0bcd060a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c49bf69ee9ba51cfce3ef38d0bcd060a = L.map(
#                 &quot;map_c49bf69ee9ba51cfce3ef38d0bcd060a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a1d58cab7e64a6375f23e58aa8974695 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a1d58cab7e64a6375f23e58aa8974695.addTo(map_c49bf69ee9ba51cfce3ef38d0bcd060a);
#
#
#             var feature_group_7372a227c987cea4414d74bddcbad82c = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_7372a227c987cea4414d74bddcbad82c.addTo(map_c49bf69ee9ba51cfce3ef38d0bcd060a);
#
#
#             var feature_group_sub_group_19cfca5a469edd13c8fc362dad6514cd = L.featureGroup.subGroup(
#                 feature_group_7372a227c987cea4414d74bddcbad82c
#             );
#
#
#             var marker_7795d78b26955e624dfa6b571caf08c8 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_19cfca5a469edd13c8fc362dad6514cd);
#
#
#         var popup_32b159b490ac3782b0a6d8a71a955f03 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b0352cade8652d03637ba5dfda29c511 = $(`&lt;div id=&quot;html_b0352cade8652d03637ba5dfda29c511&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_32b159b490ac3782b0a6d8a71a955f03.setContent(html_b0352cade8652d03637ba5dfda29c511);
#
#
#
#         marker_7795d78b26955e624dfa6b571caf08c8.bindPopup(popup_32b159b490ac3782b0a6d8a71a955f03)
#         ;
#
#
#
#
#             var marker_bd04f6d22f7eab53999faa4b1c13cc20 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_19cfca5a469edd13c8fc362dad6514cd);
#
#
#         var popup_490bb8e18e9925913a89fc041ee592e8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_76371d15dfe0b5cb84f7e373db850b5e = $(`&lt;div id=&quot;html_76371d15dfe0b5cb84f7e373db850b5e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_490bb8e18e9925913a89fc041ee592e8.setContent(html_76371d15dfe0b5cb84f7e373db850b5e);
#
#
#
#         marker_bd04f6d22f7eab53999faa4b1c13cc20.bindPopup(popup_490bb8e18e9925913a89fc041ee592e8)
#         ;
#
#
#
#
#             var marker_ade9c6c0b08b0f51687e7f3142f43f97 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_19cfca5a469edd13c8fc362dad6514cd);
#
#
#         var popup_b08defc7be7445dc015c9dbc036a912e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4a84481d8a5cdab180cacd5b561a49f6 = $(`&lt;div id=&quot;html_4a84481d8a5cdab180cacd5b561a49f6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_b08defc7be7445dc015c9dbc036a912e.setContent(html_4a84481d8a5cdab180cacd5b561a49f6);
#
#
#
#         marker_ade9c6c0b08b0f51687e7f3142f43f97.bindPopup(popup_b08defc7be7445dc015c9dbc036a912e)
#         ;
#
#
#
#
#             var marker_b92fae7e13fc899bc51508bdc475ec8f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_19cfca5a469edd13c8fc362dad6514cd);
#
#
#         var popup_9719f6a314b015f21667ea1ef01abddc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_725a2d417216e7fbe02ee885a22d3142 = $(`&lt;div id=&quot;html_725a2d417216e7fbe02ee885a22d3142&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_9719f6a314b015f21667ea1ef01abddc.setContent(html_725a2d417216e7fbe02ee885a22d3142);
#
#
#
#         marker_
