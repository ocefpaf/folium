# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e1a0ab5723c5d29064b4cd634827ef2b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e1a0ab5723c5d29064b4cd634827ef2b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e1a0ab5723c5d29064b4cd634827ef2b = L.map(
#                 &quot;map_e1a0ab5723c5d29064b4cd634827ef2b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0573ca8b78f378ac5741df91fed826f4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0573ca8b78f378ac5741df91fed826f4.addTo(map_e1a0ab5723c5d29064b4cd634827ef2b);
#
#
#             var marker_61c6fb9e0b59f76416a27f9593dbe465 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_e1a0ab5723c5d29064b4cd634827ef2b);
#
#
#         var popup_934bdc0eec2263a0750746d30c83b2ca = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b3530024187ea77119bb0bde8cfac8d1 = $(`&lt;div id=&quot;html_b3530024187ea77119bb0bde8cfac8d1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_934bdc0eec2263a0750746d30c83b2ca.setContent(html_b3530024187ea77119bb0bde8cfac8d1);
#
#
#
#         marker_61c6fb9e0b59f76416a27f9593dbe465.bindPopup(popup_934bdc0eec2263a0750746d30c83b2ca)
#         ;
#
#
#
#
#             var marker_62f2f98b962decdd1e596480d3e938e0 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_e1a0ab5723c5d29064b4cd634827ef2b);
#
#
#         var popup_71e3b38211665f3dd4903fab01e0c67d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e25b5ca64a1b9f83fcbf3daad08b9b3f = $(`&lt;div id=&quot;html_e25b5ca64a1b9f83fcbf3daad08b9b3f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_71e3b38211665f3dd4903fab01e0c67d.setContent(html_e25b5ca64a1b9f83fcbf3daad08b9b3f);
#
#
#
#         marker_62f2f98b962decdd1e596480d3e938e0.bindPopup(popup_71e3b38211665f3dd4903fab01e0c67d)
#         ;
#
#
#
#
#             var marker_22be2f5315c01fc6cb6b1b32f55e431b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_e1a0ab5723c5d29064b4cd634827ef2b);
#
#
#         var popup_3670df4cd19f6e1fdce45f295cfc02e0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4fa8a10a7118b290ffb74549cc5b221e = $(`&lt;div id=&quot;html_4fa8a10a7118b290ffb74549cc5b221e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_3670df4cd19f6e1fdce45f295cfc02e0.setContent(html_4fa8a10a7118b290ffb74549cc5b221e);
#
#
#
#         marker_22be2f5315c01fc6cb6b1b32f55e431b.bindPopup(popup_3670df4cd19f6e1fdce45f295cfc02e0)
#         ;
#
#
#
#
#             var marker_f832d3ea218993200334f56af258c2b2 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_e1a0ab5723c5d29064b4cd634827ef2b);
#
#
#         var popup_f7c7ada22c28923f95f0a123f9ecb3cf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1691fc299bda1f18edd9572759763f86 = $(`&lt;div id=&quot;html_1691fc299bda1f18edd9572759763f86&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_f7c7ada22c28923f95f0a123f9ecb3cf.setContent(html_1691fc299bda1f18edd9572759763f86);
#
#
#
#         marker_f832d3ea218993200334f56af258c2b2.bindPopup(popup_f7c7ada22c28923f95f0a123f9ecb3cf)
#         ;
#
#
#
#
#             var marker_40f928c575108bd66b8f73eed8e663c9 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_e1a0ab5723c5d29064b4cd634827ef2b);
#
#
#         var popup_59bde84a79427f1aebf072131f9d354c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fcdad4c6b63226a691c6612f90153b87 = $(`&lt;div id=&quot;html_fcdad4c6b63226a691c6612f90153b87&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_59bde84a79427f1aebf072131f9d354c.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_91f9cd83d927bcc2ce082a4671a291c8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_91f9cd83d927bcc2ce082a4671a291c8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_91f9cd83d927bcc2ce082a4671a291c8 = L.map(
#                 &quot;map_91f9cd83d927bcc2ce082a4671a291c8&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_223a6adf288000e46837b954e24c60f0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_223a6adf288000e46837b954e24c60f0.addTo(map_91f9cd83d927bcc2ce082a4671a291c8);
#
#
#             var feature_group_ecb57d518278d352615a893c5a506e9b = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_0f528ca821be7e89f42bd1529d15ab9c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_ecb57d518278d352615a893c5a506e9b);
#
#
#         var popup_19b1594ee05b3c9dd407c462eba8784b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e0c63b0b827aafe2a74a4051051cac14 = $(`&lt;div id=&quot;html_e0c63b0b827aafe2a74a4051051cac14&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_19b1594ee05b3c9dd407c462eba8784b.setContent(html_e0c63b0b827aafe2a74a4051051cac14);
#
#
#
#         marker_0f528ca821be7e89f42bd1529d15ab9c.bindPopup(popup_19b1594ee05b3c9dd407c462eba8784b)
#         ;
#
#
#
#
#             var marker_4b469bd87302b3d7d0774c018caa507d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_ecb57d518278d352615a893c5a506e9b);
#
#
#         var popup_b58cc6e9ee5764b0c86c9578f9490890 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7231b96e36575d1c945b40a85149c071 = $(`&lt;div id=&quot;html_7231b96e36575d1c945b40a85149c071&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_b58cc6e9ee5764b0c86c9578f9490890.setContent(html_7231b96e36575d1c945b40a85149c071);
#
#
#
#         marker_4b469bd87302b3d7d0774c018caa507d.bindPopup(popup_b58cc6e9ee5764b0c86c9578f9490890)
#         ;
#
#
#
#
#             var marker_a93090182ceb081f04b954d6285a789d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_ecb57d518278d352615a893c5a506e9b);
#
#
#         var popup_7919ffa420cd7772985d278f8ecdf33e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9e688c10f3ac655e798a9491202d0ac0 = $(`&lt;div id=&quot;html_9e688c10f3ac655e798a9491202d0ac0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_7919ffa420cd7772985d278f8ecdf33e.setContent(html_9e688c10f3ac655e798a9491202d0ac0);
#
#
#
#         marker_a93090182ceb081f04b954d6285a789d.bindPopup(popup_7919ffa420cd7772985d278f8ecdf33e)
#         ;
#
#
#
#
#             var marker_0df18e25f7109099e073b0a889427a6e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_ecb57d518278d352615a893c5a506e9b);
#
#
#         var popup_08daece410096bd0d99b1dd4982e61bc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d37cbad3846983feaba7d749bc44c79f = $(`&lt;div id=&quot;html_d37cbad3846983feaba7d749bc44c79f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_08daece410096bd0d99b1dd4982e61bc.setContent(html_d37cbad3846983feaba7d749bc44c79f);
#
#
#
#         marker_0df18e25f7109099e073b0a889427a6e.bindPopup(popup_08daece410096bd0d99b1dd4982e61bc)
#         ;
#
#
#
#
#             var marker_05cbe2c5091285da14bcf7e715556214 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_ecb57d518278d352615a893c5a506e9b);
#
#
#         var popup_247f6bc5b0d318c9d6d6ee166b131dff = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_75682c1b7a9c867d732053949e51d8c4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_75682c1b7a9c867d732053949e51d8c4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_75682c1b7a9c867d732053949e51d8c4 = L.map(
#                 &quot;map_75682c1b7a9c867d732053949e51d8c4&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_57bb5e1dda3cd5e2deb4426f887e5677 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_57bb5e1dda3cd5e2deb4426f887e5677.addTo(map_75682c1b7a9c867d732053949e51d8c4);
#
#
#             var feature_group_88681fa7ffdac457b78b367cb8c395af = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_88681fa7ffdac457b78b367cb8c395af.addTo(map_75682c1b7a9c867d732053949e51d8c4);
#
#
#             var feature_group_sub_group_513fd43b8f2773bba8fad6289f47c944 = L.featureGroup.subGroup(
#                 feature_group_88681fa7ffdac457b78b367cb8c395af
#             );
#
#
#             var marker_e6427b5363f944c70661ecb7735389c3 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_513fd43b8f2773bba8fad6289f47c944);
#
#
#         var popup_5ac98ccf75acd0e8f6ffca825945c064 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_faff05fe9a1c051629089e528a50350c = $(`&lt;div id=&quot;html_faff05fe9a1c051629089e528a50350c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_5ac98ccf75acd0e8f6ffca825945c064.setContent(html_faff05fe9a1c051629089e528a50350c);
#
#
#
#         marker_e6427b5363f944c70661ecb7735389c3.bindPopup(popup_5ac98ccf75acd0e8f6ffca825945c064)
#         ;
#
#
#
#
#             var marker_d4dda37e40ff82b5158878d26a892bac = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_513fd43b8f2773bba8fad6289f47c944);
#
#
#         var popup_a617a1611daeac048ce3090bfb428399 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_feb19683e9a31ee020a50773be959587 = $(`&lt;div id=&quot;html_feb19683e9a31ee020a50773be959587&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_a617a1611daeac048ce3090bfb428399.setContent(html_feb19683e9a31ee020a50773be959587);
#
#
#
#         marker_d4dda37e40ff82b5158878d26a892bac.bindPopup(popup_a617a1611daeac048ce3090bfb428399)
#         ;
#
#
#
#
#             var marker_4159779a95261ff49a8fb428145f6041 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_513fd43b8f2773bba8fad6289f47c944);
#
#
#         var popup_5d4a55115f095a7f5a30c63bb3224ae1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1a08e05f5ebdc151c229534ff81eb5b7 = $(`&lt;div id=&quot;html_1a08e05f5ebdc151c229534ff81eb5b7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_5d4a55115f095a7f5a30c63bb3224ae1.setContent(html_1a08e05f5ebdc151c229534ff81eb5b7);
#
#
#
#         marker_4159779a95261ff49a8fb428145f6041.bindPopup(popup_5d4a55115f095a7f5a30c63bb3224ae1)
#         ;
#
#
#
#
#             var marker_3c8225f17af74659b7bf98a0a3075e08 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_513fd43b8f2773bba8fad6289f47c944);
#
#
#         var popup_2200e3398959969dca50e19b45d3c596 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9f19aa735ef7ccb5a884789bcea2267b = $(`&lt;div id=&quot;html_9f19aa735ef7ccb5a884789bcea2267b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_2200e3398959969dca50e19b45d3c596.setContent(html_9f19aa735ef7ccb5a884789bcea2267b);
#
#
#
#         marker_
