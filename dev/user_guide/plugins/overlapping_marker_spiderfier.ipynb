# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7accd56efc26e4d581b5ba3f39491373 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7accd56efc26e4d581b5ba3f39491373&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7accd56efc26e4d581b5ba3f39491373 = L.map(
#                 &quot;map_7accd56efc26e4d581b5ba3f39491373&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8806a281d9ce0822203d3189012ea045 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8806a281d9ce0822203d3189012ea045.addTo(map_7accd56efc26e4d581b5ba3f39491373);
#
#
#             var marker_e6daae1287f6318134211b187e5c161c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_7accd56efc26e4d581b5ba3f39491373);
#
#
#         var popup_861e17e29a72e139987b6b6e43ed3323 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_779ae10e1b965104f5f7a7b1393eabe4 = $(`&lt;div id=&quot;html_779ae10e1b965104f5f7a7b1393eabe4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_861e17e29a72e139987b6b6e43ed3323.setContent(html_779ae10e1b965104f5f7a7b1393eabe4);
#
#
#
#         marker_e6daae1287f6318134211b187e5c161c.bindPopup(popup_861e17e29a72e139987b6b6e43ed3323)
#         ;
#
#
#
#
#             var marker_39718f627eb2a1519fea6c751090af76 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_7accd56efc26e4d581b5ba3f39491373);
#
#
#         var popup_a6a4b8f2e8e91b6e2e8e40d30aea1ddb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7941c9055f54c992a3640caabce34e3e = $(`&lt;div id=&quot;html_7941c9055f54c992a3640caabce34e3e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_a6a4b8f2e8e91b6e2e8e40d30aea1ddb.setContent(html_7941c9055f54c992a3640caabce34e3e);
#
#
#
#         marker_39718f627eb2a1519fea6c751090af76.bindPopup(popup_a6a4b8f2e8e91b6e2e8e40d30aea1ddb)
#         ;
#
#
#
#
#             var marker_8ef3c87f4c817dbb83640a2463bc982a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_7accd56efc26e4d581b5ba3f39491373);
#
#
#         var popup_c9de21d090a962c373d2599768e34168 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_294f447903a0aecc8fc94eed25158253 = $(`&lt;div id=&quot;html_294f447903a0aecc8fc94eed25158253&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_c9de21d090a962c373d2599768e34168.setContent(html_294f447903a0aecc8fc94eed25158253);
#
#
#
#         marker_8ef3c87f4c817dbb83640a2463bc982a.bindPopup(popup_c9de21d090a962c373d2599768e34168)
#         ;
#
#
#
#
#             var marker_fd785a0db56d2bf3bb247f26ec8d7519 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_7accd56efc26e4d581b5ba3f39491373);
#
#
#         var popup_e7fd9eaf4edc7c5f53d9ffafc2794af7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4c1eced8fea820278a5b88d837416705 = $(`&lt;div id=&quot;html_4c1eced8fea820278a5b88d837416705&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_e7fd9eaf4edc7c5f53d9ffafc2794af7.setContent(html_4c1eced8fea820278a5b88d837416705);
#
#
#
#         marker_fd785a0db56d2bf3bb247f26ec8d7519.bindPopup(popup_e7fd9eaf4edc7c5f53d9ffafc2794af7)
#         ;
#
#
#
#
#             var marker_901b4af4bad6fa72dc5258dee34f692d = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_7accd56efc26e4d581b5ba3f39491373);
#
#
#         var popup_b7774ff09569b2a02f780840502c80f2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_581367078dd0656da5b9e20320f8c861 = $(`&lt;div id=&quot;html_581367078dd0656da5b9e20320f8c861&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_b7774ff09569b2a02f780840502c80f2.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3e88592ae19fdaa22ca870b20f5e804b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3e88592ae19fdaa22ca870b20f5e804b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3e88592ae19fdaa22ca870b20f5e804b = L.map(
#                 &quot;map_3e88592ae19fdaa22ca870b20f5e804b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b2034c10dbd30951d7c43345c6a1b785 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b2034c10dbd30951d7c43345c6a1b785.addTo(map_3e88592ae19fdaa22ca870b20f5e804b);
#
#
#             var feature_group_1d4b04fc0caaf136b8eba96ba1bcc7fe = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_6bb4e5903bb43301f32c30d37aa977a6 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_1d4b04fc0caaf136b8eba96ba1bcc7fe);
#
#
#         var popup_26cabf808e222b23b5251a16776a4756 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ba7e2d518e6419fbd7e986c99d168479 = $(`&lt;div id=&quot;html_ba7e2d518e6419fbd7e986c99d168479&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_26cabf808e222b23b5251a16776a4756.setContent(html_ba7e2d518e6419fbd7e986c99d168479);
#
#
#
#         marker_6bb4e5903bb43301f32c30d37aa977a6.bindPopup(popup_26cabf808e222b23b5251a16776a4756)
#         ;
#
#
#
#
#             var marker_22b6cf3b9ac43dcf6b3be693d15d58fb = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_1d4b04fc0caaf136b8eba96ba1bcc7fe);
#
#
#         var popup_f888eda1e0ac0a0d6101168dd660caa7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_032b8e9bce114f94d61bfafb5e8d73e6 = $(`&lt;div id=&quot;html_032b8e9bce114f94d61bfafb5e8d73e6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_f888eda1e0ac0a0d6101168dd660caa7.setContent(html_032b8e9bce114f94d61bfafb5e8d73e6);
#
#
#
#         marker_22b6cf3b9ac43dcf6b3be693d15d58fb.bindPopup(popup_f888eda1e0ac0a0d6101168dd660caa7)
#         ;
#
#
#
#
#             var marker_3ca3a1e3f0bc154f60db499ceb62878c = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_1d4b04fc0caaf136b8eba96ba1bcc7fe);
#
#
#         var popup_2416c3c8313dac182f4c705bc8de60f3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2dc2ae1018814342b7de698e81151702 = $(`&lt;div id=&quot;html_2dc2ae1018814342b7de698e81151702&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_2416c3c8313dac182f4c705bc8de60f3.setContent(html_2dc2ae1018814342b7de698e81151702);
#
#
#
#         marker_3ca3a1e3f0bc154f60db499ceb62878c.bindPopup(popup_2416c3c8313dac182f4c705bc8de60f3)
#         ;
#
#
#
#
#             var marker_12c29e594b0c51c9341d01c499d268aa = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_1d4b04fc0caaf136b8eba96ba1bcc7fe);
#
#
#         var popup_11cac9da42c3dd381a15a8e79a798d07 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_066064e122174b16afd7db672783e087 = $(`&lt;div id=&quot;html_066064e122174b16afd7db672783e087&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_11cac9da42c3dd381a15a8e79a798d07.setContent(html_066064e122174b16afd7db672783e087);
#
#
#
#         marker_12c29e594b0c51c9341d01c499d268aa.bindPopup(popup_11cac9da42c3dd381a15a8e79a798d07)
#         ;
#
#
#
#
#             var marker_705a73d82dbcc0da121c33ef95f9a241 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_1d4b04fc0caaf136b8eba96ba1bcc7fe);
#
#
#         var popup_85858da64786bd45b08399ee58850762 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_595a51867520fde69bd2281cace8dd25 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_595a51867520fde69bd2281cace8dd25&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_595a51867520fde69bd2281cace8dd25 = L.map(
#                 &quot;map_595a51867520fde69bd2281cace8dd25&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_49debc602eab733945c5dcf2ffc62363 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_49debc602eab733945c5dcf2ffc62363.addTo(map_595a51867520fde69bd2281cace8dd25);
#
#
#             var feature_group_b33cb6a72131633b6551c3488924e184 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_b33cb6a72131633b6551c3488924e184.addTo(map_595a51867520fde69bd2281cace8dd25);
#
#
#             var feature_group_sub_group_cf71e625df3af4183e36f2d27929eab3 = L.featureGroup.subGroup(
#                 feature_group_b33cb6a72131633b6551c3488924e184
#             );
#
#
#             var marker_250c55f675903ec29086d0f8972ab31f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_cf71e625df3af4183e36f2d27929eab3);
#
#
#         var popup_549403860117924624e616e2d03e6a62 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_535389549fd100650507c31b3ddb7c1b = $(`&lt;div id=&quot;html_535389549fd100650507c31b3ddb7c1b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_549403860117924624e616e2d03e6a62.setContent(html_535389549fd100650507c31b3ddb7c1b);
#
#
#
#         marker_250c55f675903ec29086d0f8972ab31f.bindPopup(popup_549403860117924624e616e2d03e6a62)
#         ;
#
#
#
#
#             var marker_6a621e17c8bc152f379ef5ed140dbc0b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_cf71e625df3af4183e36f2d27929eab3);
#
#
#         var popup_a640ea97c51ac858bfbf1d128e2285c9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f826c9e582b226e24b99e03e848a3678 = $(`&lt;div id=&quot;html_f826c9e582b226e24b99e03e848a3678&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_a640ea97c51ac858bfbf1d128e2285c9.setContent(html_f826c9e582b226e24b99e03e848a3678);
#
#
#
#         marker_6a621e17c8bc152f379ef5ed140dbc0b.bindPopup(popup_a640ea97c51ac858bfbf1d128e2285c9)
#         ;
#
#
#
#
#             var marker_2a97b07b544385b165b3bf096c83d369 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_cf71e625df3af4183e36f2d27929eab3);
#
#
#         var popup_06958252ca0acee7f8868c2e963aff7d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_594cab13417aa52f018d701fae7b9cfc = $(`&lt;div id=&quot;html_594cab13417aa52f018d701fae7b9cfc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_06958252ca0acee7f8868c2e963aff7d.setContent(html_594cab13417aa52f018d701fae7b9cfc);
#
#
#
#         marker_2a97b07b544385b165b3bf096c83d369.bindPopup(popup_06958252ca0acee7f8868c2e963aff7d)
#         ;
#
#
#
#
#             var marker_7bc98ce1b9fda1a664650eb6fe59e407 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_cf71e625df3af4183e36f2d27929eab3);
#
#
#         var popup_b35d05996ad9ae500dab86ed339b6c27 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_417fc1742221bcf85dbadb2cb87c85a4 = $(`&lt;div id=&quot;html_417fc1742221bcf85dbadb2cb87c85a4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_b35d05996ad9ae500dab86ed339b6c27.setContent(html_417fc1742221bcf85dbadb2cb87c85a4);
#
#
#
#         marker_
