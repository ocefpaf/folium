# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cfb472236c53cb7019ab7f7b64987131 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cfb472236c53cb7019ab7f7b64987131&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cfb472236c53cb7019ab7f7b64987131 = L.map(
#                 &quot;map_cfb472236c53cb7019ab7f7b64987131&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_735adf50d522ff3558a30a99a02e2f2d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_735adf50d522ff3558a30a99a02e2f2d.addTo(map_cfb472236c53cb7019ab7f7b64987131);
#
#
#             var marker_ca86374317352325de7d78ee1ab24180 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_cfb472236c53cb7019ab7f7b64987131);
#
#
#         var popup_bcdd7f36cca604073de56ab686e02792 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8c6807935197bb1a70bf63016e41616e = $(`&lt;div id=&quot;html_8c6807935197bb1a70bf63016e41616e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_bcdd7f36cca604073de56ab686e02792.setContent(html_8c6807935197bb1a70bf63016e41616e);
#
#
#
#         marker_ca86374317352325de7d78ee1ab24180.bindPopup(popup_bcdd7f36cca604073de56ab686e02792)
#         ;
#
#
#
#
#             var marker_589a8a7bc48018688acebfaf7e10b35e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_cfb472236c53cb7019ab7f7b64987131);
#
#
#         var popup_ffef5622ce15f86058972ab1f6370686 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ed2a58944f8b3e3ddcb2f796c84f0047 = $(`&lt;div id=&quot;html_ed2a58944f8b3e3ddcb2f796c84f0047&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_ffef5622ce15f86058972ab1f6370686.setContent(html_ed2a58944f8b3e3ddcb2f796c84f0047);
#
#
#
#         marker_589a8a7bc48018688acebfaf7e10b35e.bindPopup(popup_ffef5622ce15f86058972ab1f6370686)
#         ;
#
#
#
#
#             var marker_9738e2308d474d089ed65af00bbd7ee0 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_cfb472236c53cb7019ab7f7b64987131);
#
#
#         var popup_12eaf8a18003a97acf47b324dc1bde9a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ef36c8dc62b189bd71156bf87606bdb5 = $(`&lt;div id=&quot;html_ef36c8dc62b189bd71156bf87606bdb5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_12eaf8a18003a97acf47b324dc1bde9a.setContent(html_ef36c8dc62b189bd71156bf87606bdb5);
#
#
#
#         marker_9738e2308d474d089ed65af00bbd7ee0.bindPopup(popup_12eaf8a18003a97acf47b324dc1bde9a)
#         ;
#
#
#
#
#             var marker_0b8b51445e9bd4a7a8772be208adbd94 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_cfb472236c53cb7019ab7f7b64987131);
#
#
#         var popup_8336fc904cd8e6cc6470ebf70b4c8c99 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7e29e44700841b45e8d26eafe7fb6cb1 = $(`&lt;div id=&quot;html_7e29e44700841b45e8d26eafe7fb6cb1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_8336fc904cd8e6cc6470ebf70b4c8c99.setContent(html_7e29e44700841b45e8d26eafe7fb6cb1);
#
#
#
#         marker_0b8b51445e9bd4a7a8772be208adbd94.bindPopup(popup_8336fc904cd8e6cc6470ebf70b4c8c99)
#         ;
#
#
#
#
#             var marker_02b4a37d14ea6e2edb85977d62071f44 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_cfb472236c53cb7019ab7f7b64987131);
#
#
#         var popup_deaf6ea728225de992c90d78cbcf971d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3dbc1cd332b2939ad6085d25936f8bfe = $(`&lt;div id=&quot;html_3dbc1cd332b2939ad6085d25936f8bfe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_deaf6ea728225de992c90d78cbcf971d.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cae537469bbfed9128b45bd446b56b7a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cae537469bbfed9128b45bd446b56b7a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cae537469bbfed9128b45bd446b56b7a = L.map(
#                 &quot;map_cae537469bbfed9128b45bd446b56b7a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d9d0a4ddfbd097101b5d0890b93a8d85 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d9d0a4ddfbd097101b5d0890b93a8d85.addTo(map_cae537469bbfed9128b45bd446b56b7a);
#
#
#             var feature_group_c970cec6fb89783c61c051d78c295cd8 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_6471d095f499bf953d1b36c2eeca3aed = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_c970cec6fb89783c61c051d78c295cd8);
#
#
#         var popup_51b2783067ca7b2f068b70f693a9a863 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cc76df1d9f7ba5b42ef70f08201c91a9 = $(`&lt;div id=&quot;html_cc76df1d9f7ba5b42ef70f08201c91a9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_51b2783067ca7b2f068b70f693a9a863.setContent(html_cc76df1d9f7ba5b42ef70f08201c91a9);
#
#
#
#         marker_6471d095f499bf953d1b36c2eeca3aed.bindPopup(popup_51b2783067ca7b2f068b70f693a9a863)
#         ;
#
#
#
#
#             var marker_05f3883fe3e7afdb1ba2acb90110d2a4 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_c970cec6fb89783c61c051d78c295cd8);
#
#
#         var popup_be3a6268875d1c7a6ace99fba21f4169 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fb94ee653e6499b6b00c34c00b97f28c = $(`&lt;div id=&quot;html_fb94ee653e6499b6b00c34c00b97f28c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_be3a6268875d1c7a6ace99fba21f4169.setContent(html_fb94ee653e6499b6b00c34c00b97f28c);
#
#
#
#         marker_05f3883fe3e7afdb1ba2acb90110d2a4.bindPopup(popup_be3a6268875d1c7a6ace99fba21f4169)
#         ;
#
#
#
#
#             var marker_fe288ad9b1dfb73644be5eef445718cd = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_c970cec6fb89783c61c051d78c295cd8);
#
#
#         var popup_bc97eab48278789ced82a026487d6fff = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_723049f175ba23a3316e0fddd057c758 = $(`&lt;div id=&quot;html_723049f175ba23a3316e0fddd057c758&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_bc97eab48278789ced82a026487d6fff.setContent(html_723049f175ba23a3316e0fddd057c758);
#
#
#
#         marker_fe288ad9b1dfb73644be5eef445718cd.bindPopup(popup_bc97eab48278789ced82a026487d6fff)
#         ;
#
#
#
#
#             var marker_cb672d027deffabeabe3c48e031a02c1 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_c970cec6fb89783c61c051d78c295cd8);
#
#
#         var popup_9e58d98aa4dcbe5b12c2bcee17dd7521 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4451f7d8af001b19df5e1030812cee17 = $(`&lt;div id=&quot;html_4451f7d8af001b19df5e1030812cee17&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_9e58d98aa4dcbe5b12c2bcee17dd7521.setContent(html_4451f7d8af001b19df5e1030812cee17);
#
#
#
#         marker_cb672d027deffabeabe3c48e031a02c1.bindPopup(popup_9e58d98aa4dcbe5b12c2bcee17dd7521)
#         ;
#
#
#
#
#             var marker_695272b78b5f709e75c3349bb36de127 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_c970cec6fb89783c61c051d78c295cd8);
#
#
#         var popup_f30505c91eb8ca438b6147072d0733b8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_341974d6cf3a229555cfb0451141e6c8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_341974d6cf3a229555cfb0451141e6c8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_341974d6cf3a229555cfb0451141e6c8 = L.map(
#                 &quot;map_341974d6cf3a229555cfb0451141e6c8&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_20993118386ee57f9413d0361a1ec495 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_20993118386ee57f9413d0361a1ec495.addTo(map_341974d6cf3a229555cfb0451141e6c8);
#
#
#             var feature_group_ee941fb00782bab4a15d6a2e4865548f = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_ee941fb00782bab4a15d6a2e4865548f.addTo(map_341974d6cf3a229555cfb0451141e6c8);
#
#
#             var feature_group_sub_group_92b0c285c5b10b1024ccef92acb74db9 = L.featureGroup.subGroup(
#                 feature_group_ee941fb00782bab4a15d6a2e4865548f
#             );
#
#
#             var marker_8f15af2a17de038d4e61dd1796adf24a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_92b0c285c5b10b1024ccef92acb74db9);
#
#
#         var popup_2b7fc1aad4ba86d4e326a78b62ac7520 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b2051f2c4bd1901aa2f65bae39aa1593 = $(`&lt;div id=&quot;html_b2051f2c4bd1901aa2f65bae39aa1593&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_2b7fc1aad4ba86d4e326a78b62ac7520.setContent(html_b2051f2c4bd1901aa2f65bae39aa1593);
#
#
#
#         marker_8f15af2a17de038d4e61dd1796adf24a.bindPopup(popup_2b7fc1aad4ba86d4e326a78b62ac7520)
#         ;
#
#
#
#
#             var marker_8ab1317ee1386044c3f58134d26019f3 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_92b0c285c5b10b1024ccef92acb74db9);
#
#
#         var popup_760b4b91c43441a56c2cef49b6628cb2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_57e246f96ea35ca7e663b695ab184a23 = $(`&lt;div id=&quot;html_57e246f96ea35ca7e663b695ab184a23&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_760b4b91c43441a56c2cef49b6628cb2.setContent(html_57e246f96ea35ca7e663b695ab184a23);
#
#
#
#         marker_8ab1317ee1386044c3f58134d26019f3.bindPopup(popup_760b4b91c43441a56c2cef49b6628cb2)
#         ;
#
#
#
#
#             var marker_2d4e9a9846068aebcc5ed8389a6434f9 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_92b0c285c5b10b1024ccef92acb74db9);
#
#
#         var popup_3e35f312d9b99cf8c5eadc7d7ee1731d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_721d45a0efee167120d0d7f40cd362de = $(`&lt;div id=&quot;html_721d45a0efee167120d0d7f40cd362de&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_3e35f312d9b99cf8c5eadc7d7ee1731d.setContent(html_721d45a0efee167120d0d7f40cd362de);
#
#
#
#         marker_2d4e9a9846068aebcc5ed8389a6434f9.bindPopup(popup_3e35f312d9b99cf8c5eadc7d7ee1731d)
#         ;
#
#
#
#
#             var marker_5041a5f08990f6b8ca6288459e30e2bf = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_92b0c285c5b10b1024ccef92acb74db9);
#
#
#         var popup_54d28ba33bcfa492178fbb470bad1b2c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_63e08a536694f691ede1e242c6bd27ec = $(`&lt;div id=&quot;html_63e08a536694f691ede1e242c6bd27ec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_54d28ba33bcfa492178fbb470bad1b2c.setContent(html_63e08a536694f691ede1e242c6bd27ec);
#
#
#
#         marker_
