# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9cca613fc2b8377a3f5c5d852990983a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9cca613fc2b8377a3f5c5d852990983a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9cca613fc2b8377a3f5c5d852990983a = L.map(
#                 &quot;map_9cca613fc2b8377a3f5c5d852990983a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_67168ffcb1fc85ec2e5833de85c2d310 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_67168ffcb1fc85ec2e5833de85c2d310.addTo(map_9cca613fc2b8377a3f5c5d852990983a);
#
#
#             var marker_6ed30464dc424c3a5f12a5c212ef95ee = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_9cca613fc2b8377a3f5c5d852990983a);
#
#
#         var popup_b91825352bb5b88e7bacde88c504a9d9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ec067d6c6d5e301b876490ca0e7f10e6 = $(`&lt;div id=&quot;html_ec067d6c6d5e301b876490ca0e7f10e6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_b91825352bb5b88e7bacde88c504a9d9.setContent(html_ec067d6c6d5e301b876490ca0e7f10e6);
#
#
#
#         marker_6ed30464dc424c3a5f12a5c212ef95ee.bindPopup(popup_b91825352bb5b88e7bacde88c504a9d9)
#         ;
#
#
#
#
#             var marker_8d8f398cc9d72ef81352f7a4998e308e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_9cca613fc2b8377a3f5c5d852990983a);
#
#
#         var popup_dafbb637c5339a64f74e3c7a6a6fed97 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ece74860b468814270b0072db0905a0c = $(`&lt;div id=&quot;html_ece74860b468814270b0072db0905a0c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_dafbb637c5339a64f74e3c7a6a6fed97.setContent(html_ece74860b468814270b0072db0905a0c);
#
#
#
#         marker_8d8f398cc9d72ef81352f7a4998e308e.bindPopup(popup_dafbb637c5339a64f74e3c7a6a6fed97)
#         ;
#
#
#
#
#             var marker_8aa36be86241b937036595f3b780c2b0 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_9cca613fc2b8377a3f5c5d852990983a);
#
#
#         var popup_5316fb1ff5e8c968a8bb27f16a9b0266 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cf2ca232bf8e91485d3e932fd6cefc2e = $(`&lt;div id=&quot;html_cf2ca232bf8e91485d3e932fd6cefc2e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_5316fb1ff5e8c968a8bb27f16a9b0266.setContent(html_cf2ca232bf8e91485d3e932fd6cefc2e);
#
#
#
#         marker_8aa36be86241b937036595f3b780c2b0.bindPopup(popup_5316fb1ff5e8c968a8bb27f16a9b0266)
#         ;
#
#
#
#
#             var marker_c2b45427c9d7716a2715415484649503 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_9cca613fc2b8377a3f5c5d852990983a);
#
#
#         var popup_277b6c1c251c028f445292b3380b60f2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c702f0eebed863a5398e4b2bf4fde92a = $(`&lt;div id=&quot;html_c702f0eebed863a5398e4b2bf4fde92a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_277b6c1c251c028f445292b3380b60f2.setContent(html_c702f0eebed863a5398e4b2bf4fde92a);
#
#
#
#         marker_c2b45427c9d7716a2715415484649503.bindPopup(popup_277b6c1c251c028f445292b3380b60f2)
#         ;
#
#
#
#
#             var marker_fa6e94a842d56f95797fa2359ec9a3a5 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_9cca613fc2b8377a3f5c5d852990983a);
#
#
#         var popup_450ec584a07e8b138f075a15740fa4b6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_96816048629112e2f11575b300c63fda = $(`&lt;div id=&quot;html_96816048629112e2f11575b300c63fda&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_450ec584a07e8b138f075a15740fa4b6.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2cd08684eccb21d8f285050747929f76 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2cd08684eccb21d8f285050747929f76&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2cd08684eccb21d8f285050747929f76 = L.map(
#                 &quot;map_2cd08684eccb21d8f285050747929f76&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a1ffdf9d12b8d675ace7f2974413f14b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a1ffdf9d12b8d675ace7f2974413f14b.addTo(map_2cd08684eccb21d8f285050747929f76);
#
#
#             var feature_group_5cd7cc5708de38ec170fe1f18209ef1e = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_d00dd7374aaea2cc34d66e313888d751 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_5cd7cc5708de38ec170fe1f18209ef1e);
#
#
#         var popup_0315f58efaf572efc3f4d5e7f7d7f19b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_65054a84839f3f17f81c81c812261281 = $(`&lt;div id=&quot;html_65054a84839f3f17f81c81c812261281&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_0315f58efaf572efc3f4d5e7f7d7f19b.setContent(html_65054a84839f3f17f81c81c812261281);
#
#
#
#         marker_d00dd7374aaea2cc34d66e313888d751.bindPopup(popup_0315f58efaf572efc3f4d5e7f7d7f19b)
#         ;
#
#
#
#
#             var marker_35f03d4bcf844a7cbaaebbe96440b735 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_5cd7cc5708de38ec170fe1f18209ef1e);
#
#
#         var popup_b59fe53c6cdbc4444350928c2b5e76f7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_df9e8caa585034b301dc632001721211 = $(`&lt;div id=&quot;html_df9e8caa585034b301dc632001721211&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_b59fe53c6cdbc4444350928c2b5e76f7.setContent(html_df9e8caa585034b301dc632001721211);
#
#
#
#         marker_35f03d4bcf844a7cbaaebbe96440b735.bindPopup(popup_b59fe53c6cdbc4444350928c2b5e76f7)
#         ;
#
#
#
#
#             var marker_d068085bce2a8687426cd8e08db9d315 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_5cd7cc5708de38ec170fe1f18209ef1e);
#
#
#         var popup_879d326381c6998db906ac9060ed1e47 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0badf749c0b6bdf7c33d0640a3951175 = $(`&lt;div id=&quot;html_0badf749c0b6bdf7c33d0640a3951175&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_879d326381c6998db906ac9060ed1e47.setContent(html_0badf749c0b6bdf7c33d0640a3951175);
#
#
#
#         marker_d068085bce2a8687426cd8e08db9d315.bindPopup(popup_879d326381c6998db906ac9060ed1e47)
#         ;
#
#
#
#
#             var marker_2cb0e7589e7bc64e36d56f9ee6ae1b83 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_5cd7cc5708de38ec170fe1f18209ef1e);
#
#
#         var popup_28aa055f4be1ead871569169b24607fb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_da8a7c4566225afc52aea5234f56d91b = $(`&lt;div id=&quot;html_da8a7c4566225afc52aea5234f56d91b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_28aa055f4be1ead871569169b24607fb.setContent(html_da8a7c4566225afc52aea5234f56d91b);
#
#
#
#         marker_2cb0e7589e7bc64e36d56f9ee6ae1b83.bindPopup(popup_28aa055f4be1ead871569169b24607fb)
#         ;
#
#
#
#
#             var marker_d44a923185888e730cd02e28e3782206 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_5cd7cc5708de38ec170fe1f18209ef1e);
#
#
#         var popup_2a69a2420757ea9d3fd2133b122661db = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b9dc10ccc5da81720985ca2864fefe14 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b9dc10ccc5da81720985ca2864fefe14&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b9dc10ccc5da81720985ca2864fefe14 = L.map(
#                 &quot;map_b9dc10ccc5da81720985ca2864fefe14&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_67ba76fe6ce2893e2d6f04c0371973f2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_67ba76fe6ce2893e2d6f04c0371973f2.addTo(map_b9dc10ccc5da81720985ca2864fefe14);
#
#
#             var feature_group_a9b5bdb7844763b63dcc572da93f632e = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_a9b5bdb7844763b63dcc572da93f632e.addTo(map_b9dc10ccc5da81720985ca2864fefe14);
#
#
#             var feature_group_sub_group_ee872eb05c82bd35927b429ab6add8db = L.featureGroup.subGroup(
#                 feature_group_a9b5bdb7844763b63dcc572da93f632e
#             );
#
#
#             var marker_e0ed2b113c2e5fbfe2ff9e4ab65389c2 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_ee872eb05c82bd35927b429ab6add8db);
#
#
#         var popup_b87a681330c9f9ca70483f2ad9e6ccc6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_372f223a29985c449d4fe4c239a16199 = $(`&lt;div id=&quot;html_372f223a29985c449d4fe4c239a16199&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_b87a681330c9f9ca70483f2ad9e6ccc6.setContent(html_372f223a29985c449d4fe4c239a16199);
#
#
#
#         marker_e0ed2b113c2e5fbfe2ff9e4ab65389c2.bindPopup(popup_b87a681330c9f9ca70483f2ad9e6ccc6)
#         ;
#
#
#
#
#             var marker_5bda805aaed85f6b565385d16fe199ab = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_ee872eb05c82bd35927b429ab6add8db);
#
#
#         var popup_b0bfff54e5866e1836cc20f0b9dcd936 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_541615e73cbd6711e317bd830a3a5b0c = $(`&lt;div id=&quot;html_541615e73cbd6711e317bd830a3a5b0c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_b0bfff54e5866e1836cc20f0b9dcd936.setContent(html_541615e73cbd6711e317bd830a3a5b0c);
#
#
#
#         marker_5bda805aaed85f6b565385d16fe199ab.bindPopup(popup_b0bfff54e5866e1836cc20f0b9dcd936)
#         ;
#
#
#
#
#             var marker_7551227774af3ec57917152b84f8d4a1 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_ee872eb05c82bd35927b429ab6add8db);
#
#
#         var popup_910f49babe014f80ad4a2d16972332b4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_856c102a5242ef3439af846d458eaa9f = $(`&lt;div id=&quot;html_856c102a5242ef3439af846d458eaa9f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_910f49babe014f80ad4a2d16972332b4.setContent(html_856c102a5242ef3439af846d458eaa9f);
#
#
#
#         marker_7551227774af3ec57917152b84f8d4a1.bindPopup(popup_910f49babe014f80ad4a2d16972332b4)
#         ;
#
#
#
#
#             var marker_bfac8e64254f5baa8544caf9004a6582 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_ee872eb05c82bd35927b429ab6add8db);
#
#
#         var popup_15c009ae597ced394e9d3ba6e96c4398 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9b80401a3aa84cfadf7186440859519c = $(`&lt;div id=&quot;html_9b80401a3aa84cfadf7186440859519c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_15c009ae597ced394e9d3ba6e96c4398.setContent(html_9b80401a3aa84cfadf7186440859519c);
#
#
#
#         marker_
