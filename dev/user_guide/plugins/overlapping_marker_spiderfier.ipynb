# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_aaf966ef5a1844378b5334fac7a588fd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_aaf966ef5a1844378b5334fac7a588fd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_aaf966ef5a1844378b5334fac7a588fd = L.map(
#                 &quot;map_aaf966ef5a1844378b5334fac7a588fd&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bfcc04cf5e050368b737942c7b226e41 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_bfcc04cf5e050368b737942c7b226e41.addTo(map_aaf966ef5a1844378b5334fac7a588fd);
#
#
#             var marker_dbeaf16de357134fc24c59faac551f35 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_aaf966ef5a1844378b5334fac7a588fd);
#
#
#         var popup_6b5387ee9ff17c4e6c47d5769f617fd0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ebf8adfcf981ff9d73e437b6858529d0 = $(`&lt;div id=&quot;html_ebf8adfcf981ff9d73e437b6858529d0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_6b5387ee9ff17c4e6c47d5769f617fd0.setContent(html_ebf8adfcf981ff9d73e437b6858529d0);
#
#
#
#         marker_dbeaf16de357134fc24c59faac551f35.bindPopup(popup_6b5387ee9ff17c4e6c47d5769f617fd0)
#         ;
#
#
#
#
#             var marker_9b6815c31dcf0e0f925b78c38f953e25 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_aaf966ef5a1844378b5334fac7a588fd);
#
#
#         var popup_a0b0154745543d4b3661eb2228756a48 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6549fded54fb4f40c70ed6ce06ca71ca = $(`&lt;div id=&quot;html_6549fded54fb4f40c70ed6ce06ca71ca&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_a0b0154745543d4b3661eb2228756a48.setContent(html_6549fded54fb4f40c70ed6ce06ca71ca);
#
#
#
#         marker_9b6815c31dcf0e0f925b78c38f953e25.bindPopup(popup_a0b0154745543d4b3661eb2228756a48)
#         ;
#
#
#
#
#             var marker_1d0b912098531cab7d7ee2e5f3a32f3c = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_aaf966ef5a1844378b5334fac7a588fd);
#
#
#         var popup_93a84b32bdd719f03c96b59cef457edb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a1217dbd69a721d6bc8b2861e0553ccb = $(`&lt;div id=&quot;html_a1217dbd69a721d6bc8b2861e0553ccb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_93a84b32bdd719f03c96b59cef457edb.setContent(html_a1217dbd69a721d6bc8b2861e0553ccb);
#
#
#
#         marker_1d0b912098531cab7d7ee2e5f3a32f3c.bindPopup(popup_93a84b32bdd719f03c96b59cef457edb)
#         ;
#
#
#
#
#             var marker_d9f249c831ea3909b89a0a8e7690b85f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_aaf966ef5a1844378b5334fac7a588fd);
#
#
#         var popup_9eea16c5b693bc2ea85a00d4e9a264cd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_550fb9bd78e98456c975dfa3db2d9808 = $(`&lt;div id=&quot;html_550fb9bd78e98456c975dfa3db2d9808&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_9eea16c5b693bc2ea85a00d4e9a264cd.setContent(html_550fb9bd78e98456c975dfa3db2d9808);
#
#
#
#         marker_d9f249c831ea3909b89a0a8e7690b85f.bindPopup(popup_9eea16c5b693bc2ea85a00d4e9a264cd)
#         ;
#
#
#
#
#             var marker_a809764cf21815288da087f885c5b0d8 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_aaf966ef5a1844378b5334fac7a588fd);
#
#
#         var popup_959ae92feeebfa98d482d3d791517cae = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0096a8ef148e2734a313be8a985b69ae = $(`&lt;div id=&quot;html_0096a8ef148e2734a313be8a985b69ae&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_959ae92feeebfa98d482d3d791517cae.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d1efdf671a1e1fc919f9e61960c962b3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d1efdf671a1e1fc919f9e61960c962b3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d1efdf671a1e1fc919f9e61960c962b3 = L.map(
#                 &quot;map_d1efdf671a1e1fc919f9e61960c962b3&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f3e7a5cf8c201e6bc44f6ac4bcd29c5e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f3e7a5cf8c201e6bc44f6ac4bcd29c5e.addTo(map_d1efdf671a1e1fc919f9e61960c962b3);
#
#
#             var feature_group_c9975f876d2fa710bc70a874cc8b759b = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_4ef5061207ad5b6352d1facb314a5e74 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_c9975f876d2fa710bc70a874cc8b759b);
#
#
#         var popup_929d04e6b82af03747e18ef21992f456 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8eae179caa4c64c809095bdf4aea5bcb = $(`&lt;div id=&quot;html_8eae179caa4c64c809095bdf4aea5bcb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_929d04e6b82af03747e18ef21992f456.setContent(html_8eae179caa4c64c809095bdf4aea5bcb);
#
#
#
#         marker_4ef5061207ad5b6352d1facb314a5e74.bindPopup(popup_929d04e6b82af03747e18ef21992f456)
#         ;
#
#
#
#
#             var marker_129070ddc80ebd09bc7625f40159788f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_c9975f876d2fa710bc70a874cc8b759b);
#
#
#         var popup_f5b5cd9e89e953991ae807df9adbc38d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_54494e593e870f5b6de221f9dfcfe5de = $(`&lt;div id=&quot;html_54494e593e870f5b6de221f9dfcfe5de&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_f5b5cd9e89e953991ae807df9adbc38d.setContent(html_54494e593e870f5b6de221f9dfcfe5de);
#
#
#
#         marker_129070ddc80ebd09bc7625f40159788f.bindPopup(popup_f5b5cd9e89e953991ae807df9adbc38d)
#         ;
#
#
#
#
#             var marker_5231830510ff7b3e69ba2ad9aa961c7a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_c9975f876d2fa710bc70a874cc8b759b);
#
#
#         var popup_af504f39bb121e0d340bbf7500f37271 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d07b80c81145244e08a6d116849122a3 = $(`&lt;div id=&quot;html_d07b80c81145244e08a6d116849122a3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_af504f39bb121e0d340bbf7500f37271.setContent(html_d07b80c81145244e08a6d116849122a3);
#
#
#
#         marker_5231830510ff7b3e69ba2ad9aa961c7a.bindPopup(popup_af504f39bb121e0d340bbf7500f37271)
#         ;
#
#
#
#
#             var marker_fcd380cc58cba34b2a4094d842c0aa49 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_c9975f876d2fa710bc70a874cc8b759b);
#
#
#         var popup_3374297699e5248ce644541ae5da061b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_808de00f099b98247d6468eb3b2c5898 = $(`&lt;div id=&quot;html_808de00f099b98247d6468eb3b2c5898&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_3374297699e5248ce644541ae5da061b.setContent(html_808de00f099b98247d6468eb3b2c5898);
#
#
#
#         marker_fcd380cc58cba34b2a4094d842c0aa49.bindPopup(popup_3374297699e5248ce644541ae5da061b)
#         ;
#
#
#
#
#             var marker_60b5d9c4ab05c1578462562abde973e7 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_c9975f876d2fa710bc70a874cc8b759b);
#
#
#         var popup_edb55671c290fcdf205e00a41614c1ed = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_74a20fc0b109c9f99c1496d2afed64a2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_74a20fc0b109c9f99c1496d2afed64a2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_74a20fc0b109c9f99c1496d2afed64a2 = L.map(
#                 &quot;map_74a20fc0b109c9f99c1496d2afed64a2&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d0039fc676a517fc28539e251490469e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d0039fc676a517fc28539e251490469e.addTo(map_74a20fc0b109c9f99c1496d2afed64a2);
#
#
#             var feature_group_8820e29941ac7de28af18b8e281692be = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_8820e29941ac7de28af18b8e281692be.addTo(map_74a20fc0b109c9f99c1496d2afed64a2);
#
#
#             var feature_group_sub_group_2dd8f97334bc4ab4202c327c4a01dfa2 = L.featureGroup.subGroup(
#                 feature_group_8820e29941ac7de28af18b8e281692be
#             );
#
#
#             var marker_bae3b435d5a1ee62ea5d5160a127903a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_2dd8f97334bc4ab4202c327c4a01dfa2);
#
#
#         var popup_11a3be608717300e071a3b023b262b6b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9536ac5025862885ce40ce076f10583d = $(`&lt;div id=&quot;html_9536ac5025862885ce40ce076f10583d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_11a3be608717300e071a3b023b262b6b.setContent(html_9536ac5025862885ce40ce076f10583d);
#
#
#
#         marker_bae3b435d5a1ee62ea5d5160a127903a.bindPopup(popup_11a3be608717300e071a3b023b262b6b)
#         ;
#
#
#
#
#             var marker_9b354b30dcf8cf0864136574b35877cc = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_2dd8f97334bc4ab4202c327c4a01dfa2);
#
#
#         var popup_b265d3282bc16547ade070db95e6cc95 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2b89f42a0007006e926c6f473086ef24 = $(`&lt;div id=&quot;html_2b89f42a0007006e926c6f473086ef24&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_b265d3282bc16547ade070db95e6cc95.setContent(html_2b89f42a0007006e926c6f473086ef24);
#
#
#
#         marker_9b354b30dcf8cf0864136574b35877cc.bindPopup(popup_b265d3282bc16547ade070db95e6cc95)
#         ;
#
#
#
#
#             var marker_d4b641737597da9e9e36ec3871037571 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_2dd8f97334bc4ab4202c327c4a01dfa2);
#
#
#         var popup_a5d8947b8c24e5c06d2d2c0f367ec7e1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9b03cf244892ed78365d350ac66fa11b = $(`&lt;div id=&quot;html_9b03cf244892ed78365d350ac66fa11b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_a5d8947b8c24e5c06d2d2c0f367ec7e1.setContent(html_9b03cf244892ed78365d350ac66fa11b);
#
#
#
#         marker_d4b641737597da9e9e36ec3871037571.bindPopup(popup_a5d8947b8c24e5c06d2d2c0f367ec7e1)
#         ;
#
#
#
#
#             var marker_0cf6c182563f8efdd18e010ef7b747b2 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_2dd8f97334bc4ab4202c327c4a01dfa2);
#
#
#         var popup_f2456e4ff36bcae52c94e493f2f8620d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_145a15cbbfa5c2e1e106c86acf52aa4c = $(`&lt;div id=&quot;html_145a15cbbfa5c2e1e106c86acf52aa4c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_f2456e4ff36bcae52c94e493f2f8620d.setContent(html_145a15cbbfa5c2e1e106c86acf52aa4c);
#
#
#
#         marker_
