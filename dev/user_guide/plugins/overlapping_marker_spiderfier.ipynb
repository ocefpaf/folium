# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a1b82b6d944b6b82240720ded5dd4385 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a1b82b6d944b6b82240720ded5dd4385&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a1b82b6d944b6b82240720ded5dd4385 = L.map(
#                 &quot;map_a1b82b6d944b6b82240720ded5dd4385&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4591a8e5fd11a1b09cdd553a7a615116 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4591a8e5fd11a1b09cdd553a7a615116.addTo(map_a1b82b6d944b6b82240720ded5dd4385);
#
#
#             var marker_d3be71f68981055cbbc0d16a3992a7d7 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_a1b82b6d944b6b82240720ded5dd4385);
#
#
#         var popup_8e5764876eda5c3672af1caeb62275fa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f5fa1994d4d718f01208628cf31f3e07 = $(`&lt;div id=&quot;html_f5fa1994d4d718f01208628cf31f3e07&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_8e5764876eda5c3672af1caeb62275fa.setContent(html_f5fa1994d4d718f01208628cf31f3e07);
#
#
#
#         marker_d3be71f68981055cbbc0d16a3992a7d7.bindPopup(popup_8e5764876eda5c3672af1caeb62275fa)
#         ;
#
#
#
#
#             var marker_4b67e4036d5e109cffeca227a6f8ce35 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_a1b82b6d944b6b82240720ded5dd4385);
#
#
#         var popup_62f317da8cfeb406caa3ee88346f4510 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_086e8c97cd385e710e6988c4fedbf3af = $(`&lt;div id=&quot;html_086e8c97cd385e710e6988c4fedbf3af&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_62f317da8cfeb406caa3ee88346f4510.setContent(html_086e8c97cd385e710e6988c4fedbf3af);
#
#
#
#         marker_4b67e4036d5e109cffeca227a6f8ce35.bindPopup(popup_62f317da8cfeb406caa3ee88346f4510)
#         ;
#
#
#
#
#             var marker_e9f9eb3b6863b07bec9c735b04b4bd1f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_a1b82b6d944b6b82240720ded5dd4385);
#
#
#         var popup_9071bf4230807db115462cc0525a9057 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8669c19aeace6d5ae55a201a695de1dd = $(`&lt;div id=&quot;html_8669c19aeace6d5ae55a201a695de1dd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_9071bf4230807db115462cc0525a9057.setContent(html_8669c19aeace6d5ae55a201a695de1dd);
#
#
#
#         marker_e9f9eb3b6863b07bec9c735b04b4bd1f.bindPopup(popup_9071bf4230807db115462cc0525a9057)
#         ;
#
#
#
#
#             var marker_7efc16bfd3c0c7882cb25801bc3fe257 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_a1b82b6d944b6b82240720ded5dd4385);
#
#
#         var popup_f7d7e3b1ae06f141f0d630d4b3808554 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_18f51a9b7d50b69c5ee933fb089c1e66 = $(`&lt;div id=&quot;html_18f51a9b7d50b69c5ee933fb089c1e66&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_f7d7e3b1ae06f141f0d630d4b3808554.setContent(html_18f51a9b7d50b69c5ee933fb089c1e66);
#
#
#
#         marker_7efc16bfd3c0c7882cb25801bc3fe257.bindPopup(popup_f7d7e3b1ae06f141f0d630d4b3808554)
#         ;
#
#
#
#
#             var marker_14b7b1fc593f9ff7825a84bb406a6632 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_a1b82b6d944b6b82240720ded5dd4385);
#
#
#         var popup_78c900635c73011d55e583afbc86c543 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3c054ff15d9af23f9cc7d3d48a561d4a = $(`&lt;div id=&quot;html_3c054ff15d9af23f9cc7d3d48a561d4a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_78c900635c73011d55e583afbc86c543.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d729471ffa4a0c0ae394d0789e84a437 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d729471ffa4a0c0ae394d0789e84a437&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d729471ffa4a0c0ae394d0789e84a437 = L.map(
#                 &quot;map_d729471ffa4a0c0ae394d0789e84a437&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f785389560d08b59a5c06bee139ef164 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f785389560d08b59a5c06bee139ef164.addTo(map_d729471ffa4a0c0ae394d0789e84a437);
#
#
#             var feature_group_45ee6a86f4726bc4094782fd7706a6ad = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_48420ef9dc18b9472324bbc63e3129a1 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_45ee6a86f4726bc4094782fd7706a6ad);
#
#
#         var popup_4eade1dad27d0df9628bdf2d047aac45 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4c0f805a2ccd9f2070e71e090704be07 = $(`&lt;div id=&quot;html_4c0f805a2ccd9f2070e71e090704be07&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_4eade1dad27d0df9628bdf2d047aac45.setContent(html_4c0f805a2ccd9f2070e71e090704be07);
#
#
#
#         marker_48420ef9dc18b9472324bbc63e3129a1.bindPopup(popup_4eade1dad27d0df9628bdf2d047aac45)
#         ;
#
#
#
#
#             var marker_54fffb999bfec51265cf6b9e6cee115d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_45ee6a86f4726bc4094782fd7706a6ad);
#
#
#         var popup_70566a53223dfde441cadfc1b7100be5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_513c7c88878fb2cd7c41f8c74970763b = $(`&lt;div id=&quot;html_513c7c88878fb2cd7c41f8c74970763b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_70566a53223dfde441cadfc1b7100be5.setContent(html_513c7c88878fb2cd7c41f8c74970763b);
#
#
#
#         marker_54fffb999bfec51265cf6b9e6cee115d.bindPopup(popup_70566a53223dfde441cadfc1b7100be5)
#         ;
#
#
#
#
#             var marker_730132fc89b3240af8a4881cfd0d8ff7 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_45ee6a86f4726bc4094782fd7706a6ad);
#
#
#         var popup_ceaf29dfac265b9675961d678389916d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b584d24250718f7fbe012f47e497d31e = $(`&lt;div id=&quot;html_b584d24250718f7fbe012f47e497d31e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_ceaf29dfac265b9675961d678389916d.setContent(html_b584d24250718f7fbe012f47e497d31e);
#
#
#
#         marker_730132fc89b3240af8a4881cfd0d8ff7.bindPopup(popup_ceaf29dfac265b9675961d678389916d)
#         ;
#
#
#
#
#             var marker_44dfededaedf468ad026942890bc3641 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_45ee6a86f4726bc4094782fd7706a6ad);
#
#
#         var popup_e2afdc92e6c2eb59ee5443a571ed60ca = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7f3366d4915ce81b9176aef5fc51f033 = $(`&lt;div id=&quot;html_7f3366d4915ce81b9176aef5fc51f033&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_e2afdc92e6c2eb59ee5443a571ed60ca.setContent(html_7f3366d4915ce81b9176aef5fc51f033);
#
#
#
#         marker_44dfededaedf468ad026942890bc3641.bindPopup(popup_e2afdc92e6c2eb59ee5443a571ed60ca)
#         ;
#
#
#
#
#             var marker_d6cbbc66e4a4f82dbb0e121e40f1bc9f = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_45ee6a86f4726bc4094782fd7706a6ad);
#
#
#         var popup_0f0ee4e75638823884ada0f303993288 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_658842b5a3a42388a04fcff6f3959724 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_658842b5a3a42388a04fcff6f3959724&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_658842b5a3a42388a04fcff6f3959724 = L.map(
#                 &quot;map_658842b5a3a42388a04fcff6f3959724&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5301d85922d18da934cbbb7f2f99a91b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5301d85922d18da934cbbb7f2f99a91b.addTo(map_658842b5a3a42388a04fcff6f3959724);
#
#
#             var feature_group_988ad2142697325e85bbf87b25711cc5 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_988ad2142697325e85bbf87b25711cc5.addTo(map_658842b5a3a42388a04fcff6f3959724);
#
#
#             var feature_group_sub_group_24ee6a389519fc239dcd1d0eafc970c1 = L.featureGroup.subGroup(
#                 feature_group_988ad2142697325e85bbf87b25711cc5
#             );
#
#
#             var marker_0709942083914d9384e272ea0c0020fe = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_24ee6a389519fc239dcd1d0eafc970c1);
#
#
#         var popup_36feca21651510422eb324ff5f91cbe4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3d14a56de31bdab2801b6386c5a9b8ab = $(`&lt;div id=&quot;html_3d14a56de31bdab2801b6386c5a9b8ab&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_36feca21651510422eb324ff5f91cbe4.setContent(html_3d14a56de31bdab2801b6386c5a9b8ab);
#
#
#
#         marker_0709942083914d9384e272ea0c0020fe.bindPopup(popup_36feca21651510422eb324ff5f91cbe4)
#         ;
#
#
#
#
#             var marker_e8456b5c8ce1a15f6c13e5b9d011d34f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_24ee6a389519fc239dcd1d0eafc970c1);
#
#
#         var popup_90ed5fc317b6ce34e3619af7c2f0398b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1e9869e39493b1712758c83350ddff40 = $(`&lt;div id=&quot;html_1e9869e39493b1712758c83350ddff40&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_90ed5fc317b6ce34e3619af7c2f0398b.setContent(html_1e9869e39493b1712758c83350ddff40);
#
#
#
#         marker_e8456b5c8ce1a15f6c13e5b9d011d34f.bindPopup(popup_90ed5fc317b6ce34e3619af7c2f0398b)
#         ;
#
#
#
#
#             var marker_82c1eff61568556df9ab6884b86a616f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_24ee6a389519fc239dcd1d0eafc970c1);
#
#
#         var popup_4a7d8c82e475641853bdbffc5bdd53b4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b36e12d66ae8727ba758dd7fa6c07dbf = $(`&lt;div id=&quot;html_b36e12d66ae8727ba758dd7fa6c07dbf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_4a7d8c82e475641853bdbffc5bdd53b4.setContent(html_b36e12d66ae8727ba758dd7fa6c07dbf);
#
#
#
#         marker_82c1eff61568556df9ab6884b86a616f.bindPopup(popup_4a7d8c82e475641853bdbffc5bdd53b4)
#         ;
#
#
#
#
#             var marker_4421057b82d4cd7584fcc64b86f7eb5a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_24ee6a389519fc239dcd1d0eafc970c1);
#
#
#         var popup_4e9353db569429c5e9d172a4fa30bae9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4982f2712108933cc2bd1737bf9463a1 = $(`&lt;div id=&quot;html_4982f2712108933cc2bd1737bf9463a1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_4e9353db569429c5e9d172a4fa30bae9.setContent(html_4982f2712108933cc2bd1737bf9463a1);
#
#
#
#         marker_
