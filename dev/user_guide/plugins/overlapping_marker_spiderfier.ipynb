# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_09e3db3cfbed0a2fd8019994a3a749ff {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_09e3db3cfbed0a2fd8019994a3a749ff&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_09e3db3cfbed0a2fd8019994a3a749ff = L.map(
#                 &quot;map_09e3db3cfbed0a2fd8019994a3a749ff&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_663b8720318e55e5eac9eb4f75a860c1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_663b8720318e55e5eac9eb4f75a860c1.addTo(map_09e3db3cfbed0a2fd8019994a3a749ff);
#
#
#             var marker_aa2afd63780744e1110310a27874aa70 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_09e3db3cfbed0a2fd8019994a3a749ff);
#
#
#         var popup_482008d93ec8b9c4c580782c24d52bbc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_907626fca766d647e4e4dbea079f0935 = $(`&lt;div id=&quot;html_907626fca766d647e4e4dbea079f0935&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_482008d93ec8b9c4c580782c24d52bbc.setContent(html_907626fca766d647e4e4dbea079f0935);
#
#
#
#         marker_aa2afd63780744e1110310a27874aa70.bindPopup(popup_482008d93ec8b9c4c580782c24d52bbc)
#         ;
#
#
#
#
#             var marker_802de7369df8ec733bc7308e408d7576 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_09e3db3cfbed0a2fd8019994a3a749ff);
#
#
#         var popup_9c50bbea8ec85a60e790995dd3a5e369 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8a4a2ff6508ee5f080839a9a5c239f8c = $(`&lt;div id=&quot;html_8a4a2ff6508ee5f080839a9a5c239f8c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_9c50bbea8ec85a60e790995dd3a5e369.setContent(html_8a4a2ff6508ee5f080839a9a5c239f8c);
#
#
#
#         marker_802de7369df8ec733bc7308e408d7576.bindPopup(popup_9c50bbea8ec85a60e790995dd3a5e369)
#         ;
#
#
#
#
#             var marker_8ac86d231d0802c5e3f6c080c024159a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_09e3db3cfbed0a2fd8019994a3a749ff);
#
#
#         var popup_d592eeab5d203d27eb31f340470c4093 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b505e69a19cd16d5117dfda061ccebf1 = $(`&lt;div id=&quot;html_b505e69a19cd16d5117dfda061ccebf1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_d592eeab5d203d27eb31f340470c4093.setContent(html_b505e69a19cd16d5117dfda061ccebf1);
#
#
#
#         marker_8ac86d231d0802c5e3f6c080c024159a.bindPopup(popup_d592eeab5d203d27eb31f340470c4093)
#         ;
#
#
#
#
#             var marker_7ba9b74bb6dc20aca18b9f404b71f893 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_09e3db3cfbed0a2fd8019994a3a749ff);
#
#
#         var popup_952a54169d9c36df1a5300be7e3af897 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4739aa49670a164090c9c6e3caba1873 = $(`&lt;div id=&quot;html_4739aa49670a164090c9c6e3caba1873&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_952a54169d9c36df1a5300be7e3af897.setContent(html_4739aa49670a164090c9c6e3caba1873);
#
#
#
#         marker_7ba9b74bb6dc20aca18b9f404b71f893.bindPopup(popup_952a54169d9c36df1a5300be7e3af897)
#         ;
#
#
#
#
#             var marker_d2a7cf26322dcc7a7a29a5f2e2967b62 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_09e3db3cfbed0a2fd8019994a3a749ff);
#
#
#         var popup_48e56f2d26c3a6b952067efcbced79b0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e9a05d23663829ec991650447aa19c6a = $(`&lt;div id=&quot;html_e9a05d23663829ec991650447aa19c6a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_48e56f2d26c3a6b952067efcbced79b0.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1b34bddc57e66cf7f578afcb92c6fc4c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1b34bddc57e66cf7f578afcb92c6fc4c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1b34bddc57e66cf7f578afcb92c6fc4c = L.map(
#                 &quot;map_1b34bddc57e66cf7f578afcb92c6fc4c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7bba04b157087af77f1f14efae286650 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7bba04b157087af77f1f14efae286650.addTo(map_1b34bddc57e66cf7f578afcb92c6fc4c);
#
#
#             var feature_group_4275ed06b476b5ec3b51a83ef4e01b77 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_ea96625643b39b0280447791564b4483 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_4275ed06b476b5ec3b51a83ef4e01b77);
#
#
#         var popup_38c8e18d5e541390ebb067b4522e7de2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8efa14856532746735bd386d5314e227 = $(`&lt;div id=&quot;html_8efa14856532746735bd386d5314e227&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_38c8e18d5e541390ebb067b4522e7de2.setContent(html_8efa14856532746735bd386d5314e227);
#
#
#
#         marker_ea96625643b39b0280447791564b4483.bindPopup(popup_38c8e18d5e541390ebb067b4522e7de2)
#         ;
#
#
#
#
#             var marker_f0fc2485b3e82da145135e007f5e89b8 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_4275ed06b476b5ec3b51a83ef4e01b77);
#
#
#         var popup_eddd79f2de95fc04a927e6a5a838e496 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_09b86def8a3da25e94530f3d52db9197 = $(`&lt;div id=&quot;html_09b86def8a3da25e94530f3d52db9197&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_eddd79f2de95fc04a927e6a5a838e496.setContent(html_09b86def8a3da25e94530f3d52db9197);
#
#
#
#         marker_f0fc2485b3e82da145135e007f5e89b8.bindPopup(popup_eddd79f2de95fc04a927e6a5a838e496)
#         ;
#
#
#
#
#             var marker_60a1a76e8429fb769a5da135c050b204 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_4275ed06b476b5ec3b51a83ef4e01b77);
#
#
#         var popup_bcb5b0a0070035a1d8cdaeec0dc692f9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_422f9daad70ea0cd3798304ea2eb44f7 = $(`&lt;div id=&quot;html_422f9daad70ea0cd3798304ea2eb44f7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_bcb5b0a0070035a1d8cdaeec0dc692f9.setContent(html_422f9daad70ea0cd3798304ea2eb44f7);
#
#
#
#         marker_60a1a76e8429fb769a5da135c050b204.bindPopup(popup_bcb5b0a0070035a1d8cdaeec0dc692f9)
#         ;
#
#
#
#
#             var marker_243704d6d3b13ed300feac49d2ded26f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_4275ed06b476b5ec3b51a83ef4e01b77);
#
#
#         var popup_009ec13cc7b2cac2a21e63dfbbcef2b3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b192fb999554a16072b7edd9b91fdd1d = $(`&lt;div id=&quot;html_b192fb999554a16072b7edd9b91fdd1d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_009ec13cc7b2cac2a21e63dfbbcef2b3.setContent(html_b192fb999554a16072b7edd9b91fdd1d);
#
#
#
#         marker_243704d6d3b13ed300feac49d2ded26f.bindPopup(popup_009ec13cc7b2cac2a21e63dfbbcef2b3)
#         ;
#
#
#
#
#             var marker_62c47b4db0fb3a417fc57aa07d52d7e4 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_4275ed06b476b5ec3b51a83ef4e01b77);
#
#
#         var popup_6f251fbb0e276d8323f7057a7bd29476 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_af26425da6850b8032a7109e8786a616 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_af26425da6850b8032a7109e8786a616&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_af26425da6850b8032a7109e8786a616 = L.map(
#                 &quot;map_af26425da6850b8032a7109e8786a616&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_795a20ab2cf59cb7b3d3e84a629084e7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_795a20ab2cf59cb7b3d3e84a629084e7.addTo(map_af26425da6850b8032a7109e8786a616);
#
#
#             var feature_group_c9c56c08b0e3d64d31b0a2d76fc6b81b = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_c9c56c08b0e3d64d31b0a2d76fc6b81b.addTo(map_af26425da6850b8032a7109e8786a616);
#
#
#             var feature_group_sub_group_24ab5f339988a7ef7fdd31ed133909b7 = L.featureGroup.subGroup(
#                 feature_group_c9c56c08b0e3d64d31b0a2d76fc6b81b
#             );
#
#
#             var marker_6b2c690a99475bab1ed6051177954be3 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_24ab5f339988a7ef7fdd31ed133909b7);
#
#
#         var popup_fa526faaba53fccd681b2cc584f9d7d9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d9d46e206ca7d765477a2abe082fa024 = $(`&lt;div id=&quot;html_d9d46e206ca7d765477a2abe082fa024&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_fa526faaba53fccd681b2cc584f9d7d9.setContent(html_d9d46e206ca7d765477a2abe082fa024);
#
#
#
#         marker_6b2c690a99475bab1ed6051177954be3.bindPopup(popup_fa526faaba53fccd681b2cc584f9d7d9)
#         ;
#
#
#
#
#             var marker_48d08a61258d85ef08babe70b69b82dd = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_24ab5f339988a7ef7fdd31ed133909b7);
#
#
#         var popup_2215acce4ef66607c9d0973403769781 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_597f1386a2a0bca0ad2f8ac5fe6cf04a = $(`&lt;div id=&quot;html_597f1386a2a0bca0ad2f8ac5fe6cf04a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_2215acce4ef66607c9d0973403769781.setContent(html_597f1386a2a0bca0ad2f8ac5fe6cf04a);
#
#
#
#         marker_48d08a61258d85ef08babe70b69b82dd.bindPopup(popup_2215acce4ef66607c9d0973403769781)
#         ;
#
#
#
#
#             var marker_48501e8c428f5db272c1ea136bbfacb2 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_24ab5f339988a7ef7fdd31ed133909b7);
#
#
#         var popup_d5e688ba1eb6f651cf88ec24836dc8b9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_942d1ee77413785742a9af4e3b3fa461 = $(`&lt;div id=&quot;html_942d1ee77413785742a9af4e3b3fa461&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_d5e688ba1eb6f651cf88ec24836dc8b9.setContent(html_942d1ee77413785742a9af4e3b3fa461);
#
#
#
#         marker_48501e8c428f5db272c1ea136bbfacb2.bindPopup(popup_d5e688ba1eb6f651cf88ec24836dc8b9)
#         ;
#
#
#
#
#             var marker_885599a225671bb064d34b3477506d2b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_24ab5f339988a7ef7fdd31ed133909b7);
#
#
#         var popup_a8490547f37d704069fc6a2ecb777017 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7cdb79968ac2488433d9db7f15903538 = $(`&lt;div id=&quot;html_7cdb79968ac2488433d9db7f15903538&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_a8490547f37d704069fc6a2ecb777017.setContent(html_7cdb79968ac2488433d9db7f15903538);
#
#
#
#         marker_
