# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_862c4b52cc3a0a4cdcb0f80995d0c00b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_862c4b52cc3a0a4cdcb0f80995d0c00b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_862c4b52cc3a0a4cdcb0f80995d0c00b = L.map(
#                 &quot;map_862c4b52cc3a0a4cdcb0f80995d0c00b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_82203801c7513a75d8a28819bf69901c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_82203801c7513a75d8a28819bf69901c.addTo(map_862c4b52cc3a0a4cdcb0f80995d0c00b);
#
#
#             var marker_1ec5ae9f2e8bfc77fc7a6fd32dd3d92c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_862c4b52cc3a0a4cdcb0f80995d0c00b);
#
#
#         var popup_de71cc3df45ecde127180d43768abbb9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_153aed5175df17f799c135d3d36ab1f7 = $(`&lt;div id=&quot;html_153aed5175df17f799c135d3d36ab1f7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_de71cc3df45ecde127180d43768abbb9.setContent(html_153aed5175df17f799c135d3d36ab1f7);
#
#
#
#         marker_1ec5ae9f2e8bfc77fc7a6fd32dd3d92c.bindPopup(popup_de71cc3df45ecde127180d43768abbb9)
#         ;
#
#
#
#
#             var marker_06c036ae67bd84ad72e00f1ba38773aa = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_862c4b52cc3a0a4cdcb0f80995d0c00b);
#
#
#         var popup_11542b3a4adaaa3084ace824d911a1a5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6f9cc4e6f40f4a9eba55665fe081559b = $(`&lt;div id=&quot;html_6f9cc4e6f40f4a9eba55665fe081559b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_11542b3a4adaaa3084ace824d911a1a5.setContent(html_6f9cc4e6f40f4a9eba55665fe081559b);
#
#
#
#         marker_06c036ae67bd84ad72e00f1ba38773aa.bindPopup(popup_11542b3a4adaaa3084ace824d911a1a5)
#         ;
#
#
#
#
#             var marker_8c965a75e904c5da9e21243f91f12370 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_862c4b52cc3a0a4cdcb0f80995d0c00b);
#
#
#         var popup_029671d7720b56aaf7f01154b1b0f6e7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bd69466e20fde636a94934c048db80ff = $(`&lt;div id=&quot;html_bd69466e20fde636a94934c048db80ff&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_029671d7720b56aaf7f01154b1b0f6e7.setContent(html_bd69466e20fde636a94934c048db80ff);
#
#
#
#         marker_8c965a75e904c5da9e21243f91f12370.bindPopup(popup_029671d7720b56aaf7f01154b1b0f6e7)
#         ;
#
#
#
#
#             var marker_179f1747644d02e5dbc7ce47db16f910 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_862c4b52cc3a0a4cdcb0f80995d0c00b);
#
#
#         var popup_cd215b599155657ab2acee08b3409475 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_407189dd484c2fe3e8930e61446d53fd = $(`&lt;div id=&quot;html_407189dd484c2fe3e8930e61446d53fd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_cd215b599155657ab2acee08b3409475.setContent(html_407189dd484c2fe3e8930e61446d53fd);
#
#
#
#         marker_179f1747644d02e5dbc7ce47db16f910.bindPopup(popup_cd215b599155657ab2acee08b3409475)
#         ;
#
#
#
#
#             var marker_52f81a84dc52be617cf392b6e60408e7 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_862c4b52cc3a0a4cdcb0f80995d0c00b);
#
#
#         var popup_da723ea8569e25e52c6de0ee28a6abef = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f81d64e22dd2000b174cee06ab82e866 = $(`&lt;div id=&quot;html_f81d64e22dd2000b174cee06ab82e866&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_da723ea8569e25e52c6de0ee28a6abef.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_20b2767cd42e1d9c55459ccc4414f739 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_20b2767cd42e1d9c55459ccc4414f739&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_20b2767cd42e1d9c55459ccc4414f739 = L.map(
#                 &quot;map_20b2767cd42e1d9c55459ccc4414f739&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_15f88a1cffcf4eef2397ed4c3cc3c6f2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_15f88a1cffcf4eef2397ed4c3cc3c6f2.addTo(map_20b2767cd42e1d9c55459ccc4414f739);
#
#
#             var feature_group_a190e5501b089154374f367b0d239a47 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_e3ab238765c5bfa7160361ceaab8e5c6 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_a190e5501b089154374f367b0d239a47);
#
#
#         var popup_0eeaeeec86b545fc0f56e02d4f56ba83 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_36da0ca3ea642037163d27bc1d99c16d = $(`&lt;div id=&quot;html_36da0ca3ea642037163d27bc1d99c16d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_0eeaeeec86b545fc0f56e02d4f56ba83.setContent(html_36da0ca3ea642037163d27bc1d99c16d);
#
#
#
#         marker_e3ab238765c5bfa7160361ceaab8e5c6.bindPopup(popup_0eeaeeec86b545fc0f56e02d4f56ba83)
#         ;
#
#
#
#
#             var marker_4d2c457d6b39c4482d554780db57800f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_a190e5501b089154374f367b0d239a47);
#
#
#         var popup_8954befe8499d0cd286036add79346f8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c531c67e5bfc741758eefa0f07dfb429 = $(`&lt;div id=&quot;html_c531c67e5bfc741758eefa0f07dfb429&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_8954befe8499d0cd286036add79346f8.setContent(html_c531c67e5bfc741758eefa0f07dfb429);
#
#
#
#         marker_4d2c457d6b39c4482d554780db57800f.bindPopup(popup_8954befe8499d0cd286036add79346f8)
#         ;
#
#
#
#
#             var marker_a872d31ba9fc015a6c3891d05491d68e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_a190e5501b089154374f367b0d239a47);
#
#
#         var popup_83b0c5a19e94534f0759017c04ec635c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2848525735b49337ff5f92d886dd3615 = $(`&lt;div id=&quot;html_2848525735b49337ff5f92d886dd3615&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_83b0c5a19e94534f0759017c04ec635c.setContent(html_2848525735b49337ff5f92d886dd3615);
#
#
#
#         marker_a872d31ba9fc015a6c3891d05491d68e.bindPopup(popup_83b0c5a19e94534f0759017c04ec635c)
#         ;
#
#
#
#
#             var marker_0de19a1b467e3ece8fac5ae7bff8f686 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_a190e5501b089154374f367b0d239a47);
#
#
#         var popup_938f49f3a1bd724f2d824765d3b210af = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_94dffabf6f1281181c004d3725c57f8b = $(`&lt;div id=&quot;html_94dffabf6f1281181c004d3725c57f8b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_938f49f3a1bd724f2d824765d3b210af.setContent(html_94dffabf6f1281181c004d3725c57f8b);
#
#
#
#         marker_0de19a1b467e3ece8fac5ae7bff8f686.bindPopup(popup_938f49f3a1bd724f2d824765d3b210af)
#         ;
#
#
#
#
#             var marker_ab1a690ad402b84b0229e966e1de5b10 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_a190e5501b089154374f367b0d239a47);
#
#
#         var popup_89fcdf933db0ffaae883dda82668d980 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5ecefff9ba4d5ff15e5b0531a862adef {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5ecefff9ba4d5ff15e5b0531a862adef&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5ecefff9ba4d5ff15e5b0531a862adef = L.map(
#                 &quot;map_5ecefff9ba4d5ff15e5b0531a862adef&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_54a8f3b6fdd48f88185fb8551aed2ce9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_54a8f3b6fdd48f88185fb8551aed2ce9.addTo(map_5ecefff9ba4d5ff15e5b0531a862adef);
#
#
#             var feature_group_65bbe5166f91893e86c3654f2bc89d5f = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_65bbe5166f91893e86c3654f2bc89d5f.addTo(map_5ecefff9ba4d5ff15e5b0531a862adef);
#
#
#             var feature_group_sub_group_6977acf4e6c65fddd93b9e76f8611c7f = L.featureGroup.subGroup(
#                 feature_group_65bbe5166f91893e86c3654f2bc89d5f
#             );
#
#
#             var marker_59eaa4179db8b0c845fdc8390f001edd = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_6977acf4e6c65fddd93b9e76f8611c7f);
#
#
#         var popup_7bff5b7c11573efe95aafd694f24e05d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_903d15c410d64082de546b54c1908e4e = $(`&lt;div id=&quot;html_903d15c410d64082de546b54c1908e4e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_7bff5b7c11573efe95aafd694f24e05d.setContent(html_903d15c410d64082de546b54c1908e4e);
#
#
#
#         marker_59eaa4179db8b0c845fdc8390f001edd.bindPopup(popup_7bff5b7c11573efe95aafd694f24e05d)
#         ;
#
#
#
#
#             var marker_0638964221e3ca14caeb8e7698e89e7a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_6977acf4e6c65fddd93b9e76f8611c7f);
#
#
#         var popup_e7136f3a5ca1f4582568a37c9570e7e9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fb36201e760a7fa4737647e19fd22b56 = $(`&lt;div id=&quot;html_fb36201e760a7fa4737647e19fd22b56&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_e7136f3a5ca1f4582568a37c9570e7e9.setContent(html_fb36201e760a7fa4737647e19fd22b56);
#
#
#
#         marker_0638964221e3ca14caeb8e7698e89e7a.bindPopup(popup_e7136f3a5ca1f4582568a37c9570e7e9)
#         ;
#
#
#
#
#             var marker_2d843783f7868f587ef13c492eaed97d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_6977acf4e6c65fddd93b9e76f8611c7f);
#
#
#         var popup_75b3e2ab56d95c0725f97d96fabb8fb8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_798e0a94eb5973b7e0dbdb7b534de804 = $(`&lt;div id=&quot;html_798e0a94eb5973b7e0dbdb7b534de804&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_75b3e2ab56d95c0725f97d96fabb8fb8.setContent(html_798e0a94eb5973b7e0dbdb7b534de804);
#
#
#
#         marker_2d843783f7868f587ef13c492eaed97d.bindPopup(popup_75b3e2ab56d95c0725f97d96fabb8fb8)
#         ;
#
#
#
#
#             var marker_834c668127d857c852cdb4396e25f8a3 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_6977acf4e6c65fddd93b9e76f8611c7f);
#
#
#         var popup_80e2575ad06a2e1094ea2be1c2bbf2a9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4bcbaa5a4de642df14e7228b39622136 = $(`&lt;div id=&quot;html_4bcbaa5a4de642df14e7228b39622136&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_80e2575ad06a2e1094ea2be1c2bbf2a9.setContent(html_4bcbaa5a4de642df14e7228b39622136);
#
#
#
#         marker_
