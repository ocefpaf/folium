# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_817ac6b2bd56b230067a886bff060f89 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_817ac6b2bd56b230067a886bff060f89&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_817ac6b2bd56b230067a886bff060f89 = L.map(
#                 &quot;map_817ac6b2bd56b230067a886bff060f89&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a0f3e8309c70c0e5040234b50bd85b1d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a0f3e8309c70c0e5040234b50bd85b1d.addTo(map_817ac6b2bd56b230067a886bff060f89);
#
#
#             var marker_b8afe7d501477e6ed9f67918df1fa0f7 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_817ac6b2bd56b230067a886bff060f89);
#
#
#         var popup_56fddd8ba61535154669313498870a4c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_75d562399b6e478e7ef21477cce54917 = $(`&lt;div id=&quot;html_75d562399b6e478e7ef21477cce54917&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_56fddd8ba61535154669313498870a4c.setContent(html_75d562399b6e478e7ef21477cce54917);
#
#
#
#         marker_b8afe7d501477e6ed9f67918df1fa0f7.bindPopup(popup_56fddd8ba61535154669313498870a4c)
#         ;
#
#
#
#
#             var marker_f39a6dae217f227a711afca5099b5912 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_817ac6b2bd56b230067a886bff060f89);
#
#
#         var popup_659f0eb71576cbddb34d1a0f6a28fd01 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cf41c4a41c309790fff77f64f1ee62be = $(`&lt;div id=&quot;html_cf41c4a41c309790fff77f64f1ee62be&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_659f0eb71576cbddb34d1a0f6a28fd01.setContent(html_cf41c4a41c309790fff77f64f1ee62be);
#
#
#
#         marker_f39a6dae217f227a711afca5099b5912.bindPopup(popup_659f0eb71576cbddb34d1a0f6a28fd01)
#         ;
#
#
#
#
#             var marker_a0f6e888d68efa8580fe3c54fe5bd7cc = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_817ac6b2bd56b230067a886bff060f89);
#
#
#         var popup_ea890e2017d9be0bae0481271b123c3b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_879f5bdcddb7069ab14c3c3e59042342 = $(`&lt;div id=&quot;html_879f5bdcddb7069ab14c3c3e59042342&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_ea890e2017d9be0bae0481271b123c3b.setContent(html_879f5bdcddb7069ab14c3c3e59042342);
#
#
#
#         marker_a0f6e888d68efa8580fe3c54fe5bd7cc.bindPopup(popup_ea890e2017d9be0bae0481271b123c3b)
#         ;
#
#
#
#
#             var marker_ff4b580ff3b99dbbea73532d50048130 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_817ac6b2bd56b230067a886bff060f89);
#
#
#         var popup_57f779ae43a90c3c4234792077986156 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_934d181f10029093d7e0f0fddd2ef3dd = $(`&lt;div id=&quot;html_934d181f10029093d7e0f0fddd2ef3dd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_57f779ae43a90c3c4234792077986156.setContent(html_934d181f10029093d7e0f0fddd2ef3dd);
#
#
#
#         marker_ff4b580ff3b99dbbea73532d50048130.bindPopup(popup_57f779ae43a90c3c4234792077986156)
#         ;
#
#
#
#
#             var marker_463e48d2da4faea177617a451c17deb5 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_817ac6b2bd56b230067a886bff060f89);
#
#
#         var popup_806b9bb2a81a7d5dffe03ba328e4c442 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6f64eb64f29c4490c2f7bb22507d0746 = $(`&lt;div id=&quot;html_6f64eb64f29c4490c2f7bb22507d0746&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_806b9bb2a81a7d5dffe03ba328e4c442.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_40545c35bc311dcd8cea4e0f869c21b1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_40545c35bc311dcd8cea4e0f869c21b1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_40545c35bc311dcd8cea4e0f869c21b1 = L.map(
#                 &quot;map_40545c35bc311dcd8cea4e0f869c21b1&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_79f64eb923daa25e4c2c14e50893bc7d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_79f64eb923daa25e4c2c14e50893bc7d.addTo(map_40545c35bc311dcd8cea4e0f869c21b1);
#
#
#             var feature_group_c18a1fabc64a6c176cf11b36e3c8696d = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_fa644fb43c281fadf3a74d13013f8f01 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_c18a1fabc64a6c176cf11b36e3c8696d);
#
#
#         var popup_ba0d746e35033c9de980163647ac84c3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_173b582b069445be323c9d1a1219fa70 = $(`&lt;div id=&quot;html_173b582b069445be323c9d1a1219fa70&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_ba0d746e35033c9de980163647ac84c3.setContent(html_173b582b069445be323c9d1a1219fa70);
#
#
#
#         marker_fa644fb43c281fadf3a74d13013f8f01.bindPopup(popup_ba0d746e35033c9de980163647ac84c3)
#         ;
#
#
#
#
#             var marker_f8ac4c269dc80b78038aafea2e48a3a0 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_c18a1fabc64a6c176cf11b36e3c8696d);
#
#
#         var popup_7334b8e1bd650f37ed8020def1053313 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_19aff9add71ebc4983cf28528dc35b7b = $(`&lt;div id=&quot;html_19aff9add71ebc4983cf28528dc35b7b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_7334b8e1bd650f37ed8020def1053313.setContent(html_19aff9add71ebc4983cf28528dc35b7b);
#
#
#
#         marker_f8ac4c269dc80b78038aafea2e48a3a0.bindPopup(popup_7334b8e1bd650f37ed8020def1053313)
#         ;
#
#
#
#
#             var marker_8faf6355f261ed43df41d5c37955c221 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_c18a1fabc64a6c176cf11b36e3c8696d);
#
#
#         var popup_bd9e4c087828d794b678014708a4facb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dab44f946ebdc9e48009a89f2554964d = $(`&lt;div id=&quot;html_dab44f946ebdc9e48009a89f2554964d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_bd9e4c087828d794b678014708a4facb.setContent(html_dab44f946ebdc9e48009a89f2554964d);
#
#
#
#         marker_8faf6355f261ed43df41d5c37955c221.bindPopup(popup_bd9e4c087828d794b678014708a4facb)
#         ;
#
#
#
#
#             var marker_253c83db52ef4491885d655a0da95adf = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_c18a1fabc64a6c176cf11b36e3c8696d);
#
#
#         var popup_83bf151e851b4739a867ec0f11460df0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_509fa09863614d20d919b3e668359fe4 = $(`&lt;div id=&quot;html_509fa09863614d20d919b3e668359fe4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_83bf151e851b4739a867ec0f11460df0.setContent(html_509fa09863614d20d919b3e668359fe4);
#
#
#
#         marker_253c83db52ef4491885d655a0da95adf.bindPopup(popup_83bf151e851b4739a867ec0f11460df0)
#         ;
#
#
#
#
#             var marker_cbd5cd0b985edf43211b5fbe9514ee0a = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_c18a1fabc64a6c176cf11b36e3c8696d);
#
#
#         var popup_8949721aa0c03b341e347249b97e4911 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_dcff7b855ce301b2c276105148058769 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_dcff7b855ce301b2c276105148058769&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_dcff7b855ce301b2c276105148058769 = L.map(
#                 &quot;map_dcff7b855ce301b2c276105148058769&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8ea98a2a9e5f514fe5e4cd31a0d8c773 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8ea98a2a9e5f514fe5e4cd31a0d8c773.addTo(map_dcff7b855ce301b2c276105148058769);
#
#
#             var feature_group_f0b7665dac086699e71c6369300e19ae = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_f0b7665dac086699e71c6369300e19ae.addTo(map_dcff7b855ce301b2c276105148058769);
#
#
#             var feature_group_sub_group_420294f1d59bd1d3928e2a9dc6e4c02d = L.featureGroup.subGroup(
#                 feature_group_f0b7665dac086699e71c6369300e19ae
#             );
#
#
#             var marker_0900405818ad723a02a7cc1cc296fad7 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_420294f1d59bd1d3928e2a9dc6e4c02d);
#
#
#         var popup_2f06f287b70575a9abc0c21fc19aa1b7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_061d28499d900a5713b621a149cef74b = $(`&lt;div id=&quot;html_061d28499d900a5713b621a149cef74b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_2f06f287b70575a9abc0c21fc19aa1b7.setContent(html_061d28499d900a5713b621a149cef74b);
#
#
#
#         marker_0900405818ad723a02a7cc1cc296fad7.bindPopup(popup_2f06f287b70575a9abc0c21fc19aa1b7)
#         ;
#
#
#
#
#             var marker_b019018bec9d63a010e202af4c0db81a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_420294f1d59bd1d3928e2a9dc6e4c02d);
#
#
#         var popup_077a120bdb72eb73171b110df1d2ee74 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3870fc3e1d2c2505df7bdd135be57953 = $(`&lt;div id=&quot;html_3870fc3e1d2c2505df7bdd135be57953&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_077a120bdb72eb73171b110df1d2ee74.setContent(html_3870fc3e1d2c2505df7bdd135be57953);
#
#
#
#         marker_b019018bec9d63a010e202af4c0db81a.bindPopup(popup_077a120bdb72eb73171b110df1d2ee74)
#         ;
#
#
#
#
#             var marker_dff9078f5975ca94e1717d5ec10fe537 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_420294f1d59bd1d3928e2a9dc6e4c02d);
#
#
#         var popup_416031eff901a22e711cb835ac83c849 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_64c16491b6da39c78c335b0df03c7d02 = $(`&lt;div id=&quot;html_64c16491b6da39c78c335b0df03c7d02&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_416031eff901a22e711cb835ac83c849.setContent(html_64c16491b6da39c78c335b0df03c7d02);
#
#
#
#         marker_dff9078f5975ca94e1717d5ec10fe537.bindPopup(popup_416031eff901a22e711cb835ac83c849)
#         ;
#
#
#
#
#             var marker_8c67dffcd4feea23bd6f5e70f834d376 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_420294f1d59bd1d3928e2a9dc6e4c02d);
#
#
#         var popup_59641e62ef1926868999d0acdc16e7bf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_04e5076dfa846246575350a0a9b65b5e = $(`&lt;div id=&quot;html_04e5076dfa846246575350a0a9b65b5e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_59641e62ef1926868999d0acdc16e7bf.setContent(html_04e5076dfa846246575350a0a9b65b5e);
#
#
#
#         marker_
