# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b18cceebe4013ef5a3ae57ad15ce571d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b18cceebe4013ef5a3ae57ad15ce571d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b18cceebe4013ef5a3ae57ad15ce571d = L.map(
#                 &quot;map_b18cceebe4013ef5a3ae57ad15ce571d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6a8b0f2c0c0db2c350be14dc81b13707 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6a8b0f2c0c0db2c350be14dc81b13707.addTo(map_b18cceebe4013ef5a3ae57ad15ce571d);
#
#
#             var marker_8d27bf36f9839da6f529924abd9458c9 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_b18cceebe4013ef5a3ae57ad15ce571d);
#
#
#         var popup_53aa9451ef8127e46bbfe3686ccb634b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5059d1360b4afd9f92053f445f1c2f84 = $(`&lt;div id=&quot;html_5059d1360b4afd9f92053f445f1c2f84&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_53aa9451ef8127e46bbfe3686ccb634b.setContent(html_5059d1360b4afd9f92053f445f1c2f84);
#
#
#
#         marker_8d27bf36f9839da6f529924abd9458c9.bindPopup(popup_53aa9451ef8127e46bbfe3686ccb634b)
#         ;
#
#
#
#
#             var marker_370275595242657e8a59c562b4cc2cfe = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_b18cceebe4013ef5a3ae57ad15ce571d);
#
#
#         var popup_893e7dab72f280918b9cef405221b755 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_063cdfa25809823fd251363fee8eab40 = $(`&lt;div id=&quot;html_063cdfa25809823fd251363fee8eab40&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_893e7dab72f280918b9cef405221b755.setContent(html_063cdfa25809823fd251363fee8eab40);
#
#
#
#         marker_370275595242657e8a59c562b4cc2cfe.bindPopup(popup_893e7dab72f280918b9cef405221b755)
#         ;
#
#
#
#
#             var marker_a8692bc51ad0767b462b4610bfa7f178 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_b18cceebe4013ef5a3ae57ad15ce571d);
#
#
#         var popup_b3389d163e9c66f122f0628f3bc3a26a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9ba555881aaf2731cb832968052c96c3 = $(`&lt;div id=&quot;html_9ba555881aaf2731cb832968052c96c3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_b3389d163e9c66f122f0628f3bc3a26a.setContent(html_9ba555881aaf2731cb832968052c96c3);
#
#
#
#         marker_a8692bc51ad0767b462b4610bfa7f178.bindPopup(popup_b3389d163e9c66f122f0628f3bc3a26a)
#         ;
#
#
#
#
#             var marker_f4bd553052cc3ef44c5e8006dbfbdcd9 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_b18cceebe4013ef5a3ae57ad15ce571d);
#
#
#         var popup_2d22874625cad40de12bf32fe6a690c6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0d555adc1c219f67f9e03a222bd35155 = $(`&lt;div id=&quot;html_0d555adc1c219f67f9e03a222bd35155&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_2d22874625cad40de12bf32fe6a690c6.setContent(html_0d555adc1c219f67f9e03a222bd35155);
#
#
#
#         marker_f4bd553052cc3ef44c5e8006dbfbdcd9.bindPopup(popup_2d22874625cad40de12bf32fe6a690c6)
#         ;
#
#
#
#
#             var marker_d81d672f80812b8e13af1683c680652b = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_b18cceebe4013ef5a3ae57ad15ce571d);
#
#
#         var popup_5b25da6032e75c6f5207b2cc55f6acab = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_400dbfe2f19b4721c1c905bf4522395d = $(`&lt;div id=&quot;html_400dbfe2f19b4721c1c905bf4522395d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_5b25da6032e75c6f5207b2cc55f6acab.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e641e1611588e1c640b4eb5d626aadb2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e641e1611588e1c640b4eb5d626aadb2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e641e1611588e1c640b4eb5d626aadb2 = L.map(
#                 &quot;map_e641e1611588e1c640b4eb5d626aadb2&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e36e4d433028f0927f506002cd8b8e4a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e36e4d433028f0927f506002cd8b8e4a.addTo(map_e641e1611588e1c640b4eb5d626aadb2);
#
#
#             var feature_group_b9e8c8cabddefeaeef3041bb75e43caf = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_f0e1a7b8476df2b4362b2dd747c919ef = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_b9e8c8cabddefeaeef3041bb75e43caf);
#
#
#         var popup_627ff42ee6b177a06a6d656e45949578 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a7f90fd672ebc5864684e12c660b1035 = $(`&lt;div id=&quot;html_a7f90fd672ebc5864684e12c660b1035&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_627ff42ee6b177a06a6d656e45949578.setContent(html_a7f90fd672ebc5864684e12c660b1035);
#
#
#
#         marker_f0e1a7b8476df2b4362b2dd747c919ef.bindPopup(popup_627ff42ee6b177a06a6d656e45949578)
#         ;
#
#
#
#
#             var marker_834625397fa0228e511bc7f7f14eb995 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_b9e8c8cabddefeaeef3041bb75e43caf);
#
#
#         var popup_25394bba61bbf39e7223a1d1dfe55be3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b007aebf4224d5f247b53cb68375f300 = $(`&lt;div id=&quot;html_b007aebf4224d5f247b53cb68375f300&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_25394bba61bbf39e7223a1d1dfe55be3.setContent(html_b007aebf4224d5f247b53cb68375f300);
#
#
#
#         marker_834625397fa0228e511bc7f7f14eb995.bindPopup(popup_25394bba61bbf39e7223a1d1dfe55be3)
#         ;
#
#
#
#
#             var marker_fe8ec94f4e252941dd1e3f6a86c45939 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_b9e8c8cabddefeaeef3041bb75e43caf);
#
#
#         var popup_a3219a68c93aee563d03ab741bba4990 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1c26a276590909cd8016d7e56e9e1c0f = $(`&lt;div id=&quot;html_1c26a276590909cd8016d7e56e9e1c0f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_a3219a68c93aee563d03ab741bba4990.setContent(html_1c26a276590909cd8016d7e56e9e1c0f);
#
#
#
#         marker_fe8ec94f4e252941dd1e3f6a86c45939.bindPopup(popup_a3219a68c93aee563d03ab741bba4990)
#         ;
#
#
#
#
#             var marker_f16a5ba2c664d10425ee112a7a408ca0 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_b9e8c8cabddefeaeef3041bb75e43caf);
#
#
#         var popup_06918a50eb591adb4798fc080f4675ea = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_494a487a99e8f37356a7dd799bb8c62f = $(`&lt;div id=&quot;html_494a487a99e8f37356a7dd799bb8c62f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_06918a50eb591adb4798fc080f4675ea.setContent(html_494a487a99e8f37356a7dd799bb8c62f);
#
#
#
#         marker_f16a5ba2c664d10425ee112a7a408ca0.bindPopup(popup_06918a50eb591adb4798fc080f4675ea)
#         ;
#
#
#
#
#             var marker_8d4928a0a3a26fdc2a29544cc4ba16a4 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_b9e8c8cabddefeaeef3041bb75e43caf);
#
#
#         var popup_a5cd2ad0cd124eb17b97b5a18eb36b34 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d4baa465a5803a2c78be6c2159e6cf40 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d4baa465a5803a2c78be6c2159e6cf40&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d4baa465a5803a2c78be6c2159e6cf40 = L.map(
#                 &quot;map_d4baa465a5803a2c78be6c2159e6cf40&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bb9b860690f01858b2edd6ced471a4cc = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_bb9b860690f01858b2edd6ced471a4cc.addTo(map_d4baa465a5803a2c78be6c2159e6cf40);
#
#
#             var feature_group_4d354351832904553df5f4bc41bc124e = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_4d354351832904553df5f4bc41bc124e.addTo(map_d4baa465a5803a2c78be6c2159e6cf40);
#
#
#             var feature_group_sub_group_b401313a2b92282647fed91edb97e5e9 = L.featureGroup.subGroup(
#                 feature_group_4d354351832904553df5f4bc41bc124e
#             );
#
#
#             var marker_b79fa136754aa953c9326383e5fcca0b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_b401313a2b92282647fed91edb97e5e9);
#
#
#         var popup_5c2398d887a50c68596d7f67ff8245e0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_200f67fb9c8374bec43e0626a7c560a1 = $(`&lt;div id=&quot;html_200f67fb9c8374bec43e0626a7c560a1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_5c2398d887a50c68596d7f67ff8245e0.setContent(html_200f67fb9c8374bec43e0626a7c560a1);
#
#
#
#         marker_b79fa136754aa953c9326383e5fcca0b.bindPopup(popup_5c2398d887a50c68596d7f67ff8245e0)
#         ;
#
#
#
#
#             var marker_ac4e94a624fe9805eb335b08edae1cf5 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_b401313a2b92282647fed91edb97e5e9);
#
#
#         var popup_291250275df16a63187d17ff4bc18864 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b333311e6ce18b416e067644fa62482a = $(`&lt;div id=&quot;html_b333311e6ce18b416e067644fa62482a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_291250275df16a63187d17ff4bc18864.setContent(html_b333311e6ce18b416e067644fa62482a);
#
#
#
#         marker_ac4e94a624fe9805eb335b08edae1cf5.bindPopup(popup_291250275df16a63187d17ff4bc18864)
#         ;
#
#
#
#
#             var marker_660e511c7ab2902aeff8a06cd8a9826c = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_b401313a2b92282647fed91edb97e5e9);
#
#
#         var popup_78c2a81bf92fda58f207c7960ea93507 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e164c61477a0abaa5ec226862a997420 = $(`&lt;div id=&quot;html_e164c61477a0abaa5ec226862a997420&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_78c2a81bf92fda58f207c7960ea93507.setContent(html_e164c61477a0abaa5ec226862a997420);
#
#
#
#         marker_660e511c7ab2902aeff8a06cd8a9826c.bindPopup(popup_78c2a81bf92fda58f207c7960ea93507)
#         ;
#
#
#
#
#             var marker_19f7fe76c1e6927b46ec1d39888c7405 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_b401313a2b92282647fed91edb97e5e9);
#
#
#         var popup_eff205a13ab40f1742b858efcca51c9e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_46129cec306cda226fd34b504ca15516 = $(`&lt;div id=&quot;html_46129cec306cda226fd34b504ca15516&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_eff205a13ab40f1742b858efcca51c9e.setContent(html_46129cec306cda226fd34b504ca15516);
#
#
#
#         marker_
