# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e93440610a51ed321688020b7912a873 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e93440610a51ed321688020b7912a873&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e93440610a51ed321688020b7912a873 = L.map(
#                 &quot;map_e93440610a51ed321688020b7912a873&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c4c4630534e20c59beb064f3621037f4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c4c4630534e20c59beb064f3621037f4.addTo(map_e93440610a51ed321688020b7912a873);
#
#
#             var marker_f723f67b8b8b978c900ca4eaa6c8f54d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_e93440610a51ed321688020b7912a873);
#
#
#         var popup_ff0b703440474ab18a32e1d5c61a9aa5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c26ac68446ac32ac79e50ca2c78bf1eb = $(`&lt;div id=&quot;html_c26ac68446ac32ac79e50ca2c78bf1eb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_ff0b703440474ab18a32e1d5c61a9aa5.setContent(html_c26ac68446ac32ac79e50ca2c78bf1eb);
#
#
#
#         marker_f723f67b8b8b978c900ca4eaa6c8f54d.bindPopup(popup_ff0b703440474ab18a32e1d5c61a9aa5)
#         ;
#
#
#
#
#             var marker_7e369679acb93c6cb8e81060a29e80b4 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_e93440610a51ed321688020b7912a873);
#
#
#         var popup_94ebf2be27cb3a5808c0d972981dd3d7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d6135a8a1ae8a0b5ad6cfa598bec8dc1 = $(`&lt;div id=&quot;html_d6135a8a1ae8a0b5ad6cfa598bec8dc1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_94ebf2be27cb3a5808c0d972981dd3d7.setContent(html_d6135a8a1ae8a0b5ad6cfa598bec8dc1);
#
#
#
#         marker_7e369679acb93c6cb8e81060a29e80b4.bindPopup(popup_94ebf2be27cb3a5808c0d972981dd3d7)
#         ;
#
#
#
#
#             var marker_326a4ecf7126aea16a9d210efaed7e02 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_e93440610a51ed321688020b7912a873);
#
#
#         var popup_346e62c1a6eebdcb89367acca2991d4b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2d92401842192bdf97a2d3da3c88963a = $(`&lt;div id=&quot;html_2d92401842192bdf97a2d3da3c88963a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_346e62c1a6eebdcb89367acca2991d4b.setContent(html_2d92401842192bdf97a2d3da3c88963a);
#
#
#
#         marker_326a4ecf7126aea16a9d210efaed7e02.bindPopup(popup_346e62c1a6eebdcb89367acca2991d4b)
#         ;
#
#
#
#
#             var marker_ff788a3c85c315a5453144c76c95131c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_e93440610a51ed321688020b7912a873);
#
#
#         var popup_21da547388cba074c42910a1f491da82 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e6e823232879ae327493cfc45e588659 = $(`&lt;div id=&quot;html_e6e823232879ae327493cfc45e588659&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_21da547388cba074c42910a1f491da82.setContent(html_e6e823232879ae327493cfc45e588659);
#
#
#
#         marker_ff788a3c85c315a5453144c76c95131c.bindPopup(popup_21da547388cba074c42910a1f491da82)
#         ;
#
#
#
#
#             var marker_1c9c5d681203d9dd3a618f6a054ae1ab = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_e93440610a51ed321688020b7912a873);
#
#
#         var popup_2969fcf70e0cf43abf72e469deac2884 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8ca152ee449383025142f1e122d8a914 = $(`&lt;div id=&quot;html_8ca152ee449383025142f1e122d8a914&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_2969fcf70e0cf43abf72e469deac2884.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5f3184a60330dca584038d118a4ae6e5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5f3184a60330dca584038d118a4ae6e5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5f3184a60330dca584038d118a4ae6e5 = L.map(
#                 &quot;map_5f3184a60330dca584038d118a4ae6e5&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8b192522256e0802fe427f240c3aaca4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8b192522256e0802fe427f240c3aaca4.addTo(map_5f3184a60330dca584038d118a4ae6e5);
#
#
#             var feature_group_36f76aa4b5131e7f59aa462c9f9cc1e4 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_742875c8ca42c21dd0a949e630697a05 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_36f76aa4b5131e7f59aa462c9f9cc1e4);
#
#
#         var popup_8fc221a4a99456b572e4c956fb9e944e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_926f84cc3043e8b6417b31f54ddfb630 = $(`&lt;div id=&quot;html_926f84cc3043e8b6417b31f54ddfb630&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_8fc221a4a99456b572e4c956fb9e944e.setContent(html_926f84cc3043e8b6417b31f54ddfb630);
#
#
#
#         marker_742875c8ca42c21dd0a949e630697a05.bindPopup(popup_8fc221a4a99456b572e4c956fb9e944e)
#         ;
#
#
#
#
#             var marker_947b567c599d732e84b97bc76b951b4c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_36f76aa4b5131e7f59aa462c9f9cc1e4);
#
#
#         var popup_c96a35c2536232b8fa87a888957352d9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_aa98fc7cc73e129b4a6285c2bf66fad2 = $(`&lt;div id=&quot;html_aa98fc7cc73e129b4a6285c2bf66fad2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_c96a35c2536232b8fa87a888957352d9.setContent(html_aa98fc7cc73e129b4a6285c2bf66fad2);
#
#
#
#         marker_947b567c599d732e84b97bc76b951b4c.bindPopup(popup_c96a35c2536232b8fa87a888957352d9)
#         ;
#
#
#
#
#             var marker_0df3f737e82b3d240649462a2d3aef9f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_36f76aa4b5131e7f59aa462c9f9cc1e4);
#
#
#         var popup_ccadb3a950ce7f73b1a33462ca0e6ccc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7c22626652b7e7e472e723326acc8834 = $(`&lt;div id=&quot;html_7c22626652b7e7e472e723326acc8834&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_ccadb3a950ce7f73b1a33462ca0e6ccc.setContent(html_7c22626652b7e7e472e723326acc8834);
#
#
#
#         marker_0df3f737e82b3d240649462a2d3aef9f.bindPopup(popup_ccadb3a950ce7f73b1a33462ca0e6ccc)
#         ;
#
#
#
#
#             var marker_edeb99c7a332e230bbead0fc943ce938 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_36f76aa4b5131e7f59aa462c9f9cc1e4);
#
#
#         var popup_98081e5ca0bbe2b66c6771eff02af530 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_137e3256eb20ffe9614378e187fc21ec = $(`&lt;div id=&quot;html_137e3256eb20ffe9614378e187fc21ec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_98081e5ca0bbe2b66c6771eff02af530.setContent(html_137e3256eb20ffe9614378e187fc21ec);
#
#
#
#         marker_edeb99c7a332e230bbead0fc943ce938.bindPopup(popup_98081e5ca0bbe2b66c6771eff02af530)
#         ;
#
#
#
#
#             var marker_19f296bf41daba48022c45e466be6c72 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_36f76aa4b5131e7f59aa462c9f9cc1e4);
#
#
#         var popup_f032f4f258227b821d334243332ad5af = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_aed68da914655b84d8fb82ac3884968a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_aed68da914655b84d8fb82ac3884968a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_aed68da914655b84d8fb82ac3884968a = L.map(
#                 &quot;map_aed68da914655b84d8fb82ac3884968a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c144b79af6af16662077103e16e5e811 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c144b79af6af16662077103e16e5e811.addTo(map_aed68da914655b84d8fb82ac3884968a);
#
#
#             var feature_group_f41088499da5738898c70df85b19c2e5 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_f41088499da5738898c70df85b19c2e5.addTo(map_aed68da914655b84d8fb82ac3884968a);
#
#
#             var feature_group_sub_group_8b6410c0f29d43422625258808ec583d = L.featureGroup.subGroup(
#                 feature_group_f41088499da5738898c70df85b19c2e5
#             );
#
#
#             var marker_0b10b503c7a67e7881e941ed6bd68ae1 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_8b6410c0f29d43422625258808ec583d);
#
#
#         var popup_d2c7a7c2f5814de881fe4e144f7d04d9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f0644861410b335f56a4e064d1049fb5 = $(`&lt;div id=&quot;html_f0644861410b335f56a4e064d1049fb5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_d2c7a7c2f5814de881fe4e144f7d04d9.setContent(html_f0644861410b335f56a4e064d1049fb5);
#
#
#
#         marker_0b10b503c7a67e7881e941ed6bd68ae1.bindPopup(popup_d2c7a7c2f5814de881fe4e144f7d04d9)
#         ;
#
#
#
#
#             var marker_ce28378d2d979fa629db2a4b6e2437fa = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_8b6410c0f29d43422625258808ec583d);
#
#
#         var popup_40a19a91f676cf653a076d71df18cb36 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8f13fdc71c50bfaf80c314a00702cc75 = $(`&lt;div id=&quot;html_8f13fdc71c50bfaf80c314a00702cc75&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_40a19a91f676cf653a076d71df18cb36.setContent(html_8f13fdc71c50bfaf80c314a00702cc75);
#
#
#
#         marker_ce28378d2d979fa629db2a4b6e2437fa.bindPopup(popup_40a19a91f676cf653a076d71df18cb36)
#         ;
#
#
#
#
#             var marker_0a9012881d206d24068855decfb76c24 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_8b6410c0f29d43422625258808ec583d);
#
#
#         var popup_a2186f459c6fcd603100f181ab48db22 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7c73dffa34124c1dbd4cfb4713e7b1f2 = $(`&lt;div id=&quot;html_7c73dffa34124c1dbd4cfb4713e7b1f2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_a2186f459c6fcd603100f181ab48db22.setContent(html_7c73dffa34124c1dbd4cfb4713e7b1f2);
#
#
#
#         marker_0a9012881d206d24068855decfb76c24.bindPopup(popup_a2186f459c6fcd603100f181ab48db22)
#         ;
#
#
#
#
#             var marker_aac5f0ef1eee85d1d21b4182a930d98a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_8b6410c0f29d43422625258808ec583d);
#
#
#         var popup_61435c4b46c72a3d55683b87af09c3b3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4562ca40bf4df9b0e3d686010839b6e1 = $(`&lt;div id=&quot;html_4562ca40bf4df9b0e3d686010839b6e1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_61435c4b46c72a3d55683b87af09c3b3.setContent(html_4562ca40bf4df9b0e3d686010839b6e1);
#
#
#
#         marker_
