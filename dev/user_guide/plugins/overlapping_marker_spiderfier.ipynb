# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_97def82af764e4af1356bbfc95eb141d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_97def82af764e4af1356bbfc95eb141d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_97def82af764e4af1356bbfc95eb141d = L.map(
#                 &quot;map_97def82af764e4af1356bbfc95eb141d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a35ed088bc95d4eb8c93552ba19fd27a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a35ed088bc95d4eb8c93552ba19fd27a.addTo(map_97def82af764e4af1356bbfc95eb141d);
#
#
#             var marker_1017c124f9b8cac029cea688102d1a50 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_97def82af764e4af1356bbfc95eb141d);
#
#
#         var popup_c643cd3d5e83b6f9b3b4e2f87739f0bb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_601355cecd4f324a647201352a253b22 = $(`&lt;div id=&quot;html_601355cecd4f324a647201352a253b22&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_c643cd3d5e83b6f9b3b4e2f87739f0bb.setContent(html_601355cecd4f324a647201352a253b22);
#
#
#
#         marker_1017c124f9b8cac029cea688102d1a50.bindPopup(popup_c643cd3d5e83b6f9b3b4e2f87739f0bb)
#         ;
#
#
#
#
#             var marker_62b8adf584703f116e7ee1a267e97f33 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_97def82af764e4af1356bbfc95eb141d);
#
#
#         var popup_50611af54d69560386716e37833ce82d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b4b5db1269470a8561f94c7b6e037510 = $(`&lt;div id=&quot;html_b4b5db1269470a8561f94c7b6e037510&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_50611af54d69560386716e37833ce82d.setContent(html_b4b5db1269470a8561f94c7b6e037510);
#
#
#
#         marker_62b8adf584703f116e7ee1a267e97f33.bindPopup(popup_50611af54d69560386716e37833ce82d)
#         ;
#
#
#
#
#             var marker_06f9eb3106dcdcba3edfce45bcf570e9 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_97def82af764e4af1356bbfc95eb141d);
#
#
#         var popup_4a18097a21d0957b552bd8226f8369ea = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_63b36590095efe705ff347384f1e4c40 = $(`&lt;div id=&quot;html_63b36590095efe705ff347384f1e4c40&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_4a18097a21d0957b552bd8226f8369ea.setContent(html_63b36590095efe705ff347384f1e4c40);
#
#
#
#         marker_06f9eb3106dcdcba3edfce45bcf570e9.bindPopup(popup_4a18097a21d0957b552bd8226f8369ea)
#         ;
#
#
#
#
#             var marker_98cc0efd2e6a5ed1b20a10bc5ca0dd24 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_97def82af764e4af1356bbfc95eb141d);
#
#
#         var popup_4df44fb46298449dbd86a11a457fc322 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b05c9553d08147c7ef99985dac0cf67d = $(`&lt;div id=&quot;html_b05c9553d08147c7ef99985dac0cf67d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_4df44fb46298449dbd86a11a457fc322.setContent(html_b05c9553d08147c7ef99985dac0cf67d);
#
#
#
#         marker_98cc0efd2e6a5ed1b20a10bc5ca0dd24.bindPopup(popup_4df44fb46298449dbd86a11a457fc322)
#         ;
#
#
#
#
#             var marker_5c5c2f0fcccc16c2b20975ed084c7139 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_97def82af764e4af1356bbfc95eb141d);
#
#
#         var popup_cc8e400611d3f77137b7fb7a88dd99cd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1e01ade005d40ba839de0e6df73ab504 = $(`&lt;div id=&quot;html_1e01ade005d40ba839de0e6df73ab504&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_cc8e400611d3f77137b7fb7a88dd99cd.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3a2fcd478dc5ca0bab8360ca087c9053 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3a2fcd478dc5ca0bab8360ca087c9053&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3a2fcd478dc5ca0bab8360ca087c9053 = L.map(
#                 &quot;map_3a2fcd478dc5ca0bab8360ca087c9053&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_84825d14b8491aaedb733e64f03c9411 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_84825d14b8491aaedb733e64f03c9411.addTo(map_3a2fcd478dc5ca0bab8360ca087c9053);
#
#
#             var feature_group_cb5c6fe585fb8900d5d714f95cb80cf4 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_9a1b5dd66a46eb2bc090ade187668b6c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_cb5c6fe585fb8900d5d714f95cb80cf4);
#
#
#         var popup_d3625b4625da092ed1e09cd227fd74c4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_69a8acec5e67103d9aaf1a2c041a9578 = $(`&lt;div id=&quot;html_69a8acec5e67103d9aaf1a2c041a9578&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_d3625b4625da092ed1e09cd227fd74c4.setContent(html_69a8acec5e67103d9aaf1a2c041a9578);
#
#
#
#         marker_9a1b5dd66a46eb2bc090ade187668b6c.bindPopup(popup_d3625b4625da092ed1e09cd227fd74c4)
#         ;
#
#
#
#
#             var marker_dd6d60a92c25febc889b0fcae95f07ea = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_cb5c6fe585fb8900d5d714f95cb80cf4);
#
#
#         var popup_fad2ce03c70e8bdd19e47f7d9952640f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_eaa47cd208425b65a6f10758ae211a94 = $(`&lt;div id=&quot;html_eaa47cd208425b65a6f10758ae211a94&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_fad2ce03c70e8bdd19e47f7d9952640f.setContent(html_eaa47cd208425b65a6f10758ae211a94);
#
#
#
#         marker_dd6d60a92c25febc889b0fcae95f07ea.bindPopup(popup_fad2ce03c70e8bdd19e47f7d9952640f)
#         ;
#
#
#
#
#             var marker_288e2f4575b4ba188722f8b3d9c7ee33 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_cb5c6fe585fb8900d5d714f95cb80cf4);
#
#
#         var popup_a4e5c7925553c2f417d74abc162e93a7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_75b0864e2ec4f26fa2bbd0156a3441ca = $(`&lt;div id=&quot;html_75b0864e2ec4f26fa2bbd0156a3441ca&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_a4e5c7925553c2f417d74abc162e93a7.setContent(html_75b0864e2ec4f26fa2bbd0156a3441ca);
#
#
#
#         marker_288e2f4575b4ba188722f8b3d9c7ee33.bindPopup(popup_a4e5c7925553c2f417d74abc162e93a7)
#         ;
#
#
#
#
#             var marker_bdb05a967387eaf545124134d18f1019 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_cb5c6fe585fb8900d5d714f95cb80cf4);
#
#
#         var popup_be821ec6aa2281ddbcfd31c26250bf18 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b62667a4094e406db379fc0800a1275e = $(`&lt;div id=&quot;html_b62667a4094e406db379fc0800a1275e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_be821ec6aa2281ddbcfd31c26250bf18.setContent(html_b62667a4094e406db379fc0800a1275e);
#
#
#
#         marker_bdb05a967387eaf545124134d18f1019.bindPopup(popup_be821ec6aa2281ddbcfd31c26250bf18)
#         ;
#
#
#
#
#             var marker_7bd048d67638a539bfa826cdfc8adc32 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_cb5c6fe585fb8900d5d714f95cb80cf4);
#
#
#         var popup_9a28406a98a945b407fdfe625fe18d5e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c78fcb5919434a45f864c931cf344673 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c78fcb5919434a45f864c931cf344673&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c78fcb5919434a45f864c931cf344673 = L.map(
#                 &quot;map_c78fcb5919434a45f864c931cf344673&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_607458a7671fd6b327b27fbc727f2f32 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_607458a7671fd6b327b27fbc727f2f32.addTo(map_c78fcb5919434a45f864c931cf344673);
#
#
#             var feature_group_fff8ddb4f91591e6b7ec60e604493408 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_fff8ddb4f91591e6b7ec60e604493408.addTo(map_c78fcb5919434a45f864c931cf344673);
#
#
#             var feature_group_sub_group_f311c0a1352da84485b4ffb333abc49f = L.featureGroup.subGroup(
#                 feature_group_fff8ddb4f91591e6b7ec60e604493408
#             );
#
#
#             var marker_3b15df5676493b81fd62caa80990fb89 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_f311c0a1352da84485b4ffb333abc49f);
#
#
#         var popup_bf96f57ab46d5b1a5cd19df22e2ac1e6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a255cf2bef145a358dc5217cc53e250d = $(`&lt;div id=&quot;html_a255cf2bef145a358dc5217cc53e250d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_bf96f57ab46d5b1a5cd19df22e2ac1e6.setContent(html_a255cf2bef145a358dc5217cc53e250d);
#
#
#
#         marker_3b15df5676493b81fd62caa80990fb89.bindPopup(popup_bf96f57ab46d5b1a5cd19df22e2ac1e6)
#         ;
#
#
#
#
#             var marker_fd207c200dcba3df0e255526ba576b23 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_f311c0a1352da84485b4ffb333abc49f);
#
#
#         var popup_552bd7139d689742a31b43a388ee70fa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_df9b194ea4a521ecd1838ef95fe4fa37 = $(`&lt;div id=&quot;html_df9b194ea4a521ecd1838ef95fe4fa37&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_552bd7139d689742a31b43a388ee70fa.setContent(html_df9b194ea4a521ecd1838ef95fe4fa37);
#
#
#
#         marker_fd207c200dcba3df0e255526ba576b23.bindPopup(popup_552bd7139d689742a31b43a388ee70fa)
#         ;
#
#
#
#
#             var marker_d9f55d9a14b62d96c2c4126b0ed8dff0 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_f311c0a1352da84485b4ffb333abc49f);
#
#
#         var popup_2645b12899aa7a38b1a9db67db9b6259 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f537df20e3cc392685d8784943103f62 = $(`&lt;div id=&quot;html_f537df20e3cc392685d8784943103f62&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_2645b12899aa7a38b1a9db67db9b6259.setContent(html_f537df20e3cc392685d8784943103f62);
#
#
#
#         marker_d9f55d9a14b62d96c2c4126b0ed8dff0.bindPopup(popup_2645b12899aa7a38b1a9db67db9b6259)
#         ;
#
#
#
#
#             var marker_aea76642e45b9fad15e98a5a287ffd9d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_f311c0a1352da84485b4ffb333abc49f);
#
#
#         var popup_e2fb73697fdb392a409c457aed1694cd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a0101e24c94e77247489ae808122490a = $(`&lt;div id=&quot;html_a0101e24c94e77247489ae808122490a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_e2fb73697fdb392a409c457aed1694cd.setContent(html_a0101e24c94e77247489ae808122490a);
#
#
#
#         marker_
