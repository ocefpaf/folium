# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b023770e21385c23e3946b4237176919 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b023770e21385c23e3946b4237176919&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b023770e21385c23e3946b4237176919 = L.map(
#                 &quot;map_b023770e21385c23e3946b4237176919&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d5b2e49fa745857a5d3cfc787ae7fbf3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d5b2e49fa745857a5d3cfc787ae7fbf3.addTo(map_b023770e21385c23e3946b4237176919);
#
#
#             var marker_e79209f113049761546d17f2fe49d62d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_b023770e21385c23e3946b4237176919);
#
#
#         var popup_cc00ede68b423e720f3fabed01ede8d3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_82fab6125a433925e97b6a729d16455e = $(`&lt;div id=&quot;html_82fab6125a433925e97b6a729d16455e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_cc00ede68b423e720f3fabed01ede8d3.setContent(html_82fab6125a433925e97b6a729d16455e);
#
#
#
#         marker_e79209f113049761546d17f2fe49d62d.bindPopup(popup_cc00ede68b423e720f3fabed01ede8d3)
#         ;
#
#
#
#
#             var marker_e8e870a1d8cc8de6fdd076c92bba8086 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_b023770e21385c23e3946b4237176919);
#
#
#         var popup_284c20a823594c614316e8c51b94c386 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4c18af92cc8015317bf5f55306af6fb8 = $(`&lt;div id=&quot;html_4c18af92cc8015317bf5f55306af6fb8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_284c20a823594c614316e8c51b94c386.setContent(html_4c18af92cc8015317bf5f55306af6fb8);
#
#
#
#         marker_e8e870a1d8cc8de6fdd076c92bba8086.bindPopup(popup_284c20a823594c614316e8c51b94c386)
#         ;
#
#
#
#
#             var marker_a422fcaf25d3a41dfb218d8de082f85b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_b023770e21385c23e3946b4237176919);
#
#
#         var popup_745f96af267b418b1e24e085b2aabda8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_195a78f739d6af6d1cb569173a647357 = $(`&lt;div id=&quot;html_195a78f739d6af6d1cb569173a647357&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_745f96af267b418b1e24e085b2aabda8.setContent(html_195a78f739d6af6d1cb569173a647357);
#
#
#
#         marker_a422fcaf25d3a41dfb218d8de082f85b.bindPopup(popup_745f96af267b418b1e24e085b2aabda8)
#         ;
#
#
#
#
#             var marker_c32ad2eaa10ee3bc482a31f5ce00a06e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_b023770e21385c23e3946b4237176919);
#
#
#         var popup_c8c982e3a000cc3a7eff61f7faf1e2e1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_265937055e57b5eaa2d15dc833ba2d3f = $(`&lt;div id=&quot;html_265937055e57b5eaa2d15dc833ba2d3f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_c8c982e3a000cc3a7eff61f7faf1e2e1.setContent(html_265937055e57b5eaa2d15dc833ba2d3f);
#
#
#
#         marker_c32ad2eaa10ee3bc482a31f5ce00a06e.bindPopup(popup_c8c982e3a000cc3a7eff61f7faf1e2e1)
#         ;
#
#
#
#
#             var marker_b2a5ebc2dc728e31c88bfeeec8abaac0 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_b023770e21385c23e3946b4237176919);
#
#
#         var popup_d217445669d3692697d4b7ca28a914b1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_964e0deefb59668f28097a518770264c = $(`&lt;div id=&quot;html_964e0deefb59668f28097a518770264c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_d217445669d3692697d4b7ca28a914b1.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fe2fe69610698804ee2c4f1e0a43c8c5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fe2fe69610698804ee2c4f1e0a43c8c5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fe2fe69610698804ee2c4f1e0a43c8c5 = L.map(
#                 &quot;map_fe2fe69610698804ee2c4f1e0a43c8c5&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0a49657106e37e73914b07eabd37ddba = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0a49657106e37e73914b07eabd37ddba.addTo(map_fe2fe69610698804ee2c4f1e0a43c8c5);
#
#
#             var feature_group_763c1203c5308cf9f1720db1752eb40e = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_5da1878e7b744ebc9459a0fb174e1635 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_763c1203c5308cf9f1720db1752eb40e);
#
#
#         var popup_cef1a72c5df865fb3e44015d829297e9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a362d893703a01097f9f9f1b84a3ffea = $(`&lt;div id=&quot;html_a362d893703a01097f9f9f1b84a3ffea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_cef1a72c5df865fb3e44015d829297e9.setContent(html_a362d893703a01097f9f9f1b84a3ffea);
#
#
#
#         marker_5da1878e7b744ebc9459a0fb174e1635.bindPopup(popup_cef1a72c5df865fb3e44015d829297e9)
#         ;
#
#
#
#
#             var marker_730959f93503f51b1d7fb549c6e17ce1 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_763c1203c5308cf9f1720db1752eb40e);
#
#
#         var popup_f3349de8f2d88d7685082c4ea6b2f4aa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_43dc086fb0d0d7c1a7db3910da45b4a0 = $(`&lt;div id=&quot;html_43dc086fb0d0d7c1a7db3910da45b4a0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_f3349de8f2d88d7685082c4ea6b2f4aa.setContent(html_43dc086fb0d0d7c1a7db3910da45b4a0);
#
#
#
#         marker_730959f93503f51b1d7fb549c6e17ce1.bindPopup(popup_f3349de8f2d88d7685082c4ea6b2f4aa)
#         ;
#
#
#
#
#             var marker_0ef2266c58d098a0bc82c59d7d55852a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_763c1203c5308cf9f1720db1752eb40e);
#
#
#         var popup_850721286a11bf25b31594cb2c45b971 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5883106338f35a8fe95a9b749c99d926 = $(`&lt;div id=&quot;html_5883106338f35a8fe95a9b749c99d926&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_850721286a11bf25b31594cb2c45b971.setContent(html_5883106338f35a8fe95a9b749c99d926);
#
#
#
#         marker_0ef2266c58d098a0bc82c59d7d55852a.bindPopup(popup_850721286a11bf25b31594cb2c45b971)
#         ;
#
#
#
#
#             var marker_debd64a2150d8fdf70a78b8ab108cf4f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_763c1203c5308cf9f1720db1752eb40e);
#
#
#         var popup_4e91a8a2eeb139445d6cea3d01e0a20f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_87cc7a9face9ae8f4d7c5a8dab31ae17 = $(`&lt;div id=&quot;html_87cc7a9face9ae8f4d7c5a8dab31ae17&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_4e91a8a2eeb139445d6cea3d01e0a20f.setContent(html_87cc7a9face9ae8f4d7c5a8dab31ae17);
#
#
#
#         marker_debd64a2150d8fdf70a78b8ab108cf4f.bindPopup(popup_4e91a8a2eeb139445d6cea3d01e0a20f)
#         ;
#
#
#
#
#             var marker_2d954d595cf3dd7022119d90e3552feb = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_763c1203c5308cf9f1720db1752eb40e);
#
#
#         var popup_65f329d5ff831a236ea79c1ff7d3ce55 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_dd19170c57fc11971ebd91a49ec228e2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_dd19170c57fc11971ebd91a49ec228e2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_dd19170c57fc11971ebd91a49ec228e2 = L.map(
#                 &quot;map_dd19170c57fc11971ebd91a49ec228e2&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a14f3681237b4bd9fd7cd50e8bad9f09 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a14f3681237b4bd9fd7cd50e8bad9f09.addTo(map_dd19170c57fc11971ebd91a49ec228e2);
#
#
#             var feature_group_e59d5159ecd901b57ffbc2b9c3cabffa = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_e59d5159ecd901b57ffbc2b9c3cabffa.addTo(map_dd19170c57fc11971ebd91a49ec228e2);
#
#
#             var feature_group_sub_group_32d5ea65218e185982b3fcebb59e05f1 = L.featureGroup.subGroup(
#                 feature_group_e59d5159ecd901b57ffbc2b9c3cabffa
#             );
#
#
#             var marker_7f45144f8a9ee3f434fc8eca686efa6a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_32d5ea65218e185982b3fcebb59e05f1);
#
#
#         var popup_32620ee551ce2b6f974b06ca25dec6ce = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_594fa61e03410cca2fd77c2ff23ab3ed = $(`&lt;div id=&quot;html_594fa61e03410cca2fd77c2ff23ab3ed&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_32620ee551ce2b6f974b06ca25dec6ce.setContent(html_594fa61e03410cca2fd77c2ff23ab3ed);
#
#
#
#         marker_7f45144f8a9ee3f434fc8eca686efa6a.bindPopup(popup_32620ee551ce2b6f974b06ca25dec6ce)
#         ;
#
#
#
#
#             var marker_edfaf279b42ea143e8e3efc0260e177d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_32d5ea65218e185982b3fcebb59e05f1);
#
#
#         var popup_db0750e32aa8b215a4c29701e80a91e1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ec8cf13cbee6487247af9dbd985ad540 = $(`&lt;div id=&quot;html_ec8cf13cbee6487247af9dbd985ad540&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_db0750e32aa8b215a4c29701e80a91e1.setContent(html_ec8cf13cbee6487247af9dbd985ad540);
#
#
#
#         marker_edfaf279b42ea143e8e3efc0260e177d.bindPopup(popup_db0750e32aa8b215a4c29701e80a91e1)
#         ;
#
#
#
#
#             var marker_c11d7cfb7745650be413be19614c173d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_32d5ea65218e185982b3fcebb59e05f1);
#
#
#         var popup_592ac1ed4aa446a343f6b057d97f885b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ede4c02f5fc0f34eaa5d04f1faf77a2d = $(`&lt;div id=&quot;html_ede4c02f5fc0f34eaa5d04f1faf77a2d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_592ac1ed4aa446a343f6b057d97f885b.setContent(html_ede4c02f5fc0f34eaa5d04f1faf77a2d);
#
#
#
#         marker_c11d7cfb7745650be413be19614c173d.bindPopup(popup_592ac1ed4aa446a343f6b057d97f885b)
#         ;
#
#
#
#
#             var marker_c8a2ec3ab31d311647acc6fc3437c0e4 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_32d5ea65218e185982b3fcebb59e05f1);
#
#
#         var popup_90c4703a6d821e274b821085dcc0ea8a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fee9a15ef13ae86d8a494f21248ed7cb = $(`&lt;div id=&quot;html_fee9a15ef13ae86d8a494f21248ed7cb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_90c4703a6d821e274b821085dcc0ea8a.setContent(html_fee9a15ef13ae86d8a494f21248ed7cb);
#
#
#
#         marker_
