# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_70adc93bf836b1d1aa590dbcbec080eb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_70adc93bf836b1d1aa590dbcbec080eb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_70adc93bf836b1d1aa590dbcbec080eb = L.map(
#                 &quot;map_70adc93bf836b1d1aa590dbcbec080eb&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b1c3c833331a46ac547e7cf08b8db25f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b1c3c833331a46ac547e7cf08b8db25f.addTo(map_70adc93bf836b1d1aa590dbcbec080eb);
#
#
#             var marker_3edf98b11372a4b09b5b488f4c3ae249 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_70adc93bf836b1d1aa590dbcbec080eb);
#
#
#         var popup_a06fc24419069da65a8005d2bebdc778 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_85bd48be914ca10e37395f990109acbd = $(`&lt;div id=&quot;html_85bd48be914ca10e37395f990109acbd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_a06fc24419069da65a8005d2bebdc778.setContent(html_85bd48be914ca10e37395f990109acbd);
#
#
#
#         marker_3edf98b11372a4b09b5b488f4c3ae249.bindPopup(popup_a06fc24419069da65a8005d2bebdc778)
#         ;
#
#
#
#
#             var marker_01fae71e2edc177e1392648590b125d6 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_70adc93bf836b1d1aa590dbcbec080eb);
#
#
#         var popup_0df783ea74c6a0dfd9287832ed4e97f0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_331dbe734a1f513bcb1aa348d24816ac = $(`&lt;div id=&quot;html_331dbe734a1f513bcb1aa348d24816ac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_0df783ea74c6a0dfd9287832ed4e97f0.setContent(html_331dbe734a1f513bcb1aa348d24816ac);
#
#
#
#         marker_01fae71e2edc177e1392648590b125d6.bindPopup(popup_0df783ea74c6a0dfd9287832ed4e97f0)
#         ;
#
#
#
#
#             var marker_6df931a0e52abd271db01ac8cbd903b6 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_70adc93bf836b1d1aa590dbcbec080eb);
#
#
#         var popup_adbfc9f6c6b7bbe6e5e38c0c11c7f693 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e5ada7243a551d8151bd5f0e80b70bf5 = $(`&lt;div id=&quot;html_e5ada7243a551d8151bd5f0e80b70bf5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_adbfc9f6c6b7bbe6e5e38c0c11c7f693.setContent(html_e5ada7243a551d8151bd5f0e80b70bf5);
#
#
#
#         marker_6df931a0e52abd271db01ac8cbd903b6.bindPopup(popup_adbfc9f6c6b7bbe6e5e38c0c11c7f693)
#         ;
#
#
#
#
#             var marker_23380b8de53b2ce100169929adb17ba6 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_70adc93bf836b1d1aa590dbcbec080eb);
#
#
#         var popup_0e8bcf91e0b6c019b3fa19bc32bc77ba = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2a8493814b952d062e0b06557a061178 = $(`&lt;div id=&quot;html_2a8493814b952d062e0b06557a061178&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_0e8bcf91e0b6c019b3fa19bc32bc77ba.setContent(html_2a8493814b952d062e0b06557a061178);
#
#
#
#         marker_23380b8de53b2ce100169929adb17ba6.bindPopup(popup_0e8bcf91e0b6c019b3fa19bc32bc77ba)
#         ;
#
#
#
#
#             var marker_c02f93c9b4555fa44732a69177a496ab = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_70adc93bf836b1d1aa590dbcbec080eb);
#
#
#         var popup_06e4f86906c032ef47bf416f778cc94d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8dfcac69d19b60280d5684b53b6cd026 = $(`&lt;div id=&quot;html_8dfcac69d19b60280d5684b53b6cd026&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_06e4f86906c032ef47bf416f778cc94d.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6e9787ea1ff16d596233cc18d2d08f71 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6e9787ea1ff16d596233cc18d2d08f71&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6e9787ea1ff16d596233cc18d2d08f71 = L.map(
#                 &quot;map_6e9787ea1ff16d596233cc18d2d08f71&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_161c0fd79047bbbb44044a0c2031d8db = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_161c0fd79047bbbb44044a0c2031d8db.addTo(map_6e9787ea1ff16d596233cc18d2d08f71);
#
#
#             var feature_group_258bce4bde3f993511ad0a3723b66908 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_9c4d81d7906a1cfd0a39a6a41e1aa309 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_258bce4bde3f993511ad0a3723b66908);
#
#
#         var popup_c4467db3c890fbb683977add5acb5b84 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c955ec7ce281c321f34eafcd00144cd6 = $(`&lt;div id=&quot;html_c955ec7ce281c321f34eafcd00144cd6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_c4467db3c890fbb683977add5acb5b84.setContent(html_c955ec7ce281c321f34eafcd00144cd6);
#
#
#
#         marker_9c4d81d7906a1cfd0a39a6a41e1aa309.bindPopup(popup_c4467db3c890fbb683977add5acb5b84)
#         ;
#
#
#
#
#             var marker_6bcb970295c020b5ff876d16647e5bc5 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_258bce4bde3f993511ad0a3723b66908);
#
#
#         var popup_6981ddc4b2ba35adbdb27eece5d2037e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_77034b0f959127374be1a81d0ee6e7ac = $(`&lt;div id=&quot;html_77034b0f959127374be1a81d0ee6e7ac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_6981ddc4b2ba35adbdb27eece5d2037e.setContent(html_77034b0f959127374be1a81d0ee6e7ac);
#
#
#
#         marker_6bcb970295c020b5ff876d16647e5bc5.bindPopup(popup_6981ddc4b2ba35adbdb27eece5d2037e)
#         ;
#
#
#
#
#             var marker_9b13b5b5a9a2081f70cb08a402e5b38b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_258bce4bde3f993511ad0a3723b66908);
#
#
#         var popup_e9e83c745fdb08aa3ead64d6e4b2deff = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_28b4f7579b0356e8bdbd1c85f93f75ee = $(`&lt;div id=&quot;html_28b4f7579b0356e8bdbd1c85f93f75ee&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_e9e83c745fdb08aa3ead64d6e4b2deff.setContent(html_28b4f7579b0356e8bdbd1c85f93f75ee);
#
#
#
#         marker_9b13b5b5a9a2081f70cb08a402e5b38b.bindPopup(popup_e9e83c745fdb08aa3ead64d6e4b2deff)
#         ;
#
#
#
#
#             var marker_9adf416c964d207f348e4d1a14d6a1c8 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_258bce4bde3f993511ad0a3723b66908);
#
#
#         var popup_d41dfa423d442a67ecf6533c2ec6ca1d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_98dda3a8608509d606af83192e8b4c00 = $(`&lt;div id=&quot;html_98dda3a8608509d606af83192e8b4c00&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_d41dfa423d442a67ecf6533c2ec6ca1d.setContent(html_98dda3a8608509d606af83192e8b4c00);
#
#
#
#         marker_9adf416c964d207f348e4d1a14d6a1c8.bindPopup(popup_d41dfa423d442a67ecf6533c2ec6ca1d)
#         ;
#
#
#
#
#             var marker_126ea21e7e078f78a03cb186dfa243d4 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_258bce4bde3f993511ad0a3723b66908);
#
#
#         var popup_5afdfc1008859fbf091f8fdc1f3df671 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_819c0ecf8c2eca8dc4f6145088f9895d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_819c0ecf8c2eca8dc4f6145088f9895d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_819c0ecf8c2eca8dc4f6145088f9895d = L.map(
#                 &quot;map_819c0ecf8c2eca8dc4f6145088f9895d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_eaf2099ad8158e6ab2ebb360093d3572 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_eaf2099ad8158e6ab2ebb360093d3572.addTo(map_819c0ecf8c2eca8dc4f6145088f9895d);
#
#
#             var feature_group_81419d79803d51544b969be404621271 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_81419d79803d51544b969be404621271.addTo(map_819c0ecf8c2eca8dc4f6145088f9895d);
#
#
#             var feature_group_sub_group_7ba72ce5a609779aadc7111899e07ebd = L.featureGroup.subGroup(
#                 feature_group_81419d79803d51544b969be404621271
#             );
#
#
#             var marker_9b53f6e21042d543eec42db94186ba67 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_7ba72ce5a609779aadc7111899e07ebd);
#
#
#         var popup_d84c9fd37e9fb40b34ad962844ca4502 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_eb9afba945b62c9ddb6bd47e661c998b = $(`&lt;div id=&quot;html_eb9afba945b62c9ddb6bd47e661c998b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_d84c9fd37e9fb40b34ad962844ca4502.setContent(html_eb9afba945b62c9ddb6bd47e661c998b);
#
#
#
#         marker_9b53f6e21042d543eec42db94186ba67.bindPopup(popup_d84c9fd37e9fb40b34ad962844ca4502)
#         ;
#
#
#
#
#             var marker_31ec2468472f7a955d4f018d0553e738 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_7ba72ce5a609779aadc7111899e07ebd);
#
#
#         var popup_9c2b96a1f367fe286d2d54c2d73fab37 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_93b875a4e0eefc667eb35aeb5cee2ef5 = $(`&lt;div id=&quot;html_93b875a4e0eefc667eb35aeb5cee2ef5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_9c2b96a1f367fe286d2d54c2d73fab37.setContent(html_93b875a4e0eefc667eb35aeb5cee2ef5);
#
#
#
#         marker_31ec2468472f7a955d4f018d0553e738.bindPopup(popup_9c2b96a1f367fe286d2d54c2d73fab37)
#         ;
#
#
#
#
#             var marker_a84fd3c1e36976c57664ee8cf0af9e30 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_7ba72ce5a609779aadc7111899e07ebd);
#
#
#         var popup_ea19f14783bf7a39013c004a5472d540 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e3fdc5dfa96fa38b37c555fe69a51c59 = $(`&lt;div id=&quot;html_e3fdc5dfa96fa38b37c555fe69a51c59&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_ea19f14783bf7a39013c004a5472d540.setContent(html_e3fdc5dfa96fa38b37c555fe69a51c59);
#
#
#
#         marker_a84fd3c1e36976c57664ee8cf0af9e30.bindPopup(popup_ea19f14783bf7a39013c004a5472d540)
#         ;
#
#
#
#
#             var marker_a8aedfb00ccbbc8ec2330ee0b3c10775 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_7ba72ce5a609779aadc7111899e07ebd);
#
#
#         var popup_f93d991c5137db5184e5bf3c57de898a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_aac667fbd974aa20a47106835f0c25a5 = $(`&lt;div id=&quot;html_aac667fbd974aa20a47106835f0c25a5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_f93d991c5137db5184e5bf3c57de898a.setContent(html_aac667fbd974aa20a47106835f0c25a5);
#
#
#
#         marker_
