# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3d3111706a3d735b021f6f09587c9ad7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3d3111706a3d735b021f6f09587c9ad7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3d3111706a3d735b021f6f09587c9ad7 = L.map(
#                 &quot;map_3d3111706a3d735b021f6f09587c9ad7&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a06988da352ffe8fbce50044668f356f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a06988da352ffe8fbce50044668f356f.addTo(map_3d3111706a3d735b021f6f09587c9ad7);
#
#
#             var marker_df2d49f865b1ce47bb902e6eab11e366 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_3d3111706a3d735b021f6f09587c9ad7);
#
#
#         var popup_35c3db6736c83d6a09fab57bccbb33de = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3d08eda11123ca503bccbe7652192341 = $(`&lt;div id=&quot;html_3d08eda11123ca503bccbe7652192341&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_35c3db6736c83d6a09fab57bccbb33de.setContent(html_3d08eda11123ca503bccbe7652192341);
#
#
#
#         marker_df2d49f865b1ce47bb902e6eab11e366.bindPopup(popup_35c3db6736c83d6a09fab57bccbb33de)
#         ;
#
#
#
#
#             var marker_68ea0e91cdee933a6a1385682da8a259 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_3d3111706a3d735b021f6f09587c9ad7);
#
#
#         var popup_23b884fc6f99a561d39d16fb9da84d78 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3430923a0ef18100bfcf93d1f908250c = $(`&lt;div id=&quot;html_3430923a0ef18100bfcf93d1f908250c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_23b884fc6f99a561d39d16fb9da84d78.setContent(html_3430923a0ef18100bfcf93d1f908250c);
#
#
#
#         marker_68ea0e91cdee933a6a1385682da8a259.bindPopup(popup_23b884fc6f99a561d39d16fb9da84d78)
#         ;
#
#
#
#
#             var marker_d893c3db79776eb2db0f7f98ef55b7e6 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_3d3111706a3d735b021f6f09587c9ad7);
#
#
#         var popup_93ebe38c4e04ad075eae0e7892f9871c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_651ccf41fb92406de798f04b111b4dd1 = $(`&lt;div id=&quot;html_651ccf41fb92406de798f04b111b4dd1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_93ebe38c4e04ad075eae0e7892f9871c.setContent(html_651ccf41fb92406de798f04b111b4dd1);
#
#
#
#         marker_d893c3db79776eb2db0f7f98ef55b7e6.bindPopup(popup_93ebe38c4e04ad075eae0e7892f9871c)
#         ;
#
#
#
#
#             var marker_59ced2187c43dffdf223658b61b4ba4e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_3d3111706a3d735b021f6f09587c9ad7);
#
#
#         var popup_a2b3c673a3e55b9dde44988722ff4017 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4122bdc4041f590b1b74021c362048d4 = $(`&lt;div id=&quot;html_4122bdc4041f590b1b74021c362048d4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_a2b3c673a3e55b9dde44988722ff4017.setContent(html_4122bdc4041f590b1b74021c362048d4);
#
#
#
#         marker_59ced2187c43dffdf223658b61b4ba4e.bindPopup(popup_a2b3c673a3e55b9dde44988722ff4017)
#         ;
#
#
#
#
#             var marker_8df18cf3e72cca3b381a5b3f7ee50e4a = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_3d3111706a3d735b021f6f09587c9ad7);
#
#
#         var popup_b911af2222c9bdfc9c3dae1618adcdc0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b971bb0efce8c4e0e8a0e12c5866eb6d = $(`&lt;div id=&quot;html_b971bb0efce8c4e0e8a0e12c5866eb6d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_b911af2222c9bdfc9c3dae1618adcdc0.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e308ea6ca29d93a4e70c1ec01c101bf5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e308ea6ca29d93a4e70c1ec01c101bf5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e308ea6ca29d93a4e70c1ec01c101bf5 = L.map(
#                 &quot;map_e308ea6ca29d93a4e70c1ec01c101bf5&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a2210b955d59abec2ea0a343cf3d75e5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a2210b955d59abec2ea0a343cf3d75e5.addTo(map_e308ea6ca29d93a4e70c1ec01c101bf5);
#
#
#             var feature_group_66d800b85a64d4eabac684ad66e5b81c = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_2ea05bdd71ad69ad4611bf1cbbc6d3b0 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_66d800b85a64d4eabac684ad66e5b81c);
#
#
#         var popup_f84cfc43efc2ef2bd9f034db7618c13c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_170f3e8c00aa8fee39b5f5c6db54b0cb = $(`&lt;div id=&quot;html_170f3e8c00aa8fee39b5f5c6db54b0cb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_f84cfc43efc2ef2bd9f034db7618c13c.setContent(html_170f3e8c00aa8fee39b5f5c6db54b0cb);
#
#
#
#         marker_2ea05bdd71ad69ad4611bf1cbbc6d3b0.bindPopup(popup_f84cfc43efc2ef2bd9f034db7618c13c)
#         ;
#
#
#
#
#             var marker_49cdfe30a49a7e75f6ddedce3567a429 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_66d800b85a64d4eabac684ad66e5b81c);
#
#
#         var popup_7a8600f3fdd2cce2e68c1bb087a01760 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f2a0788c72b9ddbc6b731848da2241aa = $(`&lt;div id=&quot;html_f2a0788c72b9ddbc6b731848da2241aa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_7a8600f3fdd2cce2e68c1bb087a01760.setContent(html_f2a0788c72b9ddbc6b731848da2241aa);
#
#
#
#         marker_49cdfe30a49a7e75f6ddedce3567a429.bindPopup(popup_7a8600f3fdd2cce2e68c1bb087a01760)
#         ;
#
#
#
#
#             var marker_7587cc2d1e63c5935856119b22912aa4 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_66d800b85a64d4eabac684ad66e5b81c);
#
#
#         var popup_a33ec125e539b0cb65c4c3c2ba189f9c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_272648d46c53afb8dc4595d982908f52 = $(`&lt;div id=&quot;html_272648d46c53afb8dc4595d982908f52&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_a33ec125e539b0cb65c4c3c2ba189f9c.setContent(html_272648d46c53afb8dc4595d982908f52);
#
#
#
#         marker_7587cc2d1e63c5935856119b22912aa4.bindPopup(popup_a33ec125e539b0cb65c4c3c2ba189f9c)
#         ;
#
#
#
#
#             var marker_ea75bf1ed72f708493e2e891256f238f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_66d800b85a64d4eabac684ad66e5b81c);
#
#
#         var popup_3c8602ba44d80e2036767b2ac7e3f2a1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f9a6444fcba28cb88e4308e2d7efaaad = $(`&lt;div id=&quot;html_f9a6444fcba28cb88e4308e2d7efaaad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_3c8602ba44d80e2036767b2ac7e3f2a1.setContent(html_f9a6444fcba28cb88e4308e2d7efaaad);
#
#
#
#         marker_ea75bf1ed72f708493e2e891256f238f.bindPopup(popup_3c8602ba44d80e2036767b2ac7e3f2a1)
#         ;
#
#
#
#
#             var marker_348d1b91da7b777f03a3635246122323 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_66d800b85a64d4eabac684ad66e5b81c);
#
#
#         var popup_3a95543042f122fb955a4a7024d844f5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0c667deb607f1e5b89a054214e36ce2c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0c667deb607f1e5b89a054214e36ce2c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0c667deb607f1e5b89a054214e36ce2c = L.map(
#                 &quot;map_0c667deb607f1e5b89a054214e36ce2c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_028527974f23ace1cdc2f1c5120649e0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_028527974f23ace1cdc2f1c5120649e0.addTo(map_0c667deb607f1e5b89a054214e36ce2c);
#
#
#             var feature_group_85ca9e70714d7ac62115f49d98e65feb = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_85ca9e70714d7ac62115f49d98e65feb.addTo(map_0c667deb607f1e5b89a054214e36ce2c);
#
#
#             var feature_group_sub_group_2da38508162d33c888de9b41220173f5 = L.featureGroup.subGroup(
#                 feature_group_85ca9e70714d7ac62115f49d98e65feb
#             );
#
#
#             var marker_9081249d93eee0d4031c0eb40614b8be = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_2da38508162d33c888de9b41220173f5);
#
#
#         var popup_3b3b51af3807f2063c252e22523cfb31 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9ccf992d4d3f35b435cd49acf280082e = $(`&lt;div id=&quot;html_9ccf992d4d3f35b435cd49acf280082e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_3b3b51af3807f2063c252e22523cfb31.setContent(html_9ccf992d4d3f35b435cd49acf280082e);
#
#
#
#         marker_9081249d93eee0d4031c0eb40614b8be.bindPopup(popup_3b3b51af3807f2063c252e22523cfb31)
#         ;
#
#
#
#
#             var marker_6818dfb98137b1901dfb664657c7e528 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_2da38508162d33c888de9b41220173f5);
#
#
#         var popup_3421302647b3e4799c37e331977af702 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dd3fa6c796a12438d3f4669e2388063f = $(`&lt;div id=&quot;html_dd3fa6c796a12438d3f4669e2388063f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_3421302647b3e4799c37e331977af702.setContent(html_dd3fa6c796a12438d3f4669e2388063f);
#
#
#
#         marker_6818dfb98137b1901dfb664657c7e528.bindPopup(popup_3421302647b3e4799c37e331977af702)
#         ;
#
#
#
#
#             var marker_1ab9c0770a5c48ea2aa749a34ade7dbd = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_2da38508162d33c888de9b41220173f5);
#
#
#         var popup_c1829ae7523872d19269de9dcb2cb213 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dd2d100a91166e369230ae9f40d42420 = $(`&lt;div id=&quot;html_dd2d100a91166e369230ae9f40d42420&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_c1829ae7523872d19269de9dcb2cb213.setContent(html_dd2d100a91166e369230ae9f40d42420);
#
#
#
#         marker_1ab9c0770a5c48ea2aa749a34ade7dbd.bindPopup(popup_c1829ae7523872d19269de9dcb2cb213)
#         ;
#
#
#
#
#             var marker_98d6b3b6f11faae5397b57e7f706d615 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_2da38508162d33c888de9b41220173f5);
#
#
#         var popup_6b8b8972ffd73cbf6d9dfbf23dce32c0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fd850c4e94baf8ff16656c4baa41123a = $(`&lt;div id=&quot;html_fd850c4e94baf8ff16656c4baa41123a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_6b8b8972ffd73cbf6d9dfbf23dce32c0.setContent(html_fd850c4e94baf8ff16656c4baa41123a);
#
#
#
#         marker_
