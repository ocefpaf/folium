# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_34c1f1ad285dc5b172a882fa6972a23d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_34c1f1ad285dc5b172a882fa6972a23d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_34c1f1ad285dc5b172a882fa6972a23d = L.map(
#                 &quot;map_34c1f1ad285dc5b172a882fa6972a23d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_eae601eb3412a042edeab989d786bac5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_eae601eb3412a042edeab989d786bac5.addTo(map_34c1f1ad285dc5b172a882fa6972a23d);
#
#
#             var marker_c32cbd850181cdb955d72bcf5935c1d4 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_34c1f1ad285dc5b172a882fa6972a23d);
#
#
#         var popup_c73d51c5c32ca5a5f4dd7aee43547f8d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_42ff2d741bc7c0ebc74f28a2291fbf5b = $(`&lt;div id=&quot;html_42ff2d741bc7c0ebc74f28a2291fbf5b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_c73d51c5c32ca5a5f4dd7aee43547f8d.setContent(html_42ff2d741bc7c0ebc74f28a2291fbf5b);
#
#
#
#         marker_c32cbd850181cdb955d72bcf5935c1d4.bindPopup(popup_c73d51c5c32ca5a5f4dd7aee43547f8d)
#         ;
#
#
#
#
#             var marker_23afd3e9ed5a573fffc772d03270498c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_34c1f1ad285dc5b172a882fa6972a23d);
#
#
#         var popup_7223ff27290d484be7568e0daf5a1346 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3fbfada5157f3724674342778e1ac800 = $(`&lt;div id=&quot;html_3fbfada5157f3724674342778e1ac800&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_7223ff27290d484be7568e0daf5a1346.setContent(html_3fbfada5157f3724674342778e1ac800);
#
#
#
#         marker_23afd3e9ed5a573fffc772d03270498c.bindPopup(popup_7223ff27290d484be7568e0daf5a1346)
#         ;
#
#
#
#
#             var marker_f3758e169cb814fb437beba7d5727feb = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_34c1f1ad285dc5b172a882fa6972a23d);
#
#
#         var popup_00454b64ca58dca1e0f7d590ec888f69 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8703016d0495932395aeb8900df5db2c = $(`&lt;div id=&quot;html_8703016d0495932395aeb8900df5db2c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_00454b64ca58dca1e0f7d590ec888f69.setContent(html_8703016d0495932395aeb8900df5db2c);
#
#
#
#         marker_f3758e169cb814fb437beba7d5727feb.bindPopup(popup_00454b64ca58dca1e0f7d590ec888f69)
#         ;
#
#
#
#
#             var marker_5943813b53315bf2ff013440fc62b1a6 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_34c1f1ad285dc5b172a882fa6972a23d);
#
#
#         var popup_ce78a942ea511009af51a54fb69d546e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c01e9cc37f52448f6edc0b41de369d00 = $(`&lt;div id=&quot;html_c01e9cc37f52448f6edc0b41de369d00&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_ce78a942ea511009af51a54fb69d546e.setContent(html_c01e9cc37f52448f6edc0b41de369d00);
#
#
#
#         marker_5943813b53315bf2ff013440fc62b1a6.bindPopup(popup_ce78a942ea511009af51a54fb69d546e)
#         ;
#
#
#
#
#             var marker_801b20d10dae33668b44f7f32d126b49 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_34c1f1ad285dc5b172a882fa6972a23d);
#
#
#         var popup_95b0a5a9c1c485d93b65a8e1583ffa4b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_51934562b3d6f669d9578b79e09f5a5b = $(`&lt;div id=&quot;html_51934562b3d6f669d9578b79e09f5a5b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_95b0a5a9c1c485d93b65a8e1583ffa4b.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9f29da6264ab41a2b9240cef9f9b2a06 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9f29da6264ab41a2b9240cef9f9b2a06&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9f29da6264ab41a2b9240cef9f9b2a06 = L.map(
#                 &quot;map_9f29da6264ab41a2b9240cef9f9b2a06&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_02379bb549b2bbf06f197b37d9254d7d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_02379bb549b2bbf06f197b37d9254d7d.addTo(map_9f29da6264ab41a2b9240cef9f9b2a06);
#
#
#             var feature_group_ca1dd10fc17af8a3ffaefc4d7c368320 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_1346d39aa2ef7cc282e4abe99d02d400 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_ca1dd10fc17af8a3ffaefc4d7c368320);
#
#
#         var popup_103e1d08b2d4dc9822c686453cddcb94 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2318ecfe2390e174970ee65ee014da0d = $(`&lt;div id=&quot;html_2318ecfe2390e174970ee65ee014da0d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_103e1d08b2d4dc9822c686453cddcb94.setContent(html_2318ecfe2390e174970ee65ee014da0d);
#
#
#
#         marker_1346d39aa2ef7cc282e4abe99d02d400.bindPopup(popup_103e1d08b2d4dc9822c686453cddcb94)
#         ;
#
#
#
#
#             var marker_3c9ee70aa821c223acb35f0e0d892cbb = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_ca1dd10fc17af8a3ffaefc4d7c368320);
#
#
#         var popup_ecc55dbdf7109d31d8ce72a7ee2d64da = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_954b8bc76f5520fd9e1dcb4eff877dde = $(`&lt;div id=&quot;html_954b8bc76f5520fd9e1dcb4eff877dde&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_ecc55dbdf7109d31d8ce72a7ee2d64da.setContent(html_954b8bc76f5520fd9e1dcb4eff877dde);
#
#
#
#         marker_3c9ee70aa821c223acb35f0e0d892cbb.bindPopup(popup_ecc55dbdf7109d31d8ce72a7ee2d64da)
#         ;
#
#
#
#
#             var marker_0a8bfe1edcb0ab2c81a8bdd49617c2bc = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_ca1dd10fc17af8a3ffaefc4d7c368320);
#
#
#         var popup_27d57cbed42bd1c893877f55a0675c2c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_327473658b6d79cf3d22f94f80918074 = $(`&lt;div id=&quot;html_327473658b6d79cf3d22f94f80918074&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_27d57cbed42bd1c893877f55a0675c2c.setContent(html_327473658b6d79cf3d22f94f80918074);
#
#
#
#         marker_0a8bfe1edcb0ab2c81a8bdd49617c2bc.bindPopup(popup_27d57cbed42bd1c893877f55a0675c2c)
#         ;
#
#
#
#
#             var marker_1f87ca01b4ef109b0d1d2b59c9dadfdb = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_ca1dd10fc17af8a3ffaefc4d7c368320);
#
#
#         var popup_6e934017c22b17121ff27d3dafebd042 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cd1ff65dd7fe5805af75b6707a0ca2bd = $(`&lt;div id=&quot;html_cd1ff65dd7fe5805af75b6707a0ca2bd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_6e934017c22b17121ff27d3dafebd042.setContent(html_cd1ff65dd7fe5805af75b6707a0ca2bd);
#
#
#
#         marker_1f87ca01b4ef109b0d1d2b59c9dadfdb.bindPopup(popup_6e934017c22b17121ff27d3dafebd042)
#         ;
#
#
#
#
#             var marker_46a585dababa6119c19595d62d0a1c87 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_ca1dd10fc17af8a3ffaefc4d7c368320);
#
#
#         var popup_1576aa3a340292dc3fd93cc792cf7e1c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fdbba9e3d22a023de2e06f37b3cdc13a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fdbba9e3d22a023de2e06f37b3cdc13a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fdbba9e3d22a023de2e06f37b3cdc13a = L.map(
#                 &quot;map_fdbba9e3d22a023de2e06f37b3cdc13a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4a5506c848e965b28913ad3ea9a13017 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4a5506c848e965b28913ad3ea9a13017.addTo(map_fdbba9e3d22a023de2e06f37b3cdc13a);
#
#
#             var feature_group_bc9ffec624b9b9f0fb19d62ab9710e26 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_bc9ffec624b9b9f0fb19d62ab9710e26.addTo(map_fdbba9e3d22a023de2e06f37b3cdc13a);
#
#
#             var feature_group_sub_group_c9e3a53617f7ef97840bee3928e02a23 = L.featureGroup.subGroup(
#                 feature_group_bc9ffec624b9b9f0fb19d62ab9710e26
#             );
#
#
#             var marker_8d32332df5aa15632f221d9bae8fe537 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_c9e3a53617f7ef97840bee3928e02a23);
#
#
#         var popup_56f4f2c7cc0df100398dc7649221c2a9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_52ace1948e3d97222e9d0f4c7885e8ba = $(`&lt;div id=&quot;html_52ace1948e3d97222e9d0f4c7885e8ba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_56f4f2c7cc0df100398dc7649221c2a9.setContent(html_52ace1948e3d97222e9d0f4c7885e8ba);
#
#
#
#         marker_8d32332df5aa15632f221d9bae8fe537.bindPopup(popup_56f4f2c7cc0df100398dc7649221c2a9)
#         ;
#
#
#
#
#             var marker_12d11280ab9d4c77970762a54b921f6d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_c9e3a53617f7ef97840bee3928e02a23);
#
#
#         var popup_2a4a797c25ba2a8c15a254048cbf6141 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_10f1138f7d6fef8e844f1650c6550c2d = $(`&lt;div id=&quot;html_10f1138f7d6fef8e844f1650c6550c2d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_2a4a797c25ba2a8c15a254048cbf6141.setContent(html_10f1138f7d6fef8e844f1650c6550c2d);
#
#
#
#         marker_12d11280ab9d4c77970762a54b921f6d.bindPopup(popup_2a4a797c25ba2a8c15a254048cbf6141)
#         ;
#
#
#
#
#             var marker_306fb8939dfc8cfb8a87b5bbb6fb5568 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_c9e3a53617f7ef97840bee3928e02a23);
#
#
#         var popup_ac25c670b525e9dc13132b5ce8fb6c16 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f8e0b4af4f522d6244b4e2ee3851d923 = $(`&lt;div id=&quot;html_f8e0b4af4f522d6244b4e2ee3851d923&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_ac25c670b525e9dc13132b5ce8fb6c16.setContent(html_f8e0b4af4f522d6244b4e2ee3851d923);
#
#
#
#         marker_306fb8939dfc8cfb8a87b5bbb6fb5568.bindPopup(popup_ac25c670b525e9dc13132b5ce8fb6c16)
#         ;
#
#
#
#
#             var marker_6cdfa83d8d482e7ecf48a9354422d8ac = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_c9e3a53617f7ef97840bee3928e02a23);
#
#
#         var popup_1b98bc294452f38055ce577c465368b4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4b9197c910412a30846b995068f45446 = $(`&lt;div id=&quot;html_4b9197c910412a30846b995068f45446&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_1b98bc294452f38055ce577c465368b4.setContent(html_4b9197c910412a30846b995068f45446);
#
#
#
#         marker_
