# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_02620359296539485d812c9ca39c2605 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_02620359296539485d812c9ca39c2605&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_02620359296539485d812c9ca39c2605 = L.map(
#                 &quot;map_02620359296539485d812c9ca39c2605&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4d25ac1909ec72bccbf7de1f9e9414e0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4d25ac1909ec72bccbf7de1f9e9414e0.addTo(map_02620359296539485d812c9ca39c2605);
#
#
#             var marker_1173f5d77af26924ab5c87a61f2c5c37 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_02620359296539485d812c9ca39c2605);
#
#
#         var popup_9bd27a9912523329864a20382e415641 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2b590a26645d2d5e87fc7bc1ca93ca68 = $(`&lt;div id=&quot;html_2b590a26645d2d5e87fc7bc1ca93ca68&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_9bd27a9912523329864a20382e415641.setContent(html_2b590a26645d2d5e87fc7bc1ca93ca68);
#
#
#
#         marker_1173f5d77af26924ab5c87a61f2c5c37.bindPopup(popup_9bd27a9912523329864a20382e415641)
#         ;
#
#
#
#
#             var marker_2e0aa3242092ec37a38ee039123c5635 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_02620359296539485d812c9ca39c2605);
#
#
#         var popup_0b79d8042129ca859043a6f089dc891b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_18a37b3d3bb017978c94837b8e7adf8a = $(`&lt;div id=&quot;html_18a37b3d3bb017978c94837b8e7adf8a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_0b79d8042129ca859043a6f089dc891b.setContent(html_18a37b3d3bb017978c94837b8e7adf8a);
#
#
#
#         marker_2e0aa3242092ec37a38ee039123c5635.bindPopup(popup_0b79d8042129ca859043a6f089dc891b)
#         ;
#
#
#
#
#             var marker_7b461565aecfe418a2672b26b9894bf1 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_02620359296539485d812c9ca39c2605);
#
#
#         var popup_5745daadc7109769375ed1ac1945be04 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4572e18942c54a75486263cfe48dd6ec = $(`&lt;div id=&quot;html_4572e18942c54a75486263cfe48dd6ec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_5745daadc7109769375ed1ac1945be04.setContent(html_4572e18942c54a75486263cfe48dd6ec);
#
#
#
#         marker_7b461565aecfe418a2672b26b9894bf1.bindPopup(popup_5745daadc7109769375ed1ac1945be04)
#         ;
#
#
#
#
#             var marker_7badf6ffd487634a2e331b4fb6d38852 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_02620359296539485d812c9ca39c2605);
#
#
#         var popup_84a2ffba829fbc1ff75a30c0ae5c29e1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b8f45799c772617aa227b2c230f95f13 = $(`&lt;div id=&quot;html_b8f45799c772617aa227b2c230f95f13&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_84a2ffba829fbc1ff75a30c0ae5c29e1.setContent(html_b8f45799c772617aa227b2c230f95f13);
#
#
#
#         marker_7badf6ffd487634a2e331b4fb6d38852.bindPopup(popup_84a2ffba829fbc1ff75a30c0ae5c29e1)
#         ;
#
#
#
#
#             var marker_5ef2c45c1b273cd80187904a1aa1286a = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_02620359296539485d812c9ca39c2605);
#
#
#         var popup_b425b51264d238af3533615109d9e86b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_47ae2b6c5964b2857f99310f76b3dc0a = $(`&lt;div id=&quot;html_47ae2b6c5964b2857f99310f76b3dc0a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_b425b51264d238af3533615109d9e86b.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_38daa6570922eea1cfde43a20458173d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_38daa6570922eea1cfde43a20458173d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_38daa6570922eea1cfde43a20458173d = L.map(
#                 &quot;map_38daa6570922eea1cfde43a20458173d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8e0afc6f4ba718973847b23983cce1ce = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8e0afc6f4ba718973847b23983cce1ce.addTo(map_38daa6570922eea1cfde43a20458173d);
#
#
#             var feature_group_4dee1a66b73cdc9af8a0f8b7fb69d580 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_872f9758cf1794e810281522116c513c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_4dee1a66b73cdc9af8a0f8b7fb69d580);
#
#
#         var popup_5e5246ae526ac9dbe30c86b40f71d454 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_eac62226f519f73288f70fbc758ff7b3 = $(`&lt;div id=&quot;html_eac62226f519f73288f70fbc758ff7b3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_5e5246ae526ac9dbe30c86b40f71d454.setContent(html_eac62226f519f73288f70fbc758ff7b3);
#
#
#
#         marker_872f9758cf1794e810281522116c513c.bindPopup(popup_5e5246ae526ac9dbe30c86b40f71d454)
#         ;
#
#
#
#
#             var marker_fe33f75f1c590de6202a7b28c7b5dbbd = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_4dee1a66b73cdc9af8a0f8b7fb69d580);
#
#
#         var popup_4bca1c476194e7b9928758b16b33e577 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_53e6adbe415722b528fb8d7957e8c060 = $(`&lt;div id=&quot;html_53e6adbe415722b528fb8d7957e8c060&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_4bca1c476194e7b9928758b16b33e577.setContent(html_53e6adbe415722b528fb8d7957e8c060);
#
#
#
#         marker_fe33f75f1c590de6202a7b28c7b5dbbd.bindPopup(popup_4bca1c476194e7b9928758b16b33e577)
#         ;
#
#
#
#
#             var marker_be7ce95be077d1eac7da1f1695e8b2d0 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_4dee1a66b73cdc9af8a0f8b7fb69d580);
#
#
#         var popup_0a12418ce82b4877cedca0b939fb483c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3f57db5db4a6dbb3d068b2e72375a247 = $(`&lt;div id=&quot;html_3f57db5db4a6dbb3d068b2e72375a247&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_0a12418ce82b4877cedca0b939fb483c.setContent(html_3f57db5db4a6dbb3d068b2e72375a247);
#
#
#
#         marker_be7ce95be077d1eac7da1f1695e8b2d0.bindPopup(popup_0a12418ce82b4877cedca0b939fb483c)
#         ;
#
#
#
#
#             var marker_44f1cf27a9440559c38078c60df20a0a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_4dee1a66b73cdc9af8a0f8b7fb69d580);
#
#
#         var popup_9adf1eb3b14ddeaca2cb7f7d47c7a801 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dbfc3b6e134eb5c1ae4427fd0ed04225 = $(`&lt;div id=&quot;html_dbfc3b6e134eb5c1ae4427fd0ed04225&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_9adf1eb3b14ddeaca2cb7f7d47c7a801.setContent(html_dbfc3b6e134eb5c1ae4427fd0ed04225);
#
#
#
#         marker_44f1cf27a9440559c38078c60df20a0a.bindPopup(popup_9adf1eb3b14ddeaca2cb7f7d47c7a801)
#         ;
#
#
#
#
#             var marker_1ba20d87585b12bb0492e4b2d3114946 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_4dee1a66b73cdc9af8a0f8b7fb69d580);
#
#
#         var popup_a84c9cd6d2f27fac6999b9abb4b3da6a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_af82f109e71e4c4e216447a7a928f83b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_af82f109e71e4c4e216447a7a928f83b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_af82f109e71e4c4e216447a7a928f83b = L.map(
#                 &quot;map_af82f109e71e4c4e216447a7a928f83b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bebac18454279faacca381de16e216ae = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_bebac18454279faacca381de16e216ae.addTo(map_af82f109e71e4c4e216447a7a928f83b);
#
#
#             var feature_group_31379b1069e57b79bf53aa2b336c302e = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_31379b1069e57b79bf53aa2b336c302e.addTo(map_af82f109e71e4c4e216447a7a928f83b);
#
#
#             var feature_group_sub_group_c6a3740e6609d5f506b8739a375f58d2 = L.featureGroup.subGroup(
#                 feature_group_31379b1069e57b79bf53aa2b336c302e
#             );
#
#
#             var marker_cd41d75f73671b7eb1f4f89a36f600cc = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_c6a3740e6609d5f506b8739a375f58d2);
#
#
#         var popup_3fbb8367bc87a48a83682d6eeb2aed33 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e5bb3492fb0e3c077b3eb2bfffebbe80 = $(`&lt;div id=&quot;html_e5bb3492fb0e3c077b3eb2bfffebbe80&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_3fbb8367bc87a48a83682d6eeb2aed33.setContent(html_e5bb3492fb0e3c077b3eb2bfffebbe80);
#
#
#
#         marker_cd41d75f73671b7eb1f4f89a36f600cc.bindPopup(popup_3fbb8367bc87a48a83682d6eeb2aed33)
#         ;
#
#
#
#
#             var marker_e44718e59aa4a2d15425ccb2715b3a44 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_c6a3740e6609d5f506b8739a375f58d2);
#
#
#         var popup_bad4a3f09feb4ed0f7280102a14c915c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7b128f61918f1a0f1e4f422ff8a13c0a = $(`&lt;div id=&quot;html_7b128f61918f1a0f1e4f422ff8a13c0a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_bad4a3f09feb4ed0f7280102a14c915c.setContent(html_7b128f61918f1a0f1e4f422ff8a13c0a);
#
#
#
#         marker_e44718e59aa4a2d15425ccb2715b3a44.bindPopup(popup_bad4a3f09feb4ed0f7280102a14c915c)
#         ;
#
#
#
#
#             var marker_adcda9520a96a67e9b2d61b8705f1b4f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_c6a3740e6609d5f506b8739a375f58d2);
#
#
#         var popup_a57523f95e6a897438d6e0a00c715305 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1b359b1392fbc81e971ac00eea891e02 = $(`&lt;div id=&quot;html_1b359b1392fbc81e971ac00eea891e02&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_a57523f95e6a897438d6e0a00c715305.setContent(html_1b359b1392fbc81e971ac00eea891e02);
#
#
#
#         marker_adcda9520a96a67e9b2d61b8705f1b4f.bindPopup(popup_a57523f95e6a897438d6e0a00c715305)
#         ;
#
#
#
#
#             var marker_41cad39e712e564d383d1ebde196840a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_c6a3740e6609d5f506b8739a375f58d2);
#
#
#         var popup_2fbb4243d42f227521d8e50f05f70dc2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9b9ab59f548c60c1d262e5898ad51a89 = $(`&lt;div id=&quot;html_9b9ab59f548c60c1d262e5898ad51a89&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_2fbb4243d42f227521d8e50f05f70dc2.setContent(html_9b9ab59f548c60c1d262e5898ad51a89);
#
#
#
#         marker_
