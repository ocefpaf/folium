# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3ca94834c134ea97066d43b7d87afb6e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3ca94834c134ea97066d43b7d87afb6e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3ca94834c134ea97066d43b7d87afb6e = L.map(
#                 &quot;map_3ca94834c134ea97066d43b7d87afb6e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bbb84f7383cd9b50df0c362572ebe04e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_bbb84f7383cd9b50df0c362572ebe04e.addTo(map_3ca94834c134ea97066d43b7d87afb6e);
#
#
#             var marker_5cb76ebbf081e18833f3d347bff3ab37 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_3ca94834c134ea97066d43b7d87afb6e);
#
#
#         var popup_e3ed6c84426da4c7cf327c30f24caf03 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2e7d8f55891ef0eca236edac5d3ce58b = $(`&lt;div id=&quot;html_2e7d8f55891ef0eca236edac5d3ce58b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_e3ed6c84426da4c7cf327c30f24caf03.setContent(html_2e7d8f55891ef0eca236edac5d3ce58b);
#
#
#
#         marker_5cb76ebbf081e18833f3d347bff3ab37.bindPopup(popup_e3ed6c84426da4c7cf327c30f24caf03)
#         ;
#
#
#
#
#             var marker_41c1317f9083e20f2d065a9c25e4e54f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_3ca94834c134ea97066d43b7d87afb6e);
#
#
#         var popup_29d77606248d4710333153f918e508ea = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_aa4f0ecd532fc623af6764dc961e6ed6 = $(`&lt;div id=&quot;html_aa4f0ecd532fc623af6764dc961e6ed6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_29d77606248d4710333153f918e508ea.setContent(html_aa4f0ecd532fc623af6764dc961e6ed6);
#
#
#
#         marker_41c1317f9083e20f2d065a9c25e4e54f.bindPopup(popup_29d77606248d4710333153f918e508ea)
#         ;
#
#
#
#
#             var marker_b167c6125ad20bb73f1bde64c12151bf = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_3ca94834c134ea97066d43b7d87afb6e);
#
#
#         var popup_90650718ed95fc3c005dd78c97ff48d9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ecef4cb3ca895d551e13c4e6fca0ab8f = $(`&lt;div id=&quot;html_ecef4cb3ca895d551e13c4e6fca0ab8f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_90650718ed95fc3c005dd78c97ff48d9.setContent(html_ecef4cb3ca895d551e13c4e6fca0ab8f);
#
#
#
#         marker_b167c6125ad20bb73f1bde64c12151bf.bindPopup(popup_90650718ed95fc3c005dd78c97ff48d9)
#         ;
#
#
#
#
#             var marker_2535f42848880f6ca8e00092b1acbd9e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_3ca94834c134ea97066d43b7d87afb6e);
#
#
#         var popup_a3eac4cdefc11ba90fabfef060a6f94b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_81ec4e9cab4fd6038a32a7b3abb13099 = $(`&lt;div id=&quot;html_81ec4e9cab4fd6038a32a7b3abb13099&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_a3eac4cdefc11ba90fabfef060a6f94b.setContent(html_81ec4e9cab4fd6038a32a7b3abb13099);
#
#
#
#         marker_2535f42848880f6ca8e00092b1acbd9e.bindPopup(popup_a3eac4cdefc11ba90fabfef060a6f94b)
#         ;
#
#
#
#
#             var marker_9b1db53d8d6a772c75e2a2b5cc7af7b9 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_3ca94834c134ea97066d43b7d87afb6e);
#
#
#         var popup_e6d1754de8a7b5c001399db59d1df764 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_75323db022158af59c31c16bf47fab07 = $(`&lt;div id=&quot;html_75323db022158af59c31c16bf47fab07&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_e6d1754de8a7b5c001399db59d1df764.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_333790467eb148f9f126532eb090ec54 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_333790467eb148f9f126532eb090ec54&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_333790467eb148f9f126532eb090ec54 = L.map(
#                 &quot;map_333790467eb148f9f126532eb090ec54&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0e79fe7ccdf6331d226a672917745b53 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0e79fe7ccdf6331d226a672917745b53.addTo(map_333790467eb148f9f126532eb090ec54);
#
#
#             var feature_group_f5fe2ab53d14da3b6a0f0972fc2ecafa = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_7b06e17a1504556b426aa3d05e63a27a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_f5fe2ab53d14da3b6a0f0972fc2ecafa);
#
#
#         var popup_fe59c1a090ea6c918b1ef1172be10654 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9ed9d80e8e127d47b4543878c6d92db9 = $(`&lt;div id=&quot;html_9ed9d80e8e127d47b4543878c6d92db9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_fe59c1a090ea6c918b1ef1172be10654.setContent(html_9ed9d80e8e127d47b4543878c6d92db9);
#
#
#
#         marker_7b06e17a1504556b426aa3d05e63a27a.bindPopup(popup_fe59c1a090ea6c918b1ef1172be10654)
#         ;
#
#
#
#
#             var marker_5650220fd3f97ac3be8deb608b6b155d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_f5fe2ab53d14da3b6a0f0972fc2ecafa);
#
#
#         var popup_56ce3fb3d789578e4ff7ea9010878ba0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_179179d3fc679b2ebf4404edadc9df0a = $(`&lt;div id=&quot;html_179179d3fc679b2ebf4404edadc9df0a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_56ce3fb3d789578e4ff7ea9010878ba0.setContent(html_179179d3fc679b2ebf4404edadc9df0a);
#
#
#
#         marker_5650220fd3f97ac3be8deb608b6b155d.bindPopup(popup_56ce3fb3d789578e4ff7ea9010878ba0)
#         ;
#
#
#
#
#             var marker_5d92209688c8517cebc55783bbe37865 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_f5fe2ab53d14da3b6a0f0972fc2ecafa);
#
#
#         var popup_81d72630f47d23a766dda2020234a6b0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_03981991a7a73fdbc97ef3610f950112 = $(`&lt;div id=&quot;html_03981991a7a73fdbc97ef3610f950112&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_81d72630f47d23a766dda2020234a6b0.setContent(html_03981991a7a73fdbc97ef3610f950112);
#
#
#
#         marker_5d92209688c8517cebc55783bbe37865.bindPopup(popup_81d72630f47d23a766dda2020234a6b0)
#         ;
#
#
#
#
#             var marker_f1ad29dd618421856b5c449bb1a4f1c0 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_f5fe2ab53d14da3b6a0f0972fc2ecafa);
#
#
#         var popup_91aaa80e2608decb23230183e9d9eb13 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_79a2fe42eafc3d4324e26d8de08550ea = $(`&lt;div id=&quot;html_79a2fe42eafc3d4324e26d8de08550ea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_91aaa80e2608decb23230183e9d9eb13.setContent(html_79a2fe42eafc3d4324e26d8de08550ea);
#
#
#
#         marker_f1ad29dd618421856b5c449bb1a4f1c0.bindPopup(popup_91aaa80e2608decb23230183e9d9eb13)
#         ;
#
#
#
#
#             var marker_ceeda080ed681cf1551fa0cc2e5e4b5c = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_f5fe2ab53d14da3b6a0f0972fc2ecafa);
#
#
#         var popup_c3b738ea1717172c0e0628778d841b8e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cadddfef65e0382a617f946943452cfa {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cadddfef65e0382a617f946943452cfa&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cadddfef65e0382a617f946943452cfa = L.map(
#                 &quot;map_cadddfef65e0382a617f946943452cfa&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3786e78198f31e2ecf25605e30cf3bfa = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3786e78198f31e2ecf25605e30cf3bfa.addTo(map_cadddfef65e0382a617f946943452cfa);
#
#
#             var feature_group_a0ca4619418fa254b8cf57425a99c81e = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_a0ca4619418fa254b8cf57425a99c81e.addTo(map_cadddfef65e0382a617f946943452cfa);
#
#
#             var feature_group_sub_group_1d69d3b0ebf712e362e0358437c92bbc = L.featureGroup.subGroup(
#                 feature_group_a0ca4619418fa254b8cf57425a99c81e
#             );
#
#
#             var marker_f369e9723dd130e8959fc5f3206bc7e6 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_1d69d3b0ebf712e362e0358437c92bbc);
#
#
#         var popup_4f4889bbb1db5d6dfe585aeaee661aa4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_504463556f4a433e48359b7d87292b18 = $(`&lt;div id=&quot;html_504463556f4a433e48359b7d87292b18&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_4f4889bbb1db5d6dfe585aeaee661aa4.setContent(html_504463556f4a433e48359b7d87292b18);
#
#
#
#         marker_f369e9723dd130e8959fc5f3206bc7e6.bindPopup(popup_4f4889bbb1db5d6dfe585aeaee661aa4)
#         ;
#
#
#
#
#             var marker_b4ce94be55a342b49e4fd39a5e778050 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_1d69d3b0ebf712e362e0358437c92bbc);
#
#
#         var popup_dddc3fab854a6dfbf0bb65294023bf6a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_66f9ddf8c6c97b31688321b3beb76377 = $(`&lt;div id=&quot;html_66f9ddf8c6c97b31688321b3beb76377&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_dddc3fab854a6dfbf0bb65294023bf6a.setContent(html_66f9ddf8c6c97b31688321b3beb76377);
#
#
#
#         marker_b4ce94be55a342b49e4fd39a5e778050.bindPopup(popup_dddc3fab854a6dfbf0bb65294023bf6a)
#         ;
#
#
#
#
#             var marker_02e6f552ac73c81ad166c988251933dc = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_1d69d3b0ebf712e362e0358437c92bbc);
#
#
#         var popup_a8ebce0d05f4e69594a4f7e879db0049 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a885a823d17fcbe8bc75b779cf5c1cfe = $(`&lt;div id=&quot;html_a885a823d17fcbe8bc75b779cf5c1cfe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_a8ebce0d05f4e69594a4f7e879db0049.setContent(html_a885a823d17fcbe8bc75b779cf5c1cfe);
#
#
#
#         marker_02e6f552ac73c81ad166c988251933dc.bindPopup(popup_a8ebce0d05f4e69594a4f7e879db0049)
#         ;
#
#
#
#
#             var marker_cde4cf3a6fcf14164efcad3b4942a333 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_1d69d3b0ebf712e362e0358437c92bbc);
#
#
#         var popup_59bafc0184aa9324b21a08fb7d5b78ec = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1f0a220b20e500041e5ceff63b9a651a = $(`&lt;div id=&quot;html_1f0a220b20e500041e5ceff63b9a651a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_59bafc0184aa9324b21a08fb7d5b78ec.setContent(html_1f0a220b20e500041e5ceff63b9a651a);
#
#
#
#         marker_
