# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fee44d0e516a61f0221663010fd76c94 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fee44d0e516a61f0221663010fd76c94&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fee44d0e516a61f0221663010fd76c94 = L.map(
#                 &quot;map_fee44d0e516a61f0221663010fd76c94&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1db3f4a2eafe7e4823dc6818413455a4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1db3f4a2eafe7e4823dc6818413455a4.addTo(map_fee44d0e516a61f0221663010fd76c94);
#
#
#             var marker_d46fa162c09add22ca5de138631729f4 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_fee44d0e516a61f0221663010fd76c94);
#
#
#         var popup_7058aa54946c9918c1adcf8c8742c944 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fd5a4185b747d7696551846bae9d3bd1 = $(`&lt;div id=&quot;html_fd5a4185b747d7696551846bae9d3bd1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_7058aa54946c9918c1adcf8c8742c944.setContent(html_fd5a4185b747d7696551846bae9d3bd1);
#
#
#
#         marker_d46fa162c09add22ca5de138631729f4.bindPopup(popup_7058aa54946c9918c1adcf8c8742c944)
#         ;
#
#
#
#
#             var marker_eeb3e406c11f2e7380a1fdb1f34fd38d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_fee44d0e516a61f0221663010fd76c94);
#
#
#         var popup_64a5dff42b844e7c5563c52a27cb0291 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_252b63dd0c0a97bd6fbbda1b26fb0e31 = $(`&lt;div id=&quot;html_252b63dd0c0a97bd6fbbda1b26fb0e31&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_64a5dff42b844e7c5563c52a27cb0291.setContent(html_252b63dd0c0a97bd6fbbda1b26fb0e31);
#
#
#
#         marker_eeb3e406c11f2e7380a1fdb1f34fd38d.bindPopup(popup_64a5dff42b844e7c5563c52a27cb0291)
#         ;
#
#
#
#
#             var marker_d2f50fdb4b2de4b545b32d6090f0b387 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_fee44d0e516a61f0221663010fd76c94);
#
#
#         var popup_317566cfc223564053cf5633e7498dca = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d18d0a0d1c8b96a030d7220dc9bb3676 = $(`&lt;div id=&quot;html_d18d0a0d1c8b96a030d7220dc9bb3676&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_317566cfc223564053cf5633e7498dca.setContent(html_d18d0a0d1c8b96a030d7220dc9bb3676);
#
#
#
#         marker_d2f50fdb4b2de4b545b32d6090f0b387.bindPopup(popup_317566cfc223564053cf5633e7498dca)
#         ;
#
#
#
#
#             var marker_8e9ad1cd161b77777187bea4266812a5 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_fee44d0e516a61f0221663010fd76c94);
#
#
#         var popup_55623b71c94bc80e0169cc5256dafa99 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a896078637de02e16bf77aa6f25c92bb = $(`&lt;div id=&quot;html_a896078637de02e16bf77aa6f25c92bb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_55623b71c94bc80e0169cc5256dafa99.setContent(html_a896078637de02e16bf77aa6f25c92bb);
#
#
#
#         marker_8e9ad1cd161b77777187bea4266812a5.bindPopup(popup_55623b71c94bc80e0169cc5256dafa99)
#         ;
#
#
#
#
#             var marker_13920effc5e9c7fde73a01feb94ec03a = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_fee44d0e516a61f0221663010fd76c94);
#
#
#         var popup_188009198b6c03f4f9e5797ab5b17c89 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4f780caa8ac40265f0334ee7694339ef = $(`&lt;div id=&quot;html_4f780caa8ac40265f0334ee7694339ef&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_188009198b6c03f4f9e5797ab5b17c89.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4d8bf384e78fc3843a4f17c9fd098784 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4d8bf384e78fc3843a4f17c9fd098784&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4d8bf384e78fc3843a4f17c9fd098784 = L.map(
#                 &quot;map_4d8bf384e78fc3843a4f17c9fd098784&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_822a8e2262dce25e89a552d83c2733e2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_822a8e2262dce25e89a552d83c2733e2.addTo(map_4d8bf384e78fc3843a4f17c9fd098784);
#
#
#             var feature_group_fe01a360d6346a224b9b83b71336561a = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_00103a12ac9a2495c523c4438650ad5f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_fe01a360d6346a224b9b83b71336561a);
#
#
#         var popup_24fb55db5cd5b777090bcf284ffe0bc2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9c87e6f63c7522b1bae06aa0e49445fd = $(`&lt;div id=&quot;html_9c87e6f63c7522b1bae06aa0e49445fd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_24fb55db5cd5b777090bcf284ffe0bc2.setContent(html_9c87e6f63c7522b1bae06aa0e49445fd);
#
#
#
#         marker_00103a12ac9a2495c523c4438650ad5f.bindPopup(popup_24fb55db5cd5b777090bcf284ffe0bc2)
#         ;
#
#
#
#
#             var marker_bbdfbe5308c554461640b17bbde930ca = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_fe01a360d6346a224b9b83b71336561a);
#
#
#         var popup_3c573ef94fcb24d44da8111856103c08 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e9d11964d0c1853662ef3b8b56b785ff = $(`&lt;div id=&quot;html_e9d11964d0c1853662ef3b8b56b785ff&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_3c573ef94fcb24d44da8111856103c08.setContent(html_e9d11964d0c1853662ef3b8b56b785ff);
#
#
#
#         marker_bbdfbe5308c554461640b17bbde930ca.bindPopup(popup_3c573ef94fcb24d44da8111856103c08)
#         ;
#
#
#
#
#             var marker_e4c5e2ebaf4649010d5c67bffe4edee4 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_fe01a360d6346a224b9b83b71336561a);
#
#
#         var popup_835bd0f4f0144155d39af60e2e89d091 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7702a6f2fb46c8132d7c501de1ac6d7a = $(`&lt;div id=&quot;html_7702a6f2fb46c8132d7c501de1ac6d7a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_835bd0f4f0144155d39af60e2e89d091.setContent(html_7702a6f2fb46c8132d7c501de1ac6d7a);
#
#
#
#         marker_e4c5e2ebaf4649010d5c67bffe4edee4.bindPopup(popup_835bd0f4f0144155d39af60e2e89d091)
#         ;
#
#
#
#
#             var marker_31a667af6a5f803aec027cf3c56acd97 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_fe01a360d6346a224b9b83b71336561a);
#
#
#         var popup_7c4f535e98d138b671ece3b63f8a4418 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9924151ab55f52cd1fc328693775d6f9 = $(`&lt;div id=&quot;html_9924151ab55f52cd1fc328693775d6f9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_7c4f535e98d138b671ece3b63f8a4418.setContent(html_9924151ab55f52cd1fc328693775d6f9);
#
#
#
#         marker_31a667af6a5f803aec027cf3c56acd97.bindPopup(popup_7c4f535e98d138b671ece3b63f8a4418)
#         ;
#
#
#
#
#             var marker_412828cd06f8db93fbe7d81c288652d2 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_fe01a360d6346a224b9b83b71336561a);
#
#
#         var popup_8f3e050cd0ced6b920d534f8f49d4cc0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_421ed5b3482970ade18ff95b4d8aea5e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_421ed5b3482970ade18ff95b4d8aea5e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_421ed5b3482970ade18ff95b4d8aea5e = L.map(
#                 &quot;map_421ed5b3482970ade18ff95b4d8aea5e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a82d65f0fd07b3f00ffb428aac1cd946 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a82d65f0fd07b3f00ffb428aac1cd946.addTo(map_421ed5b3482970ade18ff95b4d8aea5e);
#
#
#             var feature_group_2d2f6d81e5a3825674efcb9759f9cf94 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_2d2f6d81e5a3825674efcb9759f9cf94.addTo(map_421ed5b3482970ade18ff95b4d8aea5e);
#
#
#             var feature_group_sub_group_c9b10536e64fcb58259b45f7e0be4852 = L.featureGroup.subGroup(
#                 feature_group_2d2f6d81e5a3825674efcb9759f9cf94
#             );
#
#
#             var marker_6da11b49d47c4b4b9dc6e55bdfae3473 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_c9b10536e64fcb58259b45f7e0be4852);
#
#
#         var popup_859ff9e7b492d38b0ecc7358ab12f49f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4f1d351ff18ef693a8a85d72059dd576 = $(`&lt;div id=&quot;html_4f1d351ff18ef693a8a85d72059dd576&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_859ff9e7b492d38b0ecc7358ab12f49f.setContent(html_4f1d351ff18ef693a8a85d72059dd576);
#
#
#
#         marker_6da11b49d47c4b4b9dc6e55bdfae3473.bindPopup(popup_859ff9e7b492d38b0ecc7358ab12f49f)
#         ;
#
#
#
#
#             var marker_622598f6e20eefe2454c70d9480af8da = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_c9b10536e64fcb58259b45f7e0be4852);
#
#
#         var popup_05fb98de80f2e6c7582e6da0d048b2ec = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7f86abe77168fb587d00762891019215 = $(`&lt;div id=&quot;html_7f86abe77168fb587d00762891019215&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_05fb98de80f2e6c7582e6da0d048b2ec.setContent(html_7f86abe77168fb587d00762891019215);
#
#
#
#         marker_622598f6e20eefe2454c70d9480af8da.bindPopup(popup_05fb98de80f2e6c7582e6da0d048b2ec)
#         ;
#
#
#
#
#             var marker_9300288bb8be6702aeb7fe32791c1ffb = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_c9b10536e64fcb58259b45f7e0be4852);
#
#
#         var popup_dde206155c3063c2e3b11bf2eb4103d2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9dd5312490b8876d19215453d5315a24 = $(`&lt;div id=&quot;html_9dd5312490b8876d19215453d5315a24&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_dde206155c3063c2e3b11bf2eb4103d2.setContent(html_9dd5312490b8876d19215453d5315a24);
#
#
#
#         marker_9300288bb8be6702aeb7fe32791c1ffb.bindPopup(popup_dde206155c3063c2e3b11bf2eb4103d2)
#         ;
#
#
#
#
#             var marker_17a263198cc37a5028c372ba673936b2 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_c9b10536e64fcb58259b45f7e0be4852);
#
#
#         var popup_da1b8eb3d685fb24cc7e3b4312b124ed = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c54f6503446d7c3fbc968fa514dbd78a = $(`&lt;div id=&quot;html_c54f6503446d7c3fbc968fa514dbd78a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_da1b8eb3d685fb24cc7e3b4312b124ed.setContent(html_c54f6503446d7c3fbc968fa514dbd78a);
#
#
#
#         marker_
