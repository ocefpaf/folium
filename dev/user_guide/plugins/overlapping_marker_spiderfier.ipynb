# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ff616c7cd75dfb26a775090acc79c07c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ff616c7cd75dfb26a775090acc79c07c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ff616c7cd75dfb26a775090acc79c07c = L.map(
#                 &quot;map_ff616c7cd75dfb26a775090acc79c07c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8406267db027772e827d663bc5472a05 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8406267db027772e827d663bc5472a05.addTo(map_ff616c7cd75dfb26a775090acc79c07c);
#
#
#             var marker_97f58d58bda865f3a825daee58ad7a5d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_ff616c7cd75dfb26a775090acc79c07c);
#
#
#         var popup_5da6567655b7da725bdc90475e3cf376 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9d1a6b5f359045196aa359aa0cd93dc0 = $(`&lt;div id=&quot;html_9d1a6b5f359045196aa359aa0cd93dc0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_5da6567655b7da725bdc90475e3cf376.setContent(html_9d1a6b5f359045196aa359aa0cd93dc0);
#
#
#
#         marker_97f58d58bda865f3a825daee58ad7a5d.bindPopup(popup_5da6567655b7da725bdc90475e3cf376)
#         ;
#
#
#
#
#             var marker_af503d1415f8e30681acc0c4e45748cb = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_ff616c7cd75dfb26a775090acc79c07c);
#
#
#         var popup_3891b6d4dbac44f3dc672e4a75f772c8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_afa818ab8f930d4c584ff757482c5284 = $(`&lt;div id=&quot;html_afa818ab8f930d4c584ff757482c5284&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_3891b6d4dbac44f3dc672e4a75f772c8.setContent(html_afa818ab8f930d4c584ff757482c5284);
#
#
#
#         marker_af503d1415f8e30681acc0c4e45748cb.bindPopup(popup_3891b6d4dbac44f3dc672e4a75f772c8)
#         ;
#
#
#
#
#             var marker_aa4d4e2b603b18d3d4ebe6a2d5c91bc4 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_ff616c7cd75dfb26a775090acc79c07c);
#
#
#         var popup_16ec6528757a4b3f941e7f18c17ffd92 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e336c0146da90194a91baefe2c700f1a = $(`&lt;div id=&quot;html_e336c0146da90194a91baefe2c700f1a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_16ec6528757a4b3f941e7f18c17ffd92.setContent(html_e336c0146da90194a91baefe2c700f1a);
#
#
#
#         marker_aa4d4e2b603b18d3d4ebe6a2d5c91bc4.bindPopup(popup_16ec6528757a4b3f941e7f18c17ffd92)
#         ;
#
#
#
#
#             var marker_31f7df1987a20865ab387fa4598ffa60 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_ff616c7cd75dfb26a775090acc79c07c);
#
#
#         var popup_4d2eb5f406d78a41ab5fcaccc10322b7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d50f50bad968def9c0546cc6df7c24c1 = $(`&lt;div id=&quot;html_d50f50bad968def9c0546cc6df7c24c1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_4d2eb5f406d78a41ab5fcaccc10322b7.setContent(html_d50f50bad968def9c0546cc6df7c24c1);
#
#
#
#         marker_31f7df1987a20865ab387fa4598ffa60.bindPopup(popup_4d2eb5f406d78a41ab5fcaccc10322b7)
#         ;
#
#
#
#
#             var marker_a62afca85ce3752a20a540b92348b4fe = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_ff616c7cd75dfb26a775090acc79c07c);
#
#
#         var popup_979e76b15717d305088757ee3e1c8049 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_928541c551af62efe2a2ddd93380764f = $(`&lt;div id=&quot;html_928541c551af62efe2a2ddd93380764f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_979e76b15717d305088757ee3e1c8049.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b1f2a34e8fca0dc70e932ee2a5dbe3f5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b1f2a34e8fca0dc70e932ee2a5dbe3f5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b1f2a34e8fca0dc70e932ee2a5dbe3f5 = L.map(
#                 &quot;map_b1f2a34e8fca0dc70e932ee2a5dbe3f5&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8ab8d3ca44a4688f0ccdf951ab2efadd = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8ab8d3ca44a4688f0ccdf951ab2efadd.addTo(map_b1f2a34e8fca0dc70e932ee2a5dbe3f5);
#
#
#             var feature_group_6bf85bc252f37141733ee053edb381e7 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_bf3102da6e08f7a8580c064f87fb2869 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_6bf85bc252f37141733ee053edb381e7);
#
#
#         var popup_835dff97a26b9cf1f49c1690d6bb20c8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2a1fca7b89ae617e335d776574d190c1 = $(`&lt;div id=&quot;html_2a1fca7b89ae617e335d776574d190c1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_835dff97a26b9cf1f49c1690d6bb20c8.setContent(html_2a1fca7b89ae617e335d776574d190c1);
#
#
#
#         marker_bf3102da6e08f7a8580c064f87fb2869.bindPopup(popup_835dff97a26b9cf1f49c1690d6bb20c8)
#         ;
#
#
#
#
#             var marker_605910ad873e1e9dd5b90fbfe330a860 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_6bf85bc252f37141733ee053edb381e7);
#
#
#         var popup_b3297819dbfa60cae725419b373dc7a7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bb215f3a4950803076de398dab0bdc46 = $(`&lt;div id=&quot;html_bb215f3a4950803076de398dab0bdc46&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_b3297819dbfa60cae725419b373dc7a7.setContent(html_bb215f3a4950803076de398dab0bdc46);
#
#
#
#         marker_605910ad873e1e9dd5b90fbfe330a860.bindPopup(popup_b3297819dbfa60cae725419b373dc7a7)
#         ;
#
#
#
#
#             var marker_b85e8c91cff7cacd1cb55cb83f6d1a09 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_6bf85bc252f37141733ee053edb381e7);
#
#
#         var popup_a38b1e1d92408e047f6ec93fa4ad71eb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bc21791d0cae1adf46f020e91eb41042 = $(`&lt;div id=&quot;html_bc21791d0cae1adf46f020e91eb41042&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_a38b1e1d92408e047f6ec93fa4ad71eb.setContent(html_bc21791d0cae1adf46f020e91eb41042);
#
#
#
#         marker_b85e8c91cff7cacd1cb55cb83f6d1a09.bindPopup(popup_a38b1e1d92408e047f6ec93fa4ad71eb)
#         ;
#
#
#
#
#             var marker_9fcbd69eb43af6222ddd58ecb975afbe = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_6bf85bc252f37141733ee053edb381e7);
#
#
#         var popup_4b7d681f9f9893f012064e5757e703c6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_13bb364e59157ecc9af36de5e4a0001b = $(`&lt;div id=&quot;html_13bb364e59157ecc9af36de5e4a0001b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_4b7d681f9f9893f012064e5757e703c6.setContent(html_13bb364e59157ecc9af36de5e4a0001b);
#
#
#
#         marker_9fcbd69eb43af6222ddd58ecb975afbe.bindPopup(popup_4b7d681f9f9893f012064e5757e703c6)
#         ;
#
#
#
#
#             var marker_e31bf365c494fe1cece756ffe7db836b = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_6bf85bc252f37141733ee053edb381e7);
#
#
#         var popup_c31b8723e21b8197d18d29d8bb59ee5a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e34bb08e04f392aa86076b3cefc95b6a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e34bb08e04f392aa86076b3cefc95b6a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e34bb08e04f392aa86076b3cefc95b6a = L.map(
#                 &quot;map_e34bb08e04f392aa86076b3cefc95b6a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b7935c5075faa190d4d21237e40cca33 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b7935c5075faa190d4d21237e40cca33.addTo(map_e34bb08e04f392aa86076b3cefc95b6a);
#
#
#             var feature_group_80bf62b330cc0dde9e0386b88b9e8788 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_80bf62b330cc0dde9e0386b88b9e8788.addTo(map_e34bb08e04f392aa86076b3cefc95b6a);
#
#
#             var feature_group_sub_group_b36710680887779f6ddde5123fa8d615 = L.featureGroup.subGroup(
#                 feature_group_80bf62b330cc0dde9e0386b88b9e8788
#             );
#
#
#             var marker_41da6f98c3902cf7de39d831323b9300 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_b36710680887779f6ddde5123fa8d615);
#
#
#         var popup_9226eb635ccfca378a820fc04bf1ee5e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bc1c475cac32e396d2134925e2b26cd9 = $(`&lt;div id=&quot;html_bc1c475cac32e396d2134925e2b26cd9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_9226eb635ccfca378a820fc04bf1ee5e.setContent(html_bc1c475cac32e396d2134925e2b26cd9);
#
#
#
#         marker_41da6f98c3902cf7de39d831323b9300.bindPopup(popup_9226eb635ccfca378a820fc04bf1ee5e)
#         ;
#
#
#
#
#             var marker_78d9ab174f13bb7f1999a4c7aad4a183 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_b36710680887779f6ddde5123fa8d615);
#
#
#         var popup_cbb60b57625f4461d73ec0dbf1c5b18e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e44e62b80dd0b13cdce8a91ab963417c = $(`&lt;div id=&quot;html_e44e62b80dd0b13cdce8a91ab963417c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_cbb60b57625f4461d73ec0dbf1c5b18e.setContent(html_e44e62b80dd0b13cdce8a91ab963417c);
#
#
#
#         marker_78d9ab174f13bb7f1999a4c7aad4a183.bindPopup(popup_cbb60b57625f4461d73ec0dbf1c5b18e)
#         ;
#
#
#
#
#             var marker_4b056325b4eaee2063defa6d803a3307 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_b36710680887779f6ddde5123fa8d615);
#
#
#         var popup_376460aebbdb45d7f08e5660cb24fc7d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_378a5bbc1bbff46021c57036a1aa0018 = $(`&lt;div id=&quot;html_378a5bbc1bbff46021c57036a1aa0018&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_376460aebbdb45d7f08e5660cb24fc7d.setContent(html_378a5bbc1bbff46021c57036a1aa0018);
#
#
#
#         marker_4b056325b4eaee2063defa6d803a3307.bindPopup(popup_376460aebbdb45d7f08e5660cb24fc7d)
#         ;
#
#
#
#
#             var marker_4efe96b844d9a2b6e346daad6b8a111d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_b36710680887779f6ddde5123fa8d615);
#
#
#         var popup_537bf6dc1fe07db4b93b0a3d0e2671ba = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4271bdb72fbe03aa8e298c3177c63c77 = $(`&lt;div id=&quot;html_4271bdb72fbe03aa8e298c3177c63c77&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_537bf6dc1fe07db4b93b0a3d0e2671ba.setContent(html_4271bdb72fbe03aa8e298c3177c63c77);
#
#
#
#         marker_
