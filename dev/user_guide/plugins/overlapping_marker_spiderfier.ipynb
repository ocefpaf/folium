# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c8098d2ca922a8487d966b2e5dfaf144 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c8098d2ca922a8487d966b2e5dfaf144&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c8098d2ca922a8487d966b2e5dfaf144 = L.map(
#                 &quot;map_c8098d2ca922a8487d966b2e5dfaf144&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e769c2d92ff93d93e089391b019a490b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e769c2d92ff93d93e089391b019a490b.addTo(map_c8098d2ca922a8487d966b2e5dfaf144);
#
#
#             var marker_76aef2117953e98b212981aeb3316ae2 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_c8098d2ca922a8487d966b2e5dfaf144);
#
#
#         var popup_0cfa0496f65ae89fa0e9d763d9c52768 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_672794ef63fc6a0522c3e9673842c30f = $(`&lt;div id=&quot;html_672794ef63fc6a0522c3e9673842c30f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_0cfa0496f65ae89fa0e9d763d9c52768.setContent(html_672794ef63fc6a0522c3e9673842c30f);
#
#
#
#         marker_76aef2117953e98b212981aeb3316ae2.bindPopup(popup_0cfa0496f65ae89fa0e9d763d9c52768)
#         ;
#
#
#
#
#             var marker_8267be41affbd739041435665767b8b6 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_c8098d2ca922a8487d966b2e5dfaf144);
#
#
#         var popup_58939540369e8a4d426614c72634ff98 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e1a256e79240d28b31ca5b862b984e4f = $(`&lt;div id=&quot;html_e1a256e79240d28b31ca5b862b984e4f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_58939540369e8a4d426614c72634ff98.setContent(html_e1a256e79240d28b31ca5b862b984e4f);
#
#
#
#         marker_8267be41affbd739041435665767b8b6.bindPopup(popup_58939540369e8a4d426614c72634ff98)
#         ;
#
#
#
#
#             var marker_84cb9098c10410068d50693b077c4a6d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_c8098d2ca922a8487d966b2e5dfaf144);
#
#
#         var popup_472409fda5c64dfcb8b30da1e9856274 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a3d8fc66cc7b7ad5ab04789c06424ff4 = $(`&lt;div id=&quot;html_a3d8fc66cc7b7ad5ab04789c06424ff4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_472409fda5c64dfcb8b30da1e9856274.setContent(html_a3d8fc66cc7b7ad5ab04789c06424ff4);
#
#
#
#         marker_84cb9098c10410068d50693b077c4a6d.bindPopup(popup_472409fda5c64dfcb8b30da1e9856274)
#         ;
#
#
#
#
#             var marker_bbfdbdf79f906b0c84e608c73d0cd502 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_c8098d2ca922a8487d966b2e5dfaf144);
#
#
#         var popup_9cb97c2a2cdb194abef83a84e9f9b078 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_88a8bb66680a3290883d807100fa5c0f = $(`&lt;div id=&quot;html_88a8bb66680a3290883d807100fa5c0f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_9cb97c2a2cdb194abef83a84e9f9b078.setContent(html_88a8bb66680a3290883d807100fa5c0f);
#
#
#
#         marker_bbfdbdf79f906b0c84e608c73d0cd502.bindPopup(popup_9cb97c2a2cdb194abef83a84e9f9b078)
#         ;
#
#
#
#
#             var marker_d0db09656167d0a6531c6210303a0128 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_c8098d2ca922a8487d966b2e5dfaf144);
#
#
#         var popup_bc392bed6467901087597c279983b14e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_057481f2c1bae853a65b3b559750ffe3 = $(`&lt;div id=&quot;html_057481f2c1bae853a65b3b559750ffe3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_bc392bed6467901087597c279983b14e.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e95322b31a074d811685c34710d17714 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e95322b31a074d811685c34710d17714&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e95322b31a074d811685c34710d17714 = L.map(
#                 &quot;map_e95322b31a074d811685c34710d17714&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_debe38e3689ef808d60def87e665a1df = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_debe38e3689ef808d60def87e665a1df.addTo(map_e95322b31a074d811685c34710d17714);
#
#
#             var feature_group_a1ee4a6456602f5a6a3b787b451bd7d3 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_88b0663132952581b8135611a90edf47 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_a1ee4a6456602f5a6a3b787b451bd7d3);
#
#
#         var popup_29271dae0492d7ba2129e563e3f9ef02 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0937cf5b650cf38e6845b062c6c0ebf5 = $(`&lt;div id=&quot;html_0937cf5b650cf38e6845b062c6c0ebf5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_29271dae0492d7ba2129e563e3f9ef02.setContent(html_0937cf5b650cf38e6845b062c6c0ebf5);
#
#
#
#         marker_88b0663132952581b8135611a90edf47.bindPopup(popup_29271dae0492d7ba2129e563e3f9ef02)
#         ;
#
#
#
#
#             var marker_002d49742825286d46659939ed6417c5 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_a1ee4a6456602f5a6a3b787b451bd7d3);
#
#
#         var popup_e7b73700d22dc092944583a5bc6f655e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_54f3a4b5dbe9cac0b154c5a830aebc9b = $(`&lt;div id=&quot;html_54f3a4b5dbe9cac0b154c5a830aebc9b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_e7b73700d22dc092944583a5bc6f655e.setContent(html_54f3a4b5dbe9cac0b154c5a830aebc9b);
#
#
#
#         marker_002d49742825286d46659939ed6417c5.bindPopup(popup_e7b73700d22dc092944583a5bc6f655e)
#         ;
#
#
#
#
#             var marker_9a2cfcfb825f7b4456a24776c3fc59a0 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_a1ee4a6456602f5a6a3b787b451bd7d3);
#
#
#         var popup_7dc70882bc9b6934260a12a85135f902 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a8663cac90353a3ce3988a16d517ef32 = $(`&lt;div id=&quot;html_a8663cac90353a3ce3988a16d517ef32&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_7dc70882bc9b6934260a12a85135f902.setContent(html_a8663cac90353a3ce3988a16d517ef32);
#
#
#
#         marker_9a2cfcfb825f7b4456a24776c3fc59a0.bindPopup(popup_7dc70882bc9b6934260a12a85135f902)
#         ;
#
#
#
#
#             var marker_df1d4099d258abaf59471d5dbbe49183 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_a1ee4a6456602f5a6a3b787b451bd7d3);
#
#
#         var popup_9f1d671b28775fb9e4f30d9d72feed70 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0f02788df77f181adc070a1a657ff129 = $(`&lt;div id=&quot;html_0f02788df77f181adc070a1a657ff129&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_9f1d671b28775fb9e4f30d9d72feed70.setContent(html_0f02788df77f181adc070a1a657ff129);
#
#
#
#         marker_df1d4099d258abaf59471d5dbbe49183.bindPopup(popup_9f1d671b28775fb9e4f30d9d72feed70)
#         ;
#
#
#
#
#             var marker_23e76ec78401b284c6d4655b121ce025 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_a1ee4a6456602f5a6a3b787b451bd7d3);
#
#
#         var popup_9595cc418314f1f15c0e9620cd890fdb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d2b9a88f84509c0a6ccf6d9fdebb9ed4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d2b9a88f84509c0a6ccf6d9fdebb9ed4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d2b9a88f84509c0a6ccf6d9fdebb9ed4 = L.map(
#                 &quot;map_d2b9a88f84509c0a6ccf6d9fdebb9ed4&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d981750273c2380822901cc5bad94adc = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d981750273c2380822901cc5bad94adc.addTo(map_d2b9a88f84509c0a6ccf6d9fdebb9ed4);
#
#
#             var feature_group_4900ffb596c0b89c1b0f3c9a013ba3e2 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_4900ffb596c0b89c1b0f3c9a013ba3e2.addTo(map_d2b9a88f84509c0a6ccf6d9fdebb9ed4);
#
#
#             var feature_group_sub_group_d32ee76aa3cabe4096ffd0488b12fcf3 = L.featureGroup.subGroup(
#                 feature_group_4900ffb596c0b89c1b0f3c9a013ba3e2
#             );
#
#
#             var marker_2f9b7046e9c74f7c203e83e5cde5cc83 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_d32ee76aa3cabe4096ffd0488b12fcf3);
#
#
#         var popup_2954b962f9f59a1b41a413e2e8866801 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7d87cef752b82134733c4bbadd9dd11d = $(`&lt;div id=&quot;html_7d87cef752b82134733c4bbadd9dd11d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_2954b962f9f59a1b41a413e2e8866801.setContent(html_7d87cef752b82134733c4bbadd9dd11d);
#
#
#
#         marker_2f9b7046e9c74f7c203e83e5cde5cc83.bindPopup(popup_2954b962f9f59a1b41a413e2e8866801)
#         ;
#
#
#
#
#             var marker_a00c978d106b0ff0fafcbddf92024d50 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_d32ee76aa3cabe4096ffd0488b12fcf3);
#
#
#         var popup_91175ff1b68ede5409f12e88315d8130 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_874248511a60439fc458b68ddbb3f05e = $(`&lt;div id=&quot;html_874248511a60439fc458b68ddbb3f05e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_91175ff1b68ede5409f12e88315d8130.setContent(html_874248511a60439fc458b68ddbb3f05e);
#
#
#
#         marker_a00c978d106b0ff0fafcbddf92024d50.bindPopup(popup_91175ff1b68ede5409f12e88315d8130)
#         ;
#
#
#
#
#             var marker_75c15ba8fdacd4e8f33be6b76d6624b4 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_d32ee76aa3cabe4096ffd0488b12fcf3);
#
#
#         var popup_398144c8ea05268f744fdbc237956ef7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_65b43653d0f031830bb5e9bec2a65ed5 = $(`&lt;div id=&quot;html_65b43653d0f031830bb5e9bec2a65ed5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_398144c8ea05268f744fdbc237956ef7.setContent(html_65b43653d0f031830bb5e9bec2a65ed5);
#
#
#
#         marker_75c15ba8fdacd4e8f33be6b76d6624b4.bindPopup(popup_398144c8ea05268f744fdbc237956ef7)
#         ;
#
#
#
#
#             var marker_955551cd8cf83d5044e7970d2af0adfd = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_d32ee76aa3cabe4096ffd0488b12fcf3);
#
#
#         var popup_6184799f65f9e5da4daf97a976798a3e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a7e4288ae9d56923286b5e90a586ab7d = $(`&lt;div id=&quot;html_a7e4288ae9d56923286b5e90a586ab7d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_6184799f65f9e5da4daf97a976798a3e.setContent(html_a7e4288ae9d56923286b5e90a586ab7d);
#
#
#
#         marker_
