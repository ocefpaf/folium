# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ee87b048b6e17c0341736beccf621949 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ee87b048b6e17c0341736beccf621949&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ee87b048b6e17c0341736beccf621949 = L.map(
#                 &quot;map_ee87b048b6e17c0341736beccf621949&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_13567776f76edbbf1d82157602d0b1dc = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_13567776f76edbbf1d82157602d0b1dc.addTo(map_ee87b048b6e17c0341736beccf621949);
#
#
#             var marker_f227b2b57053b28cbc67904b663f14cd = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_ee87b048b6e17c0341736beccf621949);
#
#
#         var popup_6279a5b94f3546686330a59d73e6e122 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_58260dc73a53525110f43eaddcb53741 = $(`&lt;div id=&quot;html_58260dc73a53525110f43eaddcb53741&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_6279a5b94f3546686330a59d73e6e122.setContent(html_58260dc73a53525110f43eaddcb53741);
#
#
#
#         marker_f227b2b57053b28cbc67904b663f14cd.bindPopup(popup_6279a5b94f3546686330a59d73e6e122)
#         ;
#
#
#
#
#             var marker_98d645f905bd9c42aca777a343629c17 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_ee87b048b6e17c0341736beccf621949);
#
#
#         var popup_c74704034fd3026422849f91c625ff4e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1bed3a799b6ffad0d51e6c70b72eadfa = $(`&lt;div id=&quot;html_1bed3a799b6ffad0d51e6c70b72eadfa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_c74704034fd3026422849f91c625ff4e.setContent(html_1bed3a799b6ffad0d51e6c70b72eadfa);
#
#
#
#         marker_98d645f905bd9c42aca777a343629c17.bindPopup(popup_c74704034fd3026422849f91c625ff4e)
#         ;
#
#
#
#
#             var marker_9514131c56d06c112cbf0bb554e0972c = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_ee87b048b6e17c0341736beccf621949);
#
#
#         var popup_7154f90bb120375ad13532a7243a2850 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_852201bfe9ad8cda00894c5cfff74c4d = $(`&lt;div id=&quot;html_852201bfe9ad8cda00894c5cfff74c4d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_7154f90bb120375ad13532a7243a2850.setContent(html_852201bfe9ad8cda00894c5cfff74c4d);
#
#
#
#         marker_9514131c56d06c112cbf0bb554e0972c.bindPopup(popup_7154f90bb120375ad13532a7243a2850)
#         ;
#
#
#
#
#             var marker_248abb5a2c7e728398a839ced0674ed3 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_ee87b048b6e17c0341736beccf621949);
#
#
#         var popup_e2f5cbc0ce0f4e1d55355ad98691b079 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6bf1a26a9063442126e4be576b3692f1 = $(`&lt;div id=&quot;html_6bf1a26a9063442126e4be576b3692f1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_e2f5cbc0ce0f4e1d55355ad98691b079.setContent(html_6bf1a26a9063442126e4be576b3692f1);
#
#
#
#         marker_248abb5a2c7e728398a839ced0674ed3.bindPopup(popup_e2f5cbc0ce0f4e1d55355ad98691b079)
#         ;
#
#
#
#
#             var marker_e82813516daff72d6b4f93797366de06 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_ee87b048b6e17c0341736beccf621949);
#
#
#         var popup_0b48111fe9429c7134b099f8bd37c048 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f53947d4508be78eb2b52a409adc3621 = $(`&lt;div id=&quot;html_f53947d4508be78eb2b52a409adc3621&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_0b48111fe9429c7134b099f8bd37c048.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5c915d8fa721b3531acfca07f2c9b25e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5c915d8fa721b3531acfca07f2c9b25e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5c915d8fa721b3531acfca07f2c9b25e = L.map(
#                 &quot;map_5c915d8fa721b3531acfca07f2c9b25e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b861213f752231cc31c7cf1e6b12462d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b861213f752231cc31c7cf1e6b12462d.addTo(map_5c915d8fa721b3531acfca07f2c9b25e);
#
#
#             var feature_group_7f8ea74e28317bc54ffdce5c94a35f12 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_7552de92f5403d1309f543959118caa5 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_7f8ea74e28317bc54ffdce5c94a35f12);
#
#
#         var popup_53dd1a2e0433e7964e1029f04648402e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c8f2a70a1a177c0cd97d5969b6ccd5fd = $(`&lt;div id=&quot;html_c8f2a70a1a177c0cd97d5969b6ccd5fd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_53dd1a2e0433e7964e1029f04648402e.setContent(html_c8f2a70a1a177c0cd97d5969b6ccd5fd);
#
#
#
#         marker_7552de92f5403d1309f543959118caa5.bindPopup(popup_53dd1a2e0433e7964e1029f04648402e)
#         ;
#
#
#
#
#             var marker_05ba1e5dc08459ae2f77a2055dd347bc = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_7f8ea74e28317bc54ffdce5c94a35f12);
#
#
#         var popup_afce491cb3b05fade4e906beaea9fc3f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ce645d685e05067acfd668285091bff6 = $(`&lt;div id=&quot;html_ce645d685e05067acfd668285091bff6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_afce491cb3b05fade4e906beaea9fc3f.setContent(html_ce645d685e05067acfd668285091bff6);
#
#
#
#         marker_05ba1e5dc08459ae2f77a2055dd347bc.bindPopup(popup_afce491cb3b05fade4e906beaea9fc3f)
#         ;
#
#
#
#
#             var marker_9e23d2bc4ac5fc768bd9fbe4e7bb005e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_7f8ea74e28317bc54ffdce5c94a35f12);
#
#
#         var popup_a74fad60697c9af8c6036a55c878ba0a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5978b2e7e67926f7e4e29ca25076fd61 = $(`&lt;div id=&quot;html_5978b2e7e67926f7e4e29ca25076fd61&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_a74fad60697c9af8c6036a55c878ba0a.setContent(html_5978b2e7e67926f7e4e29ca25076fd61);
#
#
#
#         marker_9e23d2bc4ac5fc768bd9fbe4e7bb005e.bindPopup(popup_a74fad60697c9af8c6036a55c878ba0a)
#         ;
#
#
#
#
#             var marker_d99ad428fd3ecec4c73e89961abeedaf = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_7f8ea74e28317bc54ffdce5c94a35f12);
#
#
#         var popup_bab41a74e332d80db88047a47a5feb8e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5ba733ccbdb4228930fcc22b5d533cae = $(`&lt;div id=&quot;html_5ba733ccbdb4228930fcc22b5d533cae&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_bab41a74e332d80db88047a47a5feb8e.setContent(html_5ba733ccbdb4228930fcc22b5d533cae);
#
#
#
#         marker_d99ad428fd3ecec4c73e89961abeedaf.bindPopup(popup_bab41a74e332d80db88047a47a5feb8e)
#         ;
#
#
#
#
#             var marker_9b23470dd70d93673b36c9db538323a5 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_7f8ea74e28317bc54ffdce5c94a35f12);
#
#
#         var popup_55d3e7bf551b428dfd6150b343c3fb24 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cf551eb1c843f9ac4a644d50b3f075a1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cf551eb1c843f9ac4a644d50b3f075a1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cf551eb1c843f9ac4a644d50b3f075a1 = L.map(
#                 &quot;map_cf551eb1c843f9ac4a644d50b3f075a1&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_85e774d40d275e9cb9df08b8308bff45 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_85e774d40d275e9cb9df08b8308bff45.addTo(map_cf551eb1c843f9ac4a644d50b3f075a1);
#
#
#             var feature_group_51bd3fc3f11a0a4d2d26803a08a5aaf7 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_51bd3fc3f11a0a4d2d26803a08a5aaf7.addTo(map_cf551eb1c843f9ac4a644d50b3f075a1);
#
#
#             var feature_group_sub_group_8a5a87476ba13425bd0780291a87a7ee = L.featureGroup.subGroup(
#                 feature_group_51bd3fc3f11a0a4d2d26803a08a5aaf7
#             );
#
#
#             var marker_cdc1b53b4383ba393f576aa9cfee3a63 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_8a5a87476ba13425bd0780291a87a7ee);
#
#
#         var popup_a8f548a272ab0b8c7ea9c41198d73b4e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_62f0eeff0e12a8b123dc8a88bca53c1b = $(`&lt;div id=&quot;html_62f0eeff0e12a8b123dc8a88bca53c1b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_a8f548a272ab0b8c7ea9c41198d73b4e.setContent(html_62f0eeff0e12a8b123dc8a88bca53c1b);
#
#
#
#         marker_cdc1b53b4383ba393f576aa9cfee3a63.bindPopup(popup_a8f548a272ab0b8c7ea9c41198d73b4e)
#         ;
#
#
#
#
#             var marker_9b6e7725f3c1fcefbaa4087f913ec872 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_8a5a87476ba13425bd0780291a87a7ee);
#
#
#         var popup_66caac7420a3e0b7c5002c6c8da5a27e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_28e3808b451d7bc56a658e044d18583c = $(`&lt;div id=&quot;html_28e3808b451d7bc56a658e044d18583c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_66caac7420a3e0b7c5002c6c8da5a27e.setContent(html_28e3808b451d7bc56a658e044d18583c);
#
#
#
#         marker_9b6e7725f3c1fcefbaa4087f913ec872.bindPopup(popup_66caac7420a3e0b7c5002c6c8da5a27e)
#         ;
#
#
#
#
#             var marker_f6a4cfd4cf6ebf407f40b5d7075b99da = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_8a5a87476ba13425bd0780291a87a7ee);
#
#
#         var popup_f6e5260700acf5548ee33f3916f8a320 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ed158222747ea983104e1848a0db4585 = $(`&lt;div id=&quot;html_ed158222747ea983104e1848a0db4585&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_f6e5260700acf5548ee33f3916f8a320.setContent(html_ed158222747ea983104e1848a0db4585);
#
#
#
#         marker_f6a4cfd4cf6ebf407f40b5d7075b99da.bindPopup(popup_f6e5260700acf5548ee33f3916f8a320)
#         ;
#
#
#
#
#             var marker_a5dea4247d8b5cbbca4b6127c5018c04 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_8a5a87476ba13425bd0780291a87a7ee);
#
#
#         var popup_b526ee98c569bb3f2d826f6fbfc38514 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_256214f2bf9ccc1ab3ae7e55ebe004e6 = $(`&lt;div id=&quot;html_256214f2bf9ccc1ab3ae7e55ebe004e6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_b526ee98c569bb3f2d826f6fbfc38514.setContent(html_256214f2bf9ccc1ab3ae7e55ebe004e6);
#
#
#
#         marker_
