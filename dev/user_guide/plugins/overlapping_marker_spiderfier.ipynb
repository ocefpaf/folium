# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b6e8e9ac8d2b85aae6acef710d960d1a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b6e8e9ac8d2b85aae6acef710d960d1a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b6e8e9ac8d2b85aae6acef710d960d1a = L.map(
#                 &quot;map_b6e8e9ac8d2b85aae6acef710d960d1a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_05c73f1105a9941b574f32636a059ad6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_05c73f1105a9941b574f32636a059ad6.addTo(map_b6e8e9ac8d2b85aae6acef710d960d1a);
#
#
#             var marker_401c9cbf290ca4e40746e0b4354dc32d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_b6e8e9ac8d2b85aae6acef710d960d1a);
#
#
#         var popup_86c90cd98ff1452fe8a1ad6f9888bf8e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6d2c7bc09fd835a944596ebb5bade62c = $(`&lt;div id=&quot;html_6d2c7bc09fd835a944596ebb5bade62c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_86c90cd98ff1452fe8a1ad6f9888bf8e.setContent(html_6d2c7bc09fd835a944596ebb5bade62c);
#
#
#
#         marker_401c9cbf290ca4e40746e0b4354dc32d.bindPopup(popup_86c90cd98ff1452fe8a1ad6f9888bf8e)
#         ;
#
#
#
#
#             var marker_3670d12f9f34c5839ce37d2c2c466d3a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_b6e8e9ac8d2b85aae6acef710d960d1a);
#
#
#         var popup_6cc61b16fe1e9e7ca4064a06d210ec22 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6cbc07c6cbf0aada1c19b8c5546b73c8 = $(`&lt;div id=&quot;html_6cbc07c6cbf0aada1c19b8c5546b73c8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_6cc61b16fe1e9e7ca4064a06d210ec22.setContent(html_6cbc07c6cbf0aada1c19b8c5546b73c8);
#
#
#
#         marker_3670d12f9f34c5839ce37d2c2c466d3a.bindPopup(popup_6cc61b16fe1e9e7ca4064a06d210ec22)
#         ;
#
#
#
#
#             var marker_b2eb9415d893e6c217db24b22f126c6a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_b6e8e9ac8d2b85aae6acef710d960d1a);
#
#
#         var popup_264cc5b6a41a09e88a76a218e2967607 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b08f135e2fb95aee583762e77e1015a8 = $(`&lt;div id=&quot;html_b08f135e2fb95aee583762e77e1015a8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_264cc5b6a41a09e88a76a218e2967607.setContent(html_b08f135e2fb95aee583762e77e1015a8);
#
#
#
#         marker_b2eb9415d893e6c217db24b22f126c6a.bindPopup(popup_264cc5b6a41a09e88a76a218e2967607)
#         ;
#
#
#
#
#             var marker_2f5295e7af66f4190b2037b68bacdb8e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_b6e8e9ac8d2b85aae6acef710d960d1a);
#
#
#         var popup_82ba0196162a63391431030a5522ac01 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_94417d05220e1a2f2d34323d48b6ca28 = $(`&lt;div id=&quot;html_94417d05220e1a2f2d34323d48b6ca28&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_82ba0196162a63391431030a5522ac01.setContent(html_94417d05220e1a2f2d34323d48b6ca28);
#
#
#
#         marker_2f5295e7af66f4190b2037b68bacdb8e.bindPopup(popup_82ba0196162a63391431030a5522ac01)
#         ;
#
#
#
#
#             var marker_de92a5bb717d449c8f7e239b618c468f = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_b6e8e9ac8d2b85aae6acef710d960d1a);
#
#
#         var popup_13e59244e977c45fd51abba5e4ca9832 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_81e64902c90ad88c80236ded5fa6a814 = $(`&lt;div id=&quot;html_81e64902c90ad88c80236ded5fa6a814&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_13e59244e977c45fd51abba5e4ca9832.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a829901db660d29e88684631434f6ee4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a829901db660d29e88684631434f6ee4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a829901db660d29e88684631434f6ee4 = L.map(
#                 &quot;map_a829901db660d29e88684631434f6ee4&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_865931e8814f7bd79a7032a0847fb963 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_865931e8814f7bd79a7032a0847fb963.addTo(map_a829901db660d29e88684631434f6ee4);
#
#
#             var feature_group_730ee2c8f3cbb485d461fb18af61f6c6 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_e228b206e5b808792d73d56e91af7d85 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_730ee2c8f3cbb485d461fb18af61f6c6);
#
#
#         var popup_5993e58cf446935376b2cae863755e9f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_910fd1a3618821f5470396551d474681 = $(`&lt;div id=&quot;html_910fd1a3618821f5470396551d474681&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_5993e58cf446935376b2cae863755e9f.setContent(html_910fd1a3618821f5470396551d474681);
#
#
#
#         marker_e228b206e5b808792d73d56e91af7d85.bindPopup(popup_5993e58cf446935376b2cae863755e9f)
#         ;
#
#
#
#
#             var marker_1099612e029aac5c528bfd06b575ba7a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_730ee2c8f3cbb485d461fb18af61f6c6);
#
#
#         var popup_9b12a3105ab3b651659bc98edc5a02ac = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_199087653957ca52d6a02fcc6e1459d6 = $(`&lt;div id=&quot;html_199087653957ca52d6a02fcc6e1459d6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_9b12a3105ab3b651659bc98edc5a02ac.setContent(html_199087653957ca52d6a02fcc6e1459d6);
#
#
#
#         marker_1099612e029aac5c528bfd06b575ba7a.bindPopup(popup_9b12a3105ab3b651659bc98edc5a02ac)
#         ;
#
#
#
#
#             var marker_03306d281064d65758d8140defb923a7 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_730ee2c8f3cbb485d461fb18af61f6c6);
#
#
#         var popup_e8560dbb09e01b7142e092f7a7eb6a4e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_921f4ae6bd10024fe4a9a996bba730f8 = $(`&lt;div id=&quot;html_921f4ae6bd10024fe4a9a996bba730f8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_e8560dbb09e01b7142e092f7a7eb6a4e.setContent(html_921f4ae6bd10024fe4a9a996bba730f8);
#
#
#
#         marker_03306d281064d65758d8140defb923a7.bindPopup(popup_e8560dbb09e01b7142e092f7a7eb6a4e)
#         ;
#
#
#
#
#             var marker_96abed6d555317aa1ec61fa0d89c9125 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_730ee2c8f3cbb485d461fb18af61f6c6);
#
#
#         var popup_560ff7d9ebaa7e49723e35ccde1da585 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d1e7631f91de27a5b21af5790132ff18 = $(`&lt;div id=&quot;html_d1e7631f91de27a5b21af5790132ff18&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_560ff7d9ebaa7e49723e35ccde1da585.setContent(html_d1e7631f91de27a5b21af5790132ff18);
#
#
#
#         marker_96abed6d555317aa1ec61fa0d89c9125.bindPopup(popup_560ff7d9ebaa7e49723e35ccde1da585)
#         ;
#
#
#
#
#             var marker_bf7bfafb90d50403d4dcca729b12563a = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_730ee2c8f3cbb485d461fb18af61f6c6);
#
#
#         var popup_45119fff8ad896de002b58ba74c65342 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b65512b170693c8de53c5c22e92087e2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b65512b170693c8de53c5c22e92087e2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b65512b170693c8de53c5c22e92087e2 = L.map(
#                 &quot;map_b65512b170693c8de53c5c22e92087e2&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3066fe7edb60b3b7806680f5911d4384 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3066fe7edb60b3b7806680f5911d4384.addTo(map_b65512b170693c8de53c5c22e92087e2);
#
#
#             var feature_group_5b8150e558cbb6f4b7a2deab27c314c0 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_5b8150e558cbb6f4b7a2deab27c314c0.addTo(map_b65512b170693c8de53c5c22e92087e2);
#
#
#             var feature_group_sub_group_c66d53be852742d16e1b22ea1543d7e7 = L.featureGroup.subGroup(
#                 feature_group_5b8150e558cbb6f4b7a2deab27c314c0
#             );
#
#
#             var marker_79988b10b489d2cd20f2e4a5c6de7dd3 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_c66d53be852742d16e1b22ea1543d7e7);
#
#
#         var popup_2a7b67801b96858f51166caf409094e6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9872c244243fda6306b3582a70c3f3b2 = $(`&lt;div id=&quot;html_9872c244243fda6306b3582a70c3f3b2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_2a7b67801b96858f51166caf409094e6.setContent(html_9872c244243fda6306b3582a70c3f3b2);
#
#
#
#         marker_79988b10b489d2cd20f2e4a5c6de7dd3.bindPopup(popup_2a7b67801b96858f51166caf409094e6)
#         ;
#
#
#
#
#             var marker_cf4b5ef687887130e1822d1f978de290 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_c66d53be852742d16e1b22ea1543d7e7);
#
#
#         var popup_d9d94d43d12a6135daef143080891837 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_410a29906fef693b220b25c7f65371d1 = $(`&lt;div id=&quot;html_410a29906fef693b220b25c7f65371d1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_d9d94d43d12a6135daef143080891837.setContent(html_410a29906fef693b220b25c7f65371d1);
#
#
#
#         marker_cf4b5ef687887130e1822d1f978de290.bindPopup(popup_d9d94d43d12a6135daef143080891837)
#         ;
#
#
#
#
#             var marker_67549cd76802ae7ade7b6b96f7b3ffc9 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_c66d53be852742d16e1b22ea1543d7e7);
#
#
#         var popup_e069fa7fc307bb10094c4414391ebc11 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_826065664f6214b5cfbe9f57c1ad054f = $(`&lt;div id=&quot;html_826065664f6214b5cfbe9f57c1ad054f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_e069fa7fc307bb10094c4414391ebc11.setContent(html_826065664f6214b5cfbe9f57c1ad054f);
#
#
#
#         marker_67549cd76802ae7ade7b6b96f7b3ffc9.bindPopup(popup_e069fa7fc307bb10094c4414391ebc11)
#         ;
#
#
#
#
#             var marker_83aace53c26dcd4b2fa8b5da5061605c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_c66d53be852742d16e1b22ea1543d7e7);
#
#
#         var popup_01300d70e8912bab9866bfa5699b102a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_df0f98d645ad96a83793d34aa04e9309 = $(`&lt;div id=&quot;html_df0f98d645ad96a83793d34aa04e9309&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_01300d70e8912bab9866bfa5699b102a.setContent(html_df0f98d645ad96a83793d34aa04e9309);
#
#
#
#         marker_
