# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_da9bc0220bdb4227dc98fd22217cb9a7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_da9bc0220bdb4227dc98fd22217cb9a7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_da9bc0220bdb4227dc98fd22217cb9a7 = L.map(
#                 &quot;map_da9bc0220bdb4227dc98fd22217cb9a7&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f3dcbf9bdda4b7e48ef33c35e9c32f3e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f3dcbf9bdda4b7e48ef33c35e9c32f3e.addTo(map_da9bc0220bdb4227dc98fd22217cb9a7);
#
#
#             var marker_6d44d418ce43fd802cb264aca5f23eed = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_da9bc0220bdb4227dc98fd22217cb9a7);
#
#
#         var popup_9475126befc82a0b3a040f01685153e8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e9c8f8a7412444729627684a44b3e81a = $(`&lt;div id=&quot;html_e9c8f8a7412444729627684a44b3e81a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_9475126befc82a0b3a040f01685153e8.setContent(html_e9c8f8a7412444729627684a44b3e81a);
#
#
#
#         marker_6d44d418ce43fd802cb264aca5f23eed.bindPopup(popup_9475126befc82a0b3a040f01685153e8)
#         ;
#
#
#
#
#             var marker_c0e97a1079e6669f495fb95f317f58b7 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_da9bc0220bdb4227dc98fd22217cb9a7);
#
#
#         var popup_29051cb9927428c14ea2851abde01ef0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4930659e22886196d37a361b72dd4e8d = $(`&lt;div id=&quot;html_4930659e22886196d37a361b72dd4e8d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_29051cb9927428c14ea2851abde01ef0.setContent(html_4930659e22886196d37a361b72dd4e8d);
#
#
#
#         marker_c0e97a1079e6669f495fb95f317f58b7.bindPopup(popup_29051cb9927428c14ea2851abde01ef0)
#         ;
#
#
#
#
#             var marker_33a91be6e2d9de6e311d17f3029e2ef3 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_da9bc0220bdb4227dc98fd22217cb9a7);
#
#
#         var popup_b1b1419a36550fb0d542ea4f8406219a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9cabfbeefe464c044dab436be38a3651 = $(`&lt;div id=&quot;html_9cabfbeefe464c044dab436be38a3651&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_b1b1419a36550fb0d542ea4f8406219a.setContent(html_9cabfbeefe464c044dab436be38a3651);
#
#
#
#         marker_33a91be6e2d9de6e311d17f3029e2ef3.bindPopup(popup_b1b1419a36550fb0d542ea4f8406219a)
#         ;
#
#
#
#
#             var marker_ec7534e8f072f6f04f47bf57c92b5d57 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_da9bc0220bdb4227dc98fd22217cb9a7);
#
#
#         var popup_fe6edde7ab1606b85ccb2cb9d4a1798c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_784feb02162c9b62b01ebfa8c376f6f8 = $(`&lt;div id=&quot;html_784feb02162c9b62b01ebfa8c376f6f8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_fe6edde7ab1606b85ccb2cb9d4a1798c.setContent(html_784feb02162c9b62b01ebfa8c376f6f8);
#
#
#
#         marker_ec7534e8f072f6f04f47bf57c92b5d57.bindPopup(popup_fe6edde7ab1606b85ccb2cb9d4a1798c)
#         ;
#
#
#
#
#             var marker_3f1b83fc61422785727311f220bc6f35 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_da9bc0220bdb4227dc98fd22217cb9a7);
#
#
#         var popup_b6422c40d0af98b8d04a4125201f28c0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_220e4f0edcaa3a769971b03c60d56aa2 = $(`&lt;div id=&quot;html_220e4f0edcaa3a769971b03c60d56aa2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_b6422c40d0af98b8d04a4125201f28c0.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5345ccb77289f79e4345c242422f0bc5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5345ccb77289f79e4345c242422f0bc5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5345ccb77289f79e4345c242422f0bc5 = L.map(
#                 &quot;map_5345ccb77289f79e4345c242422f0bc5&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f8fef1ba5810cdd4699e5a3afb02cf07 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f8fef1ba5810cdd4699e5a3afb02cf07.addTo(map_5345ccb77289f79e4345c242422f0bc5);
#
#
#             var feature_group_6dff4465e521876205a10d15a9e8acef = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_629b7c425a2ce1dcff2dbc664b776145 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_6dff4465e521876205a10d15a9e8acef);
#
#
#         var popup_632e96c21902e098f10d57bff851207c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b11c5d49db6b32ca7fc519a2751ae96d = $(`&lt;div id=&quot;html_b11c5d49db6b32ca7fc519a2751ae96d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_632e96c21902e098f10d57bff851207c.setContent(html_b11c5d49db6b32ca7fc519a2751ae96d);
#
#
#
#         marker_629b7c425a2ce1dcff2dbc664b776145.bindPopup(popup_632e96c21902e098f10d57bff851207c)
#         ;
#
#
#
#
#             var marker_49059df5eedc4c6470752ad75dddbdf1 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_6dff4465e521876205a10d15a9e8acef);
#
#
#         var popup_02df720d46b271e5bcb1dacbb1ecced1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_50d69436eec58f9f60c8cdc3465d9c8a = $(`&lt;div id=&quot;html_50d69436eec58f9f60c8cdc3465d9c8a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_02df720d46b271e5bcb1dacbb1ecced1.setContent(html_50d69436eec58f9f60c8cdc3465d9c8a);
#
#
#
#         marker_49059df5eedc4c6470752ad75dddbdf1.bindPopup(popup_02df720d46b271e5bcb1dacbb1ecced1)
#         ;
#
#
#
#
#             var marker_816eface8cff671812996d120d69d77e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_6dff4465e521876205a10d15a9e8acef);
#
#
#         var popup_becc873d8ae9a106e1a1bcf69295910e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0b955b8e6a6236edd3b81535221919d4 = $(`&lt;div id=&quot;html_0b955b8e6a6236edd3b81535221919d4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_becc873d8ae9a106e1a1bcf69295910e.setContent(html_0b955b8e6a6236edd3b81535221919d4);
#
#
#
#         marker_816eface8cff671812996d120d69d77e.bindPopup(popup_becc873d8ae9a106e1a1bcf69295910e)
#         ;
#
#
#
#
#             var marker_99c4b4a7a6c5769f714fa1eac0338df6 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_6dff4465e521876205a10d15a9e8acef);
#
#
#         var popup_5964141d423c8dad5719f2fe8ae0a2ef = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_537c1f200ea52e90a3b6b2267bf9ebd3 = $(`&lt;div id=&quot;html_537c1f200ea52e90a3b6b2267bf9ebd3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_5964141d423c8dad5719f2fe8ae0a2ef.setContent(html_537c1f200ea52e90a3b6b2267bf9ebd3);
#
#
#
#         marker_99c4b4a7a6c5769f714fa1eac0338df6.bindPopup(popup_5964141d423c8dad5719f2fe8ae0a2ef)
#         ;
#
#
#
#
#             var marker_dcfb3677447395acd26c745c613b43ac = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_6dff4465e521876205a10d15a9e8acef);
#
#
#         var popup_74bd5bf10f2cb03e35641c07b957609a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9ffa373aa822e83a408406837bf6963a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9ffa373aa822e83a408406837bf6963a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9ffa373aa822e83a408406837bf6963a = L.map(
#                 &quot;map_9ffa373aa822e83a408406837bf6963a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_90a09e6c4704c83ba272ff454206ab2e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_90a09e6c4704c83ba272ff454206ab2e.addTo(map_9ffa373aa822e83a408406837bf6963a);
#
#
#             var feature_group_9eff8a42cf8356a721469bc2e7178073 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_9eff8a42cf8356a721469bc2e7178073.addTo(map_9ffa373aa822e83a408406837bf6963a);
#
#
#             var feature_group_sub_group_64c057257d198cc0a4145762750f0e9e = L.featureGroup.subGroup(
#                 feature_group_9eff8a42cf8356a721469bc2e7178073
#             );
#
#
#             var marker_d6c4432fe8bd399aa0af0b4a1e5ba4d8 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_64c057257d198cc0a4145762750f0e9e);
#
#
#         var popup_e34fe42495b29cb056f6b57f18daed67 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0d9857844ab545a5a16546019586c271 = $(`&lt;div id=&quot;html_0d9857844ab545a5a16546019586c271&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_e34fe42495b29cb056f6b57f18daed67.setContent(html_0d9857844ab545a5a16546019586c271);
#
#
#
#         marker_d6c4432fe8bd399aa0af0b4a1e5ba4d8.bindPopup(popup_e34fe42495b29cb056f6b57f18daed67)
#         ;
#
#
#
#
#             var marker_c553baf55057e4bafd2ecbeafe2f18b0 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_64c057257d198cc0a4145762750f0e9e);
#
#
#         var popup_5344005e5094366f148269b09e5c968f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e490070e60ca9d2ac9388bec986564d3 = $(`&lt;div id=&quot;html_e490070e60ca9d2ac9388bec986564d3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_5344005e5094366f148269b09e5c968f.setContent(html_e490070e60ca9d2ac9388bec986564d3);
#
#
#
#         marker_c553baf55057e4bafd2ecbeafe2f18b0.bindPopup(popup_5344005e5094366f148269b09e5c968f)
#         ;
#
#
#
#
#             var marker_4685e9bc4c308061e32b8b92446213d0 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_64c057257d198cc0a4145762750f0e9e);
#
#
#         var popup_11d52beb7a30fbc47a98ad07244d2ff5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b9ba318c834d7c32d8ef5098ea5d4949 = $(`&lt;div id=&quot;html_b9ba318c834d7c32d8ef5098ea5d4949&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_11d52beb7a30fbc47a98ad07244d2ff5.setContent(html_b9ba318c834d7c32d8ef5098ea5d4949);
#
#
#
#         marker_4685e9bc4c308061e32b8b92446213d0.bindPopup(popup_11d52beb7a30fbc47a98ad07244d2ff5)
#         ;
#
#
#
#
#             var marker_10179eeef42913aaea824f43e5dcc529 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_64c057257d198cc0a4145762750f0e9e);
#
#
#         var popup_4587523f41a4672ef3f52793b3f36c31 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e032ceca44102fee025e9e1086b0ed1f = $(`&lt;div id=&quot;html_e032ceca44102fee025e9e1086b0ed1f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_4587523f41a4672ef3f52793b3f36c31.setContent(html_e032ceca44102fee025e9e1086b0ed1f);
#
#
#
#         marker_
