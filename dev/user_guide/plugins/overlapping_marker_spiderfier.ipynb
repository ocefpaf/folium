# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ea95748b37a84857424b1aa45319f006 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ea95748b37a84857424b1aa45319f006&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ea95748b37a84857424b1aa45319f006 = L.map(
#                 &quot;map_ea95748b37a84857424b1aa45319f006&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_87a918f3b1c90a07ccecdc49e792e1f8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_87a918f3b1c90a07ccecdc49e792e1f8.addTo(map_ea95748b37a84857424b1aa45319f006);
#
#
#             var marker_d583a1a24b526c17f594f2ba7be65435 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_ea95748b37a84857424b1aa45319f006);
#
#
#         var popup_f6f8ab7b3817a6e15f20edce75cd78fc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6dc830b31cd8f322664891308d59c08b = $(`&lt;div id=&quot;html_6dc830b31cd8f322664891308d59c08b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_f6f8ab7b3817a6e15f20edce75cd78fc.setContent(html_6dc830b31cd8f322664891308d59c08b);
#
#
#
#         marker_d583a1a24b526c17f594f2ba7be65435.bindPopup(popup_f6f8ab7b3817a6e15f20edce75cd78fc)
#         ;
#
#
#
#
#             var marker_ea0502bac0bfd57f75b37ec06ed55053 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_ea95748b37a84857424b1aa45319f006);
#
#
#         var popup_cd367e3e080668184d16cb7862ff4605 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_957c253f9075dc47286b56467a0a82e8 = $(`&lt;div id=&quot;html_957c253f9075dc47286b56467a0a82e8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_cd367e3e080668184d16cb7862ff4605.setContent(html_957c253f9075dc47286b56467a0a82e8);
#
#
#
#         marker_ea0502bac0bfd57f75b37ec06ed55053.bindPopup(popup_cd367e3e080668184d16cb7862ff4605)
#         ;
#
#
#
#
#             var marker_074c7c1d08606fc26482b6ef1d729e70 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_ea95748b37a84857424b1aa45319f006);
#
#
#         var popup_cc9cad2c5c74bffb1d304876eea97b8d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_15721a4635cbc81ff38a2ca660ec65f2 = $(`&lt;div id=&quot;html_15721a4635cbc81ff38a2ca660ec65f2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_cc9cad2c5c74bffb1d304876eea97b8d.setContent(html_15721a4635cbc81ff38a2ca660ec65f2);
#
#
#
#         marker_074c7c1d08606fc26482b6ef1d729e70.bindPopup(popup_cc9cad2c5c74bffb1d304876eea97b8d)
#         ;
#
#
#
#
#             var marker_4fa1befd8fb99a25918c29f92af49c5b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_ea95748b37a84857424b1aa45319f006);
#
#
#         var popup_071be2a26b7343370909e56418134210 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_69388d26b627dd5a96a82985b7fb591a = $(`&lt;div id=&quot;html_69388d26b627dd5a96a82985b7fb591a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_071be2a26b7343370909e56418134210.setContent(html_69388d26b627dd5a96a82985b7fb591a);
#
#
#
#         marker_4fa1befd8fb99a25918c29f92af49c5b.bindPopup(popup_071be2a26b7343370909e56418134210)
#         ;
#
#
#
#
#             var marker_f081347568cef3e8e3feba727eeabec4 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_ea95748b37a84857424b1aa45319f006);
#
#
#         var popup_6a0c71aafd47ba994d19a9fd7ac7f617 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_48cd07b05d0e59686d28a7b5d7e44927 = $(`&lt;div id=&quot;html_48cd07b05d0e59686d28a7b5d7e44927&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_6a0c71aafd47ba994d19a9fd7ac7f617.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_331f90301ecb4427138dc0e119a90077 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_331f90301ecb4427138dc0e119a90077&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_331f90301ecb4427138dc0e119a90077 = L.map(
#                 &quot;map_331f90301ecb4427138dc0e119a90077&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e56410b7c76c47715d29f9ecee646ff9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e56410b7c76c47715d29f9ecee646ff9.addTo(map_331f90301ecb4427138dc0e119a90077);
#
#
#             var feature_group_efee95055a36b33a32c42a8e1bbe4f13 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_ff57e3395d9e14e6a5e182bf10636bfc = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_efee95055a36b33a32c42a8e1bbe4f13);
#
#
#         var popup_bf09a2b3abb44a8a5d634dfea95780c1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_df3127370bc322c2a65262d9b5dd2ed9 = $(`&lt;div id=&quot;html_df3127370bc322c2a65262d9b5dd2ed9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_bf09a2b3abb44a8a5d634dfea95780c1.setContent(html_df3127370bc322c2a65262d9b5dd2ed9);
#
#
#
#         marker_ff57e3395d9e14e6a5e182bf10636bfc.bindPopup(popup_bf09a2b3abb44a8a5d634dfea95780c1)
#         ;
#
#
#
#
#             var marker_31fbac688440525ee5d519a926051b72 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_efee95055a36b33a32c42a8e1bbe4f13);
#
#
#         var popup_4c7a76da67923746b004b0e3bcb3da54 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9c5a7dd70ac0e5f4f8964c27ec39493d = $(`&lt;div id=&quot;html_9c5a7dd70ac0e5f4f8964c27ec39493d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_4c7a76da67923746b004b0e3bcb3da54.setContent(html_9c5a7dd70ac0e5f4f8964c27ec39493d);
#
#
#
#         marker_31fbac688440525ee5d519a926051b72.bindPopup(popup_4c7a76da67923746b004b0e3bcb3da54)
#         ;
#
#
#
#
#             var marker_32ccd67b7fc7f18b4240dd6631838b28 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_efee95055a36b33a32c42a8e1bbe4f13);
#
#
#         var popup_ca7c97b9cb3d66b5eabaf5d72070abb1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cdfc65336fd275c3e9b93c71f43f0c7d = $(`&lt;div id=&quot;html_cdfc65336fd275c3e9b93c71f43f0c7d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_ca7c97b9cb3d66b5eabaf5d72070abb1.setContent(html_cdfc65336fd275c3e9b93c71f43f0c7d);
#
#
#
#         marker_32ccd67b7fc7f18b4240dd6631838b28.bindPopup(popup_ca7c97b9cb3d66b5eabaf5d72070abb1)
#         ;
#
#
#
#
#             var marker_9f17ecf4c51935a34a51cfc8b951c9b2 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_efee95055a36b33a32c42a8e1bbe4f13);
#
#
#         var popup_3ce5f1acf303341b68d91a5eabe74a8f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_56fadcbb0afd791d43352d5169c668fa = $(`&lt;div id=&quot;html_56fadcbb0afd791d43352d5169c668fa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_3ce5f1acf303341b68d91a5eabe74a8f.setContent(html_56fadcbb0afd791d43352d5169c668fa);
#
#
#
#         marker_9f17ecf4c51935a34a51cfc8b951c9b2.bindPopup(popup_3ce5f1acf303341b68d91a5eabe74a8f)
#         ;
#
#
#
#
#             var marker_215465740c197a5fa120c57b3239c7ca = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_efee95055a36b33a32c42a8e1bbe4f13);
#
#
#         var popup_563cc23959b2bf865e1dadf0b8a802c4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4e1b810ea9c6a0f985dac027d5871210 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4e1b810ea9c6a0f985dac027d5871210&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4e1b810ea9c6a0f985dac027d5871210 = L.map(
#                 &quot;map_4e1b810ea9c6a0f985dac027d5871210&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4ccc57c5b3fa0f0f8c09447603d1631e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4ccc57c5b3fa0f0f8c09447603d1631e.addTo(map_4e1b810ea9c6a0f985dac027d5871210);
#
#
#             var feature_group_8537b563c28d41661c3b9f257dd46183 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_8537b563c28d41661c3b9f257dd46183.addTo(map_4e1b810ea9c6a0f985dac027d5871210);
#
#
#             var feature_group_sub_group_6bd6c31eeecf9644c643c9d9d0d541ee = L.featureGroup.subGroup(
#                 feature_group_8537b563c28d41661c3b9f257dd46183
#             );
#
#
#             var marker_077d62101b9b9d1245bc981464471318 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_6bd6c31eeecf9644c643c9d9d0d541ee);
#
#
#         var popup_ef09fea28c3a9d355dab97e7e5d3c271 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e872666ee357af16acea4ee35bb12bf5 = $(`&lt;div id=&quot;html_e872666ee357af16acea4ee35bb12bf5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_ef09fea28c3a9d355dab97e7e5d3c271.setContent(html_e872666ee357af16acea4ee35bb12bf5);
#
#
#
#         marker_077d62101b9b9d1245bc981464471318.bindPopup(popup_ef09fea28c3a9d355dab97e7e5d3c271)
#         ;
#
#
#
#
#             var marker_9c1aba4466e4eb4e313c1c384400b11c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_6bd6c31eeecf9644c643c9d9d0d541ee);
#
#
#         var popup_c66de05c837345592dab862b4e6d0f9b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fc332ef01a8c35a51c824b1019d09cec = $(`&lt;div id=&quot;html_fc332ef01a8c35a51c824b1019d09cec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_c66de05c837345592dab862b4e6d0f9b.setContent(html_fc332ef01a8c35a51c824b1019d09cec);
#
#
#
#         marker_9c1aba4466e4eb4e313c1c384400b11c.bindPopup(popup_c66de05c837345592dab862b4e6d0f9b)
#         ;
#
#
#
#
#             var marker_2969ed1e17ebc03ae21e5d772a1d95e1 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_6bd6c31eeecf9644c643c9d9d0d541ee);
#
#
#         var popup_94d466ae2b23ef02d33ff1474cf03b62 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_09f36f229ec9a140d5113034e603b25f = $(`&lt;div id=&quot;html_09f36f229ec9a140d5113034e603b25f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_94d466ae2b23ef02d33ff1474cf03b62.setContent(html_09f36f229ec9a140d5113034e603b25f);
#
#
#
#         marker_2969ed1e17ebc03ae21e5d772a1d95e1.bindPopup(popup_94d466ae2b23ef02d33ff1474cf03b62)
#         ;
#
#
#
#
#             var marker_e5650bd5b0502be605de0814a068d93c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_6bd6c31eeecf9644c643c9d9d0d541ee);
#
#
#         var popup_894eb100dde56d73cea8704c6b22f7b6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cff49c6eec3e5c707a3a0d11a27da385 = $(`&lt;div id=&quot;html_cff49c6eec3e5c707a3a0d11a27da385&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_894eb100dde56d73cea8704c6b22f7b6.setContent(html_cff49c6eec3e5c707a3a0d11a27da385);
#
#
#
#         marker_
