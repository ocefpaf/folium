# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8e3a403ccb558b1b02fc454c4164a557 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8e3a403ccb558b1b02fc454c4164a557&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8e3a403ccb558b1b02fc454c4164a557 = L.map(
#                 &quot;map_8e3a403ccb558b1b02fc454c4164a557&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_19d5ad776f839b7590230e62935fd891 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_19d5ad776f839b7590230e62935fd891.addTo(map_8e3a403ccb558b1b02fc454c4164a557);
#
#
#             var marker_94712fcd75dbe5ff81a457f0025fbba3 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_8e3a403ccb558b1b02fc454c4164a557);
#
#
#         var popup_47eb7666d02f8164f1e06e35144d34a8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a25c8adbeb6eb9a7809eab77dc0593f1 = $(`&lt;div id=&quot;html_a25c8adbeb6eb9a7809eab77dc0593f1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_47eb7666d02f8164f1e06e35144d34a8.setContent(html_a25c8adbeb6eb9a7809eab77dc0593f1);
#
#
#
#         marker_94712fcd75dbe5ff81a457f0025fbba3.bindPopup(popup_47eb7666d02f8164f1e06e35144d34a8)
#         ;
#
#
#
#
#             var marker_ad3327e5f00e2f4e4281f5a28695aa46 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_8e3a403ccb558b1b02fc454c4164a557);
#
#
#         var popup_95d91bc605518b47016aaab0eea1cd4b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_18f97a131945e3cc023bbd503ad41e0f = $(`&lt;div id=&quot;html_18f97a131945e3cc023bbd503ad41e0f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_95d91bc605518b47016aaab0eea1cd4b.setContent(html_18f97a131945e3cc023bbd503ad41e0f);
#
#
#
#         marker_ad3327e5f00e2f4e4281f5a28695aa46.bindPopup(popup_95d91bc605518b47016aaab0eea1cd4b)
#         ;
#
#
#
#
#             var marker_19d2680724a33aa2bf60165e1250f041 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_8e3a403ccb558b1b02fc454c4164a557);
#
#
#         var popup_fba5501441afe29ddb93ce2cbe1d2511 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9229aa12cc50b8c0471828048735bd82 = $(`&lt;div id=&quot;html_9229aa12cc50b8c0471828048735bd82&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_fba5501441afe29ddb93ce2cbe1d2511.setContent(html_9229aa12cc50b8c0471828048735bd82);
#
#
#
#         marker_19d2680724a33aa2bf60165e1250f041.bindPopup(popup_fba5501441afe29ddb93ce2cbe1d2511)
#         ;
#
#
#
#
#             var marker_c1c4c701f228a2272d66dacd840cbe88 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_8e3a403ccb558b1b02fc454c4164a557);
#
#
#         var popup_20686f8ca77f65c0b13286473dc8c1f4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6cf860962fd85230dfb7404a21d20629 = $(`&lt;div id=&quot;html_6cf860962fd85230dfb7404a21d20629&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_20686f8ca77f65c0b13286473dc8c1f4.setContent(html_6cf860962fd85230dfb7404a21d20629);
#
#
#
#         marker_c1c4c701f228a2272d66dacd840cbe88.bindPopup(popup_20686f8ca77f65c0b13286473dc8c1f4)
#         ;
#
#
#
#
#             var marker_cb72308ba7462d41d7fc0090cd69c6c5 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_8e3a403ccb558b1b02fc454c4164a557);
#
#
#         var popup_8c6388b5a648300d21f8b1a950f0322f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_041ca09cce1c331e619ed2fb63594c6b = $(`&lt;div id=&quot;html_041ca09cce1c331e619ed2fb63594c6b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_8c6388b5a648300d21f8b1a950f0322f.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_af8308b41bd409e8be9e786c379ba1f9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_af8308b41bd409e8be9e786c379ba1f9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_af8308b41bd409e8be9e786c379ba1f9 = L.map(
#                 &quot;map_af8308b41bd409e8be9e786c379ba1f9&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0f1efa73ee75776be1d3decc0dc90ad4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0f1efa73ee75776be1d3decc0dc90ad4.addTo(map_af8308b41bd409e8be9e786c379ba1f9);
#
#
#             var feature_group_3954b61247c5b3fb92b32c0cb22c8b6c = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_c2fac610babca454782b457d96acde0b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_3954b61247c5b3fb92b32c0cb22c8b6c);
#
#
#         var popup_d6f018fd6b092825c922e5753fb2416e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d79f7d270fad962e4c061140e2799070 = $(`&lt;div id=&quot;html_d79f7d270fad962e4c061140e2799070&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_d6f018fd6b092825c922e5753fb2416e.setContent(html_d79f7d270fad962e4c061140e2799070);
#
#
#
#         marker_c2fac610babca454782b457d96acde0b.bindPopup(popup_d6f018fd6b092825c922e5753fb2416e)
#         ;
#
#
#
#
#             var marker_a338ab877079175d133d714391534c50 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_3954b61247c5b3fb92b32c0cb22c8b6c);
#
#
#         var popup_198478decfe90bc28ac7b00ff011350e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_114513633a6618f64f7f7a5b7a0f1bd6 = $(`&lt;div id=&quot;html_114513633a6618f64f7f7a5b7a0f1bd6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_198478decfe90bc28ac7b00ff011350e.setContent(html_114513633a6618f64f7f7a5b7a0f1bd6);
#
#
#
#         marker_a338ab877079175d133d714391534c50.bindPopup(popup_198478decfe90bc28ac7b00ff011350e)
#         ;
#
#
#
#
#             var marker_e1ee75a1af7add4a1cf6feff0a3c8b97 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_3954b61247c5b3fb92b32c0cb22c8b6c);
#
#
#         var popup_166c96cb95d4472c16d0d3fc9e636e06 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_37305a11d01e7ca4eb6016aa01ab9140 = $(`&lt;div id=&quot;html_37305a11d01e7ca4eb6016aa01ab9140&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_166c96cb95d4472c16d0d3fc9e636e06.setContent(html_37305a11d01e7ca4eb6016aa01ab9140);
#
#
#
#         marker_e1ee75a1af7add4a1cf6feff0a3c8b97.bindPopup(popup_166c96cb95d4472c16d0d3fc9e636e06)
#         ;
#
#
#
#
#             var marker_9a5b3607c46dc21383ced3faf5356b26 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_3954b61247c5b3fb92b32c0cb22c8b6c);
#
#
#         var popup_efd4724b9e5d2ab22719d03346b9a201 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_480e95ed9a5164c7c4fddf34eccd941f = $(`&lt;div id=&quot;html_480e95ed9a5164c7c4fddf34eccd941f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_efd4724b9e5d2ab22719d03346b9a201.setContent(html_480e95ed9a5164c7c4fddf34eccd941f);
#
#
#
#         marker_9a5b3607c46dc21383ced3faf5356b26.bindPopup(popup_efd4724b9e5d2ab22719d03346b9a201)
#         ;
#
#
#
#
#             var marker_414844108e642e0d37b825573e4fe62d = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_3954b61247c5b3fb92b32c0cb22c8b6c);
#
#
#         var popup_13433af97d5ba4bd59f7a0a35140357e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e57758020257b425956a9acaf2a09d61 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e57758020257b425956a9acaf2a09d61&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e57758020257b425956a9acaf2a09d61 = L.map(
#                 &quot;map_e57758020257b425956a9acaf2a09d61&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_600d236ead39482cc7da45f72c04869d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_600d236ead39482cc7da45f72c04869d.addTo(map_e57758020257b425956a9acaf2a09d61);
#
#
#             var feature_group_0404beff4cbb41dd76a1d711d897343a = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_0404beff4cbb41dd76a1d711d897343a.addTo(map_e57758020257b425956a9acaf2a09d61);
#
#
#             var feature_group_sub_group_a1fe0d685d1650fc3a027247fbf4ac40 = L.featureGroup.subGroup(
#                 feature_group_0404beff4cbb41dd76a1d711d897343a
#             );
#
#
#             var marker_c790e028bcd13acdd1d0ba7c5f556235 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_a1fe0d685d1650fc3a027247fbf4ac40);
#
#
#         var popup_ba72f1784b385dc778f812df69b4e073 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1e21ab63e76c0dd565c21372e2a3427f = $(`&lt;div id=&quot;html_1e21ab63e76c0dd565c21372e2a3427f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_ba72f1784b385dc778f812df69b4e073.setContent(html_1e21ab63e76c0dd565c21372e2a3427f);
#
#
#
#         marker_c790e028bcd13acdd1d0ba7c5f556235.bindPopup(popup_ba72f1784b385dc778f812df69b4e073)
#         ;
#
#
#
#
#             var marker_daa3cdd2c02bc20cc104a9996cfbf765 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_a1fe0d685d1650fc3a027247fbf4ac40);
#
#
#         var popup_c9c0aa4e33f5f6d14df8dac87b94fcfe = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9b7939c81b52c855c0ada30eab4c290c = $(`&lt;div id=&quot;html_9b7939c81b52c855c0ada30eab4c290c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_c9c0aa4e33f5f6d14df8dac87b94fcfe.setContent(html_9b7939c81b52c855c0ada30eab4c290c);
#
#
#
#         marker_daa3cdd2c02bc20cc104a9996cfbf765.bindPopup(popup_c9c0aa4e33f5f6d14df8dac87b94fcfe)
#         ;
#
#
#
#
#             var marker_0b4713ec1c4f4f3c84a6052abeef4aba = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_a1fe0d685d1650fc3a027247fbf4ac40);
#
#
#         var popup_e7a8c180240d70c74099e40c2c83e959 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_248f3193382369ec049fa8859860179e = $(`&lt;div id=&quot;html_248f3193382369ec049fa8859860179e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_e7a8c180240d70c74099e40c2c83e959.setContent(html_248f3193382369ec049fa8859860179e);
#
#
#
#         marker_0b4713ec1c4f4f3c84a6052abeef4aba.bindPopup(popup_e7a8c180240d70c74099e40c2c83e959)
#         ;
#
#
#
#
#             var marker_bb4e31caa6bbe4dcc52a6813b9cd6310 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_a1fe0d685d1650fc3a027247fbf4ac40);
#
#
#         var popup_c54cefd95cfc3d69ee2f924356ba918b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8c4b70b8c45c649ef66d8dfe40dd2381 = $(`&lt;div id=&quot;html_8c4b70b8c45c649ef66d8dfe40dd2381&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_c54cefd95cfc3d69ee2f924356ba918b.setContent(html_8c4b70b8c45c649ef66d8dfe40dd2381);
#
#
#
#         marker_
