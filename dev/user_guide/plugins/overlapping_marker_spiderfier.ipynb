# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_24a73698a10377a2fa1de3f47e3eaac3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_24a73698a10377a2fa1de3f47e3eaac3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_24a73698a10377a2fa1de3f47e3eaac3 = L.map(
#                 &quot;map_24a73698a10377a2fa1de3f47e3eaac3&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_db90e7bdac74da5cb75e7f24bac7ff7b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_db90e7bdac74da5cb75e7f24bac7ff7b.addTo(map_24a73698a10377a2fa1de3f47e3eaac3);
#
#
#             var marker_e2ccdd464c2b2cd1aa40a4a70958befb = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_24a73698a10377a2fa1de3f47e3eaac3);
#
#
#         var popup_8b7837bcad67c8a0f71a0c007208be5e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a539329fe075d1e86694ab3736f2464b = $(`&lt;div id=&quot;html_a539329fe075d1e86694ab3736f2464b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_8b7837bcad67c8a0f71a0c007208be5e.setContent(html_a539329fe075d1e86694ab3736f2464b);
#
#
#
#         marker_e2ccdd464c2b2cd1aa40a4a70958befb.bindPopup(popup_8b7837bcad67c8a0f71a0c007208be5e)
#         ;
#
#
#
#
#             var marker_cbf2a7c6946365ca1455f547482cb8d8 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_24a73698a10377a2fa1de3f47e3eaac3);
#
#
#         var popup_c21b6acc885cd737220cbfe2a37a18ea = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1d41ca27962f55e56952cfa9347052ad = $(`&lt;div id=&quot;html_1d41ca27962f55e56952cfa9347052ad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_c21b6acc885cd737220cbfe2a37a18ea.setContent(html_1d41ca27962f55e56952cfa9347052ad);
#
#
#
#         marker_cbf2a7c6946365ca1455f547482cb8d8.bindPopup(popup_c21b6acc885cd737220cbfe2a37a18ea)
#         ;
#
#
#
#
#             var marker_02d4bcc735c48b73d56efc797b425555 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_24a73698a10377a2fa1de3f47e3eaac3);
#
#
#         var popup_11bde17d131c7ddadfe75f729e709bfc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8b032dec893a777a3cdb7c8222decc3e = $(`&lt;div id=&quot;html_8b032dec893a777a3cdb7c8222decc3e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_11bde17d131c7ddadfe75f729e709bfc.setContent(html_8b032dec893a777a3cdb7c8222decc3e);
#
#
#
#         marker_02d4bcc735c48b73d56efc797b425555.bindPopup(popup_11bde17d131c7ddadfe75f729e709bfc)
#         ;
#
#
#
#
#             var marker_b0bc201ff93b92b192d3c6b88e2621ec = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_24a73698a10377a2fa1de3f47e3eaac3);
#
#
#         var popup_22a07903bdfd03fe1d2c9ee741b8c67a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0ed53e9e13b4131667f9b11d54dcf9e2 = $(`&lt;div id=&quot;html_0ed53e9e13b4131667f9b11d54dcf9e2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_22a07903bdfd03fe1d2c9ee741b8c67a.setContent(html_0ed53e9e13b4131667f9b11d54dcf9e2);
#
#
#
#         marker_b0bc201ff93b92b192d3c6b88e2621ec.bindPopup(popup_22a07903bdfd03fe1d2c9ee741b8c67a)
#         ;
#
#
#
#
#             var marker_2a0d296eb7710a852f55577c8eebe2df = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_24a73698a10377a2fa1de3f47e3eaac3);
#
#
#         var popup_7ca65537947e1dbffcc0e9131e6c1c0e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_70afbd72b5555ee01453bc65d427a19a = $(`&lt;div id=&quot;html_70afbd72b5555ee01453bc65d427a19a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_7ca65537947e1dbffcc0e9131e6c1c0e.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cc2394749125e75da8621af004890659 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cc2394749125e75da8621af004890659&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cc2394749125e75da8621af004890659 = L.map(
#                 &quot;map_cc2394749125e75da8621af004890659&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_964973679f1af79d504a1d4c44570dd1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_964973679f1af79d504a1d4c44570dd1.addTo(map_cc2394749125e75da8621af004890659);
#
#
#             var feature_group_b1639677de1a727796ce337dd5aa3612 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_032a23344cdda68a5c1eb4216b1b467f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_b1639677de1a727796ce337dd5aa3612);
#
#
#         var popup_7fd2772ec4c98b79595a69e94b5a6fb9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_51001b2fa8e832e767487dfdd66698d2 = $(`&lt;div id=&quot;html_51001b2fa8e832e767487dfdd66698d2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_7fd2772ec4c98b79595a69e94b5a6fb9.setContent(html_51001b2fa8e832e767487dfdd66698d2);
#
#
#
#         marker_032a23344cdda68a5c1eb4216b1b467f.bindPopup(popup_7fd2772ec4c98b79595a69e94b5a6fb9)
#         ;
#
#
#
#
#             var marker_638c166af697063f4c33414efcc9423e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_b1639677de1a727796ce337dd5aa3612);
#
#
#         var popup_a561c54d923097053e8c7990c09b5af1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ed7d3396cfb482e0b3d91d996b7bbedb = $(`&lt;div id=&quot;html_ed7d3396cfb482e0b3d91d996b7bbedb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_a561c54d923097053e8c7990c09b5af1.setContent(html_ed7d3396cfb482e0b3d91d996b7bbedb);
#
#
#
#         marker_638c166af697063f4c33414efcc9423e.bindPopup(popup_a561c54d923097053e8c7990c09b5af1)
#         ;
#
#
#
#
#             var marker_e9c71d79866c4f4fc9edf80a67b2d43b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_b1639677de1a727796ce337dd5aa3612);
#
#
#         var popup_e65ca446a99227e8549bcf315f400142 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d08e6a76f57fb467dd33f7c2a792c9fe = $(`&lt;div id=&quot;html_d08e6a76f57fb467dd33f7c2a792c9fe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_e65ca446a99227e8549bcf315f400142.setContent(html_d08e6a76f57fb467dd33f7c2a792c9fe);
#
#
#
#         marker_e9c71d79866c4f4fc9edf80a67b2d43b.bindPopup(popup_e65ca446a99227e8549bcf315f400142)
#         ;
#
#
#
#
#             var marker_256804e03cef6ba620c74950283d9b3d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_b1639677de1a727796ce337dd5aa3612);
#
#
#         var popup_a20da868b622c58e8b3f6f717a3ed956 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_77b62be88bad4c3080cab590a8ea45e5 = $(`&lt;div id=&quot;html_77b62be88bad4c3080cab590a8ea45e5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_a20da868b622c58e8b3f6f717a3ed956.setContent(html_77b62be88bad4c3080cab590a8ea45e5);
#
#
#
#         marker_256804e03cef6ba620c74950283d9b3d.bindPopup(popup_a20da868b622c58e8b3f6f717a3ed956)
#         ;
#
#
#
#
#             var marker_73128e2cd4814c614614dab1ba0dcfe0 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_b1639677de1a727796ce337dd5aa3612);
#
#
#         var popup_8099d7007ae0f4f161313918877fa7d9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_515953d72278555a8bc2530d7edca8ab {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_515953d72278555a8bc2530d7edca8ab&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_515953d72278555a8bc2530d7edca8ab = L.map(
#                 &quot;map_515953d72278555a8bc2530d7edca8ab&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f7addf3f1957304775742457b3f23f70 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f7addf3f1957304775742457b3f23f70.addTo(map_515953d72278555a8bc2530d7edca8ab);
#
#
#             var feature_group_728b9b36c66920503774a0b7dbae4c64 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_728b9b36c66920503774a0b7dbae4c64.addTo(map_515953d72278555a8bc2530d7edca8ab);
#
#
#             var feature_group_sub_group_bffdcd99076af50a2beb8810c8ad585e = L.featureGroup.subGroup(
#                 feature_group_728b9b36c66920503774a0b7dbae4c64
#             );
#
#
#             var marker_423375a91bd410ba5134553ddc81b683 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_bffdcd99076af50a2beb8810c8ad585e);
#
#
#         var popup_22a68d45de7a09dbc25034c8180938f4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_82e93f13ed1389e2e83a0de2a8f4f5d1 = $(`&lt;div id=&quot;html_82e93f13ed1389e2e83a0de2a8f4f5d1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_22a68d45de7a09dbc25034c8180938f4.setContent(html_82e93f13ed1389e2e83a0de2a8f4f5d1);
#
#
#
#         marker_423375a91bd410ba5134553ddc81b683.bindPopup(popup_22a68d45de7a09dbc25034c8180938f4)
#         ;
#
#
#
#
#             var marker_6f2f2a247f519430e37c4dd53d54b843 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_bffdcd99076af50a2beb8810c8ad585e);
#
#
#         var popup_30c0d61147bfa8d83df64907c3e7ae46 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_43b3408576b73233dc26038e8f8d0a57 = $(`&lt;div id=&quot;html_43b3408576b73233dc26038e8f8d0a57&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_30c0d61147bfa8d83df64907c3e7ae46.setContent(html_43b3408576b73233dc26038e8f8d0a57);
#
#
#
#         marker_6f2f2a247f519430e37c4dd53d54b843.bindPopup(popup_30c0d61147bfa8d83df64907c3e7ae46)
#         ;
#
#
#
#
#             var marker_dda11df8591002e366fd8a0f5ddc7441 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_bffdcd99076af50a2beb8810c8ad585e);
#
#
#         var popup_7a0d9d80af2ac18d1ef20279ab54e6d2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c8143d913c57cb011df9d1691a99fb1b = $(`&lt;div id=&quot;html_c8143d913c57cb011df9d1691a99fb1b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_7a0d9d80af2ac18d1ef20279ab54e6d2.setContent(html_c8143d913c57cb011df9d1691a99fb1b);
#
#
#
#         marker_dda11df8591002e366fd8a0f5ddc7441.bindPopup(popup_7a0d9d80af2ac18d1ef20279ab54e6d2)
#         ;
#
#
#
#
#             var marker_a0a1336414f7c09e8c7364573f4dfe96 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_bffdcd99076af50a2beb8810c8ad585e);
#
#
#         var popup_9ffa91d3f16c529426c7aab0cb8eb6f5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c06a25c4185ab8821492d3b5a939adee = $(`&lt;div id=&quot;html_c06a25c4185ab8821492d3b5a939adee&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_9ffa91d3f16c529426c7aab0cb8eb6f5.setContent(html_c06a25c4185ab8821492d3b5a939adee);
#
#
#
#         marker_
