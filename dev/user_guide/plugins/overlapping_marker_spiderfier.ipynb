# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_81182c8b11c84e43ef6ef3a2ee59a0e4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_81182c8b11c84e43ef6ef3a2ee59a0e4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_81182c8b11c84e43ef6ef3a2ee59a0e4 = L.map(
#                 &quot;map_81182c8b11c84e43ef6ef3a2ee59a0e4&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1cb242a396e5e6e2b248535f3d3bae2d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1cb242a396e5e6e2b248535f3d3bae2d.addTo(map_81182c8b11c84e43ef6ef3a2ee59a0e4);
#
#
#             var marker_c763aba00e4c23bc9691ae1314068ba6 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_81182c8b11c84e43ef6ef3a2ee59a0e4);
#
#
#         var popup_a795e34c6a6d61e1a837bf5a499ce898 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_86ca7d1592fcded3e091e49be8d2392c = $(`&lt;div id=&quot;html_86ca7d1592fcded3e091e49be8d2392c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_a795e34c6a6d61e1a837bf5a499ce898.setContent(html_86ca7d1592fcded3e091e49be8d2392c);
#
#
#
#         marker_c763aba00e4c23bc9691ae1314068ba6.bindPopup(popup_a795e34c6a6d61e1a837bf5a499ce898)
#         ;
#
#
#
#
#             var marker_4d9631fe574bea29d4867698f00f9847 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_81182c8b11c84e43ef6ef3a2ee59a0e4);
#
#
#         var popup_1e9daf00d31b084a0db6aeca6c1c77de = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_45f1131773aa09edee1c184541a5a837 = $(`&lt;div id=&quot;html_45f1131773aa09edee1c184541a5a837&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_1e9daf00d31b084a0db6aeca6c1c77de.setContent(html_45f1131773aa09edee1c184541a5a837);
#
#
#
#         marker_4d9631fe574bea29d4867698f00f9847.bindPopup(popup_1e9daf00d31b084a0db6aeca6c1c77de)
#         ;
#
#
#
#
#             var marker_88ad6bc405b1ce20d6c07341f8d6670a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_81182c8b11c84e43ef6ef3a2ee59a0e4);
#
#
#         var popup_92616578149684e0fbe9e034f03d9bed = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_eee4235f9b1208a6fd11abf6903bf3af = $(`&lt;div id=&quot;html_eee4235f9b1208a6fd11abf6903bf3af&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_92616578149684e0fbe9e034f03d9bed.setContent(html_eee4235f9b1208a6fd11abf6903bf3af);
#
#
#
#         marker_88ad6bc405b1ce20d6c07341f8d6670a.bindPopup(popup_92616578149684e0fbe9e034f03d9bed)
#         ;
#
#
#
#
#             var marker_5bd50e461aa220e65f2af5eb240ac72b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_81182c8b11c84e43ef6ef3a2ee59a0e4);
#
#
#         var popup_b6a15d4e216c245d867819184dfd1193 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c752c1daba4c035a45298dc3f3afd0bf = $(`&lt;div id=&quot;html_c752c1daba4c035a45298dc3f3afd0bf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_b6a15d4e216c245d867819184dfd1193.setContent(html_c752c1daba4c035a45298dc3f3afd0bf);
#
#
#
#         marker_5bd50e461aa220e65f2af5eb240ac72b.bindPopup(popup_b6a15d4e216c245d867819184dfd1193)
#         ;
#
#
#
#
#             var marker_52f11e207592d2a6b0a579438e960d6f = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_81182c8b11c84e43ef6ef3a2ee59a0e4);
#
#
#         var popup_3f1cdb944307855c22bf4c0cf2da5f63 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d530b5c14ff1e95967a233225ea400f8 = $(`&lt;div id=&quot;html_d530b5c14ff1e95967a233225ea400f8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_3f1cdb944307855c22bf4c0cf2da5f63.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f3361e7b34642863f52db1e31178d027 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f3361e7b34642863f52db1e31178d027&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f3361e7b34642863f52db1e31178d027 = L.map(
#                 &quot;map_f3361e7b34642863f52db1e31178d027&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5f91538bba539d681477d034f9fe365e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5f91538bba539d681477d034f9fe365e.addTo(map_f3361e7b34642863f52db1e31178d027);
#
#
#             var feature_group_cefd95acb671d98261815a508229daaa = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_d1206491550069e3f72d7dc45529e4c5 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_cefd95acb671d98261815a508229daaa);
#
#
#         var popup_dde61aaa85b8c5e6a0d26ad77be8042a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_97bc3ff0988249ecb8d6c36f521b1f17 = $(`&lt;div id=&quot;html_97bc3ff0988249ecb8d6c36f521b1f17&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_dde61aaa85b8c5e6a0d26ad77be8042a.setContent(html_97bc3ff0988249ecb8d6c36f521b1f17);
#
#
#
#         marker_d1206491550069e3f72d7dc45529e4c5.bindPopup(popup_dde61aaa85b8c5e6a0d26ad77be8042a)
#         ;
#
#
#
#
#             var marker_92f501c8755ff0181979a578821c216c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_cefd95acb671d98261815a508229daaa);
#
#
#         var popup_e83ce0fc5f969bb665dfab92b0d88319 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1d12d719631bf8096771256200f2b046 = $(`&lt;div id=&quot;html_1d12d719631bf8096771256200f2b046&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_e83ce0fc5f969bb665dfab92b0d88319.setContent(html_1d12d719631bf8096771256200f2b046);
#
#
#
#         marker_92f501c8755ff0181979a578821c216c.bindPopup(popup_e83ce0fc5f969bb665dfab92b0d88319)
#         ;
#
#
#
#
#             var marker_0c47a6909c65ae08d335feae01c114a4 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_cefd95acb671d98261815a508229daaa);
#
#
#         var popup_ef2d96186d3ed5304c707314988b55e7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_81a6b2b8feabe765de46af7c628bce47 = $(`&lt;div id=&quot;html_81a6b2b8feabe765de46af7c628bce47&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_ef2d96186d3ed5304c707314988b55e7.setContent(html_81a6b2b8feabe765de46af7c628bce47);
#
#
#
#         marker_0c47a6909c65ae08d335feae01c114a4.bindPopup(popup_ef2d96186d3ed5304c707314988b55e7)
#         ;
#
#
#
#
#             var marker_d2e9faf58da31a956945868d90eb9eb4 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_cefd95acb671d98261815a508229daaa);
#
#
#         var popup_b84a5cd09170545aef5404a43f0e3ee6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e27553fa4831d76ae514c216e2ecce30 = $(`&lt;div id=&quot;html_e27553fa4831d76ae514c216e2ecce30&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_b84a5cd09170545aef5404a43f0e3ee6.setContent(html_e27553fa4831d76ae514c216e2ecce30);
#
#
#
#         marker_d2e9faf58da31a956945868d90eb9eb4.bindPopup(popup_b84a5cd09170545aef5404a43f0e3ee6)
#         ;
#
#
#
#
#             var marker_97ae64fe89550b5e6703fbaac51a12ad = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_cefd95acb671d98261815a508229daaa);
#
#
#         var popup_c976247d4faca15ba065320a34a14349 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_389123b6ed4e16dc3e9b90bc36d06721 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_389123b6ed4e16dc3e9b90bc36d06721&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_389123b6ed4e16dc3e9b90bc36d06721 = L.map(
#                 &quot;map_389123b6ed4e16dc3e9b90bc36d06721&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_66cf5b4e0c2c2a9b8b3ea03f3747ebde = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_66cf5b4e0c2c2a9b8b3ea03f3747ebde.addTo(map_389123b6ed4e16dc3e9b90bc36d06721);
#
#
#             var feature_group_05a5fb21847c2e4c37f8c9fc7e3d0b3f = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_05a5fb21847c2e4c37f8c9fc7e3d0b3f.addTo(map_389123b6ed4e16dc3e9b90bc36d06721);
#
#
#             var feature_group_sub_group_93ea6d36edfa0e870314cbb780a41a92 = L.featureGroup.subGroup(
#                 feature_group_05a5fb21847c2e4c37f8c9fc7e3d0b3f
#             );
#
#
#             var marker_8919abb47153a0edc6a499eb53677a05 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_93ea6d36edfa0e870314cbb780a41a92);
#
#
#         var popup_3a32c5c95706d1a87f98e782defcf028 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_115229fdf7f5538d0397ecd36f63dbc4 = $(`&lt;div id=&quot;html_115229fdf7f5538d0397ecd36f63dbc4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_3a32c5c95706d1a87f98e782defcf028.setContent(html_115229fdf7f5538d0397ecd36f63dbc4);
#
#
#
#         marker_8919abb47153a0edc6a499eb53677a05.bindPopup(popup_3a32c5c95706d1a87f98e782defcf028)
#         ;
#
#
#
#
#             var marker_9820a2e37ebc70753e9aa219188933cd = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_93ea6d36edfa0e870314cbb780a41a92);
#
#
#         var popup_29dd7236938b5ecb7c76ee614a01f378 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ef0c1abeb99755233b07b367cc5d7e08 = $(`&lt;div id=&quot;html_ef0c1abeb99755233b07b367cc5d7e08&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_29dd7236938b5ecb7c76ee614a01f378.setContent(html_ef0c1abeb99755233b07b367cc5d7e08);
#
#
#
#         marker_9820a2e37ebc70753e9aa219188933cd.bindPopup(popup_29dd7236938b5ecb7c76ee614a01f378)
#         ;
#
#
#
#
#             var marker_2d65c14e8254db9d98030f1384562e61 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_93ea6d36edfa0e870314cbb780a41a92);
#
#
#         var popup_8ee5df2a2f8c1e676e1177511e28bacd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0ba7cd6a5e0dc992a757d9b4d407ef22 = $(`&lt;div id=&quot;html_0ba7cd6a5e0dc992a757d9b4d407ef22&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_8ee5df2a2f8c1e676e1177511e28bacd.setContent(html_0ba7cd6a5e0dc992a757d9b4d407ef22);
#
#
#
#         marker_2d65c14e8254db9d98030f1384562e61.bindPopup(popup_8ee5df2a2f8c1e676e1177511e28bacd)
#         ;
#
#
#
#
#             var marker_7ba744cf56a5faa8a198f55029a1cb54 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_93ea6d36edfa0e870314cbb780a41a92);
#
#
#         var popup_999d87fc110833e3df3057248bce620f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ad12806622ccda65a5124dd54daa1306 = $(`&lt;div id=&quot;html_ad12806622ccda65a5124dd54daa1306&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_999d87fc110833e3df3057248bce620f.setContent(html_ad12806622ccda65a5124dd54daa1306);
#
#
#
#         marker_
