# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_96bf025152c3bbdedc23469ec1cba9ef {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_96bf025152c3bbdedc23469ec1cba9ef&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_96bf025152c3bbdedc23469ec1cba9ef = L.map(
#                 &quot;map_96bf025152c3bbdedc23469ec1cba9ef&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_24189d719f74bca85db985a0ffa83ae2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_24189d719f74bca85db985a0ffa83ae2.addTo(map_96bf025152c3bbdedc23469ec1cba9ef);
#
#
#             var marker_315c56a19a4638b386d5f12d0c1223df = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_96bf025152c3bbdedc23469ec1cba9ef);
#
#
#         var popup_c39a26b944104f6d5de886ca1ea8c1c8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_eef5d0b46df73959b793650821a9d7fa = $(`&lt;div id=&quot;html_eef5d0b46df73959b793650821a9d7fa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_c39a26b944104f6d5de886ca1ea8c1c8.setContent(html_eef5d0b46df73959b793650821a9d7fa);
#
#
#
#         marker_315c56a19a4638b386d5f12d0c1223df.bindPopup(popup_c39a26b944104f6d5de886ca1ea8c1c8)
#         ;
#
#
#
#
#             var marker_15faa66dc398c4459f0c3480e70189d7 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_96bf025152c3bbdedc23469ec1cba9ef);
#
#
#         var popup_800555a2c9d84db74edd5097bc0f8fc7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fa751c9aa6e824516abfc8c03fb4eaaa = $(`&lt;div id=&quot;html_fa751c9aa6e824516abfc8c03fb4eaaa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_800555a2c9d84db74edd5097bc0f8fc7.setContent(html_fa751c9aa6e824516abfc8c03fb4eaaa);
#
#
#
#         marker_15faa66dc398c4459f0c3480e70189d7.bindPopup(popup_800555a2c9d84db74edd5097bc0f8fc7)
#         ;
#
#
#
#
#             var marker_22e2724b52d014458ec664dc385b83cd = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_96bf025152c3bbdedc23469ec1cba9ef);
#
#
#         var popup_209c3b7238b08c617943961da3b823a7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4e78a749cebf163059a1a93cef1655d2 = $(`&lt;div id=&quot;html_4e78a749cebf163059a1a93cef1655d2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_209c3b7238b08c617943961da3b823a7.setContent(html_4e78a749cebf163059a1a93cef1655d2);
#
#
#
#         marker_22e2724b52d014458ec664dc385b83cd.bindPopup(popup_209c3b7238b08c617943961da3b823a7)
#         ;
#
#
#
#
#             var marker_b79a4c4e131ad606039f393460dc8b83 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_96bf025152c3bbdedc23469ec1cba9ef);
#
#
#         var popup_3c45ec1861781727992bee273b52c7c8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d01adf7459fa686192c70763b1fccf62 = $(`&lt;div id=&quot;html_d01adf7459fa686192c70763b1fccf62&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_3c45ec1861781727992bee273b52c7c8.setContent(html_d01adf7459fa686192c70763b1fccf62);
#
#
#
#         marker_b79a4c4e131ad606039f393460dc8b83.bindPopup(popup_3c45ec1861781727992bee273b52c7c8)
#         ;
#
#
#
#
#             var marker_47bf0aaf064389dd8f0b670a2117d041 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_96bf025152c3bbdedc23469ec1cba9ef);
#
#
#         var popup_6a7c719b5d09aa89ee5353a7115821ea = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_81f4d80926fcda04a3eb14b76f49802f = $(`&lt;div id=&quot;html_81f4d80926fcda04a3eb14b76f49802f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_6a7c719b5d09aa89ee5353a7115821ea.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_11c97b88e2863ac8a50523e6e1964041 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_11c97b88e2863ac8a50523e6e1964041&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_11c97b88e2863ac8a50523e6e1964041 = L.map(
#                 &quot;map_11c97b88e2863ac8a50523e6e1964041&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_756373c5c511441868db345c97de21cb = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_756373c5c511441868db345c97de21cb.addTo(map_11c97b88e2863ac8a50523e6e1964041);
#
#
#             var feature_group_b7be8ae7ed5b66d8d8c163a2357418c0 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_b0e219837470ef790c44d0ea1c10315c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_b7be8ae7ed5b66d8d8c163a2357418c0);
#
#
#         var popup_ccf82418f237adf7788a9141e02365fc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c3d96816c964594483432b71b65a59d6 = $(`&lt;div id=&quot;html_c3d96816c964594483432b71b65a59d6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_ccf82418f237adf7788a9141e02365fc.setContent(html_c3d96816c964594483432b71b65a59d6);
#
#
#
#         marker_b0e219837470ef790c44d0ea1c10315c.bindPopup(popup_ccf82418f237adf7788a9141e02365fc)
#         ;
#
#
#
#
#             var marker_cf515771446240d64877d4def57458da = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_b7be8ae7ed5b66d8d8c163a2357418c0);
#
#
#         var popup_4a982b9e534a565fd7f754404a16c315 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cfea4a0a90620de8a19bdf52317a306c = $(`&lt;div id=&quot;html_cfea4a0a90620de8a19bdf52317a306c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_4a982b9e534a565fd7f754404a16c315.setContent(html_cfea4a0a90620de8a19bdf52317a306c);
#
#
#
#         marker_cf515771446240d64877d4def57458da.bindPopup(popup_4a982b9e534a565fd7f754404a16c315)
#         ;
#
#
#
#
#             var marker_670baefdc5baca7fb1e6bfa15fa6ae55 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_b7be8ae7ed5b66d8d8c163a2357418c0);
#
#
#         var popup_cf8376e97c1c5f3ed071663be02e6186 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ccb050d56609126c00ab682b21fc30a9 = $(`&lt;div id=&quot;html_ccb050d56609126c00ab682b21fc30a9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_cf8376e97c1c5f3ed071663be02e6186.setContent(html_ccb050d56609126c00ab682b21fc30a9);
#
#
#
#         marker_670baefdc5baca7fb1e6bfa15fa6ae55.bindPopup(popup_cf8376e97c1c5f3ed071663be02e6186)
#         ;
#
#
#
#
#             var marker_6a01c2d2204e344745212842650d98a1 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_b7be8ae7ed5b66d8d8c163a2357418c0);
#
#
#         var popup_c80933032178017f42d398ac713f0fad = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_07567b3eaaeced73fc9a7548a8fa29a4 = $(`&lt;div id=&quot;html_07567b3eaaeced73fc9a7548a8fa29a4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_c80933032178017f42d398ac713f0fad.setContent(html_07567b3eaaeced73fc9a7548a8fa29a4);
#
#
#
#         marker_6a01c2d2204e344745212842650d98a1.bindPopup(popup_c80933032178017f42d398ac713f0fad)
#         ;
#
#
#
#
#             var marker_eaee29eff7bf6dc681799ad34c4792b2 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_b7be8ae7ed5b66d8d8c163a2357418c0);
#
#
#         var popup_3dec0ec19887c7ab724b198cc609c7b7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1f146896966216d2d1e56685184788b7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1f146896966216d2d1e56685184788b7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1f146896966216d2d1e56685184788b7 = L.map(
#                 &quot;map_1f146896966216d2d1e56685184788b7&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_508d1942e044bc361db1a4339298100a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_508d1942e044bc361db1a4339298100a.addTo(map_1f146896966216d2d1e56685184788b7);
#
#
#             var feature_group_6b0e37487fc5b5be599653fba97f4030 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_6b0e37487fc5b5be599653fba97f4030.addTo(map_1f146896966216d2d1e56685184788b7);
#
#
#             var feature_group_sub_group_68808bc876fc688726ed5ff59cb11cf9 = L.featureGroup.subGroup(
#                 feature_group_6b0e37487fc5b5be599653fba97f4030
#             );
#
#
#             var marker_888f6ad18840a4920cf768534abb4813 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_68808bc876fc688726ed5ff59cb11cf9);
#
#
#         var popup_deb6c75e05ed9177cd5e2cc29fd8ac99 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3106f0e1e78abe126d8216f1102642ad = $(`&lt;div id=&quot;html_3106f0e1e78abe126d8216f1102642ad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_deb6c75e05ed9177cd5e2cc29fd8ac99.setContent(html_3106f0e1e78abe126d8216f1102642ad);
#
#
#
#         marker_888f6ad18840a4920cf768534abb4813.bindPopup(popup_deb6c75e05ed9177cd5e2cc29fd8ac99)
#         ;
#
#
#
#
#             var marker_65841f4bb644a607ac8c1d1725afd2a6 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_68808bc876fc688726ed5ff59cb11cf9);
#
#
#         var popup_cb1f6f9ef50dc112ca4fa0240f209664 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5c37b250dfa6db04fc4903999243c7d2 = $(`&lt;div id=&quot;html_5c37b250dfa6db04fc4903999243c7d2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_cb1f6f9ef50dc112ca4fa0240f209664.setContent(html_5c37b250dfa6db04fc4903999243c7d2);
#
#
#
#         marker_65841f4bb644a607ac8c1d1725afd2a6.bindPopup(popup_cb1f6f9ef50dc112ca4fa0240f209664)
#         ;
#
#
#
#
#             var marker_825f8f77ab3a2e005424c486202425b1 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_68808bc876fc688726ed5ff59cb11cf9);
#
#
#         var popup_7d17373ad8fbc322f654a2bdbbba7a68 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_80bcce0b4a46d253604dee6636e61578 = $(`&lt;div id=&quot;html_80bcce0b4a46d253604dee6636e61578&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_7d17373ad8fbc322f654a2bdbbba7a68.setContent(html_80bcce0b4a46d253604dee6636e61578);
#
#
#
#         marker_825f8f77ab3a2e005424c486202425b1.bindPopup(popup_7d17373ad8fbc322f654a2bdbbba7a68)
#         ;
#
#
#
#
#             var marker_c067a5513c692cbef15033560d8cf861 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_68808bc876fc688726ed5ff59cb11cf9);
#
#
#         var popup_b7efa760cbad6a87c23a1a2a6795dd26 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8b5d1387dc3ae08fae1e024bb071038a = $(`&lt;div id=&quot;html_8b5d1387dc3ae08fae1e024bb071038a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_b7efa760cbad6a87c23a1a2a6795dd26.setContent(html_8b5d1387dc3ae08fae1e024bb071038a);
#
#
#
#         marker_
