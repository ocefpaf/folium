# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_835015099b62cb0c06da931ab96c49b3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_835015099b62cb0c06da931ab96c49b3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_835015099b62cb0c06da931ab96c49b3 = L.map(
#                 &quot;map_835015099b62cb0c06da931ab96c49b3&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_21f76f16831e10d99d707e9571178a25 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_21f76f16831e10d99d707e9571178a25.addTo(map_835015099b62cb0c06da931ab96c49b3);
#
#
#             var marker_48be0c0c9f71d5ef35b6d815cc30c55c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_835015099b62cb0c06da931ab96c49b3);
#
#
#         var popup_736a6f2781a3c499e9132a56e9557db7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f62c124725b155f1ad8fbdfdb06e5faf = $(`&lt;div id=&quot;html_f62c124725b155f1ad8fbdfdb06e5faf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_736a6f2781a3c499e9132a56e9557db7.setContent(html_f62c124725b155f1ad8fbdfdb06e5faf);
#
#
#
#         marker_48be0c0c9f71d5ef35b6d815cc30c55c.bindPopup(popup_736a6f2781a3c499e9132a56e9557db7)
#         ;
#
#
#
#
#             var marker_f4e07b5ee1e9aa673797ab7eccc5afdc = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_835015099b62cb0c06da931ab96c49b3);
#
#
#         var popup_bce08b0a88045482bee8fa673c7ab69c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2f5a8389573d4de2825edf38ad8c3a9b = $(`&lt;div id=&quot;html_2f5a8389573d4de2825edf38ad8c3a9b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_bce08b0a88045482bee8fa673c7ab69c.setContent(html_2f5a8389573d4de2825edf38ad8c3a9b);
#
#
#
#         marker_f4e07b5ee1e9aa673797ab7eccc5afdc.bindPopup(popup_bce08b0a88045482bee8fa673c7ab69c)
#         ;
#
#
#
#
#             var marker_04c4a39a5a82daf7654fc306ae76d36a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_835015099b62cb0c06da931ab96c49b3);
#
#
#         var popup_63d88b10d91f2a16588219a1607ce993 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f9d6d970966310389e6d70f25c20ec99 = $(`&lt;div id=&quot;html_f9d6d970966310389e6d70f25c20ec99&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_63d88b10d91f2a16588219a1607ce993.setContent(html_f9d6d970966310389e6d70f25c20ec99);
#
#
#
#         marker_04c4a39a5a82daf7654fc306ae76d36a.bindPopup(popup_63d88b10d91f2a16588219a1607ce993)
#         ;
#
#
#
#
#             var marker_5189e1376d98a7687f9ee5bf13e81647 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_835015099b62cb0c06da931ab96c49b3);
#
#
#         var popup_c472212024414a60a5adae3b20bcf696 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a8740d3cbe06b68d2f156556766a6294 = $(`&lt;div id=&quot;html_a8740d3cbe06b68d2f156556766a6294&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_c472212024414a60a5adae3b20bcf696.setContent(html_a8740d3cbe06b68d2f156556766a6294);
#
#
#
#         marker_5189e1376d98a7687f9ee5bf13e81647.bindPopup(popup_c472212024414a60a5adae3b20bcf696)
#         ;
#
#
#
#
#             var marker_31c37c225ba7e92ea6c6ad4d114773e2 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_835015099b62cb0c06da931ab96c49b3);
#
#
#         var popup_244ce8c76f535f18f3fcbab20b055a8d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7962016fcb40dee2c7f21f9b5f53ed9c = $(`&lt;div id=&quot;html_7962016fcb40dee2c7f21f9b5f53ed9c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_244ce8c76f535f18f3fcbab20b055a8d.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6e9e2ef93fb615ebd52c750aa00c24e8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6e9e2ef93fb615ebd52c750aa00c24e8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6e9e2ef93fb615ebd52c750aa00c24e8 = L.map(
#                 &quot;map_6e9e2ef93fb615ebd52c750aa00c24e8&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_91e81a21714170533410eba53a379003 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_91e81a21714170533410eba53a379003.addTo(map_6e9e2ef93fb615ebd52c750aa00c24e8);
#
#
#             var feature_group_4e35819ecb610a2c42fd9ae8ed84d9d3 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_96e312b78f05efb5cdf9c86746535fa4 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_4e35819ecb610a2c42fd9ae8ed84d9d3);
#
#
#         var popup_6e6467b058d54ef5d5161e2017551d8e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9e7782c6937792ab8f8ed1b49c03a96e = $(`&lt;div id=&quot;html_9e7782c6937792ab8f8ed1b49c03a96e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_6e6467b058d54ef5d5161e2017551d8e.setContent(html_9e7782c6937792ab8f8ed1b49c03a96e);
#
#
#
#         marker_96e312b78f05efb5cdf9c86746535fa4.bindPopup(popup_6e6467b058d54ef5d5161e2017551d8e)
#         ;
#
#
#
#
#             var marker_a8125c46af7238dfcce98cae221b493e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_4e35819ecb610a2c42fd9ae8ed84d9d3);
#
#
#         var popup_85938a0a31cc91bb31516b012f51eb34 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ef191cba54e879a53f95174e07ad9783 = $(`&lt;div id=&quot;html_ef191cba54e879a53f95174e07ad9783&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_85938a0a31cc91bb31516b012f51eb34.setContent(html_ef191cba54e879a53f95174e07ad9783);
#
#
#
#         marker_a8125c46af7238dfcce98cae221b493e.bindPopup(popup_85938a0a31cc91bb31516b012f51eb34)
#         ;
#
#
#
#
#             var marker_857b931e161df290ea11ee551d0aaad0 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_4e35819ecb610a2c42fd9ae8ed84d9d3);
#
#
#         var popup_9070b0c9de5b3d9555170fb2f114fd17 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8f87944540d485de75ecec6f23050ea9 = $(`&lt;div id=&quot;html_8f87944540d485de75ecec6f23050ea9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_9070b0c9de5b3d9555170fb2f114fd17.setContent(html_8f87944540d485de75ecec6f23050ea9);
#
#
#
#         marker_857b931e161df290ea11ee551d0aaad0.bindPopup(popup_9070b0c9de5b3d9555170fb2f114fd17)
#         ;
#
#
#
#
#             var marker_e0b37c628798478b6f8013ca7efef5f1 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_4e35819ecb610a2c42fd9ae8ed84d9d3);
#
#
#         var popup_44b1ec0a67c63b2724fdd63d5d922b48 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cbf06a7015d024b7e9a2c478f4e91d6d = $(`&lt;div id=&quot;html_cbf06a7015d024b7e9a2c478f4e91d6d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_44b1ec0a67c63b2724fdd63d5d922b48.setContent(html_cbf06a7015d024b7e9a2c478f4e91d6d);
#
#
#
#         marker_e0b37c628798478b6f8013ca7efef5f1.bindPopup(popup_44b1ec0a67c63b2724fdd63d5d922b48)
#         ;
#
#
#
#
#             var marker_2b7285a4582aca307aa5a2253caf1db9 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_4e35819ecb610a2c42fd9ae8ed84d9d3);
#
#
#         var popup_35f624fac457441a8adbc37461e940c0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6bd1da531db4dc6b7216cde3bc72a991 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6bd1da531db4dc6b7216cde3bc72a991&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6bd1da531db4dc6b7216cde3bc72a991 = L.map(
#                 &quot;map_6bd1da531db4dc6b7216cde3bc72a991&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7f30e47a1aa111fb836df8d9eae5b53f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7f30e47a1aa111fb836df8d9eae5b53f.addTo(map_6bd1da531db4dc6b7216cde3bc72a991);
#
#
#             var feature_group_d163aed446e41b7ef32a591f64a2332a = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_d163aed446e41b7ef32a591f64a2332a.addTo(map_6bd1da531db4dc6b7216cde3bc72a991);
#
#
#             var feature_group_sub_group_36db615f87d78766aa810aa3d1039d65 = L.featureGroup.subGroup(
#                 feature_group_d163aed446e41b7ef32a591f64a2332a
#             );
#
#
#             var marker_c2c9618d6baebe819bba8441e3dbe556 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_36db615f87d78766aa810aa3d1039d65);
#
#
#         var popup_14da7e1ea76e6616ea955a32009c050e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e33c101a996a0edca27c23f864e4b9e0 = $(`&lt;div id=&quot;html_e33c101a996a0edca27c23f864e4b9e0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_14da7e1ea76e6616ea955a32009c050e.setContent(html_e33c101a996a0edca27c23f864e4b9e0);
#
#
#
#         marker_c2c9618d6baebe819bba8441e3dbe556.bindPopup(popup_14da7e1ea76e6616ea955a32009c050e)
#         ;
#
#
#
#
#             var marker_f01deb8e0553e53f87b589e081c70542 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_36db615f87d78766aa810aa3d1039d65);
#
#
#         var popup_f6fc3db4a98e4554322da26496fa7d64 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c3d4dfc4c1d63e46bd185e6183503473 = $(`&lt;div id=&quot;html_c3d4dfc4c1d63e46bd185e6183503473&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_f6fc3db4a98e4554322da26496fa7d64.setContent(html_c3d4dfc4c1d63e46bd185e6183503473);
#
#
#
#         marker_f01deb8e0553e53f87b589e081c70542.bindPopup(popup_f6fc3db4a98e4554322da26496fa7d64)
#         ;
#
#
#
#
#             var marker_d5f019b3d2689006efb00ce7649b8be8 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_36db615f87d78766aa810aa3d1039d65);
#
#
#         var popup_e0ef79a5131c59b6703e2dc0a189c2d9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b034efd5a9950babe1c43868ccb4e7c4 = $(`&lt;div id=&quot;html_b034efd5a9950babe1c43868ccb4e7c4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_e0ef79a5131c59b6703e2dc0a189c2d9.setContent(html_b034efd5a9950babe1c43868ccb4e7c4);
#
#
#
#         marker_d5f019b3d2689006efb00ce7649b8be8.bindPopup(popup_e0ef79a5131c59b6703e2dc0a189c2d9)
#         ;
#
#
#
#
#             var marker_fb7f21cb5f83ae8db1e52875297f74e3 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_36db615f87d78766aa810aa3d1039d65);
#
#
#         var popup_841dc8e352c9aaee9c1fb53eed479870 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f529bc752accf10d45ad29ed6e7dd219 = $(`&lt;div id=&quot;html_f529bc752accf10d45ad29ed6e7dd219&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_841dc8e352c9aaee9c1fb53eed479870.setContent(html_f529bc752accf10d45ad29ed6e7dd219);
#
#
#
#         marker_
