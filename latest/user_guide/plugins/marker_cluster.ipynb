# %% [markdown]
# # MarkerCluster

# %%
import folium
from folium.plugins import MarkerCluster

m = folium.Map(location=[44, -73], zoom_start=5)

marker_cluster = MarkerCluster().add_to(m)

folium.Marker(
    location=[40.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="green", icon="ok-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="red", icon="remove-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -71.94],
    popup="Add popup text here.",
    icon=None,
).add_to(marker_cluster)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6f5b8b1e44e6521003da7ad2f018f370 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6f5b8b1e44e6521003da7ad2f018f370&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6f5b8b1e44e6521003da7ad2f018f370 = L.map(
#                 &quot;map_6f5b8b1e44e6521003da7ad2f018f370&quot;,
#                 {
#                     center: [44.0, -73.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e709638f867e529ce376838e11390dff = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_e709638f867e529ce376838e11390dff.addTo(map_6f5b8b1e44e6521003da7ad2f018f370);
#
#             var marker_cluster_66bdecb2e04525ecd3eb5873ae76397c = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_a6b010e5a90d6b1153fcf7e84dfc699d = L.marker(
#                 [40.67, -73.94],
#                 {}
#             ).addTo(marker_cluster_66bdecb2e04525ecd3eb5873ae76397c);
#
#
#             var icon_446a98ac5cc274735db20a5a1285e237 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;ok-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_a6b010e5a90d6b1153fcf7e84dfc699d.setIcon(icon_446a98ac5cc274735db20a5a1285e237);
#
#
#         var popup_96d856f9d88d5b687a5a5f411947a14e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1c3ffe069370c81046592b08e23984d3 = $(`&lt;div id=&quot;html_1c3ffe069370c81046592b08e23984d3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_96d856f9d88d5b687a5a5f411947a14e.setContent(html_1c3ffe069370c81046592b08e23984d3);
#
#
#
#         marker_a6b010e5a90d6b1153fcf7e84dfc699d.bindPopup(popup_96d856f9d88d5b687a5a5f411947a14e)
#         ;
#
#
#
#
#             var marker_9f8d88e6f6e9e5feb2a7e9ed70234bcc = L.marker(
#                 [44.67, -73.94],
#                 {}
#             ).addTo(marker_cluster_66bdecb2e04525ecd3eb5873ae76397c);
#
#
#             var icon_7a420dc175df03eb563dbf00a22f0559 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;remove-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_9f8d88e6f6e9e5feb2a7e9ed70234bcc.setIcon(icon_7a420dc175df03eb563dbf00a22f0559);
#
#
#         var popup_67b3c3fdf8a494de4da13da3a821a5e8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a1aa5826be7f9e5642ee065c545c7f01 = $(`&lt;div id=&quot;html_a1aa5826be7f9e5642ee065c545c7f01&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_67b3c3fdf8a494de4da13da3a821a5e8.setContent(html_a1aa5826be7f9e5642ee065c545c7f01);
#
#
#
#         marker_9f8d88e6f6e9e5feb2a7e9ed70234bcc.bindPopup(popup_67b3c3fdf8a494de4da13da3a821a5e8)
#         ;
#
#
#
#
#             var marker_aed4f3f77e742e25a8c3e62b785d5440 = L.marker(
#                 [44.67, -71.94],
#                 {}
#             ).addTo(marker_cluster_66bdecb2e04525ecd3eb5873ae76397c);
#
#
#         var popup_685440ac997ecaaf4dbaeaaf619b4f66 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ec6538968e016f7e1e70af2c41bda1ee = $(`&lt;div id=&quot;html_ec6538968e016f7e1e70af2c41bda1ee&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_685440ac997ecaaf4dbaeaaf619b4f66.setContent(html_ec6538968e016f7e1e70af2c41bda1ee);
#
#
#
#         marker_aed4f3f77e742e25a8c3e62b785d5440.bindPopup(popup_685440ac997ecaaf4dbaeaaf619b4f66)
#         ;
#
#
#
#
#                 marker_cluster_66bdecb2e04525ecd3eb5873ae76397c.addTo(map_6f5b8b1e44e6521003da7ad2f018f370);
# &lt;/script&gt;
# &lt;/html&gt;" style="pos

# %%
import numpy as np

size = 100
lons = np.random.randint(-180, 180, size=size)
lats = np.random.randint(-90, 90, size=size)

locations = list(zip(lats, lons))
popups = ["lon:{}<br>lat:{}".format(lon, lat) for (lat, lon) in locations]

# %% [markdown]
# ## Adding all icons in a single call

# %%
icon_create_function = """\
function(cluster) {
    return L.divIcon({
    html: '<b>' + cluster.getChildCount() + '</b>',
    className: 'marker-cluster marker-cluster-large',
    iconSize: new L.Point(20, 20)
    });
}"""

# %%
from folium.plugins import MarkerCluster

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)], tiles="Cartodb Positron", zoom_start=1
)

marker_cluster = MarkerCluster(
    locations=locations,
    popups=popups,
    name="1000 clustered icons",
    overlay=True,
    control=True,
    icon_create_function=icon_create_function,
)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_683b95a37e57c13651bdaa30c2a187ef {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_683b95a37e57c13651bdaa30c2a187ef&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_683b95a37e57c13651bdaa30c2a187ef = L.map(
#                 &quot;map_683b95a37e57c13651bdaa30c2a187ef&quot;,
#                 {
#                     center: [-2.5, -11.78],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_abb1fcc3108df896787c5ea4ba08ea7b = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_abb1fcc3108df896787c5ea4ba08ea7b.addTo(map_683b95a37e57c13651bdaa30c2a187ef);
#
#             var marker_cluster_281ac643db3214313f6c00d411cabc34 = L.markerClusterGroup(
#                 {}
#             );
#             marker_cluster_281ac643db3214313f6c00d411cabc34.options.iconCreateFunction =
#                 function(cluster) {
#     return L.divIcon({
#     html: &#x27;&lt;b&gt;&#x27; + cluster.getChildCount() + &#x27;&lt;/b&gt;&#x27;,
#     className: &#x27;marker-cluster marker-cluster-large&#x27;,
#     iconSize: new L.Point(20, 20)
#     });
# };
#
#
#             var marker_7491ccb04f796fe6c2b5e5cbe6b35fdf = L.marker(
#                 [-50.0, -125.0],
#                 {}
#             ).addTo(marker_cluster_281ac643db3214313f6c00d411cabc34);
#
#
#         var popup_539c6d1c95d6e00d92988fdba003e8da = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d47ec00ab007476fdace7d123dfc32d5 = $(`&lt;div id=&quot;html_d47ec00ab007476fdace7d123dfc32d5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-125&lt;br&gt;lat:-50&lt;/div&gt;`)[0];
#                 popup_539c6d1c95d6e00d92988fdba003e8da.setContent(html_d47ec00ab007476fdace7d123dfc32d5);
#
#
#
#         marker_7491ccb04f796fe6c2b5e5cbe6b35fdf.bindPopup(popup_539c6d1c95d6e00d92988fdba003e8da)
#         ;
#
#
#
#
#             var marker_dd67b6b73a30530e6c33e6d3ae2cd320 = L.marker(
#                 [31.0, -46.0],
#                 {}
#             ).addTo(marker_cluster_281ac643db3214313f6c00d411cabc34);
#
#
#         var popup_0cdd6f3cff39299d17e95d3d3782dfdd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_47a6370d9625d3cdfe4a92abecec05d6 = $(`&lt;div id=&quot;html_47a6370d9625d3cdfe4a92abecec05d6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-46&lt;br&gt;lat:31&lt;/div&gt;`)[0];
#                 popup_0cdd6f3cff39299d17e95d3d3782dfdd.setContent(html_47a6370d9625d3cdfe4a92abecec05d6);
#
#
#
#         marker_dd67b6b73a30530e6c33e6d3ae2cd320.bindPopup(popup_0cdd6f3cff39299d17e95d3d3782dfdd)
#         ;
#
#
#
#
#             var marker_76bc375989b66ea9afa0e9136483e929 = L.marker(
#                 [46.0, 134.0],
#                 {}
#             ).addTo(marker_cluster_281ac643db3214313f6c00d411cabc34);
#
#
#         var popup_6fac7b9b593bb16a931d8482556d1a31 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5f024a0cc1c5cf533f8deb7fc1923b24 = $(`&lt;div id=&quot;html_5f024a0cc1c5cf533f8deb7fc1923b24&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:134&lt;br&gt;lat:46&lt;/div&gt;`)[0];
#                 popup_6fac7b9b593bb16a931d8482556d1a31.setContent(html_5f024a0cc1c5cf533f8deb7fc1923b24);
#
#
#
#         marker_76bc375989b66ea9afa0e9136483e929.bindPopup(popup_6fac7b9b593bb16a931d8482556d1a31)
#         ;
#
#
#
#
#             var marker_5c0d77dbc510ec324bf904c9a6264c73 = L.marker(
#                 [28.0, 131.0],
#                 {}
#             ).addTo(marker_cluster_281ac643db3214313f6c00d411cabc34);
#
#
#         var popup_4a233e1abd2bf953c8699e32f6120ad9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d8ec31167d8754b58224d3a49fac55ba = $(`&lt;div id=&quot;html_d8ec31167d8754b58224d3a49fac55ba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:131&lt;b

# %% [markdown]
# ## Explicit loop allows for customization in the loop.

# %%
m = folium.Map(
    location=[np.mean(lats), np.mean(lons)],
    tiles='Cartodb Positron',
    zoom_start=1
)

marker_cluster = MarkerCluster(
    name='1000 clustered icons',
    overlay=True,
    control=False,
    icon_create_function=None
)

for k in range(size):
    location = lats[k], lons[k]
    marker = folium.Marker(location=location)
    popup = 'lon:{}<br>lat:{}'.format(location[1], location[0])
    folium.Popup(popup).add_to(marker)
    marker_cluster.add_child(marker)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m);

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ef67317996c1f0ef29874d258841ce07 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ef67317996c1f0ef29874d258841ce07&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ef67317996c1f0ef29874d258841ce07 = L.map(
#                 &quot;map_ef67317996c1f0ef29874d258841ce07&quot;,
#                 {
#                     center: [-2.5, -11.78],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_643e9a6e623e3abdd09d51db55afd57a = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_643e9a6e623e3abdd09d51db55afd57a.addTo(map_ef67317996c1f0ef29874d258841ce07);
#
#             var marker_cluster_984e80a4787ff1e6cdfa071aa97854eb = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_ea562e2dfe31a622daffa244ec4dc32a = L.marker(
#                 [-50.0, -125.0],
#                 {}
#             ).addTo(marker_cluster_984e80a4787ff1e6cdfa071aa97854eb);
#
#
#         var popup_367f02b28e0e210b244eba7f87ba579c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5403df0bebc1438e82e9cd6b4fa85293 = $(`&lt;div id=&quot;html_5403df0bebc1438e82e9cd6b4fa85293&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-125&lt;br&gt;lat:-50&lt;/div&gt;`)[0];
#                 popup_367f02b28e0e210b244eba7f87ba579c.setContent(html_5403df0bebc1438e82e9cd6b4fa85293);
#
#
#
#         marker_ea562e2dfe31a622daffa244ec4dc32a.bindPopup(popup_367f02b28e0e210b244eba7f87ba579c)
#         ;
#
#
#
#
#             var marker_5bb976b4eb56101778e63e7cd2da4f43 = L.marker(
#                 [31.0, -46.0],
#                 {}
#             ).addTo(marker_cluster_984e80a4787ff1e6cdfa071aa97854eb);
#
#
#         var popup_101a2b11c9dd71d662c52758ff1427a6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7a3993311b1b2a2f7f4d4cdc59cdfd2c = $(`&lt;div id=&quot;html_7a3993311b1b2a2f7f4d4cdc59cdfd2c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-46&lt;br&gt;lat:31&lt;/div&gt;`)[0];
#                 popup_101a2b11c9dd71d662c52758ff1427a6.setContent(html_7a3993311b1b2a2f7f4d4cdc59cdfd2c);
#
#
#
#         marker_5bb976b4eb56101778e63e7cd2da4f43.bindPopup(popup_101a2b11c9dd71d662c52758ff1427a6)
#         ;
#
#
#
#
#             var marker_39771210fcfe2242f00c18cf9bea0de6 = L.marker(
#                 [46.0, 134.0],
#                 {}
#             ).addTo(marker_cluster_984e80a4787ff1e6cdfa071aa97854eb);
#
#
#         var popup_fb6087992ba2ecf8340ea8eea3ddb5f8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5b50b6000b1ea88b18357c815d16ad5f = $(`&lt;div id=&quot;html_5b50b6000b1ea88b18357c815d16ad5f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:134&lt;br&gt;lat:46&lt;/div&gt;`)[0];
#                 popup_fb6087992ba2ecf8340ea8eea3ddb5f8.setContent(html_5b50b6000b1ea88b18357c815d16ad5f);
#
#
#
#         marker_39771210fcfe2242f00c18cf9bea0de6.bindPopup(popup_fb6087992ba2ecf8340ea8eea3ddb5f8)
#         ;
#
#
#
#
#             var marker_fc0da72cea6d69aba6eb380c850b0993 = L.marker(
#                 [28.0, 131.0],
#                 {}
#             ).addTo(marker_cluster_984e80a4787ff1e6cdfa071aa97854eb);
#
#
#         var popup_0d1e65fd78f6272517bbb82414ae8f56 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8237dfbdf88386679b14afe2ddf7c536 = $(`&lt;div id=&quot;html_8237dfbdf88386679b14afe2ddf7c536&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:131&lt;br&gt;lat:28&lt;/div&gt;`)[0];
#                 popup_0d1e65fd78f6272517bbb82414ae8f56.setContent(html_8237dfbdf88386679b14afe2ddf7c536);
#
#
#
#         marker_fc0da72cea6d69aba6eb380c850b0993.bindPopup(popup_0d1e65fd78f6272517bbb82414ae8f56)
#         ;
#
#
#
#
#             var marker_97f711dc4a9c3b34d9a9329241ec427

# %% [markdown]
# ## FastMarkerCluster
#
# `FastMarkerCluster` is not as flexible as MarkerCluster but, like the name suggests, it is faster.

# %%
from folium.plugins import FastMarkerCluster

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)],
    tiles='Cartodb Positron',
    zoom_start=1
)

FastMarkerCluster(data=list(zip(lats, lons))).add_to(m)

folium.LayerControl().add_to(m);

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_27ea9714ac2acc9e81f652d37dae0ca7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_27ea9714ac2acc9e81f652d37dae0ca7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_27ea9714ac2acc9e81f652d37dae0ca7 = L.map(
#                 &quot;map_27ea9714ac2acc9e81f652d37dae0ca7&quot;,
#                 {
#                     center: [-2.5, -11.78],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_72e5f2708faa0506f6e847316b7501a4 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_72e5f2708faa0506f6e847316b7501a4.addTo(map_27ea9714ac2acc9e81f652d37dae0ca7);
#
#             var fast_marker_cluster_d7635755a37cb853f2d7c6c0b611e70f = (function(){
#
#                 var callback = function (row) {
#                     var icon = L.AwesomeMarkers.icon();
#                     var marker = L.marker(new L.LatLng(row[0], row[1]));
#                     marker.setIcon(icon);
#                     return marker;
#                 };
#
#                 var data = [[-50.0, -125.0], [31.0, -46.0], [46.0, 134.0], [28.0, 131.0], [9.0, -55.0], [13.0, -127.0], [-41.0, -85.0], [-6.0, 53.0], [-38.0, 21.0], [-47.0, 84.0], [69.0, -165.0], [-79.0, -10.0], [4.0, 114.0], [58.0, -137.0], [68.0, 90.0], [17.0, 34.0], [48.0, 104.0], [25.0, 5.0], [-65.0, -109.0], [-10.0, -24.0], [-67.0, 131.0], [-10.0, 82.0], [-32.0, 66.0], [-59.0, -129.0], [39.0, 18.0], [-82.0, -43.0], [-71.0, 10.0], [-68.0, -78.0], [-20.0, 61.0], [-15.0, -33.0], [17.0, 121.0], [44.0, 68.0], [-37.0, 168.0], [54.0, 107.0], [-25.0, -83.0], [21.0, -57.0], [73.0, 33.0], [38.0, -128.0], [-51.0, -161.0], [-79.0, -110.0], [17.0, 159.0], [39.0, -127.0], [63.0, 100.0], [-44.0, -143.0], [-10.0, 34.0], [18.0, -164.0], [-4.0, 166.0], [78.0, -134.0], [39.0, 134.0], [57.0, -33.0], [-21.0, -40.0], [-73.0, -178.0], [39.0, 175.0], [-78.0, 17.0], [-38.0, 158.0], [5.0, -97.0], [-70.0, -145.0], [51.0, 105.0], [-52.0, -161.0], [-26.0, -115.0], [-72.0, -141.0], [-67.0, 17.0], [-24.0, -50.0], [22.0, -177.0], [62.0, 97.0], [-63.0, 95.0], [47.0, -9.0], [-46.0, -155.0], [-18.0, -47.0], [-43.0, -114.0], [-28.0, -93.0], [-80.0, 70.0], [10.0, -162.0], [-59.0, 57.0], [-23.0, -126.0], [66.0, -57.0], [8.0, -101.0], [-16.0, -15.0], [-8.0, -24.0], [41.0, -148.0], [-9.0, -136.0], [20.0, 178.0], [15.0, 172.0], [-16.0, -157.0], [-29.0, -91.0], [-78.0, -33.0], [26.0, 52.0], [62.0, -49.0], [43.0, 162.0], [87.0, -119.0], [57.0, 113.0], [63.0, 130.0], [2.0, 71.0], [45.0, 118.0], [88.0, 76.0], [-59.0, -108.0], [-78.0, 60.0], [70.0, -179.0], [-13.0, 90.0], [5.0, -86.0]];
#                 var cluster = L.markerClusterGroup({});
#
#                 for (var i = 0; i &lt; data.length; i++) {
#                     var row = data[i];
#                     var marker = callback(row);
#                     marker.addTo(cluster);
#                 }
#
#                 cluster.addTo(map_27ea9714ac2acc9e81f652d37dae0ca7);
#                 return cluster;
#             })();
#
#
#                 fast_marker_cluster_d7635755a37cb853f2d7c6c0b611e70f.addTo(map_27ea9714ac2acc9e81f652d37dae0ca7);
#
#             var layer_control_d61f49995f153f3066d78f33e9d8b071_layers = {
#                 base_layers : {
#                     &quot;cartodbpositron&quot; : tile_layer_72e5f2708faa0506f6e847316b7501a4,
#                 },
#                 overlays :  {
#                     &quot;macro_element_d7635755a37cb853f2d7c6c0b611e70f&quot; : fast_marker_cluster_d7635755a37cb853f2d7c6c0b611e70f,
#                 },
#             };
#             let layer_control_d61f49995f153f3066d78f33e9d8b071 = L.control.layers(
#                 layer_control_d61f49995f153f3066d78f33e9d8b071_layers.base_layers,
#                 layer_control_d61f49995f153f3066d78f33e9d8b071_layers.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: true, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_27ea9714ac2acc9e81f652d37dae0ca7);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0

# %%
callback = """\
function (row) {
    var icon, marker;
    icon = L.AwesomeMarkers.icon({
        icon: "map-marker", markerColor: "red"});
    marker = L.marker(new L.LatLng(row[0], row[1]));
    marker.setIcon(icon);
    return marker;
};
"""

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)], tiles="Cartodb Positron", zoom_start=1
)

FastMarkerCluster(data=list(zip(lats, lons)), callback=callback).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c40c6be2c1d02e3cfbf8617d32de8fcb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c40c6be2c1d02e3cfbf8617d32de8fcb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c40c6be2c1d02e3cfbf8617d32de8fcb = L.map(
#                 &quot;map_c40c6be2c1d02e3cfbf8617d32de8fcb&quot;,
#                 {
#                     center: [-2.5, -11.78],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9cf881e0c8ffba5f5f167d5c2c7b0af5 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_9cf881e0c8ffba5f5f167d5c2c7b0af5.addTo(map_c40c6be2c1d02e3cfbf8617d32de8fcb);
#
#             var fast_marker_cluster_67fc8899c58309033ac8b282a8fd3520 = (function(){
#                 var callback = function (row) {
#     var icon, marker;
#     icon = L.AwesomeMarkers.icon({
#         icon: &quot;map-marker&quot;, markerColor: &quot;red&quot;});
#     marker = L.marker(new L.LatLng(row[0], row[1]));
#     marker.setIcon(icon);
#     return marker;
# };
# ;
#
#                 var data = [[-50.0, -125.0], [31.0, -46.0], [46.0, 134.0], [28.0, 131.0], [9.0, -55.0], [13.0, -127.0], [-41.0, -85.0], [-6.0, 53.0], [-38.0, 21.0], [-47.0, 84.0], [69.0, -165.0], [-79.0, -10.0], [4.0, 114.0], [58.0, -137.0], [68.0, 90.0], [17.0, 34.0], [48.0, 104.0], [25.0, 5.0], [-65.0, -109.0], [-10.0, -24.0], [-67.0, 131.0], [-10.0, 82.0], [-32.0, 66.0], [-59.0, -129.0], [39.0, 18.0], [-82.0, -43.0], [-71.0, 10.0], [-68.0, -78.0], [-20.0, 61.0], [-15.0, -33.0], [17.0, 121.0], [44.0, 68.0], [-37.0, 168.0], [54.0, 107.0], [-25.0, -83.0], [21.0, -57.0], [73.0, 33.0], [38.0, -128.0], [-51.0, -161.0], [-79.0, -110.0], [17.0, 159.0], [39.0, -127.0], [63.0, 100.0], [-44.0, -143.0], [-10.0, 34.0], [18.0, -164.0], [-4.0, 166.0], [78.0, -134.0], [39.0, 134.0], [57.0, -33.0], [-21.0, -40.0], [-73.0, -178.0], [39.0, 175.0], [-78.0, 17.0], [-38.0, 158.0], [5.0, -97.0], [-70.0, -145.0], [51.0, 105.0], [-52.0, -161.0], [-26.0, -115.0], [-72.0, -141.0], [-67.0, 17.0], [-24.0, -50.0], [22.0, -177.0], [62.0, 97.0], [-63.0, 95.0], [47.0, -9.0], [-46.0, -155.0], [-18.0, -47.0], [-43.0, -114.0], [-28.0, -93.0], [-80.0, 70.0], [10.0, -162.0], [-59.0, 57.0], [-23.0, -126.0], [66.0, -57.0], [8.0, -101.0], [-16.0, -15.0], [-8.0, -24.0], [41.0, -148.0], [-9.0, -136.0], [20.0, 178.0], [15.0, 172.0], [-16.0, -157.0], [-29.0, -91.0], [-78.0, -33.0], [26.0, 52.0], [62.0, -49.0], [43.0, 162.0], [87.0, -119.0], [57.0, 113.0], [63.0, 130.0], [2.0, 71.0], [45.0, 118.0], [88.0, 76.0], [-59.0, -108.0], [-78.0, 60.0], [70.0, -179.0], [-13.0, 90.0], [5.0, -86.0]];
#                 var cluster = L.markerClusterGroup({});
#
#                 for (var i = 0; i &lt; data.length; i++) {
#                     var row = data[i];
#                     var marker = callback(row);
#                     marker.addTo(cluster);
#                 }
#
#                 cluster.addTo(map_c40c6be2c1d02e3cfbf8617d32de8fcb);
#                 return cluster;
#             })();
#
#
#                 fast_marker_cluster_67fc8899c58309033ac8b282a8fd3520.addTo(map_c40c6be2c1d02e3cfbf8617d32de8fcb);
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
