# %% [markdown]
# # MarkerCluster

# %%
import folium
from folium.plugins import MarkerCluster

m = folium.Map(location=[44, -73], zoom_start=5)

marker_cluster = MarkerCluster().add_to(m)

folium.Marker(
    location=[40.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="green", icon="ok-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="red", icon="remove-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -71.94],
    popup="Add popup text here.",
    icon=None,
).add_to(marker_cluster)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2e66abb04840cafbcf2b2d6f0cb085a1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2e66abb04840cafbcf2b2d6f0cb085a1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2e66abb04840cafbcf2b2d6f0cb085a1 = L.map(
#                 &quot;map_2e66abb04840cafbcf2b2d6f0cb085a1&quot;,
#                 {
#                     center: [44.0, -73.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fb8918edd766a2392ced836b80641690 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_fb8918edd766a2392ced836b80641690.addTo(map_2e66abb04840cafbcf2b2d6f0cb085a1);
#
#
#             var marker_cluster_103189a0d0a2763cd9ed1ac63cafa308 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_fc141fd9054ca1dc3227a8d2ed23827c = L.marker(
#                 [40.67, -73.94],
#                 {}
#             ).addTo(marker_cluster_103189a0d0a2763cd9ed1ac63cafa308);
#
#
#             var icon_9252fd618ff471b7bb6dfa023550f6ce = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;ok-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_fc141fd9054ca1dc3227a8d2ed23827c.setIcon(icon_9252fd618ff471b7bb6dfa023550f6ce);
#
#
#         var popup_be982c7358d4f6c15cf6f48d3dab75eb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_23c24f8bf5aaefc9f29320e1a67bdb6d = $(`&lt;div id=&quot;html_23c24f8bf5aaefc9f29320e1a67bdb6d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_be982c7358d4f6c15cf6f48d3dab75eb.setContent(html_23c24f8bf5aaefc9f29320e1a67bdb6d);
#
#
#
#         marker_fc141fd9054ca1dc3227a8d2ed23827c.bindPopup(popup_be982c7358d4f6c15cf6f48d3dab75eb)
#         ;
#
#
#
#
#             var marker_8040c137e95bfe999b1f428294837d55 = L.marker(
#                 [44.67, -73.94],
#                 {}
#             ).addTo(marker_cluster_103189a0d0a2763cd9ed1ac63cafa308);
#
#
#             var icon_69f177d09d1d8d680a02567bb98bf5e3 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;remove-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_8040c137e95bfe999b1f428294837d55.setIcon(icon_69f177d09d1d8d680a02567bb98bf5e3);
#
#
#         var popup_d4d00a3f964814a94448bb0d8f9d1ca8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_421a04554fc5307980adc93c31fc58db = $(`&lt;div id=&quot;html_421a04554fc5307980adc93c31fc58db&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_d4d00a3f964814a94448bb0d8f9d1ca8.setContent(html_421a04554fc5307980adc93c31fc58db);
#
#
#
#         marker_8040c137e95bfe999b1f428294837d55.bindPopup(popup_d4d00a3f964814a94448bb0d8f9d1ca8)
#         ;
#
#
#
#
#             var marker_5e46c0b646cae47fdd270d672287ceaa = L.marker(
#                 [44.67, -71.94],
#                 {}
#             ).addTo(marker_cluster_103189a0d0a2763cd9ed1ac63cafa308);
#
#
#         var popup_6981d953fd86fde9abf93d3823caf15d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8383cc67b0005f5e2d7544dade729aa0 = $(`&lt;div id=&quot;html_8383cc67b0005f5e2d7544dade729aa0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_6981d953fd86fde9abf93d3823caf15d.setContent(html_8383cc67b0005f5e2d7544dade729aa0);
#
#
#
#         marker_5e46c0b646cae47fdd270d672287ceaa.bindPopup(popup_6981d953fd86fde9abf93d3823caf15d)
#         ;
#
#
#
#
#             marker_cluster_103189a0d0a2763cd9ed1ac63cafa308.addTo(map_2e66abb04840cafbcf2b2d6f0cb085a1);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallo

# %%
import numpy as np

size = 100
lons = np.random.randint(-180, 180, size=size)
lats = np.random.randint(-90, 90, size=size)

locations = list(zip(lats, lons))
popups = ["lon:{}<br>lat:{}".format(lon, lat) for (lat, lon) in locations]

# %% [markdown]
# ## Adding all icons in a single call

# %%
icon_create_function = """\
function(cluster) {
    return L.divIcon({
    html: '<b>' + cluster.getChildCount() + '</b>',
    className: 'marker-cluster marker-cluster-large',
    iconSize: new L.Point(20, 20)
    });
}"""

# %%
from folium.plugins import MarkerCluster

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)], tiles="Cartodb Positron", zoom_start=1
)

marker_cluster = MarkerCluster(
    locations=locations,
    popups=popups,
    name="1000 clustered icons",
    overlay=True,
    control=True,
    icon_create_function=icon_create_function,
)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d35ceea139cf5f9d41cd87c33bb8ef0a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d35ceea139cf5f9d41cd87c33bb8ef0a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d35ceea139cf5f9d41cd87c33bb8ef0a = L.map(
#                 &quot;map_d35ceea139cf5f9d41cd87c33bb8ef0a&quot;,
#                 {
#                     center: [5.51, 3.87],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_897247265454d39f43dcc38038e17f2a = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_897247265454d39f43dcc38038e17f2a.addTo(map_d35ceea139cf5f9d41cd87c33bb8ef0a);
#
#
#             var marker_cluster_7d118d6fd6ab45c2d7ef364215fb16e4 = L.markerClusterGroup(
#                 {}
#             );
#             marker_cluster_7d118d6fd6ab45c2d7ef364215fb16e4.options.iconCreateFunction =
#                 function(cluster) {
#     return L.divIcon({
#     html: &#x27;&lt;b&gt;&#x27; + cluster.getChildCount() + &#x27;&lt;/b&gt;&#x27;,
#     className: &#x27;marker-cluster marker-cluster-large&#x27;,
#     iconSize: new L.Point(20, 20)
#     });
# };
#
#
#             var marker_52ce118a5b31e558db1d0d66c331d29c = L.marker(
#                 [11.0, -62.0],
#                 {}
#             ).addTo(marker_cluster_7d118d6fd6ab45c2d7ef364215fb16e4);
#
#
#         var popup_055acd546324fee0567000ddb6fae89c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6c4c8706605c0a750346de3669395175 = $(`&lt;div id=&quot;html_6c4c8706605c0a750346de3669395175&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-62&lt;br&gt;lat:11&lt;/div&gt;`)[0];
#                 popup_055acd546324fee0567000ddb6fae89c.setContent(html_6c4c8706605c0a750346de3669395175);
#
#
#
#         marker_52ce118a5b31e558db1d0d66c331d29c.bindPopup(popup_055acd546324fee0567000ddb6fae89c)
#         ;
#
#
#
#
#             var marker_fb57982041cf7cce98955b833502157b = L.marker(
#                 [79.0, 138.0],
#                 {}
#             ).addTo(marker_cluster_7d118d6fd6ab45c2d7ef364215fb16e4);
#
#
#         var popup_29256498b378858f92b0ceebfa63ef2c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ee3305daa0a383b2b10df638747474cd = $(`&lt;div id=&quot;html_ee3305daa0a383b2b10df638747474cd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:138&lt;br&gt;lat:79&lt;/div&gt;`)[0];
#                 popup_29256498b378858f92b0ceebfa63ef2c.setContent(html_ee3305daa0a383b2b10df638747474cd);
#
#
#
#         marker_fb57982041cf7cce98955b833502157b.bindPopup(popup_29256498b378858f92b0ceebfa63ef2c)
#         ;
#
#
#
#
#             var marker_e9b4ba1d423546d79a965a522a758ff4 = L.marker(
#                 [79.0, 61.0],
#                 {}
#             ).addTo(marker_cluster_7d118d6fd6ab45c2d7ef364215fb16e4);
#
#
#         var popup_118943fc745057d65433548c77a95256 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5bbb74ab3411b925e158f1f7243df49b = $(`&lt;div id=&quot;html_5bbb74ab3411b925e158f1f7243df49b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:61&lt;br&gt;lat:79&lt;/div&gt;`)[0];
#                 popup_118943fc745057d65433548c77a95256.setContent(html_5bbb74ab3411b925e158f1f7243df49b);
#
#
#
#         marker_e9b4ba1d423546d79a965a522a758ff4.bindPopup(popup_118943fc745057d65433548c77a95256)
#         ;
#
#
#
#
#             var marker_c583df52b20ceb77421fc2005326352e = L.marker(
#                 [-9.0, -117.0],
#                 {}
#             ).addTo(marker_cluster_7d118d6fd6ab45c2d7ef364215fb16e4);
#
#
#         var popup_bc27dd4ac12ee1a2dfc3dee11eaa1eec = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c317d7f9c583a5b5a8b71d1d6750c8cc = $(`&lt;div id=&quot;html_c317d7f9c583a5b5a8b71d1d6750c8cc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-117&lt;br&gt;lat:-9&lt;/div&gt;`)[0];
#                 popup_bc27dd4ac12ee1a2dfc3dee11eaa1eec.setContent(html_c317d7f9c583a5b5a8b71d1d6750c8cc);
#
#
#
#         marker_c583df52b20ceb77421f

# %% [markdown]
# ## Explicit loop allows for customization in the loop.

# %%
m = folium.Map(
    location=[np.mean(lats), np.mean(lons)],
    tiles='Cartodb Positron',
    zoom_start=1
)

marker_cluster = MarkerCluster(
    name='1000 clustered icons',
    overlay=True,
    control=False,
    icon_create_function=None
)

for k in range(size):
    location = lats[k], lons[k]
    marker = folium.Marker(location=location)
    popup = 'lon:{}<br>lat:{}'.format(location[1], location[0])
    folium.Popup(popup).add_to(marker)
    marker_cluster.add_child(marker)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m);

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ce2b33f3041799c616618c4c11ae5cdc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ce2b33f3041799c616618c4c11ae5cdc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ce2b33f3041799c616618c4c11ae5cdc = L.map(
#                 &quot;map_ce2b33f3041799c616618c4c11ae5cdc&quot;,
#                 {
#                     center: [5.51, 3.87],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9b3d52052e4a4998640244f2cb6ef547 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_9b3d52052e4a4998640244f2cb6ef547.addTo(map_ce2b33f3041799c616618c4c11ae5cdc);
#
#
#             var marker_cluster_4f229cf12bf239604e1daaa19f83636b = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_7909db8b6577c5ec009ae6f7acce8dfa = L.marker(
#                 [11.0, -62.0],
#                 {}
#             ).addTo(marker_cluster_4f229cf12bf239604e1daaa19f83636b);
#
#
#         var popup_1103dfb7d48a7438cb1b3de0e247f608 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_54e3d85b597ce52ccd336c4ce1bd0e03 = $(`&lt;div id=&quot;html_54e3d85b597ce52ccd336c4ce1bd0e03&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-62&lt;br&gt;lat:11&lt;/div&gt;`)[0];
#                 popup_1103dfb7d48a7438cb1b3de0e247f608.setContent(html_54e3d85b597ce52ccd336c4ce1bd0e03);
#
#
#
#         marker_7909db8b6577c5ec009ae6f7acce8dfa.bindPopup(popup_1103dfb7d48a7438cb1b3de0e247f608)
#         ;
#
#
#
#
#             var marker_c4c92f8ec5441fa8a652045a3f1e265d = L.marker(
#                 [79.0, 138.0],
#                 {}
#             ).addTo(marker_cluster_4f229cf12bf239604e1daaa19f83636b);
#
#
#         var popup_f4f589e66192871cf368d91afd58d93a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c1450a23f2e112add2dce79fd41547c4 = $(`&lt;div id=&quot;html_c1450a23f2e112add2dce79fd41547c4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:138&lt;br&gt;lat:79&lt;/div&gt;`)[0];
#                 popup_f4f589e66192871cf368d91afd58d93a.setContent(html_c1450a23f2e112add2dce79fd41547c4);
#
#
#
#         marker_c4c92f8ec5441fa8a652045a3f1e265d.bindPopup(popup_f4f589e66192871cf368d91afd58d93a)
#         ;
#
#
#
#
#             var marker_48a123d3b10ed5c070bfc05d8551c2ec = L.marker(
#                 [79.0, 61.0],
#                 {}
#             ).addTo(marker_cluster_4f229cf12bf239604e1daaa19f83636b);
#
#
#         var popup_b96bf58bdbd529e89fc33720c0d68da7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3faf457b6e63f61b7b1adb60fd73ce23 = $(`&lt;div id=&quot;html_3faf457b6e63f61b7b1adb60fd73ce23&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:61&lt;br&gt;lat:79&lt;/div&gt;`)[0];
#                 popup_b96bf58bdbd529e89fc33720c0d68da7.setContent(html_3faf457b6e63f61b7b1adb60fd73ce23);
#
#
#
#         marker_48a123d3b10ed5c070bfc05d8551c2ec.bindPopup(popup_b96bf58bdbd529e89fc33720c0d68da7)
#         ;
#
#
#
#
#             var marker_db85e4b20ce38eff3562f5518c445d80 = L.marker(
#                 [-9.0, -117.0],
#                 {}
#             ).addTo(marker_cluster_4f229cf12bf239604e1daaa19f83636b);
#
#
#         var popup_41eea6b1c174fc8a88967a016c073117 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_87d564cb707e696a7006311760a0a8f3 = $(`&lt;div id=&quot;html_87d564cb707e696a7006311760a0a8f3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-117&lt;br&gt;lat:-9&lt;/div&gt;`)[0];
#                 popup_41eea6b1c174fc8a88967a016c073117.setContent(html_87d564cb707e696a7006311760a0a8f3);
#
#
#
#         marker_db85e4b20ce38eff3562f5518c445d80.bindPopup(popup_41eea6b1c174fc8a88967a016c073117)
#         ;
#
#
#
#
#             var marker_bcaf722407baba1e4a7174f654985e24 = L.marker(
#                 [63.0, -59.0],
#                 {}
#             ).addTo(marker_cluster_4f229cf12bf239604e1daaa19f83636b);
#
#
#         var popup_2a3502631e4dcbf56fbb0f68578d

# %% [markdown]
# ## FastMarkerCluster
#
# `FastMarkerCluster` is not as flexible as MarkerCluster but, like the name suggests, it is faster.

# %%
from folium.plugins import FastMarkerCluster

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)],
    tiles='Cartodb Positron',
    zoom_start=1
)

FastMarkerCluster(data=list(zip(lats, lons))).add_to(m)

folium.LayerControl().add_to(m);

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_07329293dff988f7cf792455cf0832a0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_07329293dff988f7cf792455cf0832a0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_07329293dff988f7cf792455cf0832a0 = L.map(
#                 &quot;map_07329293dff988f7cf792455cf0832a0&quot;,
#                 {
#                     center: [5.51, 3.87],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_46c6e0856fd6cfd864ec77f988e182c3 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_46c6e0856fd6cfd864ec77f988e182c3.addTo(map_07329293dff988f7cf792455cf0832a0);
#
#
#             var fast_marker_cluster_7a6b4c73b6bc258405a11bd644ff4cbf = (function(){
#
#                 var callback = function (row) {
#                     var icon = L.AwesomeMarkers.icon();
#                     var marker = L.marker(new L.LatLng(row[0], row[1]));
#                     marker.setIcon(icon);
#                     return marker;
#                 };
#
#                 var data = [[11.0, -62.0], [79.0, 138.0], [79.0, 61.0], [-9.0, -117.0], [63.0, -59.0], [18.0, 25.0], [-65.0, 101.0], [-43.0, -10.0], [-19.0, -127.0], [-3.0, -167.0], [30.0, -23.0], [64.0, 175.0], [-68.0, -51.0], [88.0, 149.0], [41.0, 101.0], [70.0, 100.0], [-8.0, 121.0], [-77.0, 164.0], [-20.0, 55.0], [-51.0, -47.0], [-47.0, -101.0], [33.0, 126.0], [42.0, 51.0], [-40.0, 72.0], [-22.0, -146.0], [-49.0, -145.0], [20.0, -1.0], [73.0, -121.0], [-28.0, 60.0], [2.0, -99.0], [82.0, -129.0], [44.0, 70.0], [65.0, -103.0], [48.0, 153.0], [1.0, -77.0], [41.0, -31.0], [-12.0, 26.0], [27.0, -127.0], [-29.0, -87.0], [13.0, -136.0], [43.0, 110.0], [17.0, -137.0], [23.0, 179.0], [-17.0, 130.0], [-89.0, 29.0], [85.0, 175.0], [24.0, 92.0], [-40.0, 155.0], [-88.0, -18.0], [-71.0, -97.0], [-20.0, -42.0], [68.0, -108.0], [-8.0, -44.0], [14.0, -147.0], [-29.0, 13.0], [-57.0, -139.0], [-7.0, -87.0], [-80.0, 75.0], [-16.0, 51.0], [22.0, 42.0], [67.0, -21.0], [1.0, -113.0], [84.0, 176.0], [-38.0, 124.0], [-66.0, -18.0], [28.0, 164.0], [3.0, -142.0], [-32.0, -155.0], [-23.0, -24.0], [-3.0, -160.0], [73.0, 128.0], [70.0, -180.0], [-33.0, 171.0], [24.0, 43.0], [59.0, 115.0], [20.0, -66.0], [-32.0, 158.0], [-65.0, 20.0], [-45.0, -75.0], [32.0, 29.0], [-42.0, 52.0], [27.0, 37.0], [-14.0, 48.0], [-14.0, -69.0], [-18.0, 96.0], [36.0, 13.0], [76.0, -120.0], [60.0, -124.0], [-16.0, 33.0], [87.0, 36.0], [83.0, -73.0], [40.0, 156.0], [65.0, 26.0], [-39.0, 177.0], [63.0, -71.0], [26.0, -51.0], [-72.0, -109.0], [-75.0, -40.0], [7.0, 52.0], [-71.0, 130.0]];
#                 var cluster = L.markerClusterGroup({});
#
#                 for (var i = 0; i &lt; data.length; i++) {
#                     var row = data[i];
#                     var marker = callback(row);
#                     marker.addTo(cluster);
#                 }
#
#                 cluster.addTo(map_07329293dff988f7cf792455cf0832a0);
#                 return cluster;
#             })();
#
#
#             fast_marker_cluster_7a6b4c73b6bc258405a11bd644ff4cbf.addTo(map_07329293dff988f7cf792455cf0832a0);
#
#
#             var layer_control_912746bc4e9d017b2edcbe8960ba8d96_layers = {
#                 base_layers : {
#                     &quot;cartodbpositron&quot; : tile_layer_46c6e0856fd6cfd864ec77f988e182c3,
#                 },
#                 overlays :  {
#                     &quot;macro_element_7a6b4c73b6bc258405a11bd644ff4cbf&quot; : fast_marker_cluster_7a6b4c73b6bc258405a11bd644ff4cbf,
#                 },
#             };
#             let layer_control_912746bc4e9d017b2edcbe8960ba8d96 = L.control.layers(
#                 layer_control_912746bc4e9d017b2edcbe8960ba8d96_layers.base_layers,
#                 layer_control_912746bc4e9d017b2edcbe8960ba8d96_layers.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: true, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_07329293dff988f7cf792455cf0832a0);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
callback = """\
function (row) {
    var icon, marker;
    icon = L.AwesomeMarkers.icon({
        icon: "map-marker", markerColor: "red"});
    marker = L.marker(new L.LatLng(row[0], row[1]));
    marker.setIcon(icon);
    return marker;
};
"""

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)], tiles="Cartodb Positron", zoom_start=1
)

FastMarkerCluster(data=list(zip(lats, lons)), callback=callback).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0e3b4cfa54e6dbc0dd3eb65aadc129bd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0e3b4cfa54e6dbc0dd3eb65aadc129bd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0e3b4cfa54e6dbc0dd3eb65aadc129bd = L.map(
#                 &quot;map_0e3b4cfa54e6dbc0dd3eb65aadc129bd&quot;,
#                 {
#                     center: [5.51, 3.87],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_efb105fa2da8e99edd38904dea107930 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_efb105fa2da8e99edd38904dea107930.addTo(map_0e3b4cfa54e6dbc0dd3eb65aadc129bd);
#
#
#             var fast_marker_cluster_c44393ef9109f84990255d133a6cdd7f = (function(){
#                 var callback = function (row) {
#     var icon, marker;
#     icon = L.AwesomeMarkers.icon({
#         icon: &quot;map-marker&quot;, markerColor: &quot;red&quot;});
#     marker = L.marker(new L.LatLng(row[0], row[1]));
#     marker.setIcon(icon);
#     return marker;
# };
# ;
#
#                 var data = [[11.0, -62.0], [79.0, 138.0], [79.0, 61.0], [-9.0, -117.0], [63.0, -59.0], [18.0, 25.0], [-65.0, 101.0], [-43.0, -10.0], [-19.0, -127.0], [-3.0, -167.0], [30.0, -23.0], [64.0, 175.0], [-68.0, -51.0], [88.0, 149.0], [41.0, 101.0], [70.0, 100.0], [-8.0, 121.0], [-77.0, 164.0], [-20.0, 55.0], [-51.0, -47.0], [-47.0, -101.0], [33.0, 126.0], [42.0, 51.0], [-40.0, 72.0], [-22.0, -146.0], [-49.0, -145.0], [20.0, -1.0], [73.0, -121.0], [-28.0, 60.0], [2.0, -99.0], [82.0, -129.0], [44.0, 70.0], [65.0, -103.0], [48.0, 153.0], [1.0, -77.0], [41.0, -31.0], [-12.0, 26.0], [27.0, -127.0], [-29.0, -87.0], [13.0, -136.0], [43.0, 110.0], [17.0, -137.0], [23.0, 179.0], [-17.0, 130.0], [-89.0, 29.0], [85.0, 175.0], [24.0, 92.0], [-40.0, 155.0], [-88.0, -18.0], [-71.0, -97.0], [-20.0, -42.0], [68.0, -108.0], [-8.0, -44.0], [14.0, -147.0], [-29.0, 13.0], [-57.0, -139.0], [-7.0, -87.0], [-80.0, 75.0], [-16.0, 51.0], [22.0, 42.0], [67.0, -21.0], [1.0, -113.0], [84.0, 176.0], [-38.0, 124.0], [-66.0, -18.0], [28.0, 164.0], [3.0, -142.0], [-32.0, -155.0], [-23.0, -24.0], [-3.0, -160.0], [73.0, 128.0], [70.0, -180.0], [-33.0, 171.0], [24.0, 43.0], [59.0, 115.0], [20.0, -66.0], [-32.0, 158.0], [-65.0, 20.0], [-45.0, -75.0], [32.0, 29.0], [-42.0, 52.0], [27.0, 37.0], [-14.0, 48.0], [-14.0, -69.0], [-18.0, 96.0], [36.0, 13.0], [76.0, -120.0], [60.0, -124.0], [-16.0, 33.0], [87.0, 36.0], [83.0, -73.0], [40.0, 156.0], [65.0, 26.0], [-39.0, 177.0], [63.0, -71.0], [26.0, -51.0], [-72.0, -109.0], [-75.0, -40.0], [7.0, 52.0], [-71.0, 130.0]];
#                 var cluster = L.markerClusterGroup({});
#
#                 for (var i = 0; i &lt; data.length; i++) {
#                     var row = data[i];
#                     var marker = callback(row);
#                     marker.addTo(cluster);
#                 }
#
#                 cluster.addTo(map_0e3b4cfa54e6dbc0dd3eb65aadc129bd);
#                 return cluster;
#             })();
#
#
#             fast_marker_cluster_c44393ef9109f84990255d133a6cdd7f.addTo(map_0e3b4cfa54e6dbc0dd3eb65aadc129bd);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
