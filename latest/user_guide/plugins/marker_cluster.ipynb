# %% [markdown]
# # MarkerCluster

# %%
import folium
from folium.plugins import MarkerCluster

m = folium.Map(location=[44, -73], zoom_start=5)

marker_cluster = MarkerCluster().add_to(m)

folium.Marker(
    location=[40.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="green", icon="ok-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="red", icon="remove-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -71.94],
    popup="Add popup text here.",
    icon=None,
).add_to(marker_cluster)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bec613e3d40c4aad2ba5ac59fee69644 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bec613e3d40c4aad2ba5ac59fee69644&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bec613e3d40c4aad2ba5ac59fee69644 = L.map(
#                 &quot;map_bec613e3d40c4aad2ba5ac59fee69644&quot;,
#                 {
#                     center: [44.0, -73.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b8b133f0fbd463f5443c33f77d61d143 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_b8b133f0fbd463f5443c33f77d61d143.addTo(map_bec613e3d40c4aad2ba5ac59fee69644);
#
#
#             var marker_cluster_57cb8d7ab0ab806a2f70efcbed0c2552 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_f67dae8db88687d22dc096e4679d859d = L.marker(
#                 [40.67, -73.94],
#                 {}
#             ).addTo(marker_cluster_57cb8d7ab0ab806a2f70efcbed0c2552);
#
#
#             var icon_75b52498bf7ad0b70a8415a0fdb1da6b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;ok-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f67dae8db88687d22dc096e4679d859d.setIcon(icon_75b52498bf7ad0b70a8415a0fdb1da6b);
#
#
#         var popup_6b717220ee23cb62d2b4f75e89cd2202 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3482e68525a577a777d472680b16086c = $(`&lt;div id=&quot;html_3482e68525a577a777d472680b16086c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_6b717220ee23cb62d2b4f75e89cd2202.setContent(html_3482e68525a577a777d472680b16086c);
#
#
#
#         marker_f67dae8db88687d22dc096e4679d859d.bindPopup(popup_6b717220ee23cb62d2b4f75e89cd2202)
#         ;
#
#
#
#
#             var marker_36c22cd910f3bb614f1aabe3e77a8318 = L.marker(
#                 [44.67, -73.94],
#                 {}
#             ).addTo(marker_cluster_57cb8d7ab0ab806a2f70efcbed0c2552);
#
#
#             var icon_83dfb92d97d1ec991778ca512f539183 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;remove-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_36c22cd910f3bb614f1aabe3e77a8318.setIcon(icon_83dfb92d97d1ec991778ca512f539183);
#
#
#         var popup_1e3232a465937abe4845231f8f8f4c88 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_39f113ae71b066d710f110f0ce8a9ca1 = $(`&lt;div id=&quot;html_39f113ae71b066d710f110f0ce8a9ca1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_1e3232a465937abe4845231f8f8f4c88.setContent(html_39f113ae71b066d710f110f0ce8a9ca1);
#
#
#
#         marker_36c22cd910f3bb614f1aabe3e77a8318.bindPopup(popup_1e3232a465937abe4845231f8f8f4c88)
#         ;
#
#
#
#
#             var marker_18a619b6f1921cfe13a97cbcff958f79 = L.marker(
#                 [44.67, -71.94],
#                 {}
#             ).addTo(marker_cluster_57cb8d7ab0ab806a2f70efcbed0c2552);
#
#
#         var popup_5f121ad6f4e85104f814d72d9dc33129 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6bb3b9129615ceb8705148cfbea5ef58 = $(`&lt;div id=&quot;html_6bb3b9129615ceb8705148cfbea5ef58&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_5f121ad6f4e85104f814d72d9dc33129.setContent(html_6bb3b9129615ceb8705148cfbea5ef58);
#
#
#
#         marker_18a619b6f1921cfe13a97cbcff958f79.bindPopup(popup_5f121ad6f4e85104f814d72d9dc33129)
#         ;
#
#
#
#
#             marker_cluster_57cb8d7ab0ab806a2f70efcbed0c2552.addTo(map_bec613e3d40c4aad2ba5ac59fee69644);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallo

# %%
import numpy as np

size = 100
lons = np.random.randint(-180, 180, size=size)
lats = np.random.randint(-90, 90, size=size)

locations = list(zip(lats, lons))
popups = ["lon:{}<br>lat:{}".format(lon, lat) for (lat, lon) in locations]

# %% [markdown]
# ## Adding all icons in a single call

# %%
icon_create_function = """\
function(cluster) {
    return L.divIcon({
    html: '<b>' + cluster.getChildCount() + '</b>',
    className: 'marker-cluster marker-cluster-large',
    iconSize: new L.Point(20, 20)
    });
}"""

# %%
from folium.plugins import MarkerCluster

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)], tiles="Cartodb Positron", zoom_start=1
)

marker_cluster = MarkerCluster(
    locations=locations,
    popups=popups,
    name="1000 clustered icons",
    overlay=True,
    control=True,
    icon_create_function=icon_create_function,
)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b61a1157afa1428285ae1d2de92eb224 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b61a1157afa1428285ae1d2de92eb224&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b61a1157afa1428285ae1d2de92eb224 = L.map(
#                 &quot;map_b61a1157afa1428285ae1d2de92eb224&quot;,
#                 {
#                     center: [-7.8, 12.86],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_07bca437314304a1d18dbc6959601dad = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_07bca437314304a1d18dbc6959601dad.addTo(map_b61a1157afa1428285ae1d2de92eb224);
#
#
#             var marker_cluster_cebe70499223ebe900792ae9b473c212 = L.markerClusterGroup(
#                 {}
#             );
#             marker_cluster_cebe70499223ebe900792ae9b473c212.options.iconCreateFunction =
#                 function(cluster) {
#     return L.divIcon({
#     html: &#x27;&lt;b&gt;&#x27; + cluster.getChildCount() + &#x27;&lt;/b&gt;&#x27;,
#     className: &#x27;marker-cluster marker-cluster-large&#x27;,
#     iconSize: new L.Point(20, 20)
#     });
# };
#
#
#             var marker_fe8aa2b7adc5bd1bf3636c6fea5acabe = L.marker(
#                 [-52.0, -139.0],
#                 {}
#             ).addTo(marker_cluster_cebe70499223ebe900792ae9b473c212);
#
#
#         var popup_045e1fc8193921577022e95431e7a180 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_334e1a24e57515037950cefbd5898326 = $(`&lt;div id=&quot;html_334e1a24e57515037950cefbd5898326&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-139&lt;br&gt;lat:-52&lt;/div&gt;`)[0];
#                 popup_045e1fc8193921577022e95431e7a180.setContent(html_334e1a24e57515037950cefbd5898326);
#
#
#
#         marker_fe8aa2b7adc5bd1bf3636c6fea5acabe.bindPopup(popup_045e1fc8193921577022e95431e7a180)
#         ;
#
#
#
#
#             var marker_5481ba193eedfd71ef2a4ccd787720db = L.marker(
#                 [14.0, -73.0],
#                 {}
#             ).addTo(marker_cluster_cebe70499223ebe900792ae9b473c212);
#
#
#         var popup_acf9b92b50d7e8fa26ad8f663970a982 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_044b48b9f8fd4cb8b0de7bb51e185816 = $(`&lt;div id=&quot;html_044b48b9f8fd4cb8b0de7bb51e185816&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-73&lt;br&gt;lat:14&lt;/div&gt;`)[0];
#                 popup_acf9b92b50d7e8fa26ad8f663970a982.setContent(html_044b48b9f8fd4cb8b0de7bb51e185816);
#
#
#
#         marker_5481ba193eedfd71ef2a4ccd787720db.bindPopup(popup_acf9b92b50d7e8fa26ad8f663970a982)
#         ;
#
#
#
#
#             var marker_47c422db71f6508d6493baef01857517 = L.marker(
#                 [40.0, -119.0],
#                 {}
#             ).addTo(marker_cluster_cebe70499223ebe900792ae9b473c212);
#
#
#         var popup_b2509102662fb5035e883fd7934f7c5b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0da81c357afa3add96b38160ef4d3b94 = $(`&lt;div id=&quot;html_0da81c357afa3add96b38160ef4d3b94&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-119&lt;br&gt;lat:40&lt;/div&gt;`)[0];
#                 popup_b2509102662fb5035e883fd7934f7c5b.setContent(html_0da81c357afa3add96b38160ef4d3b94);
#
#
#
#         marker_47c422db71f6508d6493baef01857517.bindPopup(popup_b2509102662fb5035e883fd7934f7c5b)
#         ;
#
#
#
#
#             var marker_0175b138e6eb5a87d822bcffe196dd2d = L.marker(
#                 [-40.0, 70.0],
#                 {}
#             ).addTo(marker_cluster_cebe70499223ebe900792ae9b473c212);
#
#
#         var popup_788aa92d5bef14d7eac070fa2da8f18b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d4269eed623f7c879ead076e3a9d466d = $(`&lt;div id=&quot;html_d4269eed623f7c879ead076e3a9d466d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:70&lt;br&gt;lat:-40&lt;/div&gt;`)[0];
#                 popup_788aa92d5bef14d7eac070fa2da8f18b.setContent(html_d4269eed623f7c879ead076e3a9d466d);
#
#
#
#         marker_0175b138e6eb5

# %% [markdown]
# ## Explicit loop allows for customization in the loop.

# %%
m = folium.Map(
    location=[np.mean(lats), np.mean(lons)],
    tiles='Cartodb Positron',
    zoom_start=1
)

marker_cluster = MarkerCluster(
    name='1000 clustered icons',
    overlay=True,
    control=False,
    icon_create_function=None
)

for k in range(size):
    location = lats[k], lons[k]
    marker = folium.Marker(location=location)
    popup = 'lon:{}<br>lat:{}'.format(location[1], location[0])
    folium.Popup(popup).add_to(marker)
    marker_cluster.add_child(marker)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m);

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fdb27bc515df0215af86679c000a18f2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fdb27bc515df0215af86679c000a18f2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fdb27bc515df0215af86679c000a18f2 = L.map(
#                 &quot;map_fdb27bc515df0215af86679c000a18f2&quot;,
#                 {
#                     center: [-7.8, 12.86],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1fb95b21f5293830e3ae064d61a6a163 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_1fb95b21f5293830e3ae064d61a6a163.addTo(map_fdb27bc515df0215af86679c000a18f2);
#
#
#             var marker_cluster_3b9684ff88e7f26e0ce7b10c229c1fc1 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_7d8a39f344320ae110b34d150f6c63a2 = L.marker(
#                 [-52.0, -139.0],
#                 {}
#             ).addTo(marker_cluster_3b9684ff88e7f26e0ce7b10c229c1fc1);
#
#
#         var popup_a298aacd70bb37d76ce4f20801f58702 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d080ad3521c9c9b42dbc95d8e38c4416 = $(`&lt;div id=&quot;html_d080ad3521c9c9b42dbc95d8e38c4416&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-139&lt;br&gt;lat:-52&lt;/div&gt;`)[0];
#                 popup_a298aacd70bb37d76ce4f20801f58702.setContent(html_d080ad3521c9c9b42dbc95d8e38c4416);
#
#
#
#         marker_7d8a39f344320ae110b34d150f6c63a2.bindPopup(popup_a298aacd70bb37d76ce4f20801f58702)
#         ;
#
#
#
#
#             var marker_8f460729304ab8df4d6fc04f59bdcfd9 = L.marker(
#                 [14.0, -73.0],
#                 {}
#             ).addTo(marker_cluster_3b9684ff88e7f26e0ce7b10c229c1fc1);
#
#
#         var popup_e9bfb35b35784f3200a5922c6fb39ed3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_adf29253a68d61da9c018f13db2aefa9 = $(`&lt;div id=&quot;html_adf29253a68d61da9c018f13db2aefa9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-73&lt;br&gt;lat:14&lt;/div&gt;`)[0];
#                 popup_e9bfb35b35784f3200a5922c6fb39ed3.setContent(html_adf29253a68d61da9c018f13db2aefa9);
#
#
#
#         marker_8f460729304ab8df4d6fc04f59bdcfd9.bindPopup(popup_e9bfb35b35784f3200a5922c6fb39ed3)
#         ;
#
#
#
#
#             var marker_f0b9687b0f5b0c4be56e4432b8f6db76 = L.marker(
#                 [40.0, -119.0],
#                 {}
#             ).addTo(marker_cluster_3b9684ff88e7f26e0ce7b10c229c1fc1);
#
#
#         var popup_bda390ea9f70adcf19986a3e33e9ef38 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fd454cd7fafd8ced0448587002623a3d = $(`&lt;div id=&quot;html_fd454cd7fafd8ced0448587002623a3d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-119&lt;br&gt;lat:40&lt;/div&gt;`)[0];
#                 popup_bda390ea9f70adcf19986a3e33e9ef38.setContent(html_fd454cd7fafd8ced0448587002623a3d);
#
#
#
#         marker_f0b9687b0f5b0c4be56e4432b8f6db76.bindPopup(popup_bda390ea9f70adcf19986a3e33e9ef38)
#         ;
#
#
#
#
#             var marker_d4ca3af100487e38139fa3e992ca9109 = L.marker(
#                 [-40.0, 70.0],
#                 {}
#             ).addTo(marker_cluster_3b9684ff88e7f26e0ce7b10c229c1fc1);
#
#
#         var popup_7c84033472ea2ad120b92dd760680a5b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_65b0906601804a3f530ca3d4b1ff29fc = $(`&lt;div id=&quot;html_65b0906601804a3f530ca3d4b1ff29fc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:70&lt;br&gt;lat:-40&lt;/div&gt;`)[0];
#                 popup_7c84033472ea2ad120b92dd760680a5b.setContent(html_65b0906601804a3f530ca3d4b1ff29fc);
#
#
#
#         marker_d4ca3af100487e38139fa3e992ca9109.bindPopup(popup_7c84033472ea2ad120b92dd760680a5b)
#         ;
#
#
#
#
#             var marker_e2542c8e1130fc600be9cd64216fb00d = L.marker(
#                 [-54.0, 109.0],
#                 {}
#             ).addTo(marker_cluster_3b9684ff88e7f26e0ce7b10c229c1fc1);
#
#
#         var popup_7ffc96bc7b740afcd1fd

# %% [markdown]
# ## FastMarkerCluster
#
# `FastMarkerCluster` is not as flexible as MarkerCluster but, like the name suggests, it is faster.

# %%
from folium.plugins import FastMarkerCluster

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)],
    tiles='Cartodb Positron',
    zoom_start=1
)

FastMarkerCluster(data=list(zip(lats, lons))).add_to(m)

folium.LayerControl().add_to(m);

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_01521e30dc4a29cb77cf3bbac90cdc00 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_01521e30dc4a29cb77cf3bbac90cdc00&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_01521e30dc4a29cb77cf3bbac90cdc00 = L.map(
#                 &quot;map_01521e30dc4a29cb77cf3bbac90cdc00&quot;,
#                 {
#                     center: [-7.8, 12.86],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_be4dcc75a93f84e1df58b8d1a49502d3 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_be4dcc75a93f84e1df58b8d1a49502d3.addTo(map_01521e30dc4a29cb77cf3bbac90cdc00);
#
#
#             var fast_marker_cluster_609675a4270a61f32d192eed841eb133 = (function(){
#
#                 var callback = function (row) {
#                     var icon = L.AwesomeMarkers.icon();
#                     var marker = L.marker(new L.LatLng(row[0], row[1]));
#                     marker.setIcon(icon);
#                     return marker;
#                 };
#
#                 var data = [[-52.0, -139.0], [14.0, -73.0], [40.0, -119.0], [-40.0, 70.0], [-54.0, 109.0], [-38.0, 88.0], [-37.0, 123.0], [26.0, 81.0], [41.0, -5.0], [-34.0, 166.0], [-66.0, 102.0], [85.0, -158.0], [26.0, -125.0], [21.0, 132.0], [70.0, -21.0], [-38.0, -50.0], [-23.0, -86.0], [18.0, -176.0], [-59.0, 3.0], [73.0, -66.0], [-43.0, 81.0], [61.0, -52.0], [63.0, -144.0], [-77.0, -65.0], [-54.0, 89.0], [-48.0, -42.0], [-29.0, 140.0], [-67.0, -101.0], [-83.0, 152.0], [-14.0, -150.0], [-3.0, -28.0], [-51.0, -90.0], [18.0, 159.0], [-27.0, 103.0], [-25.0, 157.0], [66.0, 101.0], [15.0, 136.0], [33.0, 133.0], [58.0, -174.0], [-39.0, -52.0], [44.0, 82.0], [28.0, 167.0], [83.0, -143.0], [-11.0, 12.0], [7.0, 164.0], [-63.0, -68.0], [-66.0, 116.0], [-7.0, 15.0], [7.0, 127.0], [-77.0, 129.0], [-26.0, -104.0], [66.0, -94.0], [-32.0, -85.0], [86.0, -102.0], [61.0, 154.0], [-43.0, -87.0], [25.0, 65.0], [46.0, 84.0], [12.0, -68.0], [-21.0, -68.0], [87.0, 25.0], [-42.0, 120.0], [-82.0, -101.0], [65.0, 169.0], [21.0, -160.0], [-52.0, -18.0], [-71.0, 48.0], [20.0, 124.0], [-43.0, 90.0], [-79.0, 153.0], [62.0, -114.0], [-61.0, 177.0], [-52.0, 69.0], [-72.0, -84.0], [-6.0, -39.0], [57.0, -20.0], [-80.0, 6.0], [-15.0, 148.0], [30.0, -160.0], [-15.0, 57.0], [-59.0, 159.0], [-79.0, 65.0], [-3.0, -92.0], [-18.0, -47.0], [47.0, -37.0], [-52.0, -85.0], [65.0, -31.0], [23.0, 76.0], [-2.0, 74.0], [-53.0, 89.0], [-75.0, -18.0], [-25.0, -144.0], [8.0, 87.0], [0.0, 143.0], [-67.0, -37.0], [-10.0, -122.0], [4.0, 142.0], [43.0, -19.0], [-68.0, 81.0], [23.0, 7.0]];
#                 var cluster = L.markerClusterGroup({});
#
#                 for (var i = 0; i &lt; data.length; i++) {
#                     var row = data[i];
#                     var marker = callback(row);
#                     marker.addTo(cluster);
#                 }
#
#                 cluster.addTo(map_01521e30dc4a29cb77cf3bbac90cdc00);
#                 return cluster;
#             })();
#
#
#             fast_marker_cluster_609675a4270a61f32d192eed841eb133.addTo(map_01521e30dc4a29cb77cf3bbac90cdc00);
#
#
#             var layer_control_7a75147d636ed22342b3a2eed41b21e4_layers = {
#                 base_layers : {
#                     &quot;cartodbpositron&quot; : tile_layer_be4dcc75a93f84e1df58b8d1a49502d3,
#                 },
#                 overlays :  {
#                     &quot;macro_element_609675a4270a61f32d192eed841eb133&quot; : fast_marker_cluster_609675a4270a61f32d192eed841eb133,
#                 },
#             };
#             let layer_control_7a75147d636ed22342b3a2eed41b21e4 = L.control.layers(
#                 layer_control_7a75147d636ed22342b3a2eed41b21e4_layers.base_layers,
#                 layer_control_7a75147d636ed22342b3a2eed41b21e4_layers.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: true, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_01521e30dc4a29cb77cf3bbac90cdc00);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
callback = """\
function (row) {
    var icon, marker;
    icon = L.AwesomeMarkers.icon({
        icon: "map-marker", markerColor: "red"});
    marker = L.marker(new L.LatLng(row[0], row[1]));
    marker.setIcon(icon);
    return marker;
};
"""

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)], tiles="Cartodb Positron", zoom_start=1
)

FastMarkerCluster(data=list(zip(lats, lons)), callback=callback).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4a3879b050bf04c27aa712e054c048aa {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4a3879b050bf04c27aa712e054c048aa&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4a3879b050bf04c27aa712e054c048aa = L.map(
#                 &quot;map_4a3879b050bf04c27aa712e054c048aa&quot;,
#                 {
#                     center: [-7.8, 12.86],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c74f24c286eb95bdd38cf4fe6842b4d2 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_c74f24c286eb95bdd38cf4fe6842b4d2.addTo(map_4a3879b050bf04c27aa712e054c048aa);
#
#
#             var fast_marker_cluster_66539890fc829a74cd14593af7abd51e = (function(){
#                 var callback = function (row) {
#     var icon, marker;
#     icon = L.AwesomeMarkers.icon({
#         icon: &quot;map-marker&quot;, markerColor: &quot;red&quot;});
#     marker = L.marker(new L.LatLng(row[0], row[1]));
#     marker.setIcon(icon);
#     return marker;
# };
# ;
#
#                 var data = [[-52.0, -139.0], [14.0, -73.0], [40.0, -119.0], [-40.0, 70.0], [-54.0, 109.0], [-38.0, 88.0], [-37.0, 123.0], [26.0, 81.0], [41.0, -5.0], [-34.0, 166.0], [-66.0, 102.0], [85.0, -158.0], [26.0, -125.0], [21.0, 132.0], [70.0, -21.0], [-38.0, -50.0], [-23.0, -86.0], [18.0, -176.0], [-59.0, 3.0], [73.0, -66.0], [-43.0, 81.0], [61.0, -52.0], [63.0, -144.0], [-77.0, -65.0], [-54.0, 89.0], [-48.0, -42.0], [-29.0, 140.0], [-67.0, -101.0], [-83.0, 152.0], [-14.0, -150.0], [-3.0, -28.0], [-51.0, -90.0], [18.0, 159.0], [-27.0, 103.0], [-25.0, 157.0], [66.0, 101.0], [15.0, 136.0], [33.0, 133.0], [58.0, -174.0], [-39.0, -52.0], [44.0, 82.0], [28.0, 167.0], [83.0, -143.0], [-11.0, 12.0], [7.0, 164.0], [-63.0, -68.0], [-66.0, 116.0], [-7.0, 15.0], [7.0, 127.0], [-77.0, 129.0], [-26.0, -104.0], [66.0, -94.0], [-32.0, -85.0], [86.0, -102.0], [61.0, 154.0], [-43.0, -87.0], [25.0, 65.0], [46.0, 84.0], [12.0, -68.0], [-21.0, -68.0], [87.0, 25.0], [-42.0, 120.0], [-82.0, -101.0], [65.0, 169.0], [21.0, -160.0], [-52.0, -18.0], [-71.0, 48.0], [20.0, 124.0], [-43.0, 90.0], [-79.0, 153.0], [62.0, -114.0], [-61.0, 177.0], [-52.0, 69.0], [-72.0, -84.0], [-6.0, -39.0], [57.0, -20.0], [-80.0, 6.0], [-15.0, 148.0], [30.0, -160.0], [-15.0, 57.0], [-59.0, 159.0], [-79.0, 65.0], [-3.0, -92.0], [-18.0, -47.0], [47.0, -37.0], [-52.0, -85.0], [65.0, -31.0], [23.0, 76.0], [-2.0, 74.0], [-53.0, 89.0], [-75.0, -18.0], [-25.0, -144.0], [8.0, 87.0], [0.0, 143.0], [-67.0, -37.0], [-10.0, -122.0], [4.0, 142.0], [43.0, -19.0], [-68.0, 81.0], [23.0, 7.0]];
#                 var cluster = L.markerClusterGroup({});
#
#                 for (var i = 0; i &lt; data.length; i++) {
#                     var row = data[i];
#                     var marker = callback(row);
#                     marker.addTo(cluster);
#                 }
#
#                 cluster.addTo(map_4a3879b050bf04c27aa712e054c048aa);
#                 return cluster;
#             })();
#
#
#             fast_marker_cluster_66539890fc829a74cd14593af7abd51e.addTo(map_4a3879b050bf04c27aa712e054c048aa);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
